# %% [markdown]
# This notebook shows how to solve the problem as a multi-class classification by finding candidate points based on geographic location.<br>
# Similarity as a string, such as edit distance and LCS (Longest Common Subsequence), was used for the features of the candidate points.<br>
# <br>
# Inference is made on test data only, but the code for training is left commented out.<br>
# <br>
# In addition, making the matches bidirectional as a post-processing step improved the score by about 1%.<br>
# <br>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import seaborn as sns
import pickle
import json
import re
import time
import sys
from requests import get
import multiprocessing
import joblib
# !pip uninstall lightgbm -y
# !pip install lightgbm==3.3.1

class CFG:
    seed = 46
    target = "point_of_interest"
    n_neighbors = 6
    n_splits = 3
    debug = False

    expID = ""
    if "google.colab" in sys.modules:
        expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0].split("-")[0]

random.seed(CFG.seed)
os.environ["PYTHONHASHSEED"] = str(CFG.seed)
np.random.seed(CFG.seed)

plt.rcParams["font.size"] = 13
warnings.filterwarnings('ignore')

# %cd /content/drive/MyDrive/Kaggle/Foursquare/Notebook
# Out:
# Found existing installation: lightgbm 2.2.3
# Uninstalling lightgbm-2.2.3:
#   Successfully uninstalled lightgbm-2.2.3
# Collecting lightgbm==3.3.1
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.4.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (1.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.1
# /content/drive/MyDrive/Kaggle/Foursquare/Notebook

# %%
OUTPUT_DIR = '../Output'
if not os.path.exists(os.path.join(OUTPUT_DIR, CFG.expID)):
    os.makedirs(os.path.join(OUTPUT_DIR, CFG.expID))

# %%
train = pd.read_csv("../Input/train.csv")
test = pd.read_csv("../Input/test.csv")
test[CFG.target] = "TEST"

train.head(1)
# Out:
#                  id                  name   latitude  longitude      address  \
# 0  E_000001272c6c5d  Café Stad Oudenaarde  50.859975   3.634196  Abdijstraat
#
#          city            state   zip country  url phone categories  \
# 0  Nederename  Oost-Vlaanderen  9700      BE  NaN   NaN       Bars
#
#   point_of_interest
# 0  P_677e840bb6fc7e

# %% [markdown]
# # Devide Train Data into about 600K×2

# %%
kf = GroupKFold(n_splits=2)
for i, (trn_idx, val_idx) in enumerate(kf.split(train, train[CFG.target], train[CFG.target])):
    train.loc[val_idx, "set"] = i
train["set"].value_counts()
# Out:
# 1.0    569406
# 0.0    569406
# Name: set, dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor

def add_neighbor_features(df):
    dfs = []
    columns = ['id', 'name', 'address', 'city', 'state',
           'zip', 'country', 'url', 'phone', 'categories']
    for c in columns:
        if c != "id":
            df[c] = df[c].astype(str).str.lower()

    for country, country_df in tqdm(df.groupby("country")):
        country_df = country_df.reset_index(drop=True)
        
        knn = KNeighborsRegressor(n_neighbors=min(len(country_df), CFG.n_neighbors), 
                                  metric='haversine', n_jobs=-1)
        knn.fit(country_df[['latitude','longitude']], country_df.index)
        dists, nears = knn.kneighbors(country_df[['latitude','longitude']], return_distance=True)
        
        targets = country_df[CFG.target].values
        for i in range(min(len(country_df), CFG.n_neighbors)):
            country_df[f"d_near_{i}"] = dists[:, i]
            country_df[f"near_target_{i}"] = targets[nears[:, i]]
            for c in columns:
                country_df[f"near_{c}_{i}"] = country_df[c].values[nears[:, i]]

        for i in range(min(len(country_df), CFG.n_neighbors), CFG.n_neighbors):
            country_df[f"d_near_{i}"] = np.nan
            country_df[f"near_target_{i}"] = np.nan
            for c in columns:
                country_df[f"near_{c}_{i}"] = np.nan

        dfs.append(country_df)
    df = pd.concat(dfs).reset_index(drop=True)
    return df

train = pd.concat([
    add_neighbor_features(train[train["set"]==0]), 
    add_neighbor_features(train[train["set"]==1]), 
])
test = add_neighbor_features(test)

train.head(1)
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]
#   0%|          | 0/211 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#                  id        name   latitude  longitude            address  \
# 0  E_1104d3664585a4  mamá maría  42.508166   1.525205  av. meritxell, 25
#
#                city                         state  zip country  url  ...  \
# 0  andorra la vella  parròquia d'andorra la vella  nan      ad  nan  ...
#
#           near_id_5            near_name_5 near_address_5  near_city_5  \
# 0  E_c93b28d5249c89  burger king near szgm             ad           ad
#
#    near_state_5 near_zip_5 near_country_5 near_url_5 near_phone_5  \
# 0           nan        nan             ad        nan          nan
#
#       near_categories_5
# 0  american restaurants
#
# [1 rows x 86 columns]

# %%
if CFG.debug:
    train = train[:10000]

# %% [markdown]
# # Create Target

# %%
print(CFG.target)
# Out:
# point_of_interest

# %%
for i in range(CFG.n_neighbors):
    train.loc[train[CFG.target]==train[f"near_target_{i}"], "target"] = i
train.head()
# Out:
#                  id                                             name  \
# 0  E_1104d3664585a4                                       mamá maría
# 1  E_1514d74b987ae1                       ahotels piolets park & spa
# 2  E_206f06060f193d                                    la borda xica
# 3  E_20b7920b07557d  escola de esquí el forn de canillo, grandvalira
# 4  E_4a34a5012e88c3                                     pic negre 11
#
#     latitude  longitude                   address              city  \
# 0  42.508166   1.525205         av. meritxell, 25  andorra la vella
# 1  42.578021   1.663907  carretera de soldeu, s/n            soldeu
# 2  42.571045   1.487248            cap del carrer        la massana
# 3  42.556103   1.616165   el forn de canillo, s/n           canillo
# 4  42.546688   1.513963                       nan        la massana
#
#                           state    zip country                      url  ...  \
# 0  parròquia d'andorra la vella    nan      ad                      nan  ...
# 1                       andorra  ad100      ad  http://www.ahotels.com/  ...
# 2                           nan    nan      ad                      nan  ...
# 3                       canillo  ad100      ad                      nan  ...
# 4                           nan  ad400      ad                      nan  ...
#
#                                near_name_5  \
# 0                    burger king near szgm
# 1  vallnord - pal arinsal (sector arinsal)
# 2                             pic negre 12
# 3                               borda xica
# 4                       el forn de canillo
#
#                           near_address_5 near_city_5  near_state_5  \
# 0                                     ad          ad           nan
# 1  carretera d'arinsal. ed. comallemple.     arinsal       arinsal
# 2                              sanantoni  la massana           nan
# 3                      c/ cap del carrer  la massana        ordino
# 4                                    nan     canillo           nan
#
#    near_zip_5 near_country_5               near_url_5 near_phone_5  \
# 0         nan             ad                      nan          nan
# 1       ad400             ad  http://www.vallnord.com       737020
# 2       ad400             ad                      nan       737745
# 3         nan             ad                      nan    376837190
# 4         nan             ad                      nan          nan
#
#       near_categories_5 target
# 0  american restaurants    1.0
# 1             ski areas    1.0
# 2  sporting goods shops    0.0
# 3           restaurants    1.0
# 4             ski areas    0.0
#
# [5 rows x 87 columns]

# %%
plt.hist(train["target"], bins=sorted(train["target"].unique()))
plt.grid()
plt.xlabel("target")
plt.show()

# %% [markdown]
# # Check Maximum Score

# %%
# https://www.kaggle.com/code/columbia2131/foursquare-iou-metrics
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

def get_score(input_df: pd.DataFrame):
    scores = []
    for id_str, matches in zip(input_df['id'].to_numpy(), input_df['matches'].to_numpy()):
        targets = poi2ids[id2poi[id_str]]
        preds = set(matches.split())
        score = len((targets & preds)) / len((targets | preds))
        scores.append(score)
    scores = np.array(scores)
    return scores.mean()

id2poi = get_id2poi(train)
poi2ids = get_poi2ids(train)

# %%
scores = []

train["matches"] = ""
for i in tqdm(range(CFG.n_neighbors)):
    idx = train[CFG.target]==train[f"near_target_{i}"]
    train.loc[idx, "matches"] += " " + train.loc[idx, f"near_id_{i}"]
    scores.append(get_score(train))
train["mathces"] = None
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
plt.subplots(figsize=(8, 3), facecolor="white")
plt.plot(range(CFG.n_neighbors), scores, marker="o")
plt.grid()
plt.xlabel("# of candidates")
plt.ylabel("Maximum Score")
plt.ylim([0.6, 1.0])
plt.show()

# %%
# del train
# gc.collect()

# %% [markdown]
# # Feature Engineering

# %%
if "google.colab" in sys.modules:
    # !pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 4.0 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 52.8 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.2
#   Downloading jarowinkler-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 74.5 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.2 rapidfuzz-2.0.11

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
import Levenshtein
import difflib
# !pip install fuzzywuzzy
from fuzzywuzzy import fuzz

def _add_distance_features(args):
    _, df = args

    columns = ['name', 'address', 'city', 'state',
           'zip', 'country', 'url', 'phone', 'categories']

    for i in tqdm(range(CFG.n_neighbors)):
        for c in columns:
            geshs = []
            levens = []
            jaros = []
            lcss = []
            partial_ratio = []
            for str1, str2 in df[[f"near_{c}_0", f"near_{c}_{i}"]].values.astype(str):
                if str1==str1 and str2==str2:
                    geshs.append(difflib.SequenceMatcher(None, str1, str2).ratio())
                    levens.append(Levenshtein.distance(str1, str2))
                    jaros.append(Levenshtein.jaro_winkler(str1, str2))
                    lcss.append(LCS(str(str1), str(str2)))
                    partial_ratio.append(fuzz.partial_ratio(str1, str2))
                else:
                    geshs.append(-1)
                    levens.append(-1)
                    jaros.append(-1)
                    partial_ratio.append(-1)
            df[f"near_{c}_{i}_gesh"] = geshs
            df[f"near_{c}_{i}_leven"] = levens
            df[f"near_{c}_{i}_jaro"] = jaros
            df[f"near_{c}_{i}_lcs"] = lcss
            df[f"near_{c}_{i}_partial_ratio"] = partial_ratio
            
            if not c in ['country', "phone", "zip"]:
                df[f"near_{c}_{i}_len"] = df[f"near_{c}_{i}"].astype(str).map(len)
                df[f"near_{c}_{i}_nleven"] = df[f"near_{c}_{i}_leven"] / df[[f"near_{c}_{i}_len", f"near_{c}_0_len"]].max(axis=1)
                df[f"near_{c}_{i}_nlcsi"] = df[f"near_{c}_{i}_lcs"] / df[f"near_{c}_{i}_len"]
                df[f"near_{c}_{i}_nlcs0"] = df[f"near_{c}_{i}_lcs"] / df[f"near_{c}_0_len"]

            geshs = []
            levens = []
            jaros = []
            lcss = []
            partial_ratio = []        
            for str1, str2 in df[[f"near_{c}_0", f"near_{c}_{i}"]].values.astype(str):
                str1 = str1.lower()
                str2 = str1.lower()
                if str1==str1 and str2==str2:
                    geshs.append(difflib.SequenceMatcher(None, str1, str2).ratio())
                    levens.append(Levenshtein.distance(str1, str2))
                    jaros.append(Levenshtein.jaro_winkler(str1, str2))
                    lcss.append(LCS(str(str1), str(str2)))
                    partial_ratio.append(fuzz.partial_ratio(str1, str2))
                else:
                    geshs.append(-1)
                    levens.append(-1)
                    jaros.append(-1)
                    partial_ratio.append(-1)
            df[f"near_{c}_{i}_gesh_lower"] = geshs
            df[f"near_{c}_{i}_leven_lower"] = levens
            df[f"near_{c}_{i}_jaro_lower"] = jaros
            df[f"near_{c}_{i}_lcs_lower"] = lcss
            df[f"near_{c}_{i}_partial_ratio_lower"] = partial_ratio
            
            if not c in ['country', "phone", "zip"]:
                df[f"near_{c}_{i}_len_lower"] = df[f"near_{c}_{i}"].astype(str).map(len)
                df[f"near_{c}_{i}_nleven_lower"] = df[f"near_{c}_{i}_leven_lower"] / df[[f"near_{c}_{i}_len_lower", f"near_{c}_0_len_lower"]].max(axis=1)
                df[f"near_{c}_{i}_nlcsi_lower"] = df[f"near_{c}_{i}_lcs_lower"] / df[f"near_{c}_{i}_len_lower"]
                df[f"near_{c}_{i}_nlcs0_lower"] = df[f"near_{c}_{i}_lcs_lower"] / df[f"near_{c}_0_len_lower"]
    return df


def add_distance_features(df):
    processes = multiprocessing.cpu_count()
    with multiprocessing.Pool(processes=processes) as pool:
        dfs = pool.imap_unordered(_add_distance_features, df.groupby('country'))
        dfs = tqdm(dfs)
        dfs = list(dfs)
    df = pd.concat(dfs)
    return df

train = add_distance_features(train)
test = add_distance_features(test)
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# # Delete Unusing Columns (just for avoiding OOM)

# %%
features = []

columns = ['name', 'address', 'city', 'state',
       'zip', 'country', 'url', 'phone', 'categories']
for i in tqdm(range(CFG.n_neighbors)):
    features.append(f"d_near_{i}")
    for c in columns:        
        features += [f"near_{c}_{i}_gesh", f"near_{c}_{i}_jaro", f"near_{c}_{i}_lcs", f"near_{c}_{i}_partial_ratio"]
        features += [f"near_{c}_{i}_gesh_lower", f"near_{c}_{i}_jaro_lower", f"near_{c}_{i}_lcs_lower", f"near_{c}_{i}_partial_ratio_lower"]
        if c in ['country', "phone", "zip"]:
            features += [f"near_{c}_{i}_leven"]
            features += [f"near_{c}_{i}_leven_lower"]
        else:
            features += [f"near_{c}_{i}_len", f"near_{c}_{i}_nleven", f"near_{c}_{i}_nlcsi", f"near_{c}_{i}_nlcs0"]
            features += [f"near_{c}_{i}_len_lower", f"near_{c}_{i}_nleven_lower", f"near_{c}_{i}_nlcsi_lower", f"near_{c}_{i}_nlcs0_lower"]

for f in features:
#     assert f in train.columns
    if f not in test.columns:
        test[f] = np.nan

print(features)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ['d_near_0', 'near_name_0_gesh', 'near_name_0_jaro', 'near_name_0_lcs', 'near_name_0_partial_ratio', 'near_name_0_gesh_lower', 'near_name_0_jaro_lower', 'near_name_0_lcs_lower', 'near_name_0_partial_ratio_lower', 'near_name_0_len', 'near_name_0_nleven', 'near_name_0_nlcsi', 'near_name_0_nlcs0', 'near_name_0_len_lower', 'near_name_0_nleven_lower', 'near_name_0_nlcsi_lower', 'near_name_0_nlcs0_lower', 'near_address_0_gesh', 'near_address_0_jaro', 'near_address_0_lcs', 'near_address_0_partial_ratio', 'near_address_0_gesh_lower', 'near_address_0_jaro_lower', 'near_address_0_lcs_lower', 'near_address_0_partial_ratio_lower', 'near_address_0_len', 'near_address_0_nleven', 'near_address_0_nlcsi', 'near_address_0_nlcs0', 'near_address_0_len_lower', 'near_address_0_nleven_lower', 'near_address_0_nlcsi_lower', 'near_address_0_nlcs0_lower', 'near_city_0_gesh', 'near_city_0_jaro', 'near_city_0_lcs', 'near_city_0_partial_ratio', 'near_city_0_gesh_lower', 'near_city_0_jaro_lower', 'near_city_0_lcs_lower', 'near_city_0_partial_ratio_lower', 'near_city_0_len', 'near_city_0_nleven', 'near_city_0_nlcsi', 'near_city_0_nlcs0', 'near_city_0_len_lower', 'near_city_0_nleven_lower', 'near_city_0_nlcsi_lower', 'near_city_0_nlcs0_lower', 'near_state_0_gesh', 'near_state_0_jaro', 'near_state_0_lcs', 'near_state_0_partial_ratio', 'near_state_0_gesh_lower', 'near_state_0_jaro_lower', 'near_state_0_lcs_lower', 'near_state_0_partial_ratio_lower', 'near_state_0_len', 'near_state_0_nleven', 'near_state_0_nlcsi', 'near_state_0_nlcs0', 'near_state_0_len_lower', 'near_state_0_nleven_lower', 'near_state_0_nlcsi_lower', 'near_state_0_nlcs0_lower', 'near_zip_0_gesh', 'near_zip_0_jaro', 'near_zip_0_lcs', 'near_zip_0_partial_ratio', 'near_zip_0_gesh_lower', 'near_zip_0_jaro_lower', 'near_zip_0_lcs_lower', 'near_zip_0_partial_ratio_lower', 'near_zip_0_leven', 'near_zip_0_leven_lower', 'near_country_0_gesh', 'near_country_0_jaro', 'near_country_0_lcs', 'near_country_0_partial_ratio', 'near_country_0_gesh_lower', 'near_country_0_jaro_lower', 'near_country_0_lcs_lower', 'near_country_0_partial_ratio_lower', 'near_country_0_leven', 'near_country_0_leven_lower', 'near_url_0_gesh', 'near_url_0_jaro', 'near_url_0_lcs', 'near_url_0_partial_ratio', 'near_url_0_gesh_lower', 'near_url_0_jaro_lower', 'near_url_0_lcs_lower', 'near_url_0_partial_ratio_lower', 'near_url_0_len', 'near_url_0_nleven', 'near_url_0_nlcsi', 'near_url_0_nlcs0', 'near_url_0_len_lower', 'near_url_0_nleven_lower', 'near_url_0_nlcsi_lower', 'near_url_0_nlcs0_lower', 'near_phone_0_gesh', 'near_phone_0_jaro', 'near_phone_0_lcs', 'near_phone_0_partial_ratio', 'near_phone_0_gesh_lower', 'near_phone_0_jaro_lower', 'near_phone_0_lcs_lower', 'near_phone_0_partial_ratio_lower', 'near_phone_0_leven', 'near_phone_0_leven_lower', 'near_categories_0_gesh', 'near_categories_0_jaro', 'near_categories_0_lcs', 'near_categories_0_partial_ratio', 'near_categories_0_gesh_lower', 'near_categories_0_jaro_lower', 'near_categories_0_lcs_lower', 'near_categories_0_partial_ratio_lower', 'near_categories_0_len', 'near_categories_0_nleven', 'near_categories_0_nlcsi', 'near_categories_0_nlcs0', 'near_categories_0_len_lower', 'near_categories_0_nleven_lower', 'near_categories_0_nlcsi_lower', 'near_categories_0_nlcs0_lower', 'd_near_1', 'near_name_1_gesh', 'near_name_1_jaro', 'near_name_1_lcs', 'near_name_1_partial_ratio', 'near_name_1_gesh_lower', 'near_name_1_jaro_lower', 'near_name_1_lcs_lower', 'near_name_1_partial_ratio_lower', 'near_name_1_len', 'near_name_1_nleven', 'near_name_1_nlcsi', 'near_name_1_nlcs0', 'near_name_1_len_lower', 'near_name_1_nleven_lower', 'near_name_1_nlcsi_lower', 'near_name_1_nlcs0_lower', 'near_address_1_gesh', 'near_address_1_jaro', 'near_address_1_lcs', 'near_address_1_partial_ratio', 'near_address_1_gesh_lower', 'near_address_1_jaro_lower', 'near_address_1_lcs_lower', 'near_address_1_partial_ratio_lower', 'near_address_1_len', 'near_address_1_nleven', 'near_address_1_nlcsi', 'near_address_1_nlcs0', 'near_ad ...

# %%
train = train[features + [CFG.target, "target", "id"] + [f"near_id_{i}" for i in range(CFG.n_neighbors)]]
test = test[features + ["id"] + [f"near_id_{i}" for i in range(CFG.n_neighbors)]]

train[features] = train[features].astype(np.float16)
test[features] = test[features].astype(np.float16)

train["target"] = train["target"].fillna(0)

train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)

for _ in range(5):
    gc.collect()

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138812 entries, 0 to 1138811
# Columns: 771 entries, d_near_0 to near_id_5
# dtypes: float16(762), float64(1), object(8)
# memory usage: 1.7+ GB

# %% [markdown]
# # Split Folds

# %%
kf = StratifiedKFold(n_splits=CFG.n_splits, shuffle=True, random_state=CFG.seed)
for i, (trn_idx, val_idx) in tqdm(enumerate(kf.split(train, train["target"], train["target"]))):
    train.loc[val_idx, "fold"] = i
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Model Learning

# %%
import lightgbm as lgbm

def fit_lgbm(X, y, params=None, es_rounds=20, seed=42, N_SPLITS=5, 
             n_class=None, model_dir=None, folds=None):
    models = []
    oof = np.zeros((len(y), n_class), dtype=np.float64)
    
    for i in tqdm(range(CFG.n_splits)):
        print(f"== fold {i} ==")
        trn_idx = folds!=i
        val_idx = folds==i
        X_train, y_train = X[trn_idx], y.iloc[trn_idx]
        X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]

        if model_dir is None:
            model = lgbm.LGBMClassifier(**params)
            model.fit(
                X_train, y_train, 
                eval_set=[(X_valid, y_valid)],  
                early_stopping_rounds=es_rounds, 
                eval_metric='logloss',  
    #             verbose=-1)
                verbose=50)
        else:
            with open(f'{model_dir}/lgbm_fold{i}.pkl', 'rb') as f:
                model = pickle.load(f)
            
        pred = model.predict_proba(X_valid)
        oof[val_idx] = pred
        models.append(model)
        
        file = os.path.join(OUTPUT_DIR, os.path.join(CFG.expID, f'lgbm_fold{i}.pkl'))
        pickle.dump(model, open(file, 'wb'))
        print()

    cv = (oof.argmax(axis=-1) == y).mean()
    print(f"CV-accuracy: {cv}")

    return oof, models

def inference_lgbm(models, feat_df):
    pred = np.array([model.predict_proba(feat_df) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

# %%
params = {
    'objective': "logloss",
    'learning_rate': 0.2,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'random_state': 42,

    'max_depth': 7,   
    'num_leaves': 35, 
    'n_estimators': 1000000, 
    "colsample_bytree": 0.9,
}

oof, models = fit_lgbm(train[features], train["target"].astype(int), 
                       params=params, n_class=int(train["target"].max() + 1), 
                       N_SPLITS=CFG.n_splits, folds=train["fold"].values)

# models = [joblib.load(f'../input/foursquare-exp009/lgbm_fold{i}.pkl') for i in range(CFG.n_splits)]
pred = inference_lgbm(models, test[features])
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# == fold 0 ==
# [50]	valid_0's multi_logloss: 0.368864
# [100]	valid_0's multi_logloss: 0.357653
# [150]	valid_0's multi_logloss: 0.353781
# [200]	valid_0's multi_logloss: 0.351525
# [250]	valid_0's multi_logloss: 0.35008
# [300]	valid_0's multi_logloss: 0.34892
# [350]	valid_0's multi_logloss: 0.348227
# [400]	valid_0's multi_logloss: 0.347761
# [450]	valid_0's multi_logloss: 0.347338
# [500]	valid_0's multi_logloss: 0.347149
# [550]	valid_0's multi_logloss: 0.347015
#
# == fold 1 ==
# [50]	valid_0's multi_logloss: 0.366109
# [100]	valid_0's multi_logloss: 0.355134
# [150]	valid_0's multi_logloss: 0.351285
# [200]	valid_0's multi_logloss: 0.349085
# [250]	valid_0's multi_logloss: 0.347214
# [300]	valid_0's multi_logloss: 0.346063
# [350]	valid_0's multi_logloss: 0.345282
# [400]	valid_0's multi_logloss: 0.344405
# [450]	valid_0's multi_logloss: 0.344051
# [500]	valid_0's multi_logloss: 0.343773
#
# == fold 2 ==
# [50]	valid_0's multi_logloss: 0.368258
# [100]	valid_0's multi_logloss: 0.357448
# [150]	valid_0's multi_logloss: 0.353338
# [200]	valid_0's multi_logloss: 0.350928
# [250]	valid_0's multi_logloss: 0.349329
# [300]	valid_0's multi_logloss: 0.348321
# [350]	valid_0's multi_logloss: 0.347864
# [400]	valid_0's multi_logloss: 0.347093
# [450]	valid_0's multi_logloss: 0.346641
# [500]	valid_0's multi_logloss: 0.346266
#
# CV-accuracy: 0.879479668285898

# %% [markdown]
# # Check CV

# %%
near_ids = train[[f"near_id_{i}" for i in range(CFG.n_neighbors)]].values

matches = []
for id, ps, ids in tqdm(zip(train["id"], oof, near_ids)):
    idx = np.argmax(ps)
    if idx > 0 and ids[idx]==ids[idx]:
        matches.append(id + " " + ids[idx])
    else:
        matches.append(id)
train["matches"] = matches
print(f"CV: {get_score(train):.6f}")
# Out:
# 0it [00:00, ?it/s]
# CV: 0.801854

# %%
near_ids = test[[f"near_id_{i}" for i in range(CFG.n_neighbors)]].values

matches = []
for id, ps, ids in tqdm(zip(test["id"], pred, near_ids)):
    idx = np.argmax(ps)
    if idx > 0 and ids[idx]==ids[idx]:
        matches.append(id + " " + ids[idx])
    else:
        matches.append(id)
test["matches"] = matches
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Check Feature Importances

# %%
def plot_importances(models):
    importance_df = pd.DataFrame(models[0].feature_importances_, 
                                 index=features, 
                                 columns=['importance'])\
                        .sort_values("importance", ascending=False)

    plt.subplots(figsize=(len(features) // 4, 5))
    plt.bar(importance_df.index, importance_df.importance)
    plt.grid()
    plt.xticks(rotation=90)
    plt.ylabel("importance")
    plt.tight_layout()
    plt.show()

plot_importances(models)

# %% [markdown]
# # Simple Post-Processing

# %%
def postprocess(df):
    id2match = dict(zip(df["id"].values, df["matches"].str.split()))

    for match in tqdm(df["matches"]):
        match = match.split()
        if len(match) == 1:        
            continue

        base = match[0]
        for m in match[1:]:
            if not base in id2match[m]:
                id2match[m].append(base)
    df["matches"] = df["id"].map(id2match).map(" ".join)
    return df 

train = postprocess(train)
test = postprocess(test)
print(f"CV: {get_score(train):.6f}")
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# CV: 0.812132

# %% [markdown]
# # Submit

# %%
ssub = pd.read_csv("../Input/sample_submission.csv")
ssub = ssub.drop(columns="matches")
ssub = ssub.merge(test[["id", "matches"]], on="id")
ssub.to_csv("submission.csv", index=False)

ssub.head()
# Out:
#                  id                            matches
# 0  E_00001118ad0191                   E_00001118ad0191
# 1  E_000020eb6fed40                   E_000020eb6fed40
# 2  E_00002f98667edf                   E_00002f98667edf
# 3  E_001b6bad66eb98  E_001b6bad66eb98 E_0283d9f61e569d
# 4  E_0283d9f61e569d  E_0283d9f61e569d E_001b6bad66eb98
