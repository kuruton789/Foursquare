# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install Levenshtein
    # !pip install unidecode
    # !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 31.2 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 62.6 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.3
#   Downloading jarowinkler-1.0.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.1 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.3 rapidfuzz-2.0.13
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 30.6 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 29.3 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=f8166116de623ab3ba902cd2605173508aeaeafa6f07caf765f80a04565adf24
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import seaborn as sns
import re
from requests import get
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from difflib import SequenceMatcher
import lightgbm as lgb
import pickle
import Levenshtein
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from unidecode import unidecode
import emoji
import re

random.seed(42)
np.random.seed(42)
warnings.filterwarnings('ignore')

# %%
if "google.colab" in sys.modules:
    expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0]
ROOT_PATH = '/content/drive/MyDrive/Kaggle/Foursquare'
INPUT_PATH = os.path.join(ROOT_PATH, 'input')
OUTPUT_PATH = os.path.join(ROOT_PATH, 'output')
MODEL_PATH = os.path.join(os.path.join(ROOT_PATH, 'models'), expID)
TARGET = 'point_of_interest'

# %%
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %%
N_NEIGHBORS = 300
NAME_RANK=5
ADDRESS_RANK = 3
CAT_RANK = 5
K_NEIGHBORS = 3
FILTER = 0.0
N_FOLD = 2
DISTANCE = 10000
CATEGORY_COUNT = 100
NAME_THRESHOLD = 0.4
CAT_THRESHOLD = 0.2

DEBUG = False
TFIDF = True
KDIST = True
NET = False # post processでは当たり前にやってた。# predの閾値は利用していなかったので、改良の余地あり。
MOJIBAKE = False
SAMPLING = False

def remove_emoji(src_str):
    return ''.join(c for c in src_str if c not in emoji.UNICODE_EMOJI)

# %%
# with open(os.path.join(OUTPUT_PATH, 'name_variants.pkl'), mode='rb') as f:
#     name_dict = pickle.load(f)

# %%
data = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
if DEBUG:
    data = data.iloc[:10000]
print(data.shape)

# cols = ['name', 'address', 'city', 'state']
cols = ['name']
# cols = ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone'] # categoriesは大文字が小文字になると困る。
for col in cols:
#     if col=='name':
#         data[col].update(data[col].map(name_dict))
    data[col] = data[col].fillna('').apply(unidecode)
    data[col] = data[col].str.lower()
    data[col] = data[col].apply(remove_emoji)

data.head()
# Out:
# (1138812, 13)
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     cafe stad oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           carioca manero -22.907225  -43.178244
# 2  E_000007f24ebc95      raantadphmkaaraaekd  13.780813  100.484900
# 3  E_000008a8ba4f48                 turkcell  37.844510   27.844202
# 4  E_00001d92066153  restaurante casa cofino  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# 1   NaN  Brazilian Restaurants  P_d82910d8382a83
# 2   NaN   Salons / Barbershops  P_b1066599e78477
# 3   NaN     Mobile Phone Shops  P_b2ed86905a4cd3
# 4   NaN    Spanish Restaurants  P_809a884d4407fb

# %%
def sub(x):
    return re.sub(r'[^a-zA-Z0-9 ]', ' ', x)
cols = ['name', 'address', 'city', 'state']
# cols = ['name']
for col in cols:
    data[col] = data[col].fillna('').apply(sub)
    data[f'{col}_split'] = data[col].str.split()

# %%
if MOJIBAKE:
    data.loc[data['name'].str.contains('[买哪侈为裤溦发围货浓调时吧间价爱处灵节怎么办]', na=False), ['name', 'address', 'city']] = '<MOJIBAKE>'

# %%
kf = GroupKFold(n_splits=N_FOLD)
for i, (_, val_idx) in enumerate(kf.split(data, data[TARGET], data[TARGET])):
    data.loc[val_idx, "cv"] = i
print(data["cv"].value_counts())
# Out:
# 1.0    569406
# 0.0    569406
# Name: cv, dtype: int64

# %% [markdown]
# # add Data

# %%
with open(os.path.join(OUTPUT_PATH, 'id2com_30.pkl'), mode='rb') as f:
    id2com = pickle.load(f)
node_df = pd.read_csv(os.path.join(OUTPUT_PATH, 'node_df.csv'))
node_df.columns = ['main_category', 'id_code', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']
node_df = node_df[['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']]

def add_co_net(x):
    if x is np.nan:
        return np.nan
    out = -1
    for cat in x.split(', '):
        if cat in id2com.keys():
            out = id2com[cat]
            break

    return out

data['co_net'] = data['categories'].apply(add_co_net)

# %%
def add_main_category(x):
    if x is np.nan:
        return np.nan

    return x.split(', ')[0]

data['main_category'] = data['categories'].apply(add_main_category)

# %%
aggregated_df = pd.read_csv(os.path.join(INPUT_PATH, 'aggregated_df.csv'))
aggregated_df = aggregated_df.iloc[2:]
aggregated_df.columns = ['main_category', 'median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min', 'count']

float_cols = ['median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min']
aggregated_df[float_cols] = aggregated_df[float_cols].astype(float)
aggregated_df['count'] = aggregated_df['count'].astype(int)
aggregated_df['category_rate'] = aggregated_df['count'] / aggregated_df['count'].sum() # leakではない？

aggregated_df.head()
# Out:
#           main_category  median_distances_max  median_distances_75  \
# 2                  ATMs          1.446457e+07         27032.192275
# 3           Acai Houses          1.350800e+05         17781.269899
# 4    Accessories Stores          1.317399e+07         17636.724841
# 5  Acehnese Restaurants          1.394807e+05         28385.619678
# 6        Acupuncturists          1.099943e+06         30876.313672
#
#    median_distances_median  median_distances_25  median_distances_min  count  \
# 2              4490.248044          1012.594350              0.000000   1366
# 3              6117.784384          1359.040401             19.017952     25
# 4              4397.253023          1609.960599              0.000000    890
# 5             11585.417039          6524.589277            308.232222     22
# 6              5262.894842          1160.926141              0.000000     67
#
#    category_rate
# 2       0.002505
# 3       0.000046
# 4       0.001632
# 5       0.000040
# 6       0.000123

# %%
large_scales = list(aggregated_df[(aggregated_df['median_distances_median']>=DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)
small_scales = list(aggregated_df[(aggregated_df['median_distances_median']<DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)

def add_scale(x):
    categories = x.split(", ")
    out = -1
    for cat in categories:
        if cat in large_scales:
            out = 1
            break
        if cat in small_scales:
            out = 0
            break
    return out

data['scale'] = data['categories'].fillna('').apply(add_scale)
data.scale.value_counts()
# Out:
#  0    897808
#  1    127772
# -1    113232
# Name: scale, dtype: int64

# %%
cols = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient']
data= data.merge(node_df[cols], on='main_category', how='left')

cols = ['main_category', 'median_distances_median', 'category_rate'] # maxとかはリークな気がする。
data= data.merge(aggregated_df[cols], on='main_category', how='left')

# %%
# category similarity
cats = data.categories.fillna('')

cat_stats = {}

for c in cats:
    csplit = c.split(", ")
    for c_ in csplit:
        if c_ not in cat_stats:
            cat_stats[c_] = [1, {ca: 1 for ca in csplit}]
        else:
            prev_cat_stats = cat_stats[c_]
            prev_cat_stats[0] += 1
            prev_sims = prev_cat_stats[1]
            
            for ca in csplit:
                prev_sims[ca] = prev_sims.get(ca, 0) + 1
        
for c, val in cat_stats.items():
    
    overall_count = sum(v for ca, v in val[1].items() if ca != c and v > 1)
    
    new_probs = {c: 1.0}
    if overall_count != 0:
        new_probs.update({ca: round(v / overall_count, 3) for ca, v in val[1].items() if v / overall_count > 0.01 and ca != c and v > 1})
        cat_stats[c] = [1.0, new_probs]
        
def get_cat_similarity(cat1, cat2):
    
    if cat1 == '' or cat2 == '':
        return 0.000000001
    
    if cat1 in cat2 or cat2 in cat1:
        return 1.0
    
    best = 0
    
    for c1 in cat1.split(", "):
        for c2 in cat2.split(", "):
            if c1 in cat_stats:
                best = max(best, cat_stats[c1][1].get(c2, 0))
            if c2 in cat_stats:
                best = max(best, cat_stats[c2][1].get(c1, 0))
    
    return best
get_cat_similarity('Bars', 'Cafes, Restaurants')
# Out:
# 0.065

# %% [markdown]
# # Generate Train Data

# %%
# def get_name_contain(name, match_name):
#     if name=='' or match_name=='':
#         return False
#     elif name in match_name or match_name in name:
#         return True
#     else:
#         return False

# def recall_knn_name(df, Neighbors = 10):
#     train = pd.DataFrame()
#     dfs = []
#     Neighbors = min(Neighbors, len(df))
#     knn = NearestNeighbors(n_neighbors = Neighbors)
#     knn.fit(df[['latitude','longitude']], df.index)
    
#     num_splits = len(df) // NUM_SPLIT_DATA
#     start_row = 0
#     for i in tqdm(range(1, NUM_SPLIT_DATA + 1)):
#         end_row = start_row + num_splits
#         if i < NUM_SPLIT_DATA:
#             tmp = df.iloc[start_row : end_row]
#         else:
#             tmp = df.iloc[start_row: ]
#         dists, nears = knn.kneighbors(tmp[['latitude','longitude']])
    
#         for k in tqdm(range(Neighbors)):            
#             cur_df = tmp[['id']]
#             cur_df['match_id'] = df['id'].values[nears[:, k]]
#             cur_df['kdist_name'] = dists[:, k]
#             cur_df['kneighbors_name'] = k
        
#             cols = ['name']
#     #         cols = ['name', 'categories', 'address']
#             for col in cols:
#                 cur_df[col] = tmp[col]
#                 cur_df[f'match_{col}'] = df[col].values[nears[:, k]]
#                 cur_df[f'{col}_contain'] = np.vectorize(get_name_contain)(cur_df[col], cur_df[f'match_{col}'])
#             cur_df = cur_df[(cur_df['name']==cur_df['match_name']) | (cur_df['name_contain'])]
        
#             dfs.append(cur_df)
#         start_row = end_row
#         print('end_row', end_row)

#     return pd.concat(dfs)

# cvs = []
# for i in range(N_FOLD):
#     tmp = recall_knn_name(data[data['cv']==i], 1000)
# #     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
# #               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
#     tmp['cv_name'] = i
#     print(tmp.shape)
#     cvs.append(tmp)
# train_name = pd.concat(cvs)
# print(train_name.shape)
# # train_name.drop(['name', 'match_name', 'name_contain', 'kneighbors_name'], axis=1, inplace=True)
# # train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
# # train.drop(['address', 'match_address', 'address_split', 'match_address_split'], axis=1, inplace=True)
# train_name.drop(['name', 'match_name', 'name_contain'], axis=1, inplace=True)
# train_name.head()
# # 8679523

# %%
def sm_ratio_name(x):
    return SequenceMatcher(None, x['name'], x['match_name']).ratio()

def sm_ratio_name(name, match_name):
    return SequenceMatcher(None, name, match_name).ratio()

def get_name_iou(name_split, match_name_split):
    if len(set(name_split) | set(match_name_split))==0:
        return 0
    else:
        return len(set(name_split) & set(match_name_split)) / len(set(name_split) | set(match_name_split))

def apply_get_cat_similarity(categories, match_categories):
    return get_cat_similarity(categories, match_categories)

def recall_knn_name(df, Neighbors = 10):
    train = pd.DataFrame()
    dfs = []
    Neighbors = min(Neighbors, len(df))
    # print(f'{Neighbors=}')
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in tqdm(range(Neighbors)):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        
        cols = ['name', 'categories']
        for col in cols:
            cur_df[col] = df[col]
            cur_df[f'match_{col}'] = df[col].values[nears[:, k]]

        cols = ['name']
        for col in cols:
            cur_df[f'{col}_split'] = df[f'{col}_split']
            cur_df[f'match_{col}_split'] = df[f'{col}_split'].values[nears[:, k]]
            cur_df[f'{col}_iou'] = np.vectorize(get_name_iou)(cur_df[f'{col}_split'], cur_df[f'match_{col}_split'])
        
        cur_df['cat_similarity'] = np.vectorize(apply_get_cat_similarity)(cur_df['categories'].fillna(''), cur_df['match_categories'].fillna(''))
        cur_df = cur_df[(cur_df['cat_similarity']>0.0) | (cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
#                        | (cur_df['address_iou']>0.0)| (cur_df['city_iou']>0.0)| (cur_df['state_iou']>0.0)]
#         cur_df = cur_df[(cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
        dfs.append(cur_df)
        
        if k!=0 and (k % 50 == 0 or k==Neighbors-1):
            print(f'calc rank: {k}')
            tmp = pd.concat(dfs)
            tmp['sm_ratio_name'] = np.vectorize(sm_ratio_name)(tmp['name'], tmp['match_name'])
            tmp['name_rank'] = 99 # 念の為、入れておく
#             tmp['cat_rank'] = 99 # 念の為、入れておく
            train = pd.concat([train, tmp])
            train['name_rank'] = train.groupby('id')['sm_ratio_name'].rank(ascending=False, method='dense')
#             train['cat_rank'] = train.groupby('id')['cat_similarity'].rank(ascending=False, method='dense')
            train = train[((train['name_rank']<=NAME_RANK) & train['sm_ratio_name']>0.0) | 
                                  (train['categories']==train['match_categories']) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   (train['cat_similarity']==1.0) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   ((train['cat_rank']<=CAT_RANK) & (train['cat_similarity']>0.0) & (train['sm_ratio_name']>0.0)) | 
                                  (train['kneighbors']<K_NEIGHBORS)]
            del tmp, dfs
            dfs = []

    return train

cvs = []
for i in range(N_FOLD):
    tmp = recall_knn_name(data[data['cv']==i], N_NEIGHBORS)
#     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
#               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
    tmp['cv'] = i
    cvs.append(tmp)
train = pd.concat(cvs)
print(train.shape)
train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
train.head()
# 8679523
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 100
# calc rank: 150
# calc rank: 200
# calc rank: 250
# calc rank: 299
#   0%|          | 0/300 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 100
# calc rank: 150
# calc rank: 200
# calc rank: 250
# calc rank: 299
# (17212199, 15)
#                  id          match_id  kdist  kneighbors  name_iou  \
# 1  E_000002eae2a589  E_000002eae2a589    0.0           0       1.0
# 2  E_000007f24ebc95  E_000007f24ebc95    0.0           0       1.0
# 3  E_000008a8ba4f48  E_000008a8ba4f48    0.0           0       1.0
# 4  E_00001d92066153  E_00001d92066153    0.0           0       1.0
# 5  E_000023d8f4be44  E_000023d8f4be44    0.0           0       1.0
#
#    cat_similarity  name_rank  cv
# 1             1.0        1.0   0
# 2             1.0        1.0   0
# 3             1.0        1.0   0
# 4             1.0        1.0   0
# 5             1.0        1.0   0

# %%
# train.to_csv(os.path.join(OUTPUT_PATH, 'train_pred_100.csv'), index = False)

# %%
# train = train.merge(train_name, on = ['id', 'match_id'], how = 'outer')
# train.head()

# %%
# train.loc[train['cv'].isnull(), 'cv'] = train.loc[train['cv'].isnull(), 'cv_name']
# train.loc[train['kdist'].isnull(), 'kdist'] = train.loc[train['kdist'].isnull(), 'kdist_name']
# train.drop(['cv_name', 'kdist_name'], axis=1, inplace=True)

# %%
if TFIDF:
    id2index_d = dict(zip(data['id'].values, data.index)) # tf-idfで使う
data = data.set_index('id')

# %%
for col in ['co_net', 'scale']:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'is_match_{col}'] = train[col]==train[f'match_{col}']
# train.drop(['co_net', 'match_co_net', 'scale', 'match_scale'], axis=1, inplace=True)

# %%
num_cols = ['adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'median_distances_median', 'category_rate']
for col in num_cols:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'mean_{col}'] = (train[col] + train[f'match_{col}']) / 2
#     train.drop([col, f'match_{col}'], axis=1, inplace=True)

# %%
# label作り

ids = train['id'].tolist()
match_ids = train['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train['label'] = np.array(poi == match_poi, dtype = np.int8)

# %% [markdown]
# # Check Maximum Score

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(data.index.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(train.iterrows()):
    if row['label']==1:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
# for base, match in oof_pred.items():
#     if len(match) == 1:        
#         continue

#     for m in match:
#         if base not in oof_pred[m]:
#             oof_pred[m].append(base)

# %%
ids = list(data.index.unique())
scores = []

for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('max score is ', np.array(scores).mean())
# 0.913(30, co_net)
# 50: 0.928(5), 0.930(10)
# 100: 0.930, 0.938
# 200: 0.934
# 300: 0.938

# scale(10000)
# 50: 0.928
# 300: 0.941

# 0.926
# 0.918
# 0.933
# 0.940
# 0.941
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# max score is  0.9538098173754304

# %%
train['label'].value_counts()
# 0    5067914
# 1    1980366

# 0    3326444
# 1    1952844
# Out:
# 0    14983855
# 1     2228344
# Name: label, dtype: int64

# %%
train.label.mean()
# 0.232
# 0.223
# Out:
# 0.12946306279633416

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'))

# %%
data.to_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = pd.read_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = data.set_index('id')

# data2 = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
# id2index_d = dict(zip(data2['id'].values, data2.index))
# del data2

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            print(col)
            pass
#             df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ## Candidate Miss Sampling

# %%
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    if preds != targets:
        print(f'preds: {preds}')
        print(f'targets: {targets}')
        print(f'{TARGET}: {id2poi[id_x]}')
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# point_of_interest: P_68d8923b659a6f
# preds: {'E_0e5598cc621e95'}
# targets: {'E_c44f57de58697a', 'E_785e94c021674a', 'E_36d0633807fdde', 'E_8c503cfc915096', 'E_5e5cb2ef2c698b', 'E_0e5598cc621e95', 'E_845525ace75fde', 'E_1ad70db6ae0fb0'}
# point_of_interest: P_52899c11b0fa9f
# preds: {'E_0e562d85b19373', 'E_936b4b2c6e8f3a', 'E_780f0fe2219a42'}
# targets: {'E_0e562d85b19373', 'E_c21d959b74c2f2', 'E_936b4b2c6e8f3a', 'E_780f0fe2219a42'}
# point_of_interest: P_21b3ea36cf59c5
# preds: {'E_35bd95ca8a66c5', 'E_0e563e0d2f42b0', 'E_091b2c0a3a2d03'}
# targets: {'E_35bd95ca8a66c5', 'E_0e563e0d2f42b0', 'E_091b2c0a3a2d03', 'E_5dc17d975c730a'}
# point_of_interest: P_35f582eef770f5
# preds: {'E_0e56be64010777'}
# targets: {'E_cb1148f2eb228f', 'E_2a7664b288d668', 'E_0e56be64010777', 'E_6a8870c878bd26', 'E_3f503090d6d44c', 'E_9bfad0b71bd7b5', 'E_0b369ea0a16598', 'E_05ad2be7be9584', 'E_3e68100d25203b'}
# point_of_interest: P_80f67eff225658
# preds: {'E_a5884ba906f39a', 'E_3edfa3b5da8021', 'E_9f166ad136fbce', 'E_0e574bc47d2e54', 'E_ff096a8d258271', 'E_b85b5f6978b772'}
# targets: {'E_a5884ba906f39a', 'E_9e47da45dcb360', 'E_3edfa3b5da8021', 'E_9f166ad136fbce', 'E_0e574bc47d2e54', 'E_ff096a8d258271', 'E_b85b5f6978b772'}
# point_of_interest: P_584ffbb2118b9a
# preds: {'E_eb5e1bc0d8cf5f', 'E_0e57c100f8a46a'}
# targets: {'E_eb5e1bc0d8cf5f', 'E_0e57c100f8a46a', 'E_e670990d4ef03e'}
# point_of_interest: P_ac816d7879ffb5
# preds: {'E_215ff2256b547e', 'E_9c90a7c6235fe0', 'E_1f450316fc7c2e', 'E_1aa23ca2761eb6', 'E_d0009c42033958', 'E_50b0f00cd7a9dd', 'E_a36e5c6c2f7791', 'E_2284cccae4e4f3', 'E_9bb198493e11e1', 'E_cf3bf49d21a3cd', 'E_783e6f99dacaa3', 'E_0e57c570b01216', 'E_932190a4897d7b', 'E_5fd7772765d988', 'E_2ee0e9c934e022', 'E_1d956e33f223c1', 'E_261a290d0e75f7', 'E_9a1780fa9bc442', 'E_72a04da43775ec', 'E_a75d0cfce26c15'}
# targets: {'E_215ff2256b547e', 'E_e8c804f5dd4cac', 'E_1f450316fc7c2e', 'E_9c90a7c6235fe0', 'E_1aa23ca2761eb6', 'E_d0009c42033958', 'E_50b0f00cd7a9dd', 'E_a36e5c6c2f7791', 'E_9ae278274a0e1b', 'E_4bc10c7fe336c6', 'E_2284cccae4e4f3', 'E_9bb198493e11e1', 'E_cf3bf49d21a3cd', 'E_783e6f99dacaa3', 'E_0e57c570b01216', 'E_932190a4897d7b', 'E_5fd7772765d988', 'E_2ee0e9c934e022', 'E_1d956e33f223c1', 'E_261a290d0e75f7', 'E_9a1780fa9bc442', 'E_72a04da43775ec', 'E_a75d0cfce26c15'}
# point_of_interest: P_eedb60d090dffd
# preds: {'E_0e58cbf353c24e'}
# targets: {'E_0e58cbf353c24e', 'E_edd66d18ce509d'}
# point_of_interest: P_984cc13f737d89
# preds: {'E_0e58fb913ffb17', 'E_afd1148697e46f', 'E_0daa23d61a01fb'}
# targets: {'E_0e58fb913ffb17', 'E_afd1148697e46f', 'E_f3d9882a731f77', 'E_0daa23d61a01fb'}
# point_of_interest: P_578ca99ab39260
# preds: {'E_0e5a6101061f04'}
# targets: {'E_0e5a6101061f04', 'E_4592d44146072d', 'E_e879f2495a2c7c', 'E_4fb424fd590db9', 'E_c1542df5846d20', 'E_1bcf7d0aa7ac76'}
# point_of_interest: P_eaf904edd6df38
# preds: {'E_0e5c5eae80f369', 'E_2632fd4c4eda47', 'E_2524aa10a8ba40'}
# targets: {'E_fd81bfae465447', 'E_37ff599d886981', 'E_2632fd4c4eda47', 'E_0e5c5eae80f369', 'E_2524aa10a8ba40'}
# point_of_interest: P_fafe635af8bc9d
# preds: {'E_0e5ca2495c8ba5', 'E_8e9f9da2a2715c', 'E_778696f4414f85', 'E_f37589e7edbaef'}
# targets: {'E_11350b3f76788b', 'E_939407332d1d74', 'E_f37589e7edbaef', 'E_3311a0a6478eec', 'E_e0de205d3a52d2', 'E_0e5ca2495c8ba5', 'E_3441d5abefdb55', 'E_49bddaebbcbfe0', 'E_39562b74ff3ac6', 'E_778696f4414f85', 'E_eeb3a2902bbb3b', 'E_8e9f9da2a2715c'}
# point_of_interest: P_56accb29ae0844
# preds: {'E_0e5dfab558542b'}
# targets: {'E_9193dc995eb030', 'E_0e5dfab558542b'}
# point_of_interest: P_9152a9011d1a17
# preds: {'E_0e5eba16e54aab'}
# targets: {'E_0e5eba16e54aab', 'E_75f0e3b315354d', 'E_87d5b6a8f5fcee', 'E_4154210c812f58'}
# point_of_interest: P_f003821031c8db
# preds: {'E_0e5ec2c7e79a96'}
# targets: {'E_60325c343e9391', 'E_6c6f76207147ea', 'E_b6319a63b42796', 'E_974fa80362d660', 'E_af37bf3be4da88', 'E_58a211a0bc1ebc', 'E_f3eea9c1abee77', 'E_9288f2c52b95b1', 'E_0e5ec2c7e79a96', 'E_704c874178655b', 'E_a008f1a48dfb8b', 'E_ec1455fd7aee60', 'E_3a84d3763b4743', 'E_f2d4969d5c5e4f', 'E_a9ad3a202047dc', 'E_244304290204b8', 'E_ee643aa7607deb', 'E_54cabed22aec88', 'E_03dfe0b662a86e', 'E_eb650a46f6aeba', 'E_2bda4165870f9c', 'E_184a4ff2fd083e', 'E_10c89f33460940', 'E_e29386985d2e5f', 'E_4e08a4b2275313', 'E_ae89fa7d01865c', 'E_bf0f642cdad7a7', 'E_cf39cda9d12547', 'E_8fe4ee5c50704e', 'E_c6b05704698a32', 'E_dd328767a2a71e', 'E_acd4f69442a7a0', 'E_f5b82ac6b42ce3', 'E_38bac03370bb37', 'E_fdd0f24f366cde', 'E_37ec5e306c21a5', 'E_e13110edd39e62', 'E_fc3c44ce36be12', 'E_f8a38a7b95f90f', 'E_b9653bb5254673', 'E_f47403b41b4e77', 'E_d16d4f1e8f0a78'}
# point_of_interest: P_4746ac21a18841
# preds: {'E_0e5f74f17638fd', 'E_633210d4ae3721', 'E_57efde1794b28f'}
# targets: {'E_633210d4ae3721', 'E_57efde1794b28f', 'E_0e5f74f17638fd', 'E_59d6942b5edaac', 'E_4322930f94835c'}
# point_of_interest: P_130a34de576d1e
# preds: {'E_0e6033a2075ab9'}
# targets: {'E_53c433409bde49', 'E_0e6033a2075ab9'}
# point_of_interest: P_ee8a8241d3644b
# preds: {'E_8923fcd4e80d3d', 'E_f975bc5d88b02d', 'E_a6f1af32649ab3', 'E_2ad1dfb4f29a74', 'E_87c09740e80459', 'E_55bbab51451cac', 'E_ba05aba810e47e', 'E_37060b02813ad4', 'E_69c6fa1123c6d8', 'E_3470c668fdcd9d', 'E_8c4384cb5b7550', 'E_cba41070bb33c4', 'E_5f8c7d4913d768', 'E_06555d152b106e', 'E_0e6124a6a7e174'}
# targets: {'E_8923fcd4e80d3d', 'E_f975bc5d88b02d', 'E_37060b02813ad4', 'E_8c4384cb5b7550', 'E_3470c668fdcd9d', 'E_cba41070bb33c4', 'E_fcfa0c0966486e', 'E_4ef1b1621b31bd', 'E_c7f90af7befa90', 'E_0e6124a6a7e174', 'E_02d6db2f9577df', 'E_ba05aba810e47e', 'E_69c6fa1123c6d8', 'E_55bbab51451cac', 'E_9c995a194527e2', 'E_2ad1dfb4f29a74', 'E_0f9abfb48426f7', 'E_87c09740e80459', 'E_a6f1af32649ab3', 'E_440c3ef480677b', 'E_06555d152b106e', 'E_5f8c7d4913d768'}
# point_of_interest: P_b5ab9566af2c2a
# preds: {'E_0e61e166125c9d'}
# targets: {'E_e31e29c4302998', 'E_4cefee5a95599f', 'E_ad9d57d6b23c97', 'E_213854bb3167a3', 'E_518003546db11a', 'E_dafebe3df9d368', 'E_17ca460de42643', 'E_f6f92c0781bc67', 'E_bddb42ffa52f88', 'E_d36d00f46c7144', 'E_0e61e166125c9d', 'E_01069914b44b03', 'E_0f62791da922c4', 'E_1e9f41f1087937', 'E_71c81e5e2bb0c0'}
# point_of_interest: P_89db0ea928e317
# preds: {'E_68ca3efdf77c21', 'E_83743d25fd10c1', 'E_7259683ecaf77c', 'E_0e627b2321bebe'}
# targets: {'E_0e627b2321bebe', 'E_c89072213357e6', 'E_83743d25fd10c1', 'E_7259683ecaf77c', 'E_e0bb54563ae370', 'E_68ca3efdf77c21'}
# point_of_interest: P_3c72b71d7b6b74
# preds: {'E_23fb263049d7eb', 'E_3946ea51981da2', 'E_9cbc7628d3a263', 'E_d5d5954e74c295', 'E_e8da994ad1e23c', 'E_82ef7bf60b5a82', 'E_c457eef8548bbe', 'E_9d3e5e436e8c31', 'E_d327af33669115', 'E_0e62c37430a866', 'E_e6006087b72d57', 'E_d7cf24ac765edf', 'E_a292d5b9cd7fba', 'E_1c219f204e7e30', 'E_b152c780be8272', 'E_c97e6d78d60dfb'}
# targets: {'E_d327af33669115', 'E_e6006087b72d57', 'E_1c219f204e7e30', 'E_c97e6d78d60dfb', 'E_3946ea51981da2', 'E_a292d5b9cd7fba', 'E_e8da994ad1e23c', 'E_fd928d01a339e6', 'E_82ef7bf60b5a82', 'E_9d3e5e436e8c31', 'E_7f898d206565f0', 'E_fd9d05656057be', 'E_d7cf24ac765edf', 'E_c457eef8548bbe', 'E_b152c780be8272', 'E_d5d5954e74c295', 'E_ac06e28ebd84b6', 'E_9cbc7628d3a263', 'E_248d9f92b27f8f', 'E_0e62c37430a866', 'E_23fb263049d7eb'}
# point_of_interest: P_d4647d7433b5a3
# preds: {'E_ea45e8933c907d', 'E_232be72c54cfc6', 'E_9536bef25effb1', 'E_a79a6a105ea65c', 'E_3318f59d0e5e7f', 'E_7b7833ab9aeda0', 'E_b85826588075f1', 'E_76be7184ef764b', 'E_d486841aee9164', 'E_974447a8330f94', 'E_7ec72430970252', 'E_5a655bae3360bb', 'E_e1f02d7bb0ab17', 'E_e8c3ea885dc04e', 'E_8f903b8c6ebf07', 'E_4c6a3b76ab3f69', 'E_a9e78d596bcc6c', 'E_3223f55fb45d7d', 'E_1f0707ec420a90', 'E_2cb60c34a71662', 'E_db090b2730110e', 'E_c924a78ba71730', 'E_16457f92676f54', 'E_b8da94890c302e', 'E_d6e249dfaac644', 'E_0863b3743da335', 'E_e3d13d128c45cf', 'E_11d0de3e45f353', 'E_81b70a5f8c3957', 'E_285790eeb28731', 'E_2b97e88df27c15', 'E_37c3694eb2eb99', 'E_785f18113e8104', 'E_a5c622c9f00c90', 'E_b7de199ca33c8b', 'E_1624a1a2240416', 'E_d3bf018f40380f', 'E_0e6302109429fa'}
# targets: {'E_ea45e8933c907d', 'E_232be72c54cfc6', 'E_9536bef25effb1', 'E_3318f59d0e5e7f', 'E_a79a6a105ea65c', 'E_7b7833ab9aeda0', 'E_b85826588075f1', 'E_546ef1ea6424a1', 'E_76be7184ef764b', 'E_d486841aee9164', 'E_974447a8330f94', 'E_7ec72430970252', 'E_5a655bae3360bb', 'E_870af461673f57', 'E_e1f02d7bb0ab17', 'E_e8c3ea885dc04e', 'E_e30fcebbafda93', 'E_8f903b8c6ebf07', 'E_4c6a3b76ab3f69', 'E_a9e78d596bcc6c', 'E_3223f55fb45d7d', 'E_1f0707ec420a90', 'E_2cb60c34a71662', 'E_db090b2730110e', 'E_cb0fa25611617d', 'E_c924a78ba71730', 'E_16457f92676f54', 'E_b8da94890c302e', 'E_0863b3743da335', 'E_d6e249dfaac644', 'E_e3d13d128c45cf', 'E_11d0de3e45f353', 'E_03f693517012b2', 'E_81b70a5f8c3957', 'E_285790eeb28731', 'E_23c0077ee3d8a9', 'E_dd4638d2ac5622', 'E_2b97e88df27c15', 'E_37c3694eb2eb99', 'E_20cac4481a129a', 'E_6bedc823644572', 'E_785f18113e8104', 'E_bae63a4280c2e8', 'E_a5c622c9f00c90', 'E_b7de199ca33c8b', 'E_1624a1a2240416', 'E_d3bf018f40380f', 'E_0e6302109429fa'}
# point_of_interest: P_ccdfa61716c2e8
# preds: {'E_0e63b37930b4a1'}
# targets: {'E_6d9385090dba4f', 'E_0e63b37930b4a1'}
# point_of_interest: P_32b5d335a5dd9c
# preds: {'E_0e63bd5e69fea6'}
# targets: {'E_0e63bd5e69fea6', 'E_71bf0ff1ad9c8b', 'E_28786bfeaf630a'}
# point_of_interest: P_f55d040639909c
# preds: {'E_201762a1f9acc7', 'E_7cc6d2f613eb94', 'E_0e65f6fb800628', 'E_b414d97ef21c77', 'E_2c6985d8e2855f'}
# targets: {'E_201762a1f9acc7', 'E_1318e5f2915648', 'E_d30bff9eb04d68', 'E_7cc6d2f613eb94', 'E_0e65f6fb800628', 'E_b414d97ef21c77', 'E_2c6985d8e2855f'}
# point_of_interest: P_24e4f370991087
# preds: {'E_0e66d8728b5d59'}
# targets: {'E_0bfe1044784d26', 'E_0e66d8728b5d59'}
# point_of_interest: P_c1c0f2a8b4fadb
# preds: {'E_f7f49b7787cf1c', 'E_3268a20eadb61b', 'E_cd339d85c7245e', 'E_3578821c0ff71b', 'E_da619674e4c037', 'E_815e99d867c893', 'E_9ac5b27322d94e', 'E_0e66e39a995df8'}
# targets: {'E_f7f49b7787cf1c', 'E_3268a20eadb61b', 'E_cd339d85c7245e', 'E_3578821c0ff71b', 'E_da619674e4c037', 'E_815e99d867c893', 'E_d05de1e0384259', 'E_9ac5b27322d94e', 'E_0e66e39a995df8'}
# point_of_interest: P_08e3290146253c
# preds: {'E_55796f35999eb6', 'E_bf67cf9e52df3f', 'E_dace1d87b7a322', 'E_0e66e565002764'}
# targets: {'E_55796f35999eb6', 'E_4b4a9900266336', 'E_bf67cf9e52df3f', 'E_dace1d87b7a322', 'E_0e66e565002764'}
# point_of_interest: P_81146f46f0b262
# preds: {'E_0e671a0192e508'}
# targets: {'E_e33dd11a1351b2', 'E_24209ea89a5737', 'E_e85bf1c0daec7e', 'E_bf998a15067c5a', 'E_17b82fa25bcca4', 'E_137431ee415dc1', 'E_9bb6ff8a6bafee', 'E_1939de5a70f731', 'E_b7be9db10883dd', 'E_edc6e11607c209', 'E_1188c8ae8ab009', 'E_79fdd25823bbe7', 'E_f74e55f7520e43', 'E_8d94f480fa38cb', 'E_ab8e128fde770a', 'E_7a66e40473284c', 'E_04ff79c3b1352e', 'E_f33900addc4734', 'E_86a6acb3fa2b96', 'E_b2b40f087bb618', 'E_5bb6f34b45fdc2', 'E_5020581b17cf60', 'E_080f9f37bd6cfe', 'E_0705c635699cb0', 'E_ac8e43ad3f0c1f', 'E_7891fd57304b05', 'E_5589a1ce3555f4', 'E_1d4efea8f88caa', 'E_6b4202fe7a3cbf', 'E_fce8b8178f97ba', 'E_d0cc43dae6bc7f', 'E_d108ded22cc286', 'E_d4527279e57f81', 'E_fc45c0a4974ee1', 'E_c8e037b22886a8', 'E_407d90e2c466a8', 'E_44d14cf4936df1', 'E_d509a2e16f267f', 'E_de736990e3fea7', 'E_0269337d645c98', 'E_88b974117db59c', 'E_4576c71cbf6089', 'E_e1dcf62203437e', 'E_f7f9cd64668f38', 'E_23cdac41a952a1', 'E_9c5aeeedee1aba', 'E_f95cfc4ba00400', 'E_6ee62ddc88ea69', 'E_8f0a66ae7c67fe', 'E_8ac886aa49c4f9', 'E_0e671a0192e508', 'E_a097dbc6c75013'}
# point_of_interest: P_ea5a068b35685f
# preds: {'E_0e681d3d522666'}
# targets: {'E_8fdfcc43562a59', 'E_0e681d3d522666'}
# point_of_interest: P_cb0ac3079ca4ac
# preds: {'E_0e6960ff1502f9', 'E_c12117f79d7378', 'E_a42ad909d413e6', 'E_96dea095af8586'}
# targets: {'E_c163506bc24499', 'E_a42ad909d413e6', 'E_96dea095af8586', 'E_0e6960ff1502f9', 'E_c12117f79d7378'}
# point_of_interest: P_9dc8f93a7f9631
# preds: {'E_b55f01e0097e75', 'E_f0d3726969b393', 'E_6be852b84eab7e', 'E_e50fab457f5148', 'E_c13d01d8d5cf04', 'E_a828a2df4c70d8', 'E_f42865087e044e', 'E_4f2c2a5468006c', 'E_d6a3865a87978b', 'E_c7f5608f490c7f', 'E_1ca56e1cad9226', 'E_54f58d49d2b625', 'E_26c8de1bb2743f', 'E_2fa83b5b818614', 'E_0e6a16f5c65351'}
# targets: {'E_b55f01e0097e75', 'E_c13d01d8d5cf04', 'E_4f2c2a5468006c', 'E_c4047b049e21bf', 'E_26c8de1bb2743f', 'E_f19ecb94a7553e', 'E_fc74e1aeab1610', 'E_f3cf1c35edfd40', 'E_54c0bacdd6c35a', 'E_c7f5608f490c7f', 'E_5ce691c861ede1', 'E_f0d3726969b393', 'E_6be852b84eab7e', 'E_a828a2df4c70d8', 'E_f42865087e044e', 'E_6cdee88b384967', 'E_be8badb6f4ef76', 'E_2fa83b5b818614', 'E_e50fab457f5148', 'E_d6a3865a87978b', 'E_1ca56e1cad9226', 'E_54f58d49d2b625', 'E_eb050de63572c2', 'E_deb707f982dffa', 'E_0e6a16f5c65351'}
# point_of_interest: P_fe9b5ac0a58069
# preds: {'E_0e6a1edf3297ee'}
# targets: {'E_0e6a1edf3297ee', 'E_0bd0c624132141', 'E_42770208100d18'}
# point_of_interest: P_0d4dcb39caf706
# preds: {'E_16825a205ce55e', 'E_583be5ca746718', 'E_0fa982b51c6e45', 'E_0e6b66426ca0ff'}
# targets: {'E_16825a205ce55e', 'E_0e6b66426ca0ff', 'E_0fa982b51c6e45', 'E_e74e38e5160e5c', 'E_583be5ca746718'}
# point_of_interest: P_a920def3bacf48
# preds: {'E_0e6bb5d0253d7d'}
# targets: {'E_0e6bb5d0253d7d', 'E_547b44a8dc4cb2', 'E_54eb0f43fd7fba'}
# point_of_interest: P_2228333cdd1c65
# preds: {'E_407bf3eec6c605', 'E_0e6bc74a09045e', 'E_a0b0ed750f40e3'}
# targets: {'E_407bf3eec6c605', 'E_0e6bc74a09045e', 'E_21ba682e6d4367', 'E_a0b0ed750f40e3'}
# point_of_interest: P_97347fba2282b5
# preds: {'E_0e6bf8f38e0877'}
# targets: {'E_0e6bf8f38e0877', 'E_3a4086308dceff'}
# point_of_interest: P_3dd22e36d210ba
# preds: {'E_067dbd0e0736d8', 'E_0e6c104cbdbd47', 'E_b86ad09e569ae1', 'E_38bb1fd0205788'}
# targets: {'E_0e6c104cbdbd47', 'E_067dbd0e0736d8', 'E_38bb1fd0205788', 'E_b86ad09e569ae1', 'E_a632fd3166dac8'}
# point_of_interest: P_d8be43fdf8e9ed
# preds: {'E_0e6c16b2c213f1', 'E_575d147e18fdbf', 'E_8b7ba2c0b397fd', 'E_0c7cb0ec6f13f4', 'E_dd4bbbf0e1e67e', 'E_0eb15624c93012', 'E_a112e9aa7949e0', 'E_8e98fa6022e4e9'}
# targets: {'E_0e6c16b2c213f1', 'E_6125c428327e8d', 'E_575d147e18fdbf', 'E_8b7ba2c0b397fd', 'E_0c7cb0ec6f13f4', 'E_0eb15624c93012', 'E_dd4bbbf0e1e67e', 'E_a112e9aa7949e0', 'E_8e98fa6022e4e9'}
# point_of_interest: P_923619031d9c67
# preds: {'E_0e6c35b8d8153c'}
# targets: {'E_159fc1d88b6813', 'E_0e6c35b8d8153c'}
# point_of_interest: P_a47c9556ac9eb0
# preds: {'E_0e6dfe0591b0b8'}
# targets: {'E_e82057bc2bbb27', 'E_0e6dfe0591b0b8'}
# point_of_interest: P_f380d70f4f14c2
# preds: {'E_5906cc2dc0b25b', 'E_0e6f3147504b99'}
# targets: {'E_d73efb38e66880', 'E_5906cc2dc0b25b', 'E_0e6f3147504b99', 'E_68da0ab8438650'}
# point_of_interest: P_b7a5e3b9d5fe29
# preds: {'E_735d4974546adc', 'E_0e6f62d4790d1b'}
# targets: {'E_735d4974546adc', 'E_846110cce43535', 'E_0e6f62d4790d1b'}
# point_of_interest: P_a38beacfbeba68
# preds: {'E_a79c3236d0cfab', 'E_c0d85e3128b4f1', 'E_b24e9cd4fc112a', 'E_0e70f9c5bd95f2', 'E_6a228e7ed323f1'}
# targets: {'E_a79c3236d0cfab', 'E_c0d85e3128b4f1', 'E_6bde7efa29210c', 'E_0e70f9c5bd95f2', 'E_6a228e7ed323f1', 'E_b24e9cd4fc112a'}
# point_of_interest: P_a9421550aafaad
# preds: {'E_32df7ace86eb85', 'E_0e711bbfcb46d5'}
# targets: {'E_32df7ace86eb85', 'E_0e711bbfcb46d5', 'E_b5cae447be976a'}
# point_of_interest: P_b3b5d61b5841be
# preds: {'E_0e725cc217ea21'}
# targets: {'E_0e725cc217ea21', 'E_64211f9f386ea0', 'E_369492a0195226'}
# point_of_interest: P_7eb439c9d8cf44
# preds: {'E_789983217a81ce', 'E_37f22488d29168', 'E_25da32d8f03e9c', 'E_0e73ae1b7ad0f0'}
# targets: {'E_44420c554c8fcf', 'E_789983217a81ce', 'E_37f22488d29168', 'E_25da32d8f03e9c', 'E_0e73ae1b7ad0f0'}
# point_of_interest: P_cbd03d26ac1234
# preds: {'E_0e742ee9b9aaef'}
# targets: {'E_28931f9bd6663a', 'E_0e742ee9b9aaef'}
# point_of_interest: P_9a2337b16f1634
# preds: {'E_0e75b71fe7a51a'}
# targets: {'E_0e75b71fe7a51a', 'E_0546625358de32'}
# point_of_interest: P_3a2bac63e85ff2
# preds: {'E_fefce3bc628066', 'E_e0905e5714d6f3', 'E_0e75e354106343', 'E_f28e3bbaa6e342'}
# targets: {'E_fefce3bc628066', 'E_e0905e5714d6f3', 'E_0e75e354106343', 'E_f28e3bbaa6e342', 'E_5d44ed0222e3bc'}
# point_of_interest: P_9631a3fdc76a94
# preds: {'E_dbb0e4a805e19e', 'E_ed738a8c9d7af3', 'E_be0eafbe1144f3', 'E_89e804f969841c', 'E_0e761cda7ae92d', 'E_31b59d321f3aae', 'E_11d639aa25f53d'}
# targets: {'E_5a2b6400b0b515', 'E_dbb0e4a805e19e', 'E_ed738a8c9d7af3', 'E_be0eafbe1144f3', 'E_89e804f969841c', 'E_0e761cda7ae92d', 'E_31b59d321f3aae', 'E_11d639aa25f53d'}
# point_of_interest: P_4955161bb1bf9e
# preds: {'E_14c9c1a35f9aad', 'E_ffca55cc35a48a', 'E_513a6c8c2b4405', 'E_b8405ccd69a07b', 'E_8408d10d06d9a9', 'E_0e771e521b49c8', 'E_2a76c846709717', 'E_27d7a6c6bd8878'}
# targets: {'E_14c9c1a35f9aad', 'E_2cd2c896f60b6b', 'E_85fe323ccd1fde', 'E_2b738eb79ad089', 'E_b8405ccd69a07b', 'E_27d7a6c6bd8878', 'E_4400d24db8c6fc', 'E_8408d10d06d9a9', 'E_f296f371683807', 'E_49405162b7a8fb', 'E_2366738305d2da', 'E_8c7d048548e4ee', 'E_be93b26e533a7a', 'E_b144ab3f324c18', 'E_ffca55cc35a48a', 'E_513a6c8c2b4405', 'E_ff656f4a848c4b', 'E_2a76c846709717', 'E_0e771e521b49c8', 'E_6a7e893ff54ff1'}
# point_of_interest: P_8228b66aefbeb0
# preds: {'E_81235ae0362faf', 'E_906edd59cd19f7', 'E_cb8fbe1f3ef192', 'E_66e08e5130ea33', 'E_e30fb2d771ec08', 'E_e0c72bc056344e', 'E_0890fa87e38185', 'E_521749f38dd249', 'E_2b883a8f2dbba4', 'E_e205a954199315', 'E_357058f27b0ec7', 'E_55a8b296fde815', 'E_f16d927393c332', 'E_18e7d96ba692e3', 'E_90b9e67aaa0365', 'E_0e77229e45c08b', 'E_25c6a094dcf9dd'}
# targets: {'E_16cdd3e4868021', 'E_906edd59cd19f7', 'E_cb8fbe1f3ef192', 'E_b6cad2d5a2f63a', 'E_90b9e67aaa0365', 'E_25c6a094dcf9dd', 'E_81235ae0362faf', 'E_e0c72bc056344e', 'E_2b883a8f2dbba4', 'E_1598c2ea23abd6', 'E_357058f27b0ec7', 'E_55a8b296fde815', 'E_11ef71e6d524d3', 'E_54047f650b1122', 'E_295ab9f0a6d71d', 'E_e30fb2d771ec08', 'E_521749f38dd249', 'E_e205a954199315', 'E_f16d927393c332', 'E_0890fa87e38185', 'E_5cd94e88b708fd', 'E_66e08e5130ea33', 'E_18e7d96ba692e3', 'E_0e77229e45c08b'}
# point_of_interest: P_b1c07d3800447a
# preds: {'E_0e772d5a8cda7a', 'E_7b28fde26fa271'}
# targets: {'E_20886cc70473bc', 'E_0e772d5a8cda7a', 'E_7b28fde26fa271'}
# point_of_interest: P_810b142385b5d1
# preds: {'E_726aa94fd87f1a', 'E_38eb14f62a8082', 'E_a4f50782cffff5', 'E_230d7f6f9d9dc3', 'E_da1d37ca850424', 'E_4bf4d544284e58', 'E_8ace4a0bc5515f', 'E_80de4deedd894e', 'E_6e88eb53685d2c', 'E_0e77aef7142b4a', 'E_fafe881c1589ef', 'E_c66cf8ed6bc653', 'E_4592c66eeb198c'}
# targets: {'E_4bf4d544284e58', 'E_27a6170a4aa391', 'E_c74341c20f5960', 'E_4ce75b272a0186', 'E_752551ecfe9013', 'E_6e88eb53685d2c', 'E_51d1fdb0f4e3cb', 'E_e47ab8d553cb04', 'E_321b2012987fe4', 'E_fafe881c1589ef', 'E_92c60de6e9a0a3', 'E_4592c66eeb198c', 'E_c66cf8ed6bc653', 'E_0c5ec736c78411', 'E_da1d37ca850424', 'E_80de4deedd894e', 'E_6187667c0b1c1a', 'E_0e77aef7142b4a', 'E_268a5c3ab1f2c8', 'E_1cfe9dccdbad31', 'E_a4f50782cffff5', 'E_003f7353bc029f', 'E_230d7f6f9d9dc3', 'E_dee2c79dac460e', 'E_8ace4a0bc5515f', 'E_feca75122881d3', 'E_3e4bd8383aca82', 'E_4d75b52599de02', 'E_0e8420ea726813', 'E_726aa94fd87f1a', 'E_0ce6ea9aa972df', 'E_38eb14f62a8082', 'E_21bf869fc0c0e6', 'E_78556f4c176632', 'E_b453d207ad1ef1', 'E_bf8d3949a939d6', 'E_e1afe2c06876a3'}
# point_of_interest: P_4fc8af539375b5
# preds: {'E_0e78c58af909e3', 'E_50ea38ba424a6e', 'E_ec58748b450116'}
# targets: {'E_0c8ec6290b142a', 'E_0e78c58af909e3', 'E_50ea38ba424a6e', 'E_ec58748b450116'}
# point_of_interest: P_be890d647bca14
# preds: {'E_0e78d201610263'}
# targets: {'E_9515c724dfacb0', 'E_0e78d201610263'}
# point_of_interest: P_aa0e4536e8bae1
# preds: {'E_a2a26c4a0c9d66', 'E_08dc198eb66eba', 'E_89cbd32cf39190', 'E_0e790d18aaa487', 'E_481647948f4b8b', 'E_64957bdcbbe6bf', 'E_0ed34d32c689d7', 'E_700caf68727ca9', 'E_7c9fec464d0710', 'E_3fa4f386b2d179', 'E_9876b7ad9e8ce3', 'E_3c45a622f10a3a', 'E_d7ebbbeccf6972', 'E_36fb2b187bb779', 'E_1b12c9bf62d16c', 'E_637a718d71e849', 'E_3c0f48682221e5', 'E_f106a529fe545c'}
# targets: {'E_01c8195a01b4e7', 'E_3aa4e37675d4e5', 'E_3fa4f386b2d179', 'E_722bbf774e2aea', 'E_cc65898bbf48a5', 'E_700caf68727ca9', 'E_08dc198eb66eba', 'E_64957bdcbbe6bf', 'E_2337735c959715', 'E_1b12c9bf62d16c', 'E_0d3c23e5f5a1ac', 'E_a2a26c4a0c9d66', 'E_0e790d18aaa487', 'E_481647948f4b8b', 'E_89cbd32cf39190', 'E_9876b7ad9e8ce3', 'E_332445d106d426', 'E_d7ebbbeccf6972', 'E_fdc96fe8b39e78', 'E_36fb2b187bb779', 'E_0ed34d32c689d7', 'E_637a718d71e849', 'E_ad31f92f27f3b1', 'E_5e52ca19eb9404', 'E_7ff90274442c45', 'E_7c9fec464d0710', 'E_3c45a622f10a3a', 'E_c287472e70c61d', 'E_3c0f48682221e5', 'E_f106a529fe545c'}
# point_of_interest: P_ae7c55a13d8c80
# preds: {'E_54f31f52e4f58e', 'E_0e7abb808b8eee'}
# targets: {'E_c64a8dddbe6043', 'E_54f31f52e4f58e', 'E_0e7abb808b8eee'}
# point_of_interest: P_e9be274c714ea5
# preds: {'E_0e7aee5e714c5f'}
# targets: {'E_05fb92689de1a0', 'E_77fc1423e0c0d1', 'E_171176a16320f1', 'E_33520ed5ac76a0', 'E_1c445c170ca67e', 'E_2945183774be79', 'E_0574e84ec08179', 'E_2a1894f5ec0822', 'E_10869b589be911', 'E_a7fa58b1bf002d', 'E_6c00f189c644c8', 'E_c141683988a6d2', 'E_9993ce62f8533f', 'E_cbffa18ae168f9', 'E_2128c30d2aa08a', 'E_66437ed62237fa', 'E_4786f36dc7e176', 'E_004d266e889933', 'E_0a95920168fe8d', 'E_0e7aee5e714c5f'}
# point_of_interest: P_ae3bcff8df0714
# preds: {'E_0e7b7a755569a0'}
# targets: {'E_0e7b7a755569a0', 'E_4f4097f73c7ed7'}
# point_of_interest: P_c539dbcb4feea2
# preds: {'E_0e7b84b6f11163', 'E_5240b41aaea69d', 'E_0a4b8a949bb315', 'E_af7711326afb75', 'E_4a79bcff84c081', 'E_4c6b9e8dfc784b', 'E_1a3e326814f57a', 'E_14f92af36c2f71'}
# targets: {'E_8857fdd669ff98', 'E_4c8f68a417e237', 'E_375516b8ca2bbb', 'E_6ba57dca320684', 'E_b3e91212a954a0', 'E_adae525225ecde', 'E_c4eb79f86b5550', 'E_5b95e0dfa38dc6', 'E_8c4508661a7c41', 'E_11730b4a92f9a2', 'E_53548fecb43d54', 'E_790e214e0da3b1', 'E_4a79bcff84c081', 'E_d299db2c69bd04', 'E_078b196c1781ca', 'E_1670d7d4b51a06', 'E_5736ef1617d9a2', 'E_8f623b3a4460c7', 'E_a0f1bb467d4f27', 'E_650b5a88ecb87e', 'E_45512b87227f0a', 'E_e61020f71027d8', 'E_14f92af36c2f71', 'E_2ad12375b0cea1', 'E_f528aceb64ecda', 'E_49be98136f21fe', 'E_af7711326afb75', 'E_00dd561441762d', 'E_4c6b9e8dfc784b', 'E_549f3fca35bb45', 'E_9900f860d22226', 'E_1a3e326814f57a', 'E_cebe7dfbdcedc3', 'E_cf77abf5646a6c', 'E_1655c69c947c9f', 'E_11c3b2cd87cbf5', 'E_13de991dad0440', 'E_244c8a81ec1a12', 'E_9a3a661077608c', 'E_404563d8f8293e', 'E_0e7b84b6f11163', 'E_5240b41aaea69d', 'E_5f7b6afdfcb521', 'E_2148fda1dd9f87', 'E_c16f45e6cecaa7', 'E_0f0b0e9f3624e6', 'E_a3a90bbe3f8531', 'E_d2ea15308070cf', 'E_0a4b8a949bb315', 'E_dd2b74794a04d7', 'E_4a3a73ad159ed7', 'E_633a7af288f39c', 'E_210da5a456b0f2', 'E_c7ecfa44368a81', 'E_144eec5a08d250', 'E_1f7f7c738551a4'}
# point_of_interest: P_d25bbd09299fc1
# preds: {'E_0e7ca1be639ea7'}
# targets: {'E_d0585f37a0f261', 'E_0e7ca1be639ea7'}
# point_of_interest: P_0d05e236f12c0c
# preds: {'E_6f301959812ca0', 'E_ac9b678a144762', 'E_0e7d2af9bf425c', 'E_c57af52a59992c'}
# targets: {'E_c57af52a59992c', 'E_ac9b678a144762', 'E_6f301959812ca0', 'E_0e7d2af9bf425c', 'E_17b7b691f83ebb'}
# point_of_interest: P_1dd8b297270cc7
# preds: {'E_0e7d38f6572b3d'}
# targets: {'E_ebbfaca6888d2c', 'E_16b93ec8cd22cd', 'E_b5af3611f59874', 'E_5eee384cdf4365', 'E_7bb2a9bef8fa03', 'E_c59859d1f9293f', 'E_2949abb6098b50', 'E_5aef67316f45ad', 'E_27e4e2f11b4188', 'E_08d72a83fc5036', 'E_600d92f3a4d9dd', 'E_5172b13923fd1c', 'E_f3fd8fc107e902', 'E_8a7625ee856c20', 'E_4257a4f2fa879a', 'E_54273a1f6850df', 'E_0e7d38f6572b3d'}
# point_of_interest: P_8d97265da93513
# preds: {'E_1177155f68630f', 'E_4aeb9432f5344b', 'E_d13a708ae1b806', 'E_79d43bd7907aee', 'E_d8e4b2835e03e3', 'E_c18280a32c8dc1', 'E_109e42b49b9179', 'E_35b09457d2dc34', 'E_1e902fd9c36662', 'E_cd33fa2a0d0a14', 'E_2727a8062c6ec0', 'E_a72407eff24d29', 'E_fb77cd4189b2c6', 'E_270fd3edc7abe3', 'E_0e7d6245b87899', 'E_a84936b8b04776', 'E_4dfb246fb40832', 'E_abb7a4b3f148ae', 'E_28bf956a99efc7', 'E_e64ec9dd3a05c1', 'E_cd1fbd5973d00e', 'E_f934fcbbe18e0a'}
# targets: {'E_1177155f68630f', 'E_4aeb9432f5344b', 'E_d13a708ae1b806', 'E_79d43bd7907aee', 'E_d8e4b2835e03e3', 'E_c18280a32c8dc1', 'E_109e42b49b9179', 'E_35b09457d2dc34', 'E_1e902fd9c36662', 'E_fdf2f42d42c049', 'E_cd33fa2a0d0a14', 'E_2727a8062c6ec0', 'E_9f57c9928e66ec', 'E_7e68d0fce147ca', 'E_a72407eff24d29', 'E_fb77cd4189b2c6', 'E_2b6ee4cbba4629', 'E_270fd3edc7abe3', 'E_0e7d6245b87899', 'E_4dfb246fb40832', 'E_a84936b8b04776', 'E_abb7a4b3f148ae', 'E_28bf956a99efc7', 'E_e64ec9dd3a05c1', 'E_cd1fbd5973d00e', 'E_f934fcbbe18e0a'}
# point_of_interest: P_19c12bcdef08ad
# preds: {'E_0e7da5425f0fbe'}
# targets: {'E_0e7da5425f0fbe', 'E_75c28dacafc764'}
# point_of_interest: P_91ca00b3ca15c3
# preds: {'E_0e7e1a9c994bbc'}
# targets: {'E_291ebb827a14b3', 'E_75a989b2e88f27', 'E_cc5faab5104c09', 'E_9a43517215a198', 'E_3191cff9d0d5ee', 'E_0e7e1a9c994bbc', 'E_79090abb3ede55', 'E_41b6b80a254e21'}
# point_of_interest: P_d83795cd20699e
# preds: {'E_0e7efcfbf2cc98'}
# targets: {'E_0e7efcfbf2cc98', 'E_a920afe76aac4b'}
# point_of_interest: P_bed5b769673c44
# preds: {'E_0e7f0d92434803'}
# targets: {'E_0e7f0d92434803', 'E_123fdce8005004', 'E_208bf7b8159e1f', 'E_1aa02a1464ebaf', 'E_5d9a44a0406c17', 'E_e2ab2dd34020f5', 'E_bb878b79c4517f', 'E_7717b10fe5f86d'}
# point_of_interest: P_9f0560b4050115
# preds: {'E_0e7f69379cfdbe'}
# targets: {'E_be75bdd1458fbb', 'E_0e7f69379cfdbe'}
# point_of_interest: P_aed9cfac38bcf5
# preds: {'E_0e8002e8c1db4d'}
# targets: {'E_b9bb27567aba2c', 'E_9237ab0e70c389', 'E_c77a389b4e2242', 'E_f74c5436f80005', 'E_6eed7501bb5d69', 'E_5b3db13eca60b0', 'E_966f21be01fcf6', 'E_d545fe4f5e4f7b', 'E_1c0faca9f2a750', 'E_0e8002e8c1db4d', 'E_e1934cc54d34d5', 'E_d0f9c51ccbbde4', 'E_4f68a0b0e754fe', 'E_456e8a1fa262ac', 'E_5ed3cd72df2d18', 'E_b3c6f24cbea241', 'E_87970440c87bbf', 'E_801a417d5289db', 'E_c122d40384241f', 'E_7f6594eab36269', 'E_046bf4018f92f6', 'E_670aabd7e6cd8b', 'E_e63fd282aa1a80', 'E_3d1c8b99cd4f27', 'E_736f543b697976', 'E_d8a044f66b988c', 'E_10a8358168eae4', 'E_ec9142d78e5d91', 'E_8c6309d9e98b87', 'E_8d975df63f8112', 'E_09b34f1ebdff0b'}
# point_of_interest: P_b95c52e7526e77
# preds: {'E_fd1d298f940bf9', 'E_79034b00efd673', 'E_83c052d224697e', 'E_b38fb717270bf7', 'E_6dc6ce021278e6', 'E_b0e7c253ab7fa9', 'E_35958321c08247', 'E_0e8088c284304a', 'E_0c105b60ec2859'}
# targets: {'E_fd1d298f940bf9', 'E_79034b00efd673', 'E_83c052d224697e', 'E_9961eb67a66896', 'E_b38fb717270bf7', 'E_6dc6ce021278e6', 'E_b0e7c253ab7fa9', 'E_35958321c08247', 'E_0e8088c284304a', 'E_0c105b60ec2859'}
# point_of_interest: P_89dcc3155bd4ee
# preds: {'E_ca9847f4c4df30', 'E_ec49423f86a927', 'E_0e8155066618e2', 'E_4813e736d6dc4c'}
# targets: {'E_5aea7a5ca3356e', 'E_ec49423f86a927', 'E_ca9847f4c4df30', 'E_0e8155066618e2', 'E_4813e736d6dc4c'}
# point_of_interest: P_e0723c27bed8f5
# preds: {'E_f609b495cd978e', 'E_0e815a0418dac8', 'E_d68a1917c2aae2', 'E_5e0362902be4bb'}
# targets: {'E_d68a1917c2aae2', 'E_f609b495cd978e', 'E_0e815a0418dac8', 'E_5e0362902be4bb', 'E_9156283f784720'}
# point_of_interest: P_6bc832ad91c9ed
# preds: {'E_0e823af4e97955', 'E_db24d6c3cf7b53', 'E_e62560774367d9'}
# targets: {'E_db24d6c3cf7b53', 'E_e62560774367d9', 'E_0e823af4e97955', 'E_2b8089d52232f1', 'E_613bd68537b88e'}
# point_of_interest: P_56772a32f345d1
# preds: {'E_0e825490fe5ec0'}
# targets: {'E_5141d01bef3694', 'E_0e825490fe5ec0', 'E_4e179e363741c2', 'E_7b5e9e3a6ee264', 'E_1569f41f7962c3', 'E_f8bf08203d4f0b', 'E_a510a73d7525a8', 'E_9b1682e1470782', 'E_759886a5c16f82', 'E_6ec67c03cbeefb', 'E_881d1b5a675ebe'}
# point_of_interest: P_b529d6d64ed413
# preds: {'E_4fa592cae2abe1', 'E_8f9ddc0653781f', 'E_c6d094427892df', 'E_0e82ea9eddbda6', 'E_05f4a038906617', 'E_87d8511ad6620b', 'E_f4d405b5692d51', 'E_3c64aeb59e71dd', 'E_cb69ba8983659f', 'E_9f326ee3f17840', 'E_551224f65bc7bd', 'E_daf26c4491ef7e', 'E_b953b456e56848', 'E_f7520971cca73e', 'E_5f78ddf9d0b782', 'E_59cb749e6752a9', 'E_7de6110b64b336', 'E_0cb8e77b64d817', 'E_7567a803101ffc', 'E_84b2a8416be68a', 'E_e21122f49084e1'}
# targets: {'E_4fa592cae2abe1', 'E_8f9ddc0653781f', 'E_c6d094427892df', 'E_1009b8281570bf', 'E_0e82ea9eddbda6', 'E_c4b11fd97c4397', 'E_05f4a038906617', 'E_87d8511ad6620b', 'E_c2befc65bb3eb1', 'E_d191271a0a9257', 'E_f4d405b5692d51', 'E_3c64aeb59e71dd', 'E_cb69ba8983659f', 'E_9f326ee3f17840', 'E_551224f65bc7bd', 'E_b953b456e56848', 'E_daf26c4491ef7e', 'E_f7520971cca73e', 'E_5f78ddf9d0b782', 'E_59cb749e6752a9', 'E_7de6110b64b336', 'E_0cb8e77b64d817', 'E_7567a803101ffc', 'E_84b2a8416be68a', 'E_26f83fa13e5b4a', 'E_58f8487a5ba41c', 'E_e21122f49084e1', 'E_b6083e8c53ecfa'}
# point_of_interest: P_61e2c111cf964c
# preds: {'E_0e833aacd434b9'}
# targets: {'E_0e833aacd434b9', 'E_e1196163ad971e'}
# point_of_interest: P_42012a07283d94
# preds: {'E_0e83829f586a4d'}
# targets: {'E_0e83829f586a4d', 'E_aa1b3c3901cd43'}
# point_of_interest: P_25d33be45daf0a
# preds: {'E_744861dc5604a4', 'E_d85e06a47237d2', 'E_0e838af94dedea', 'E_14fadc885fc50e', 'E_6658e1fde05865', 'E_e367b12a561c9b', 'E_ed47d38783e818', 'E_ab8b1abd57a69d', 'E_6c887e5b1f3bd1', 'E_3cc8c245fbf657', 'E_faf3ff56e6f229', 'E_d4a7dc8a46dc1a'}
# targets: {'E_cdc470f4b96dc7', 'E_27e37618c47639', 'E_14fadc885fc50e', 'E_30b0c0ad347831', 'E_bfbb3665a37a67', 'E_a9f9515aa9b42f', 'E_c806116a488c8b', 'E_826bed9c37696d', 'E_66d3de321a4110', 'E_c75dfa321e03dc', 'E_1de7e9619d79d0', 'E_cff6316c50b70b', 'E_c5f5fa1bb0f670', 'E_de19629d46563c', 'E_fd1e2919a61b1d', 'E_151497f69f2e8d', 'E_476123f3f68763', 'E_9d1a52ecc15815', 'E_2fad2f1cefa8cb', 'E_5160e9527ea89a', 'E_edd1613aaf2a69', 'E_81c4c1005af3e8', 'E_4e49954305e4c2', 'E_d59265192bcbc8', 'E_f9f73c8e6f6f17', 'E_fb08ea831f4cfa', 'E_320a4b2aaed012', 'E_8cdf06762805d8', 'E_d85e06a47237d2', 'E_4185c9d7dbad1c', 'E_ed47d38783e818', 'E_6c887e5b1f3bd1', 'E_057c0fef0ebf36', 'E_744861dc5604a4', 'E_e0986f0cd25573', 'E_0e838af94dedea', 'E_f86170551a591c', 'E_1c5af2aee3eec6', 'E_ec900362181145', 'E_52ae64dc199561', 'E_4fb09781693543', 'E_f89af657042d90', 'E_604aadb4fc398e', 'E_faf3ff56e6f229', 'E_8397eca734dc13', 'E_114b42653f2dcd', 'E_6cb8d65b80e155', 'E_70aad2eac02891', 'E_fa600b778ee5b6', 'E_37251f775e7c56', 'E_e367b12a561c9b', 'E_42d5eb4def011c', 'E_897a6e84733263', 'E_cc4302267147f8', 'E_fc8eace7feadfc', 'E_3f2509dda6fad6', 'E_bf2c368ed4a1fa', 'E_748be169762701', 'E_9715966b031412', 'E_f6898e213f88ef', 'E_1d2eae3f3d19e5', 'E_3cc8c245fbf657', 'E_fe43e9366d948a', 'E_ae8ec10e6e0031', 'E_9ca7e33a76c3bc', 'E_aca3abab739102', 'E_50ddadbd9521bb', 'E_7a7190abba8404', 'E_5be36b371fba48', 'E_2e0eabcf4f1fce', 'E_0eb30b1f8ffdcf', 'E_288b8e272b0e7e', 'E_ac57c7788688ab', 'E_f5e9ed0257747b', 'E_b12d7f42eaee3d', 'E_53004ec82073cf', 'E_5efff2fbf5000d', 'E_d0d9b55da85c5e', 'E_3fa69132bf96f1', 'E_97513f48b16ad4', 'E_a85c82b7fc5428', 'E_52789212fedd24', 'E_1d75cf887ab419', 'E_5284dba5f4300f', 'E_e29327b4713c8c', 'E_999ff9341a1649', 'E_9daa6ccf3bbf50', 'E_f19846a71d32df', 'E_f791e59356cefd', 'E_4359dcf4dd3c98', 'E_3bdf8344eaae3d', 'E_98d06cdcbfa22e', 'E_b3d922db710aa2', 'E_6658e1fde05865', 'E_859eab45556a81', 'E_d55cd44d7559c5', 'E_bbb9eece6631b4', 'E_b776cd05dc6ae2', 'E_7a162b640507d0', 'E_deaa4246dfd6e3', 'E_b1cc8e99a1c615', 'E_5bdb17dd2b534e', 'E_d1f18e807be799', 'E_21d9f483d2d9a3', 'E_3c758a11221cd4', 'E_70b14b3adc0898', 'E_655b3b5444dfcc', 'E_73f7c956149bbd', 'E_1b778d0a4a3182', 'E_6c4f2cfcf59b48', 'E_42e1e40e9309db', 'E_1050382d5c574f', 'E_674ad6640c09e4', 'E_c6f924e0e1a28a', 'E_27602a972cac11', 'E_16a1b4430c9f9c', 'E_fa3f089d94ab18', 'E_5fe34b830c4e1c', 'E_96389d224e0a98', 'E_5460d58601c7b6', 'E_90b4eea67fac4e', 'E_241434606f1706', 'E_b7a8576db9ee44', 'E_28a89ffb05a699', 'E_d4a7dc8a46dc1a', 'E_59f52f53f71905', 'E_6f9df5a72ec627', 'E_a19c4a6c0f44a7', 'E_580615ebe1c98e', 'E_fbbd4f617b4a69', 'E_ab8b1abd57a69d', 'E_f25f1b7e9335ad'}
# point_of_interest: P_fbe61733fcdebe
# preds: {'E_809d0e6df7fc15', 'E_b8c789ef4d5ba9', 'E_8c877e7d8f3844', 'E_9b2eb4021a467f', 'E_0e839dab4490f4', 'E_4f9427ef40cd04', 'E_d30968563bcd44', 'E_1364eac834106a'}
# targets: {'E_809d0e6df7fc15', 'E_b8c789ef4d5ba9', 'E_b4d8967963b373', 'E_8c877e7d8f3844', 'E_9b2eb4021a467f', 'E_faa4c539dd4957', 'E_a07675f53519e0', 'E_0c94ef91de70b8', 'E_0e839dab4490f4', 'E_4f9427ef40cd04', 'E_d30968563bcd44', 'E_1364eac834106a'}
# point_of_interest: P_782447217cd852
# preds: {'E_0e83ac15f59469', 'E_df8aed6e3cb244', 'E_b64b8e1b2bcad6', 'E_5574c0937af25a'}
# targets: {'E_0e83ac15f59469', 'E_b64b8e1b2bcad6', 'E_5574c0937af25a', 'E_cf25a097b53642', 'E_df8aed6e3cb244'}
# point_of_interest: P_351f894af55bff
# preds: {'E_27a6170a4aa391', 'E_4ce75b272a0186', 'E_6e88eb53685d2c', 'E_e47ab8d553cb04', 'E_fafe881c1589ef', 'E_c66cf8ed6bc653', 'E_da1d37ca850424', 'E_6187667c0b1c1a', 'E_1cfe9dccdbad31', 'E_a4f50782cffff5', 'E_003f7353bc029f', 'E_dee2c79dac460e', 'E_8ace4a0bc5515f', 'E_feca75122881d3', 'E_3e4bd8383aca82', 'E_0e8420ea726813', 'E_726aa94fd87f1a', 'E_38eb14f62a8082', 'E_78556f4c176632', 'E_b453d207ad1ef1', 'E_e1afe2c06876a3', 'E_bf8d3949a939d6'}
# targets: {'E_4bf4d544284e58', 'E_27a6170a4aa391', 'E_c74341c20f5960', 'E_4ce75b272a0186', 'E_752551ecfe9013', 'E_6e88eb53685d2c', 'E_51d1fdb0f4e3cb', 'E_e47ab8d553cb04', 'E_321b2012987fe4', 'E_fafe881c1589ef', 'E_92c60de6e9a0a3', 'E_4592c66eeb198c', 'E_c66cf8ed6bc653', 'E_0c5ec736c78411', 'E_da1d37ca850424', 'E_80de4deedd894e', 'E_6187667c0b1c1a', 'E_0e77aef7142b4a', 'E_268a5c3ab1f2c8', 'E_1cfe9dccdbad31', 'E_a4f50782cffff5', 'E_003f7353bc029f', 'E_230d7f6f9d9dc3', 'E_dee2c79dac460e', 'E_8ace4a0bc5515f', 'E_feca75122881d3', 'E_3e4bd8383aca82', 'E_4d75b52599de02', 'E_0e8420ea726813', 'E_726aa94fd87f1a', 'E_0ce6ea9aa972df', 'E_38eb14f62a8082', 'E_21bf869fc0c0e6', 'E_78556f4c176632', 'E_b453d207ad1ef1', 'E_bf8d3949a939d6', 'E_e1afe2c06876a3'}
# point_of_interest: P_4fc8af539375b5
# preds: {'E_0e8449ea78bbca'}
# targets: {'E_39a3bfbdfbaf2c', 'E_0e8449ea78bbca'}
# point_of_interest: P_82d59322fc3c79
# preds: {'E_53f715eb2c928f', 'E_0e84e22ac6830f'}
# targets: {'E_c326bc5261941f', 'E_53f715eb2c928f', 'E_0e84e22ac6830f'}
# point_of_interest: P_ec844eed852e21
# preds: {'E_0e851118799ae1'}
# targets: {'E_0e851118799ae1', 'E_f864eb8bea221a'}
# point_of_interest: P_04c50360ffda57
# preds: {'E_07b83da6c5964f', 'E_c6418d279d21d7', 'E_afce36460629a6', 'E_464bbe17321e95', 'E_c86494ec0ef19c', 'E_0e861302a46520', 'E_d760d6d942c8e3', 'E_6e468f0e1e4852', 'E_f3342b686ff349', 'E_36a4bc57e159c1'}
# targets: {'E_07b83da6c5964f', 'E_28aee1e02cae47', 'E_c6418d279d21d7', 'E_7672a183549eab', 'E_53de9db4125a16', 'E_2d98fddc0994b9', 'E_10f9a04b52ae49', 'E_350382f245c87d', 'E_6e468f0e1e4852', 'E_077d4a1a4bc99e', 'E_0c24c14aa886ec', 'E_36a4bc57e159c1', 'E_8ae7ae8b7eed50', 'E_8898ca6f6fc1f8', 'E_1dbd2306889590', 'E_799769df922e90', 'E_773e59b5ffb2b9', 'E_8244c5dcef7a71', 'E_d760d6d942c8e3', 'E_364dbeac2125b2', 'E_c69e9bfb7e47e6', 'E_4b06ccc3b529c9', 'E_798678868911ca', 'E_89ba10eb461284', 'E_464bbe17321e95', 'E_0e861302a46520', 'E_07430cff355c45', 'E_3a677aca08d336', 'E_57bab3ac0c62bb', 'E_953e604ef7e60f', 'E_3530cfeb71ecdc', 'E_54cf4cf9401ed0', 'E_e01c1504ff883c', 'E_1eba4ac967e6e7', 'E_aa67928c4324ca', 'E_afce36460629a6', 'E_efc7fcefb9b5d8', 'E_8d5d5f34ee7694', 'E_5543c3915ab622', 'E_c86494ec0ef19c', 'E_8c9b69cb3bc7fd', 'E_f3342b686ff349'}
# point_of_interest: P_ee54f2c4a61285
# preds: {'E_495c1cba48177a', 'E_0e862728beefdc'}
# targets: {'E_495c1cba48177a', 'E_0e862728beefdc', 'E_ac525524d246ad'}
# point_of_interest: P_13559d9847559c
# preds: {'E_0e865903759cf2'}
# targets: {'E_2afda58c710019', 'E_0e865903759cf2'}
# point_of_interest: P_5b1d413c4808de
# preds: {'E_0e872454f29442'}
# targets: {'E_d399ae3b492bf6', 'E_0e872454f29442'}
# point_of_interest: P_a59d1d68ea8afb
# preds: {'E_4444823809615b', 'E_ba37a3635d332e', 'E_3fe0479aa38775', 'E_ea43d2c848ab64', 'E_b1e43dffbeb2b9', 'E_314e2439324fde', 'E_0e87a55f03e9b9', 'E_b7d2388196f2bd', 'E_645e9c436b0ebb', 'E_1ce3b7d6f5f1ec', 'E_53da1a67b83f9f', 'E_39af378acb512a', 'E_d97e99d6e57546'}
# targets: {'E_3fe0479aa38775', 'E_2e8a07c08b3653', 'E_ca204c45004b25', 'E_4444823809615b', 'E_8558b63fde36ec', 'E_ea43d2c848ab64', 'E_f7d8ed3ce1a374', 'E_645e9c436b0ebb', 'E_39af378acb512a', 'E_cf0e9ce5047c83', 'E_ba37a3635d332e', 'E_b1e43dffbeb2b9', 'E_314e2439324fde', 'E_60d852b01097f5', 'E_0e87a55f03e9b9', 'E_b7d2388196f2bd', 'E_2cd076fc41173c', 'E_1ce3b7d6f5f1ec', 'E_53da1a67b83f9f', 'E_d97e99d6e57546'}
# point_of_interest: P_57443cd44a2ee4
# preds: {'E_8737f28ed5123b', 'E_961ba95941c880', 'E_cd24b66cf5f00e', 'E_6bbea31568aed4', 'E_7ea96cb743ed3c', 'E_5628819a1b41aa', 'E_a2514f2a0c312d', 'E_4d3a856d660a01', 'E_0e87d1398e5cf8', 'E_c3b6514b4928c0'}
# targets: {'E_8737f28ed5123b', 'E_961ba95941c880', 'E_cd24b66cf5f00e', 'E_fd1b8fbd83a654', 'E_6bbea31568aed4', 'E_7ea96cb743ed3c', 'E_05d55b2fae01e1', 'E_5628819a1b41aa', 'E_9ad9d740c433e0', 'E_a2514f2a0c312d', 'E_38e55e0e65c4c3', 'E_4d3a856d660a01', 'E_0e87d1398e5cf8', 'E_c3b6514b4928c0'}
# point_of_interest: P_ff5436984a8fe4
# preds: {'E_0e8816f8096793'}
# targets: {'E_2156c353e39765', 'E_0e8816f8096793'}
# point_of_interest: P_5ccb8c065a0943
# preds: {'E_9bbf0f6c80a126', 'E_3f2b5fdb2c0afa', 'E_0e88e1da288423'}
# targets: {'E_17b6e647aee3a2', 'E_9bbf0f6c80a126', 'E_e26f8d30a6d5a1', 'E_3f2b5fdb2c0afa', 'E_0e88e1da288423', 'E_6fa1d85e51ebee'}
# point_of_interest: P_06e9224faf453f
# preds: {'E_0e8939a44bbd84', 'E_632fcd7135680f', 'E_8e9cdfff4a914b'}
# targets: {'E_fbd5425420bf69', 'E_4cdf4fb6e98d68', 'E_4db3b65b945a89', 'E_8e9cdfff4a914b', 'E_0e8939a44bbd84', 'E_632fcd7135680f', 'E_faf9920f4fbe41', 'E_73ebdd92043a08', 'E_1d434ddebbda2a'}
# point_of_interest: P_d8b0aabb99852d
# preds: {'E_d0d18435d6a152', 'E_c28b4d705fb1d8', 'E_35f1e1d675da7a', 'E_b9bbfab89e9550', 'E_25db2ebc91988e', 'E_e694cb45237c54', 'E_5da12852bf3150', 'E_0b47f064e7b5ff', 'E_f0a05881e32626', 'E_78e7159d482d96', 'E_5b3b36d49aaf1c', 'E_36f21e3b0c4fc3', 'E_e849a6325173e4', 'E_53b6b54796328f', 'E_ae3886657e22ee', 'E_c01e4d5f2dfc29', 'E_2cf16b27e4a8e6', 'E_a84377fb69548a', 'E_331967d3e03b6b', 'E_4cd09ec809db6b', 'E_b5c3548e6c37fd', 'E_53163f850bb6b6', 'E_0e899e8eacc24e', 'E_de496af6819743', 'E_ad2656eed12751', 'E_69b9de5c1a0145'}
# targets: {'E_d0d18435d6a152', 'E_c28b4d705fb1d8', 'E_b54f912c40e75e', 'E_35f1e1d675da7a', 'E_ded8fcc3961695', 'E_b9bbfab89e9550', 'E_25db2ebc91988e', 'E_e694cb45237c54', 'E_5da12852bf3150', 'E_21baee37a98570', 'E_0b47f064e7b5ff', 'E_f0a05881e32626', 'E_78e7159d482d96', 'E_5b3b36d49aaf1c', 'E_36f21e3b0c4fc3', 'E_e849a6325173e4', 'E_53b6b54796328f', 'E_ae3886657e22ee', 'E_f3f4c7db824e40', 'E_c01e4d5f2dfc29', 'E_2cf16b27e4a8e6', 'E_a71e403f5d9166', 'E_a84377fb69548a', 'E_331967d3e03b6b', 'E_4cd09ec809db6b', 'E_1e38a1fde17cfb', 'E_b5c3548e6c37fd', 'E_53163f850bb6b6', 'E_0e899e8eacc24e', 'E_de496af6819743', 'E_ad2656eed12751', 'E_69b9de5c1a0145'}
# point_of_interest: P_1d9ba79daa60f2
# preds: {'E_497e027fd53995', 'E_5cab937535ed01', 'E_6c228e992669c2', 'E_9249eefb3e69d4', 'E_5d0b901da22b99', 'E_d25506ecaa1fc5', 'E_3911d7ac875833', 'E_3d1da993fde7df', 'E_bc9e6d0431277e', 'E_b452ca4e840bdc', 'E_c394123de0c3a8', 'E_f2ada3b9269297', 'E_721c0fea0784ab', 'E_76f3ca25131701', 'E_e73513c551e599', 'E_aa0cfc962f9571', 'E_4547e0a0815ca6', 'E_3d8a269783d610', 'E_06a3be196a4013', 'E_4c461859e44281', 'E_65762b75f5b6af', 'E_9bcdfe0a767e65', 'E_0d89862917a64e', 'E_925da818a5873a', 'E_041fc6a15a4da2', 'E_0a9f68fa9ccf91', 'E_bb1858ce4c9170', 'E_352d3ba90d11c7', 'E_67215e014a59fa', 'E_4a9cca4000c2d5', 'E_a22256bae24141', 'E_5e25d4943c993a', 'E_3348ccc5be1731', 'E_1dc06e721d6e19', 'E_1f6f4662a6dab3', 'E_ab48f25a1e4f3a', 'E_4ad9f1e575a34c', 'E_1794e853946369', 'E_6946ef03483ce9', 'E_39b7ac64616649', 'E_0e89bb62034141', 'E_a851f7cda32c36', 'E_736000b6099d73', 'E_29a26b73ce02ff', 'E_8c9a947c9cae6e', 'E_59626002fee85b', 'E_b7abefa9e9cd45', 'E_5d2b2c274bca26', 'E_67ced1075f7cb4', 'E_7b080dd5bbf2b5', 'E_3403c83650e5bc', 'E_8a4ad5cf7b86b7', 'E_7cc0846674fbac', 'E_84b24d50a01869', 'E_c6cd232f5b3e9e', 'E_6ce5795c4b4d29', 'E_8cd093eee3ea63', 'E_a813fc5c7dd436', 'E_3328e2fc1c1c14', 'E_39d3f8fe0da1c3', 'E_bfc09cf0af8c51', 'E_a8be3f751989b9', 'E_cc112e9870a495'}
# targets: {'E_497e027fd53995', 'E_dc6719553ac824', 'E_25a61d28f32843', 'E_76f3ca25131701', 'E_f06d100209f730', 'E_e73513c551e599', 'E_65762b75f5b6af', 'E_8cfd2f9a9f8add', 'E_947c4ddf5a441f', 'E_05fc96debf9951', 'E_bb0d028d0485bd', 'E_2d5f06d1ec7bf8', 'E_67215e014a59fa', 'E_5e25d4943c993a', 'E_1dc06e721d6e19', 'E_157fce86706b09', 'E_ab48f25a1e4f3a', 'E_ad144c8a0027e2', 'E_4ad9f1e575a34c', 'E_1c0b7c1479aabf', 'E_5aa1e7b267198a', 'E_0e89bb62034141', 'E_6ce5795c4b4d29', 'E_a813fc5c7dd436', 'E_bfc09cf0af8c51', 'E_d25506ecaa1fc5', 'E_3911d7ac875833', 'E_3d1da993fde7df', 'E_bc9e6d0431277e', 'E_c394123de0c3a8', 'E_4547e0a0815ca6', 'E_06a3be196a4013', 'E_0d89862917a64e', 'E_9bcdfe0a767e65', 'E_e3deee8dd551e9', 'E_f08b4b3c93e6fb', 'E_925da818a5873a', 'E_041fc6a15a4da2', 'E_bb1858ce4c9170', 'E_1f6f4662a6dab3', 'E_1794e853946369', 'E_6946ef03483ce9', 'E_a851f7cda32c36', 'E_bae8e2082c6a35', 'E_254a7fa8c4452c', 'E_8c9a947c9cae6e', 'E_87bd33d4b3afd8', 'E_f8401758e2a013', 'E_7b080dd5bbf2b5', 'E_96822035f27f32', 'E_39b7ac64616649', 'E_3328e2fc1c1c14', 'E_39d3f8fe0da1c3', 'E_aa0cfc962f9571', 'E_0e9142ca60df15', 'E_6c228e992669c2', 'E_fb3da6f4907e21', 'E_5d0b901da22b99', 'E_d3e45df72e1ee5', 'E_b452ca4e840bdc', 'E_f2ada3b9269297', 'E_4c461859e44281', 'E_0a9f68fa9ccf91', 'E_b4b8cc72cea768', 'E_352d3ba90d11c7', 'E_bf9e07a5febb02', 'E_3348ccc5be1731', 'E_458d96264588e2', 'E_f5d939a5536256', 'E_9575bac59a0b59', 'E_eafb001e06634c', 'E_736000b6099d73', 'E_166962007a3808', 'E_29a26b73ce02ff', 'E_f127eb9f868443', 'E_59626002fee85b', 'E_5d2b2c274bca26', 'E_8a4ad5cf7b86b7', 'E_84b24d50a01869', 'E_3d691145badfb8', 'E_8cd093eee3ea63', 'E_a8be3f751989b9', 'E_cc112e9870a495', 'E_5cab937535ed01', 'E_9249eefb3e69d4', 'E_5a692c3efb3013', 'E_721c0fea0784ab', 'E_3d8a269783d610', 'E_6c2989fbec961b', 'E_f3295d526794b3', 'E_4a9cca4000c2d5', 'E_a22256bae24141', 'E_b3ac8cd2c5c449', 'E_384e8ff185f7a5', 'E_eaf384f42d3a0f', 'E_fac094f778374a', 'E_67ced1075f7cb4', 'E_bfb10724a57634', 'E_3403c83650e5bc', 'E_7cc0846674fbac', 'E_c6cd232f5b3e9e', 'E_1b39e6b6b30b06', 'E_b7abefa9e9cd45'}
# point_of_interest: P_bee1aae475d656
# preds: {'E_0e89ebf873ee35'}
# targets: {'E_799f7d5860e05c', 'E_1a1ffd564bcf1e', 'E_11f15991b206e4', 'E_04f2da6a2f3d40', 'E_f78245965556ed', 'E_e534abf3a9f835', 'E_b57075a4046b82', 'E_0d0bee9bb3acb1', 'E_64fd635a8e9e25', 'E_0e89ebf873ee35'}
# point_of_interest: P_8ac4730938406d
# preds: {'E_0e8a658b9d1697', 'E_e336cf81dc9176'}
# targets: {'E_0e8a658b9d1697', 'E_d1a7a09010e710', 'E_e336cf81dc9176'}
# point_of_interest: P_8fc8921ff8ce79
# preds: {'E_0e8cde61d0d2dc'}
# targets: {'E_0e8cde61d0d2dc', 'E_ead56f0be3a359'}
# point_of_interest: P_267ed692a9ccd5
# preds: {'E_5f148ff84e0496', 'E_57ddcf2636c58b', 'E_74c4f2f16753d7', 'E_8cb06d33bf82fd', 'E_f1736fdad5bfb5', 'E_0e8d5ab67bf5c7', 'E_1c77a77946f2b8', 'E_b29e275694737a'}
# targets: {'E_951f95f42f0dd9', 'E_5f148ff84e0496', 'E_b29e275694737a', 'E_db55e548a418f5', 'E_57ddcf2636c58b', 'E_74c4f2f16753d7', 'E_ab7572856d0917', 'E_4431995764fd51', 'E_8cb06d33bf82fd', 'E_f1736fdad5bfb5', 'E_0e8d5ab67bf5c7', 'E_1c77a77946f2b8', 'E_0a38da2a680dd5', 'E_4337e14a1ed20d'}
# point_of_interest: P_5cfac7a9f64be7
# preds: {'E_0e8d8449ae9065'}
# targets: {'E_de40838619eb0e', 'E_0fe97992be1ad8', 'E_a1b082e81c2504', 'E_d78fcec07d320c', 'E_5d565cdff656a2', 'E_4831137799cc81', 'E_7e962022c6a6ee', 'E_4d4d5c9be08893', 'E_7c97be37788d5f', 'E_d429beb3b36fd3', 'E_a63fb86d513ed7', 'E_ea56635210a733', 'E_20002f97f9b3d4', 'E_07c79a37b877ba', 'E_0e8d8449ae9065', 'E_953acffc071e32', 'E_06ac0805ff0fd5', 'E_8c0c7255d83638', 'E_9739f06778421f', 'E_8f0bbc9f59713d', 'E_4945a02abe0ffd', 'E_e9f55f65eb6428', 'E_1511b0719dc990', 'E_10c328aaf8d995', 'E_0152543754109c', 'E_6195cb3232a225', 'E_143b3731f99810', 'E_7186da493a6172', 'E_d7960860f8fffa', 'E_5f325b03d6518a', 'E_3880d40d3dd1cb', 'E_f0dc37bb032106', 'E_801170724d9249', 'E_959efa8f878a9d', 'E_d6f80f75f74ad3', 'E_e5e477aedd1b47', 'E_20ffd0689c3941', 'E_b5e6d684b0eb65', 'E_e55d2fe7edbd38', 'E_2900039cfaf8c4', 'E_9adddb25bd236d', 'E_fb648091500889', 'E_a6d6edbd179d85', 'E_a22d03e3c495bd', 'E_a9d5079809af7e', 'E_d5199aee5aa46c', 'E_b85379059c448a', 'E_978033ce577765', 'E_059cf5da755a3e', 'E_3149fdda80bd83', 'E_ac941b339202ef', 'E_44af85d7513d4c', 'E_15ebea961d67b0', 'E_48484807b9a74c', 'E_ded6ae2bf3c6cf', 'E_94194d3fa5acc4', 'E_d74301a0bced08', 'E_ae879c7b4ccce4', 'E_3aa4f8087865e0', 'E_5026d15bb13fd1', 'E_55cabac07baea2', 'E_5b470c5fb52280', 'E_9904e596c4d1cb', 'E_87fafb7857d18c', 'E_3a3fef9d9d327c', 'E_cd8da852e940fa', 'E_689b131bfbf4ff', 'E_299a3338967e31', 'E_8a4d5b77c01b50', 'E_8cde8a5967d197', 'E_8d6ca7ccef6ffe', 'E_4690e04186a19b', 'E_2f37796f9715f1', 'E_6a80ebef75570e', 'E_5c36b128665e36', 'E_742779277dc682', 'E_8820af2821265a', 'E_c395e67228d7d6', 'E_9679c60f735f55', 'E_b6d13871941e22', 'E_85bf94d38ad488', 'E_76310b5664cf5c', 'E_6ef6a240bc3d4a', 'E_57e7b214dcf826', 'E_eb57b3363e406a', 'E_2d4cd81a01024e', 'E_2627c45318623b', 'E_dfe499ae41382c', 'E_ce2463fce3a7b0', 'E_3ed5649863c4cc', 'E_98bf83d73fb8f6', 'E_00d0406ee818fc', 'E_ab1730bb1a7520', 'E_29fa9609b62f79', 'E_82a0f792bfe5bd', 'E_3283026a42cd80', 'E_e1d0206eb62d92', 'E_cbac70924bf038', 'E_f0a88762680d4c', 'E_0bdd796a03c619', 'E_623c00b5352fd3', 'E_8388be24c11dfa', 'E_e9c99a3b022414', 'E_edfcf733f4b2d7', 'E_cab60f8ce907e5', 'E_cc6bbe29e7277d', 'E_a097241491f277', 'E_169e97981f88c6', 'E_70fa9fc45aec6f', 'E_099029694f833c', 'E_6c63d7ad4b0367', 'E_45309c2c42ba62', 'E_69b2f7c241dde6', 'E_fa8a12bd195e82', 'E_fb266978e50f17', 'E_a309431c44b898', 'E_dc7d87ffb93a0a', 'E_d2d6c3021646e3', 'E_cf08d75f97c35f', 'E_eda8f56722c312'}
# point_of_interest: P_f82d146eaf21da
# preds: {'E_0e8dd7f5d6fa85'}
# targets: {'E_0e8dd7f5d6fa85', 'E_2452cbcddb99de'}
# point_of_interest: P_af0e63db1c75c1
# preds: {'E_0e8e9529692f27', 'E_e9df2ad8e088e8', 'E_f72c943948851d', 'E_0c90d15d60d8ec'}
# targets: {'E_e9df2ad8e088e8', 'E_0c90d15d60d8ec', 'E_f72c943948851d', 'E_0e8e9529692f27', 'E_1b75038480cb5a'}
# point_of_interest: P_d40cc6b4e58456
# preds: {'E_0e8eac14317cca', 'E_743fcaf938b9ec'}
# targets: {'E_d0118ac33736ef', 'E_0e8eac14317cca', 'E_743fcaf938b9ec'}
# point_of_interest: P_5e0c8683a300a6
# preds: {'E_45dee9e5da5662', 'E_0e8ee7062b8125'}
# targets: {'E_45dee9e5da5662', 'E_855796228ff8f5', 'E_0e8ee7062b8125'}
# point_of_interest: P_741fcc03479d48
# preds: {'E_0e8fb8f512cf22'}
# targets: {'E_63a9082bf41092', 'E_76b623f47b145e', 'E_1159f8a93b619c', 'E_db94fc8b297d31', 'E_e3a1e47978d3ba', 'E_0e8fb8f512cf22', 'E_a2e4913b018abc', 'E_a9387488b1cb97', 'E_772fac89677e3a', 'E_d3594d3bf2b6b2', 'E_3eb9b8518e7e65', 'E_3f8b3b019e4545', 'E_da066180238227', 'E_2c815862abc95d', 'E_02e246c090f416', 'E_88905a53560812', 'E_eb9246676537af', 'E_9d1407bef99224', 'E_632abf5aada973'}
# point_of_interest: P_6e1e889f679ef4
# preds: {'E_0e901cb7aede2f'}
# targets: {'E_d3807a90eb203d', 'E_256e5be457f995', 'E_171f37cf5db369', 'E_7d31f8b6333782', 'E_4b2c306703041d', 'E_0e901cb7aede2f', 'E_b88cd3ab6f91c4', 'E_f97473caf37919'}
# point_of_interest: P_cd3b8a6fa6fbbc
# preds: {'E_0e9142ca60df15', 'E_f127eb9f868443'}
# ...
# preds: {'E_ffeda5b2c9ee89', 'E_f94156b527f288'}
# targets: {'E_ffeda5b2c9ee89', 'E_d6b53044e0fd23', 'E_f94156b527f288'}
# point_of_interest: P_0e9b4bcb576c7d
# preds: {'E_b7da27e454f402', 'E_3ca98219bed9e5', 'E_3e6ebff29b46bc', 'E_ffee33330a6d59', 'E_d760dd675b407e'}
# targets: {'E_b7da27e454f402', 'E_3ca98219bed9e5', 'E_6539635f88a02e', 'E_3e6ebff29b46bc', 'E_ffee33330a6d59', 'E_d760dd675b407e', 'E_bd0fd933fba9dd'}
# point_of_interest: P_fabaf69582a730
# preds: {'E_ffeefeb227a2b0'}
# targets: {'E_ffeefeb227a2b0', 'E_98a7961bcb64c1', 'E_cd7185286a0404'}
# point_of_interest: P_96bf81353c7b66
# preds: {'E_098bbd04488463', 'E_ffef1186631782'}
# targets: {'E_098bbd04488463', 'E_ffef1186631782', 'E_7f7df37ca29f7d'}
# point_of_interest: P_4b739ce9c90689
# preds: {'E_60a188f00e91b2', 'E_be5188c06e3e66', 'E_7da5adbc889734', 'E_fff0686373f911', 'E_f8e1fd79ce0944', 'E_baceed4201029f', 'E_8309c5766613cf'}
# targets: {'E_60a188f00e91b2', 'E_be5188c06e3e66', 'E_7da5adbc889734', 'E_fff0686373f911', 'E_68911ddb2cab12', 'E_f8e1fd79ce0944', 'E_ffc48172d51f16', 'E_baceed4201029f', 'E_bc1f3c57ee0511', 'E_8309c5766613cf'}
# point_of_interest: P_455e8b62ca4f5a
# preds: {'E_cec171e8565bca', 'E_93e588933cf51d', 'E_1f1418c85e5208', 'E_84ed7cb3e3782e', 'E_27746db2599e7e', 'E_8015d24e901473', 'E_e1398a003edb62', 'E_31dfd99e4cf565', 'E_2a58a1b968419d', 'E_be82e3aeb23edb', 'E_164a39648823e8', 'E_fff07e4897e36e', 'E_c88b079b174d14'}
# targets: {'E_cec171e8565bca', 'E_f33195a7b1e255', 'E_93e588933cf51d', 'E_1f1418c85e5208', 'E_27746db2599e7e', 'E_1651debc73c571', 'E_8015d24e901473', 'E_84ed7cb3e3782e', 'E_e1398a003edb62', 'E_2a58a1b968419d', 'E_31dfd99e4cf565', 'E_be82e3aeb23edb', 'E_164a39648823e8', 'E_fff07e4897e36e', 'E_c88b079b174d14'}
# point_of_interest: P_bd887fbc13ac54
# preds: {'E_99e05910762091', 'E_9a564349fa6881', 'E_538ebc482cd5d8', 'E_2b80b1eacd3291', 'E_fff084dced1f09', 'E_a2ed3a1044c4f5', 'E_94f3d3df8a9528', 'E_98c81f24be1470'}
# targets: {'E_99e05910762091', 'E_f41eb2d5194c22', 'E_543ac8c2066f2a', 'E_9a564349fa6881', 'E_538ebc482cd5d8', 'E_2e5e606031ef06', 'E_2b80b1eacd3291', 'E_a2ed3a1044c4f5', 'E_a870bb23cb3df3', 'E_af65698ef49dfc', 'E_fff084dced1f09', 'E_94f3d3df8a9528', 'E_d7b7f6a89dcaaf', 'E_98c81f24be1470'}
# point_of_interest: P_5510cf5bb797e3
# preds: {'E_f22e0da1d97e0f', 'E_a548922b549a81', 'E_fff1b1dd4d8883', 'E_6830347bfd7280', 'E_d5bb45fc42fdde', 'E_26a34403fce0f5', 'E_65db18d9f6eb30', 'E_82fd05ee7efa00'}
# targets: {'E_91f1942b9a4144', 'E_a548922b549a81', 'E_f22e0da1d97e0f', 'E_ec481101ef4297', 'E_fff1b1dd4d8883', 'E_6830347bfd7280', 'E_850a256d3f5d13', 'E_0a4a05ef60e434', 'E_d5bb45fc42fdde', 'E_3e9eb656adfba1', 'E_26a34403fce0f5', 'E_65db18d9f6eb30', 'E_82fd05ee7efa00'}
# point_of_interest: P_346b237d61cd5c
# preds: {'E_fff1eac4917e2f'}
# targets: {'E_fff1eac4917e2f', 'E_2740338cb4bac5'}
# point_of_interest: P_c39b5c766497d0
# preds: {'E_fff27edaf455ae'}
# targets: {'E_fff27edaf455ae', 'E_a21e2fa389cd7a'}
# point_of_interest: P_c4291acb6061c9
# preds: {'E_7b0acc9e55515d', 'E_bb94da5af8de80', 'E_e563a9b2f88065', 'E_651155a119dc78', 'E_36296aaf40eb69', 'E_da9ebf0b71ae9e', 'E_defb0c87e0e8f1', 'E_1ae31b7a544b54', 'E_7d43f65f541c80', 'E_fff33cdd288e2c'}
# targets: {'E_7b0acc9e55515d', 'E_bb94da5af8de80', 'E_e563a9b2f88065', 'E_651155a119dc78', 'E_36296aaf40eb69', 'E_da9ebf0b71ae9e', 'E_defb0c87e0e8f1', 'E_144046d1c111aa', 'E_1ae31b7a544b54', 'E_7d43f65f541c80', 'E_fff33cdd288e2c'}
# point_of_interest: P_7f75f291dfcae8
# preds: {'E_fff35a21c59588'}
# targets: {'E_c1c5e6b105e3bc', 'E_fff35a21c59588'}
# point_of_interest: P_41fad6a9473c69
# preds: {'E_fff39c4a604330'}
# targets: {'E_a9ed8bb6ce6106', 'E_fff39c4a604330'}
# point_of_interest: P_7fc384bf991009
# preds: {'E_fff3f40a762e93'}
# targets: {'E_db9177b0745d11', 'E_88a9e9044743bb', 'E_140b5041aa4cd6', 'E_bb6f24674e9f91', 'E_5f1899f44a7c86', 'E_da0aa051443a08', 'E_ce383a59adbcb6', 'E_bbe83e6cfd360b', 'E_d16734d8b6ed38', 'E_98f6bdd1163564', 'E_8b0c48bb236b24', 'E_20557c53571641', 'E_91c69e0866c171', 'E_c3b0a81f7dcebc', 'E_e363c38d88f33c', 'E_6fd2b312eb7d2f', 'E_6bc44f0a0372a6', 'E_a051895895b738', 'E_3938de6cbda8ca', 'E_5d7f288c0b01d2', 'E_f0ad84e1e13837', 'E_046132a06d8bc5', 'E_d3c25e43bcec38', 'E_62222b0e1c13fa', 'E_6b9d0dee191c32', 'E_fff3f40a762e93', 'E_19360b0c07c44e', 'E_759283f776859c', 'E_8ac726b963c6d5', 'E_cc0ee3b3c25370', 'E_8f74678428e747', 'E_400ff1d74561fe', 'E_b88be0c865c715', 'E_583807772277c9', 'E_414f7880fbfcc8', 'E_ffe8c72a51f9c6', 'E_5365a77191a928', 'E_28fdd80c9aebab', 'E_bedb87cd827a8b', 'E_7a53ac861de8a2', 'E_8600580e6998e7', 'E_1387ed99e9ce8e', 'E_dabfe88b6f990b', 'E_80ee19ca1a1d2a', 'E_74189350ea1d40', 'E_469b88d09124ec', 'E_b917f0daac3dd4', 'E_4eb9a9ecfc8cc8', 'E_8ee9d39a35e9e4', 'E_eecbea7afd4a51', 'E_a1e4707531c6eb', 'E_d72dd3688bf5d9', 'E_73874b2cdd4d92', 'E_9909b6725039f8', 'E_ef7103b8d78e40', 'E_cdcf89fbc20b3b', 'E_e295a8635a8854', 'E_e39ee996aa8d12', 'E_cbd9c2ae6025f7', 'E_93831c4c435242', 'E_95134d7b1f75ba', 'E_8ef09aac876a6d', 'E_6c742b8c70caea', 'E_396415ba3cf826', 'E_b04e6001ff0024', 'E_c0767d1b87cfa6', 'E_99cd0807addab6', 'E_c6c0db2d9485da', 'E_04d15c990bfd9e', 'E_71b63d8f78b86c', 'E_81c1ce4f402780', 'E_8d896a44f7e9f5', 'E_3e2813d69a8c59', 'E_c32833701814e1', 'E_7775dd642dcc30', 'E_f67974531d123e', 'E_558d583271c64f', 'E_9afb7e0f12c543', 'E_a72ad6078cfe59', 'E_42250fcb04266c', 'E_72834ea099fa85', 'E_e4707d5fe73c96', 'E_0bbd909382cd75', 'E_52f0c4bade9955', 'E_59055483770086', 'E_48a384219bc28e', 'E_60c178ff435b18', 'E_91d74973015229', 'E_f68bf00215f313', 'E_e971a894f5a94a', 'E_502a13fa5aa72b', 'E_75dd68f89e611f', 'E_a418a87cda236e', 'E_2dda26bb98ab49', 'E_8d50dcaeac54c1', 'E_9f1082969881d7', 'E_d181d8540001cd', 'E_dfaf5f0b5ca510', 'E_2dcb5b985819b4', 'E_0ff1a279a14a0f', 'E_76b7416d2c897a', 'E_90958502ddf574', 'E_981a7bfdf306a0', 'E_3cfcdf84257fd2', 'E_e6afeda2f4894b', 'E_6730382afd40c7', 'E_3f8cd633b76b05', 'E_acf39c38433c0e', 'E_5132d2e105a8ee', 'E_1f45847efea3e5', 'E_9da4babb2dc98a', 'E_05bd0fb0583a00', 'E_fed28e5ada5e81', 'E_42a6d6639b3753', 'E_824f097568d33d', 'E_e76f85ed8f35fc', 'E_b5cf0be507c58e', 'E_9f24e2fbcf2bd8', 'E_9f1603ea1e92bb', 'E_ee475a84e88c26', 'E_c20813637c8f3c', 'E_836817aec832d6', 'E_0fc82270e70bf3', 'E_cfc2ff038334cd', 'E_b63e5a6583f3ae', 'E_c82a952258ca44', 'E_a21ac79b27e67f', 'E_b2159f7cbd1588', 'E_76eb204fa2a49f', 'E_1f8472e776298d', 'E_b1fe04bd0698b3', 'E_f127bc8fcc9a60', 'E_9def7e6622aff9', 'E_7b06ca5e1ee0ca', 'E_1e594d5dd8ad5d', 'E_23d3c7e4117a18', 'E_2202b119f83988', 'E_be041b6f3871fa', 'E_cd810f976c37d1', 'E_4d90c2ac0fdbbd', 'E_b8334ac91bbf00', 'E_e2b5b47143a5f3', 'E_f336a60ceca48a', 'E_0351377fc6b71d', 'E_a212368ad314e5', 'E_592c2dfaa18c39', 'E_7a97df0189d838', 'E_ae81abe3cafdc0', 'E_a271bf95b35497', 'E_62f9235b937698', 'E_9afb683ae9c42d', 'E_95ab858c88562d', 'E_35c7b6caec33ec', 'E_2290d067ee57cb', 'E_31ac6f4a443311', 'E_5ab963c9aa78d6', 'E_e773e0b06aff87', 'E_dd60a994b06437', 'E_f4f22cfb71102e', 'E_5c0b1edbffefa1', 'E_e0ca03194ccffb', 'E_492682b489c5c5', 'E_47f5f883c73c64', 'E_1967ffa1c92d7d', 'E_04c39deab3aba2', 'E_e55dff9c1b1a54', 'E_2ace04975dad08', 'E_8f611bab43254e', 'E_3673b4f50a47d5', 'E_d28eecc14882b9', 'E_de86a86735fb6d', 'E_7b5993ea269167', 'E_9854239e1edccb', 'E_e43c2dfc8c59cb', 'E_80191e9690ae4d', 'E_258dbed9f9ff86', 'E_38698a5579e504', 'E_7e37451e479da4', 'E_2972bc662f0831', 'E_c5718ff5345ab7', 'E_6fce691986c090', 'E_8f644ea72a398d', 'E_68eadfa4355677', 'E_ab0681b7651abb', 'E_813f15ff086eea', 'E_62433d49b17303', 'E_33d057de2d00ac', 'E_b8e13b4dc1a514', 'E_9ac9376f860ae1', 'E_73643b4e9192a6', 'E_29f7cf3af5170b', 'E_5f43096da4291e', 'E_6eefe645a99151', 'E_4e49051cd64729', 'E_c6c908350af685', 'E_50826410cedcf5', 'E_60d8a84257cf63', 'E_e8e02a1b28fa7b', 'E_f43a547c2bf278', 'E_a4ffbfa ...
# point_of_interest: P_fb339198a31db3
# preds: {'E_fff406b7128e76', 'E_cd0d4f078ba9a6'}
# targets: {'E_fff406b7128e76', 'E_fa99078086e7c8', 'E_cd0d4f078ba9a6'}
# point_of_interest: P_df0f6b0d356fa5
# preds: {'E_05bcefa943af5c', 'E_2235fd2b8e3b33', 'E_1ea74a22184a46', 'E_4bfc30e59e5c1e', 'E_fff610e05c669a', 'E_efeb98b3a2e6a3', 'E_e266beee62653f', 'E_ecc220d607b8c4'}
# targets: {'E_05bcefa943af5c', 'E_2235fd2b8e3b33', 'E_55f8dc7c352fdf', 'E_c2f81a76a332c7', 'E_1ea74a22184a46', 'E_4bfc30e59e5c1e', 'E_fff610e05c669a', 'E_efeb98b3a2e6a3', 'E_e266beee62653f', 'E_236a8d942ba98d', 'E_ecc220d607b8c4'}
# point_of_interest: P_397aee87a200fe
# preds: {'E_fff66bd98231ac', 'E_fc74b56d737ae3'}
# targets: {'E_0825d0574b6014', 'E_f2440c8e92b0b2', 'E_24726948012455', 'E_fff66bd98231ac', 'E_25016b93248671', 'E_86b07a1eb702c2', 'E_fc74b56d737ae3'}
# point_of_interest: P_81ef009ce81cfb
# preds: {'E_fff737a873bc34', 'E_e5f6039af60d31'}
# targets: {'E_d37cecd8afa280', 'E_fff737a873bc34', 'E_e5f6039af60d31'}
# point_of_interest: P_8a6fad90258408
# preds: {'E_831aef2dde91a5', 'E_b368a03176b5e9', 'E_3c776c4dca047b', 'E_fff7871b89de63', 'E_b6bcd0abdc59bb', 'E_04eec92d750e17', 'E_c0943ca8325026', 'E_94cf05f3655112', 'E_8253bf51d7daa9', 'E_cf1ff302c49aa6', 'E_7d657f045e762f', 'E_7bf3410dcdbe1d', 'E_28fbfb3405b2ab', 'E_65895c944e1825', 'E_8ab60acfb8d5e5', 'E_4fdb47a714f128', 'E_869709fc0feefb', 'E_c4f534be7597e9', 'E_b0ac23d30e5d29', 'E_499d70f0ea4673', 'E_363e7549520807', 'E_e9ff9cf67cdb82', 'E_267313446db841', 'E_036e02d50e8899', 'E_b4470520f18bfd', 'E_49d41a451f1357', 'E_7042ec353dda3a', 'E_d744da9e72f128', 'E_e9863ee18f0f24', 'E_ab5e2bdab03a73', 'E_c4c3c7e3abf37a', 'E_35b09125341428', 'E_ad529e21e5cf87', 'E_2ab6204de9f88c'}
# targets: {'E_831aef2dde91a5', 'E_860a08f5a9fa1d', 'E_b368a03176b5e9', 'E_3d780b7f217827', 'E_3c776c4dca047b', 'E_7cb4171bb1b0fe', 'E_fff7871b89de63', 'E_04eec92d750e17', 'E_b6bcd0abdc59bb', 'E_c0943ca8325026', 'E_94cf05f3655112', 'E_8253bf51d7daa9', 'E_bf8b0e418fe79d', 'E_cf1ff302c49aa6', 'E_7d657f045e762f', 'E_7bf3410dcdbe1d', 'E_28fbfb3405b2ab', 'E_65895c944e1825', 'E_8ab60acfb8d5e5', 'E_4fdb47a714f128', 'E_869709fc0feefb', 'E_0bcb3476e71761', 'E_c4f534be7597e9', 'E_b0ac23d30e5d29', 'E_3b95404237bfd8', 'E_499d70f0ea4673', 'E_363e7549520807', 'E_01cb94c87ecb16', 'E_e9ff9cf67cdb82', 'E_267313446db841', 'E_3fd2db0d62a021', 'E_036e02d50e8899', 'E_b4470520f18bfd', 'E_ba2bcf588f2f31', 'E_49d41a451f1357', 'E_7042ec353dda3a', 'E_e28fed36384998', 'E_d744da9e72f128', 'E_e9863ee18f0f24', 'E_42a8d4f5cd3c5d', 'E_cb7a01ce2648c8', 'E_ab5e2bdab03a73', 'E_b08459c6156232', 'E_c4c3c7e3abf37a', 'E_35b09125341428', 'E_ad529e21e5cf87', 'E_2ab6204de9f88c'}
# point_of_interest: P_613812d1d196e5
# preds: {'E_fff7e3b47c8884', 'E_0c4ceb74236407', 'E_fa9cc3e00627b4'}
# targets: {'E_fff7e3b47c8884', 'E_a7147a419efd7a', 'E_207b463915525b', 'E_59e3459983ddc4', 'E_fa9cc3e00627b4', 'E_9bb3a2c55a2788', 'E_0c4ceb74236407'}
# point_of_interest: P_ae7e9ca82eb46b
# preds: {'E_f010fc2ff286c7', 'E_a0b65b50fe2d13', 'E_9780a5641a5e01', 'E_fff7ef9e2bf8b5'}
# targets: {'E_f6cd8c78e9f571', 'E_04d37344e3b493', 'E_e5fa79ead3ca4a', 'E_822eeb37a531a6', 'E_97c8e51887e1c8', 'E_125160d22f1d40', 'E_33c0e5d8b73e59', 'E_867e13e14bd14f', 'E_e78f939b1c5997', 'E_e5e3dbb0aca13a', 'E_07c8f23eeef5ef', 'E_9780a5641a5e01', 'E_ca7831a1152340', 'E_a0b65b50fe2d13', 'E_f99ff3be42b85a', 'E_9349688d0bbdcc', 'E_02bb6365f7219d', 'E_84c725f04d148d', 'E_e147fafea289b5', 'E_739c156b99ee41', 'E_44f84684680307', 'E_fff7ef9e2bf8b5', 'E_c370450e26f8da', 'E_68ffe417725fb0', 'E_05492dbf35e9df', 'E_2e04e39fa6eae6', 'E_128e39e59cb703', 'E_d44a1fed814160', 'E_f010fc2ff286c7', 'E_7d48a5dfb0108a', 'E_329d43a18af3e2', 'E_f240f7b075cb66'}
# point_of_interest: P_65769c7e8a4d68
# preds: {'E_fff91a35d8450e'}
# targets: {'E_18e6d22f5814d7', 'E_6a6af6657da169', 'E_fff91a35d8450e', 'E_2687d57ff5d8f8', 'E_c1b46643951edb', 'E_f34992fee0fea1', 'E_379cdc6ac34f61', 'E_545253fae23ac0', 'E_4fba5535dd4663', 'E_8c4d3eae70b0b6'}
# point_of_interest: P_f9d0383fcd3375
# preds: {'E_fff970fefa5030'}
# targets: {'E_946af2da40ad33', 'E_fff970fefa5030', 'E_5596f8e6b79a0a'}
# point_of_interest: P_86211a487b8d36
# preds: {'E_393d42bc0cdbce', 'E_5a051b204b6f1f', 'E_fff9ecf69690da'}
# targets: {'E_393d42bc0cdbce', 'E_5a051b204b6f1f', 'E_fff9ecf69690da', 'E_f9f321bbd92810'}
# point_of_interest: P_0d8cb65f0aabef
# preds: {'E_ccbdaf4bd611ea', 'E_110abe3244b781', 'E_ad36723ad3919f', 'E_7949f9fccece0d', 'E_4582cbe6311784', 'E_9d5569bb9c912c', 'E_fff9fde4bb588b', 'E_7a5a4643a1793c', 'E_3d702be64bc520', 'E_d27ee7afd3dfcf', 'E_9ca4c40f5c4bfb', 'E_61c368ebed2929', 'E_7a3605ad09873c', 'E_86dc8f86a37524', 'E_dc58a9627ef81d', 'E_12d46bdd9a48cd', 'E_7fa50a9b5c716a'}
# targets: {'E_a14b58bb276fa1', 'E_ccbdaf4bd611ea', 'E_7949f9fccece0d', 'E_4582cbe6311784', 'E_9d5569bb9c912c', 'E_fff9fde4bb588b', 'E_59cfad2bb4c3cf', 'E_7a5a4643a1793c', 'E_dc58a9627ef81d', 'E_110abe3244b781', 'E_0bd232628aed2c', 'E_3d702be64bc520', 'E_61c368ebed2929', 'E_ba275df384e4db', 'E_7ab09afb1e3417', 'E_1a1004d18455f1', 'E_ad36723ad3919f', 'E_86dc8f86a37524', 'E_85fd3226ebf730', 'E_d27ee7afd3dfcf', 'E_9ca4c40f5c4bfb', 'E_d487f94d32e0db', 'E_7a3605ad09873c', 'E_12d46bdd9a48cd', 'E_7fa50a9b5c716a'}
# point_of_interest: P_1e8e17b542e178
# preds: {'E_fffa63a008cbcd'}
# targets: {'E_623477839dbabb', 'E_fffa63a008cbcd'}
# point_of_interest: P_037468d7274565
# preds: {'E_21fa073ae384f9', 'E_1f3d42adcfe5e5', 'E_fffac30c476d81', 'E_1b1219771c2043', 'E_c83769ec3d4042', 'E_a0156de39267f8'}
# targets: {'E_bc1c284402464f', 'E_1bce18a92a7d97', 'E_e1ef13dbe6dace', 'E_21fa073ae384f9', 'E_0568da68fa916c', 'E_f40e1a9c047527', 'E_1f3d42adcfe5e5', 'E_fffac30c476d81', 'E_050e27e0d8730d', 'E_31cdd83e28c26d', 'E_c83769ec3d4042', 'E_ef3fd6555ddfc0', 'E_c7e67ae2fa2506', 'E_1b1219771c2043', 'E_37575e96587df4', 'E_a0156de39267f8', 'E_0bf85126c569c7'}
# point_of_interest: P_4de520740c4ca4
# preds: {'E_fffc94cbf08007'}
# targets: {'E_c6ae0edb8f697e', 'E_fffc94cbf08007'}
# point_of_interest: P_ac9cca68dcce06
# preds: {'E_c9ff41f8d5f343', 'E_799e6abd807731', 'E_591d9bc7dbdb0e', 'E_fffe9cbe5a2c75', 'E_959fea1a5ee646'}
# targets: {'E_c9ff41f8d5f343', 'E_f54890d9f4cec8', 'E_64aacc7e5a2801', 'E_799e6abd807731', 'E_591d9bc7dbdb0e', 'E_fffe9cbe5a2c75', 'E_959fea1a5ee646'}
# point_of_interest: P_97e04d9412237c
# preds: {'E_fffebfdf9be4cc', 'E_c5e2c92a64ad20'}
# targets: {'E_380d545ca08021', 'E_c5e2c92a64ad20', 'E_fffebfdf9be4cc'}
# point_of_interest: P_9d295f9b619c61
# preds: {'E_ffff83a9496324'}
# targets: {'E_ffff83a9496324', 'E_73c8800d7ca936', 'E_c7618699344378'}
# point_of_interest: P_a630bf50670209
# preds: {'E_008558a7c44ed5', 'E_ffffb80854f713'}
# targets: {'E_008558a7c44ed5', 'E_a05914fd828a1c', 'E_ffffb80854f713', 'E_f5d055893ef064'}
# point_of_interest: P_7ccbeab96cd82e
# preds: {'E_27bcc6f6dd33ed', 'E_8081185a219dc3', 'E_ffffc572b4d35b'}
# targets: {'E_f6784c3ad5cf36', 'E_7bc9754f88e61e', 'E_ccce01d35e4bb9', 'E_daec4fe0f67a32', 'E_ffffc572b4d35b', 'E_ed824ef794fd8d', 'E_2f2d2cddc9bceb', 'E_82dba89a0b1625', 'E_aeb56cd1562100', 'E_60671d056a2f42', 'E_7eff49983c6aae', 'E_22173232a724f4', 'E_55a3173dcf0afb', 'E_613b3e931eed56', 'E_2c023b9995f3ed', 'E_715f3cdecb5a9c', 'E_8bb4b3ee0c2545', 'E_9dbe99342afc03', 'E_dba0f10d7e8ee2', 'E_5ce7fc40a0736a', 'E_21f8bccd2c4b6a', 'E_a3f5efa32b61e4', 'E_e119eafad69c11', 'E_95e47258c151ac', 'E_3d11785a5c17b3', 'E_a690401ef32775', 'E_2594bb48e53f02', 'E_6e74746d07af54', 'E_cf11032bd3e80c', 'E_140d67717e2d94', 'E_195a9c71600fd5', 'E_dd87f47ac061f9', 'E_68f7241cf74ab6', 'E_773e4716304a03', 'E_17a9c780152c95', 'E_ecb38b2d992261', 'E_04074a25e0158f', 'E_ab5647083ae7bc', 'E_fb46d2ef0aa83c', 'E_00911dfe3e73c9', 'E_41ba0ec3d20a87', 'E_44b416dbe8d3bf', 'E_6cdee403ae037a', 'E_8a1a1ee359b513', 'E_27bcc6f6dd33ed', 'E_9789223349d203', 'E_a357fea47f42c6', 'E_d03b08a4b4c643', 'E_e30d2199f33e14', 'E_46a062dcbe4086', 'E_317ab5c540ee7b', 'E_27e9a292b8d5c5', 'E_3c6ce34400830b', 'E_164ddb739d3a0a', 'E_9b8960c3ca6ce7', 'E_262de0dd9121c8', 'E_89c96ef9598397', 'E_67ce70f92a4648', 'E_b7a5768590c1cc', 'E_9a5e5d5a74c443', 'E_83a78a20004360', 'E_4d4539c08587f1', 'E_daf7f534cb27fb', 'E_228816bf35c635', 'E_771a8749f5e13a', 'E_6291bd32843b71', 'E_6781d6dc30517e', 'E_fab1e94cd3c3ee', 'E_1ab928c3b6ff8f', 'E_3d03c9cc82a5ce', 'E_97e209b71d9e2b', 'E_8081185a219dc3', 'E_c3e000daf39030', 'E_4113d3e1cfad18', 'E_42e65609de0b83'}
# point_of_interest: P_ae96252a6a9380

# %%
e_id = 'E_0000764d65557e'
poi = 'P_be89c778befb23'

# %%
data[data[TARGET]==poi]
# Out:
#                                   name  latitude   longitude  \
# id
# E_0000764d65557e            mcdonald s -7.265894  112.749382
# E_0507e10f6eb526            mcdonald s -7.265468  112.748612
# E_30424388e6852c       mcd delta plaza -7.265279  112.748338
# E_7da6445404a886  mcdonald delta plaza -7.279387  112.759431
# E_f4b00a6db8b587      mc d delta plaza -7.264304  112.749496
#
#                                           address      city       state  \
# id
# E_0000764d65557e  Plaza Surabaya  Pemuda Building
# E_0507e10f6eb526            Plaza Surabaya  Lt  1  Surabaya  Jawa Timur
# E_30424388e6852c
# E_7da6445404a886
# E_f4b00a6db8b587
#
#                     zip country                         url      phone  ...  \
# id                                                                      ...
# E_0000764d65557e    NaN      ID                         NaN        NaN  ...
# E_0507e10f6eb526  60271      ID  http://www.mcdonalds.co.id  315450509  ...
# E_30424388e6852c    NaN      ID                         NaN        NaN  ...
# E_7da6445404a886    NaN      ID                         NaN        NaN  ...
# E_f4b00a6db8b587    NaN      ID                         NaN        NaN  ...
#
#                     state_split   cv co_net          main_category scale  \
# id
# E_0000764d65557e             []  0.0    0.0  Fast Food Restaurants     0
# E_0507e10f6eb526  [Jawa, Timur]  0.0    0.0  Fast Food Restaurants     0
# E_30424388e6852c             []  0.0    0.0   American Restaurants     0
# E_7da6445404a886             []  0.0    NaN                    NaN    -1
# E_f4b00a6db8b587             []  0.0    0.0  Fast Food Restaurants     0
#
#                  adjacency_frequency  betweeness_centrality  \
# id
# E_0000764d65557e                 5.0               0.003875
# E_0507e10f6eb526                 5.0               0.003875
# E_30424388e6852c                 7.0               0.027375
# E_7da6445404a886                 NaN                    NaN
# E_f4b00a6db8b587                 5.0               0.003875
#
#                   clustering_coefficient median_distances_median  \
# id
# E_0000764d65557e                0.300000             6354.897123
# E_0507e10f6eb526                0.300000             6354.897123
# E_30424388e6852c                0.190476             6815.049017
# E_7da6445404a886                     NaN                     NaN
# E_f4b00a6db8b587                0.300000             6354.897123
#
#                   category_rate
# id
# E_0000764d65557e       0.015049
# E_0507e10f6eb526       0.015049
# E_30424388e6852c       0.008548
# E_7da6445404a886            NaN
# E_f4b00a6db8b587       0.015049
#
# [5 rows x 25 columns]

# %%
train[train['id']==e_id]
# Out:
#                  id          match_id     kdist  kneighbors  name_iou  \
# 7  E_0000764d65557e  E_0000764d65557e  0.000000           0  1.000000
# 7  E_0000764d65557e  E_47dfd60969c589  0.000478           1  0.000000
# 7  E_0000764d65557e  E_0bc47bcb7d588e  0.000514           2  0.000000
# 7  E_0000764d65557e  E_0507e10f6eb526  0.000880           8  1.000000
# 7  E_0000764d65557e  E_f4b00a6db8b587  0.001594          22  0.000000
# 7  E_0000764d65557e  E_4fc971dfaefd59  0.003169          60  0.000000
# 7  E_0000764d65557e  E_4a59fc88c9517e  0.004188         107  0.000000
# 7  E_0000764d65557e  E_44bc3fc930fc7b  0.004464         124  0.250000
# 7  E_0000764d65557e  E_841b54c05455e1  0.006879         199  0.666667
# 7  E_0000764d65557e  E_0d3f1391ad699b  0.007375         221  0.000000
# 7  E_0000764d65557e  E_0403a6ace011f8  0.008177         253  1.000000
# 7  E_0000764d65557e  E_867ba478324f1e  0.008270         258  0.000000
# 7  E_0000764d65557e  E_3af4615be25d11  0.008279         259  0.666667
# 7  E_0000764d65557e  E_1238fa57e8279b  0.008313         262  0.000000
# 7  E_0000764d65557e  E_7cbb02406596d5  0.008338         265  1.000000
# 7  E_0000764d65557e  E_09fffd6d9b0843  0.008471         275  0.000000
# 7  E_0000764d65557e  E_c689bc36437dc3  0.008502         276  0.666667
# 7  E_0000764d65557e  E_0b22444570c7ed  0.008732         299  0.000000
#
#    cat_similarity  name_rank  cv  co_net  match_co_net  ...  \
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    0.000000e+00       13.0   0     0.0           NaN  ...
# 7    0.000000e+00       15.0   0     0.0           0.0  ...
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    1.000000e+00       10.0   0     0.0           0.0  ...
# 7    1.000000e+00       12.0   0     0.0           0.0  ...
# 7    1.000000e-09        9.0   0     0.0           NaN  ...
# 7    1.000000e+00        7.0   0     0.0           0.0  ...
# 7    0.000000e+00        5.0   0     0.0           NaN  ...
# 7    1.000000e-09        8.0   0     0.0           NaN  ...
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    6.140000e-01        2.0   0     0.0           0.0  ...
# 7    1.000000e+00        4.0   0     0.0           0.0  ...
# 7    1.000000e+00        7.0   0     0.0           0.0  ...
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    1.000000e-09        9.0   0     0.0           NaN  ...
# 7    1.000000e+00        3.0   0     0.0           0.0  ...
# 7    1.000000e+00        6.0   0     0.0           0.0  ...
#
#    clustering_coefficient  match_clustering_coefficient  \
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.000000
# 7                     0.3                      0.300000
# 7                     0.3                      0.300000
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.190476
# 7                     0.3                           NaN
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                      0.300000
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                      0.300000
#
#    mean_clustering_coefficient  median_distances_median  \
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.150000              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.245238              6354.897123
# 7                          NaN              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.300000              6354.897123
#
#    match_median_distances_median  mean_median_distances_median  category_rate  \
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3226.275791                   4790.586457       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3245.487887                   4800.192505       0.015049
# 7                            NaN                           NaN       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                   14017.797394                  10186.347259       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6354.897123                   6354.897123       0.015049
#
#    match_category_rate  mean_category_rate  label
# 7             0.015049            0.015049      1
# 7                  NaN                 NaN      0
# 7             0.002269            0.008659      0
# 7             0.015049            0.015049      1
# 7             0.015049            0.015049      1
# 7             0.015049            0.015049      0
# 7                  NaN                 NaN      0
# 7             0.016522            0.015786      0
# 7                  NaN                 NaN      0
# 7                  NaN                 NaN      0
# 7             0.015049            0.015049      0
# 7             0.000044            0.007547      0
# 7             0.015049            0.015049      0
# 7             0.015049            0.015049      0
# 7             0.015049            0.015049      0
# 7                  NaN                 NaN      0
# 7             0.015049            0.015049      0
# 7             0.015049            0.015049      0
#
# [18 rows x 30 columns]

# %%
# data2 = data.copy()
# data2.reset_index(drop=False, inplace=True)
# tmp = train[train.id==e_id]
# # tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], on='id', how='left')
# tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], left_on='match_id', right_on='id', how='left')
# del data2

# tmp

# %% [markdown]
# # Make Features

# %% [markdown]
# ## TF-IDF

# %%
if TFIDF:
    vec_columns = ['name', 'categories', 'address', 'state', 'url', 'country']

    tfidf_d = {}
    for col in vec_columns:
        tfidf = TfidfVectorizer()
        tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
        tfidf_d[col] = tv_fit

# %% [markdown]
# ## NLP

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
str_columns = ['url', 'name', 'address', 'city', 'state', 'zip', 'categories', 'phone',  'country']
# data['city_state'] = data['city'].fillna('') + data['state'].fillna('')
# data['all'] = data['name'] + data['address'].fillna('') + data['city'].fillna('') + data['state'].fillna('')
# str_columns += ['city_state', 'all']

# if COM > 0:
#     co_columns = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']

# def intersection(s, match_s):
#     return len(set(s.split(' ')) & set(match_s.split(' ')))

# %%
# %%time

# def sm_ratio(x):
#     return SequenceMatcher(None, x[0], x[1]).ratio()

# def levens_dist(x):
#     return Levenshtein.distance(x[0], x[1])

# def calc_jaro_winkler(x):
#     return Levenshtein.jaro_winkler(x[0], x[1])

# def calc_LCS(x):
#     return LCS(str(x[0]), str(x[1]))

def add_features(df):
    for col in tqdm(str_columns):
        before_cols = df.columns
        if TFIDF and col in vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_tfidf_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
            df[f'{col}_tfidf_diff'] = (tv_fit[indexs] - tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
#         arrs = np.array([col_values, matcol_values])
#         df[f'{col}_gesh'] = np.apply_along_axis(sm_ratio, 0, arrs)
#         df[f'{col}_leven'] = np.apply_along_axis(levens_dist, 0, arrs)
#         df[f'{col}_jaro'] = np.apply_along_axis(calc_jaro_winkler, 0, arrs)
#         df[f'{col}_lcs'] = np.apply_along_axis(calc_LCS, 0, arrs)
#         del arrs
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
#         intersections = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
#                 intersections.append(intersection(str(s), str(match_s)))
            elif s != 'nan' and match_s != 'nan':
                geshs.append(-1)
                levens.append(-1)
                jaros.append(-1)
                lcss.append(-1)
#                 intersections.append(-1)
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
#                 intersections.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
#         df[f'{col}_intersections'] = intersections
        
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
        
        del col_values, matcol_values
        after_cols = df.columns
        diff_cols = list(set(after_cols) - set(before_cols))
        df[diff_cols] = reduce_mem_usage(df[diff_cols])
        gc.collect()
        
#     if COM > 0:
#         for col in tqdm(co_columns):
#             col_values = data.loc[df['id']][col].values
#             matcol_values = data.loc[df['match_id']][col].values
#             if col != 'main_category':
#                 df[f's_{col}'] = col_values
#                 df[f't_{col}'] = matcol_values

#             if TFIDF and col in ['main_category', 'co_net']:
#                 df[f'is_match_{col}'] = col_values == matcol_values

    return df

train = add_features(train)

# %% [markdown]
# # Train

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'))

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        print(col)
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
#             df[col] = df[col].astype('category')
            pass

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

train = reduce_mem_usage(train)

# %%
features = ['kdist', 'kneighbors', 'name_gesh', 'name_leven', 'name_jaro',
       'name_lcs', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs',
       'address_gesh', 'address_leven', 'address_jaro', 'address_lcs',
       'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs',
       'city_gesh', 'city_leven', 'city_jaro', 'city_lcs', 'city_len_diff',
       'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_leven',
       'state_jaro', 'state_lcs', 'state_len_diff', 'state_nleven',
       'state_nlcsk', 'state_nlcs', 'zip_gesh', 'zip_leven', 'zip_jaro',
       'zip_lcs', 'categories_gesh', 'categories_leven', 'categories_jaro',
       'categories_lcs', 'categories_len_diff', 'categories_nleven',
       'categories_nlcsk', 'categories_nlcs', 'phone_gesh', 'phone_leven',
       'phone_jaro', 'phone_lcs', 'url_gesh', 'url_leven', 'url_jaro',
       'url_lcs', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs',
       'country_len_diff', 'country_jaro', 'country_lcs', 'country_nlcsk',
       'country_nleven', 'country_nlcs', 'country_leven', 'country_gesh', 
       'co_net', 'match_co_net', 'name_rank',
#        'match_scale', 'is_match_scale', 'is_match_co_net']
       'is_match_scale', 'is_match_co_net', 'match_scale', 'scale',
       'category_rate', 'match_adjacency_frequency', 'clustering_coefficient', 'match_category_rate',
       'betweeness_centrality', 'mean_clustering_coefficient', 'match_median_distances_median',
       'mean_category_rate', 'match_betweeness_centrality', 'mean_betweeness_centrality', 'mean_adjacency_frequency',
       'adjacency_frequency', 'median_distances_median', 'match_clustering_coefficient', 'mean_median_distances_median',
       'cat_similarity', 'name_iou'] # cat_similarity
#        'city_state_gesh', 'all_jaro', 'all_gesh', 'city_state_jaro', 'city_state_len_diff', 'all_nleven', 'city_state_nlcs', 'city_state_leven']
#         'name_intersections', 'address_intersections', 'city_intersections', 'state_intersections']

if TFIDF:
       features.extend(
           ['country_tfidf_sim', 'name_tfidf_diff', 'address_tfidf_diff', 'state_tfidf_sim', 'categories_tfidf_sim', 'url_tfidf_diff', 
       'country_tfidf_diff', 'categories_tfidf_diff', 'url_tfidf_sim', 'name_tfidf_sim', 'address_tfidf_sim', 'state_tfidf_diff'])
    

print(set(train.columns) - set(features))
print(f'no cols: {set(features) - set(train.columns)}')

# %%
params = {
    'num_boost_round': 10000,
    'num_leaves': 500,
    'max_bin':300,
    'feature_fraction': 0.52,
    'bagging_fraction': 0.52,
    'max_depth': -1,
    'objective': 'binary',
    'learning_rate': 0.05,
    "boosting_type": "gbdt",
    "metric": 'auc',
    'early_stopping_rounds': 100,
    "verbosity": 50,
    'random_state': 47
}

# %%
# %%time

models = []
oof = np.zeros((len(train), N_FOLD), dtype=np.float64)
for i in range(N_FOLD):
    trn_idx = train['cv']!=i
    val_idx = train['cv']==i
    valid = train[train['cv']==i]
    train_X, train_y = train[trn_idx][features], train[trn_idx]['label']
    valid_X, valid_y = train[val_idx][features], train[val_idx]['label']
    
    print(f'*** start train cv: {i} ***')
    model = lgb.LGBMClassifier(**params)
    model.fit(
                train_X, train_y, 
                eval_set=[(valid_X, valid_y)])
    
    oof[val_idx] = model.predict_proba(valid_X)
    models.append(model)
    
    model_path = os.path.join(MODEL_PATH, f'lgb_fold{i}.pkl')
    print(f'save model: {model_path}')
    pickle.dump(model, open(model_path, 'wb'))

# %%
# int_cols = ['s_co_net', 's_adjacency_frequency', 't_adjacency_frequency', 't_co_net']
# float_cols = ['t_clustering_coefficient', 's_clustering_coefficient', 's_betweeness_centrality', 't_betweeness_centrality']
# for col in int_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)
    
# for col in float_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)

# %%
cv = (oof.argmax(axis=-1) == train["label"].astype(int)).mean()
print(f"CV-accuracy: {cv}")
# 0.9726

# %%
importance_df = pd.DataFrame(models[0].feature_importances_, 
                             index=features, 
                             columns=['importance'])\
                    .sort_values("importance", ascending=False)


plt.figure(figsize=(20, 10))
sns.barplot(x="importance", y="index", data=importance_df.head(30).reset_index(drop=False))
plt.show()

# %%
del train_X, train_y, valid_X, valid_y, models

# %% [markdown]
# # Change Submission Format

# %%
tmp = train[['id', 'match_id', 'label']]
tmp[['pred_0', 'pred_1']] = oof

# %%
tmp.to_csv(os.path.join(OUTPUT_PATH, 'oof.csv'), index = False)

# %% [markdown]
# ### memoryリセットかけた

# %%
oof = pd.read_csv(os.path.join(OUTPUT_PATH, 'oof.csv'))
oof.head()

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(oof.id.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(oof.iterrows()):
    if row['pred_0'] < row['pred_1']:
        oof_pred[row['id']].append(row['match_id'])

# %%
scores = []
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('cv score is', np.array(scores).mean())
# 0.8643
# 0.8655

# %% [markdown]
# # Check Misclassification

# %%
oof['pred'] = oof['pred_1'].round()
tmp = oof[['id', 'match_id', 'label', 'pred', 'pred_1']]

# %%
t = tmp[tmp['label']!=tmp['pred']]
tt = t[t['pred_1']<0.2]

# %%
len(t)

# %%
tt

# %%
id = 'E_0146e712d66bb8'
m_id = 'E_512009c07275bc'
ids = [id, m_id]
data[data.index.isin(ids)]
# data[data.id.isin(ids)]

# %%
train[(train['id']==id) & (train['match_id']==m_id)][['kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven']]

# %%
train.name_lcs.min()

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==0)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==1)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
train.head(20)[['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
# cols = ['kdist_country', 'kdist', 'categories_jaro', 'name_jaro']
# train[(train['id']==id) & (train['match_id']==m_id)][cols]

# %%
# train[train['kdist_country']== train['kdist']]

# %%
# data[data.index.isin(ids)].loc['E_34199c1154c0d9']['name'].split()

# %%
# data[data.index.isin(ids)].loc['E_0258802b17b98e']['name'].split()
