# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install Levenshtein
    # !pip install unidecode
    # !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.7/dist-packages (0.18.1)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from Levenshtein) (2.0.15)
# Requirement already satisfied: jarowinkler<1.1.0,>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from rapidfuzz<3.0.0,>=2.0.1->Levenshtein) (1.0.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (1.7.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import seaborn as sns
import re
from requests import get
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from difflib import SequenceMatcher
import lightgbm as lgb
import pickle
import Levenshtein
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from unidecode import unidecode
import emoji
import re

random.seed(42)
np.random.seed(42)
warnings.filterwarnings('ignore')

# %%
if "google.colab" in sys.modules:
    expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0]
ROOT_PATH = '/content/drive/MyDrive/Kaggle/Foursquare'
INPUT_PATH = os.path.join(ROOT_PATH, 'input')
OUTPUT_PATH = os.path.join(os.path.join(ROOT_PATH, 'output'), expID)
MODEL_PATH = os.path.join(os.path.join(ROOT_PATH, 'models'), expID)
TARGET = 'point_of_interest'

# %%
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %%
N_NEIGHBORS = 100
NAME_RANK=5
ADDRESS_RANK = 3
CAT_RANK = 5
K_NEIGHBORS = 3
FILTER = 0.0
N_FOLD = 2
DISTANCE = 10000
CATEGORY_COUNT = 100
NAME_THRESHOLD = 0.4
CAT_THRESHOLD = 0.2

DEBUG = False
TFIDF = True
KDIST = True
NET = False # post processでは当たり前にやってた。# predの閾値は利用していなかったので、改良の余地あり。
MOJIBAKE = False
SAMPLING = False

def remove_emoji(src_str):
    return ''.join(c for c in src_str if c not in emoji.UNICODE_EMOJI)

# %%
# with open(os.path.join(OUTPUT_PATH, 'name_variants.pkl'), mode='rb') as f:
#     name_dict = pickle.load(f)

# %%
data = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
if DEBUG:
    data = data.iloc[:10000]
print(data.shape)

# cols = ['name', 'address', 'city', 'state']
cols = ['name']
# cols = ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone'] # categoriesは大文字が小文字になると困る。
for col in cols:
#     if col=='name':
#         data[col].update(data[col].map(name_dict))
    data[col] = data[col].fillna('').apply(unidecode)
    data[col] = data[col].str.lower()
    data[col] = data[col].apply(remove_emoji)

data.head()
# Out:
# (1138812, 13)
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     cafe stad oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           carioca manero -22.907225  -43.178244
# 2  E_000007f24ebc95      raantadphmkaaraaekd  13.780813  100.484900
# 3  E_000008a8ba4f48                 turkcell  37.844510   27.844202
# 4  E_00001d92066153  restaurante casa cofino  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# 1   NaN  Brazilian Restaurants  P_d82910d8382a83
# 2   NaN   Salons / Barbershops  P_b1066599e78477
# 3   NaN     Mobile Phone Shops  P_b2ed86905a4cd3
# 4   NaN    Spanish Restaurants  P_809a884d4407fb

# %%
def sub(x):
    return re.sub(r'[^a-zA-Z0-9 ]', ' ', x)
cols = ['name', 'address', 'city', 'state']
# cols = ['name']
for col in cols:
    data[col] = data[col].fillna('').apply(sub)
    data[f'{col}_split'] = data[col].str.split()

# %%
if MOJIBAKE:
    data.loc[data['name'].str.contains('[买哪侈为裤溦发围货浓调时吧间价爱处灵节怎么办]', na=False), ['name', 'address', 'city']] = '<MOJIBAKE>'

# %%
kf = GroupKFold(n_splits=N_FOLD)
for i, (_, val_idx) in enumerate(kf.split(data, data[TARGET], data[TARGET])):
    data.loc[val_idx, "cv"] = i
print(data["cv"].value_counts())
# Out:
# 1.0    569406
# 0.0    569406
# Name: cv, dtype: int64

# %% [markdown]
# # add Data

# %%
with open(os.path.join(INPUT_PATH, 'id2com_30.pkl'), mode='rb') as f:
    id2com = pickle.load(f)
node_df = pd.read_csv(os.path.join(INPUT_PATH, 'node_df.csv'))
node_df.columns = ['main_category', 'id_code', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']
node_df = node_df[['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']]

def add_co_net(x):
    if x is np.nan:
        return np.nan
    out = -1
    for cat in x.split(', '):
        if cat in id2com.keys():
            out = id2com[cat]
            break

    return out

data['co_net'] = data['categories'].apply(add_co_net)

# %%
def add_main_category(x):
    if x is np.nan:
        return np.nan

    return x.split(', ')[0]

data['main_category'] = data['categories'].apply(add_main_category)

# %%
aggregated_df = pd.read_csv(os.path.join(INPUT_PATH, 'aggregated_df.csv'))
aggregated_df = aggregated_df.iloc[2:]
aggregated_df.columns = ['main_category', 'median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min', 'count']

float_cols = ['median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min']
aggregated_df[float_cols] = aggregated_df[float_cols].astype(float)
aggregated_df['count'] = aggregated_df['count'].astype(int)
aggregated_df['category_rate'] = aggregated_df['count'] / aggregated_df['count'].sum() # leakではない？

aggregated_df.head()
# Out:
#           main_category  median_distances_max  median_distances_75  \
# 2                  ATMs          1.446457e+07         27032.192275
# 3           Acai Houses          1.350800e+05         17781.269899
# 4    Accessories Stores          1.317399e+07         17636.724841
# 5  Acehnese Restaurants          1.394807e+05         28385.619678
# 6        Acupuncturists          1.099943e+06         30876.313672
#
#    median_distances_median  median_distances_25  median_distances_min  count  \
# 2              4490.248044          1012.594350              0.000000   1366
# 3              6117.784384          1359.040401             19.017952     25
# 4              4397.253023          1609.960599              0.000000    890
# 5             11585.417039          6524.589277            308.232222     22
# 6              5262.894842          1160.926141              0.000000     67
#
#    category_rate
# 2       0.002505
# 3       0.000046
# 4       0.001632
# 5       0.000040
# 6       0.000123

# %%
large_scales = list(aggregated_df[(aggregated_df['median_distances_median']>=DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)
small_scales = list(aggregated_df[(aggregated_df['median_distances_median']<DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)

def add_scale(x):
    categories = x.split(", ")
    out = -1
    for cat in categories:
        if cat in large_scales:
            out = 1
            break
        if cat in small_scales:
            out = 0
            break
    return out

data['scale'] = data['categories'].fillna('').apply(add_scale)
data.scale.value_counts()
# Out:
#  0    897808
#  1    127772
# -1    113232
# Name: scale, dtype: int64

# %%
cols = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient']
data= data.merge(node_df[cols], on='main_category', how='left')

cols = ['main_category', 'median_distances_median', 'category_rate'] # maxとかはリークな気がする。
data= data.merge(aggregated_df[cols], on='main_category', how='left')

# %%
# category similarity
cats = data.categories.fillna('')

cat_stats = {}

for c in cats:
    csplit = c.split(", ")
    for c_ in csplit:
        if c_ not in cat_stats:
            cat_stats[c_] = [1, {ca: 1 for ca in csplit}]
        else:
            prev_cat_stats = cat_stats[c_]
            prev_cat_stats[0] += 1
            prev_sims = prev_cat_stats[1]
            
            for ca in csplit:
                prev_sims[ca] = prev_sims.get(ca, 0) + 1
        
for c, val in cat_stats.items():
    
    overall_count = sum(v for ca, v in val[1].items() if ca != c and v > 1)
    
    new_probs = {c: 1.0}
    if overall_count != 0:
        new_probs.update({ca: round(v / overall_count, 3) for ca, v in val[1].items() if v / overall_count > 0.01 and ca != c and v > 1})
        cat_stats[c] = [1.0, new_probs]
        
def get_cat_similarity(cat1, cat2):
    
    if cat1 == '' or cat2 == '':
        return 0.000000001
    
    if cat1 in cat2 or cat2 in cat1:
        return 1.0
    
    best = 0
    
    for c1 in cat1.split(", "):
        for c2 in cat2.split(", "):
            if c1 in cat_stats:
                best = max(best, cat_stats[c1][1].get(c2, 0))
            if c2 in cat_stats:
                best = max(best, cat_stats[c2][1].get(c1, 0))
    
    return best
get_cat_similarity('Bars', 'Cafes, Restaurants')
# Out:
# 0.065

# %% [markdown]
# # Generate Train Data

# %%
# def get_name_contain(name, match_name):
#     if name=='' or match_name=='':
#         return False
#     elif name in match_name or match_name in name:
#         return True
#     else:
#         return False

# def recall_knn_name(df, Neighbors = 10):
#     train = pd.DataFrame()
#     dfs = []
#     Neighbors = min(Neighbors, len(df))
#     knn = NearestNeighbors(n_neighbors = Neighbors)
#     knn.fit(df[['latitude','longitude']], df.index)
    
#     num_splits = len(df) // NUM_SPLIT_DATA
#     start_row = 0
#     for i in tqdm(range(1, NUM_SPLIT_DATA + 1)):
#         end_row = start_row + num_splits
#         if i < NUM_SPLIT_DATA:
#             tmp = df.iloc[start_row : end_row]
#         else:
#             tmp = df.iloc[start_row: ]
#         dists, nears = knn.kneighbors(tmp[['latitude','longitude']])
    
#         for k in tqdm(range(Neighbors)):            
#             cur_df = tmp[['id']]
#             cur_df['match_id'] = df['id'].values[nears[:, k]]
#             cur_df['kdist_name'] = dists[:, k]
#             cur_df['kneighbors_name'] = k
        
#             cols = ['name']
#     #         cols = ['name', 'categories', 'address']
#             for col in cols:
#                 cur_df[col] = tmp[col]
#                 cur_df[f'match_{col}'] = df[col].values[nears[:, k]]
#                 cur_df[f'{col}_contain'] = np.vectorize(get_name_contain)(cur_df[col], cur_df[f'match_{col}'])
#             cur_df = cur_df[(cur_df['name']==cur_df['match_name']) | (cur_df['name_contain'])]
        
#             dfs.append(cur_df)
#         start_row = end_row
#         print('end_row', end_row)

#     return pd.concat(dfs)

# cvs = []
# for i in range(N_FOLD):
#     tmp = recall_knn_name(data[data['cv']==i], 1000)
# #     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
# #               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
#     tmp['cv_name'] = i
#     print(tmp.shape)
#     cvs.append(tmp)
# train_name = pd.concat(cvs)
# print(train_name.shape)
# # train_name.drop(['name', 'match_name', 'name_contain', 'kneighbors_name'], axis=1, inplace=True)
# # train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
# # train.drop(['address', 'match_address', 'address_split', 'match_address_split'], axis=1, inplace=True)
# train_name.drop(['name', 'match_name', 'name_contain'], axis=1, inplace=True)
# train_name.head()
# # 8679523

# %%
def sm_ratio_name(x):
    return SequenceMatcher(None, x['name'], x['match_name']).ratio()

def sm_ratio_name(name, match_name):
    return SequenceMatcher(None, name, match_name).ratio()

def get_name_iou(name_split, match_name_split):
    if len(set(name_split) | set(match_name_split))==0:
        return 0
    else:
        return len(set(name_split) & set(match_name_split)) / len(set(name_split) | set(match_name_split))

def apply_get_cat_similarity(categories, match_categories):
    return get_cat_similarity(categories, match_categories)

def recall_knn_name(df, Neighbors = 10):
    train = pd.DataFrame()
    dfs = []
    Neighbors = min(Neighbors, len(df))
    # print(f'{Neighbors=}')
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in tqdm(range(Neighbors)):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        
        cols = ['name', 'categories']
        for col in cols:
            cur_df[col] = df[col]
            cur_df[f'match_{col}'] = df[col].values[nears[:, k]]

        cols = ['name']
        for col in cols:
            cur_df[f'{col}_split'] = df[f'{col}_split']
            cur_df[f'match_{col}_split'] = df[f'{col}_split'].values[nears[:, k]]
            cur_df[f'{col}_iou'] = np.vectorize(get_name_iou)(cur_df[f'{col}_split'], cur_df[f'match_{col}_split'])
        
        cur_df['cat_similarity'] = np.vectorize(apply_get_cat_similarity)(cur_df['categories'].fillna(''), cur_df['match_categories'].fillna(''))
        cur_df = cur_df[(cur_df['cat_similarity']>0.0) | (cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
#                        | (cur_df['address_iou']>0.0)| (cur_df['city_iou']>0.0)| (cur_df['state_iou']>0.0)]
#         cur_df = cur_df[(cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
        dfs.append(cur_df)
        
        if k!=0 and (k % 50 == 0 or k==Neighbors-1):
            print(f'calc rank: {k}')
            tmp = pd.concat(dfs)
            tmp['sm_ratio_name'] = np.vectorize(sm_ratio_name)(tmp['name'], tmp['match_name'])
            tmp['name_rank'] = 99 # 念の為、入れておく
#             tmp['cat_rank'] = 99 # 念の為、入れておく
            train = pd.concat([train, tmp])
            train['name_rank'] = train.groupby('id')['sm_ratio_name'].rank(ascending=False, method='dense')
#             train['cat_rank'] = train.groupby('id')['cat_similarity'].rank(ascending=False, method='dense')
            train = train[((train['name_rank']<=NAME_RANK) & train['sm_ratio_name']>0.0) | 
                                  (train['categories']==train['match_categories']) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   (train['cat_similarity']==1.0) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   ((train['cat_rank']<=CAT_RANK) & (train['cat_similarity']>0.0) & (train['sm_ratio_name']>0.0)) | 
                                  (train['kneighbors']<K_NEIGHBORS)]
            del tmp, dfs
            dfs = []

    return train

cvs = []
for i in range(N_FOLD):
    tmp = recall_knn_name(data[data['cv']==i], N_NEIGHBORS)
#     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
#               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
    tmp['cv'] = i
    cvs.append(tmp)
train = pd.concat(cvs)
print(train.shape)
train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
train.head()
# 8679523
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 99
#   0%|          | 0/100 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 99
# (10696991, 15)
#                  id          match_id  kdist  kneighbors  name_iou  \
# 1  E_000002eae2a589  E_000002eae2a589    0.0           0       1.0
# 2  E_000007f24ebc95  E_000007f24ebc95    0.0           0       1.0
# 3  E_000008a8ba4f48  E_000008a8ba4f48    0.0           0       1.0
# 4  E_00001d92066153  E_00001d92066153    0.0           0       1.0
# 5  E_000023d8f4be44  E_000023d8f4be44    0.0           0       1.0
#
#    cat_similarity  name_rank  cv
# 1             1.0        1.0   0
# 2             1.0        1.0   0
# 3             1.0        1.0   0
# 4             1.0        1.0   0
# 5             1.0        1.0   0

# %%
# train.to_csv(os.path.join(OUTPUT_PATH, 'train_pred_100.csv'), index = False)

# %%
# train = train.merge(train_name, on = ['id', 'match_id'], how = 'outer')
# train.head()

# %%
# train.loc[train['cv'].isnull(), 'cv'] = train.loc[train['cv'].isnull(), 'cv_name']
# train.loc[train['kdist'].isnull(), 'kdist'] = train.loc[train['kdist'].isnull(), 'kdist_name']
# train.drop(['cv_name', 'kdist_name'], axis=1, inplace=True)

# %%
if TFIDF:
    id2index_d = dict(zip(data['id'].values, data.index)) # tf-idfで使う
data = data.set_index('id')

# %%
for col in ['co_net', 'scale']:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'is_match_{col}'] = train[col]==train[f'match_{col}']
# train.drop(['co_net', 'match_co_net', 'scale', 'match_scale'], axis=1, inplace=True)

# %%
num_cols = ['adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'median_distances_median', 'category_rate']
for col in num_cols:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'mean_{col}'] = (train[col] + train[f'match_{col}']) / 2
#     train.drop([col, f'match_{col}'], axis=1, inplace=True)

# %%
# label作り

ids = train['id'].tolist()
match_ids = train['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train['label'] = np.array(poi == match_poi, dtype = np.int8)

# %% [markdown]
# # Check Maximum Score

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(data.index.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(train.iterrows()):
    if row['label']==1:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
# for base, match in oof_pred.items():
#     if len(match) == 1:        
#         continue

#     for m in match:
#         if base not in oof_pred[m]:
#             oof_pred[m].append(base)

# %%
ids = list(data.index.unique())
scores = []

for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('max score is ', np.array(scores).mean())
# 0.913(30, co_net)
# 50: 0.928(5), 0.930(10)
# 100: 0.930, 0.938
# 200: 0.934
# 300: 0.938

# scale(10000)
# 50: 0.928
# 300: 0.941

# 0.926
# 0.918
# 0.933
# 0.940
# 0.941
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# max score is  0.942248587659333

# %%
train['label'].value_counts()
# 0    5067914
# 1    1980366

# 0    3326444
# 1    1952844
# Out:
# 0    8569240
# 1    2127751
# Name: label, dtype: int64

# %%
train.label.mean()
# 0.232
# 0.223
# Out:
# 0.19891117044036027

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'))

# %%
data.to_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = pd.read_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = data.set_index('id')

# data2 = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
# id2index_d = dict(zip(data2['id'].values, data2.index))
# del data2

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            print(col)
            pass
#             df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ## Candidate Miss Sampling

# %%
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    if preds != targets:
        print(f'preds: {preds}')
        print(f'targets: {targets}')
        print(f'{TARGET}: {id2poi[id_x]}')
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# targets: {'E_c2f88b249aa264', 'E_fca5c38c445c3c', 'E_47216afa56c4a1', 'E_58491550636382', 'E_14f446ad818de2', 'E_ea686a43643f01', 'E_81b950819298dd', 'E_1ea17a3def0038', 'E_604947af3c174e', 'E_6285ae9783e16a', 'E_68da76684d36c6', 'E_c1b36ef168a3bc', 'E_ffa3bf5b4dd6a1', 'E_c079c24c269d3f', 'E_d28d0c9a5793a1', 'E_c26e031c2276fd', 'E_cc98aa264ed88c', 'E_e20fd0e6176a7d', 'E_44385cbfb3f056', 'E_7a244e1fe4d628', 'E_bc661aa4d5260f'}
# point_of_interest: P_c1076f7b9f955d
# preds: {'E_fca5e3737d88d5'}
# targets: {'E_7c340b7ad60bae', 'E_0140dc58d47bdc', 'E_f265ab4fc024f3', 'E_00c6926b303904', 'E_fca5e3737d88d5'}
# point_of_interest: P_706d2c3d29db76
# preds: {'E_fca609f938a52e'}
# targets: {'E_9bf326447b9776', 'E_af4b7481e2f125', 'E_f7eb446e5e863a', 'E_2a82ace263ef7c', 'E_0b7700cf09665d', 'E_138aff22671f30', 'E_1a5da820296317', 'E_8ea320cc1e5f01', 'E_fca609f938a52e', 'E_7a477575be0f94', 'E_27c639a0d48ad4'}
# point_of_interest: P_49cfe4f1f891cf
# preds: {'E_fca690e7ebcc11'}
# targets: {'E_62397f647c293c', 'E_fca690e7ebcc11'}
# point_of_interest: P_d68329e32a399d
# preds: {'E_fca6a3863a6536', 'E_4ffef512b6c933'}
# targets: {'E_1135d68df3f919', 'E_fca6a3863a6536', 'E_4ffef512b6c933'}
# point_of_interest: P_30785a810c1fd7
# preds: {'E_fca6c416c40763'}
# targets: {'E_3fd2c1dfbe1bc3', 'E_fca6c416c40763'}
# point_of_interest: P_0d6772061e8b6b
# preds: {'E_205f95218899a5', 'E_d549e0eb855c20', 'E_df96fa0b4ae710', 'E_b573fede918b44', 'E_a5f254d3c59862', 'E_fca6f86d8dc5e7'}
# targets: {'E_205f95218899a5', 'E_d549e0eb855c20', 'E_df96fa0b4ae710', 'E_22e0e348387197', 'E_a5b8d873b1662c', 'E_b573fede918b44', 'E_a5f254d3c59862', 'E_fca6f86d8dc5e7', 'E_449c59b77af1f4'}
# point_of_interest: P_fb3c264cdee299
# preds: {'E_bef3e2050ab3c1', 'E_fca71518f76574'}
# targets: {'E_bef3e2050ab3c1', 'E_fca71518f76574', 'E_3f8bd9c28abe1e'}
# point_of_interest: P_b9286b208cd7f8
# preds: {'E_fca719e8b902b1', 'E_52efa076f50823'}
# targets: {'E_fca719e8b902b1', 'E_52efa076f50823', 'E_8da36325d6715e'}
# point_of_interest: P_7578302291557f
# preds: {'E_fca7436da02140'}
# targets: {'E_f3ab133cbe8699', 'E_fca7436da02140'}
# point_of_interest: P_858b07c8cecbd7
# preds: {'E_fca7bc6ceaa5cf'}
# targets: {'E_d76828ba70e756', 'E_fca7bc6ceaa5cf'}
# point_of_interest: P_254aca08df65a8
# preds: {'E_35d28eedbf2e7f', 'E_fca9c5cf589aad'}
# targets: {'E_8949b51ae69453', 'E_35d28eedbf2e7f', 'E_fca9c5cf589aad', 'E_c463280d1b16a4'}
# point_of_interest: P_66e3ac8caa4503
# preds: {'E_fcaa2caf6c17c6'}
# targets: {'E_e1ed0f57a7d8bf', 'E_fcaa2caf6c17c6'}
# point_of_interest: P_8bad517e339967
# preds: {'E_9cb559213726a6', 'E_fcaa3f0da8e7d7'}
# targets: {'E_9cb559213726a6', 'E_fcaa3f0da8e7d7', 'E_560b90fb00ec20'}
# point_of_interest: P_b9a4bffdd12abb
# preds: {'E_fcab3670415e0e'}
# targets: {'E_fcab3670415e0e', 'E_da64c52d395c5e'}
# point_of_interest: P_1adb244f69d017
# preds: {'E_175170979bb65f', 'E_6f7059fb1b86ee', 'E_309a0e2956f2bb', 'E_6bd822793aa61d', 'E_27b44d60867e3b', 'E_4675c17b423156', 'E_fcab4ce18ce346', 'E_96c88d18976c23', 'E_6527287fb4cc20'}
# targets: {'E_4e37a13bed8392', 'E_175170979bb65f', 'E_8565fa400eaa2e', 'E_6f7059fb1b86ee', 'E_ae0d894b20befb', 'E_309a0e2956f2bb', 'E_03a4543a9c8452', 'E_6bd822793aa61d', 'E_27b44d60867e3b', 'E_4675c17b423156', 'E_fcab4ce18ce346', 'E_96c88d18976c23', 'E_6527287fb4cc20'}
# point_of_interest: P_0f6b0f3241ff66
# preds: {'E_fcab935d1c8db0'}
# targets: {'E_fcab935d1c8db0', 'E_f79d0bfa736fd7'}
# point_of_interest: P_b710ebf9af4377
# preds: {'E_fcac9d74daa806'}
# targets: {'E_fcac9d74daa806', 'E_9f95b1688a97c3'}
# point_of_interest: P_51ff66846efa34
# preds: {'E_78ce666b2da1ae', 'E_10b2be20e85bca', 'E_e5a16267b8bf9f', 'E_7eb7d38a660d75', 'E_a7b45c929271bf', 'E_79d5c630d01517', 'E_4a4ba809f2e531', 'E_d2b261a2883fb5', 'E_2692cb6d49a24b', 'E_f76c771b928c97', 'E_f6c6e0c74dc6af', 'E_aa966bc8b653d8', 'E_df62edd70302f2', 'E_cbc2922900ee43', 'E_d71b795e7bd828', 'E_6da30451ba84b7', 'E_f81be5603e92bd', 'E_9b27102e2f0c17', 'E_e8ce0845c672bd', 'E_c2cca1e66838a5', 'E_831328ec294a3e', 'E_c923c9c970d2e2', 'E_19b4360b596816', 'E_fcad6f80eff4b9', 'E_21d5d27da2e6b5'}
# targets: {'E_78ce666b2da1ae', 'E_10b2be20e85bca', 'E_e5a16267b8bf9f', 'E_7eb7d38a660d75', 'E_888f1d4069f406', 'E_a7b45c929271bf', 'E_79d5c630d01517', 'E_4a4ba809f2e531', 'E_e972ddd17c2b1e', 'E_f201f4854dafbd', 'E_d2b261a2883fb5', 'E_2692cb6d49a24b', 'E_f76c771b928c97', 'E_f6c6e0c74dc6af', 'E_607d263ef22131', 'E_aa966bc8b653d8', 'E_df62edd70302f2', 'E_cbc2922900ee43', 'E_d71b795e7bd828', 'E_6da30451ba84b7', 'E_f81be5603e92bd', 'E_9b27102e2f0c17', 'E_e8ce0845c672bd', 'E_31a7eaa880be6b', 'E_4c5a5bff13b4dd', 'E_c2cca1e66838a5', 'E_953c168268fae9', 'E_79f1b193e0a38d', 'E_831328ec294a3e', 'E_c923c9c970d2e2', 'E_59fdb4ab8f29ca', 'E_4230b117bcbc99', 'E_1314595ed9a419', 'E_19b4360b596816', 'E_fcad6f80eff4b9', 'E_21d5d27da2e6b5'}
# point_of_interest: P_30eaf5781193eb
# preds: {'E_fcad9cc99e3773'}
# targets: {'E_fcad9cc99e3773', 'E_e11fd30bf2c83b'}
# point_of_interest: P_505af6d666f47c
# preds: {'E_fcaf23fb9e16c9', 'E_c9ff3d3f23c903', 'E_54415536b24b5e'}
# targets: {'E_c9ff3d3f23c903', 'E_666888f6719aef', 'E_fcaf23fb9e16c9', 'E_54415536b24b5e'}
# point_of_interest: P_adc7ccb02613f2
# preds: {'E_fcafa804098cb3'}
# targets: {'E_fcafa804098cb3', 'E_66dda3be23a6a6'}
# point_of_interest: P_b7a1e3fa13bcf1
# preds: {'E_fcb03f9a8c169e'}
# targets: {'E_4b8c4854385b4f', 'E_fcb03f9a8c169e'}
# point_of_interest: P_84fa9a2a6bb768
# preds: {'E_fcb060e807cc98'}
# targets: {'E_fcb060e807cc98', 'E_8aa575c7a4b67e', 'E_36b45444945fdc'}
# point_of_interest: P_f29f4db0e1d1a1
# preds: {'E_fcb0babeb86ddb', 'E_e82a70172e2d5e'}
# targets: {'E_fcb0babeb86ddb', 'E_e82a70172e2d5e', 'E_cc703cd567e044'}
# point_of_interest: P_fdd234a8b8e8bd
# preds: {'E_fcb14bec64388b', 'E_6ddcdefce19f61', 'E_726eb69309fa50', 'E_b9d46bcdf59b76', 'E_fa634219dc867b', 'E_f73b28b4ddc92e', 'E_768f20ba61dc39', 'E_7731dc7482f7a4', 'E_f0441b4f9f3e8a', 'E_7e44eeebe6f4b6', 'E_7dfeaca6fbb8ad', 'E_99b26763397d00', 'E_5023cae142e33f', 'E_067bd95c5b802a', 'E_ab7e2308a81a64', 'E_419c7adfab2257', 'E_f5189dc634bf4b', 'E_28469a8c8dcd28', 'E_91ce60351a7631'}
# targets: {'E_6ddcdefce19f61', 'E_fcb14bec64388b', 'E_726eb69309fa50', 'E_b9d46bcdf59b76', 'E_fa634219dc867b', 'E_f73b28b4ddc92e', 'E_768f20ba61dc39', 'E_7731dc7482f7a4', 'E_f0441b4f9f3e8a', 'E_7dfeaca6fbb8ad', 'E_2e794ad6c76dc0', 'E_99b26763397d00', 'E_5023cae142e33f', 'E_067bd95c5b802a', 'E_ab7e2308a81a64', 'E_419c7adfab2257', 'E_28469a8c8dcd28', 'E_ea7397fdfa9527', 'E_f5189dc634bf4b', 'E_ef590e87722e96', 'E_7e44eeebe6f4b6', 'E_91ce60351a7631'}
# point_of_interest: P_18ae0d03c46b53
# preds: {'E_73e70b7f3b1b3b', 'E_76909754dea65c', 'E_4ef088696f1dd2', 'E_b7e0ce17f762a7', 'E_fcb1693dc8a02b'}
# targets: {'E_73e70b7f3b1b3b', 'E_76909754dea65c', 'E_09e900d28f831b', 'E_4ef088696f1dd2', 'E_b7e0ce17f762a7', 'E_fcb1693dc8a02b', 'E_33cf503d56a933'}
# point_of_interest: P_ccd6e230cad858
# preds: {'E_fcb1c718a8dded'}
# targets: {'E_fcb1c718a8dded', 'E_c7ce1e1e6f55f3'}
# point_of_interest: P_6c878cca660311
# preds: {'E_fcb21273559492'}
# targets: {'E_a6b871a5d9e44a', 'E_428d627a4726d3', 'E_fcb21273559492', 'E_f6951d4cdb3848'}
# point_of_interest: P_b9610129fb4d01
# preds: {'E_4dd3488042eda6', 'E_601511f4a7b5e2', 'E_fcb3e40b7e9be3'}
# targets: {'E_4dd3488042eda6', 'E_92dacc0f390d59', 'E_fcb3e40b7e9be3', 'E_601511f4a7b5e2'}
# point_of_interest: P_40c5265b252f23
# preds: {'E_fcb42bfc38cee9'}
# targets: {'E_fcb42bfc38cee9', 'E_c1fc52c47b669a', 'E_4ec4dee387337b', 'E_5003c9dce7d8c4'}
# point_of_interest: P_2cc18b07bcc149
# preds: {'E_fcb46b2f1034d8'}
# targets: {'E_fcb46b2f1034d8', 'E_8e2acb19228836'}
# point_of_interest: P_6cdcd238e55ae6
# preds: {'E_8116ef15b1e6cb', 'E_fcb48768c0a14d'}
# targets: {'E_8116ef15b1e6cb', 'E_6b7c08af363726', 'E_fcb48768c0a14d'}
# point_of_interest: P_3b451882959714
# preds: {'E_550ba37c6837ac', 'E_e005fc2fec80f9', 'E_fcb49d67136ec0'}
# targets: {'E_efb9ff8c45b3df', 'E_fcb49d67136ec0', 'E_550ba37c6837ac', 'E_e005fc2fec80f9', 'E_9d43a38140b400'}
# point_of_interest: P_7e411e939c78f7
# preds: {'E_fcb4dce50fa46f'}
# targets: {'E_7450e1bde9c0fe', 'E_fcb4dce50fa46f'}
# point_of_interest: P_c57de701d7e952
# preds: {'E_fcb5d76f3cc1c2'}
# targets: {'E_6bd75c1e45a8ba', 'E_fcb5d76f3cc1c2'}
# point_of_interest: P_b078021257a818
# preds: {'E_fcb6094d4c1c97'}
# targets: {'E_fcb6094d4c1c97', 'E_2e0d69796cf455', 'E_3eaae1309182cd', 'E_ecd968681db6b9', 'E_a443575f4f7972'}
# point_of_interest: P_8f46a735c146f4
# preds: {'E_fcb6b8cba11c3b'}
# targets: {'E_ed7d1443188e65', 'E_fcb6b8cba11c3b'}
# point_of_interest: P_d8634d62bec84e
# preds: {'E_fcb6db35029ea4'}
# targets: {'E_fcb6db35029ea4', 'E_0218a1607e5d48', 'E_2bef6f72a4141e'}
# point_of_interest: P_a2138f4d817ae2
# preds: {'E_fcb704bf710f8f'}
# targets: {'E_b46d1c51a19acf', 'E_fcb704bf710f8f'}
# point_of_interest: P_d0f1401003e10d
# preds: {'E_020b8907509ae4', 'E_f57af69bd48021', 'E_fcb73fe910343f'}
# targets: {'E_020b8907509ae4', 'E_1c892d973bfb52', 'E_fcb73fe910343f', 'E_f57af69bd48021'}
# point_of_interest: P_64c57d92ba208d
# preds: {'E_fcb76eb8aa30df'}
# targets: {'E_fcb76eb8aa30df', 'E_2f7795ddc02605', 'E_3f622d18341b33', 'E_8a3e1eff85f29a', 'E_0fc67c8de4c0d5', 'E_72d3d7527ba6f9'}
# point_of_interest: P_03aa0dba833844
# preds: {'E_fcb7718d3b9438'}
# targets: {'E_6c2638a614099b', 'E_ab67e8017bee9a', 'E_fcb7718d3b9438'}
# point_of_interest: P_4661690302dbad
# preds: {'E_fcb793675aca04'}
# targets: {'E_4288d926d9669d', 'E_fcb793675aca04'}
# point_of_interest: P_d8769b6d57dc71
# preds: {'E_fcb7be205daee7'}
# targets: {'E_fcb7be205daee7', 'E_a2f7e6829bcef7'}
# point_of_interest: P_d4eac379fbde98
# preds: {'E_33569cb1137078', 'E_68b327ca7a0c69', 'E_86b7249230586d', 'E_fcb89ef5a29b6d', 'E_debad846997826', 'E_a16a3ede97304d', 'E_cc3f41ad8f77d2', 'E_432d6cb8bb806a'}
# targets: {'E_33569cb1137078', 'E_526d7af3cd6049', 'E_68b327ca7a0c69', 'E_86b7249230586d', 'E_fcb89ef5a29b6d', 'E_6ebe26783f3a50', 'E_debad846997826', 'E_a16a3ede97304d', 'E_cc3f41ad8f77d2', 'E_432d6cb8bb806a'}
# point_of_interest: P_f8c089d876baa5
# preds: {'E_a58ad793d5e70a', 'E_8769263816176a', 'E_fcb9a78a11e2c8'}
# targets: {'E_cce2593f6a1957', 'E_fcb9a78a11e2c8', 'E_a58ad793d5e70a', 'E_ad0f599d94ded7', 'E_8769263816176a'}
# point_of_interest: P_0acf132ba27d29
# preds: {'E_fcb9c99ffee521'}
# targets: {'E_5a458fc99ce953', 'E_fcb9c99ffee521'}
# point_of_interest: P_37be18bc3da2ce
# preds: {'E_fcb9d09b0f0613'}
# targets: {'E_fcb9d09b0f0613', 'E_ee6f7b5ee7c636'}
# point_of_interest: P_ed66a6dfcd5e8d
# preds: {'E_fcbabed956a422'}
# targets: {'E_63f40f38eb1216', 'E_fcbabed956a422'}
# point_of_interest: P_0094deac35f322
# preds: {'E_fcbba85c221d0d', 'E_7cf12f5789adba', 'E_56b2e70fb8f97e', 'E_b9b0f3c854c13f', 'E_1afdb43b3645a0', 'E_4d2a9770b02bd4', 'E_b9ecd7e76cd600', 'E_235fc8fbf6607e'}
# targets: {'E_fcbba85c221d0d', 'E_a1fc7b34e0310f', 'E_7cf12f5789adba', 'E_56b2e70fb8f97e', 'E_b9b0f3c854c13f', 'E_3af999748520cd', 'E_1afdb43b3645a0', 'E_4d2a9770b02bd4', 'E_b9ecd7e76cd600', 'E_235fc8fbf6607e', 'E_eb0f33ac34a475'}
# point_of_interest: P_d2659dcd04024a
# preds: {'E_881eda05ebfd2e', 'E_fcbcdd3c680acd'}
# targets: {'E_40b8950dee8b10', 'E_fcbcdd3c680acd', 'E_881eda05ebfd2e'}
# point_of_interest: P_dfd6d254fa60de
# preds: {'E_fcbd4471531364'}
# targets: {'E_fcbd4471531364', 'E_3a0f3c604e782f'}
# point_of_interest: P_4eae9b5b20fc0e
# preds: {'E_fcbdc1cd6715ef'}
# targets: {'E_fcbdc1cd6715ef', 'E_eb579f0cbd6d8d'}
# point_of_interest: P_c919c0fbe3d671
# preds: {'E_fcbef0a89dde46'}
# targets: {'E_fcbef0a89dde46', 'E_a760fc4029dfe0'}
# point_of_interest: P_02c623418be86c
# preds: {'E_fcbef0df405a9f'}
# targets: {'E_fcbef0df405a9f', 'E_03a9abd9a9cec4'}
# point_of_interest: P_32cde2556bc63e
# preds: {'E_fcbf1bab2caad7'}
# targets: {'E_5f5bce03a85808', 'E_73838a8f322bfb', 'E_b9a628a6bdf8f5', 'E_fcbf1bab2caad7', 'E_c04ca727bc208d', 'E_9185862e287713', 'E_b5d7366d35c972', 'E_ba29f084ca1e9c', 'E_8b48199ef0ac39', 'E_df03ca04c049c3', 'E_e7be44c7983113', 'E_fd2e41c01a2901', 'E_027fe050b5109e', 'E_361b0fc38f14d9', 'E_8e12d835812316', 'E_7094e818a93260'}
# point_of_interest: P_0576b1b5ba3344
# preds: {'E_fb9a489eba6273', 'E_fcbf30df2aff45'}
# targets: {'E_e33a32a191fd19', 'E_fb9a489eba6273', 'E_fcbf30df2aff45'}
# point_of_interest: P_749691e6b481eb
# preds: {'E_fcbf52f6a7a8aa'}
# targets: {'E_fcbf52f6a7a8aa', 'E_2ee4e150f54593', 'E_180eb716065a01'}
# point_of_interest: P_acf82c3c2c18c3
# preds: {'E_fcbf79385e1e13'}
# targets: {'E_6271265ff0e358', 'E_fcbf79385e1e13'}
# point_of_interest: P_da8ac7485a72d6
# preds: {'E_a4b2e72e587fbd', 'E_fcc0b2a00d3cfb'}
# targets: {'E_c0105fb0264793', 'E_a4b2e72e587fbd', 'E_e5bd3fd232a545', 'E_6cd11c3aec9006', 'E_fcc0b2a00d3cfb'}
# point_of_interest: P_ac6d90d52ba180
# preds: {'E_fcc137376788c8', 'E_fea3de492d0380', 'E_3be6815893fec0', 'E_f93c735f31b65d'}
# targets: {'E_e1f1d8c9174ba9', 'E_fea3de492d0380', 'E_380b52452fa335', 'E_fcc137376788c8', 'E_3be6815893fec0', 'E_f93c735f31b65d'}
# point_of_interest: P_4a03e6c93ece04
# preds: {'E_fcc1e9307b454d'}
# targets: {'E_ee82a80f8d3a1f', 'E_fcc1e9307b454d', 'E_89bbbfae28929e'}
# point_of_interest: P_d161c37272a4fb
# preds: {'E_fcc212e68c1c47'}
# targets: {'E_fcc212e68c1c47', 'E_8643a041af53b3'}
# point_of_interest: P_815e4349ed7792
# preds: {'E_3789c5f5e0ff2a', 'E_fcc227b357b2dd'}
# targets: {'E_c26c5c1b2e63e4', 'E_3789c5f5e0ff2a', 'E_fcc227b357b2dd'}
# point_of_interest: P_c7fca79a82781b
# preds: {'E_fcc2aaec59c14e', 'E_b745059e3eb6fd'}
# targets: {'E_b3463bc4873308', 'E_b745059e3eb6fd', 'E_fcc2aaec59c14e'}
# point_of_interest: P_82bd57b61546fe
# preds: {'E_2455abb0a10a6d', 'E_fcc2eac4b82377', 'E_a94fb9ea797ea3', 'E_57b6972a889579', 'E_8472dfb67233e4', 'E_dab35142dd7b26', 'E_b5bf5eb591caa0', 'E_f35098e9f993c5'}
# targets: {'E_2455abb0a10a6d', 'E_fcc2eac4b82377', 'E_a94fb9ea797ea3', 'E_57b6972a889579', 'E_8472dfb67233e4', 'E_dab35142dd7b26', 'E_3efe71ec6a4e56', 'E_b5bf5eb591caa0', 'E_f35098e9f993c5'}
# point_of_interest: P_7b387a197309ee
# preds: {'E_fcc2f880a4d559'}
# targets: {'E_7fffc710716e8f', 'E_e6bf736f461a7c', 'E_91a02fb091cdc0', 'E_1fda1cb4ca4937', 'E_327d4d1aa4481e', 'E_d50b4c66fe5cbe', 'E_739db07b6fb795', 'E_d2db3739ae8bc8', 'E_ffaf3f2b2d4120', 'E_f74a2bdd0dedd1', 'E_fcc2f880a4d559', 'E_9a10749070296f', 'E_c5973d5033a570', 'E_2d6aaa862fb793', 'E_595b406f1067f8', 'E_271389fc260a72'}
# point_of_interest: P_73d37d2fb608b6
# preds: {'E_fcc33cfc64325a'}
# targets: {'E_43b16a5cd79901', 'E_9e2d99055ddf66', 'E_82ad7a55bdf778', 'E_cfa59165c93b55', 'E_da09eb8397440e', 'E_5847de96301325', 'E_bf7ad8cf2c1002', 'E_ea1bcc2c1669d9', 'E_fcc33cfc64325a', 'E_5bda37ce0bc8da', 'E_fc42617acfb9a3', 'E_78b1d7ca7b07ae', 'E_f75d9b2d2ed105', 'E_a1a9a77aeca146', 'E_9f683c1bbe19f7'}
# point_of_interest: P_ad464e8f73902d
# preds: {'E_fcc3625045d09f'}
# targets: {'E_0fe063a786d190', 'E_fcc3625045d09f'}
# point_of_interest: P_2921de75753291
# preds: {'E_de238176428bcf', 'E_2a39ce6222e051', 'E_a5afa3b326856e', 'E_3f40fb0d3f1fe1', 'E_fcc36f4e76002c', 'E_fd2d7aef646dab', 'E_f8860230bcaeb0', 'E_022114a1b125ee'}
# targets: {'E_3d0488633f44d9', 'E_de238176428bcf', 'E_a5afa3b326856e', 'E_cd7df02054c0e8', 'E_11c59edf6d2611', 'E_77a92452d4d300', 'E_16c461ca8ff46a', 'E_8dc52185bae88e', 'E_e55babcef6d525', 'E_eeff04e3538873', 'E_fcc36f4e76002c', 'E_94ed67dfe5be4d', 'E_c3c8afcbdbb34a', 'E_d446059ff6314f', 'E_9225eaffb93e73', 'E_dafab37f824dd1', 'E_2a39ce6222e051', 'E_4b2804e886d179', 'E_3f40fb0d3f1fe1', 'E_aae91cd51a9374', 'E_fd380b5290b7f1', 'E_7469548ab287cc', 'E_d763731184955c', 'E_022114a1b125ee', 'E_48a07f393144d1', 'E_815036f722b938', 'E_dd2998cd36ef79', 'E_34d5fa41de1cde', 'E_71f0a216f60624', 'E_c1854b2d19162b', 'E_240a701f7890c1', 'E_77a1f984d6515b', 'E_377f236c1685ee', 'E_c9de3c6007288e', 'E_c181f9c53a3bf1', 'E_499345178dd348', 'E_663e1499964372', 'E_b56fbe71add344', 'E_f8860230bcaeb0', 'E_e0eedfc308d424', 'E_8b78ee40bdecc7', 'E_8d183284964f18', 'E_fd2d7aef646dab', 'E_2fb4e90f9252c4', 'E_9cda0644f1ddf8', 'E_bedac21ce3d81d', 'E_680374bcc5098f'}
# point_of_interest: P_6e7dd319013fa4
# preds: {'E_fcc46721be5161', 'E_249554ecef6eb4'}
# targets: {'E_fcc46721be5161', 'E_249554ecef6eb4', 'E_14605a7c8faaef'}
# point_of_interest: P_b31854c4033207
# preds: {'E_105d819b4443ee', 'E_082655de807e7d', 'E_fcc4f5167d6098', 'E_bce4ddaa66b9f6', 'E_42f5ef4c59e1d6', 'E_1e84a9df1254df'}
# targets: {'E_082655de807e7d', 'E_105d819b4443ee', 'E_a73a1a2d6d0d07', 'E_fcc4f5167d6098', 'E_bce4ddaa66b9f6', 'E_42f5ef4c59e1d6', 'E_1e84a9df1254df', 'E_2d7a442020225f', 'E_956b5efb06443d'}
# point_of_interest: P_9e157b47411f2e
# preds: {'E_fcc597646318c1'}
# targets: {'E_c575751057013e', 'E_fcc597646318c1'}
# point_of_interest: P_0b240b9c0f1df4
# preds: {'E_fcc5f318ce33d8'}
# targets: {'E_fcc5f318ce33d8', 'E_08b85e1d34cc6b'}
# point_of_interest: P_f2d7449f90cf2b
# preds: {'E_fcc698a057695a'}
# targets: {'E_656634a2d9e571', 'E_fcc698a057695a'}
# point_of_interest: P_532b4a2e6e7a81
# preds: {'E_fcc6bee50609ec', 'E_1f61a814629e55', 'E_abf2d5b16c3104', 'E_a3df3be8acd2bb', 'E_2779328db31b5c'}
# targets: {'E_23d26e3cfe8248', 'E_ad5e43b36532fa', 'E_b4513c27872acd', 'E_9199a57cc81cdf', 'E_cb836eafc04654', 'E_0276dc3ac1b940', 'E_1f61a814629e55', 'E_791698b56e63dc', 'E_e8fe4dceb741fc', 'E_5aa077b16eed10', 'E_ebf4ebb1d287cb', 'E_750d031bfa0514', 'E_10639b4b65d135', 'E_e7f8dfb1261475', 'E_00f91ad3d844c7', 'E_e069b25d0d19b4', 'E_a9c178129c45a1', 'E_6277ca968ccaf9', 'E_e64111a454c468', 'E_3aa5a77ddb32ea', 'E_a1eb0b2a454c91', 'E_5930b83a258341', 'E_e91fa0e9259859', 'E_ad71d6b89393f6', 'E_1af36b24cef8d8', 'E_0148052ad7e6ef', 'E_5fdb7a6d841a99', 'E_e6ea395f6107e3', 'E_5073bd0799df06', 'E_c08a043305bda8', 'E_b894b295da3127', 'E_059bba5e9d705c', 'E_e56b5d017ff5be', 'E_fcc6bee50609ec', 'E_e0707a53830f73', 'E_92a7a60b5e8ea1', 'E_28c51681035a99', 'E_58600e94e2be69', 'E_abf2d5b16c3104', 'E_64153083f79f78', 'E_1f28b9914bf118', 'E_9304cc9714f54d', 'E_edef4e884c7f66', 'E_0beeb18be5f9a6', 'E_fc8bb26ceab15f', 'E_eb31e849d9e8e9', 'E_8e5620c6c290b0', 'E_ece5864aa16090', 'E_ac7b544a6bab3b', 'E_5967b4e2baf0a5', 'E_90b8d5d3d1670b', 'E_f1349769ed93ca', 'E_c353d9ef04a400', 'E_fc08204edf6e14', 'E_add34db0029a90', 'E_b162bc42355a76', 'E_fa0223339cc61a', 'E_87dd644eb4de3c', 'E_8f4ec6b229ad82', 'E_bcb36c33d4ab6a', 'E_0b94dcae5a8d02', 'E_cd7eb628e0c2c0', 'E_c2f4ff87d64f56', 'E_7399af91b4ae05', 'E_2d5bcb36b01967', 'E_baa2c502231c04', 'E_3f938a510d9436', 'E_0e2daac2f241eb', 'E_64c47f72cb1f7c', 'E_5fb70a0a0f8ec7', 'E_0918ed79d7e19c', 'E_a586eadf0080ec', 'E_c1b165eaf3be5c', 'E_2779328db31b5c', 'E_d322550c4df228', 'E_c9999b4301992a', 'E_72ae77050f445f', 'E_572ef4e5a016fa', 'E_43c820a076edd3', 'E_a3df3be8acd2bb'}
# point_of_interest: P_7c5f67c96b0d53
# preds: {'E_615843b234aeb9', 'E_fcc6f4c94525bc'}
# targets: {'E_615843b234aeb9', 'E_70e171037dbbfa', 'E_fcc6f4c94525bc'}
# point_of_interest: P_0f7a2d168c0825
# preds: {'E_fcc728f297f1d8'}
# targets: {'E_fcc728f297f1d8', 'E_7cda23a96dbac9', 'E_35313cf08df8bf'}
# point_of_interest: P_4943e6e732637f
# preds: {'E_f78349a97aefd2', 'E_fcc75700080ef1'}
# targets: {'E_a4667b6382286f', 'E_2cf7ed329db3ce', 'E_c6a0fd28ebdca2', 'E_f78349a97aefd2', 'E_a6876e04a8b260', 'E_fcc75700080ef1'}
# point_of_interest: P_88511318818031
# preds: {'E_59d7bb129bc8cf', 'E_65537225818279', 'E_315008468794d2', 'E_7ab1d75419ca2a', 'E_fcc7f296e33c07'}
# targets: {'E_063189f25bd8b2', 'E_59d7bb129bc8cf', 'E_65537225818279', 'E_315008468794d2', 'E_7ab1d75419ca2a', 'E_fcc7f296e33c07'}
# point_of_interest: P_87606d6388637f
# preds: {'E_fcc90ca74d7951'}
# targets: {'E_3eb138445648ea', 'E_890e9b0e769638', 'E_fcc90ca74d7951'}
# point_of_interest: P_74c04a772239f7
# preds: {'E_fcc9f0f0bfb00e', 'E_390778d6c1a195', 'E_f9ea46a7fc6db6'}
# targets: {'E_eaaeb99d3d880f', 'E_d569d1260bd69b', 'E_390778d6c1a195', 'E_387fa31497e45a', 'E_1e2c24066e5867', 'E_5f9011eeb99372', 'E_fcc9f0f0bfb00e', 'E_d581c3934b536b', 'E_f9ea46a7fc6db6'}
# point_of_interest: P_529a20a1108f2d
# preds: {'E_fcca3da560b9f1'}
# targets: {'E_ff988a01735cfb', 'E_fcca3da560b9f1'}
# point_of_interest: P_e508d149512292
# preds: {'E_fcca926bd870f3', 'E_7d50a79c010aaa', 'E_775f8fe252cd40', 'E_e41c4cf2e1adea', 'E_57ae6d331e8549'}
# targets: {'E_fcca926bd870f3', 'E_7d50a79c010aaa', 'E_775f8fe252cd40', 'E_e41c4cf2e1adea', 'E_1bc2cbf10294b5', 'E_225f90ff78b5fd', 'E_8a368e0eaf8b58', 'E_57ae6d331e8549'}
# point_of_interest: P_2b1633094758d6
# preds: {'E_fccad2fb1a7fbb', 'E_9a950ccff64f10', 'E_2f8a4ee63cbb10', 'E_a923e556fddfae', 'E_c70cbc480e741f', 'E_bdfcaf4ff81822', 'E_3a94a893e0ca2c', 'E_f6befca44ab424', 'E_af53d9ae34c721'}
# targets: {'E_fccad2fb1a7fbb', 'E_9a950ccff64f10', 'E_2f8a4ee63cbb10', 'E_9f035ad28bd670', 'E_a923e556fddfae', 'E_c70cbc480e741f', 'E_f6befca44ab424', 'E_9c7b7bb2dd4ffc', 'E_4fb657429cc8e0', 'E_bdfcaf4ff81822', 'E_3a94a893e0ca2c', 'E_39e3002802b19e', 'E_845acfdb500718', 'E_4e53e941f8ff6e', 'E_8556e2bf98b9bd', 'E_af53d9ae34c721'}
# point_of_interest: P_1da84df140b02d
# preds: {'E_fccb35a9165b6e'}
# targets: {'E_7a671a514147c4', 'E_fccb35a9165b6e'}
# point_of_interest: P_f43596c4f51eb9
# preds: {'E_fccbcb6cd5253e'}
# targets: {'E_2042eda0d7ff72', 'E_fccbcb6cd5253e'}
# point_of_interest: P_a895dc3526328b
# preds: {'E_fccbe3635976e8'}
# targets: {'E_50d8a28d912a3b', 'E_0db4c3735fd042', 'E_63377148bbb6bd', 'E_fccbe3635976e8', 'E_343e2087e7e0a3', 'E_c58e6203779ab1', 'E_60087beed59736', 'E_9dba5fbed73972'}
# point_of_interest: P_15fe28a0f75909
# preds: {'E_a821513a573d09', 'E_23dd4448d8d4da', 'E_938c57e5bfd1a8', 'E_19f2c05d70b101', 'E_581a636175eaa0', 'E_504b40447f99d9', 'E_15fb33fd4d2086', 'E_de8facfb1b5d4a', 'E_3b8731e041fb79', 'E_a80306a5f68c09', 'E_4000239763e58f', 'E_e33e2dea022aed', 'E_d291cfe027f02e', 'E_e7b191e3ebaa2f', 'E_ab8ffa5ac8f054', 'E_7cd2b0bedf6fd7', 'E_fccbeeb457396d', 'E_da3ce8021514df', 'E_9bd4bed139b807'}
# targets: {'E_a821513a573d09', 'E_e4f01ccb26843a', 'E_23dd4448d8d4da', 'E_86f0c5f29e7822', 'E_938c57e5bfd1a8', 'E_19f2c05d70b101', 'E_581a636175eaa0', 'E_3b8a4736e504ad', 'E_32ba68f3babbb9', 'E_504b40447f99d9', 'E_15fb33fd4d2086', 'E_33ad5785b90700', 'E_e5cd5c58ea9097', 'E_de8facfb1b5d4a', 'E_a0114fd78ddb29', 'E_4585176787a86f', 'E_cfec51a2e3fbb1', 'E_3b8731e041fb79', 'E_7f81b2f8ae27dd', 'E_88616d55fbf743', 'E_fc8d70909f570f', 'E_4216513ff2fe47', 'E_346bb35113f18f', 'E_10d295733835b1', 'E_a80306a5f68c09', 'E_a3f080d764e47e', 'E_fa35f80d2eac4d', 'E_15563294fef3af', 'E_4000239763e58f', 'E_e33e2dea022aed', 'E_75fee2c9bb8732', 'E_24074e504de86f', 'E_d07756e14855b9', 'E_ee5ddda43a8aae', 'E_d291cfe027f02e', 'E_285841ea976ce6', 'E_c1616366202461', 'E_ec2c47f7ef1d7c', 'E_e57255c5aa4405', 'E_e7b191e3ebaa2f', 'E_ab8ffa5ac8f054', 'E_7cd2b0bedf6fd7', 'E_af18a6f7d30cba', 'E_da3ce8021514df', 'E_fccbeeb457396d', 'E_8893bce2532d7d', 'E_9bd4bed139b807', 'E_ca1624256c38bd'}
# point_of_interest: P_ff24d5001f44a4
# preds: {'E_fccc62b706def0'}
# targets: {'E_54a7680699a2f5', 'E_7e0b113a60f414', 'E_38f8b64890071c', 'E_fccc62b706def0'}
# point_of_interest: P_7f0d0d5506f996
# preds: {'E_27a47f7da1f1f8', 'E_fccce260e2ce6f'}
# targets: {'E_b68b98a106350c', 'E_cd5bd8e17712e8', 'E_d5c654c7dcad6f', 'E_b0e4ac37f5db61', 'E_17f3f9ee21c8a4', 'E_7c873369e1fd4d', 'E_fd335e6367c2cd', 'E_fccce260e2ce6f', 'E_d00a2b8d52898a', 'E_f8bb8e9d9853c8', 'E_89cfb7e332c994', 'E_095303c0ffcc82', 'E_5cb5e7b6d16e75', 'E_3cad89be2f6e17', 'E_f858f9b665288e', 'E_dbe114981cf6c0', 'E_27a47f7da1f1f8', 'E_437031372df0fa', 'E_f78777e3613122', 'E_fc07609b2e1e9c', 'E_25159b6861aa36', 'E_7a933f1e6d2a5a'}
# point_of_interest: P_a358ceecd08ded
# preds: {'E_fcccef10bc0181'}
# targets: {'E_fba425e21cdf4e', 'E_fcccef10bc0181', 'E_217cdcb6759ccb', 'E_a69403f633fb00', 'E_672442f15f1552'}
# point_of_interest: P_6faeed483e4412
# preds: {'E_e652c38f68a34b', 'E_51718c21887fca', 'E_a9d5548350cdb3', 'E_53283f6da4eac3', 'E_52b535436ebf91', 'E_63f9e41b460d72', 'E_887fe6cb705fec', 'E_53338c98fc5d03', 'E_90527cc61184c0', 'E_8757c9d957f94a', 'E_8431845fd8333d', 'E_e35cfda5db1ce7', 'E_fccd3115e2fc5a', 'E_8a1d411effedf7', 'E_347e1120c38a31', 'E_c7e8bfdda91508', 'E_07fee809a7dd5a', 'E_230950f8a4f5cb', 'E_8eb994a115e2ab', 'E_37a40df3f42787', 'E_9350f8a1ff267c', 'E_9149f4f9fd34d2', 'E_2bf67c508c0af0', 'E_681124b6d7ca38', 'E_5cc24d81284c29', 'E_8316eb72acae32'}
# targets: {'E_e652c38f68a34b', 'E_51718c21887fca', 'E_8fd6c82f03bdc6', 'E_a9d5548350cdb3', 'E_53283f6da4eac3', 'E_52b535436ebf91', 'E_63f9e41b460d72', 'E_887fe6cb705fec', 'E_737e4d47b3d0fe', 'E_53338c98fc5d03', 'E_90527cc61184c0', 'E_8757c9d957f94a', 'E_8431845fd8333d', 'E_e35cfda5db1ce7', 'E_dedf8f1db4140b', 'E_fccd3115e2fc5a', 'E_ea291cb4e93738', 'E_8a1d411effedf7', 'E_347e1120c38a31', 'E_c7e8bfdda91508', 'E_918ac58204004f', 'E_07fee809a7dd5a', 'E_230950f8a4f5cb', 'E_8eb994a115e2ab', 'E_37a40df3f42787', 'E_9350f8a1ff267c', 'E_1d0ec27cbe81b5', 'E_9149f4f9fd34d2', 'E_2bf67c508c0af0', 'E_681124b6d7ca38', 'E_5cc24d81284c29', 'E_8316eb72acae32'}
# point_of_interest: P_cd8f1ebfd54b2a
# preds: {'E_72f3e094122700', 'E_fe5834e0e554ac', 'E_fccd406bb16124', 'E_3d124945757a16'}
# targets: {'E_72f3e094122700', 'E_fccd406bb16124', 'E_fe5834e0e554ac', 'E_87919cc2df99fc', 'E_3d124945757a16'}
# point_of_interest: P_b09422e0ee2b37
# preds: {'E_fccd4e76d9c741'}
# targets: {'E_fccd4e76d9c741', 'E_1b7e3d7a55f992'}
# point_of_interest: P_a0148709d28725
# preds: {'E_fccda1659dc703', 'E_c65400a98d9307', 'E_c9cf7216ff4cce', 'E_25fa1091e61735', 'E_5e816b21afa2e6'}
# targets: {'E_fccda1659dc703', 'E_c65400a98d9307', 'E_c150298dfaa19d', 'E_c9cf7216ff4cce', 'E_25fa1091e61735', 'E_5e816b21afa2e6'}
# point_of_interest: P_3f51afc1166dfc
# preds: {'E_fcce50dced89d7'}
# targets: {'E_bd2e1aba6fb061', 'E_fcce50dced89d7'}
# point_of_interest: P_6013d5005d5216
# preds: {'E_ad09e534beffb7', 'E_fcceb0516973b0'}
# targets: {'E_ad09e534beffb7', 'E_b5dd53a70a90d8', 'E_fcceb0516973b0'}
# point_of_interest: P_fb8d5c8bb220b9
# preds: {'E_fcceda55847916'}
# targets: {'E_fcceda55847916', 'E_09a18e943232aa'}
# point_of_interest: P_f9bfa216b8a153
# preds: {'E_fccee6f7436a2c', 'E_0862931e19655d', 'E_35a6b20a6dd9c3', 'E_1816d3e375f79c'}
# targets: {'E_370a3ff30933c6', 'E_fccee6f7436a2c', 'E_69719a54953328', 'E_aecc57299cf47f', 'E_35a6b20a6dd9c3', 'E_0862931e19655d', 'E_066a767b2323e6', 'E_8a8624cc9a9163', 'E_1816d3e375f79c', 'E_871bbf76ed143c'}
# point_of_interest: P_e5759f0c2e8864
# preds: {'E_fccef5c8b9ddcd'}
# targets: {'E_e026471a2cdee6', 'E_d57ae62f7ed3a5', 'E_d23507488d5393', 'E_065caeef66ca7f', 'E_3689b1c40999d0', 'E_540269e963b449', 'E_c5e0783c6f9630', 'E_fccef5c8b9ddcd', 'E_9c4bde25dd3b08', 'E_550b95cf4db111', 'E_06aea418983a17', 'E_50a5619cebf61f'}
# point_of_interest: P_c308a04e9cd188
# preds: {'E_fccf0c4a658305'}
# targets: {'E_fccf0c4a658305', 'E_bcfe4038657761'}
# point_of_interest: P_b86ba447d66e85
# preds: {'E_fccf3a51dbc4e5'}
# targets: {'E_fccf3a51dbc4e5', 'E_2c74d7a9d38267'}
# point_of_interest: P_b581fccc823adf
# preds: {'E_fcd01d6789c0fd'}
# targets: {'E_66761fda87d8f8', 'E_fcd01d6789c0fd'}
# point_of_interest: P_b3f2c8730b5590
# preds: {'E_fcd022163f5845'}
# targets: {'E_0129ec0e7eb2eb', 'E_fcd022163f5845'}
# point_of_interest: P_9efc25483b66d2
# preds: {'E_fcd037159a86cc'}
# targets: {'E_5313e5c9675214', 'E_fcd037159a86cc'}
# point_of_interest: P_e14a6265ace0ad
# preds: {'E_0ba54a4628119f', 'E_fcd065abefe0ae', 'E_cd6ea64aeed280'}
# targets: {'E_4970889a6e67e5', 'E_abcf0173b98cfa', 'E_8116dafbe5cec1', 'E_bebce8029163fd', 'E_df43f8168034a1', 'E_b0e182d2ef15c2', 'E_03f38fb9b31561', 'E_1529e33e52bbfd', 'E_44ee4ee86665c4', 'E_7166ce8a3931ef', 'E_e4687e302b4805', 'E_f2f015b1b53655', 'E_67712be9adae60', 'E_1628aa9b58a715', 'E_53bd2cbef5fc29', 'E_1526e879abaec9', 'E_8c7f27a2588d6f', 'E_ac0d3acf76ef19', 'E_6bd87221ecefe3', 'E_c1a431db57acfe', 'E_dee23a071ea3f7', 'E_0214fc9e563e98', 'E_1f37cff2611301', 'E_562f4cb8a4f845', 'E_0ba54a4628119f', 'E_cfb199b0e7f23d', 'E_1302e4caa47454', 'E_a463fd137db5b3', 'E_6b61a9596f36fd', 'E_a91da46e752e4c', 'E_fcd065abefe0ae', 'E_729fb9704295c4', 'E_d8d9d3b889b988', 'E_cd6ea64aeed280', 'E_ea61666bb7dd50', 'E_d486d924f336f1', 'E_0c9607a746734a', 'E_88fc588df069a7', 'E_4004f5678c7659', 'E_b778165bf447c3', 'E_7017d8d4448871', 'E_dd1efca476179b', 'E_8cb74dd0f849b4', 'E_5f79b2f1e91b86', 'E_7cf07fb3b23ea4'}
# point_of_interest: P_9a1384e16f3e4f
# preds: {'E_9e761f5cc7e38e', 'E_fcd0bdf304d7db', 'E_479e03d9326cf3'}
# targets: {'E_22e11b37138d2f', 'E_fcd0bdf304d7db', 'E_a2e640cc4aea28', 'E_479e03d9326cf3', 'E_9e761f5cc7e38e'}
# point_of_interest: P_53296480afa950
# preds: {'E_5516f9b9f7790b', 'E_92c74ab7c05427', 'E_fcd0ee7543746e'}
# targets: {'E_92c74ab7c05427', 'E_fcd0ee7543746e', 'E_2a87ea09a34d41', 'E_116bb378ac2f11', 'E_5516f9b9f7790b'}
# point_of_interest: P_ac63db5aee500e
# preds: {'E_fcd147b818730b', 'E_1317659960ff54', 'E_26e6b5ee76418a', 'E_516bf3737c1b7e'}
# targets: {'E_fcd147b818730b', 'E_516bf3737c1b7e', 'E_fbb67376a2f74d', 'E_1317659960ff54', 'E_26e6b5ee76418a'}
# point_of_interest: P_a96b81fbe8bfd0
# preds: {'E_fcd155ce1bf201'}
# targets: {'E_13d3113021293d', 'E_fcd155ce1bf201'}
# point_of_interest: P_2f737426bf861f
# preds: {'E_fcd1df6e9d3611'}
# targets: {'E_1ac8c834eb6e7c', 'E_3fe9cc909dac86', 'E_f8681b98541c52', 'E_7a616daa47e92b', 'E_e3445a39d3b87c', 'E_4400f8dd22b9bf', 'E_4dbaafd6a4ba54', 'E_d26d1bd02db5c1', 'E_fcd1df6e9d3611', 'E_0847847228e6da', 'E_7c8dd2983b7055', 'E_553a4d008f0fe9', 'E_2b19155a937b5b', 'E_ed84f9a3e1a3ef', 'E_a1937d1c010fc9', 'E_0a1ca91fb411b2', 'E_7fa0530d355c93', 'E_6a98c568aec382', 'E_95d3f005074fc8', 'E_0abd0b3f5f7fbb', 'E_d6d54108986138', 'E_ae3eb1cf4e056e', 'E_b0a7d99b908a04', 'E_e6ad2cf49a0f1c', 'E_049ca044abf002', 'E_566ff1c1142b63', 'E_7860c735e0843f', 'E_cd661fce3ef904', 'E_e5c73855659860', 'E_45a5dd191da716', 'E_bf4f696e4e4c9f', 'E_0e2aacd91f1c37', 'E_c804c1738013e0', 'E_8e984dc758affb', 'E_67f5f6de3a2efc', 'E_76f611de884255', 'E_60a54a8ea685f2'}
# point_of_interest: P_a3fddc2f0a77e7
# preds: {'E_fcd254971eb22e'}
# targets: {'E_7565e5d9f634e5', 'E_fcd254971eb22e'}
# point_of_interest: P_f47da9552c27a9
# preds: {'E_fcd2f243d813ce'}
# targets: {'E_7aa9ad34d2c0d0', 'E_fcd2f243d813ce'}
# point_of_interest: P_46af9a41d33d6c
# preds: {'E_8edcb98c1674f1', 'E_fcd39aeb744077'}
# targets: {'E_8edcb98c1674f1', 'E_f816e07f244bc9', 'E_fcd39aeb744077'}
# point_of_interest: P_bc5a827b040abf
# preds: {'E_b0939f637f865a', 'E_fcd3a20ec9a022', 'E_2223b288bb3a86'}
# targets: {'E_b0939f637f865a', 'E_2223b288bb3a86', 'E_fcd3a20ec9a022', 'E_aa14fa6c3ec3a1'}
# point_of_interest: P_46929e75e6601c
# preds: {'E_fcd3c65c3dc60a', 'E_24db69f0cf3648', 'E_57eea3eaee76b4', 'E_23b03d6b40ab17'}
# targets: {'E_fcd3c65c3dc60a', 'E_51624c542c5cf8', 'E_57eea3eaee76b4', 'E_23b03d6b40ab17', 'E_24db69f0cf3648'}
# point_of_interest: P_14487b5330e566
# preds: {'E_fcd4281288cf75'}
# targets: {'E_e3bdf82e29e3a1', 'E_fcd4281288cf75'}
# point_of_interest: P_46c24ed5254ef3
# preds: {'E_fcd476fe24ecf2'}
# targets: {'E_fcd476fe24ecf2', 'E_cd100cade604b7', 'E_fcb7409928d86d'}
# point_of_interest: P_f68379dd165e46
# preds: {'E_fcd47fe89cec14'}
# targets: {'E_c6dd878b458edd', 'E_fcd47fe89cec14'}
# point_of_interest: P_7dde98b326e807
# preds: {'E_bb6993b23ef6bf', 'E_b51ed5f636dee8', 'E_6047d018b910b7', 'E_fcd6a391a7e9dc', 'E_837662ae3d6663'}
# targets: {'E_50c44a9ef4a4ef', 'E_bb6993b23ef6bf', 'E_b51ed5f636dee8', 'E_5041732d7c0443', 'E_6047d018b910b7', 'E_fcd6a391a7e9dc', 'E_db044454e37a51', 'E_92f84d3e7b19d6', 'E_837662ae3d6663'}
# point_of_interest: P_0f48b6a18f9d15
# preds: {'E_fcd7583a850556'}
# targets: {'E_a15c8877d0a05c', 'E_031f885c2e80e2', 'E_6f645b36bea8af', 'E_fcd7583a850556', 'E_e6396292f3e647', 'E_0608e083719497', 'E_89571fc9420db5', 'E_3abdef26a3ab0e', 'E_19332fd7f01d9e', 'E_a11a9c834a8f1c', 'E_1a335675b2c03f', 'E_99f57fc7de2c28'}
# point_of_interest: P_554e94ddafb268
# preds: {'E_2f718c08f0a78f', 'E_fcd7c4eb6142f9', 'E_ea1a7faf95c7e0'}
# targets: {'E_97fbf2680c16d1', 'E_2f718c08f0a78f', 'E_ea1a7faf95c7e0', 'E_fcd7c4eb6142f9'}
# point_of_interest: P_b1ef667f422efb
# preds: {'E_fcd84801c55ae8', 'E_fe81be811d0c55'}
# targets: {'E_9e759f83f3339f', 'E_fcd84801c55ae8', 'E_fe81be811d0c55'}
# point_of_interest: P_eeac785dcf2d03
# preds: {'E_bb8161eca54c89', 'E_b4cd560d5dc77b', 'E_1e2d2cc91b9e05', 'E_43ca105d985c9b', 'E_41773cbd44dcc2', 'E_fcd86c0e39f5b5'}
# targets: {'E_21daffc8d9a27a', 'E_2647ea4c94e206', 'E_fcd86c0e39f5b5', 'E_bb8161eca54c89', 'E_1e2d2cc91b9e05', 'E_43ca105d985c9b', 'E_41773cbd44dcc2', 'E_b4cd560d5dc77b'}
# point_of_interest: P_5c5276c2da3548
# preds: {'E_fcd9325c277e58'}
# targets: {'E_0217809dcb15c0', 'E_fcd9325c277e58'}
# point_of_interest: P_83b847103c9e88
# preds: {'E_586ee948e1b11b', 'E_2bb2c752a040b5', 'E_26f35f8275f3bc', 'E_b1425cc3466d4a', 'E_7b9009baa2e642', 'E_fcd9aed6011c7f', 'E_10938d5258c2c2', 'E_7b7ef56436a4b0', 'E_70a8821793f23e', 'E_001b7fcfd8ecc1', 'E_45c0a6abf36465'}
# targets: {'E_586ee948e1b11b', 'E_2bb2c752a040b5', 'E_692f58f0cad6ce', 'E_26f35f8275f3bc', 'E_5fc9be7a8cea1c', 'E_b2de242a415dc5', 'E_0b8e79d52c633f', 'E_b1425cc3466d4a', 'E_40640fa00d3708', 'E_7b9009baa2e642', 'E_10938d5258c2c2', 'E_fcd9aed6011c7f', 'E_7b7ef56436a4b0', 'E_70a8821793f23e', 'E_001b7fcfd8ecc1', 'E_45c0a6abf36465'}
# point_of_interest: P_fbffd4beaf833d
# preds: {'E_9856ba0b498916', 'E_fcdbb712fb6da7', 'E_ecfcc61dbb9b49'}
# targets: {'E_9856ba0b498916', 'E_fcdbb712fb6da7', 'E_7ba3efe287e53f', 'E_ecfcc61dbb9b49'}
# point_of_interest: P_58c949a345fa15
# preds: {'E_fcdbe32ed7921d'}
# targets: {'E_6207c27a47fbc5', 'E_964618be9d9fea', 'E_e1c6fa9aac5338', 'E_e2a1301657397d', 'E_41b61bd52219e8', 'E_ac748d366e5265', 'E_298a25022f2120', 'E_c52f6e4267cb53', 'E_e538bb559e4c13', 'E_adce9a0eed290f', 'E_bff5ccfdaa1e56', 'E_50faa571a8695a', 'E_bde5077ee1aefe', 'E_45fa4fab4b91d5', 'E_e216922a902467', 'E_8462592c50b1a9', 'E_91b4cfe2e103f5', 'E_46d96a83caf8ce', 'E_c0bedfcab0c11b', 'E_f7f986fd374681', 'E_35ceb11453b4a4', 'E_29017510b340ec', 'E_fe8a359e7d66eb', 'E_7698e745d1ac51', 'E_58fe43f3fc16a7', 'E_6a7847a3f0d2d0', 'E_fa21736579541b', 'E_fcdbe32ed7921d', 'E_90296a1edf8229', 'E_40e0786a1924ef', 'E_47ac64535aa32e', 'E_5ae7bd3d0ba18f', 'E_b000cf6f252471', 'E_4e06167b71ad77', 'E_66891d9daa39dc', 'E_0551ed385d1132'}
# point_of_interest: P_1b9460f59e0c56
# preds: {'E_fcdc4a3dc51a1e'}
# targets: {'E_6d282f64e16fd9', 'E_fcdc4a3dc51a1e'}
# point_of_interest: P_f7c35548211257
# preds: {'E_fcdceae351b196'}
# targets: {'E_8cdc4c163c2f46', 'E_7117e682395c62', 'E_83709687788146', 'E_0a4bea152beeac', 'E_fcdceae351b196', 'E_fc5734507dca64'}
# point_of_interest: P_b2b76e18bbcce0
# preds: {'E_fcdd09dbcb8990'}
# targets: {'E_ee6445c238d6f6', 'E_68f4a18cd29b0b', 'E_a6e54daa8012c3', 'E_e6671d37decf29', 'E_649ef3ab731996', 'E_2984717a0fbdb8', 'E_978013f69d7596', 'E_46ba86c843cdb0', 'E_3f459cad2fa5df', 'E_32da1a3f50da95', 'E_765c02705bd045', 'E_db0a2a50312063', 'E_1e214751b72785', 'E_566d96d156f432', 'E_1bbf368c9ba1e7', 'E_e6c87c8676f87a', 'E_c28c3425995c46', 'E_6c6e4b8ea2ca80', 'E_2891784859a066', 'E_db8c72dca5d7c2', 'E_26d773a12563c4', 'E_f2e6b36ee91c2a', 'E_163dac50d11ba6', 'E_8f31f6e2f2c81b', 'E_cff00c297ba03f', 'E_fcdd09dbcb8990', 'E_adeed208b40848'}
# point_of_interest: P_36354d2fd7fc2a
# preds: {'E_fcdd9b70490341'}
# targets: {'E_c143412fea455f', 'E_8b962c2478c605', 'E_4f103b03dfdf18', 'E_3e18b62756a816', 'E_38a289f49adc6a', 'E_63b798c32021ca', 'E_fcdd9b70490341', 'E_ce9f80a5ac8fec'}
# point_of_interest: P_87e811e68477de
# preds: {'E_fcddc3892aaee3'}
# targets: {'E_fcddc3892aaee3', 'E_723dc3aaad482d'}
# point_of_interest: P_1f05b64a71fd4c
# preds: {'E_98a54e387a8d50', 'E_fcddc5d462ef18'}
# targets: {'E_fcddc5d462ef18', 'E_d93a44f01d016e', 'E_30a18f8e1c96ae', 'E_28c0dfc287c209', 'E_98a54e387a8d50'}
# point_of_interest: P_68d4d88817e90c
# preds: {'E_42c61cf5297867', 'E_fcddcb5d5d8f95'}
# targets: {'E_42c61cf5297867', 'E_fcddcb5d5d8f95', 'E_c52be6db8b77d5'}
# point_of_interest: P_629707e2af2d07
# preds: {'E_fcde4947146a7e'}
# targets: {'E_1606011e6bf642', 'E_fcde4947146a7e'}
# point_of_interest: P_0a978e13c77157
# preds: {'E_fcdebfe72f7bd8'}
# targets: {'E_fcdebfe72f7bd8', 'E_f2995a648ac4d0'}
# point_of_interest: P_0109312b117ed9
# preds: {'E_fcdec86a97a2a4'}
# targets: {'E_ae38341e438628', 'E_fcdec86a97a2a4'}
# point_of_interest: P_94ba88b670bedc
# preds: {'E_fcdf73087edf5f'}
# targets: {'E_616535607ef152', 'E_fcdf73087edf5f'}
# point_of_interest: P_f670851f2774e2
# preds: {'E_fcdfb06f8393a1'}
# targets: {'E_fcdfb06f8393a1', 'E_91fdbf0428f6f8'}
# point_of_interest: P_06c489285a776d
# preds: {'E_fce08167496755'}
# targets: {'E_8b41de7553b6f0', 'E_fce08167496755'}
# point_of_interest: P_72ec14febf7435
# preds: {'E_b01c2856795a41', 'E_b5340bbd77e221', 'E_fce0d0dff409dc'}
# targets: {'E_bebf73a0a64a67', 'E_b5340bbd77e221', 'E_b01c2856795a41', 'E_876ae0b7d7d53e', 'E_fce0d0dff409dc'}
# point_of_interest: P_d99f4284545161
# preds: {'E_fce27109bdf3c7'}
# targets: {'E_bc88c121b1055a', 'E_fce27109bdf3c7'}
# point_of_interest: P_5658fbb41300b2
# preds: {'E_fce292deebf378'}
# targets: {'E_fce292deebf378', 'E_d5134cbbf89f28'}
# point_of_interest: P_d78831131e60c6
# preds: {'E_fce39708b27aca'}
# targets: {'E_fce39708b27aca', 'E_b5d00c40153285'}
# point_of_interest: P_08147a05c4b1b9
# preds: {'E_b8ef702cde956d', 'E_fce5c7825da483'}
# targets: {'E_7a0c6196c0d879', 'E_b8ef702cde956d', 'E_fce5c7825da483'}
# point_of_interest: P_6303daf1676603
# preds: {'E_fce6a71c6ce1fb'}
# targets: {'E_6c32050305212e', 'E_322ae5126ec20d', 'E_2ca2a52051c697', 'E_aeb2ec5ed1a733', 'E_101a01a340ddab', 'E_dd38fabfd8cc28', 'E_61105ca2a4a115', 'E_b5d5004c69f873', 'E_c2d723f8960b4d', 'E_989bd1ac6b7026', 'E_667df05d2b441a', 'E_8467539ec05cfd', 'E_fe704af74b2ef1', 'E_4344074725cc37', 'E_640949951e4c6e', 'E_7aeb0cab185ea5', 'E_45b4d6f2af7e78', 'E_fce6a71c6ce1fb', 'E_479dabf38b6ea6', 'E_8617a41f7c7a9e', 'E_897afb52a603ac'}
# point_of_interest: P_b0620d68a78f5a
# preds: {'E_fce6bf9b57e86f'}
# targets: {'E_9cd3ba453e65a4', 'E_fce6bf9b57e86f'}
# point_of_interest: P_0e4386901d02f3
# preds: {'E_fce6fef2c98815'}
# targets: {'E_8849e248a99fba', 'E_fce6fef2c98815', 'E_8631e6531d1f8e'}
# point_of_interest: P_ae8e94181e3ec5
# preds: {'E_fce81dfea741a2'}
# targets: {'E_bfd27276be63b4', 'E_fce81dfea741a2'}
# point_of_interest: P_94f92134d14195
# preds: {'E_e33dd11a1351b2', 'E_f33900addc4734', 'E_9c5aeeedee1aba', 'E_79fdd25823bbe7', 'E_f74e55f7520e43', 'E_88b974117db59c', 'E_a097dbc6c75013', 'E_f7f9cd64668f38', 'E_1939de5a70f731', 'E_6b4202fe7a3cbf', 'E_fce8b8178f97ba'}
# targets: {'E_e85bf1c0daec7e', 'E_edc6e11607c209', 'E_f33900addc4734', 'E_9c5aeeedee1aba', 'E_bf998a15067c5a', 'E_17b82fa25bcca4', 'E_d4527279e57f81', 'E_1188c8ae8ab009', 'E_24209ea89a5737', 'E_f95cfc4ba00400', 'E_88b974117db59c', 'E_23cdac41a952a1', 'E_1d4efea8f88caa', 'E_7891fd57304b05', 'E_9bb6ff8a6bafee', 'E_ac8e43ad3f0c1f', 'E_e33dd11a1351b2', 'E_79fdd25823bbe7', 'E_e1dcf62203437e', 'E_d108ded22cc286', 'E_c8e037b22886a8', 'E_0e671a0192e508', 'E_f7f9cd64668f38', 'E_b7be9db10883dd', 'E_b2b40f087bb618', 'E_5589a1ce3555f4', 'E_1939de5a70f731', 'E_0269337d645c98', 'E_5bb6f34b45fdc2', 'E_8f0a66ae7c67fe', 'E_86a6acb3fa2b96', 'E_fc45c0a4974ee1', 'E_8d94f480fa38cb', 'E_0705c635699cb0', 'E_ab8e128fde770a', 'E_4576c71cbf6089', 'E_44d14cf4936df1', 'E_6ee62ddc88ea69', 'E_d0cc43dae6bc7f', 'E_a097dbc6c75013', 'E_7a66e40473284c', 'E_de736990e3fea7', 'E_137431ee415dc1', 'E_fce8b8178f97ba', 'E_407d90e2c466a8', 'E_8ac886aa49c4f9', 'E_d509a2e16f267f', 'E_f74e55f7520e43', 'E_080f9f37bd6cfe', 'E_5020581b17cf60', 'E_04ff79c3b1352e', 'E_6b4202fe7a3cbf'}
# point_of_interest: P_ea5a068b35685f
# preds: {'E_fce8e43452ccf9'}
# targets: {'E_69299de87eedb7', 'E_fce8e43452ccf9', 'E_a961b231b9f6e4'}
# point_of_interest: P_184baa08494671
# preds: {'E_eb4c02ae7b0a6c', 'E_b8f79a4634eacf', 'E_fc1a9d549652a9', 'E_3da8d76b7b7d39', 'E_8c6cc18804ce2b', 'E_a52633d3e8480a', 'E_308c9c7ff9e6d5', 'E_0f580bd38141a2', 'E_4e617462c8b7e1', 'E_301b6af66a540a', 'E_2c081798b6e79d', 'E_23f587800c6079', 'E_e4b5204098b4c5', 'E_0eca06ebaea979', 'E_6d1bc39e6729f2', 'E_60e54efd71aeb6', 'E_99487ff4b543e5', 'E_dde76805c3a4a8', 'E_9e11d3c59f88f5', 'E_034dbffe9091b8', 'E_d9ea193e01065c', 'E_5b52e0b9cb8b66', 'E_af0e1651406a81', 'E_124e712813151b', 'E_fa228efc196671', 'E_e4d0d928bbba2e', 'E_efda26936720b9', 'E_54f16f670314ab', 'E_decd15588c8db8', 'E_b5c475b33652e9', 'E_3a49b30ddce8fe', 'E_7bcb5170689541', 'E_4cc580a265f492', 'E_27cd8d0ddeba8f', 'E_cd918e8049b6c4', 'E_61a627aa0ec991', 'E_ed27bd39ce2892', 'E_ab7a639fa2b033', 'E_a35bd490252ff3', 'E_ff57e025e203b9', 'E_58a57463c876ac', 'E_ac23f01e8e72b9', 'E_fce922efdeeaa4', 'E_1454adce4b27ac', 'E_8eb5c42bcc257e', 'E_929e2729df172f', 'E_c2ae00f219f895', 'E_10ba158d14199a', 'E_1f92d47ba7a1cc', 'E_48f66062f2f9b8'}
# targets: {'E_eb4c02ae7b0a6c', 'E_b8f79a4634eacf', 'E_fc1a9d549652a9', 'E_3da8d76b7b7d39', 'E_8c6cc18804ce2b', 'E_a52633d3e8480a', 'E_c6a9207754e4fc', 'E_308c9c7ff9e6d5', 'E_c3f42a48b76319', 'E_0f580bd38141a2', 'E_4e617462c8b7e1', 'E_301b6af66a540a', 'E_2c081798b6e79d', 'E_eb5fe7824ed7d3', 'E_23f587800c6079', 'E_e4b5204098b4c5', 'E_929e2729df172f', 'E_05b9c9fc1cd4a1', 'E_b39702efbcc007', 'E_0eca06ebaea979', 'E_60e54efd71aeb6', 'E_6d1bc39e6729f2', 'E_99487ff4b543e5', 'E_dde76805c3a4a8', 'E_9e11d3c59f88f5', 'E_034dbffe9091b8', 'E_5b52e0b9cb8b66', 'E_d9ea193e01065c', 'E_124e712813151b', 'E_8b22c133e8916d', 'E_af0e1651406a81', 'E_f74402b061b6fd', 'E_a773cd61fdda3f', 'E_e4d0d928bbba2e', 'E_fa228efc196671', 'E_9db749574c8b47', 'E_916a8a7b4e8e35', 'E_efda26936720b9', 'E_54f16f670314ab', 'E_decd15588c8db8', 'E_3a49b30ddce8fe', 'E_b5c475b33652e9', 'E_83c4b56d8b81c5', 'E_e120a7ce86dc1f', 'E_7bcb5170689541', 'E_73e5cc25c072dc', 'E_4cc580a265f492', 'E_7f48278215b26a', 'E_2f72db27d2da2a', 'E_27cd8d0ddeba8f', 'E_cd918e8049b6c4', 'E_61a627aa0ec991', 'E_cbdbc1ad3299a0', 'E_80995985c04084', 'E_ab7a639fa2b033', 'E_e5ce328a176764', 'E_ed27bd39ce2892', 'E_9f8f78cb56db5c', 'E_a35bd490252ff3', 'E_29816e4c5dae58', 'E_58a57463c876ac', 'E_b914ebf8adb3e1', 'E_ff57e025e203b9', 'E_ac23f01e8e72b9', 'E_fce922efdeeaa4', 'E_1454adce4b27ac', 'E_821648d8055764', 'E_8eb5c42bcc257e', 'E_5699a2ccfe94f7', 'E_c2ae00f219f895', 'E_10ba158d14199a', 'E_1e52bae5636b8a', 'E_1f92d47ba7a1cc', 'E_48f66062f2f9b8'}
# point_of_interest: P_162d8569d0fe9b
# preds: {'E_fce942e23e82c2'}
# targets: {'E_fce942e23e82c2', 'E_e5918ce0aeb854'}
# point_of_interest: P_a20dc8c435009e
# preds: {'E_fcea9d93a9eab5'}
# targets: {'E_fcea9d93a9eab5', 'E_02e2921f02dd17'}
# point_of_interest: P_a89434bc656ae2
# preds: {'E_fcead7623d5b59'}
# targets: {'E_fcead7623d5b59', 'E_b72e5e2531b431', 'E_6274055ed61fe0'}
# point_of_interest: P_4bf360520bfce1
# preds: {'E_fcec22ae6168f2', 'E_a8ee5be976ac0f', 'E_c171d51d0366b6'}
# targets: {'E_fcec22ae6168f2', 'E_a8ee5be976ac0f', 'E_2b67af982aed5d', 'E_c171d51d0366b6'}
# point_of_interest: P_d1083647816628
# preds: {'E_fcecb6cdcdebc6', 'E_fd7aa97d4e7025'}
# targets: {'E_82f3cb078ec7b6', 'E_fcecb6cdcdebc6', 'E_fd7aa97d4e7025'}
# point_of_interest: P_63f8172f402f5b
# preds: {'E_11fe5ece1ca596', 'E_fcecd39628f8cf'}
# targets: {'E_11fe5ece1ca596', 'E_e5bd417cf9bdd8', 'E_fcecd39628f8cf'}
# point_of_interest: P_95a11e5ace0139
# preds: {'E_fcecdbcd787e09'}
# targets: {'E_57b27bbc9263f8', 'E_fcecdbcd787e09'}
# point_of_interest: P_5e41f6e8d3a3dd
# preds: {'E_fcee9b645ad3c9'}
# targets: {'E_8876dbb710e8a0', 'E_fcee9b645ad3c9'}
# point_of_interest: P_a606de1a77fbab
# preds: {'E_fceea2d51e78c5'}
# targets: {'E_7ef6705e4f0667', 'E_fceea2d51e78c5'}
# point_of_interest: P_280a20a2137294
# preds: {'E_a566171c70f765', 'E_fcef275a58be88'}
# targets: {'E_a566171c70f765', 'E_e10705937a433a', 'E_fcef275a58be88'}
# point_of_interest: P_755d53b43a4eba
# preds: {'E_fcef8bd8e8bc06'}
# targets: {'E_d10d20432993d8', 'E_fcef8bd8e8bc06'}
# point_of_interest: P_695845bb6912d1
# preds: {'E_fcefef3d7891df'}
# targets: {'E_e90b061c03c61d', 'E_fcefef3d7891df'}
# point_of_interest: P_a959bb476c5544
# preds: {'E_fcf1d2d64d7b50'}
# targets: {'E_fcf1d2d64d7b50', 'E_d58368805a5595', 'E_5bd4643f6982eb'}
# point_of_interest: P_9cc3b65c71212d
# preds: {'E_c3535c688247e4', 'E_fcf1e3b0970210', 'E_1a5635647f08d8', 'E_aa01e39b8365ff', 'E_12cc1f8dd54d2a'}
# targets: {'E_e60c6ca4e33729', 'E_c3535c688247e4', 'E_fcf1e3b0970210', 'E_640003a6b60be4', 'E_1a5635647f08d8', 'E_aa01e39b8365ff', 'E_12cc1f8dd54d2a'}
# point_of_interest: P_c7df5a99fbba9c
# preds: {'E_fcf248053480ae'}
# targets: {'E_5800be7b32412b', 'E_fcf248053480ae'}
# point_of_interest: P_07e0c6a721f368
# preds: {'E_c070c680a66ce2', 'E_8b726f18e2247f', 'E_fcf29919ced255'}
# targets: {'E_c070c680a66ce2', 'E_8b726f18e2247f', 'E_fcf29919ced255', 'E_905bd6522d1ad8'}
# point_of_interest: P_fbb03e2208e6e3
# preds: {'E_bcbf5bbc9d0a3c', 'E_ac716662b1335f', 'E_62615ca829ccfd', 'E_8a760e34685930', 'E_fcf2aeef4f599e', 'E_93e4ccb919ce6a', 'E_7a7b7cbc85c58c', 'E_50d39f7778cca3'}
# targets: {'E_9cafb9969671ca', 'E_bcbf5bbc9d0a3c', 'E_d7d86cc227fd45', 'E_bbc703b27836d3', 'E_ac716662b1335f', 'E_3a7ba868068757', 'E_1c69afd8299e2d', 'E_62615ca829ccfd', 'E_8a760e34685930', 'E_fcf2aeef4f599e', 'E_93e4ccb919ce6a', 'E_fac32c6270b179', 'E_7a7b7cbc85c58c', 'E_50d39f7778cca3'}
# point_of_interest: P_1d5530c72bceaa
# preds: {'E_fcf36e189fa5bd', 'E_011a9c54e5859a', 'E_90f1cdd89c92df'}
# targets: {'E_e55c02f7348f90', 'E_011a9c54e5859a', 'E_90f1cdd89c92df', 'E_4092b6086e9aca', 'E_0666ed40425446', 'E_94578390c27147', 'E_fcf36e189fa5bd', 'E_f0fba846105be7', 'E_18ed049b0ac507'}
# point_of_interest: P_edb2c59400c518
# preds: {'E_fcf3ab7d2b3eb7', 'E_535debebc5170f', 'E_36a0f25986dbfa'}
# targets: {'E_830a8ec11df7f4', 'E_535debebc5170f', 'E_36a0f25986dbfa', 'E_fcf3ab7d2b3eb7'}
# point_of_interest: P_b48c604488e902
# preds: {'E_669f765e67b9ff', 'E_4adcd18ffc61b7', 'E_8904c741463ab6', 'E_fcf3ed9ea08878'}
# targets: {'E_df5523db3ee56d', 'E_015d3cb456ecfe', 'E_669f765e67b9ff', 'E_242a5ba83736c0', 'E_8904c741463ab6', 'E_a6547b46fb40e3', 'E_4adcd18ffc61b7', 'E_fcf3ed9ea08878'}
# point_of_interest: P_8e583fc8573b8e
# preds: {'E_11ee3195fe3816', 'E_fcf56e75c3604c', 'E_bcadb5ad7994d7', 'E_72563d9ed0ff50', 'E_bbaf7a431463a6', 'E_86caeaa2c7f32d', 'E_c90290b2e08690', 'E_cb1f551e944d73'}
# targets: {'E_e7aace734c1f86', 'E_530c6a5cf37a97', 'E_c650c867edc14c', 'E_cb1f551e944d73', 'E_11ee3195fe3816', 'E_fcf56e75c3604c', 'E_bcadb5ad7994d7', 'E_0c3b6cfcd08264', 'E_72563d9ed0ff50', 'E_86caeaa2c7f32d', 'E_bbaf7a431463a6', 'E_c90290b2e08690', 'E_5ca2051ead529a', 'E_1e7a11ee9798c9'}
# point_of_interest: P_a923fce843d3dd
# preds: {'E_fcf59fb6f627dd'}
# targets: {'E_47583921be63e2', 'E_fcf59fb6f627dd'}
# point_of_interest: P_baffa24f7b0a04
# preds: {'E_fcf6484ef19d1b'}
# targets: {'E_fcf6484ef19d1b', 'E_1b4e8a02b62626'}
# point_of_interest: P_451c5f62aaa511
# preds: {'E_fcf6b495822252'}
# targets: {'E_fcf6b495822252', 'E_fbf86c98d309e5', 'E_56f760953df7ac', 'E_7fcef0ed77ac55', 'E_23c2fb1a28edca', 'E_feec483254dcd8', 'E_2f24377e73981b', 'E_01442055a49395', 'E_4ddc0b3462f9a4'}
# point_of_interest: P_ada342ad548729
# preds: {'E_fcf7377954e8a9'}
# targets: {'E_fcf7377954e8a9', 'E_6880545541d714', 'E_87eeb62d27c41e'}
# point_of_interest: P_bd561413a8defe
# preds: {'E_6251d670ce09e3', 'E_230c160c11e418', 'E_87389c5255ffb0', 'E_fcf7483e564a73', 'E_97f652ff52bb61', 'E_2374785204bb32'}
# targets: {'E_6251d670ce09e3', 'E_230c160c11e418', 'E_87389c5255ffb0', 'E_fcf7483e564a73', 'E_2374785204bb32', 'E_3786df6b7b92b4', 'E_97f652ff52bb61'}
# point_of_interest: P_1278442e363225
# preds: {'E_7bb97e590bd0d9', 'E_fcf81118431380'}
# targets: {'E_7bb97e590bd0d9', 'E_91c57d11420760', 'E_fcf81118431380'}
# point_of_interest: P_7650f28dda89a5
# preds: {'E_fcf8434821d56e'}
# targets: {'E_fcf8434821d56e', 'E_67106d516aa454'}
# point_of_interest: P_3d57ec52a0043a
# preds: {'E_51d3a0046de7d5', 'E_5cff261ec7096c', 'E_425f08391c8f85', 'E_fcf8fc47f8464d'}
# targets: {'E_aa8c197853dc57', 'E_425f08391c8f85', 'E_fcf8fc47f8464d', 'E_51d3a0046de7d5', 'E_5cff261ec7096c'}
# point_of_interest: P_7ac96c0c817c3b
# preds: {'E_327a38390d9286', 'E_fcf979f2bfe7ce', 'E_57420799faca85', 'E_5f804450015c4b', 'E_f62663f1deec44', 'E_15926f9aa15e32', 'E_bb606e1c6711e8'}
# targets: {'E_327a38390d9286', 'E_fcf979f2bfe7ce', 'E_7acfd3ae72e785', 'E_57420799faca85', 'E_0a2bbe64dcbec6', 'E_1e32b20c466494', 'E_af22dc1ee4a02c', 'E_5f804450015c4b', 'E_f62663f1deec44', 'E_15926f9aa15e32', 'E_bb606e1c6711e8'}
# point_of_interest: P_128733a0ac8c56
# preds: {'E_ed818dc7837df4', 'E_195ee8ee365aab', 'E_76d543acb86279', 'E_5994fcb2ebc3ad', 'E_89385f2ba1662a', 'E_fcf9d47c1764f6', 'E_f06af28f5c26cd', 'E_75266f009943bc'}
# ...
# targets: {'E_ffef033fdd2215', 'E_1955aeefa085c8', 'E_09284c74af94fa'}
# point_of_interest: P_077edfe27f12fa
# preds: {'E_098bbd04488463', 'E_ffef1186631782'}
# targets: {'E_ffef1186631782', 'E_7f7df37ca29f7d', 'E_098bbd04488463'}
# point_of_interest: P_4b739ce9c90689
# preds: {'E_be5188c06e3e66', 'E_7da5adbc889734', 'E_baceed4201029f', 'E_fff0686373f911', 'E_8309c5766613cf', 'E_60a188f00e91b2', 'E_f8e1fd79ce0944'}
# targets: {'E_ffc48172d51f16', 'E_be5188c06e3e66', 'E_7da5adbc889734', 'E_baceed4201029f', 'E_68911ddb2cab12', 'E_f8e1fd79ce0944', 'E_fff0686373f911', 'E_60a188f00e91b2', 'E_bc1f3c57ee0511', 'E_8309c5766613cf'}
# point_of_interest: P_455e8b62ca4f5a
# preds: {'E_84ed7cb3e3782e', 'E_cec171e8565bca', 'E_31dfd99e4cf565', 'E_1f1418c85e5208', 'E_27746db2599e7e', 'E_e1398a003edb62', 'E_be82e3aeb23edb', 'E_2a58a1b968419d', 'E_93e588933cf51d', 'E_8015d24e901473', 'E_c88b079b174d14', 'E_fff07e4897e36e', 'E_164a39648823e8'}
# targets: {'E_f33195a7b1e255', 'E_84ed7cb3e3782e', 'E_cec171e8565bca', 'E_31dfd99e4cf565', 'E_1f1418c85e5208', 'E_e1398a003edb62', 'E_be82e3aeb23edb', 'E_2a58a1b968419d', 'E_93e588933cf51d', 'E_1651debc73c571', 'E_c88b079b174d14', 'E_8015d24e901473', 'E_27746db2599e7e', 'E_fff07e4897e36e', 'E_164a39648823e8'}
# point_of_interest: P_bd887fbc13ac54
# preds: {'E_fff084dced1f09', 'E_9a564349fa6881', 'E_2b80b1eacd3291', 'E_538ebc482cd5d8', 'E_94f3d3df8a9528', 'E_98c81f24be1470', 'E_99e05910762091', 'E_a2ed3a1044c4f5'}
# targets: {'E_fff084dced1f09', 'E_9a564349fa6881', 'E_543ac8c2066f2a', 'E_2b80b1eacd3291', 'E_538ebc482cd5d8', 'E_94f3d3df8a9528', 'E_98c81f24be1470', 'E_a870bb23cb3df3', 'E_af65698ef49dfc', 'E_99e05910762091', 'E_f41eb2d5194c22', 'E_d7b7f6a89dcaaf', 'E_2e5e606031ef06', 'E_a2ed3a1044c4f5'}
# point_of_interest: P_5510cf5bb797e3
# preds: {'E_a514ded7a1697c', 'E_a0bbb87321e9e0', 'E_30c25db9c7f4b3', 'E_6f92823c034a93', 'E_a0e2d5b5172ed3', 'E_fff168ca975c01'}
# targets: {'E_a514ded7a1697c', 'E_a0bbb87321e9e0', 'E_30c25db9c7f4b3', 'E_fff168ca975c01', 'E_6f92823c034a93', 'E_a0e2d5b5172ed3', 'E_e2b367fddf04bf', 'E_43665738c74031'}
# point_of_interest: P_bda21437f64eb6
# preds: {'E_26a34403fce0f5', 'E_6830347bfd7280', 'E_fff1b1dd4d8883', 'E_82fd05ee7efa00', 'E_d5bb45fc42fdde', 'E_a548922b549a81', 'E_f22e0da1d97e0f', 'E_65db18d9f6eb30'}
# targets: {'E_26a34403fce0f5', 'E_0a4a05ef60e434', 'E_6830347bfd7280', 'E_fff1b1dd4d8883', 'E_82fd05ee7efa00', 'E_850a256d3f5d13', 'E_d5bb45fc42fdde', 'E_a548922b549a81', 'E_ec481101ef4297', 'E_3e9eb656adfba1', 'E_f22e0da1d97e0f', 'E_91f1942b9a4144', 'E_65db18d9f6eb30'}
# point_of_interest: P_346b237d61cd5c
# preds: {'E_fff1eac4917e2f'}
# targets: {'E_fff1eac4917e2f', 'E_2740338cb4bac5'}
# point_of_interest: P_c39b5c766497d0
# preds: {'E_fff27edaf455ae'}
# targets: {'E_a21e2fa389cd7a', 'E_fff27edaf455ae'}
# point_of_interest: P_c4291acb6061c9
# preds: {'E_e563a9b2f88065', 'E_36296aaf40eb69', 'E_1ae31b7a544b54', 'E_bb94da5af8de80', 'E_7b0acc9e55515d', 'E_7d43f65f541c80', 'E_da9ebf0b71ae9e', 'E_651155a119dc78', 'E_fff33cdd288e2c', 'E_defb0c87e0e8f1'}
# targets: {'E_e563a9b2f88065', 'E_1ae31b7a544b54', 'E_36296aaf40eb69', 'E_bb94da5af8de80', 'E_7b0acc9e55515d', 'E_7d43f65f541c80', 'E_da9ebf0b71ae9e', 'E_651155a119dc78', 'E_144046d1c111aa', 'E_fff33cdd288e2c', 'E_defb0c87e0e8f1'}
# point_of_interest: P_7f75f291dfcae8
# preds: {'E_fff35a21c59588'}
# targets: {'E_c1c5e6b105e3bc', 'E_fff35a21c59588'}
# point_of_interest: P_41fad6a9473c69
# preds: {'E_fff39c4a604330'}
# targets: {'E_a9ed8bb6ce6106', 'E_fff39c4a604330'}
# point_of_interest: P_7fc384bf991009
# preds: {'E_fff3f40a762e93'}
# targets: {'E_ae81abe3cafdc0', 'E_a395c282422433', 'E_f6c73a9b378bab', 'E_07f58814417602', 'E_81843b6184ccb8', 'E_4e49051cd64729', 'E_c82a952258ca44', 'E_ec84fc96b32fec', 'E_e6afeda2f4894b', 'E_b63e5a6583f3ae', 'E_a6a29ca016c959', 'E_4eb9a9ecfc8cc8', 'E_ce0796a22e7431', 'E_8ef09aac876a6d', 'E_8f19392e1702c5', 'E_9afb7e0f12c543', 'E_b202e17b333d3f', 'E_42250fcb04266c', 'E_74ba66c8496334', 'E_e2b5b47143a5f3', 'E_54455ed849627c', 'E_e80d060c1536bd', 'E_9ff1b72865099e', 'E_8ac726b963c6d5', 'E_a04071b93d451e', 'E_95ab858c88562d', 'E_3cfcdf84257fd2', 'E_0ff39c27b373f2', 'E_1da10bd0569205', 'E_9da4babb2dc98a', 'E_bedb87cd827a8b', 'E_29f793b22a13ff', 'E_351afd081caaca', 'E_6839dd53aa3cc9', 'E_7775dd642dcc30', 'E_5d7f288c0b01d2', 'E_b1fe04bd0698b3', 'E_72834ea099fa85', 'E_824f097568d33d', 'E_38698a5579e504', 'E_c012349ce1d098', 'E_eecbea7afd4a51', 'E_81c1ce4f402780', 'E_502a13fa5aa72b', 'E_28fdd80c9aebab', 'E_73643b4e9192a6', 'E_74189350ea1d40', 'E_3f8cd633b76b05', 'E_745012fb2341d0', 'E_9ac9376f860ae1', 'E_d3c25e43bcec38', 'E_1f45847efea3e5', 'E_d28eecc14882b9', 'E_02761e40f68230', 'E_492682b489c5c5', 'E_be041b6f3871fa', 'E_cdf1c07db03007', 'E_3673b4f50a47d5', 'E_73874b2cdd4d92', 'E_0bbd909382cd75', 'E_d6f70b3c0af2f7', 'E_75dd68f89e611f', 'E_e76f85ed8f35fc', 'E_0351377fc6b71d', 'E_04e0dc77ae3b41', 'E_a212368ad314e5', 'E_3ee3e48fadd4e1', 'E_8b0c48bb236b24', 'E_0bea717f95598d', 'E_7b5993ea269167', 'E_c6c0db2d9485da', 'E_568073f005d825', 'E_c5b233c31b5b11', 'E_b917f0daac3dd4', 'E_d3cc173c5f5313', 'E_35c7b6caec33ec', 'E_f127bc8fcc9a60', 'E_4f6b56e4b7de98', 'E_b582256a286f3b', 'E_0eb7483e7563be', 'E_d4912a13853779', 'E_400ff1d74561fe', 'E_0c1da0c43edac4', 'E_0ec9254b228d91', 'E_fed28e5ada5e81', 'E_cfbdf3a7e88e93', 'E_3e2813d69a8c59', 'E_99cd0807addab6', 'E_759283f776859c', 'E_b2159f7cbd1588', 'E_046132a06d8bc5', 'E_8f611bab43254e', 'E_6b5b65fed6c5c4', 'E_47f5f883c73c64', 'E_95134d7b1f75ba', 'E_1c359ed6eaf0da', 'E_6fd2b312eb7d2f', 'E_d19568e3534ec5', 'E_5ab963c9aa78d6', 'E_2972bc662f0831', 'E_1f26f5da326ac5', 'E_33d057de2d00ac', 'E_a271bf95b35497', 'E_6ed8b3f61a9bd8', 'E_a1e4707531c6eb', 'E_a61e7727e4c47b', 'E_0fc82270e70bf3', 'E_59055483770086', 'E_f68bf00215f313', 'E_d8df25140470d5', 'E_d5e2e151ebff17', 'E_e363c38d88f33c', 'E_b5e0cb0b2b399d', 'E_91c69e0866c171', 'E_dfaf5f0b5ca510', 'E_98f6bdd1163564', 'E_b8e13b4dc1a514', 'E_ee475a84e88c26', 'E_276f4b0ab4f03a', 'E_60d8a84257cf63', 'E_2e29c9c9fa4622', 'E_4d9a4e1a8bcd38', 'E_6745b7ef2d4036', 'E_cdcf89fbc20b3b', 'E_0fa9246c3bebcb', 'E_414f7880fbfcc8', 'E_5365a77191a928', 'E_e295a8635a8854', 'E_1f8472e776298d', 'E_8600580e6998e7', 'E_59d0031512fc4d', 'E_62433d49b17303', 'E_3223456a0e03d3', 'E_c3b0a81f7dcebc', 'E_e43c2dfc8c59cb', 'E_eea2b01b98f3a1', 'E_9f24e2fbcf2bd8', 'E_dabfe88b6f990b', 'E_19929ac288e12c', 'E_7a53ac861de8a2', 'E_112935613c0fe6', 'E_f4f22cfb71102e', 'E_6bedda163506af', 'E_c72cbd53b65012', 'E_8d50dcaeac54c1', 'E_064c0b1349b6bc', 'E_b5cf0be507c58e', 'E_80191e9690ae4d', 'E_6c742b8c70caea', 'E_b24a4a582eb499', 'E_558d583271c64f', 'E_d3c83a7d32211d', 'E_ffa093e04175aa', 'E_0870969c2a1b6a', 'E_a03f46663d15a6', 'E_87c385365c7bfe', 'E_55a5491b9969d9', 'E_f0ad84e1e13837', 'E_da0aa051443a08', 'E_4caffefb38026c', 'E_62f9235b937698', 'E_19c2a0c71f183d', 'E_e8e02a1b28fa7b', 'E_6bc44f0a0372a6', 'E_31ac6f4a443311', 'E_a4ffbfa815b8f0', 'E_80ee19ca1a1d2a', 'E_a418a87cda236e', 'E_ca4e974daebde7', 'E_93831c4c435242', 'E_42a6d6639b3753', 'E_e0ca03194ccffb', 'E_e773e0b06aff87', 'E_62222b0e1c13fa', 'E_836817aec832d6', 'E_c6c908350af685', 'E_229b69a945928d', 'E_8761b59278470e', 'E_20557c53571641', 'E_5c0b1edbffefa1', 'E_acf39c38433c0e', 'E_88a9e9044743bb', 'E_a6668e66df8353', 'E_ffe8c72a51f9c6', 'E_60c178ff435b18', 'E_de86a86735fb6d', 'E_85c1c4a86d07ac', 'E_46293cf1df101f', 'E_9f1082969881d7', 'E_8cb7549de2a7ff', 'E_9f3dfa174729a7', 'E_a72ad6078cfe59', 'E_d78bd15cd226e9', 'E_2de23e68f1a50d', 'E_9def7e6622aff9', 'E_cc0ee3b3c25370', 'E_8d896a44f7e9f5', 'E_b945c90c01a63d', 'E_0ad700c8278a40', 'E_84e97e7 ...
# point_of_interest: P_fb339198a31db3
# preds: {'E_fff406b7128e76', 'E_cd0d4f078ba9a6'}
# targets: {'E_fa99078086e7c8', 'E_fff406b7128e76', 'E_cd0d4f078ba9a6'}
# point_of_interest: P_df0f6b0d356fa5
# preds: {'E_fff610e05c669a'}
# targets: {'E_ecc220d607b8c4', 'E_1ea74a22184a46', 'E_236a8d942ba98d', 'E_e266beee62653f', 'E_fff610e05c669a', 'E_2235fd2b8e3b33', 'E_efeb98b3a2e6a3', 'E_55f8dc7c352fdf', 'E_c2f81a76a332c7', 'E_4bfc30e59e5c1e', 'E_05bcefa943af5c'}
# point_of_interest: P_397aee87a200fe
# preds: {'E_fc74b56d737ae3', 'E_fff66bd98231ac'}
# targets: {'E_25016b93248671', 'E_fff66bd98231ac', 'E_24726948012455', 'E_86b07a1eb702c2', 'E_f2440c8e92b0b2', 'E_0825d0574b6014', 'E_fc74b56d737ae3'}
# point_of_interest: P_81ef009ce81cfb
# preds: {'E_fff737a873bc34', 'E_e5f6039af60d31'}
# targets: {'E_d37cecd8afa280', 'E_fff737a873bc34', 'E_e5f6039af60d31'}
# point_of_interest: P_8a6fad90258408
# preds: {'E_fff7871b89de63', 'E_7bf3410dcdbe1d', 'E_8253bf51d7daa9', 'E_036e02d50e8899'}
# targets: {'E_35b09125341428', 'E_ba2bcf588f2f31', 'E_b0ac23d30e5d29', 'E_4fdb47a714f128', 'E_363e7549520807', 'E_267313446db841', 'E_49d41a451f1357', 'E_0bcb3476e71761', 'E_ad529e21e5cf87', 'E_b4470520f18bfd', 'E_c4c3c7e3abf37a', 'E_c4f534be7597e9', 'E_831aef2dde91a5', 'E_b368a03176b5e9', 'E_3fd2db0d62a021', 'E_ab5e2bdab03a73', 'E_869709fc0feefb', 'E_3c776c4dca047b', 'E_499d70f0ea4673', 'E_7bf3410dcdbe1d', 'E_65895c944e1825', 'E_7042ec353dda3a', 'E_7cb4171bb1b0fe', 'E_b6bcd0abdc59bb', 'E_cf1ff302c49aa6', 'E_8253bf51d7daa9', 'E_e9ff9cf67cdb82', 'E_e9863ee18f0f24', 'E_b08459c6156232', 'E_04eec92d750e17', 'E_8ab60acfb8d5e5', 'E_7d657f045e762f', 'E_3b95404237bfd8', 'E_01cb94c87ecb16', 'E_e28fed36384998', 'E_2ab6204de9f88c', 'E_036e02d50e8899', 'E_94cf05f3655112', 'E_c0943ca8325026', 'E_fff7871b89de63', 'E_d744da9e72f128', 'E_28fbfb3405b2ab', 'E_860a08f5a9fa1d', 'E_cb7a01ce2648c8', 'E_42a8d4f5cd3c5d', 'E_3d780b7f217827', 'E_bf8b0e418fe79d'}
# point_of_interest: P_613812d1d196e5
# preds: {'E_fff79504c2f5a0'}
# targets: {'E_9821e7d25f3259', 'E_fff79504c2f5a0'}
# point_of_interest: P_4d34884ebb3d1e
# preds: {'E_0c4ceb74236407', 'E_fff7e3b47c8884', 'E_fa9cc3e00627b4'}
# targets: {'E_fff7e3b47c8884', 'E_a7147a419efd7a', 'E_fa9cc3e00627b4', 'E_0c4ceb74236407', 'E_9bb3a2c55a2788', 'E_59e3459983ddc4', 'E_207b463915525b'}
# point_of_interest: P_ae7e9ca82eb46b
# preds: {'E_fff7ef9e2bf8b5', 'E_a0b65b50fe2d13', 'E_f010fc2ff286c7', 'E_9780a5641a5e01'}
# targets: {'E_f99ff3be42b85a', 'E_e78f939b1c5997', 'E_329d43a18af3e2', 'E_f240f7b075cb66', 'E_fff7ef9e2bf8b5', 'E_e5e3dbb0aca13a', 'E_867e13e14bd14f', 'E_97c8e51887e1c8', 'E_9780a5641a5e01', 'E_c370450e26f8da', 'E_f6cd8c78e9f571', 'E_e5fa79ead3ca4a', 'E_05492dbf35e9df', 'E_04d37344e3b493', 'E_128e39e59cb703', 'E_07c8f23eeef5ef', 'E_02bb6365f7219d', 'E_33c0e5d8b73e59', 'E_68ffe417725fb0', 'E_9349688d0bbdcc', 'E_e147fafea289b5', 'E_739c156b99ee41', 'E_822eeb37a531a6', 'E_d44a1fed814160', 'E_2e04e39fa6eae6', 'E_a0b65b50fe2d13', 'E_84c725f04d148d', 'E_ca7831a1152340', 'E_44f84684680307', 'E_f010fc2ff286c7', 'E_7d48a5dfb0108a', 'E_125160d22f1d40'}
# point_of_interest: P_65769c7e8a4d68
# preds: {'E_6147ccc1654631', 'E_ac5c79012d0a6e', 'E_fff8dc2f9f231e'}
# targets: {'E_6147ccc1654631', 'E_9966dc85cc9a72', 'E_3444740b764be0', 'E_ac5c79012d0a6e', 'E_fff8dc2f9f231e', 'E_975352f338b43a'}
# point_of_interest: P_88e9f5ceb3ef63
# preds: {'E_fff91a35d8450e'}
# targets: {'E_18e6d22f5814d7', 'E_f34992fee0fea1', 'E_fff91a35d8450e', 'E_545253fae23ac0', 'E_2687d57ff5d8f8', 'E_c1b46643951edb', 'E_379cdc6ac34f61', 'E_6a6af6657da169', 'E_4fba5535dd4663', 'E_8c4d3eae70b0b6'}
# point_of_interest: P_f9d0383fcd3375
# preds: {'E_fff970fefa5030'}
# targets: {'E_fff970fefa5030', 'E_5596f8e6b79a0a', 'E_946af2da40ad33'}
# point_of_interest: P_86211a487b8d36
# preds: {'E_fff9ecf69690da', 'E_5a051b204b6f1f', 'E_393d42bc0cdbce'}
# targets: {'E_fff9ecf69690da', 'E_f9f321bbd92810', 'E_5a051b204b6f1f', 'E_393d42bc0cdbce'}
# point_of_interest: P_0d8cb65f0aabef
# preds: {'E_9d5569bb9c912c', 'E_ccbdaf4bd611ea', 'E_3d702be64bc520', 'E_d27ee7afd3dfcf', 'E_61c368ebed2929', 'E_12d46bdd9a48cd', 'E_7fa50a9b5c716a', 'E_110abe3244b781', 'E_86dc8f86a37524', 'E_7a3605ad09873c', 'E_ad36723ad3919f', 'E_dc58a9627ef81d', 'E_9ca4c40f5c4bfb', 'E_7a5a4643a1793c', 'E_fff9fde4bb588b', 'E_7949f9fccece0d', 'E_4582cbe6311784'}
# targets: {'E_12d46bdd9a48cd', 'E_ad36723ad3919f', 'E_59cfad2bb4c3cf', 'E_7a5a4643a1793c', 'E_ba275df384e4db', 'E_9d5569bb9c912c', 'E_61c368ebed2929', 'E_3d702be64bc520', 'E_0bd232628aed2c', 'E_7fa50a9b5c716a', 'E_110abe3244b781', 'E_86dc8f86a37524', 'E_7a3605ad09873c', 'E_fff9fde4bb588b', 'E_7949f9fccece0d', 'E_4582cbe6311784', 'E_ccbdaf4bd611ea', 'E_a14b58bb276fa1', 'E_d487f94d32e0db', 'E_9ca4c40f5c4bfb', 'E_d27ee7afd3dfcf', 'E_1a1004d18455f1', 'E_7ab09afb1e3417', 'E_dc58a9627ef81d', 'E_85fd3226ebf730'}
# point_of_interest: P_1e8e17b542e178
# preds: {'E_fffa45025c612f'}
# targets: {'E_47134eec37ad3e', 'E_1b0dca65a7d8cb', 'E_fffa45025c612f'}
# point_of_interest: P_cee99f2efdd9ca
# preds: {'E_fffa63a008cbcd'}
# targets: {'E_fffa63a008cbcd', 'E_623477839dbabb'}
# point_of_interest: P_037468d7274565
# preds: {'E_c83769ec3d4042', 'E_fffac30c476d81', 'E_a0156de39267f8', 'E_21fa073ae384f9', 'E_1f3d42adcfe5e5', 'E_1b1219771c2043'}
# targets: {'E_c7e67ae2fa2506', 'E_c83769ec3d4042', 'E_f40e1a9c047527', 'E_37575e96587df4', 'E_fffac30c476d81', 'E_1bce18a92a7d97', 'E_a0156de39267f8', 'E_21fa073ae384f9', 'E_bc1c284402464f', 'E_e1ef13dbe6dace', 'E_ef3fd6555ddfc0', 'E_050e27e0d8730d', 'E_0568da68fa916c', 'E_1f3d42adcfe5e5', 'E_0bf85126c569c7', 'E_31cdd83e28c26d', 'E_1b1219771c2043'}
# point_of_interest: P_4de520740c4ca4
# preds: {'E_fffc623025d9c7'}
# targets: {'E_dacc3109c8f9af', 'E_fffc623025d9c7'}
# point_of_interest: P_a18d59ed8d1b60
# preds: {'E_fffc94cbf08007'}
# targets: {'E_fffc94cbf08007', 'E_c6ae0edb8f697e'}
# point_of_interest: P_ac9cca68dcce06
# preds: {'E_fffde923648247'}
# targets: {'E_fffde923648247', 'E_c05167aac5b3f5'}
# point_of_interest: P_e416fda64302f1
# preds: {'E_e1b2397966e6e7', 'E_fffe6d258fd605'}
# targets: {'E_59b459e448fce1', 'E_e1b2397966e6e7', 'E_fffe6d258fd605'}
# point_of_interest: P_7e9de22212d02c
# preds: {'E_799e6abd807731', 'E_959fea1a5ee646', 'E_fffe9cbe5a2c75', 'E_591d9bc7dbdb0e', 'E_c9ff41f8d5f343'}
# targets: {'E_799e6abd807731', 'E_959fea1a5ee646', 'E_fffe9cbe5a2c75', 'E_591d9bc7dbdb0e', 'E_f54890d9f4cec8', 'E_c9ff41f8d5f343', 'E_64aacc7e5a2801'}
# point_of_interest: P_97e04d9412237c
# preds: {'E_c5e2c92a64ad20', 'E_fffebfdf9be4cc'}
# targets: {'E_380d545ca08021', 'E_c5e2c92a64ad20', 'E_fffebfdf9be4cc'}
# point_of_interest: P_9d295f9b619c61
# preds: {'E_ffff83a9496324'}
# targets: {'E_73c8800d7ca936', 'E_ffff83a9496324', 'E_c7618699344378'}
# point_of_interest: P_a630bf50670209
# preds: {'E_008558a7c44ed5', 'E_ffffb80854f713'}
# targets: {'E_f5d055893ef064', 'E_ffffb80854f713', 'E_008558a7c44ed5', 'E_a05914fd828a1c'}
# point_of_interest: P_7ccbeab96cd82e
# preds: {'E_27bcc6f6dd33ed', 'E_ffffc572b4d35b', 'E_8081185a219dc3'}
# targets: {'E_1ab928c3b6ff8f', 'E_27bcc6f6dd33ed', 'E_42e65609de0b83', 'E_ccce01d35e4bb9', 'E_195a9c71600fd5', 'E_6cdee403ae037a', 'E_3d03c9cc82a5ce', 'E_771a8749f5e13a', 'E_83a78a20004360', 'E_228816bf35c635', 'E_aeb56cd1562100', 'E_3c6ce34400830b', 'E_613b3e931eed56', 'E_9a5e5d5a74c443', 'E_67ce70f92a4648', 'E_5ce7fc40a0736a', 'E_7eff49983c6aae', 'E_140d67717e2d94', 'E_cf11032bd3e80c', 'E_8bb4b3ee0c2545', 'E_68f7241cf74ab6', 'E_6e74746d07af54', 'E_97e209b71d9e2b', 'E_95e47258c151ac', 'E_9dbe99342afc03', 'E_b7a5768590c1cc', 'E_daf7f534cb27fb', 'E_ecb38b2d992261', 'E_e30d2199f33e14', 'E_3d11785a5c17b3', 'E_22173232a724f4', 'E_c3e000daf39030', 'E_ed824ef794fd8d', 'E_773e4716304a03', 'E_8081185a219dc3', 'E_d03b08a4b4c643', 'E_27e9a292b8d5c5', 'E_9b8960c3ca6ce7', 'E_daec4fe0f67a32', 'E_262de0dd9121c8', 'E_dba0f10d7e8ee2', 'E_9789223349d203', 'E_fb46d2ef0aa83c', 'E_2594bb48e53f02', 'E_60671d056a2f42', 'E_ab5647083ae7bc', 'E_a3f5efa32b61e4', 'E_f6784c3ad5cf36', 'E_2c023b9995f3ed', 'E_a690401ef32775', 'E_6291bd32843b71', 'E_e119eafad69c11', 'E_164ddb739d3a0a', 'E_04074a25e0158f', 'E_82dba89a0b1625', 'E_317ab5c540ee7b', 'E_2f2d2cddc9bceb', 'E_8a1a1ee359b513', 'E_7bc9754f88e61e', 'E_44b416dbe8d3bf', 'E_715f3cdecb5a9c', 'E_ffffc572b4d35b', 'E_a357fea47f42c6', 'E_dd87f47ac061f9', 'E_4d4539c08587f1', 'E_17a9c780152c95', 'E_55a3173dcf0afb', 'E_6781d6dc30517e', 'E_fab1e94cd3c3ee', 'E_41ba0ec3d20a87', 'E_00911dfe3e73c9', 'E_21f8bccd2c4b6a', 'E_46a062dcbe4086', 'E_89c96ef9598397', 'E_4113d3e1cfad18'}
# point_of_interest: P_ae96252a6a9380

# %%
e_id = 'E_0000764d65557e'
poi = 'P_be89c778befb23'

# %%
data[data[TARGET]==poi]
# Out:
#                                   name  latitude   longitude  \
# id
# E_0000764d65557e            mcdonald s -7.265894  112.749382
# E_0507e10f6eb526            mcdonald s -7.265468  112.748612
# E_30424388e6852c       mcd delta plaza -7.265279  112.748338
# E_7da6445404a886  mcdonald delta plaza -7.279387  112.759431
# E_f4b00a6db8b587      mc d delta plaza -7.264304  112.749496
#
#                                           address      city       state  \
# id
# E_0000764d65557e  Plaza Surabaya  Pemuda Building
# E_0507e10f6eb526            Plaza Surabaya  Lt  1  Surabaya  Jawa Timur
# E_30424388e6852c
# E_7da6445404a886
# E_f4b00a6db8b587
#
#                     zip country                         url      phone  ...  \
# id                                                                      ...
# E_0000764d65557e    NaN      ID                         NaN        NaN  ...
# E_0507e10f6eb526  60271      ID  http://www.mcdonalds.co.id  315450509  ...
# E_30424388e6852c    NaN      ID                         NaN        NaN  ...
# E_7da6445404a886    NaN      ID                         NaN        NaN  ...
# E_f4b00a6db8b587    NaN      ID                         NaN        NaN  ...
#
#                     state_split   cv co_net          main_category scale  \
# id
# E_0000764d65557e             []  0.0    0.0  Fast Food Restaurants     0
# E_0507e10f6eb526  [Jawa, Timur]  0.0    0.0  Fast Food Restaurants     0
# E_30424388e6852c             []  0.0    0.0   American Restaurants     0
# E_7da6445404a886             []  0.0    NaN                    NaN    -1
# E_f4b00a6db8b587             []  0.0    0.0  Fast Food Restaurants     0
#
#                  adjacency_frequency  betweeness_centrality  \
# id
# E_0000764d65557e                 5.0               0.003875
# E_0507e10f6eb526                 5.0               0.003875
# E_30424388e6852c                 7.0               0.027375
# E_7da6445404a886                 NaN                    NaN
# E_f4b00a6db8b587                 5.0               0.003875
#
#                   clustering_coefficient median_distances_median  \
# id
# E_0000764d65557e                0.300000             6354.897123
# E_0507e10f6eb526                0.300000             6354.897123
# E_30424388e6852c                0.190476             6815.049017
# E_7da6445404a886                     NaN                     NaN
# E_f4b00a6db8b587                0.300000             6354.897123
#
#                   category_rate
# id
# E_0000764d65557e       0.015049
# E_0507e10f6eb526       0.015049
# E_30424388e6852c       0.008548
# E_7da6445404a886            NaN
# E_f4b00a6db8b587       0.015049
#
# [5 rows x 25 columns]

# %%
train[train['id']==e_id]
# Out:
#                  id          match_id     kdist  kneighbors  name_iou  \
# 7  E_0000764d65557e  E_0000764d65557e  0.000000           0       1.0
# 7  E_0000764d65557e  E_47dfd60969c589  0.000478           1       0.0
# 7  E_0000764d65557e  E_0bc47bcb7d588e  0.000514           2       0.0
# 7  E_0000764d65557e  E_0507e10f6eb526  0.000880           8       1.0
# 7  E_0000764d65557e  E_c3297d51132b3f  0.001462          20       0.0
# 7  E_0000764d65557e  E_f4b00a6db8b587  0.001594          22       0.0
# 7  E_0000764d65557e  E_98cbf3929e673c  0.001926          33       0.0
# 7  E_0000764d65557e  E_4fc971dfaefd59  0.003169          60       0.0
# 7  E_0000764d65557e  E_8ea8718b17229d  0.003492          71       0.0
# 7  E_0000764d65557e  E_c269bd2cbf5d6d  0.003865          84       0.0
#
#    cat_similarity  name_rank  cv  co_net  match_co_net  ...  \
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    0.000000e+00       12.0   0     0.0           NaN  ...
# 7    0.000000e+00       15.0   0     0.0           0.0  ...
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    1.000000e+00        5.0   0     0.0           0.0  ...
# 7    1.000000e+00        5.0   0     0.0           0.0  ...
# 7    1.800000e-02        4.0   0     0.0           0.0  ...
# 7    1.000000e+00       10.0   0     0.0           0.0  ...
# 7    1.000000e-09        3.0   0     0.0           NaN  ...
# 7    1.800000e-02        2.0   0     0.0           0.0  ...
#
#    clustering_coefficient  match_clustering_coefficient  \
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.000000
# 7                     0.3                      0.300000
# 7                     0.3                      0.190476
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.136364
#
#    mean_clustering_coefficient  median_distances_median  \
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.150000              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.245238              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.218182              6354.897123
#
#    match_median_distances_median  mean_median_distances_median  category_rate  \
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3226.275791                   4790.586457       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6815.049017                   6584.973070       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    3200.938525                   4777.917824       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3307.259945                   4831.078534       0.015049
#
#    match_category_rate  mean_category_rate  label
# 7             0.015049            0.015049      1
# 7                  NaN                 NaN      0
# 7             0.002269            0.008659      0
# 7             0.015049            0.015049      1
# 7             0.008548            0.011799      0
# 7             0.015049            0.015049      1
# 7             0.005019            0.010034      0
# 7             0.015049            0.015049      0
# 7                  NaN                 NaN      0
# 7             0.026689            0.020869      0
#
# [10 rows x 30 columns]

# %%
# data2 = data.copy()
# data2.reset_index(drop=False, inplace=True)
# tmp = train[train.id==e_id]
# # tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], on='id', how='left')
# tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], left_on='match_id', right_on='id', how='left')
# del data2

# tmp

# %% [markdown]
# # Make Features

# %% [markdown]
# ## TF-IDF

# %%
if TFIDF:
    vec_columns = ['name', 'categories', 'address', 'state', 'url', 'country']

    tfidf_d = {}
    for col in vec_columns:
        tfidf = TfidfVectorizer()
        tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
        tfidf_d[col] = tv_fit

# %% [markdown]
# ## NLP

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
str_columns = ['url', 'name', 'address', 'city', 'state', 'zip', 'categories', 'phone',  'country']
# data['city_state'] = data['city'].fillna('') + data['state'].fillna('')
# data['all'] = data['name'] + data['address'].fillna('') + data['city'].fillna('') + data['state'].fillna('')
# str_columns += ['city_state', 'all']

# if COM > 0:
#     co_columns = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']

# def intersection(s, match_s):
#     return len(set(s.split(' ')) & set(match_s.split(' ')))

# %%
# %%time

# def sm_ratio(x):
#     return SequenceMatcher(None, x[0], x[1]).ratio()

# def levens_dist(x):
#     return Levenshtein.distance(x[0], x[1])

# def calc_jaro_winkler(x):
#     return Levenshtein.jaro_winkler(x[0], x[1])

# def calc_LCS(x):
#     return LCS(str(x[0]), str(x[1]))

def add_features(df):
    for col in tqdm(str_columns):
        before_cols = df.columns
        if TFIDF and col in vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_tfidf_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
            df[f'{col}_tfidf_diff'] = (tv_fit[indexs] - tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
#         arrs = np.array([col_values, matcol_values])
#         df[f'{col}_gesh'] = np.apply_along_axis(sm_ratio, 0, arrs)
#         df[f'{col}_leven'] = np.apply_along_axis(levens_dist, 0, arrs)
#         df[f'{col}_jaro'] = np.apply_along_axis(calc_jaro_winkler, 0, arrs)
#         df[f'{col}_lcs'] = np.apply_along_axis(calc_LCS, 0, arrs)
#         del arrs
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
#         intersections = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
#                 intersections.append(intersection(str(s), str(match_s)))
            elif s != 'nan' and match_s != 'nan':
                geshs.append(-1)
                levens.append(-1)
                jaros.append(-1)
                lcss.append(-1)
#                 intersections.append(-1)
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
#                 intersections.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
#         df[f'{col}_intersections'] = intersections
        
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
        
        del col_values, matcol_values
        after_cols = df.columns
        diff_cols = list(set(after_cols) - set(before_cols))
        df[diff_cols] = reduce_mem_usage(df[diff_cols])
        gc.collect()
        
#     if COM > 0:
#         for col in tqdm(co_columns):
#             col_values = data.loc[df['id']][col].values
#             matcol_values = data.loc[df['match_id']][col].values
#             if col != 'main_category':
#                 df[f's_{col}'] = col_values
#                 df[f't_{col}'] = matcol_values

#             if TFIDF and col in ['main_category', 'co_net']:
#                 df[f'is_match_{col}'] = col_values == matcol_values

    return df

train = add_features(train)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 285.64 MB
# Decreased by 68.2%
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 285.64 MB
# Decreased by 68.2%
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 285.64 MB
# Decreased by 68.2%
# Memory usage of dataframe is 734.50 MB
# Memory usage after optimization is: 214.23 MB
# Decreased by 70.8%
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 255.04 MB
# Decreased by 71.6%
# Memory usage of dataframe is 408.06 MB
# Memory usage after optimization is: 163.22 MB
# Decreased by 60.0%
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 275.44 MB
# Decreased by 69.3%
# Memory usage of dataframe is 408.06 MB
# Memory usage after optimization is: 163.22 MB
# Decreased by 60.0%
# Memory usage of dataframe is 897.73 MB
# Memory usage after optimization is: 275.44 MB
# Decreased by 69.3%
# CPU times: user 1h 29min 22s, sys: 1min 54s, total: 1h 31min 17s
# Wall time: 1h 31min 3s

# %% [markdown]
# # Train

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'))

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        print(col)
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
#             df[col] = df[col].astype('category')
            pass

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

train = reduce_mem_usage(train)
# Out:
# Memory usage of dataframe is 3784.74 MB
# id
# match_id
# kdist
# kneighbors
# name_iou
# cat_similarity
# name_rank
# cv
# co_net
# match_co_net
# is_match_co_net
# scale
# match_scale
# is_match_scale
# adjacency_frequency
# match_adjacency_frequency
# mean_adjacency_frequency
# betweeness_centrality
# match_betweeness_centrality
# mean_betweeness_centrality
# clustering_coefficient
# match_clustering_coefficient
# mean_clustering_coefficient
# median_distances_median
# match_median_distances_median
# mean_median_distances_median
# category_rate
# match_category_rate
# mean_category_rate
# label
# url_tfidf_sim
# url_tfidf_diff
# url_gesh
# url_leven
# url_jaro
# url_lcs
# url_len_diff
# url_nleven
# url_nlcsk
# url_nlcs
# name_tfidf_sim
# name_tfidf_diff
# name_gesh
# name_leven
# name_jaro
# name_lcs
# name_len_diff
# name_nleven
# name_nlcsk
# name_nlcs
# address_tfidf_sim
# address_tfidf_diff
# address_gesh
# address_leven
# address_jaro
# address_lcs
# address_len_diff
# address_nleven
# address_nlcsk
# address_nlcs
# city_gesh
# city_leven
# city_jaro
# city_lcs
# city_len_diff
# city_nleven
# city_nlcsk
# city_nlcs
# state_tfidf_sim
# state_tfidf_diff
# state_gesh
# state_leven
# state_jaro
# state_lcs
# state_len_diff
# state_nleven
# state_nlcsk
# state_nlcs
# zip_gesh
# zip_leven
# zip_jaro
# zip_lcs
# categories_tfidf_sim
# categories_tfidf_diff
# categories_gesh
# categories_leven
# categories_jaro
# categories_lcs
# categories_len_diff
# categories_nleven
# categories_nlcsk
# categories_nlcs
# phone_gesh
# phone_leven
# phone_jaro
# phone_lcs
# country_tfidf_sim
# country_tfidf_diff
# country_gesh
# country_leven
# country_jaro
# country_lcs
# country_len_diff
# country_nleven
# country_nlcsk
# country_nlcs
# Memory usage after optimization is: 2295.33 MB
# Decreased by 39.4%

# %%
features = ['kdist', 'kneighbors', 'name_gesh', 'name_leven', 'name_jaro',
       'name_lcs', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs',
       'address_gesh', 'address_leven', 'address_jaro', 'address_lcs',
       'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs',
       'city_gesh', 'city_leven', 'city_jaro', 'city_lcs', 'city_len_diff',
       'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_leven',
       'state_jaro', 'state_lcs', 'state_len_diff', 'state_nleven',
       'state_nlcsk', 'state_nlcs', 'zip_gesh', 'zip_leven', 'zip_jaro',
       'zip_lcs', 'categories_gesh', 'categories_leven', 'categories_jaro',
       'categories_lcs', 'categories_len_diff', 'categories_nleven',
       'categories_nlcsk', 'categories_nlcs', 'phone_gesh', 'phone_leven',
       'phone_jaro', 'phone_lcs', 'url_gesh', 'url_leven', 'url_jaro',
       'url_lcs', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs',
       'country_len_diff', 'country_jaro', 'country_lcs', 'country_nlcsk',
       'country_nleven', 'country_nlcs', 'country_leven', 'country_gesh', 
       'co_net', 'match_co_net', 'name_rank',
#        'match_scale', 'is_match_scale', 'is_match_co_net']
       'is_match_scale', 'is_match_co_net', 'match_scale', 'scale',
       'category_rate', 'match_adjacency_frequency', 'clustering_coefficient', 'match_category_rate',
       'betweeness_centrality', 'mean_clustering_coefficient', 'match_median_distances_median',
       'mean_category_rate', 'match_betweeness_centrality', 'mean_betweeness_centrality', 'mean_adjacency_frequency',
       'adjacency_frequency', 'median_distances_median', 'match_clustering_coefficient', 'mean_median_distances_median',
       'cat_similarity', 'name_iou'] # cat_similarity
#        'city_state_gesh', 'all_jaro', 'all_gesh', 'city_state_jaro', 'city_state_len_diff', 'all_nleven', 'city_state_nlcs', 'city_state_leven']
#         'name_intersections', 'address_intersections', 'city_intersections', 'state_intersections']

if TFIDF:
       features.extend(
           ['country_tfidf_sim', 'name_tfidf_diff', 'address_tfidf_diff', 'state_tfidf_sim', 'categories_tfidf_sim', 'url_tfidf_diff', 
       'country_tfidf_diff', 'categories_tfidf_diff', 'url_tfidf_sim', 'name_tfidf_sim', 'address_tfidf_sim', 'state_tfidf_diff'])
    

print(set(train.columns) - set(features))
print(f'no cols: {set(features) - set(train.columns)}')
# Out:
# {'id', 'label', 'match_id', 'cv'}
# no cols: set()

# %%
params = {
    'num_boost_round': 10000,
    'num_leaves': 500,
    'max_bin':300,
    'feature_fraction': 0.52,
    'bagging_fraction': 0.52,
    'max_depth': -1,
    'objective': 'binary',
    'learning_rate': 0.05,
    "boosting_type": "gbdt",
    "metric": 'auc',
    'early_stopping_rounds': 100,
    "verbosity": 50,
    'random_state': 47
}

# %%
# %%time

models = []
oof = np.zeros((len(train), N_FOLD), dtype=np.float64)
for i in range(N_FOLD):
    trn_idx = train['cv']!=i
    val_idx = train['cv']==i
    valid = train[train['cv']==i]
    train_X, train_y = train[trn_idx][features], train[trn_idx]['label']
    valid_X, valid_y = train[val_idx][features], train[val_idx]['label']
    
    print(f'*** start train cv: {i} ***')
    model = lgb.LGBMClassifier(**params)
    model.fit(
                train_X, train_y, 
                eval_set=[(valid_X, valid_y)])
    
    oof[val_idx] = model.predict_proba(valid_X)
    models.append(model)
    
    model_path = os.path.join(MODEL_PATH, f'lgb_fold{i}.pkl')
    print(f'save model: {model_path}')
    pickle.dump(model, open(model_path, 'wb'))
# Out:
# *** start train cv: 0 ***
# [1]	valid_0's auc: 0.966974
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.970801
# [3]	valid_0's auc: 0.980129
# [4]	valid_0's auc: 0.982028
# [5]	valid_0's auc: 0.983112
# [6]	valid_0's auc: 0.984168
# [7]	valid_0's auc: 0.984675
# [8]	valid_0's auc: 0.984942
# [9]	valid_0's auc: 0.985146
# [10]	valid_0's auc: 0.98538
# [11]	valid_0's auc: 0.985503
# [12]	valid_0's auc: 0.985674
# [13]	valid_0's auc: 0.985666
# [14]	valid_0's auc: 0.985687
# [15]	valid_0's auc: 0.98568
# [16]	valid_0's auc: 0.985694
# [17]	valid_0's auc: 0.98592
# [18]	valid_0's auc: 0.986096
# [19]	valid_0's auc: 0.986058
# [20]	valid_0's auc: 0.986256
# [21]	valid_0's auc: 0.986488
# [22]	valid_0's auc: 0.986563
# [23]	valid_0's auc: 0.986547
# [24]	valid_0's auc: 0.986742
# [25]	valid_0's auc: 0.986825
# [26]	valid_0's auc: 0.986953
# [27]	valid_0's auc: 0.987054
# [28]	valid_0's auc: 0.987042
# [29]	valid_0's auc: 0.987132
# [30]	valid_0's auc: 0.987199
# [31]	valid_0's auc: 0.987198
# [32]	valid_0's auc: 0.987293
# [33]	valid_0's auc: 0.987413
# [34]	valid_0's auc: 0.987482
# [35]	valid_0's auc: 0.987549
# [36]	valid_0's auc: 0.987566
# [37]	valid_0's auc: 0.987619
# [38]	valid_0's auc: 0.987644
# [39]	valid_0's auc: 0.987653
# [40]	valid_0's auc: 0.9877
# [41]	valid_0's auc: 0.987741
# [42]	valid_0's auc: 0.987828
# [43]	valid_0's auc: 0.987904
# [44]	valid_0's auc: 0.987939
# [45]	valid_0's auc: 0.987984
# [46]	valid_0's auc: 0.988054
# [47]	valid_0's auc: 0.988119
# [48]	valid_0's auc: 0.988169
# [49]	valid_0's auc: 0.988213
# [50]	valid_0's auc: 0.988257
# [51]	valid_0's auc: 0.988292
# [52]	valid_0's auc: 0.988318
# [53]	valid_0's auc: 0.98836
# [54]	valid_0's auc: 0.988409
# [55]	valid_0's auc: 0.988442
# [56]	valid_0's auc: 0.988472
# [57]	valid_0's auc: 0.988507
# [58]	valid_0's auc: 0.988525
# [59]	valid_0's auc: 0.988585
# [60]	valid_0's auc: 0.988617
# [61]	valid_0's auc: 0.988663
# [62]	valid_0's auc: 0.988704
# [63]	valid_0's auc: 0.988716
# [64]	valid_0's auc: 0.988745
# [65]	valid_0's auc: 0.988772
# [66]	valid_0's auc: 0.988811
# [67]	valid_0's auc: 0.988855
# [68]	valid_0's auc: 0.988893
# [69]	valid_0's auc: 0.988916
# [70]	valid_0's auc: 0.988944
# [71]	valid_0's auc: 0.988963
# [72]	valid_0's auc: 0.988981
# [73]	valid_0's auc: 0.989023
# [74]	valid_0's auc: 0.989047
# [75]	valid_0's auc: 0.989068
# [76]	valid_0's auc: 0.989102
# [77]	valid_0's auc: 0.989119
# [78]	valid_0's auc: 0.989149
# [79]	valid_0's auc: 0.989186
# [80]	valid_0's auc: 0.989221
# [81]	valid_0's auc: 0.989237
# [82]	valid_0's auc: 0.989271
# [83]	valid_0's auc: 0.989302
# [84]	valid_0's auc: 0.989324
# [85]	valid_0's auc: 0.989343
# [86]	valid_0's auc: 0.989367
# [87]	valid_0's auc: 0.989398
# [88]	valid_0's auc: 0.989416
# [89]	valid_0's auc: 0.989447
# [90]	valid_0's auc: 0.989463
# [91]	valid_0's auc: 0.98949
# [92]	valid_0's auc: 0.989507
# [93]	valid_0's auc: 0.989529
# [94]	valid_0's auc: 0.98955
# [95]	valid_0's auc: 0.989575
# [96]	valid_0's auc: 0.989598
# [97]	valid_0's auc: 0.989615
# [98]	valid_0's auc: 0.989633
# [99]	valid_0's auc: 0.989649
# [100]	valid_0's auc: 0.989671
# [101]	valid_0's auc: 0.989685
# [102]	valid_0's auc: 0.9897
# [103]	valid_0's auc: 0.989721
# [104]	valid_0's auc: 0.989743
# [105]	valid_0's auc: 0.989757
# [106]	valid_0's auc: 0.98977
# [107]	valid_0's auc: 0.989788
# [108]	valid_0's auc: 0.989808
# [109]	valid_0's auc: 0.989829
# [110]	valid_0's auc: 0.989846
# [111]	valid_0's auc: 0.989859
# [112]	valid_0's auc: 0.989877
# [113]	valid_0's auc: 0.989886
# [114]	valid_0's auc: 0.989903
# [115]	valid_0's auc: 0.989918
# [116]	valid_0's auc: 0.989937
# [117]	valid_0's auc: 0.989953
# [118]	valid_0's auc: 0.989968
# [119]	valid_0's auc: 0.989986
# [120]	valid_0's auc: 0.990003
# [121]	valid_0's auc: 0.990014
# [122]	valid_0's auc: 0.990026
# [123]	valid_0's auc: 0.990045
# [124]	valid_0's auc: 0.990061
# [125]	valid_0's auc: 0.990081
# [126]	valid_0's auc: 0.990091
# [127]	valid_0's auc: 0.990104
# [128]	valid_0's auc: 0.990115
# [129]	valid_0's auc: 0.990135
# [130]	valid_0's auc: 0.990149
# [131]	valid_0's auc: 0.990159
# [132]	valid_0's auc: 0.99017
# [133]	valid_0's auc: 0.990181
# [134]	valid_0's auc: 0.990191
# [135]	valid_0's auc: 0.990203
# [136]	valid_0's auc: 0.990215
# [137]	valid_0's auc: 0.990227
# [138]	valid_0's auc: 0.990237
# [139]	valid_0's auc: 0.990246
# [140]	valid_0's auc: 0.990259
# [141]	valid_0's auc: 0.99027
# [142]	valid_0's auc: 0.990279
# [143]	valid_0's auc: 0.990286
# [144]	valid_0's auc: 0.990299
# [145]	valid_0's auc: 0.990322
# [146]	valid_0's auc: 0.990331
# [147]	valid_0's auc: 0.990338
# [148]	valid_0's auc: 0.990343
# [149]	valid_0's auc: 0.99035
# [150]	valid_0's auc: 0.990356
# [151]	valid_0's auc: 0.990364
# [152]	valid_0's auc: 0.990371
# [153]	valid_0's auc: 0.990383
# [154]	valid_0's auc: 0.990391
# [155]	valid_0's auc: 0.990399
# [156]	valid_0's auc: 0.990409
# [157]	valid_0's auc: 0.990422
# [158]	valid_0's auc: 0.990428
# [159]	valid_0's auc: 0.99044
# [160]	valid_0's auc: 0.99045
# [161]	valid_0's auc: 0.990456
# [162]	valid_0's auc: 0.990465
# [163]	valid_0's auc: 0.99047
# [164]	valid_0's auc: 0.990479
# [165]	valid_0's auc: 0.990486
# [166]	valid_0's auc: 0.990493
# [167]	valid_0's auc: 0.990502
# [168]	valid_0's auc: 0.990507
# [169]	valid_0's auc: 0.990515
# [170]	valid_0's auc: 0.990528
# [171]	valid_0's auc: 0.990534
# [172]	valid_0's auc: 0.990534
# [173]	valid_0's auc: 0.990541
# [174]	valid_0's auc: 0.990547
# [175]	valid_0's auc: 0.990554
# [176]	valid_0's auc: 0.990565
# [177]	valid_0's auc: 0.990578
# [178]	valid_0's auc: 0.990586
# [179]	valid_0's auc: 0.99059
# [180]	valid_0's auc: 0.990598
# [181]	valid_0's auc: 0.990603
# [182]	valid_0's auc: 0.990611
# [183]	valid_0's auc: 0.990615
# [184]	valid_0's auc: 0.99062
# [185]	valid_0's auc: 0.990624
# [186]	valid_0's auc: 0.990634
# [187]	valid_0's auc: 0.990638
# [188]	valid_0's auc: 0.990645
# [189]	valid_0's auc: 0.990652
# [190]	valid_0's auc: 0.99066
# [191]	valid_0's auc: 0.990668
# [192]	valid_0's auc: 0.990671
# [193]	valid_0's auc: 0.990678
# [194]	valid_0's auc: 0.990684
# [195]	valid_0's auc: 0.990691
# [196]	valid_0's auc: 0.990698
# [197]	valid_0's auc: 0.990709
# [198]	valid_0's auc: 0.990711
# [199]	valid_0's auc: 0.990723
# [200]	valid_0's auc: 0.990728
# [201]	valid_0's auc: 0.990735
# [202]	valid_0's auc: 0.990738
# [203]	valid_0's auc: 0.990744
# [204]	valid_0's auc: 0.990749
# [205]	valid_0's auc: 0.990753
# [206]	valid_0's auc: 0.990758
# [207]	valid_0's auc: 0.99076
# [208]	valid_0's auc: 0.990765
# [209]	valid_0's auc: 0.990771
# [210]	valid_0's auc: 0.990781
# [211]	valid_0's auc: 0.990787
# [212]	valid_0's auc: 0.990794
# [213]	valid_0's auc: 0.990796
# [214]	valid_0's auc: 0.990802
# [215]	valid_0's auc: 0.990806
# [216]	valid_0's auc: 0.990808
# [217]	valid_0's auc: 0.990812
# [218]	valid_0's auc: 0.990814
# [219]	valid_0's auc: 0.990818
# [220]	valid_0's auc: 0.990822
# [221]	valid_0's auc: 0.990827
# [222]	valid_0's auc: 0.990834
# [223]	valid_0's auc: 0.990836
# [224]	valid_0's auc: 0.990839
# [225]	valid_0's auc: 0.990845
# [226]	valid_0's auc: 0.990847
# [227]	valid_0's auc: 0.990855
# [228]	valid_0's auc: 0.990857
# [229]	valid_0's auc: 0.99086
# [230]	valid_0's auc: 0.990861
# [231]	valid_0's auc: 0.990868
# [232]	valid_0's auc: 0.99087
# [233]	valid_0's auc: 0.990868
# [234]	valid_0's auc: 0.990869
# [235]	valid_0's auc: 0.990877
# [236]	valid_0's auc: 0.990879
# [237]	valid_0's auc: 0.990883
# [238]	valid_0's auc: 0.990884
# [239]	valid_0's auc: 0.990884
# [240]	valid_0's auc: 0.990889
# [241]	valid_0's auc: 0.990891
# [242]	valid_0's auc: 0.990897
# [243]	valid_0's auc: 0.9909
# [244]	valid_0's auc: 0.990902
# [245]	valid_0's auc: 0.990907
# [246]	valid_0's auc: 0.990912
# [247]	valid_0's auc: 0.990913
# [248]	valid_0's auc: 0.990915
# [249]	valid_0's auc: 0.990916
# [250]	valid_0's auc: 0.990918
# [251]	valid_0's auc: 0.990919
# [252]	valid_0's auc: 0.990923
# [253]	valid_0's auc: 0.990925
# [254]	valid_0's auc: 0.990929
# [255]	valid_0's auc: 0.990931
# [256]	valid_0's auc: 0.990934
# [257]	valid_0's auc: 0.990935
# [258]	valid_0's auc: 0.990936
# [259]	valid_0's auc: 0.990938
# [260]	valid_0's auc: 0.990941
# [261]	valid_0's auc: 0.990941
# [262]	valid_0's auc: 0.990942
# [263]	valid_0's auc: 0.990943
# [264]	valid_0's auc: 0.990945
# [265]	valid_0's auc: 0.990946
# [266]	valid_0's auc: 0.990944
# [267]	valid_0's auc: 0.99095
# [268]	valid_0's auc: 0.99095
# [269]	valid_0's auc: 0.99095
# [270]	valid_0's auc: 0.990955
# [271]	valid_0's auc: 0.990955
# [272]	valid_0's auc: 0.990958
# [273]	valid_0's auc: 0.990963
# [274]	valid_0's auc: 0.990963
# [275]	valid_0's auc: 0.990969
# [276]	valid_0's auc: 0.990971
# [277]	valid_0's auc: 0.990979
# [278]	valid_0's auc: 0.990982
# [279]	valid_0's auc: 0.990985
# [280]	valid_0's auc: 0.990984
# [281]	valid_0's auc: 0.990984
# [282]	valid_0's auc: 0.990981
# [283]	valid_0's auc: 0.990982
# [284]	valid_0's auc: 0.990983
# [285]	valid_0's auc: 0.990986
# [286]	valid_0's auc: 0.990987
# [287]	valid_0's auc: 0.990989
# [288]	valid_0's auc: 0.990986
# [289]	valid_0's auc: 0.990992
# [290]	valid_0's auc: 0.990993
# [291]	valid_0's auc: 0.990995
# [292]	valid_0's auc: 0.990998
# [293]	valid_0's auc: 0.990998
# [294]	valid_0's auc: 0.991
# [295]	valid_0's auc: 0.991
# [296]	valid_0's auc: 0.991002
# [297]	valid_0's auc: 0.991004
# [298]	valid_0's auc: 0.991007
# [299]	valid_0's auc: 0.991006
# [300]	valid_0's auc: 0.991007
# [301]	valid_0's auc: 0.991008
# [302]	valid_0's auc: 0.991004
# [303]	valid_0's auc: 0.991005
# [304]	valid_0's auc: 0.991005
# [305]	valid_0's auc: 0.991008
# [306]	valid_0's auc: 0.991008
# [307]	valid_0's auc: 0.991009
# [308]	valid_0's auc: 0.991009
# [309]	valid_0's auc: 0.991013
# [310]	valid_0's auc: 0.991014
# [311]	valid_0's auc: 0.991015
# [312]	valid_0's auc: 0.991019
# [313]	valid_0's auc: 0.99102
# [314]	valid_0's auc: 0.99102
# [315]	valid_0's auc: 0.991021
# [316]	valid_0's auc: 0.991022
# [317]	valid_0's auc: 0.991023
# [318]	valid_0's auc: 0.991025
# [319]	valid_0's auc: 0.991026
# [320]	valid_0's auc: 0.991028
# [321]	valid_0's auc: 0.991028
# [322]	valid_0's auc: 0.991028
# [323]	valid_0's auc: 0.991028
# [324]	valid_0's auc: 0.991029
# [325]	valid_0's auc: 0.991029
# [326]	valid_0's auc: 0.991029
# [327]	valid_0's auc: 0.991035
# [328]	valid_0's auc: 0.991035
# [329]	valid_0's auc: 0.991033
# [330]	valid_0's auc: 0.991039
# [331]	valid_0's auc: 0.991041
# [332]	valid_0's auc: 0.991041
# [333]	valid_0's auc: 0.991042
# [334]	valid_0's auc: 0.991046
# [335]	valid_0's auc: 0.991047
# [336]	valid_0's auc: 0.991048
# [337]	valid_0's auc: 0.991049
# [338]	valid_0's auc: 0.991051
# [339]	valid_0's auc: 0.991052
# [340]	valid_0's auc: 0.991055
# [341]	valid_0's auc: 0.991053
# [342]	valid_0's auc: 0.991056
# [343]	valid_0's auc: 0.991057
# [344]	valid_0's auc: 0.991057
# [345]	valid_0's auc: 0.991059
# [346]	valid_0's auc: 0.991059
# [347]	valid_0's auc: 0.991059
# [348]	valid_0's auc: 0.991061
# [349]	valid_0's auc: 0.991061
# [350]	valid_0's auc: 0.991061
# [351]	valid_0's auc: 0.991061
# [352]	valid_0's auc: 0.991061
# [353]	valid_0's auc: 0.991061
# [354]	valid_0's auc: 0.991061
# [355]	valid_0's auc: 0.991063
# [356]	valid_0's auc: 0.991067
# [357]	valid_0's auc: 0.991067
# [358]	valid_0's auc: 0.991068
# [359]	valid_0's auc: 0.991065
# [360]	valid_0's auc: 0.991066
# [361]	valid_0's auc: 0.991065
# [362]	valid_0's auc: 0.991068
# [363]	valid_0's auc: 0.991067
# [364]	valid_0's auc: 0.991064
# [365]	valid_0's auc: 0.991055
# [366]	valid_0's auc: 0.991051
# [367]	valid_0's auc: 0.991051
# [368]	valid_0's auc: 0.99105
# [369]	valid_0's auc: 0.991051
# [370]	valid_0's auc: 0.991049
# [371]	valid_0's auc: 0.991048
# [372]	valid_0's auc: 0.991048
# [373]	valid_0's auc: 0.991045
# [374]	valid_0's auc: 0.991045
# [375]	valid_0's auc: 0.991044
# [376]	valid_0's auc: 0.991045
# [377]	valid_0's auc: 0.991044
# [378]	valid_0's auc: 0.991043
# [379]	valid_0's auc: 0.991048
# [380]	valid_0's auc: 0.991049
# [381]	valid_0's auc: 0.991048
# [382]	valid_0's auc: 0.991047
# [383]	valid_0's auc: 0.991051
# [384]	valid_0's auc: 0.991049
# [385]	valid_0's auc: 0.991049
# [386]	valid_0's auc: 0.991052
# [387]	valid_0's auc: 0.991052
# [388]	valid_0's auc: 0.991052
# [389]	valid_0's auc: 0.991055
# [390]	valid_0's auc: 0.991054
# [391]	valid_0's auc: 0.991054
# [392]	valid_0's auc: 0.991052
# [393]	valid_0's auc: 0.991052
# [394]	valid_0's auc: 0.991053
# [395]	valid_0's auc: 0.991055
# [396]	valid_0's auc: 0.991055
# [397]	valid_0's auc: 0.991055
# [398]	valid_0's auc: 0.991056
# [399]	valid_0's auc: 0.991056
# [400]	valid_0's auc: 0.991057
# [401]	valid_0's auc: 0.991056
# [402]	valid_0's auc: 0.991056
# [403]	valid_0's auc: 0.991058
# [404]	valid_0's auc: 0.991059
# [405]	valid_0's auc: 0.991059
# [406]	valid_0's auc: 0.991059
# [407]	valid_0's auc: 0.991064
# [408]	valid_0's auc: 0.991066
# [409]	valid_0's auc: 0.991066
# [410]	valid_0's auc: 0.991068
# [411]	valid_0's auc: 0.991071
# [412]	valid_0's auc: 0.991071
# [413]	valid_0's auc: 0.991073
# [414]	valid_0's auc: 0.991072
# [415]	valid_0's auc: 0.991071
# [416]	valid_0's auc: 0.991073
# [417]	valid_0's auc: 0.991073
# [418]	valid_0's auc: 0.991072
# [419]	valid_0's auc: 0.991074
# [420]	valid_0's auc: 0.991073
# [421]	valid_0's auc: 0.991074
# [422]	valid_0's auc: 0.991074
# [423]	valid_0's auc: 0.991074
# [424]	valid_0's auc: 0.991076
# [425]	valid_0's auc: 0.991076
# [426]	valid_0's auc: 0.991078
# [427]	valid_0's auc: 0.991078
# [428]	valid_0's auc: 0.991079
# [429]	valid_0's auc: 0.99108
# [430]	valid_0's auc: 0.99108
# [431]	valid_0's auc: 0.99108
# [432]	valid_0's auc: 0.991081
# [433]	valid_0's auc: 0.991081
# [434]	valid_0's auc: 0.991081
# [435]	valid_0's auc: 0.99108
# [436]	valid_0's auc: 0.991081
# [437]	valid_0's auc: 0.991081
# [438]	valid_0's auc: 0.991081
# [439]	valid_0's auc: 0.991085
# [440]	valid_0's auc: 0.991086
# [441]	valid_0's auc: 0.991086
# [442]	valid_0's auc: 0.991086
# [443]	valid_0's auc: 0.991087
# [444]	valid_0's auc: 0.991088
# [445]	valid_0's auc: 0.991088
# [446]	valid_0's auc: 0.991088
# [447]	valid_0's auc: 0.991088
# [448]	valid_0's auc: 0.99109
# [449]	valid_0's auc: 0.991094
# [450]	valid_0's auc: 0.991094
# [451]	valid_0's auc: 0.991095
# [452]	valid_0's auc: 0.991096
# [453]	valid_0's auc: 0.9911
# [454]	valid_0's auc: 0.9911
# [455]	valid_0's auc: 0.9911
# [456]	valid_0's auc: 0.9911
# [457]	valid_0's auc: 0.9911
# [458]	valid_0's auc: 0.991103
# [459]	valid_0's auc: 0.991102
# [460]	valid_0's auc: 0.991102
# [461]	valid_0's auc: 0.991103
# [462]	valid_0's auc: 0.991104
# [463]	valid_0's auc: 0.991105
# [464]	valid_0's auc: 0.991106
# [465]	valid_0's auc: 0.991108
# [466]	valid_0's auc: 0.99111
# [467]	valid_0's auc: 0.99111
# [468]	valid_0's auc: 0.99111
# [469]	valid_0's auc: 0.991112
# [470]	valid_0's auc: 0.991111
# [471]	valid_0's auc: 0.991115
# [472]	valid_0's auc: 0.991115
# [473]	valid_0's auc: 0.991117
# [474]	valid_0's auc: 0.991117
# [475]	valid_0's auc: 0.991118
# [476]	valid_0's auc: 0.991118
# [477]	valid_0's auc: 0.991119
# [478]	valid_0's auc: 0.991119
# [479]	valid_0's auc: 0.99112
# [480]	valid_0's auc: 0.991121
# [481]	valid_0's auc: 0.991121
# [482]	valid_0's auc: 0.991121
# [483]	valid_0's auc: 0.991123
# [484]	valid_0's auc: 0.991124
# [485]	valid_0's auc: 0.991123
# [486]	valid_0's auc: 0.991122
# [487]	valid_0's auc: 0.991124
# [488]	valid_0's auc: 0.991124
# [489]	valid_0's auc: 0.991124
# [490]	valid_0's auc: 0.991125
# [491]	valid_0's auc: 0.991125
# [492]	valid_0's auc: 0.991126
# [493]	valid_0's auc: 0.991128
# [494]	valid_0's auc: 0.991128
# [495]	valid_0's auc: 0.991127
# [496]	valid_0's auc: 0.991127
# [497]	valid_0's auc: 0.99113
# [498]	valid_0's auc: 0.99113
# [499]	valid_0's auc: 0.991128
# [500]	valid_0's auc: 0.991128
# [501]	valid_0's auc: 0.991129
# [502]	valid_0's auc: 0.991129
# [503]	valid_0's auc: 0.991131
# [504]	valid_0's auc: 0.991131
# [505]	valid_0's auc: 0.991132
# [506]	valid_0's auc: 0.991133
# [507]	valid_0's auc: 0.991133
# [508]	valid_0's auc: 0.991134
# [509]	valid_0's auc: 0.991133
# [510]	valid_0's auc: 0.991134
# [511]	valid_0's auc: 0.991136
# [512]	valid_0's auc: 0.991136
# [513]	valid_0's auc: 0.991138
# [514]	valid_0's auc: 0.991139
# [515]	valid_0's auc: 0.991143
# [516]	valid_0's auc: 0.991144
# [517]	valid_0's auc: 0.991144
# [518]	valid_0's auc: 0.991144
# [519]	valid_0's auc: 0.991146
# [520]	valid_0's auc: 0.991145
# [521]	valid_0's auc: 0.991147
# [522]	valid_0's auc: 0.991148
# [523]	valid_0's auc: 0.991149
# [524]	valid_0's auc: 0.991149
# [525]	valid_0's auc: 0.991149
# [526]	valid_0's auc: 0.991151
# [527]	valid_0's auc: 0.991152
# [528]	valid_0's auc: 0.991153
# [529]	valid_0's auc: 0.991152
# [530]	valid_0's auc: 0.991153
# [531]	valid_0's auc: 0.991154
# [532]	valid_0's auc: 0.991154
# [533]	valid_0's auc: 0.991155
# [534]	valid_0's auc: 0.991155
# [535]	valid_0's auc: 0.991156
# [536]	valid_0's auc: 0.991155
# [537]	valid_0's auc: 0.991155
# [538]	valid_0's auc: 0.991156
# [539]	valid_0's auc: 0.991156
# [540]	valid_0's auc: 0.991156
# [541]	valid_0's auc: 0.991156
# [542]	valid_0's auc: 0.991155
# [543]	valid_0's auc: 0.991155
# [544]	valid_0's auc: 0.991155
# [545]	valid_0's auc: 0.991155
# [546]	valid_0's auc: 0.991157
# [547]	valid_0's auc: 0.991156
# [548]	valid_0's auc: 0.991156
# [549]	valid_0's auc: 0.991156
# [550]	valid_0's auc: 0.991157
# [551]	valid_0's auc: 0.991158
# [552]	valid_0's auc: 0.99116
# [553]	valid_0's auc: 0.99116
# [554]	valid_0's auc: 0.99116
# [555]	valid_0's auc: 0.991164
# [556]	valid_0's auc: 0.991164
# [557]	valid_0's auc: 0.991164
# [558]	valid_0's auc: 0.991164
# [559]	valid_0's auc: 0.991163
# [560]	valid_0's auc: 0.991163
# [561]	valid_0's auc: 0.991163
# [562]	valid_0's auc: 0.991164
# [563]	valid_0's auc: 0.991166
# [564]	valid_0's auc: 0.991167
# [565]	valid_0's auc: 0.991166
# [566]	valid_0's auc: 0.991167
# [567]	valid_0's auc: 0.991167
# [568]	valid_0's auc: 0.991169
# [569]	valid_0's auc: 0.991169
# [570]	valid_0's auc: 0.991165
# [571]	valid_0's auc: 0.991166
# [572]	valid_0's auc: 0.991167
# [573]	valid_0's auc: 0.991167
# [574]	valid_0's auc: 0.991169
# [575]	valid_0's auc: 0.991171
# [576]	valid_0's auc: 0.991171
# [577]	valid_0's auc: 0.991172
# [578]	valid_0's auc: 0.991172
# [579]	valid_0's auc: 0.991173
# [580]	valid_0's auc: 0.991174
# [581]	valid_0's auc: 0.991175
# [582]	valid_0's auc: 0.991174
# [583]	valid_0's auc: 0.991175
# [584]	valid_0's auc: 0.991176
# [585]	valid_0's auc: 0.991177
# [586]	valid_0's auc: 0.991177
# [587]	valid_0's auc: 0.991179
# [588]	valid_0's auc: 0.991182
# [589]	valid_0's auc: 0.991182
# [590]	valid_0's auc: 0.991181
# [591]	valid_0's auc: 0.991181
# [592]	valid_0's auc: 0.991183
# [593]	valid_0's auc: 0.991183
# [594]	valid_0's auc: 0.991183
# [595]	valid_0's auc: 0.991182
# [596]	valid_0's auc: 0.991182
# [597]	valid_0's auc: 0.99118
# [598]	valid_0's auc: 0.99118
# [599]	valid_0's auc: 0.99118
# [600]	valid_0's auc: 0.991183
# [601]	valid_0's auc: 0.991185
# [602]	valid_0's auc: 0.991188
# [603]	valid_0's auc: 0.991188
# [604]	valid_0's auc: 0.991189
# [605]	valid_0's auc: 0.991189
# [606]	valid_0's auc: 0.991191
# [607]	valid_0's auc: 0.991191
# [608]	valid_0's auc: 0.991193
# [609]	valid_0's auc: 0.991193
# [610]	valid_0's auc: 0.991195
# [611]	valid_0's auc: 0.991195
# [612]	valid_0's auc: 0.991196
# [613]	valid_0's auc: 0.991196
# [614]	valid_0's auc: 0.991198
# [615]	valid_0's auc: 0.991198
# [616]	valid_0's auc: 0.991199
# [617]	valid_0's auc: 0.9912
# [618]	valid_0's auc: 0.9912
# [619]	valid_0's auc: 0.991202
# [620]	valid_0's auc: 0.991204
# [621]	valid_0's auc: 0.991205
# [622]	valid_0's auc: 0.991205
# [623]	valid_0's auc: 0.991205
# [624]	valid_0's auc: 0.991206
# [625]	valid_0's auc: 0.991204
# [626]	valid_0's auc: 0.991204
# [627]	valid_0's auc: 0.991205
# [628]	valid_0's auc: 0.991207
# [629]	valid_0's auc: 0.991206
# [630]	valid_0's auc: 0.991207
# [631]	valid_0's auc: 0.991207
# [632]	valid_0's auc: 0.991208
# [633]	valid_0's auc: 0.991209
# [634]	valid_0's auc: 0.99121
# [635]	valid_0's auc: 0.991211
# [636]	valid_0's auc: 0.991211
# [637]	valid_0's auc: 0.991212
# [638]	valid_0's auc: 0.991213
# [639]	valid_0's auc: 0.991213
# [640]	valid_0's auc: 0.991213
# [641]	valid_0's auc: 0.991214
# [642]	valid_0's auc: 0.991213
# [643]	valid_0's auc: 0.991214
# [644]	valid_0's auc: 0.991214
# [645]	valid_0's auc: 0.991214
# [646]	valid_0's auc: 0.991215
# [647]	valid_0's auc: 0.991214
# [648]	valid_0's auc: 0.991215
# [649]	valid_0's auc: 0.991215
# [650]	valid_0's auc: 0.991216
# [651]	valid_0's auc: 0.991216
# [652]	valid_0's auc: 0.991216
# [653]	valid_0's auc: 0.991216
# [654]	valid_0's auc: 0.991216
# [655]	valid_0's auc: 0.991216
# [656]	valid_0's auc: 0.991215
# [657]	valid_0's auc: 0.991215
# [658]	valid_0's auc: 0.991216
# [659]	valid_0's auc: 0.991216
# [660]	valid_0's auc: 0.991216
# [661]	valid_0's auc: 0.991217
# [662]	valid_0's auc: 0.991217
# [663]	valid_0's auc: 0.991218
# [664]	valid_0's auc: 0.991219
# [665]	valid_0's auc: 0.99122
# [666]	valid_0's auc: 0.991219
# [667]	valid_0's auc: 0.991219
# [668]	valid_0's auc: 0.991219
# [669]	valid_0's auc: 0.991219
# [670]	valid_0's auc: 0.99122
# [671]	valid_0's auc: 0.99122
# [672]	valid_0's auc: 0.99122
# [673]	valid_0's auc: 0.991222
# [674]	valid_0's auc: 0.991224
# [675]	valid_0's auc: 0.991226
# [676]	valid_0's auc: 0.991226
# [677]	valid_0's auc: 0.991226
# [678]	valid_0's auc: 0.991227
# [679]	valid_0's auc: 0.991229
# [680]	valid_0's auc: 0.99123
# [681]	valid_0's auc: 0.991231
# [682]	valid_0's auc: 0.991232
# [683]	valid_0's auc: 0.991232
# [684]	valid_0's auc: 0.991231
# [685]	valid_0's auc: 0.991231
# [686]	valid_0's auc: 0.991231
# [687]	valid_0's auc: 0.991231
# [688]	valid_0's auc: 0.991234
# [689]	valid_0's auc: 0.991235
# [690]	valid_0's auc: 0.991234
# [691]	valid_0's auc: 0.991235
# [692]	valid_0's auc: 0.991236
# [693]	valid_0's auc: 0.991236
# [694]	valid_0's auc: 0.991236
# [695]	valid_0's auc: 0.991236
# [696]	valid_0's auc: 0.991236
# [697]	valid_0's auc: 0.991236
# [698]	valid_0's auc: 0.991237
# [699]	valid_0's auc: 0.991239
# [700]	valid_0's auc: 0.991239
# [701]	valid_0's auc: 0.991241
# [702]	valid_0's auc: 0.99124
# [703]	valid_0's auc: 0.991241
# [704]	valid_0's auc: 0.991242
# [705]	valid_0's auc: 0.991242
# [706]	valid_0's auc: 0.991243
# [707]	valid_0's auc: 0.991244
# [708]	valid_0's auc: 0.991244
# [709]	valid_0's auc: 0.991244
# [710]	valid_0's auc: 0.991244
# [711]	valid_0's auc: 0.991243
# [712]	valid_0's auc: 0.991243
# [713]	valid_0's auc: 0.991244
# [714]	valid_0's auc: 0.991245
# [715]	valid_0's auc: 0.991245
# [716]	valid_0's auc: 0.991246
# [717]	valid_0's auc: 0.991247
# [718]	valid_0's auc: 0.991247
# [719]	valid_0's auc: 0.991249
# [720]	valid_0's auc: 0.991249
# [721]	valid_0's auc: 0.99125
# [722]	valid_0's auc: 0.991252
# [723]	valid_0's auc: 0.991252
# [724]	valid_0's auc: 0.991253
# [725]	valid_0's auc: 0.991253
# [726]	valid_0's auc: 0.991254
# [727]	valid_0's auc: 0.991255
# [728]	valid_0's auc: 0.991255
# [729]	valid_0's auc: 0.991257
# [730]	valid_0's auc: 0.99126
# [731]	valid_0's auc: 0.99126
# [732]	valid_0's auc: 0.991261
# [733]	valid_0's auc: 0.991261
# [734]	valid_0's auc: 0.991261
# [735]	valid_0's auc: 0.991262
# [736]	valid_0's auc: 0.991263
# [737]	valid_0's auc: 0.991265
# [738]	valid_0's auc: 0.991266
# [739]	valid_0's auc: 0.991266
# [740]	valid_0's auc: 0.991266
# [741]	valid_0's auc: 0.991266
# [742]	valid_0's auc: 0.991266
# [743]	valid_0's auc: 0.991266
# [744]	valid_0's auc: 0.991266
# [745]	valid_0's auc: 0.991267
# [746]	valid_0's auc: 0.991266
# [747]	valid_0's auc: 0.991267
# [748]	valid_0's auc: 0.991267
# [749]	valid_0's auc: 0.99127
# [750]	valid_0's auc: 0.99127
# [751]	valid_0's auc: 0.99127
# [752]	valid_0's auc: 0.99127
# [753]	valid_0's auc: 0.991271
# [754]	valid_0's auc: 0.991271
# [755]	valid_0's auc: 0.99127
# [756]	valid_0's auc: 0.991271
# [757]	valid_0's auc: 0.991272
# [758]	valid_0's auc: 0.991272
# [759]	valid_0's auc: 0.991272
# [760]	valid_0's auc: 0.991272
# [761]	valid_0's auc: 0.991272
# [762]	valid_0's auc: 0.991272
# [763]	valid_0's auc: 0.991272
# [764]	valid_0's auc: 0.991273
# [765]	valid_0's auc: 0.991273
# [766]	valid_0's auc: 0.991274
# [767]	valid_0's auc: 0.991276
# [768]	valid_0's auc: 0.991277
# [769]	valid_0's auc: 0.991276
# [770]	valid_0's auc: 0.991276
# [771]	valid_0's auc: 0.991277
# [772]	valid_0's auc: 0.991277
# [773]	valid_0's auc: 0.991277
# [774]	valid_0's auc: 0.991277
# [775]	valid_0's auc: 0.991278
# [776]	valid_0's auc: 0.991277
# [777]	valid_0's auc: 0.991277
# [778]	valid_0's auc: 0.991278
# [779]	valid_0's auc: 0.991279
# [780]	valid_0's auc: 0.99128
# [781]	valid_0's auc: 0.991279
# [782]	valid_0's auc: 0.991281
# [783]	valid_0's auc: 0.991281
# [784]	valid_0's auc: 0.991281
# [785]	valid_0's auc: 0.991282
# [786]	valid_0's auc: 0.991282
# [787]	valid_0's auc: 0.991282
# [788]	valid_0's auc: 0.991283
# [789]	valid_0's auc: 0.991283
# [790]	valid_0's auc: 0.991283
# [791]	valid_0's auc: 0.991284
# [792]	valid_0's auc: 0.991284
# [793]	valid_0's auc: 0.991284
# [794]	valid_0's auc: 0.991284
# [795]	valid_0's auc: 0.991283
# [796]	valid_0's auc: 0.991284
# [797]	valid_0's auc: 0.991284
# [798]	valid_0's auc: 0.991285
# [799]	valid_0's auc: 0.991286
# [800]	valid_0's auc: 0.991287
# [801]	valid_0's auc: 0.991288
# [802]	valid_0's auc: 0.991288
# [803]	valid_0's auc: 0.991289
# [804]	valid_0's auc: 0.991291
# [805]	valid_0's auc: 0.991291
# [806]	valid_0's auc: 0.99129
# [807]	valid_0's auc: 0.99129
# [808]	valid_0's auc: 0.991291
# [809]	valid_0's auc: 0.991291
# [810]	valid_0's auc: 0.991291
# [811]	valid_0's auc: 0.991292
# [812]	valid_0's auc: 0.991294
# [813]	valid_0's auc: 0.991294
# [814]	valid_0's auc: 0.991295
# [815]	valid_0's auc: 0.991294
# [816]	valid_0's auc: 0.991295
# [817]	valid_0's auc: 0.991296
# [818]	valid_0's auc: 0.991294
# [819]	valid_0's auc: 0.991295
# [820]	valid_0's auc: 0.991293
# [821]	valid_0's auc: 0.991293
# [822]	valid_0's auc: 0.991293
# [823]	valid_0's auc: 0.991293
# [824]	valid_0's auc: 0.991294
# [825]	valid_0's auc: 0.991293
# [826]	valid_0's auc: 0.991294
# [827]	valid_0's auc: 0.991294
# [828]	valid_0's auc: 0.991295
# [829]	valid_0's auc: 0.991295
# [830]	valid_0's auc: 0.991294
# [831]	valid_0's auc: 0.991295
# [832]	valid_0's auc: 0.991296
# [833]	valid_0's auc: 0.991298
# [834]	valid_0's auc: 0.991298
# [835]	valid_0's auc: 0.991301
# [836]	valid_0's auc: 0.991301
# [837]	valid_0's auc: 0.991301
# [838]	valid_0's auc: 0.991301
# [839]	valid_0's auc: 0.991301
# [840]	valid_0's auc: 0.991302
# [841]	valid_0's auc: 0.991303
# [842]	valid_0's auc: 0.991303
# [843]	valid_0's auc: 0.991304
# [844]	valid_0's auc: 0.991304
# [845]	valid_0's auc: 0.991302
# [846]	valid_0's auc: 0.991303
# [847]	valid_0's auc: 0.991303
# [848]	valid_0's auc: 0.991305
# [849]	valid_0's auc: 0.991304
# [850]	valid_0's auc: 0.991305
# [851]	valid_0's auc: 0.991305
# [852]	valid_0's auc: 0.991305
# [853]	valid_0's auc: 0.991306
# [854]	valid_0's auc: 0.991307
# [855]	valid_0's auc: 0.991307
# [856]	valid_0's auc: 0.991307
# [857]	valid_0's auc: 0.991308
# [858]	valid_0's auc: 0.991308
# [859]	valid_0's auc: 0.991308
# [860]	valid_0's auc: 0.991308
# [861]	valid_0's auc: 0.991309
# [862]	valid_0's auc: 0.991309
# [863]	valid_0's auc: 0.991309
# [864]	valid_0's auc: 0.99131
# [865]	valid_0's auc: 0.991311
# [866]	valid_0's auc: 0.991311
# [867]	valid_0's auc: 0.99131
# [868]	valid_0's auc: 0.99131
# [869]	valid_0's auc: 0.991311
# [870]	valid_0's auc: 0.991311
# [871]	valid_0's auc: 0.991311
# [872]	valid_0's auc: 0.991312
# [873]	valid_0's auc: 0.991312
# [874]	valid_0's auc: 0.991312
# [875]	valid_0's auc: 0.991311
# [876]	valid_0's auc: 0.991312
# [877]	valid_0's auc: 0.991313
# [878]	valid_0's auc: 0.991312
# [879]	valid_0's auc: 0.991313
# [880]	valid_0's auc: 0.991313
# [881]	valid_0's auc: 0.991314
# [882]	valid_0's auc: 0.991314
# [883]	valid_0's auc: 0.991313
# [884]	valid_0's auc: 0.991313
# [885]	valid_0's auc: 0.991313
# [886]	valid_0's auc: 0.991313
# [887]	valid_0's auc: 0.991314
# [888]	valid_0's auc: 0.991315
# [889]	valid_0's auc: 0.991315
# [890]	valid_0's auc: 0.991316
# [891]	valid_0's auc: 0.991317
# [892]	valid_0's auc: 0.991317
# [893]	valid_0's auc: 0.991318
# [894]	valid_0's auc: 0.991318
# [895]	valid_0's auc: 0.991319
# [896]	valid_0's auc: 0.991319
# [897]	valid_0's auc: 0.99132
# [898]	valid_0's auc: 0.99132
# [899]	valid_0's auc: 0.99132
# [900]	valid_0's auc: 0.991321
# [901]	valid_0's auc: 0.991322
# [902]	valid_0's auc: 0.991323
# [903]	valid_0's auc: 0.991324
# [904]	valid_0's auc: 0.991324
# [905]	valid_0's auc: 0.991324
# [906]	valid_0's auc: 0.991326
# [907]	valid_0's auc: 0.991326
# [908]	valid_0's auc: 0.991326
# [909]	valid_0's auc: 0.991326
# [910]	valid_0's auc: 0.991327
# [911]	valid_0's auc: 0.991327
# [912]	valid_0's auc: 0.991328
# [913]	valid_0's auc: 0.991328
# [914]	valid_0's auc: 0.991328
# [915]	valid_0's auc: 0.991328
# [916]	valid_0's auc: 0.991328
# [917]	valid_0's auc: 0.991328
# [918]	valid_0's auc: 0.991328
# [919]	valid_0's auc: 0.99133
# [920]	valid_0's auc: 0.991331
# [921]	valid_0's auc: 0.991332
# [922]	valid_0's auc: 0.991332
# [923]	valid_0's auc: 0.991333
# [924]	valid_0's auc: 0.991333
# [925]	valid_0's auc: 0.991333
# [926]	valid_0's auc: 0.991333
# [927]	valid_0's auc: 0.991334
# [928]	valid_0's auc: 0.991334
# [929]	valid_0's auc: 0.991333
# [930]	valid_0's auc: 0.991333
# [931]	valid_0's auc: 0.991334
# [932]	valid_0's auc: 0.991334
# [933]	valid_0's auc: 0.991335
# [934]	valid_0's auc: 0.991334
# [935]	valid_0's auc: 0.991334
# [936]	valid_0's auc: 0.991335
# [937]	valid_0's auc: 0.991336
# [938]	valid_0's auc: 0.991336
# [939]	valid_0's auc: 0.991335
# [940]	valid_0's auc: 0.991336
# [941]	valid_0's auc: 0.991337
# [942]	valid_0's auc: 0.991337
# [943]	valid_0's auc: 0.991337
# [944]	valid_0's auc: 0.991337
# [945]	valid_0's auc: 0.991336
# [946]	valid_0's auc: 0.991337
# [947]	valid_0's auc: 0.991337
# [948]	valid_0's auc: 0.991337
# [949]	valid_0's auc: 0.991336
# [950]	valid_0's auc: 0.991337
# [951]	valid_0's auc: 0.991336
# [952]	valid_0's auc: 0.991338
# [953]	valid_0's auc: 0.991339
# [954]	valid_0's auc: 0.991339
# [955]	valid_0's auc: 0.991339
# [956]	valid_0's auc: 0.991339
# [957]	valid_0's auc: 0.991339
# [958]	valid_0's auc: 0.99134
# [959]	valid_0's auc: 0.99134
# [960]	valid_0's auc: 0.991341
# [961]	valid_0's auc: 0.991339
# [962]	valid_0's auc: 0.991338
# [963]	valid_0's auc: 0.991338
# [964]	valid_0's auc: 0.991338
# [965]	valid_0's auc: 0.991338
# [966]	valid_0's auc: 0.991338
# [967]	valid_0's auc: 0.99134
# [968]	valid_0's auc: 0.99134
# [969]	valid_0's auc: 0.99134
# [970]	valid_0's auc: 0.991339
# [971]	valid_0's auc: 0.991339
# [972]	valid_0's auc: 0.991339
# [973]	valid_0's auc: 0.991339
# [974]	valid_0's auc: 0.99134
# [975]	valid_0's auc: 0.99134
# [976]	valid_0's auc: 0.99134
# [977]	valid_0's auc: 0.99134
# [978]	valid_0's auc: 0.991342
# [979]	valid_0's auc: 0.991342
# [980]	valid_0's auc: 0.991342
# [981]	valid_0's auc: 0.991341
# [982]	valid_0's auc: 0.991341
# [983]	valid_0's auc: 0.991341
# [984]	valid_0's auc: 0.99134
# [985]	valid_0's auc: 0.991341
# [986]	valid_0's auc: 0.991341
# [987]	valid_0's auc: 0.991341
# [988]	valid_0's auc: 0.991341
# [989]	valid_0's auc: 0.991341
# [990]	valid_0's auc: 0.991341
# [991]	valid_0's auc: 0.991342
# [992]	valid_0's auc: 0.991342
# [993]	valid_0's auc: 0.991342
# [994]	valid_0's auc: 0.991343
# [995]	valid_0's auc: 0.991343
# [996]	valid_0's auc: 0.991343
# [997]	valid_0's auc: 0.991343
# [998]	valid_0's auc: 0.991344
# [999]	valid_0's auc: 0.991344
# [1000]	valid_0's auc: 0.991344
# [1001]	valid_0's auc: 0.991345
# [1002]	valid_0's auc: 0.991345
# [1003]	valid_0's auc: 0.991346
# [1004]	valid_0's auc: 0.991347
# [1005]	valid_0's auc: 0.991347
# [1006]	valid_0's auc: 0.991348
# [1007]	valid_0's auc: 0.991348
# [1008]	valid_0's auc: 0.991348
# [1009]	valid_0's auc: 0.991348
# [1010]	valid_0's auc: 0.991349
# [1011]	valid_0's auc: 0.991349
# [1012]	valid_0's auc: 0.991349
# [1013]	valid_0's auc: 0.991349
# [1014]	valid_0's auc: 0.991349
# [1015]	valid_0's auc: 0.99135
# [1016]	valid_0's auc: 0.99135
# [1017]	valid_0's auc: 0.991349
# [1018]	valid_0's auc: 0.99135
# [1019]	valid_0's auc: 0.99135
# [1020]	valid_0's auc: 0.99135
# [1021]	valid_0's auc: 0.991349
# [1022]	valid_0's auc: 0.99135
# [1023]	valid_0's auc: 0.99135
# [1024]	valid_0's auc: 0.991351
# [1025]	valid_0's auc: 0.991352
# [1026]	valid_0's auc: 0.991352
# [1027]	valid_0's auc: 0.991352
# [1028]	valid_0's auc: 0.991352
# [1029]	valid_0's auc: 0.991353
# [1030]	valid_0's auc: 0.991353
# [1031]	valid_0's auc: 0.991352
# [1032]	valid_0's auc: 0.991353
# [1033]	valid_0's auc: 0.991353
# [1034]	valid_0's auc: 0.991353
# [1035]	valid_0's auc: 0.991353
# [1036]	valid_0's auc: 0.991353
# [1037]	valid_0's auc: 0.991353
# [1038]	valid_0's auc: 0.991353
# [1039]	valid_0's auc: 0.991353
# [1040]	valid_0's auc: 0.991354
# [1041]	valid_0's auc: 0.991354
# [1042]	valid_0's auc: 0.991354
# [1043]	valid_0's auc: 0.991356
# [1044]	valid_0's auc: 0.991356
# [1045]	valid_0's auc: 0.991355
# [1046]	valid_0's auc: 0.991355
# [1047]	valid_0's auc: 0.991355
# [1048]	valid_0's auc: 0.991355
# [1049]	valid_0's auc: 0.991353
# [1050]	valid_0's auc: 0.991353
# [1051]	valid_0's auc: 0.991353
# [1052]	valid_0's auc: 0.991354
# [1053]	valid_0's auc: 0.991353
# [1054]	valid_0's auc: 0.991354
# [1055]	valid_0's auc: 0.991354
# [1056]	valid_0's auc: 0.991354
# [1057]	valid_0's auc: 0.991355
# [1058]	valid_0's auc: 0.991357
# [1059]	valid_0's auc: 0.991357
# [1060]	valid_0's auc: 0.991357
# [1061]	valid_0's auc: 0.991358
# [1062]	valid_0's auc: 0.991358
# [1063]	valid_0's auc: 0.991358
# [1064]	valid_0's auc: 0.991358
# [1065]	valid_0's auc: 0.991359
# [1066]	valid_0's auc: 0.991359
# [1067]	valid_0's auc: 0.991359
# [1068]	valid_0's auc: 0.99136
# [1069]	valid_0's auc: 0.99136
# [1070]	valid_0's auc: 0.991358
# [1071]	valid_0's auc: 0.991358
# [1072]	valid_0's auc: 0.991357
# [1073]	valid_0's auc: 0.991357
# [1074]	valid_0's auc: 0.991358
# [1075]	valid_0's auc: 0.991358
# [1076]	valid_0's auc: 0.991358
# [1077]	valid_0's auc: 0.991358
# [1078]	valid_0's auc: 0.991359
# [1079]	valid_0's auc: 0.99136
# [1080]	valid_0's auc: 0.99136
# [1081]	valid_0's auc: 0.99136
# [1082]	valid_0's auc: 0.991359
# [1083]	valid_0's auc: 0.99136
# [1084]	valid_0's auc: 0.991361
# [1085]	valid_0's auc: 0.991361
# [1086]	valid_0's auc: 0.991361
# [1087]	valid_0's auc: 0.991361
# [1088]	valid_0's auc: 0.991359
# [1089]	valid_0's auc: 0.99136
# [1090]	valid_0's auc: 0.99136
# [1091]	valid_0's auc: 0.991361
# [1092]	valid_0's auc: 0.991361
# [1093]	valid_0's auc: 0.991361
# [1094]	valid_0's auc: 0.991362
# [1095]	valid_0's auc: 0.991362
# [1096]	valid_0's auc: 0.991362
# [1097]	valid_0's auc: 0.991362
# [1098]	valid_0's auc: 0.991361
# [1099]	valid_0's auc: 0.991362
# [1100]	valid_0's auc: 0.991362
# [1101]	valid_0's auc: 0.991362
# [1102]	valid_0's auc: 0.991363
# [1103]	valid_0's auc: 0.991363
# [1104]	valid_0's auc: 0.991363
# [1105]	valid_0's auc: 0.991363
# [1106]	valid_0's auc: 0.991364
# [1107]	valid_0's auc: 0.991363
# [1108]	valid_0's auc: 0.991363
# [1109]	valid_0's auc: 0.991363
# [1110]	valid_0's auc: 0.991363
# [1111]	valid_0's auc: 0.991363
# [1112]	valid_0's auc: 0.991364
# [1113]	valid_0's auc: 0.991364
# [1114]	valid_0's auc: 0.991363
# [1115]	valid_0's auc: 0.991364
# [1116]	valid_0's auc: 0.991365
# [1117]	valid_0's auc: 0.991366
# [1118]	valid_0's auc: 0.991367
# [1119]	valid_0's auc: 0.991366
# [1120]	valid_0's auc: 0.991367
# [1121]	valid_0's auc: 0.991367
# [1122]	valid_0's auc: 0.991367
# [1123]	valid_0's auc: 0.991368
# [1124]	valid_0's auc: 0.991369
# [1125]	valid_0's auc: 0.991369
# [1126]	valid_0's auc: 0.991369
# [1127]	valid_0's auc: 0.991369
# [1128]	valid_0's auc: 0.991369
# [1129]	valid_0's auc: 0.991369
# [1130]	valid_0's auc: 0.991369
# [1131]	valid_0's auc: 0.991369
# [1132]	valid_0's auc: 0.991369
# [1133]	valid_0's auc: 0.991369
# [1134]	valid_0's auc: 0.991372
# [1135]	valid_0's auc: 0.991372
# [1136]	valid_0's auc: 0.991372
# [1137]	valid_0's auc: 0.991371
# [1138]	valid_0's auc: 0.991372
# [1139]	valid_0's auc: 0.991372
# [1140]	valid_0's auc: 0.991372
# [1141]	valid_0's auc: 0.991372
# [1142]	valid_0's auc: 0.991372
# [1143]	valid_0's auc: 0.991372
# [1144]	valid_0's auc: 0.991373
# [1145]	valid_0's auc: 0.991373
# [1146]	valid_0's auc: 0.991373
# [1147]	valid_0's auc: 0.991373
# [1148]	valid_0's auc: 0.991373
# [1149]	valid_0's auc: 0.991373
# [1150]	valid_0's auc: 0.991373
# [1151]	valid_0's auc: 0.991373
# [1152]	valid_0's auc: 0.991374
# [1153]	valid_0's auc: 0.991373
# [1154]	valid_0's auc: 0.991373
# [1155]	valid_0's auc: 0.991372
# [1156]	valid_0's auc: 0.991372
# [1157]	valid_0's auc: 0.991373
# [1158]	valid_0's auc: 0.991373
# [1159]	valid_0's auc: 0.991373
# [1160]	valid_0's auc: 0.991373
# [1161]	valid_0's auc: 0.991373
# [1162]	valid_0's auc: 0.991372
# [1163]	valid_0's auc: 0.991373
# [1164]	valid_0's auc: 0.991372
# [1165]	valid_0's auc: 0.991374
# [1166]	valid_0's auc: 0.991375
# [1167]	valid_0's auc: 0.991375
# [1168]	valid_0's auc: 0.991375
# [1169]	valid_0's auc: 0.991376
# [1170]	valid_0's auc: 0.991375
# [1171]	valid_0's auc: 0.991375
# [1172]	valid_0's auc: 0.991376
# [1173]	valid_0's auc: 0.991376
# [1174]	valid_0's auc: 0.991377
# [1175]	valid_0's auc: 0.991377
# [1176]	valid_0's auc: 0.991377
# [1177]	valid_0's auc: 0.991378
# [1178]	valid_0's auc: 0.991377
# [1179]	valid_0's auc: 0.991378
# [1180]	valid_0's auc: 0.99138
# [1181]	valid_0's auc: 0.991379
# [1182]	valid_0's auc: 0.991379
# [1183]	valid_0's auc: 0.99138
# [1184]	valid_0's auc: 0.99138
# [1185]	valid_0's auc: 0.99138
# [1186]	valid_0's auc: 0.99138
# [1187]	valid_0's auc: 0.99138
# [1188]	valid_0's auc: 0.99138
# [1189]	valid_0's auc: 0.99138
# [1190]	valid_0's auc: 0.99138
# [1191]	valid_0's auc: 0.991381
# [1192]	valid_0's auc: 0.991382
# [1193]	valid_0's auc: 0.991382
# [1194]	valid_0's auc: 0.991383
# [1195]	valid_0's auc: 0.991383
# [1196]	valid_0's auc: 0.991384
# [1197]	valid_0's auc: 0.991383
# [1198]	valid_0's auc: 0.991384
# [1199]	valid_0's auc: 0.991384
# [1200]	valid_0's auc: 0.991385
# [1201]	valid_0's auc: 0.991384
# [1202]	valid_0's auc: 0.991384
# [1203]	valid_0's auc: 0.991384
# [1204]	valid_0's auc: 0.991385
# [1205]	valid_0's auc: 0.991386
# [1206]	valid_0's auc: 0.991384
# [1207]	valid_0's auc: 0.991384
# [1208]	valid_0's auc: 0.991386
# [1209]	valid_0's auc: 0.991386
# [1210]	valid_0's auc: 0.991386
# [1211]	valid_0's auc: 0.991386
# [1212]	valid_0's auc: 0.991386
# [1213]	valid_0's auc: 0.991387
# [1214]	valid_0's auc: 0.991387
# [1215]	valid_0's auc: 0.991387
# [1216]	valid_0's auc: 0.991388
# [1217]	valid_0's auc: 0.991388
# [1218]	valid_0's auc: 0.991388
# [1219]	valid_0's auc: 0.991388
# [1220]	valid_0's auc: 0.991388
# [1221]	valid_0's auc: 0.991389
# [1222]	valid_0's auc: 0.99139
# [1223]	valid_0's auc: 0.99139
# [1224]	valid_0's auc: 0.99139
# [1225]	valid_0's auc: 0.991391
# [1226]	valid_0's auc: 0.991391
# [1227]	valid_0's auc: 0.991391
# [1228]	valid_0's auc: 0.991391
# [1229]	valid_0's auc: 0.991392
# [1230]	valid_0's auc: 0.991393
# [1231]	valid_0's auc: 0.991392
# [1232]	valid_0's auc: 0.991391
# [1233]	valid_0's auc: 0.991391
# [1234]	valid_0's auc: 0.991391
# [1235]	valid_0's auc: 0.991391
# [1236]	valid_0's auc: 0.991391
# [1237]	valid_0's auc: 0.991391
# [1238]	valid_0's auc: 0.991391
# [1239]	valid_0's auc: 0.991391
# [1240]	valid_0's auc: 0.991392
# [1241]	valid_0's auc: 0.991392
# [1242]	valid_0's auc: 0.991392
# [1243]	valid_0's auc: 0.991391
# [1244]	valid_0's auc: 0.991391
# [1245]	valid_0's auc: 0.991391
# [1246]	valid_0's auc: 0.991391
# [1247]	valid_0's auc: 0.99139
# [1248]	valid_0's auc: 0.99139
# [1249]	valid_0's auc: 0.991391
# [1250]	valid_0's auc: 0.99139
# [1251]	valid_0's auc: 0.99139
# [1252]	valid_0's auc: 0.99139
# [1253]	valid_0's auc: 0.991391
# [1254]	valid_0's auc: 0.991391
# [1255]	valid_0's auc: 0.991392
# [1256]	valid_0's auc: 0.991392
# [1257]	valid_0's auc: 0.991392
# [1258]	valid_0's auc: 0.991392
# [1259]	valid_0's auc: 0.991392
# [1260]	valid_0's auc: 0.991392
# [1261]	valid_0's auc: 0.991392
# [1262]	valid_0's auc: 0.991392
# [1263]	valid_0's auc: 0.991392
# [1264]	valid_0's auc: 0.991393
# [1265]	valid_0's auc: 0.991393
# [1266]	valid_0's auc: 0.991394
# [1267]	valid_0's auc: 0.991394
# [1268]	valid_0's auc: 0.991395
# [1269]	valid_0's auc: 0.991395
# [1270]	valid_0's auc: 0.991395
# [1271]	valid_0's auc: 0.991395
# [1272]	valid_0's auc: 0.991395
# [1273]	valid_0's auc: 0.991395
# [1274]	valid_0's auc: 0.991396
# [1275]	valid_0's auc: 0.991396
# [1276]	valid_0's auc: 0.991396
# [1277]	valid_0's auc: 0.991396
# [1278]	valid_0's auc: 0.991396
# [1279]	valid_0's auc: 0.991396
# [1280]	valid_0's auc: 0.991396
# [1281]	valid_0's auc: 0.991396
# [1282]	valid_0's auc: 0.991395
# [1283]	valid_0's auc: 0.991396
# [1284]	valid_0's auc: 0.991396
# [1285]	valid_0's auc: 0.991396
# [1286]	valid_0's auc: 0.991396
# [1287]	valid_0's auc: 0.991397
# [1288]	valid_0's auc: 0.991396
# [1289]	valid_0's auc: 0.991396
# [1290]	valid_0's auc: 0.991396
# [1291]	valid_0's auc: 0.991396
# [1292]	valid_0's auc: 0.991397
# [1293]	valid_0's auc: 0.991397
# [1294]	valid_0's auc: 0.991397
# [1295]	valid_0's auc: 0.991397
# [1296]	valid_0's auc: 0.991398
# [1297]	valid_0's auc: 0.991398
# [1298]	valid_0's auc: 0.991398
# [1299]	valid_0's auc: 0.991398
# [1300]	valid_0's auc: 0.991398
# [1301]	valid_0's auc: 0.991398
# [1302]	valid_0's auc: 0.991398
# [1303]	valid_0's auc: 0.991398
# [1304]	valid_0's auc: 0.991399
# [1305]	valid_0's auc: 0.9914
# [1306]	valid_0's auc: 0.9914
# [1307]	valid_0's auc: 0.9914
# [1308]	valid_0's auc: 0.991401
# [1309]	valid_0's auc: 0.991401
# [1310]	valid_0's auc: 0.991401
# [1311]	valid_0's auc: 0.991401
# [1312]	valid_0's auc: 0.991401
# [1313]	valid_0's auc: 0.991401
# [1314]	valid_0's auc: 0.991401
# [1315]	valid_0's auc: 0.991401
# [1316]	valid_0's auc: 0.991401
# [1317]	valid_0's auc: 0.991401
# [1318]	valid_0's auc: 0.991401
# [1319]	valid_0's auc: 0.9914
# [1320]	valid_0's auc: 0.9914
# [1321]	valid_0's auc: 0.9914
# [1322]	valid_0's auc: 0.9914
# [1323]	valid_0's auc: 0.9914
# [1324]	valid_0's auc: 0.9914
# [1325]	valid_0's auc: 0.9914
# [1326]	valid_0's auc: 0.991401
# [1327]	valid_0's auc: 0.991402
# [1328]	valid_0's auc: 0.991402
# [1329]	valid_0's auc: 0.991403
# [1330]	valid_0's auc: 0.991403
# [1331]	valid_0's auc: 0.991402
# [1332]	valid_0's auc: 0.991403
# [1333]	valid_0's auc: 0.991403
# [1334]	valid_0's auc: 0.991403
# [1335]	valid_0's auc: 0.991403
# [1336]	valid_0's auc: 0.991404
# [1337]	valid_0's auc: 0.991404
# [1338]	valid_0's auc: 0.991404
# [1339]	valid_0's auc: 0.991404
# [1340]	valid_0's auc: 0.991405
# [1341]	valid_0's auc: 0.991404
# [1342]	valid_0's auc: 0.991403
# [1343]	valid_0's auc: 0.991404
# [1344]	valid_0's auc: 0.991404
# [1345]	valid_0's auc: 0.991404
# [1346]	valid_0's auc: 0.991404
# [1347]	valid_0's auc: 0.991404
# [1348]	valid_0's auc: 0.991404
# [1349]	valid_0's auc: 0.991405
# [1350]	valid_0's auc: 0.991404
# [1351]	valid_0's auc: 0.991405
# [1352]	valid_0's auc: 0.991405
# [1353]	valid_0's auc: 0.991405
# [1354]	valid_0's auc: 0.991405
# [1355]	valid_0's auc: 0.991406
# [1356]	valid_0's auc: 0.991406
# [1357]	valid_0's auc: 0.991406
# [1358]	valid_0's auc: 0.991406
# [1359]	valid_0's auc: 0.991406
# [1360]	valid_0's auc: 0.991406
# [1361]	valid_0's auc: 0.991406
# [1362]	valid_0's auc: 0.991407
# [1363]	valid_0's auc: 0.991407
# [1364]	valid_0's auc: 0.991408
# [1365]	valid_0's auc: 0.991408
# [1366]	valid_0's auc: 0.991409
# [1367]	valid_0's auc: 0.991409
# [1368]	valid_0's auc: 0.991409
# [1369]	valid_0's auc: 0.991409
# [1370]	valid_0's auc: 0.99141
# [1371]	valid_0's auc: 0.99141
# [1372]	valid_0's auc: 0.99141
# [1373]	valid_0's auc: 0.99141
# [1374]	valid_0's auc: 0.991409
# [1375]	valid_0's auc: 0.991409
# [1376]	valid_0's auc: 0.991409
# [1377]	valid_0's auc: 0.991409
# [1378]	valid_0's auc: 0.991409
# [1379]	valid_0's auc: 0.991409
# [1380]	valid_0's auc: 0.99141
# [1381]	valid_0's auc: 0.99141
# [1382]	valid_0's auc: 0.99141
# [1383]	valid_0's auc: 0.991411
# [1384]	valid_0's auc: 0.991411
# [1385]	valid_0's auc: 0.991411
# [1386]	valid_0's auc: 0.991411
# [1387]	valid_0's auc: 0.991412
# [1388]	valid_0's auc: 0.991411
# [1389]	valid_0's auc: 0.991411
# [1390]	valid_0's auc: 0.991411
# [1391]	valid_0's auc: 0.991411
# [1392]	valid_0's auc: 0.991411
# [1393]	valid_0's auc: 0.991411
# [1394]	valid_0's auc: 0.991411
# [1395]	valid_0's auc: 0.991411
# [1396]	valid_0's auc: 0.991411
# [1397]	valid_0's auc: 0.99141
# [1398]	valid_0's auc: 0.991411
# [1399]	valid_0's auc: 0.991411
# [1400]	valid_0's auc: 0.99141
# [1401]	valid_0's auc: 0.99141
# [1402]	valid_0's auc: 0.99141
# [1403]	valid_0's auc: 0.991411
# [1404]	valid_0's auc: 0.991411
# [1405]	valid_0's auc: 0.991411
# [1406]	valid_0's auc: 0.991411
# [1407]	valid_0's auc: 0.991411
# [1408]	valid_0's auc: 0.991411
# [1409]	valid_0's auc: 0.991412
# [1410]	valid_0's auc: 0.991411
# [1411]	valid_0's auc: 0.991411
# [1412]	valid_0's auc: 0.991412
# [1413]	valid_0's auc: 0.991412
# [1414]	valid_0's auc: 0.991412
# [1415]	valid_0's auc: 0.991412
# [1416]	valid_0's auc: 0.991412
# [1417]	valid_0's auc: 0.991413
# [1418]	valid_0's auc: 0.991413
# [1419]	valid_0's auc: 0.991414
# [1420]	valid_0's auc: 0.991415
# [1421]	valid_0's auc: 0.991415
# [1422]	valid_0's auc: 0.991415
# [1423]	valid_0's auc: 0.991416
# [1424]	valid_0's auc: 0.991417
# [1425]	valid_0's auc: 0.991417
# [1426]	valid_0's auc: 0.991417
# [1427]	valid_0's auc: 0.991417
# [1428]	valid_0's auc: 0.991417
# [1429]	valid_0's auc: 0.991417
# [1430]	valid_0's auc: 0.991417
# [1431]	valid_0's auc: 0.991417
# [1432]	valid_0's auc: 0.991418
# [1433]	valid_0's auc: 0.991418
# [1434]	valid_0's auc: 0.991418
# [1435]	valid_0's auc: 0.991419
# [1436]	valid_0's auc: 0.991419
# [1437]	valid_0's auc: 0.991419
# [1438]	valid_0's auc: 0.991419
# [1439]	valid_0's auc: 0.991419
# [1440]	valid_0's auc: 0.991419
# [1441]	valid_0's auc: 0.991419
# [1442]	valid_0's auc: 0.991419
# [1443]	valid_0's auc: 0.991419
# [1444]	valid_0's auc: 0.991419
# [1445]	valid_0's auc: 0.99142
# [1446]	valid_0's auc: 0.99142
# [1447]	valid_0's auc: 0.99142
# [1448]	valid_0's auc: 0.99142
# [1449]	valid_0's auc: 0.99142
# [1450]	valid_0's auc: 0.99142
# [1451]	valid_0's auc: 0.99142
# [1452]	valid_0's auc: 0.99142
# [1453]	valid_0's auc: 0.99142
# [1454]	valid_0's auc: 0.991419
# [1455]	valid_0's auc: 0.991419
# [1456]	valid_0's auc: 0.991419
# [1457]	valid_0's auc: 0.991419
# [1458]	valid_0's auc: 0.991419
# [1459]	valid_0's auc: 0.991419
# [1460]	valid_0's auc: 0.991419
# [1461]	valid_0's auc: 0.991419
# [1462]	valid_0's auc: 0.991418
# [1463]	valid_0's auc: 0.991418
# [1464]	valid_0's auc: 0.991418
# [1465]	valid_0's auc: 0.991419
# [1466]	valid_0's auc: 0.991419
# [1467]	valid_0's auc: 0.991419
# [1468]	valid_0's auc: 0.991419
# [1469]	valid_0's auc: 0.99142
# [1470]	valid_0's auc: 0.99142
# [1471]	valid_0's auc: 0.991419
# [1472]	valid_0's auc: 0.99142
# [1473]	valid_0's auc: 0.99142
# [1474]	valid_0's auc: 0.99142
# [1475]	valid_0's auc: 0.991421
# [1476]	valid_0's auc: 0.991421
# [1477]	valid_0's auc: 0.991421
# [1478]	valid_0's auc: 0.991421
# [1479]	valid_0's auc: 0.991421
# [1480]	valid_0's auc: 0.991421
# [1481]	valid_0's auc: 0.991421
# [1482]	valid_0's auc: 0.991421
# [1483]	valid_0's auc: 0.991421
# [1484]	valid_0's auc: 0.991421
# [1485]	valid_0's auc: 0.991421
# [1486]	valid_0's auc: 0.991422
# [1487]	valid_0's auc: 0.991422
# [1488]	valid_0's auc: 0.991422
# [1489]	valid_0's auc: 0.991423
# [1490]	valid_0's auc: 0.991424
# [1491]	valid_0's auc: 0.991424
# [1492]	valid_0's auc: 0.991424
# [1493]	valid_0's auc: 0.991424
# [1494]	valid_0's auc: 0.991424
# [1495]	valid_0's auc: 0.991424
# [1496]	valid_0's auc: 0.991424
# [1497]	valid_0's auc: 0.991424
# [1498]	valid_0's auc: 0.991425
# [1499]	valid_0's auc: 0.991425
# [1500]	valid_0's auc: 0.991425
# [1501]	valid_0's auc: 0.991425
# [1502]	valid_0's auc: 0.991425
# [1503]	valid_0's auc: 0.991425
# [1504]	valid_0's auc: 0.991425
# [1505]	valid_0's auc: 0.991425
# [1506]	valid_0's auc: 0.991426
# [1507]	valid_0's auc: 0.991426
# [1508]	valid_0's auc: 0.991426
# [1509]	valid_0's auc: 0.991426
# [1510]	valid_0's auc: 0.991425
# [1511]	valid_0's auc: 0.991425
# [1512]	valid_0's auc: 0.991425
# [1513]	valid_0's auc: 0.991425
# [1514]	valid_0's auc: 0.991426
# [1515]	valid_0's auc: 0.991425
# [1516]	valid_0's auc: 0.991426
# [1517]	valid_0's auc: 0.991426
# [1518]	valid_0's auc: 0.991426
# [1519]	valid_0's auc: 0.991426
# [1520]	valid_0's auc: 0.991427
# [1521]	valid_0's auc: 0.991427
# [1522]	valid_0's auc: 0.991427
# [1523]	valid_0's auc: 0.991428
# [1524]	valid_0's auc: 0.991428
# [1525]	valid_0's auc: 0.991428
# [1526]	valid_0's auc: 0.991427
# [1527]	valid_0's auc: 0.991427
# [1528]	valid_0's auc: 0.991428
# [1529]	valid_0's auc: 0.991428
# [1530]	valid_0's auc: 0.991428
# [1531]	valid_0's auc: 0.991428
# [1532]	valid_0's auc: 0.991428
# [1533]	valid_0's auc: 0.991428
# [1534]	valid_0's auc: 0.991427
# [1535]	valid_0's auc: 0.991428
# [1536]	valid_0's auc: 0.991428
# [1537]	valid_0's auc: 0.991428
# [1538]	valid_0's auc: 0.991428
# [1539]	valid_0's auc: 0.991429
# [1540]	valid_0's auc: 0.991429
# [1541]	valid_0's auc: 0.991429
# [1542]	valid_0's auc: 0.991429
# [1543]	valid_0's auc: 0.991429
# [1544]	valid_0's auc: 0.99143
# [1545]	valid_0's auc: 0.99143
# [1546]	valid_0's auc: 0.991431
# [1547]	valid_0's auc: 0.991431
# [1548]	valid_0's auc: 0.991431
# [1549]	valid_0's auc: 0.991431
# [1550]	valid_0's auc: 0.991431
# [1551]	valid_0's auc: 0.991432
# [1552]	valid_0's auc: 0.991432
# [1553]	valid_0's auc: 0.991432
# [1554]	valid_0's auc: 0.991432
# [1555]	valid_0's auc: 0.991432
# [1556]	valid_0's auc: 0.991432
# [1557]	valid_0's auc: 0.991432
# [1558]	valid_0's auc: 0.991432
# [1559]	valid_0's auc: 0.991432
# [1560]	valid_0's auc: 0.991432
# [1561]	valid_0's auc: 0.991433
# [1562]	valid_0's auc: 0.991432
# [1563]	valid_0's auc: 0.991433
# [1564]	valid_0's auc: 0.991433
# [1565]	valid_0's auc: 0.991433
# [1566]	valid_0's auc: 0.991433
# [1567]	valid_0's auc: 0.991433
# [1568]	valid_0's auc: 0.991433
# [1569]	valid_0's auc: 0.991433
# [1570]	valid_0's auc: 0.991433
# [1571]	valid_0's auc: 0.991433
# [1572]	valid_0's auc: 0.991433
# [1573]	valid_0's auc: 0.991433
# [1574]	valid_0's auc: 0.991433
# [1575]	valid_0's auc: 0.991433
# [1576]	valid_0's auc: 0.991433
# [1577]	valid_0's auc: 0.991433
# [1578]	valid_0's auc: 0.991434
# [1579]	valid_0's auc: 0.991434
# [1580]	valid_0's auc: 0.991433
# [1581]	valid_0's auc: 0.991434
# [1582]	valid_0's auc: 0.991434
# [1583]	valid_0's auc: 0.991434
# [1584]	valid_0's auc: 0.991434
# [1585]	valid_0's auc: 0.991433
# [1586]	valid_0's auc: 0.991434
# [1587]	valid_0's auc: 0.991433
# ...
# [1000]	valid_0's auc: 0.991332
# [1001]	valid_0's auc: 0.991332
# [1002]	valid_0's auc: 0.991332
# [1003]	valid_0's auc: 0.991332
# [1004]	valid_0's auc: 0.991332
# [1005]	valid_0's auc: 0.991334
# [1006]	valid_0's auc: 0.991334
# [1007]	valid_0's auc: 0.991334
# [1008]	valid_0's auc: 0.991336
# [1009]	valid_0's auc: 0.991336
# [1010]	valid_0's auc: 0.991336
# [1011]	valid_0's auc: 0.991337
# [1012]	valid_0's auc: 0.991337
# [1013]	valid_0's auc: 0.991337
# [1014]	valid_0's auc: 0.991337
# [1015]	valid_0's auc: 0.991338
# [1016]	valid_0's auc: 0.991339
# [1017]	valid_0's auc: 0.99134
# [1018]	valid_0's auc: 0.99134
# [1019]	valid_0's auc: 0.99134
# [1020]	valid_0's auc: 0.99134
# [1021]	valid_0's auc: 0.99134
# [1022]	valid_0's auc: 0.991341
# [1023]	valid_0's auc: 0.99134
# [1024]	valid_0's auc: 0.99134
# [1025]	valid_0's auc: 0.991341
# [1026]	valid_0's auc: 0.991341
# [1027]	valid_0's auc: 0.991342
# [1028]	valid_0's auc: 0.991342
# [1029]	valid_0's auc: 0.991343
# [1030]	valid_0's auc: 0.991343
# [1031]	valid_0's auc: 0.991343
# [1032]	valid_0's auc: 0.991344
# [1033]	valid_0's auc: 0.991345
# [1034]	valid_0's auc: 0.991345
# [1035]	valid_0's auc: 0.991346
# [1036]	valid_0's auc: 0.991346
# [1037]	valid_0's auc: 0.991347
# [1038]	valid_0's auc: 0.991347
# [1039]	valid_0's auc: 0.991347
# [1040]	valid_0's auc: 0.991347
# [1041]	valid_0's auc: 0.991346
# [1042]	valid_0's auc: 0.99135
# [1043]	valid_0's auc: 0.991351
# [1044]	valid_0's auc: 0.991351
# [1045]	valid_0's auc: 0.991351
# [1046]	valid_0's auc: 0.991352
# [1047]	valid_0's auc: 0.991352
# [1048]	valid_0's auc: 0.991352
# [1049]	valid_0's auc: 0.991352
# [1050]	valid_0's auc: 0.991352
# [1051]	valid_0's auc: 0.991352
# [1052]	valid_0's auc: 0.991353
# [1053]	valid_0's auc: 0.991354
# [1054]	valid_0's auc: 0.991354
# [1055]	valid_0's auc: 0.991354
# [1056]	valid_0's auc: 0.991355
# [1057]	valid_0's auc: 0.991355
# [1058]	valid_0's auc: 0.991355
# [1059]	valid_0's auc: 0.991355
# [1060]	valid_0's auc: 0.991355
# [1061]	valid_0's auc: 0.991355
# [1062]	valid_0's auc: 0.991355
# [1063]	valid_0's auc: 0.991356
# [1064]	valid_0's auc: 0.991355
# [1065]	valid_0's auc: 0.991355
# [1066]	valid_0's auc: 0.991355
# [1067]	valid_0's auc: 0.991355
# [1068]	valid_0's auc: 0.991355
# [1069]	valid_0's auc: 0.991356
# [1070]	valid_0's auc: 0.991356
# [1071]	valid_0's auc: 0.991356
# [1072]	valid_0's auc: 0.991355
# [1073]	valid_0's auc: 0.991355
# [1074]	valid_0's auc: 0.991354
# [1075]	valid_0's auc: 0.991354
# [1076]	valid_0's auc: 0.991355
# [1077]	valid_0's auc: 0.991355
# [1078]	valid_0's auc: 0.991355
# [1079]	valid_0's auc: 0.991355
# [1080]	valid_0's auc: 0.991356
# [1081]	valid_0's auc: 0.991357
# [1082]	valid_0's auc: 0.991357
# [1083]	valid_0's auc: 0.991357
# [1084]	valid_0's auc: 0.991357
# [1085]	valid_0's auc: 0.991358
# [1086]	valid_0's auc: 0.991358
# [1087]	valid_0's auc: 0.991358
# [1088]	valid_0's auc: 0.991357
# [1089]	valid_0's auc: 0.991357
# [1090]	valid_0's auc: 0.991358
# [1091]	valid_0's auc: 0.991358
# [1092]	valid_0's auc: 0.991358
# [1093]	valid_0's auc: 0.991358
# [1094]	valid_0's auc: 0.991358
# [1095]	valid_0's auc: 0.991357
# [1096]	valid_0's auc: 0.991358
# [1097]	valid_0's auc: 0.991357
# [1098]	valid_0's auc: 0.991358
# [1099]	valid_0's auc: 0.991358
# [1100]	valid_0's auc: 0.991359
# [1101]	valid_0's auc: 0.99136
# [1102]	valid_0's auc: 0.99136
# [1103]	valid_0's auc: 0.99136
# [1104]	valid_0's auc: 0.991361
# [1105]	valid_0's auc: 0.991361
# [1106]	valid_0's auc: 0.991362
# [1107]	valid_0's auc: 0.991362
# [1108]	valid_0's auc: 0.991361
# [1109]	valid_0's auc: 0.991361
# [1110]	valid_0's auc: 0.991361
# [1111]	valid_0's auc: 0.991361
# [1112]	valid_0's auc: 0.991361
# [1113]	valid_0's auc: 0.991361
# [1114]	valid_0's auc: 0.991361
# [1115]	valid_0's auc: 0.991361
# [1116]	valid_0's auc: 0.99136
# [1117]	valid_0's auc: 0.991361
# [1118]	valid_0's auc: 0.991361
# [1119]	valid_0's auc: 0.991361
# [1120]	valid_0's auc: 0.991362
# [1121]	valid_0's auc: 0.991362
# [1122]	valid_0's auc: 0.991362
# [1123]	valid_0's auc: 0.991362
# [1124]	valid_0's auc: 0.991362
# [1125]	valid_0's auc: 0.991362
# [1126]	valid_0's auc: 0.991363
# [1127]	valid_0's auc: 0.991363
# [1128]	valid_0's auc: 0.991362
# [1129]	valid_0's auc: 0.991362
# [1130]	valid_0's auc: 0.991362
# [1131]	valid_0's auc: 0.991362
# [1132]	valid_0's auc: 0.991362
# [1133]	valid_0's auc: 0.991362
# [1134]	valid_0's auc: 0.991361
# [1135]	valid_0's auc: 0.991362
# [1136]	valid_0's auc: 0.991363
# [1137]	valid_0's auc: 0.991364
# [1138]	valid_0's auc: 0.991364
# [1139]	valid_0's auc: 0.991364
# [1140]	valid_0's auc: 0.991364
# [1141]	valid_0's auc: 0.991365
# [1142]	valid_0's auc: 0.991365
# [1143]	valid_0's auc: 0.991365
# [1144]	valid_0's auc: 0.991365
# [1145]	valid_0's auc: 0.991365
# [1146]	valid_0's auc: 0.991366
# [1147]	valid_0's auc: 0.991366
# [1148]	valid_0's auc: 0.991366
# [1149]	valid_0's auc: 0.991366
# [1150]	valid_0's auc: 0.991366
# [1151]	valid_0's auc: 0.991366
# [1152]	valid_0's auc: 0.991366
# [1153]	valid_0's auc: 0.991367
# [1154]	valid_0's auc: 0.991367
# [1155]	valid_0's auc: 0.991366
# [1156]	valid_0's auc: 0.991366
# [1157]	valid_0's auc: 0.991366
# [1158]	valid_0's auc: 0.991367
# [1159]	valid_0's auc: 0.991367
# [1160]	valid_0's auc: 0.991367
# [1161]	valid_0's auc: 0.991367
# [1162]	valid_0's auc: 0.991368
# [1163]	valid_0's auc: 0.99137
# [1164]	valid_0's auc: 0.991371
# [1165]	valid_0's auc: 0.991371
# [1166]	valid_0's auc: 0.991371
# [1167]	valid_0's auc: 0.991372
# [1168]	valid_0's auc: 0.991371
# [1169]	valid_0's auc: 0.991371
# [1170]	valid_0's auc: 0.991371
# [1171]	valid_0's auc: 0.991371
# [1172]	valid_0's auc: 0.99137
# [1173]	valid_0's auc: 0.991371
# [1174]	valid_0's auc: 0.99137
# [1175]	valid_0's auc: 0.991371
# [1176]	valid_0's auc: 0.991371
# [1177]	valid_0's auc: 0.991371
# [1178]	valid_0's auc: 0.99137
# [1179]	valid_0's auc: 0.991369
# [1180]	valid_0's auc: 0.991369
# [1181]	valid_0's auc: 0.991369
# [1182]	valid_0's auc: 0.99137
# [1183]	valid_0's auc: 0.99137
# [1184]	valid_0's auc: 0.99137
# [1185]	valid_0's auc: 0.991371
# [1186]	valid_0's auc: 0.99137
# [1187]	valid_0's auc: 0.99137
# [1188]	valid_0's auc: 0.99137
# [1189]	valid_0's auc: 0.99137
# [1190]	valid_0's auc: 0.99137
# [1191]	valid_0's auc: 0.99137
# [1192]	valid_0's auc: 0.99137
# [1193]	valid_0's auc: 0.99137
# [1194]	valid_0's auc: 0.99137
# [1195]	valid_0's auc: 0.991371
# [1196]	valid_0's auc: 0.991372
# [1197]	valid_0's auc: 0.991372
# [1198]	valid_0's auc: 0.991372
# [1199]	valid_0's auc: 0.991372
# [1200]	valid_0's auc: 0.991372
# [1201]	valid_0's auc: 0.991372
# [1202]	valid_0's auc: 0.991372
# [1203]	valid_0's auc: 0.991372
# [1204]	valid_0's auc: 0.991372
# [1205]	valid_0's auc: 0.991372
# [1206]	valid_0's auc: 0.991372
# [1207]	valid_0's auc: 0.991372
# [1208]	valid_0's auc: 0.991371
# [1209]	valid_0's auc: 0.991371
# [1210]	valid_0's auc: 0.991371
# [1211]	valid_0's auc: 0.991371
# [1212]	valid_0's auc: 0.991372
# [1213]	valid_0's auc: 0.991372
# [1214]	valid_0's auc: 0.991373
# [1215]	valid_0's auc: 0.991373
# [1216]	valid_0's auc: 0.991373
# [1217]	valid_0's auc: 0.991373
# [1218]	valid_0's auc: 0.991373
# [1219]	valid_0's auc: 0.991373
# [1220]	valid_0's auc: 0.991372
# [1221]	valid_0's auc: 0.991372
# [1222]	valid_0's auc: 0.991373
# [1223]	valid_0's auc: 0.991374
# [1224]	valid_0's auc: 0.991374
# [1225]	valid_0's auc: 0.991374
# [1226]	valid_0's auc: 0.991375
# [1227]	valid_0's auc: 0.991375
# [1228]	valid_0's auc: 0.991374
# [1229]	valid_0's auc: 0.991375
# [1230]	valid_0's auc: 0.991375
# [1231]	valid_0's auc: 0.991375
# [1232]	valid_0's auc: 0.991375
# [1233]	valid_0's auc: 0.991375
# [1234]	valid_0's auc: 0.991374
# [1235]	valid_0's auc: 0.991375
# [1236]	valid_0's auc: 0.991375
# [1237]	valid_0's auc: 0.991376
# [1238]	valid_0's auc: 0.991376
# [1239]	valid_0's auc: 0.991376
# [1240]	valid_0's auc: 0.991376
# [1241]	valid_0's auc: 0.991376
# [1242]	valid_0's auc: 0.991377
# [1243]	valid_0's auc: 0.991378
# [1244]	valid_0's auc: 0.991379
# [1245]	valid_0's auc: 0.991379
# [1246]	valid_0's auc: 0.991379
# [1247]	valid_0's auc: 0.991379
# [1248]	valid_0's auc: 0.991379
# [1249]	valid_0's auc: 0.99138
# [1250]	valid_0's auc: 0.99138
# [1251]	valid_0's auc: 0.99138
# [1252]	valid_0's auc: 0.991381
# [1253]	valid_0's auc: 0.99138
# [1254]	valid_0's auc: 0.991381
# [1255]	valid_0's auc: 0.991381
# [1256]	valid_0's auc: 0.991382
# [1257]	valid_0's auc: 0.991382
# [1258]	valid_0's auc: 0.991382
# [1259]	valid_0's auc: 0.991382
# [1260]	valid_0's auc: 0.991382
# [1261]	valid_0's auc: 0.991382
# [1262]	valid_0's auc: 0.991383
# [1263]	valid_0's auc: 0.991383
# [1264]	valid_0's auc: 0.991383
# [1265]	valid_0's auc: 0.991385
# [1266]	valid_0's auc: 0.991385
# [1267]	valid_0's auc: 0.991385
# [1268]	valid_0's auc: 0.991386
# [1269]	valid_0's auc: 0.991386
# [1270]	valid_0's auc: 0.991388
# [1271]	valid_0's auc: 0.991388
# [1272]	valid_0's auc: 0.991388
# [1273]	valid_0's auc: 0.991388
# [1274]	valid_0's auc: 0.991388
# [1275]	valid_0's auc: 0.991389
# [1276]	valid_0's auc: 0.991389
# [1277]	valid_0's auc: 0.991389
# [1278]	valid_0's auc: 0.991389
# [1279]	valid_0's auc: 0.991389
# [1280]	valid_0's auc: 0.991388
# [1281]	valid_0's auc: 0.991388
# [1282]	valid_0's auc: 0.991388
# [1283]	valid_0's auc: 0.991388
# [1284]	valid_0's auc: 0.991388
# [1285]	valid_0's auc: 0.991388
# [1286]	valid_0's auc: 0.991388
# [1287]	valid_0's auc: 0.991388
# [1288]	valid_0's auc: 0.991387
# [1289]	valid_0's auc: 0.991386
# [1290]	valid_0's auc: 0.991386
# [1291]	valid_0's auc: 0.991386
# [1292]	valid_0's auc: 0.991387
# [1293]	valid_0's auc: 0.991388
# [1294]	valid_0's auc: 0.991388
# [1295]	valid_0's auc: 0.991388
# [1296]	valid_0's auc: 0.991388
# [1297]	valid_0's auc: 0.991388
# [1298]	valid_0's auc: 0.991389
# [1299]	valid_0's auc: 0.991389
# [1300]	valid_0's auc: 0.991388
# [1301]	valid_0's auc: 0.991389
# [1302]	valid_0's auc: 0.99139
# [1303]	valid_0's auc: 0.991389
# [1304]	valid_0's auc: 0.991389
# [1305]	valid_0's auc: 0.991389
# [1306]	valid_0's auc: 0.991389
# [1307]	valid_0's auc: 0.991389
# [1308]	valid_0's auc: 0.991389
# [1309]	valid_0's auc: 0.991389
# [1310]	valid_0's auc: 0.991389
# [1311]	valid_0's auc: 0.99139
# [1312]	valid_0's auc: 0.99139
# [1313]	valid_0's auc: 0.991391
# [1314]	valid_0's auc: 0.991391
# [1315]	valid_0's auc: 0.991391
# [1316]	valid_0's auc: 0.991392
# [1317]	valid_0's auc: 0.991392
# [1318]	valid_0's auc: 0.991392
# [1319]	valid_0's auc: 0.991392
# [1320]	valid_0's auc: 0.991392
# [1321]	valid_0's auc: 0.991392
# [1322]	valid_0's auc: 0.991392
# [1323]	valid_0's auc: 0.991391
# [1324]	valid_0's auc: 0.991391
# [1325]	valid_0's auc: 0.991391
# [1326]	valid_0's auc: 0.991391
# [1327]	valid_0's auc: 0.991391
# [1328]	valid_0's auc: 0.991391
# [1329]	valid_0's auc: 0.991391
# [1330]	valid_0's auc: 0.991392
# [1331]	valid_0's auc: 0.991392
# [1332]	valid_0's auc: 0.991392
# [1333]	valid_0's auc: 0.991392
# [1334]	valid_0's auc: 0.991392
# [1335]	valid_0's auc: 0.991393
# [1336]	valid_0's auc: 0.991393
# [1337]	valid_0's auc: 0.991393
# [1338]	valid_0's auc: 0.991393
# [1339]	valid_0's auc: 0.991392
# [1340]	valid_0's auc: 0.991393
# [1341]	valid_0's auc: 0.991393
# [1342]	valid_0's auc: 0.991393
# [1343]	valid_0's auc: 0.991393
# [1344]	valid_0's auc: 0.991394
# [1345]	valid_0's auc: 0.991394
# [1346]	valid_0's auc: 0.991395
# [1347]	valid_0's auc: 0.991396
# [1348]	valid_0's auc: 0.991396
# [1349]	valid_0's auc: 0.991396
# [1350]	valid_0's auc: 0.991396
# [1351]	valid_0's auc: 0.991397
# [1352]	valid_0's auc: 0.991397
# [1353]	valid_0's auc: 0.991397
# [1354]	valid_0's auc: 0.991397
# [1355]	valid_0's auc: 0.991397
# [1356]	valid_0's auc: 0.991397
# [1357]	valid_0's auc: 0.991397
# [1358]	valid_0's auc: 0.991396
# [1359]	valid_0's auc: 0.991397
# [1360]	valid_0's auc: 0.991396
# [1361]	valid_0's auc: 0.991396
# [1362]	valid_0's auc: 0.991396
# [1363]	valid_0's auc: 0.991397
# [1364]	valid_0's auc: 0.991397
# [1365]	valid_0's auc: 0.991397
# [1366]	valid_0's auc: 0.991397
# [1367]	valid_0's auc: 0.991396
# [1368]	valid_0's auc: 0.991397
# [1369]	valid_0's auc: 0.991397
# [1370]	valid_0's auc: 0.991397
# [1371]	valid_0's auc: 0.991398
# [1372]	valid_0's auc: 0.991399
# [1373]	valid_0's auc: 0.991398
# [1374]	valid_0's auc: 0.991398
# [1375]	valid_0's auc: 0.991397
# [1376]	valid_0's auc: 0.991397
# [1377]	valid_0's auc: 0.991395
# [1378]	valid_0's auc: 0.991396
# [1379]	valid_0's auc: 0.991396
# [1380]	valid_0's auc: 0.991396
# [1381]	valid_0's auc: 0.991396
# [1382]	valid_0's auc: 0.991395
# [1383]	valid_0's auc: 0.991396
# [1384]	valid_0's auc: 0.991395
# [1385]	valid_0's auc: 0.991396
# [1386]	valid_0's auc: 0.991395
# [1387]	valid_0's auc: 0.991396
# [1388]	valid_0's auc: 0.991396
# [1389]	valid_0's auc: 0.991396
# [1390]	valid_0's auc: 0.991396
# [1391]	valid_0's auc: 0.991396
# [1392]	valid_0's auc: 0.991396
# [1393]	valid_0's auc: 0.991397
# [1394]	valid_0's auc: 0.991397
# [1395]	valid_0's auc: 0.991397
# [1396]	valid_0's auc: 0.991398
# [1397]	valid_0's auc: 0.991398
# [1398]	valid_0's auc: 0.991398
# [1399]	valid_0's auc: 0.991398
# [1400]	valid_0's auc: 0.991398
# [1401]	valid_0's auc: 0.991398
# [1402]	valid_0's auc: 0.991398
# [1403]	valid_0's auc: 0.991398
# [1404]	valid_0's auc: 0.991399
# [1405]	valid_0's auc: 0.991399
# [1406]	valid_0's auc: 0.991399
# [1407]	valid_0's auc: 0.991401
# [1408]	valid_0's auc: 0.991401
# [1409]	valid_0's auc: 0.9914
# [1410]	valid_0's auc: 0.991399
# [1411]	valid_0's auc: 0.991398
# [1412]	valid_0's auc: 0.991398
# [1413]	valid_0's auc: 0.991398
# [1414]	valid_0's auc: 0.991399
# [1415]	valid_0's auc: 0.991398
# [1416]	valid_0's auc: 0.991398
# [1417]	valid_0's auc: 0.991398
# [1418]	valid_0's auc: 0.991398
# [1419]	valid_0's auc: 0.991398
# [1420]	valid_0's auc: 0.991398
# [1421]	valid_0's auc: 0.991397
# [1422]	valid_0's auc: 0.991398
# [1423]	valid_0's auc: 0.991398
# [1424]	valid_0's auc: 0.991398
# [1425]	valid_0's auc: 0.991399
# [1426]	valid_0's auc: 0.991398
# [1427]	valid_0's auc: 0.991399
# [1428]	valid_0's auc: 0.991399
# [1429]	valid_0's auc: 0.991399
# [1430]	valid_0's auc: 0.991399
# [1431]	valid_0's auc: 0.991398
# [1432]	valid_0's auc: 0.991399
# [1433]	valid_0's auc: 0.991399
# [1434]	valid_0's auc: 0.991399
# [1435]	valid_0's auc: 0.991399
# [1436]	valid_0's auc: 0.991399
# [1437]	valid_0's auc: 0.991398
# [1438]	valid_0's auc: 0.991398
# [1439]	valid_0's auc: 0.991398
# [1440]	valid_0's auc: 0.991398
# [1441]	valid_0's auc: 0.991398
# [1442]	valid_0's auc: 0.991398
# [1443]	valid_0's auc: 0.991398
# [1444]	valid_0's auc: 0.991398
# [1445]	valid_0's auc: 0.991398
# [1446]	valid_0's auc: 0.991398
# [1447]	valid_0's auc: 0.991398
# [1448]	valid_0's auc: 0.991398
# [1449]	valid_0's auc: 0.991398
# [1450]	valid_0's auc: 0.991399
# [1451]	valid_0's auc: 0.991399
# [1452]	valid_0's auc: 0.991399
# [1453]	valid_0's auc: 0.991399
# [1454]	valid_0's auc: 0.991399
# [1455]	valid_0's auc: 0.991399
# [1456]	valid_0's auc: 0.9914
# [1457]	valid_0's auc: 0.9914
# [1458]	valid_0's auc: 0.9914
# [1459]	valid_0's auc: 0.9914
# [1460]	valid_0's auc: 0.9914
# [1461]	valid_0's auc: 0.991399
# [1462]	valid_0's auc: 0.991399
# [1463]	valid_0's auc: 0.991399
# [1464]	valid_0's auc: 0.991399
# [1465]	valid_0's auc: 0.991398
# [1466]	valid_0's auc: 0.991397
# [1467]	valid_0's auc: 0.991397
# [1468]	valid_0's auc: 0.991397
# [1469]	valid_0's auc: 0.991397
# [1470]	valid_0's auc: 0.991396
# [1471]	valid_0's auc: 0.991396
# [1472]	valid_0's auc: 0.991396
# [1473]	valid_0's auc: 0.991396
# [1474]	valid_0's auc: 0.991397
# [1475]	valid_0's auc: 0.991397
# [1476]	valid_0's auc: 0.991397
# [1477]	valid_0's auc: 0.991397
# [1478]	valid_0's auc: 0.991395
# [1479]	valid_0's auc: 0.991395
# [1480]	valid_0's auc: 0.991395
# [1481]	valid_0's auc: 0.991395
# [1482]	valid_0's auc: 0.991395
# [1483]	valid_0's auc: 0.991394
# [1484]	valid_0's auc: 0.991395
# [1485]	valid_0's auc: 0.991395
# [1486]	valid_0's auc: 0.991395
# [1487]	valid_0's auc: 0.991395
# [1488]	valid_0's auc: 0.991397
# [1489]	valid_0's auc: 0.991397
# [1490]	valid_0's auc: 0.991397
# [1491]	valid_0's auc: 0.991397
# [1492]	valid_0's auc: 0.991397
# [1493]	valid_0's auc: 0.991397
# [1494]	valid_0's auc: 0.991398
# [1495]	valid_0's auc: 0.991399
# [1496]	valid_0's auc: 0.991399
# [1497]	valid_0's auc: 0.991399
# [1498]	valid_0's auc: 0.991399
# [1499]	valid_0's auc: 0.991399
# [1500]	valid_0's auc: 0.991399
# [1501]	valid_0's auc: 0.991398
# [1502]	valid_0's auc: 0.991398
# [1503]	valid_0's auc: 0.991399
# [1504]	valid_0's auc: 0.9914
# [1505]	valid_0's auc: 0.991399
# [1506]	valid_0's auc: 0.991399
# [1507]	valid_0's auc: 0.991401
# Early stopping, best iteration is:
# [1407]	valid_0's auc: 0.991401
# save model: /content/drive/MyDrive/Kaggle/Foursquare/models/train_lgbm_recall_name_iou_edge_betweenness_centrality_0627_002/lgb_fold1.pkl
# CPU times: user 11h 29min 55s, sys: 1min 16s, total: 11h 31min 11s
# Wall time: 1h 45min 54s

# %%
# int_cols = ['s_co_net', 's_adjacency_frequency', 't_adjacency_frequency', 't_co_net']
# float_cols = ['t_clustering_coefficient', 's_clustering_coefficient', 's_betweeness_centrality', 't_betweeness_centrality']
# for col in int_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)
    
# for col in float_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)

# %%
cv = (oof.argmax(axis=-1) == train["label"].astype(int)).mean()
print(f"CV-accuracy: {cv}")
# 0.9726
# Out:
# CV-accuracy: 0.9665612507292939

# %%
importance_df = pd.DataFrame(models[0].feature_importances_, 
                             index=features, 
                             columns=['importance'])\
                    .sort_values("importance", ascending=False)


plt.figure(figsize=(20, 10))
sns.barplot(x="importance", y="index", data=importance_df.head(30).reset_index(drop=False))
plt.show()

# %%
del train_X, train_y, valid_X, valid_y, models

# %% [markdown]
# # Change Submission Format

# %%
tmp = train[['id', 'match_id', 'label']]
tmp[['pred_0', 'pred_1']] = oof

# %%
tmp.to_csv(os.path.join(OUTPUT_PATH, 'oof.csv'), index = False)

# %% [markdown]
# ### memoryリセットかけた

# %%
oof = pd.read_csv(os.path.join(OUTPUT_PATH, 'oof.csv'))
oof.head()
# Out:
#                  id          match_id  label    pred_0    pred_1
# 0  E_000002eae2a589  E_000002eae2a589      1  0.000003  0.999997
# 1  E_000007f24ebc95  E_000007f24ebc95      1  0.000136  0.999864
# 2  E_000008a8ba4f48  E_000008a8ba4f48      1  0.000005  0.999995
# 3  E_00001d92066153  E_00001d92066153      1  0.000002  0.999998
# 4  E_000023d8f4be44  E_000023d8f4be44      1  0.000003  0.999997

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(oof.id.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(oof.iterrows()):
    if row['pred_0'] < row['pred_1']:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
scores = []
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('cv score is', np.array(scores).mean())
# 0.8643
# 0.8655
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# cv score is 0.8642625033698648

# %% [markdown]
# # Using edge betweenness centrality

# %%
# !pip install cugraph
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cugraph
#   Using cached cugraph-0.6.1.post1.tar.gz (1.1 kB)
# Building wheels for collected packages: cugraph
#   Building wheel for cugraph (setup.py) ... error
#   ERROR: Failed building wheel for cugraph
#   Running setup.py clean for cugraph
# Failed to build cugraph
# Installing collected packages: cugraph
#     Running setup.py install for cugraph ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-z5wpfu6_/cugraph_33d8b486a3fe4589abbe506491b6a405/setup.py'"'"'; __file__='"'"'/tmp/pip-install-z5wpfu6_/cugraph_33d8b486a3fe4589abbe506491b6a405/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-h1m6rdfg/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/cugraph Check the logs for full command output.

# %%
import networkx as nx
from tqdm import tqdm

def using_edge_betweenness_centrality(df, weight_threshold = 0.15780210284453428, remove_edge_threshold = 0.11766651703447985, graph_member_num = 2):
    G = nx.Graph()
    for i, j, w in df[['id', 'match_id', 'pred_0']].values:
        G.add_edge(i, j, weight=w)

    list_remove_edges = []
    list_add_edges = []
    def split_graph(G):
        list_comp = list(nx.connected_components(G))
        n = len(G.nodes)
        if len(list_comp) == 1:
            map_bet = nx.edge_betweenness_centrality(G, normalized=True)
            map_bet = {(i, j): w  for (i, j), w in map_bet.items() 
                      if G[i][j]['weight'] < weight_threshold}
            if len(map_bet) == 0:
                return
            edge, val = max(map_bet.items(), key=lambda x: x[1])
            if val > remove_edge_threshold:
                G.remove_edge(*edge)
                list_remove_edges.append(edge)
                return split_graph(G)
        else:
            iters = list_comp
            for comp in iters:
                if len(comp) > graph_member_num:
                    split_graph(nx.Graph(G.subgraph(comp)))
                    
    split_graph(G)
    for edge in list_remove_edges:
        G.remove_edge(*edge)

    def get_score(i, j):
        try:
            return G[i][j]['weight']
        except KeyError:
            return -1

    ids = df['id'].unique()
    matches = []

    for i in ids:
        if i in G:
            m = list(set([i] + list(G.neighbors(i))))
        else:
            m = [i]
        matches.append(' '.join(m))
    matched = pd.DataFrame(dict(id=ids, matches=matches))
    return matched


def objective(trial):
    weight_threshold = trial.suggest_uniform("weight_threshold", 0, 1)
    remove_edge_threshold = trial.suggest_uniform("remove_edge_threshold", 0, 1)

    matched = using_edge_betweenness_centrality(oof, weight_threshold, remove_edge_threshold, 2)
    scores = []
    for id_x, preds in zip(matched['id'], matched['matches']):
        preds = set(preds.split())
        targets = poi2ids[id2poi[id_x]]
        score = len((targets & preds)) / len((targets | preds))
        scores.append(score)
    cv = np.array(scores).mean()
    print('cv score is', cv)
    return cv

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.37)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.7.1)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
import optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)
print('params:', study.best_params)
# Out:
# [I 2022-06-27 13:15:42,689] A new study created in memory with name: no-name-d95cd4ce-3ea1-4de6-b76b-1b4a5d8be269

# %%
study.best_value

# %%
# matched['matches_num'] = matched['matches'].map(lambda x: len(x.split()))
# plt.plot(matched['matches_num'])

# %% [markdown]
# # Check Misclassification

# %%
oof['pred'] = oof['pred_1'].round()
tmp = oof[['id', 'match_id', 'label', 'pred', 'pred_1']]

# %%
t = tmp[tmp['label']!=tmp['pred']]
tt = t[t['pred_1']<0.2]

# %%
len(t)

# %%
tt

# %%
id = 'E_0146e712d66bb8'
m_id = 'E_512009c07275bc'
ids = [id, m_id]
data[data.index.isin(ids)]
# data[data.id.isin(ids)]

# %%
train[(train['id']==id) & (train['match_id']==m_id)][['kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven']]

# %%
train.name_lcs.min()

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==0)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==1)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
train.head(20)[['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]

# %%
# cols = ['kdist_country', 'kdist', 'categories_jaro', 'name_jaro']
# train[(train['id']==id) & (train['match_id']==m_id)][cols]

# %%
# train[train['kdist_country']== train['kdist']]

# %%
# data[data.index.isin(ids)].loc['E_34199c1154c0d9']['name'].split()

# %%
# data[data.index.isin(ids)].loc['E_0258802b17b98e']['name'].split()
