# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Imports
import warnings
warnings.filterwarnings('ignore')

import sys

if "google.colab" in sys.modules:
    # !pip uninstall lightgbm -y
    # !pip install lightgbm==3.3.1
    # !pip install Levenshtein

import os
import gc
import time
import random
import pickle
import Levenshtein
import difflib
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import lightgbm as lgb
from tqdm.auto import tqdm
from requests import get
from collections import Counter, defaultdict
from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
# Out:
# Found existing installation: lightgbm 2.2.3
# Uninstalling lightgbm-2.2.3:
#   Successfully uninstalled lightgbm-2.2.3
# Collecting lightgbm==3.3.1
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 29.3 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.21.6)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.0.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (1.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.1
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 25.4 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 67.5 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.2
#   Downloading jarowinkler-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 77.8 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.2 rapidfuzz-2.0.11

# %%
def stratified_group_k_fold(X, y, groups, k, seed=None):
    labels_num = np.max(y) + 1
    y_counts_per_group = defaultdict(lambda: np.zeros(labels_num))
    y_distr = Counter()
    for label, g in zip(y, groups):
        y_counts_per_group[g][label] += 1
        y_distr[label] += 1

    y_counts_per_fold = defaultdict(lambda: np.zeros(labels_num))
    groups_per_fold = defaultdict(set)

    def eval_y_counts_per_fold(y_counts, fold):
        y_counts_per_fold[fold] += y_counts
        std_per_label = []
        for label in range(labels_num):
            label_std = np.std([y_counts_per_fold[i][label] / y_distr[label] for i in range(k)])
            std_per_label.append(label_std)
        y_counts_per_fold[fold] -= y_counts
        return np.mean(std_per_label)
    
    groups_and_y_counts = list(y_counts_per_group.items())
    random.Random(seed).shuffle(groups_and_y_counts)

    for g, y_counts in sorted(groups_and_y_counts, key=lambda x: -np.std(x[1])):
        best_fold = None
        min_eval = None
        for i in range(k):
            fold_eval = eval_y_counts_per_fold(y_counts, i)
            if min_eval is None or fold_eval < min_eval:
                min_eval = fold_eval
                best_fold = i
        y_counts_per_fold[best_fold] += y_counts
        groups_per_fold[best_fold].add(g)

    all_groups = set(groups)
    for i in range(k):
        train_groups = all_groups - groups_per_fold[i]
        test_groups = groups_per_fold[i]

        train_indices = [i for i, g in enumerate(groups) if g in train_groups]
        test_indices = [i for i, g in enumerate(groups) if g in test_groups]

        yield train_indices, test_indices

# %%
def get_distribution(y_vals):
    y_distr = Counter(y_vals)
    y_vals_sum = sum(y_distr.values())
    return [f'{y_distr[i] / y_vals_sum:.2%}' for i in range(np.max(y_vals) + 1)]

# %%
## Parameters
class CFG:
    AUTHOR = "kuruton"
    expID = ""
    if "google.colab" in sys.modules:
        expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0].split("-")[0]
    ROOT_DIR = '/content/drive/MyDrive/Kaggle/Foursquare'
    DATASET_DIR = os.path.join(ROOT_DIR, 'Dataset')
    INPUT_DIR = os.path.join(ROOT_DIR, 'Input')
    OUTPUT_DIR = os.path.join(ROOT_DIR, 'Output')
    is_debug = True
    SEED = 2022
    num_neighbors = 20
    num_split = 5
    feat_columns = ['name', 'address', 'city', 
                'state', 'zip', 'url', 
              'phone', 'categories', 'country']
    vec_columns = ['name', 'categories', 'address', 
                  'state', 'url', 'country']

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
seed_everything(CFG.SEED)

# %%
if not os.path.exists(os.path.join(CFG.OUTPUT_DIR, CFG.expID)):
    os.makedirs(os.path.join(CFG.OUTPUT_DIR, CFG.expID))

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
def recall_knn(df, Neighbors = 10):
    print('Start knn grouped by latlon_section')
    train_df_country = []
    for country, country_df in tqdm(df.groupby('latlon_section')):
        country_df = country_df.reset_index(drop = True)

        neighbors = min(len(country_df), Neighbors)
        knn = KNeighborsRegressor(n_neighbors = neighbors,
                                    metric = 'haversine',
                                    n_jobs = -1)
        knn.fit(country_df[['latitude','longitude']], country_df.index)
        dists, nears = knn.kneighbors(country_df[['latitude', 'longitude']], 
                                        return_distance = True)

        for k in range(neighbors):            
            cur_df = country_df[['id', 'point_of_interest']]
            cur_df['match_id'] = country_df['id'].values[nears[:, k]]
            cur_df['kdist_country'] = dists[:, k]
            cur_df['kneighbors_country'] = k
            
            train_df_country.append(cur_df)
    train_df_country = pd.concat(train_df_country)
    
    print('Start knn')
    train_df = []
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in range(Neighbors):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        train_df.append(cur_df)
    
    train_df = pd.concat(train_df)
    train_df = train_df.merge(train_df_country,
                                 on = ['id', 'match_id'],
                                 how = 'outer')
    del train_df_country
    
    return train_df

# %%
def add_features(df):    
    for col in tqdm(CFG.feat_columns):       
        if col in CFG.vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(difflib.SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
            
    return df

# %%
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

def get_score(input_df: pd.DataFrame):
    scores = []
    for id_str, matches in zip(input_df['id'].to_numpy(), input_df['matches'].to_numpy()):
        targets = poi2ids[id2poi[id_str]]
        preds = set(matches.split())
        score = len((targets & preds)) / len((targets | preds))
        scores.append(score)
    scores = np.array(scores)
    return scores.mean()

def analysis(df):
    print('Num of data: %s' % len(df))
    print('Num of unique id: %s' % df['id'].nunique())
    print('Num of unique poi: %s' % df['point_of_interest'].nunique())
    
    poi_grouped = df.groupby('point_of_interest')['id'].count().reset_index()
    print('Mean num of unique poi: %s' % poi_grouped['id'].mean())

# %%
## Data load
if "google.colab" in sys.modules:
    data_root = CFG.INPUT_DIR
else:
    data_root = '../input/foursquare-location-matching'
data = pd.read_csv(os.path.join(data_root, 'train.csv'))

if CFG.is_debug:
    data = data.sample(n = 10000, random_state = CFG.SEED)
    data = data.reset_index(drop = True)

# %%
## Data split
kf = GroupKFold(n_splits=2)
for i, (trn_idx, val_idx) in enumerate(kf.split(data, 
                                                data['point_of_interest'], 
                                                data['point_of_interest'])):
    data.loc[val_idx, 'set'] = i

print('Num of train data: %s' % len(data))
print(data['set'].value_counts())

valid_data = data[data['set'] == 0]
train_data = data[data['set'] == 1]

print('Train data: ')
analysis(train_data)
print('Valid data: ')
analysis(valid_data)

train_poi = train_data['point_of_interest'].unique().tolist()
valid_poi = valid_data['point_of_interest'].unique().tolist()

print(set(train_poi) & set(valid_poi))

train_ids = train_data['id'].unique().tolist()
valid_ids = valid_data['id'].unique().tolist()
      
print(set(train_ids) & set(valid_ids))
      
tv_ids_d = {}
tv_ids_d['train_ids'] = train_ids
tv_ids_d['valid_ids'] = valid_ids

np.save('tv_ids_d.npy', tv_ids_d)

del train_data, valid_data
gc.collect()

data = data.set_index('id')
data = data.loc[tv_ids_d['train_ids']]
data = data.reset_index()
# Out:
# Num of train data: 1138812
# 1.0    569406
# 0.0    569406
# Name: set, dtype: int64
# Train data:
# Num of data: 569406
# Num of unique id: 569406
# Num of unique poi: 369987
# Mean num of unique poi: 1.5389892077289202
# Valid data:
# Num of data: 569406
# Num of unique id: 569406
# Num of unique poi: 369985
# Mean num of unique poi: 1.5389975269267673
# set()
# set()

# %% [markdown]
# #Add new geographic coordinate classification

# %%
latitude = [-90 + 180 / (CFG.n_geographic_split // 2) * i for i in range(1, CFG.n_geographic_split // 2)]
longitude = [-180 + 360 / CFG.n_geographic_split * i for i in range(CFG.n_geographic_split)]

# %%
latlons = [(lat, lon) for lon in longitude for lat in latitude]
latlons.append((-90, 0))
latlons.append((90, 0))

# %%
# !pip install haversine
from haversine import haversine, Unit

# %%
def latlon_section(latlon):
    min_distance = float('inf')
    min_latlon = None
    for i in range(len(latlons)):
        distance = haversine(latlons[i], latlon)
        if distance < min_distance:
            min_distance = distance
            min_latlon = i
    return min_latlon
data['latlon_section'] = data[['latitude', 'longitude']].apply(latlon_section, axis = 1)
data.head()

# %%
plt.bar(data['latlon_section'].value_counts().index, data['latlon_section'].value_counts())

# %%
counts = np.array(data['latlon_section'].value_counts())
counts_sum = counts.sum()
counts = np.sort(counts)[::-1]
plt.plot(np.arange(len(counts)), np.cumsum(counts) / counts_sum)

# %%
## Train data generated by knn
id2index_d = dict(zip(data['id'].values, data.index))

tfidf_d = {}
for col in CFG.vec_columns:
    tfidf = TfidfVectorizer()
    tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
    tfidf_d[col] = tv_fit

train_data = pd.concat([
    recall_knn(data[data["set"]==0], CFG.num_neighbors), 
    recall_knn(data[data["set"]==1], CFG.num_neighbors), 
])

data = data.set_index('id')
ids = train_data['id'].tolist()
match_ids = train_data['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train_data['label'] = np.array(poi == match_poi, dtype = np.int8)
del poi, match_poi, ids, match_ids
gc.collect()

print('Num of unique id: %s' % train_data['id'].nunique())
print('Num of train data: %s' % len(train_data))
print('Pos rate: %s' % train_data['label'].mean())
print(train_data.sample(5))
# Out:
# Start knn grouped by country
#   0%|          | 0/210 [00:00<?, ?it/s]
# Start knn
# Num of unique id: 569406
# Num of train data: 13928057
# Pos rate: 0.07242905453359359
#                         id          match_id     kdist  kneighbors  \
# 2271553   E_fd464ba1740098  E_e9f184d83cae1e  0.007594         3.0
# 2195812   E_db1da0832b0edb  E_43d12cd75a508f  0.003153         3.0
# 6242880   E_f6b56f1f995bb8  E_559775ec266daa  0.002581        10.0
# 9817306   E_3daed89cf926d8  E_7d12548cb02d23  0.001735        17.0
# 11950281  E_92c117b8a31433  E_8f8f0ab8d049d3       NaN         NaN
#
#           kdist_country  kneighbors_country  label
# 2271553        0.006657                 2.0      0
# 2195812        0.003124                 3.0      0
# 6242880        0.002541                10.0      0
# 9817306        0.001725                17.0      0
# 11950281       0.040197                12.0      0

# %%
## Eval
data = data.reset_index()

id2poi = get_id2poi(data)
poi2ids = get_poi2ids(data)

eval_df = pd.DataFrame()
eval_df['id'] = data['id'].unique().tolist()
eval_df['match_id'] = eval_df['id']
print('Unique id: %s' % len(eval_df))

eval_df_ = train_data[train_data['label'] == 1][['id', 'match_id']]
eval_df = pd.concat([eval_df, eval_df_])

eval_df = eval_df.groupby('id')['match_id'].\
                        apply(list).reset_index()
eval_df['matches'] = eval_df['match_id'].apply(lambda x: ' '.join(set(x)))
print('Unique id: %s' % len(eval_df))

iou_score = get_score(eval_df)
print('IoU score: %s' % iou_score)
# Out:
# Unique id: 569406
# Unique id: 569406
# IoU score: 0.9231233344021228

# %%
distrs = [get_distribution(train_data["label"])]
index = ['training set']

for fold_ind, (dev_ind, val_ind) in enumerate(stratified_group_k_fold(train_data, train_data["label"], train_data["point_of_interest"], k=CFG.num_split, seed=CFG.SEED)):
    train_data.loc[val_ind, "fold"] = fold_ind

    dev_y, val_y = train_data.loc[dev_ind, "label"], train_data.loc[val_ind, "label"]
    dev_groups, val_groups = train_data.loc[dev_ind, "point_of_interest"], train_data.loc[val_ind, "point_of_interest"]
    
    assert len(set(dev_groups) & set(val_groups)) == 0
    
    distrs.append(get_distribution(dev_y))
    index.append(f'development set - fold {fold_ind}')
    distrs.append(get_distribution(val_y))
    index.append(f'validation set - fold {fold_ind}')

display('Distribution per class:')
pd.DataFrame(distrs, index=index, columns=[f'Label {l}' for l in range(np.max(train_data["label"]) + 1)])
# Out:
# 'Distribution per class:'
#                          Label 0 Label 1
# training set              92.76%   7.24%
# development set - fold 0  92.76%   7.24%
# validation set - fold 0   92.76%   7.24%
# development set - fold 1  92.76%   7.24%
# validation set - fold 1   92.76%   7.24%
# development set - fold 2  92.76%   7.24%
# validation set - fold 2   92.76%   7.24%
# development set - fold 3  92.76%   7.24%
# validation set - fold 3   92.76%   7.24%
# development set - fold 4  92.76%   7.24%
# validation set - fold 4   92.76%   7.24%

# %% [markdown]
# # model learning

# %%
data = data.set_index('id')
train_data = add_features(train_data)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
train_data['kdist_diff'] = (train_data['kdist'] - train_data['kdist_country']) /\
                            train_data['kdist_country']
train_data['kneighbors_mean'] = train_data[['kneighbors', 'kneighbors_country']].mean(axis = 1)

# %%
features = ['kdist','kneighbors','kdist_country','kneighbors_country', 'kdist_diff', 'kneighbors_mean']

columns = ['name', 'address', 'city', 'state',
       'zip', 'country', 'url', 'phone', 'categories']

for c in columns:
    if c == 'country':
        features += ['country_leven', 'country_sim', 'country_gesh', 'country_nleven']
        continue
    features += [f"{c}_gesh", f"{c}_jaro", f"{c}_lcs", f"{c}_leven"]
    if c == 'city':
        features += [f"{c}_len_diff", f"{c}_nleven", f"{c}_nlcsk", f"{c}_nlcs"]
    if c in ['address', 'categories', 'country', 'name', 'state', 'url']:
        features += [f"{c}_len_diff", f"{c}_nleven", f"{c}_nlcsk", f"{c}_nlcs", f"{c}_sim"]

print(len(features))
print(features)
# Out:
# 71
# ['kdist', 'kneighbors', 'kdist_country', 'kneighbors_country', 'kdist_diff', 'kneighbors_mean', 'name_gesh', 'name_jaro', 'name_lcs', 'name_leven', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs', 'name_sim', 'address_gesh', 'address_jaro', 'address_lcs', 'address_leven', 'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs', 'address_sim', 'city_gesh', 'city_jaro', 'city_lcs', 'city_leven', 'city_len_diff', 'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_jaro', 'state_lcs', 'state_leven', 'state_len_diff', 'state_nleven', 'state_nlcsk', 'state_nlcs', 'state_sim', 'zip_gesh', 'zip_jaro', 'zip_lcs', 'zip_leven', 'country_leven', 'country_sim', 'country_gesh', 'country_nleven', 'url_gesh', 'url_jaro', 'url_lcs', 'url_leven', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs', 'url_sim', 'phone_gesh', 'phone_jaro', 'phone_lcs', 'phone_leven', 'categories_gesh', 'categories_jaro', 'categories_lcs', 'categories_leven', 'categories_len_diff', 'categories_nleven', 'categories_nlcsk', 'categories_nlcs', 'categories_sim']

# %%
def fit_lgb(X, y, params=None, es_rounds=20, seed=42, N_SPLITS=5, 
             n_class=None, model_dir=None, folds=None):
    models = []
    oof = np.zeros((len(y), 2), dtype=np.float64)
    
    for i in tqdm(range(CFG.num_split)):
        print(f"== fold {i} ==")
        trn_idx = folds!=i
        val_idx = folds==i
        X_train, y_train = X[trn_idx], y.iloc[trn_idx]
        X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]

        if model_dir is None:
            model = lgb.LGBMClassifier(**params)
            model.fit(
                X_train, y_train, 
                eval_set=[(X_valid, y_valid)],  
                early_stopping_rounds=es_rounds, 
                eval_metric='binary',  
    #             verbose=-1)
                verbose=50)
        else:
            with open(f'{model_dir}/lgb_fold{i}.pkl', 'rb') as f:
                model = pickle.load(f)
            
        pred = model.predict_proba(X_valid)
        oof[val_idx] = pred
        models.append(model)
        
        file = os.path.join(CFG.OUTPUT_DIR, os.path.join(CFG.expID, f'lgb_fold{i}.pkl'))
        pickle.dump(model, open(file, 'wb'))
        print()

    cv = (oof.argmax(axis=-1) == y).mean()
    print(f"CV-accuracy: {cv}")

    return oof, models

def inference_lgb(models, feat_df):
    pred = np.array([model.predict_proba(feat_df) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

# %%
params = {
    'objective': "binary",
    'learning_rate': 0.2,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'random_state': 42,

    'max_depth': 7,   
    'num_leaves': 35, 
    'n_estimators': 1000000, 
    "colsample_bytree": 0.9,
}


oof, models = fit_lgb(train_data[features], train_data["label"].astype(int), 
                      params=params, n_class=2, 
                      N_SPLITS=CFG.num_split, folds=train_data["fold"].values)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# == fold 0 ==
# [50]	valid_0's binary_logloss: 0.0440953
# [100]	valid_0's binary_logloss: 0.0423057
# [150]	valid_0's binary_logloss: 0.0414409
# [200]	valid_0's binary_logloss: 0.0408319
# [250]	valid_0's binary_logloss: 0.0403797
# [300]	valid_0's binary_logloss: 0.0399813
# [350]	valid_0's binary_logloss: 0.0396457
# [400]	valid_0's binary_logloss: 0.0392769
# [450]	valid_0's binary_logloss: 0.038973
# [500]	valid_0's binary_logloss: 0.0386924
# [550]	valid_0's binary_logloss: 0.0384583
# [600]	valid_0's binary_logloss: 0.0382465
# [650]	valid_0's binary_logloss: 0.0380182
# [700]	valid_0's binary_logloss: 0.0378259
# [750]	valid_0's binary_logloss: 0.0376188
# [800]	valid_0's binary_logloss: 0.0374366
# [850]	valid_0's binary_logloss: 0.0373011
# [900]	valid_0's binary_logloss: 0.0371323
# [950]	valid_0's binary_logloss: 0.036997
# [1000]	valid_0's binary_logloss: 0.0368482
# [1050]	valid_0's binary_logloss: 0.0366841
# [1100]	valid_0's binary_logloss: 0.0365267
# [1150]	valid_0's binary_logloss: 0.0363661
# [1200]	valid_0's binary_logloss: 0.0362194
# [1250]	valid_0's binary_logloss: 0.0360909
# [1300]	valid_0's binary_logloss: 0.0359324
# [1350]	valid_0's binary_logloss: 0.0357989
# [1400]	valid_0's binary_logloss: 0.0356839
# [1450]	valid_0's binary_logloss: 0.0355563
# [1500]	valid_0's binary_logloss: 0.0354488
# [1550]	valid_0's binary_logloss: 0.0353195
# [1600]	valid_0's binary_logloss: 0.0352005
# [1650]	valid_0's binary_logloss: 0.0350911
# [1700]	valid_0's binary_logloss: 0.0349807
# [1750]	valid_0's binary_logloss: 0.0348818
# [1800]	valid_0's binary_logloss: 0.0347643
# [1850]	valid_0's binary_logloss: 0.0346602
# [1900]	valid_0's binary_logloss: 0.0345677
# [1950]	valid_0's binary_logloss: 0.0344539
# [2000]	valid_0's binary_logloss: 0.0343312
# [2050]	valid_0's binary_logloss: 0.0342369
# [2100]	valid_0's binary_logloss: 0.0341463
# [2150]	valid_0's binary_logloss: 0.0340505
# [2200]	valid_0's binary_logloss: 0.0339562
# [2250]	valid_0's binary_logloss: 0.0338546
# [2300]	valid_0's binary_logloss: 0.0337448
# [2350]	valid_0's binary_logloss: 0.0336592
# [2400]	valid_0's binary_logloss: 0.0335662
# [2450]	valid_0's binary_logloss: 0.0334764
# [2500]	valid_0's binary_logloss: 0.033378
# [2550]	valid_0's binary_logloss: 0.033291
# [2600]	valid_0's binary_logloss: 0.0331977
# [2650]	valid_0's binary_logloss: 0.0331068
# [2700]	valid_0's binary_logloss: 0.0330259
# [2750]	valid_0's binary_logloss: 0.0329393
# [2800]	valid_0's binary_logloss: 0.0328561
# [2850]	valid_0's binary_logloss: 0.0327566
# [2900]	valid_0's binary_logloss: 0.0326937
# [2950]	valid_0's binary_logloss: 0.0326219
# [3000]	valid_0's binary_logloss: 0.0325493
# [3050]	valid_0's binary_logloss: 0.0324576
# [3100]	valid_0's binary_logloss: 0.0323706
# [3150]	valid_0's binary_logloss: 0.0322873
# [3200]	valid_0's binary_logloss: 0.0322094
# [3250]	valid_0's binary_logloss: 0.0321359
# [3300]	valid_0's binary_logloss: 0.0320602
# [3350]	valid_0's binary_logloss: 0.0319891
# [3400]	valid_0's binary_logloss: 0.0319153
# [3450]	valid_0's binary_logloss: 0.0318425
# [3500]	valid_0's binary_logloss: 0.0317577
# [3550]	valid_0's binary_logloss: 0.0316955
# [3600]	valid_0's binary_logloss: 0.0316229
# [3650]	valid_0's binary_logloss: 0.0315387
# [3700]	valid_0's binary_logloss: 0.0314774
# [3750]	valid_0's binary_logloss: 0.0314082
# [3800]	valid_0's binary_logloss: 0.0313456
# [3850]	valid_0's binary_logloss: 0.0312777
# [3900]	valid_0's binary_logloss: 0.0312218
# [3950]	valid_0's binary_logloss: 0.0311588
# [4000]	valid_0's binary_logloss: 0.0311122
# [4050]	valid_0's binary_logloss: 0.0310372
# [4100]	valid_0's binary_logloss: 0.0309829
# [4150]	valid_0's binary_logloss: 0.0309287
# [4200]	valid_0's binary_logloss: 0.0308694
# [4250]	valid_0's binary_logloss: 0.0307994
# [4300]	valid_0's binary_logloss: 0.0307201
# [4350]	valid_0's binary_logloss: 0.0306653
# [4400]	valid_0's binary_logloss: 0.0306051
# [4450]	valid_0's binary_logloss: 0.0305338
# [4500]	valid_0's binary_logloss: 0.030471
# [4550]	valid_0's binary_logloss: 0.0304174
# [4600]	valid_0's binary_logloss: 0.0303561
# [4650]	valid_0's binary_logloss: 0.0303011
# [4700]	valid_0's binary_logloss: 0.0302519
# [4750]	valid_0's binary_logloss: 0.0301776
# [4800]	valid_0's binary_logloss: 0.0301244
# [4850]	valid_0's binary_logloss: 0.0300715
# [4900]	valid_0's binary_logloss: 0.0300142
# [4950]	valid_0's binary_logloss: 0.0299559
# [5000]	valid_0's binary_logloss: 0.0298997
# [5050]	valid_0's binary_logloss: 0.0298434
# [5100]	valid_0's binary_logloss: 0.0297858
# [5150]	valid_0's binary_logloss: 0.0297411
# [5200]	valid_0's binary_logloss: 0.0296962
# [5250]	valid_0's binary_logloss: 0.0296424
# [5300]	valid_0's binary_logloss: 0.0295844
# [5350]	valid_0's binary_logloss: 0.0295318
# [5400]	valid_0's binary_logloss: 0.0294721
# [5450]	valid_0's binary_logloss: 0.0294266
# [5500]	valid_0's binary_logloss: 0.0293769
# [5550]	valid_0's binary_logloss: 0.0293323
# [5600]	valid_0's binary_logloss: 0.0292823
# [5650]	valid_0's binary_logloss: 0.0292293
# [5700]	valid_0's binary_logloss: 0.029179
# [5750]	valid_0's binary_logloss: 0.0291265
# [5800]	valid_0's binary_logloss: 0.0290804
# [5850]	valid_0's binary_logloss: 0.0290299
# [5900]	valid_0's binary_logloss: 0.0289747
# [5950]	valid_0's binary_logloss: 0.0289272
# [6000]	valid_0's binary_logloss: 0.0288771
# [6050]	valid_0's binary_logloss: 0.0288186
# [6100]	valid_0's binary_logloss: 0.0287689
# [6150]	valid_0's binary_logloss: 0.0287262
# [6200]	valid_0's binary_logloss: 0.0286705
# [6250]	valid_0's binary_logloss: 0.0286274
# [6300]	valid_0's binary_logloss: 0.0285898
# [6350]	valid_0's binary_logloss: 0.0285404
# [6400]	valid_0's binary_logloss: 0.0285104
# [6450]	valid_0's binary_logloss: 0.0284594
# [6500]	valid_0's binary_logloss: 0.0284023
# [6550]	valid_0's binary_logloss: 0.0283534
# [6600]	valid_0's binary_logloss: 0.0283077
# [6650]	valid_0's binary_logloss: 0.0282608
# [6700]	valid_0's binary_logloss: 0.0282235
# [6750]	valid_0's binary_logloss: 0.0281703
# [6800]	valid_0's binary_logloss: 0.028131
# [6850]	valid_0's binary_logloss: 0.0280893
# [6900]	valid_0's binary_logloss: 0.0280443
# [6950]	valid_0's binary_logloss: 0.0279951
# [7000]	valid_0's binary_logloss: 0.0279495
# [7050]	valid_0's binary_logloss: 0.0278985
# [7100]	valid_0's binary_logloss: 0.0278442
# [7150]	valid_0's binary_logloss: 0.0278032
# [7200]	valid_0's binary_logloss: 0.0277673
# [7250]	valid_0's binary_logloss: 0.0277265
# [7300]	valid_0's binary_logloss: 0.0276905
# [7350]	valid_0's binary_logloss: 0.02765
# [7400]	valid_0's binary_logloss: 0.0276197
# [7450]	valid_0's binary_logloss: 0.0275739
# [7500]	valid_0's binary_logloss: 0.0275384
# [7550]	valid_0's binary_logloss: 0.0274961
# [7600]	valid_0's binary_logloss: 0.0274552
# [7650]	valid_0's binary_logloss: 0.0274109
# [7700]	valid_0's binary_logloss: 0.027372
# [7750]	valid_0's binary_logloss: 0.0273329
# [7800]	valid_0's binary_logloss: 0.0272859
# [7850]	valid_0's binary_logloss: 0.0272462
# [7900]	valid_0's binary_logloss: 0.0271995
# [7950]	valid_0's binary_logloss: 0.0271519
# [8000]	valid_0's binary_logloss: 0.0271139
# [8050]	valid_0's binary_logloss: 0.0270798
# [8100]	valid_0's binary_logloss: 0.0270457
# [8150]	valid_0's binary_logloss: 0.0270091
# [8200]	valid_0's binary_logloss: 0.0269725
# [8250]	valid_0's binary_logloss: 0.0269378
# [8300]	valid_0's binary_logloss: 0.026906
# [8350]	valid_0's binary_logloss: 0.0268751
# [8400]	valid_0's binary_logloss: 0.0268469
# [8450]	valid_0's binary_logloss: 0.0268132
# [8500]	valid_0's binary_logloss: 0.0267862
# [8550]	valid_0's binary_logloss: 0.0267554
# [8600]	valid_0's binary_logloss: 0.0267234
# [8650]	valid_0's binary_logloss: 0.0267024
# [8700]	valid_0's binary_logloss: 0.0266705
# [8750]	valid_0's binary_logloss: 0.0266405
# [8800]	valid_0's binary_logloss: 0.0266067
# [8850]	valid_0's binary_logloss: 0.0265765
# [8900]	valid_0's binary_logloss: 0.0265417
# [8950]	valid_0's binary_logloss: 0.0265083
# [9000]	valid_0's binary_logloss: 0.0264767
# [9050]	valid_0's binary_logloss: 0.0264394
# [9100]	valid_0's binary_logloss: 0.026405
# [9150]	valid_0's binary_logloss: 0.0263663
# [9200]	valid_0's binary_logloss: 0.026331
# [9250]	valid_0's binary_logloss: 0.0262922
# [9300]	valid_0's binary_logloss: 0.0262561
# [9350]	valid_0's binary_logloss: 0.0262244
# [9400]	valid_0's binary_logloss: 0.0261933
# [9450]	valid_0's binary_logloss: 0.0261616
# [9500]	valid_0's binary_logloss: 0.0261228
# [9550]	valid_0's binary_logloss: 0.0260964
# [9600]	valid_0's binary_logloss: 0.0260662
# [9650]	valid_0's binary_logloss: 0.0260412
# [9700]	valid_0's binary_logloss: 0.0259994
# [9750]	valid_0's binary_logloss: 0.0259701
# [9800]	valid_0's binary_logloss: 0.0259399
# [9850]	valid_0's binary_logloss: 0.0259115
# [9900]	valid_0's binary_logloss: 0.0258944
# [9950]	valid_0's binary_logloss: 0.0258708
# [10000]	valid_0's binary_logloss: 0.0258452
# [10050]	valid_0's binary_logloss: 0.0258232
# [10100]	valid_0's binary_logloss: 0.0257958
# [10150]	valid_0's binary_logloss: 0.0257619
# [10200]	valid_0's binary_logloss: 0.0257368
# [10250]	valid_0's binary_logloss: 0.0257167
# [10300]	valid_0's binary_logloss: 0.0256927
# [10350]	valid_0's binary_logloss: 0.0256704
# [10400]	valid_0's binary_logloss: 0.0256467
# [10450]	valid_0's binary_logloss: 0.0256229
# [10500]	valid_0's binary_logloss: 0.0255954
# [10550]	valid_0's binary_logloss: 0.0255775
# [10600]	valid_0's binary_logloss: 0.0255557
# [10650]	valid_0's binary_logloss: 0.025522
# [10700]	valid_0's binary_logloss: 0.0254978
# [10750]	valid_0's binary_logloss: 0.0254764
# [10800]	valid_0's binary_logloss: 0.0254536
# [10850]	valid_0's binary_logloss: 0.0254277
# [10900]	valid_0's binary_logloss: 0.0253994
# [10950]	valid_0's binary_logloss: 0.0253755
# [11000]	valid_0's binary_logloss: 0.0253533
# [11050]	valid_0's binary_logloss: 0.0253269
# [11100]	valid_0's binary_logloss: 0.0252994
# [11150]	valid_0's binary_logloss: 0.0252726
# [11200]	valid_0's binary_logloss: 0.0252455
# [11250]	valid_0's binary_logloss: 0.0252171
# [11300]	valid_0's binary_logloss: 0.0251856
# [11350]	valid_0's binary_logloss: 0.0251577
# [11400]	valid_0's binary_logloss: 0.0251317
# [11450]	valid_0's binary_logloss: 0.0251139
# [11500]	valid_0's binary_logloss: 0.025092
# [11550]	valid_0's binary_logloss: 0.0250645
# [11600]	valid_0's binary_logloss: 0.0250386
# [11650]	valid_0's binary_logloss: 0.0250164
# [11700]	valid_0's binary_logloss: 0.024992
# [11750]	valid_0's binary_logloss: 0.0249644
# [11800]	valid_0's binary_logloss: 0.0249452
# [11850]	valid_0's binary_logloss: 0.0249103
# [11900]	valid_0's binary_logloss: 0.0248884
# [11950]	valid_0's binary_logloss: 0.0248624
# [12000]	valid_0's binary_logloss: 0.0248417
# [12050]	valid_0's binary_logloss: 0.0248194
# [12100]	valid_0's binary_logloss: 0.0247979
# [12150]	valid_0's binary_logloss: 0.0247647
# [12200]	valid_0's binary_logloss: 0.024741
# [12250]	valid_0's binary_logloss: 0.0247231
# [12300]	valid_0's binary_logloss: 0.0246981
# [12350]	valid_0's binary_logloss: 0.0246756
# [12400]	valid_0's binary_logloss: 0.0246489
# [12450]	valid_0's binary_logloss: 0.0246245
# [12500]	valid_0's binary_logloss: 0.0246082
# [12550]	valid_0's binary_logloss: 0.0245902
# [12600]	valid_0's binary_logloss: 0.0245734
# [12650]	valid_0's binary_logloss: 0.0245526
# [12700]	valid_0's binary_logloss: 0.0245377
# [12750]	valid_0's binary_logloss: 0.024513
# [12800]	valid_0's binary_logloss: 0.0244855
# [12850]	valid_0's binary_logloss: 0.0244605
# [12900]	valid_0's binary_logloss: 0.0244443
# [12950]	valid_0's binary_logloss: 0.024424
# [13000]	valid_0's binary_logloss: 0.0243997
# [13050]	valid_0's binary_logloss: 0.0243843
# [13100]	valid_0's binary_logloss: 0.0243629
# [13150]	valid_0's binary_logloss: 0.0243384
# [13200]	valid_0's binary_logloss: 0.024325
# [13250]	valid_0's binary_logloss: 0.0243071
# [13300]	valid_0's binary_logloss: 0.0242875
# [13350]	valid_0's binary_logloss: 0.0242714
# [13400]	valid_0's binary_logloss: 0.0242526
# [13450]	valid_0's binary_logloss: 0.0242306
# [13500]	valid_0's binary_logloss: 0.0242099
# [13550]	valid_0's binary_logloss: 0.0241914
# [13600]	valid_0's binary_logloss: 0.0241738
# [13650]	valid_0's binary_logloss: 0.0241579
# [13700]	valid_0's binary_logloss: 0.0241401
# [13750]	valid_0's binary_logloss: 0.0241231
# [13800]	valid_0's binary_logloss: 0.0241049
# [13850]	valid_0's binary_logloss: 0.0240857
# [13900]	valid_0's binary_logloss: 0.0240704
# [13950]	valid_0's binary_logloss: 0.0240541
# [14000]	valid_0's binary_logloss: 0.0240276
# [14050]	valid_0's binary_logloss: 0.0240141
# [14100]	valid_0's binary_logloss: 0.0239987
# [14150]	valid_0's binary_logloss: 0.0239776
# [14200]	valid_0's binary_logloss: 0.0239557
# [14250]	valid_0's binary_logloss: 0.0239437
# [14300]	valid_0's binary_logloss: 0.023926
# [14350]	valid_0's binary_logloss: 0.0239024
# [14400]	valid_0's binary_logloss: 0.0238866
# [14450]	valid_0's binary_logloss: 0.0238676
# [14500]	valid_0's binary_logloss: 0.0238478
# [14550]	valid_0's binary_logloss: 0.0238314
# [14600]	valid_0's binary_logloss: 0.0238224
# [14650]	valid_0's binary_logloss: 0.023808
# [14700]	valid_0's binary_logloss: 0.0237999
# [14750]	valid_0's binary_logloss: 0.0237868
# [14800]	valid_0's binary_logloss: 0.0237672
# [14850]	valid_0's binary_logloss: 0.0237518
# [14900]	valid_0's binary_logloss: 0.0237378
# [14950]	valid_0's binary_logloss: 0.0237195
# [15000]	valid_0's binary_logloss: 0.0237029
# [15050]	valid_0's binary_logloss: 0.0236833
# [15100]	valid_0's binary_logloss: 0.0236666
# [15150]	valid_0's binary_logloss: 0.0236539
# [15200]	valid_0's binary_logloss: 0.0236419
# [15250]	valid_0's binary_logloss: 0.0236292
# [15300]	valid_0's binary_logloss: 0.023618
# [15350]	valid_0's binary_logloss: 0.0235977
# [15400]	valid_0's binary_logloss: 0.0235844
# [15450]	valid_0's binary_logloss: 0.0235711
# [15500]	valid_0's binary_logloss: 0.0235654
#
# == fold 1 ==
# [50]	valid_0's binary_logloss: 0.0439372
# [100]	valid_0's binary_logloss: 0.0420663
# [150]	valid_0's binary_logloss: 0.0411313
# [200]	valid_0's binary_logloss: 0.0406574
# [250]	valid_0's binary_logloss: 0.0401417
# [300]	valid_0's binary_logloss: 0.039788
# [350]	valid_0's binary_logloss: 0.0394199
# [400]	valid_0's binary_logloss: 0.0391181
# [450]	valid_0's binary_logloss: 0.0388354
# [500]	valid_0's binary_logloss: 0.038565
# [550]	valid_0's binary_logloss: 0.038333
# [600]	valid_0's binary_logloss: 0.038113
# [650]	valid_0's binary_logloss: 0.0379002
# [700]	valid_0's binary_logloss: 0.0376951
# [750]	valid_0's binary_logloss: 0.0375282
# [800]	valid_0's binary_logloss: 0.0373808
# [850]	valid_0's binary_logloss: 0.0372409
# [900]	valid_0's binary_logloss: 0.0370869
# [950]	valid_0's binary_logloss: 0.0369392
# [1000]	valid_0's binary_logloss: 0.0367925
# [1050]	valid_0's binary_logloss: 0.036608
# [1100]	valid_0's binary_logloss: 0.0364531
# [1150]	valid_0's binary_logloss: 0.036324
# [1200]	valid_0's binary_logloss: 0.0361677
# [1250]	valid_0's binary_logloss: 0.0360456
# [1300]	valid_0's binary_logloss: 0.0359402
# [1350]	valid_0's binary_logloss: 0.0357827
# [1400]	valid_0's binary_logloss: 0.0356593
# [1450]	valid_0's binary_logloss: 0.0355274
# [1500]	valid_0's binary_logloss: 0.0354015
# [1550]	valid_0's binary_logloss: 0.0352826
# [1600]	valid_0's binary_logloss: 0.035163
# [1650]	valid_0's binary_logloss: 0.0350438
# [1700]	valid_0's binary_logloss: 0.0349181
# [1750]	valid_0's binary_logloss: 0.0348295
# [1800]	valid_0's binary_logloss: 0.0347197
# [1850]	valid_0's binary_logloss: 0.0346027
# [1900]	valid_0's binary_logloss: 0.0344839
# [1950]	valid_0's binary_logloss: 0.0344017
# [2000]	valid_0's binary_logloss: 0.0343178
# [2050]	valid_0's binary_logloss: 0.0342319
# [2100]	valid_0's binary_logloss: 0.034122
# [2150]	valid_0's binary_logloss: 0.0340432
# [2200]	valid_0's binary_logloss: 0.0339444
# [2250]	valid_0's binary_logloss: 0.0338532
# [2300]	valid_0's binary_logloss: 0.0337619
# [2350]	valid_0's binary_logloss: 0.0336625
# [2400]	valid_0's binary_logloss: 0.0335601
# [2450]	valid_0's binary_logloss: 0.0334796
# [2500]	valid_0's binary_logloss: 0.0333916
# [2550]	valid_0's binary_logloss: 0.0333069
# [2600]	valid_0's binary_logloss: 0.0332162
# [2650]	valid_0's binary_logloss: 0.0331342
# [2700]	valid_0's binary_logloss: 0.0330408
# [2750]	valid_0's binary_logloss: 0.0329563
# [2800]	valid_0's binary_logloss: 0.0328923
# [2850]	valid_0's binary_logloss: 0.0328275
# [2900]	valid_0's binary_logloss: 0.0327659
# [2950]	valid_0's binary_logloss: 0.0326939
# [3000]	valid_0's binary_logloss: 0.0325929
# [3050]	valid_0's binary_logloss: 0.0325062
# [3100]	valid_0's binary_logloss: 0.0324421
# [3150]	valid_0's binary_logloss: 0.0323628
# [3200]	valid_0's binary_logloss: 0.0322902
# [3250]	valid_0's binary_logloss: 0.0322286
# [3300]	valid_0's binary_logloss: 0.0321613
# [3350]	valid_0's binary_logloss: 0.0320918
# [3400]	valid_0's binary_logloss: 0.0320229
# [3450]	valid_0's binary_logloss: 0.0319528
# [3500]	valid_0's binary_logloss: 0.031879
# [3550]	valid_0's binary_logloss: 0.0318032
# [3600]	valid_0's binary_logloss: 0.0317368
# [3650]	valid_0's binary_logloss: 0.0316572
# [3700]	valid_0's binary_logloss: 0.031585
# [3750]	valid_0's binary_logloss: 0.0315261
# [3800]	valid_0's binary_logloss: 0.0314542
# [3850]	valid_0's binary_logloss: 0.0313806
# [3900]	valid_0's binary_logloss: 0.0313163
# [3950]	valid_0's binary_logloss: 0.0312481
# [4000]	valid_0's binary_logloss: 0.0311885
# [4050]	valid_0's binary_logloss: 0.0311194
# [4100]	valid_0's binary_logloss: 0.0310684
# [4150]	valid_0's binary_logloss: 0.0310124
# [4200]	valid_0's binary_logloss: 0.0309463
# [4250]	valid_0's binary_logloss: 0.0308774
# [4300]	valid_0's binary_logloss: 0.0308017
# [4350]	valid_0's binary_logloss: 0.0307463
# [4400]	valid_0's binary_logloss: 0.0306813
# [4450]	valid_0's binary_logloss: 0.0306101
# [4500]	valid_0's binary_logloss: 0.0305633
# [4550]	valid_0's binary_logloss: 0.0305084
# [4600]	valid_0's binary_logloss: 0.0304491
# [4650]	valid_0's binary_logloss: 0.0303847
# [4700]	valid_0's binary_logloss: 0.0303209
# [4750]	valid_0's binary_logloss: 0.0302717
# [4800]	valid_0's binary_logloss: 0.0302159
# [4850]	valid_0's binary_logloss: 0.0301495
# [4900]	valid_0's binary_logloss: 0.0300993
# [4950]	valid_0's binary_logloss: 0.0300486
# [5000]	valid_0's binary_logloss: 0.0299933
# [5050]	valid_0's binary_logloss: 0.0299483
# [5100]	valid_0's binary_logloss: 0.029888
# [5150]	valid_0's binary_logloss: 0.0298267
# [5200]	valid_0's binary_logloss: 0.0297787
# [5250]	valid_0's binary_logloss: 0.0297411
# [5300]	valid_0's binary_logloss: 0.0296908
# [5350]	valid_0's binary_logloss: 0.0296321
# [5400]	valid_0's binary_logloss: 0.0295962
# [5450]	valid_0's binary_logloss: 0.0295581
# [5500]	valid_0's binary_logloss: 0.029521
# [5550]	valid_0's binary_logloss: 0.0294768
# [5600]	valid_0's binary_logloss: 0.0294246
# [5650]	valid_0's binary_logloss: 0.0293818
# [5700]	valid_0's binary_logloss: 0.0293247
# [5750]	valid_0's binary_logloss: 0.0292661
# [5800]	valid_0's binary_logloss: 0.0292132
# [5850]	valid_0's binary_logloss: 0.0291707
# [5900]	valid_0's binary_logloss: 0.0291212
# [5950]	valid_0's binary_logloss: 0.0290659
# [6000]	valid_0's binary_logloss: 0.0290137
# [6050]	valid_0's binary_logloss: 0.0289688
# [6100]	valid_0's binary_logloss: 0.0289157
# [6150]	valid_0's binary_logloss: 0.0288696
# [6200]	valid_0's binary_logloss: 0.0288158
# [6250]	valid_0's binary_logloss: 0.0287782
# [6300]	valid_0's binary_logloss: 0.0287171
# [6350]	valid_0's binary_logloss: 0.0286683
# [6400]	valid_0's binary_logloss: 0.0286157
# [6450]	valid_0's binary_logloss: 0.0285662
# [6500]	valid_0's binary_logloss: 0.0285202
# [6550]	valid_0's binary_logloss: 0.0284727
# [6600]	valid_0's binary_logloss: 0.0284288
# [6650]	valid_0's binary_logloss: 0.0283866
# [6700]	valid_0's binary_logloss: 0.0283398
# [6750]	valid_0's binary_logloss: 0.0283025
# [6800]	valid_0's binary_logloss: 0.0282499
# [6850]	valid_0's binary_logloss: 0.0282113
# [6900]	valid_0's binary_logloss: 0.0281682
# [6950]	valid_0's binary_logloss: 0.0281245
# [7000]	valid_0's binary_logloss: 0.028087
# [7050]	valid_0's binary_logloss: 0.0280484
# [7100]	valid_0's binary_logloss: 0.0280077
# [7150]	valid_0's binary_logloss: 0.0279596
# [7200]	valid_0's binary_logloss: 0.0279294
# [7250]	valid_0's binary_logloss: 0.0278886
# [7300]	valid_0's binary_logloss: 0.0278512
# [7350]	valid_0's binary_logloss: 0.0278061
# [7400]	valid_0's binary_logloss: 0.0277689
# [7450]	valid_0's binary_logloss: 0.027731
# [7500]	valid_0's binary_logloss: 0.0276936
# [7550]	valid_0's binary_logloss: 0.0276596
# [7600]	valid_0's binary_logloss: 0.0276291
# [7650]	valid_0's binary_logloss: 0.0275907
# [7700]	valid_0's binary_logloss: 0.0275593
# [7750]	valid_0's binary_logloss: 0.0275288
# [7800]	valid_0's binary_logloss: 0.0274965
# [7850]	valid_0's binary_logloss: 0.0274473
# [7900]	valid_0's binary_logloss: 0.0274096
# [7950]	valid_0's binary_logloss: 0.0273705
# [8000]	valid_0's binary_logloss: 0.0273358
# [8050]	valid_0's binary_logloss: 0.0273009
# [8100]	valid_0's binary_logloss: 0.0272649
# [8150]	valid_0's binary_logloss: 0.0272256
# [8200]	valid_0's binary_logloss: 0.027194
# [8250]	valid_0's binary_logloss: 0.0271617
# [8300]	valid_0's binary_logloss: 0.0271314
# [8350]	valid_0's binary_logloss: 0.0270889
# [8400]	valid_0's binary_logloss: 0.0270551
# [8450]	valid_0's binary_logloss: 0.0270089
# [8500]	valid_0's binary_logloss: 0.0269756
# [8550]	valid_0's binary_logloss: 0.0269536
# [8600]	valid_0's binary_logloss: 0.0269156
# [8650]	valid_0's binary_logloss: 0.026892
# [8700]	valid_0's binary_logloss: 0.0268517
# [8750]	valid_0's binary_logloss: 0.0268087
# [8800]	valid_0's binary_logloss: 0.0267697
# [8850]	valid_0's binary_logloss: 0.0267232
# [8900]	valid_0's binary_logloss: 0.026695
# [8950]	valid_0's binary_logloss: 0.0266601
# [9000]	valid_0's binary_logloss: 0.0266204
# [9050]	valid_0's binary_logloss: 0.0265838
# [9100]	valid_0's binary_logloss: 0.0265535
# [9150]	valid_0's binary_logloss: 0.0265308
# [9200]	valid_0's binary_logloss: 0.0265021
# [9250]	valid_0's binary_logloss: 0.0264743
# [9300]	valid_0's binary_logloss: 0.0264419
# [9350]	valid_0's binary_logloss: 0.026407
# [9400]	valid_0's binary_logloss: 0.0263712
# [9450]	valid_0's binary_logloss: 0.0263391
# [9500]	valid_0's binary_logloss: 0.0263061
# [9550]	valid_0's binary_logloss: 0.026278
# [9600]	valid_0's binary_logloss: 0.0262484
# [9650]	valid_0's binary_logloss: 0.0262228
# [9700]	valid_0's binary_logloss: 0.0261921
# [9750]	valid_0's binary_logloss: 0.0261685
# [9800]	valid_0's binary_logloss: 0.0261333
# [9850]	valid_0's binary_logloss: 0.026096
# [9900]	valid_0's binary_logloss: 0.0260682
# [9950]	valid_0's binary_logloss: 0.0260402
# [10000]	valid_0's binary_logloss: 0.0260071
# [10050]	valid_0's binary_logloss: 0.0259675
# [10100]	valid_0's binary_logloss: 0.0259377
# [10150]	valid_0's binary_logloss: 0.0258983
# [10200]	valid_0's binary_logloss: 0.0258788
# [10250]	valid_0's binary_logloss: 0.0258457
# [10300]	valid_0's binary_logloss: 0.0258173
# [10350]	valid_0's binary_logloss: 0.0257847
# [10400]	valid_0's binary_logloss: 0.0257657
# [10450]	valid_0's binary_logloss: 0.0257379
# [10500]	valid_0's binary_logloss: 0.025704
# [10550]	valid_0's binary_logloss: 0.0256779
# [10600]	valid_0's binary_logloss: 0.0256595
# [10650]	valid_0's binary_logloss: 0.025636
# [10700]	valid_0's binary_logloss: 0.0256139
# [10750]	valid_0's binary_logloss: 0.0255893
# [10800]	valid_0's binary_logloss: 0.0255588
# [10850]	valid_0's binary_logloss: 0.0255327
# [10900]	valid_0's binary_logloss: 0.0255153
# [10950]	valid_0's binary_logloss: 0.0254896
# [11000]	valid_0's binary_logloss: 0.0254636
# [11050]	valid_0's binary_logloss: 0.0254343
# [11100]	valid_0's binary_logloss: 0.0254048
# [11150]	valid_0's binary_logloss: 0.025394
# [11200]	valid_0's binary_logloss: 0.0253643
# [11250]	valid_0's binary_logloss: 0.0253427
# [11300]	valid_0's binary_logloss: 0.0253118
# [11350]	valid_0's binary_logloss: 0.0252837
# [11400]	valid_0's binary_logloss: 0.0252625
# [11450]	valid_0's binary_logloss: 0.025239
# [11500]	valid_0's binary_logloss: 0.0252089
# [11550]	valid_0's binary_logloss: 0.0251811
# [11600]	valid_0's binary_logloss: 0.0251577
# [11650]	valid_0's binary_logloss: 0.0251363
# [11700]	valid_0's binary_logloss: 0.0251095
# [11750]	valid_0's binary_logloss: 0.0250839
# [11800]	valid_0's binary_logloss: 0.025059
# [11850]	valid_0's binary_logloss: 0.0250281
# [11900]	valid_0's binary_logloss: 0.0250028
# [11950]	valid_0's binary_logloss: 0.0249869
# [12000]	valid_0's binary_logloss: 0.0249604
# [12050]	valid_0's binary_logloss: 0.024938
# [12100]	valid_0's binary_logloss: 0.0249141
# [12150]	valid_0's binary_logloss: 0.0248967
# [12200]	valid_0's binary_logloss: 0.0248733
# [12250]	valid_0's binary_logloss: 0.0248529
# [12300]	valid_0's binary_logloss: 0.0248324
# [12350]	valid_0's binary_logloss: 0.0248134
# [12400]	valid_0's binary_logloss: 0.024795
# [12450]	valid_0's binary_logloss: 0.0247711
# [12500]	valid_0's binary_logloss: 0.0247505
# [12550]	valid_0's binary_logloss: 0.0247268
# [12600]	valid_0's binary_logloss: 0.0247067
# [12650]	valid_0's binary_logloss: 0.0246835
# [12700]	valid_0's binary_logloss: 0.0246704
# [12750]	valid_0's binary_logloss: 0.0246488
# [12800]	valid_0's binary_logloss: 0.0246324
# [12850]	valid_0's binary_logloss: 0.0246119
# [12900]	valid_0's binary_logloss: 0.0245931
# [12950]	valid_0's binary_logloss: 0.0245671
# [13000]	valid_0's binary_logloss: 0.0245486
# [13050]	valid_0's binary_logloss: 0.0245366
# [13100]	valid_0's binary_logloss: 0.0245225
# [13150]	valid_0's binary_logloss: 0.0244956
# [13200]	valid_0's binary_logloss: 0.0244746
# [13250]	valid_0's binary_logloss: 0.0244568
# [13300]	valid_0's binary_logloss: 0.0244382
# [13350]	valid_0's binary_logloss: 0.0244208
# [13400]	valid_0's binary_logloss: 0.0243975
# [13450]	valid_0's binary_logloss: 0.0243812
# [13500]	valid_0's binary_logloss: 0.0243655
# [13550]	valid_0's binary_logloss: 0.0243496
# [13600]	valid_0's binary_logloss: 0.0243304
# [13650]	valid_0's binary_logloss: 0.0243097
# [13700]	valid_0's binary_logloss: 0.0242941
# [13750]	valid_0's binary_logloss: 0.0242746
# [13800]	valid_0's binary_logloss: 0.0242494
# [13850]	valid_0's binary_logloss: 0.0242341
# [13900]	valid_0's binary_logloss: 0.024215
# [13950]	valid_0's binary_logloss: 0.0241956
# [14000]	valid_0's binary_logloss: 0.0241796
# [14050]	valid_0's binary_logloss: 0.0241644
# [14100]	valid_0's binary_logloss: 0.0241459
# [14150]	valid_0's binary_logloss: 0.024138
# [14200]	valid_0's binary_logloss: 0.024117
# [14250]	valid_0's binary_logloss: 0.0240974
# [14300]	valid_0's binary_logloss: 0.0240803
# [14350]	valid_0's binary_logloss: 0.0240614
# [14400]	valid_0's binary_logloss: 0.0240425
# [14450]	valid_0's binary_logloss: 0.0240291
# [14500]	valid_0's binary_logloss: 0.0240085
# [14550]	valid_0's binary_logloss: 0.0239934
# [14600]	valid_0's binary_logloss: 0.0239844
# [14650]	valid_0's binary_logloss: 0.023964
# [14700]	valid_0's binary_logloss: 0.0239499
# [14750]	valid_0's binary_logloss: 0.0239329
# [14800]	valid_0's binary_logloss: 0.0239086
# [14850]	valid_0's binary_logloss: 0.0238928
# [14900]	valid_0's binary_logloss: 0.0238786
# [14950]	valid_0's binary_logloss: 0.0238706
# [15000]	valid_0's binary_logloss: 0.0238572
# [15050]	valid_0's binary_logloss: 0.0238385
# [15100]	valid_0's binary_logloss: 0.0238252
# [15150]	valid_0's binary_logloss: 0.0238094
# [15200]	valid_0's binary_logloss: 0.0237891
# [15250]	valid_0's binary_logloss: 0.0237758
# [15300]	valid_0's binary_logloss: 0.0237599
# [15350]	valid_0's binary_logloss: 0.0237538
# [15400]	valid_0's binary_logloss: 0.0237448
#
# == fold 2 ==
# [50]	valid_0's binary_logloss: 0.0436489
# [100]	valid_0's binary_logloss: 0.041893
# [150]	valid_0's binary_logloss: 0.0411351
# [200]	valid_0's binary_logloss: 0.0405578
# [250]	valid_0's binary_logloss: 0.0401352
# [300]	valid_0's binary_logloss: 0.039723
# [350]	valid_0's binary_logloss: 0.0394002
# [400]	valid_0's binary_logloss: 0.0391411
# [450]	valid_0's binary_logloss: 0.0388216
# [500]	valid_0's binary_logloss: 0.038536
# [550]	valid_0's binary_logloss: 0.0383124
# [600]	valid_0's binary_logloss: 0.0380338
# [650]	valid_0's binary_logloss: 0.0378067
# [700]	valid_0's binary_logloss: 0.037624
# [750]	valid_0's binary_logloss: 0.0374123
# [800]	valid_0's binary_logloss: 0.0372166
# [850]	valid_0's binary_logloss: 0.0370413
# [900]	valid_0's binary_logloss: 0.036883
# [950]	valid_0's binary_logloss: 0.0367028
# [1000]	valid_0's binary_logloss: 0.0365354
# [1050]	valid_0's binary_logloss: 0.0363801
# [1100]	valid_0's binary_logloss: 0.0362391
# [1150]	valid_0's binary_logloss: 0.0361081
# [1200]	valid_0's binary_logloss: 0.0359894
# [1250]	valid_0's binary_logloss: 0.0358576
# [1300]	valid_0's binary_logloss: 0.0357251
# [1350]	valid_0's binary_logloss: 0.0355747
# [1400]	valid_0's binary_logloss: 0.0354562
# [1450]	valid_0's binary_logloss: 0.0353038
# [1500]	valid_0's binary_logloss: 0.0351575
# [1550]	valid_0's binary_logloss: 0.035032
# [1600]	valid_0's binary_logloss: 0.0349118
# [1650]	valid_0's binary_logloss: 0.0347896
# [1700]	valid_0's binary_logloss: 0.034701
# [1750]	valid_0's binary_logloss: 0.034604
# [1800]	valid_0's binary_logloss: 0.0344798
# [1850]	valid_0's binary_logloss: 0.0343714
# [1900]	valid_0's binary_logloss: 0.0342875
# [1950]	valid_0's binary_logloss: 0.0341786
# [2000]	valid_0's binary_logloss: 0.0340868
# [2050]	valid_0's binary_logloss: 0.0339873
# [2100]	valid_0's binary_logloss: 0.0338972
# [2150]	valid_0's binary_logloss: 0.0337981
# [2200]	valid_0's binary_logloss: 0.0337004
# [2250]	valid_0's binary_logloss: 0.0336103
# [2300]	valid_0's binary_logloss: 0.0335132
# [2350]	valid_0's binary_logloss: 0.0334186
# [2400]	valid_0's binary_logloss: 0.0333251
# [2450]	valid_0's binary_logloss: 0.0332185
# [2500]	valid_0's binary_logloss: 0.0331226
# [2550]	valid_0's binary_logloss: 0.0330416
# [2600]	valid_0's binary_logloss: 0.0329582
# [2650]	valid_0's binary_logloss: 0.0328579
# [2700]	valid_0's binary_logloss: 0.03277
# [2750]	valid_0's binary_logloss: 0.0326902
# [2800]	valid_0's binary_logloss: 0.032593
# [2850]	valid_0's binary_logloss: 0.0325193
# [2900]	valid_0's binary_logloss: 0.0324415
# [2950]	valid_0's binary_logloss: 0.0323658
# [3000]	valid_0's binary_logloss: 0.0322921
# [3050]	valid_0's binary_logloss: 0.0321971
# [3100]	valid_0's binary_logloss: 0.0321102
# [3150]	valid_0's binary_logloss: 0.0320509
# [3200]	valid_0's binary_logloss: 0.0319881
# [3250]	valid_0's binary_logloss: 0.0319166
# [3300]	valid_0's binary_logloss: 0.0318435
# [3350]	valid_0's binary_logloss: 0.0317783
# [3400]	valid_0's binary_logloss: 0.0317121
# [3450]	valid_0's binary_logloss: 0.031641
# [3500]	valid_0's binary_logloss: 0.0315691
# [3550]	valid_0's binary_logloss: 0.031503
# [3600]	valid_0's binary_logloss: 0.0314406
# [3650]	valid_0's binary_logloss: 0.0313786
# [3700]	valid_0's binary_logloss: 0.0312952
# [3750]	valid_0's binary_logloss: 0.031219
# [3800]	valid_0's binary_logloss: 0.031147
# [3850]	valid_0's binary_logloss: 0.0310811
# [3900]	valid_0's binary_logloss: 0.0310001
# [3950]	valid_0's binary_logloss: 0.0309257
# [4000]	valid_0's binary_logloss: 0.0308593
# [4050]	valid_0's binary_logloss: 0.0307819
# [4100]	valid_0's binary_logloss: 0.0307207
# [4150]	valid_0's binary_logloss: 0.0306492
# [4200]	valid_0's binary_logloss: 0.030581
# [4250]	valid_0's binary_logloss: 0.0305224
# [4300]	valid_0's binary_logloss: 0.0304487
# [4350]	valid_0's binary_logloss: 0.0303933
# [4400]	valid_0's binary_logloss: 0.030342
# [4450]	valid_0's binary_logloss: 0.0302663
# [4500]	valid_0's binary_logloss: 0.0302091
# [4550]	valid_0's binary_logloss: 0.0301533
# [4600]	valid_0's binary_logloss: 0.0300866
# [4650]	valid_0's binary_logloss: 0.0300313
# [4700]	valid_0's binary_logloss: 0.029991
# [4750]	valid_0's binary_logloss: 0.0299342
# [4800]	valid_0's binary_logloss: 0.0298784
# [4850]	valid_0's binary_logloss: 0.0298183
# [4900]	valid_0's binary_logloss: 0.0297544
# [4950]	valid_0's binary_logloss: 0.0296961
# [5000]	valid_0's binary_logloss: 0.0296356
# [5050]	valid_0's binary_logloss: 0.0295618
# [5100]	valid_0's binary_logloss: 0.0295013
# [5150]	valid_0's binary_logloss: 0.0294407
# [5200]	valid_0's binary_logloss: 0.0293909
# [5250]	valid_0's binary_logloss: 0.0293375
# [5300]	valid_0's binary_logloss: 0.0292728
# [5350]	valid_0's binary_logloss: 0.0292224
# [5400]	valid_0's binary_logloss: 0.0291702
# [5450]	valid_0's binary_logloss: 0.0291313
# [5500]	valid_0's binary_logloss: 0.0290902
# [5550]	valid_0's binary_logloss: 0.0290305
# [5600]	valid_0's binary_logloss: 0.0289722
# [5650]	valid_0's binary_logloss: 0.0289301
# [5700]	valid_0's binary_logloss: 0.0288889
# [5750]	valid_0's binary_logloss: 0.028843
# [5800]	valid_0's binary_logloss: 0.0287974
# [5850]	valid_0's binary_logloss: 0.0287537
# [5900]	valid_0's binary_logloss: 0.0287053
# [5950]	valid_0's binary_logloss: 0.0286678
# [6000]	valid_0's binary_logloss: 0.0286172
# [6050]	valid_0's binary_logloss: 0.0285661
# [6100]	valid_0's binary_logloss: 0.0285363
# [6150]	valid_0's binary_logloss: 0.0284945
# [6200]	valid_0's binary_logloss: 0.0284613
# [6250]	valid_0's binary_logloss: 0.0284084
# [6300]	valid_0's binary_logloss: 0.0283574
# [6350]	valid_0's binary_logloss: 0.0283072
# [6400]	valid_0's binary_logloss: 0.0282664
# [6450]	valid_0's binary_logloss: 0.0282234
# [6500]	valid_0's binary_logloss: 0.0281814
# [6550]	valid_0's binary_logloss: 0.0281395
# [6600]	valid_0's binary_logloss: 0.0281064
# [6650]	valid_0's binary_logloss: 0.0280605
# [6700]	valid_0's binary_logloss: 0.0280137
# [6750]	valid_0's binary_logloss: 0.0279819
# [6800]	valid_0's binary_logloss: 0.0279279
# [6850]	valid_0's binary_logloss: 0.0278823
# [6900]	valid_0's binary_logloss: 0.0278377
# [6950]	valid_0's binary_logloss: 0.0277917
# [7000]	valid_0's binary_logloss: 0.0277516
# [7050]	valid_0's binary_logloss: 0.0277081
# [7100]	valid_0's binary_logloss: 0.0276603
# [7150]	valid_0's binary_logloss: 0.0276203
# [7200]	valid_0's binary_logloss: 0.0275823
# [7250]	valid_0's binary_logloss: 0.0275425
# [7300]	valid_0's binary_logloss: 0.0275019
# [7350]	valid_0's binary_logloss: 0.0274617
# [7400]	valid_0's binary_logloss: 0.0274325
# [7450]	valid_0's binary_logloss: 0.0273989
# [7500]	valid_0's binary_logloss: 0.0273653
# [7550]	valid_0's binary_logloss: 0.0273266
# [7600]	valid_0's binary_logloss: 0.0272868
# [7650]	valid_0's binary_logloss: 0.0272388
# [7700]	valid_0's binary_logloss: 0.0271991
# [7750]	valid_0's binary_logloss: 0.0271645
# [7800]	valid_0's binary_logloss: 0.0271227
# [7850]	valid_0's binary_logloss: 0.0270717
# [7900]	valid_0's binary_logloss: 0.0270323
# [7950]	valid_0's binary_logloss: 0.0269914
# [8000]	valid_0's binary_logloss: 0.0269627
# [8050]	valid_0's binary_logloss: 0.0269296
# [8100]	valid_0's binary_logloss: 0.0268835
# [8150]	valid_0's binary_logloss: 0.0268438
# [8200]	valid_0's binary_logloss: 0.0268107
# [8250]	valid_0's binary_logloss: 0.0267821
# [8300]	valid_0's binary_logloss: 0.026741
# [8350]	valid_0's binary_logloss: 0.0266971
# [8400]	valid_0's binary_logloss: 0.0266709
# [8450]	valid_0's binary_logloss: 0.0266311
# [8500]	valid_0's binary_logloss: 0.0265992
# [8550]	valid_0's binary_logloss: 0.0265672
# [8600]	valid_0's binary_logloss: 0.0265312
# [8650]	valid_0's binary_logloss: 0.0264868
# [8700]	valid_0's binary_logloss: 0.0264538
# [8750]	valid_0's binary_logloss: 0.0264239
# [8800]	valid_0's binary_logloss: 0.0263825
# [8850]	valid_0's binary_logloss: 0.0263472
# [8900]	valid_0's binary_logloss: 0.0263126
# [8950]	valid_0's binary_logloss: 0.0262696
# [9000]	valid_0's binary_logloss: 0.026238
# [9050]	valid_0's binary_logloss: 0.0262024
# [9100]	valid_0's binary_logloss: 0.0261701
# [9150]	valid_0's binary_logloss: 0.0261387
# [9200]	valid_0's binary_logloss: 0.0261086
# [9250]	valid_0's binary_logloss: 0.0260806
# [9300]	valid_0's binary_logloss: 0.0260399
# [9350]	valid_0's binary_logloss: 0.0260161
# [9400]	valid_0's binary_logloss: 0.025983
# [9450]	valid_0's binary_logloss: 0.0259437
# [9500]	valid_0's binary_logloss: 0.0259175
# [9550]	valid_0's binary_logloss: 0.0258904
# [9600]	valid_0's binary_logloss: 0.025856
# [9650]	valid_0's binary_logloss: 0.0258316
# [9700]	valid_0's binary_logloss: 0.0258043
# [9750]	valid_0's binary_logloss: 0.0257665
# [9800]	valid_0's binary_logloss: 0.0257293
# [9850]	valid_0's binary_logloss: 0.0256992
# [9900]	valid_0's binary_logloss: 0.0256768
# [9950]	valid_0's binary_logloss: 0.0256473
# [10000]	valid_0's binary_logloss: 0.025618
# [10050]	valid_0's binary_logloss: 0.0255849
# [10100]	valid_0's binary_logloss: 0.0255554
# [10150]	valid_0's binary_logloss: 0.0255299
# [10200]	valid_0's binary_logloss: 0.0255047
# [10250]	valid_0's binary_logloss: 0.0254813
# [10300]	valid_0's binary_logloss: 0.0254558
# [10350]	valid_0's binary_logloss: 0.0254326
# [10400]	valid_0's binary_logloss: 0.0254125
# [10450]	valid_0's binary_logloss: 0.0253802
# [10500]	valid_0's binary_logloss: 0.0253583
# [10550]	valid_0's binary_logloss: 0.02533
# [10600]	valid_0's binary_logloss: 0.0253016
# [10650]	valid_0's binary_logloss: 0.0252852
# [10700]	valid_0's binary_logloss: 0.0252579
# [10750]	valid_0's binary_logloss: 0.0252257
# [10800]	valid_0's binary_logloss: 0.0251992
# [10850]	valid_0's binary_logloss: 0.0251789
# [10900]	valid_0's binary_logloss: 0.0251421
# [10950]	valid_0's binary_logloss: 0.025124
# [11000]	valid_0's binary_logloss: 0.025104
# [11050]	valid_0's binary_logloss: 0.0250775
# [11100]	valid_0's binary_logloss: 0.0250528
# [11150]	valid_0's binary_logloss: 0.0250313
# [11200]	valid_0's binary_logloss: 0.0250022
# [11250]	valid_0's binary_logloss: 0.0249808
# [11300]	valid_0's binary_logloss: 0.0249601
# [11350]	valid_0's binary_logloss: 0.0249285
# [11400]	valid_0's binary_logloss: 0.0249032
# [11450]	valid_0's binary_logloss: 0.0248785
# [11500]	valid_0's binary_logloss: 0.0248435
# [11550]	valid_0's binary_logloss: 0.0248098
# [11600]	valid_0's binary_logloss: 0.0247865
# [11650]	valid_0's binary_logloss: 0.024761
# [11700]	valid_0's binary_logloss: 0.0247345
# [11750]	valid_0's binary_logloss: 0.0247206
# [11800]	valid_0's binary_logloss: 0.0247025
# [11850]	valid_0's binary_logloss: 0.0246739
# [11900]	valid_0's binary_logloss: 0.0246481
# [11950]	valid_0's binary_logloss: 0.024624
# [12000]	valid_0's binary_logloss: 0.0246072
# [12050]	valid_0's binary_logloss: 0.0245884
# [12100]	valid_0's binary_logloss: 0.0245641
# [12150]	valid_0's binary_logloss: 0.0245359
# [12200]	valid_0's binary_logloss: 0.0245122
# [12250]	valid_0's binary_logloss: 0.0244936
# [12300]	valid_0's binary_logloss: 0.0244813
# [12350]	valid_0's binary_logloss: 0.0244626
# [12400]	valid_0's binary_logloss: 0.0244398
# [12450]	valid_0's binary_logloss: 0.0244175
# [12500]	valid_0's binary_logloss: 0.0243949
# [12550]	valid_0's binary_logloss: 0.0243754
# [12600]	valid_0's binary_logloss: 0.0243481
# [12650]	valid_0's binary_logloss: 0.0243281
# [12700]	valid_0's binary_logloss: 0.024304
# [12750]	valid_0's binary_logloss: 0.0242788
# [12800]	valid_0's binary_logloss: 0.0242584
# [12850]	valid_0's binary_logloss: 0.0242278
# [12900]	valid_0's binary_logloss: 0.024207
# [12950]	valid_0's binary_logloss: 0.0241892
# [13000]	valid_0's binary_logloss: 0.0241715
# [13050]	valid_0's binary_logloss: 0.024151
# [13100]	valid_0's binary_logloss: 0.0241263
# [13150]	valid_0's binary_logloss: 0.0241079
# [13200]	valid_0's binary_logloss: 0.0240861
# [13250]	valid_0's binary_logloss: 0.0240699
# [13300]	valid_0's binary_logloss: 0.024045
# [13350]	valid_0's binary_logloss: 0.0240281
# [13400]	valid_0's binary_logloss: 0.0240103
# [13450]	valid_0's binary_logloss: 0.0239879
# [13500]	valid_0's binary_logloss: 0.0239666
# [13550]	valid_0's binary_logloss: 0.0239523
# [13600]	valid_0's binary_logloss: 0.0239408
# [13650]	valid_0's binary_logloss: 0.0239271
# [13700]	valid_0's binary_logloss: 0.0239053
# [13750]	valid_0's binary_logloss: 0.0238815
# [13800]	valid_0's binary_logloss: 0.0238622
# [13850]	valid_0's binary_logloss: 0.0238458
# [13900]	valid_0's binary_logloss: 0.0238209
# [13950]	valid_0's binary_logloss: 0.0237984
# [14000]	valid_0's binary_logloss: 0.0237821
# [14050]	valid_0's binary_logloss: 0.0237659
# [14100]	valid_0's binary_logloss: 0.0237533
# [14150]	valid_0's binary_logloss: 0.0237343
# [14200]	valid_0's binary_logloss: 0.0237217
# [14250]	valid_0's binary_logloss: 0.0237072
# [14300]	valid_0's binary_logloss: 0.0236934
# [14350]	valid_0's binary_logloss: 0.0236765
# [14400]	valid_0's binary_logloss: 0.0236631
# [14450]	valid_0's binary_logloss: 0.0236438
# [14500]	valid_0's binary_logloss: 0.0236197
# [14550]	valid_0's binary_logloss: 0.0236033
# [14600]	valid_0's binary_logloss: 0.0235845
# [14650]	valid_0's binary_logloss: 0.023565
# [14700]	valid_0's binary_logloss: 0.023552
# [14750]	valid_0's binary_logloss: 0.0235371
# [14800]	valid_0's binary_logloss: 0.0235168
# [14850]	valid_0's binary_logloss: 0.0234963
# [14900]	valid_0's binary_logloss: 0.023469
# [14950]	valid_0's binary_logloss: 0.0234516
# [15000]	valid_0's binary_logloss: 0.0234391
# [15050]	valid_0's binary_logloss: 0.023423
# [15100]	valid_0's binary_logloss: 0.0234073
# [15150]	valid_0's binary_logloss: 0.0233878
# [15200]	valid_0's binary_logloss: 0.0233717
# [15250]	valid_0's binary_logloss: 0.0233616
# [15300]	valid_0's binary_logloss: 0.0233487
# [15350]	valid_0's binary_logloss: 0.0233325
# [15400]	valid_0's binary_logloss: 0.02332
# [15450]	valid_0's binary_logloss: 0.0233017
# [15500]	valid_0's binary_logloss: 0.0232846
# [15550]	valid_0's binary_logloss: 0.0232706
# [15600]	valid_0's binary_logloss: 0.0232519
# [15650]	valid_0's binary_logloss: 0.023238
# [15700]	valid_0's binary_logloss: 0.0232288
# [15750]	valid_0's binary_logloss: 0.0232104
# [15800]	valid_0's binary_logloss: 0.0231969
# [15850]	valid_0's binary_logloss: 0.0231847
# [15900]	valid_0's binary_logloss: 0.0231658
# [15950]	valid_0's binary_logloss: 0.0231513
# [16000]	valid_0's binary_logloss: 0.0231413
# [16050]	valid_0's binary_logloss: 0.0231261
# [16100]	valid_0's binary_logloss: 0.0231141
#
# == fold 3 ==
# [50]	valid_0's binary_logloss: 0.0433428
# [100]	valid_0's binary_logloss: 0.0415318
# [150]	valid_0's binary_logloss: 0.0406742
# [200]	valid_0's binary_logloss: 0.0400875
# [250]	valid_0's binary_logloss: 0.0396689
# [300]	valid_0's binary_logloss: 0.03927
# [350]	valid_0's binary_logloss: 0.0389865
# [400]	valid_0's binary_logloss: 0.0386606
# [450]	valid_0's binary_logloss: 0.0383581
# [500]	valid_0's binary_logloss: 0.0381479
# [550]	valid_0's binary_logloss: 0.0379065
# [600]	valid_0's binary_logloss: 0.0376734
# [650]	valid_0's binary_logloss: 0.037466
# [700]	valid_0's binary_logloss: 0.0372998
# [750]	valid_0's binary_logloss: 0.0371146
# [800]	valid_0's binary_logloss: 0.0369228
# [850]	valid_0's binary_logloss: 0.0367656
# [900]	valid_0's binary_logloss: 0.0365899
# [950]	valid_0's binary_logloss: 0.0364358
# [1000]	valid_0's binary_logloss: 0.0362883
# [1050]	valid_0's binary_logloss: 0.0361021
# [1100]	valid_0's binary_logloss: 0.03596
# [1150]	valid_0's binary_logloss: 0.0358147
# [1200]	valid_0's binary_logloss: 0.0356774
# [1250]	valid_0's binary_logloss: 0.0355623
# [1300]	valid_0's binary_logloss: 0.0354329
# [1350]	valid_0's binary_logloss: 0.0353142
# [1400]	valid_0's binary_logloss: 0.0351832
# [1450]	valid_0's binary_logloss: 0.0350501
# [1500]	valid_0's binary_logloss: 0.0349281
# [1550]	valid_0's binary_logloss: 0.0348099
# [1600]	valid_0's binary_logloss: 0.0347064
# [1650]	valid_0's binary_logloss: 0.0346021
# [1700]	valid_0's binary_logloss: 0.0344842
# [1750]	valid_0's binary_logloss: 0.0343624
# [1800]	valid_0's binary_logloss: 0.0342522
# [1850]	valid_0's binary_logloss: 0.0341654
# [1900]	valid_0's binary_logloss: 0.0340633
# [1950]	valid_0's binary_logloss: 0.0339482
# [2000]	valid_0's binary_logloss: 0.0338459
# [2050]	valid_0's binary_logloss: 0.0337403
# [2100]	valid_0's binary_logloss: 0.0336438
# [2150]	valid_0's binary_logloss: 0.0335491
# [2200]	valid_0's binary_logloss: 0.0334313
# [2250]	valid_0's binary_logloss: 0.0333275
# [2300]	valid_0's binary_logloss: 0.0332196
# [2350]	valid_0's binary_logloss: 0.033124
# [2400]	valid_0's binary_logloss: 0.0330336
# [2450]	valid_0's binary_logloss: 0.0329401
# [2500]	valid_0's binary_logloss: 0.0328532
# [2550]	valid_0's binary_logloss: 0.032771
# [2600]	valid_0's binary_logloss: 0.032695
# [2650]	valid_0's binary_logloss: 0.0326048
# [2700]	valid_0's binary_logloss: 0.0325126
# [2750]	valid_0's binary_logloss: 0.0324224
# [2800]	valid_0's binary_logloss: 0.0323296
# [2850]	valid_0's binary_logloss: 0.0322438
# [2900]	valid_0's binary_logloss: 0.0321781
# [2950]	valid_0's binary_logloss: 0.0321061
# [3000]	valid_0's binary_logloss: 0.0320271
# [3050]	valid_0's binary_logloss: 0.0319521
# [3100]	valid_0's binary_logloss: 0.031878
# [3150]	valid_0's binary_logloss: 0.0317995
# [3200]	valid_0's binary_logloss: 0.0317164
# [3250]	valid_0's binary_logloss: 0.0316326
# [3300]	valid_0's binary_logloss: 0.0315565
# [3350]	valid_0's binary_logloss: 0.0314778
# [3400]	valid_0's binary_logloss: 0.0314075
# [3450]	valid_0's binary_logloss: 0.0313329
# [3500]	valid_0's binary_logloss: 0.0312538
# [3550]	valid_0's binary_logloss: 0.0311856
# [3600]	valid_0's binary_logloss: 0.0311135
# [3650]	valid_0's binary_logloss: 0.0310431
# [3700]	valid_0's binary_logloss: 0.0309646
# [3750]	valid_0's binary_logloss: 0.0309043
# [3800]	valid_0's binary_logloss: 0.0308448
# [3850]	valid_0's binary_logloss: 0.0307888
# [3900]	valid_0's binary_logloss: 0.0307263
# [3950]	valid_0's binary_logloss: 0.0306623
# [4000]	valid_0's binary_logloss: 0.0305878
# [4050]	valid_0's binary_logloss: 0.0305312
# [4100]	valid_0's binary_logloss: 0.0304628
# [4150]	valid_0's binary_logloss: 0.0303938
# [4200]	valid_0's binary_logloss: 0.0303104
# [4250]	valid_0's binary_logloss: 0.0302616
# [4300]	valid_0's binary_logloss: 0.0301987
# [4350]	valid_0's binary_logloss: 0.0301379
# [4400]	valid_0's binary_logloss: 0.0300777
# [4450]	valid_0's binary_logloss: 0.0300209
# [4500]	valid_0's binary_logloss: 0.0299744
# [4550]	valid_0's binary_logloss: 0.0299266
# [4600]	valid_0's binary_logloss: 0.029869
# [4650]	valid_0's binary_logloss: 0.0298135
# [4700]	valid_0's binary_logloss: 0.0297515
# [4750]	valid_0's binary_logloss: 0.029693
# [4800]	valid_0's binary_logloss: 0.0296247
# [4850]	valid_0's binary_logloss: 0.0295648
# [4900]	valid_0's binary_logloss: 0.0295141
# [4950]	valid_0's binary_logloss: 0.0294568
# [5000]	valid_0's binary_logloss: 0.0294043
# [5050]	valid_0's binary_logloss: 0.0293529
# [5100]	valid_0's binary_logloss: 0.0292981
# [5150]	valid_0's binary_logloss: 0.0292491
# [5200]	valid_0's binary_logloss: 0.0291881
# [5250]	valid_0's binary_logloss: 0.0291367
# [5300]	valid_0's binary_logloss: 0.0290862
# [5350]	valid_0's binary_logloss: 0.0290426
# [5400]	valid_0's binary_logloss: 0.0289938
# [5450]	valid_0's binary_logloss: 0.0289507
# [5500]	valid_0's binary_logloss: 0.0288948
# [5550]	valid_0's binary_logloss: 0.0288473
# [5600]	valid_0's binary_logloss: 0.0288033
# [5650]	valid_0's binary_logloss: 0.0287527
# [5700]	valid_0's binary_logloss: 0.0287016
# [5750]	valid_0's binary_logloss: 0.0286549
# [5800]	valid_0's binary_logloss: 0.0286079
# [5850]	valid_0's binary_logloss: 0.0285691
# [5900]	valid_0's binary_logloss: 0.0285168
# [5950]	valid_0's binary_logloss: 0.0284643
# [6000]	valid_0's binary_logloss: 0.0284143
# [6050]	valid_0's binary_logloss: 0.0283578
# [6100]	valid_0's binary_logloss: 0.0283188
# [6150]	valid_0's binary_logloss: 0.0282716
# [6200]	valid_0's binary_logloss: 0.0282219
# [6250]	valid_0's binary_logloss: 0.0281795
# [6300]	valid_0's binary_logloss: 0.0281225
# [6350]	valid_0's binary_logloss: 0.0280805
# [6400]	valid_0's binary_logloss: 0.0280264
# [6450]	valid_0's binary_logloss: 0.027983
# [6500]	valid_0's binary_logloss: 0.0279396
# [6550]	valid_0's binary_logloss: 0.027895
# [6600]	valid_0's binary_logloss: 0.0278497
# [6650]	valid_0's binary_logloss: 0.0278066
# [6700]	valid_0's binary_logloss: 0.0277674
# [6750]	valid_0's binary_logloss: 0.0277224
# [6800]	valid_0's binary_logloss: 0.0276813
# [6850]	valid_0's binary_logloss: 0.0276343
# [6900]	valid_0's binary_logloss: 0.0275949
# [6950]	valid_0's binary_logloss: 0.0275543
# [7000]	valid_0's binary_logloss: 0.0275161
# [7050]	valid_0's binary_logloss: 0.0274828
# [7100]	valid_0's binary_logloss: 0.0274452
# [7150]	valid_0's binary_logloss: 0.0274168
# [7200]	valid_0's binary_logloss: 0.027387
# [7250]	valid_0's binary_logloss: 0.0273467
# [7300]	valid_0's binary_logloss: 0.0273094
# [7350]	valid_0's binary_logloss: 0.0272735
# [7400]	valid_0's binary_logloss: 0.0272387
# [7450]	valid_0's binary_logloss: 0.0272099
# [7500]	valid_0's binary_logloss: 0.0271705
# [7550]	valid_0's binary_logloss: 0.0271233
# [7600]	valid_0's binary_logloss: 0.0270944
# [7650]	valid_0's binary_logloss: 0.0270692
# [7700]	valid_0's binary_logloss: 0.0270316
# [7750]	valid_0's binary_logloss: 0.0269924
# [7800]	valid_0's binary_logloss: 0.0269509
# [7850]	valid_0's binary_logloss: 0.0269131
# [7900]	valid_0's binary_logloss: 0.0268789
# [7950]	valid_0's binary_logloss: 0.0268524
# [8000]	valid_0's binary_logloss: 0.026812
# [8050]	valid_0's binary_logloss: 0.0267705
# [8100]	valid_0's binary_logloss: 0.0267309
# [8150]	valid_0's binary_logloss: 0.026695
# [8200]	valid_0's binary_logloss: 0.0266676
# [8250]	valid_0's binary_logloss: 0.0266391
# [8300]	valid_0's binary_logloss: 0.0266039
# [8350]	valid_0's binary_logloss: 0.026568
# [8400]	valid_0's binary_logloss: 0.0265347
# [8450]	valid_0's binary_logloss: 0.0264936
# [8500]	valid_0's binary_logloss: 0.02646
# [8550]	valid_0's binary_logloss: 0.0264375
# [8600]	valid_0's binary_logloss: 0.0264044
# [8650]	valid_0's binary_logloss: 0.026381
# [8700]	valid_0's binary_logloss: 0.0263397
# [8750]	valid_0's binary_logloss: 0.0263068
# [8800]	valid_0's binary_logloss: 0.0262725
# [8850]	valid_0's binary_logloss: 0.0262357
# [8900]	valid_0's binary_logloss: 0.0261988
# [8950]	valid_0's binary_logloss: 0.0261699
# [9000]	valid_0's binary_logloss: 0.0261428
# [9050]	valid_0's binary_logloss: 0.0261109
# [9100]	valid_0's binary_logloss: 0.0260681
# [9150]	valid_0's binary_logloss: 0.0260379
# [9200]	valid_0's binary_logloss: 0.0260039
# [9250]	valid_0's binary_logloss: 0.0259823
# [9300]	valid_0's binary_logloss: 0.0259511
# [9350]	valid_0's binary_logloss: 0.0259138
# [9400]	valid_0's binary_logloss: 0.025886
# [9450]	valid_0's binary_logloss: 0.025856
# [9500]	valid_0's binary_logloss: 0.025832
# [9550]	valid_0's binary_logloss: 0.0257894
# [9600]	valid_0's binary_logloss: 0.0257645
# [9650]	valid_0's binary_logloss: 0.0257267
# [9700]	valid_0's binary_logloss: 0.0256932
# [9750]	valid_0's binary_logloss: 0.0256587
# [9800]	valid_0's binary_logloss: 0.0256318
# [9850]	valid_0's binary_logloss: 0.0255933
# [9900]	valid_0's binary_logloss: 0.0255673
# [9950]	valid_0's binary_logloss: 0.0255436
# [10000]	valid_0's binary_logloss: 0.0255163
# [10050]	valid_0's binary_logloss: 0.0254956
# [10100]	valid_0's binary_logloss: 0.025456
# [10150]	valid_0's binary_logloss: 0.0254407
# [10200]	valid_0's binary_logloss: 0.025416
# [10250]	valid_0's binary_logloss: 0.0253853
# [10300]	valid_0's binary_logloss: 0.0253552
# [10350]	valid_0's binary_logloss: 0.0253286
# [10400]	valid_0's binary_logloss: 0.0253039
# [10450]	valid_0's binary_logloss: 0.0252714
# [10500]	valid_0's binary_logloss: 0.0252549
# [10550]	valid_0's binary_logloss: 0.0252303
# [10600]	valid_0's binary_logloss: 0.0251902
# [10650]	valid_0's binary_logloss: 0.0251644
# [10700]	valid_0's binary_logloss: 0.0251401
# [10750]	valid_0's binary_logloss: 0.0251153
# [10800]	valid_0's binary_logloss: 0.0250847
# [10850]	valid_0's binary_logloss: 0.0250547
# [10900]	valid_0's binary_logloss: 0.0250318
# [10950]	valid_0's binary_logloss: 0.0250029
# [11000]	valid_0's binary_logloss: 0.0249854
# [11050]	valid_0's binary_logloss: 0.0249622
# [11100]	valid_0's binary_logloss: 0.024943
# [11150]	valid_0's binary_logloss: 0.0249164
# [11200]	valid_0's binary_logloss: 0.0249043
# [11250]	valid_0's binary_logloss: 0.0248732
# [11300]	valid_0's binary_logloss: 0.0248483
# [11350]	valid_0's binary_logloss: 0.0248228
# [11400]	valid_0's binary_logloss: 0.0247999
# [11450]	valid_0's binary_logloss: 0.0247756
# [11500]	valid_0's binary_logloss: 0.0247497
# [11550]	valid_0's binary_logloss: 0.0247162
# [11600]	valid_0's binary_logloss: 0.0246911
# [11650]	valid_0's binary_logloss: 0.0246658
# [11700]	valid_0's binary_logloss: 0.0246375
# [11750]	valid_0's binary_logloss: 0.024614
# [11800]	valid_0's binary_logloss: 0.0245852
# [11850]	valid_0's binary_logloss: 0.0245697
# [11900]	valid_0's binary_logloss: 0.0245419
# [11950]	valid_0's binary_logloss: 0.0245236
# [12000]	valid_0's binary_logloss: 0.0245039
# [12050]	valid_0's binary_logloss: 0.024481
# [12100]	valid_0's binary_logloss: 0.0244542
# [12150]	valid_0's binary_logloss: 0.0244343
# [12200]	valid_0's binary_logloss: 0.0244126
# [12250]	valid_0's binary_logloss: 0.0243929
# [12300]	valid_0's binary_logloss: 0.0243687
# [12350]	valid_0's binary_logloss: 0.0243536
# [12400]	valid_0's binary_logloss: 0.0243332
# [12450]	valid_0's binary_logloss: 0.0243096
# [12500]	valid_0's binary_logloss: 0.0242914
# [12550]	valid_0's binary_logloss: 0.0242686
# [12600]	valid_0's binary_logloss: 0.0242515
# [12650]	valid_0's binary_logloss: 0.0242262
# [12700]	valid_0's binary_logloss: 0.0242076
# [12750]	valid_0's binary_logloss: 0.0241914
# [12800]	valid_0's binary_logloss: 0.0241712
# [12850]	valid_0's binary_logloss: 0.0241551
# [12900]	valid_0's binary_logloss: 0.0241382
# [12950]	valid_0's binary_logloss: 0.024114
# [13000]	valid_0's binary_logloss: 0.0240979
# [13050]	valid_0's binary_logloss: 0.024077
# [13100]	valid_0's binary_logloss: 0.0240619
# [13150]	valid_0's binary_logloss: 0.0240403
# [13200]	valid_0's binary_logloss: 0.0240294
# [13250]	valid_0's binary_logloss: 0.024014
# [13300]	valid_0's binary_logloss: 0.0239931
# [13350]	valid_0's binary_logloss: 0.0239866
# [13400]	valid_0's binary_logloss: 0.0239645
# [13450]	valid_0's binary_logloss: 0.0239385
# [13500]	valid_0's binary_logloss: 0.0239123
# [13550]	valid_0's binary_logloss: 0.0238989
# [13600]	valid_0's binary_logloss: 0.0238812
# [13650]	valid_0's binary_logloss: 0.0238709
# [13700]	valid_0's binary_logloss: 0.0238528
# [13750]	valid_0's binary_logloss: 0.0238304
# [13800]	valid_0's binary_logloss: 0.0238147
# [13850]	valid_0's binary_logloss: 0.0238012
# [13900]	valid_0's binary_logloss: 0.0237913
# [13950]	valid_0's binary_logloss: 0.0237743
# [14000]	valid_0's binary_logloss: 0.0237605
# [14050]	valid_0's binary_logloss: 0.023744
# [14100]	valid_0's binary_logloss: 0.023731
# [14150]	valid_0's binary_logloss: 0.0237152
# [14200]	valid_0's binary_logloss: 0.0237007
# [14250]	valid_0's binary_logloss: 0.0236887
# [14300]	valid_0's binary_logloss: 0.0236724
# [14350]	valid_0's binary_logloss: 0.023654
# [14400]	valid_0's binary_logloss: 0.023639
# [14450]	valid_0's binary_logloss: 0.0236233
# [14500]	valid_0's binary_logloss: 0.023607
# [14550]	valid_0's binary_logloss: 0.0235905
# [14600]	valid_0's binary_logloss: 0.0235775
# [14650]	valid_0's binary_logloss: 0.0235651
# [14700]	valid_0's binary_logloss: 0.023548
# [14750]	valid_0's binary_logloss: 0.0235292
# [14800]	valid_0's binary_logloss: 0.0235015
# [14850]	valid_0's binary_logloss: 0.0234839
# [14900]	valid_0's binary_logloss: 0.0234611
# [14950]	valid_0's binary_logloss: 0.0234409
# [15000]	valid_0's binary_logloss: 0.0234191
# [15050]	valid_0's binary_logloss: 0.0234013
# [15100]	valid_0's binary_logloss: 0.0233858
# [15150]	valid_0's binary_logloss: 0.0233751
# [15200]	valid_0's binary_logloss: 0.0233626
# [15250]	valid_0's binary_logloss: 0.0233487
# [15300]	valid_0's binary_logloss: 0.0233302
# [15350]	valid_0's binary_logloss: 0.0233129
# [15400]	valid_0's binary_logloss: 0.0232919
# [15450]	valid_0's binary_logloss: 0.0232771
# [15500]	valid_0's binary_logloss: 0.023263
# [15550]	valid_0's binary_logloss: 0.0232471
# [15600]	valid_0's binary_logloss: 0.0232339
# [15650]	valid_0's binary_logloss: 0.0232299
# [15700]	valid_0's binary_logloss: 0.0232196
# [15750]	valid_0's binary_logloss: 0.0232039
# [15800]	valid_0's binary_logloss: 0.0231934
# [15850]	valid_0's binary_logloss: 0.0231852
# [15900]	valid_0's binary_logloss: 0.0231773
# [15950]	valid_0's binary_logloss: 0.0231669
# [16000]	valid_0's binary_logloss: 0.0231498
# [16050]	valid_0's binary_logloss: 0.0231372
# [16100]	valid_0's binary_logloss: 0.0231292
# [16150]	valid_0's binary_logloss: 0.0231133
# [16200]	valid_0's binary_logloss: 0.0231029
# [16250]	valid_0's binary_logloss: 0.0230829
# [16300]	valid_0's binary_logloss: 0.0230694
# [16350]	valid_0's binary_logloss: 0.0230567
# [16400]	valid_0's binary_logloss: 0.0230493
#
# == fold 4 ==
# [50]	valid_0's binary_logloss: 0.0432412
# [100]	valid_0's binary_logloss: 0.0414293
# [150]	valid_0's binary_logloss: 0.0406969
# [200]	valid_0's binary_logloss: 0.0400993
# [250]	valid_0's binary_logloss: 0.039709
# [300]	valid_0's binary_logloss: 0.0392992
# [350]	valid_0's binary_logloss: 0.0389901
# [400]	valid_0's binary_logloss: 0.038674
# [450]	valid_0's binary_logloss: 0.038439
# [500]	valid_0's binary_logloss: 0.038193
# [550]	valid_0's binary_logloss: 0.0379367
# [600]	valid_0's binary_logloss: 0.0377527
# [650]	valid_0's binary_logloss: 0.0375401
# [700]	valid_0's binary_logloss: 0.0373584
# [750]	valid_0's binary_logloss: 0.0371504
# [800]	valid_0's binary_logloss: 0.036977
# [850]	valid_0's binary_logloss: 0.0368144
# [900]	valid_0's binary_logloss: 0.0366474
# [950]	valid_0's binary_logloss: 0.0364716
# [1000]	valid_0's binary_logloss: 0.0363165
# [1050]	valid_0's binary_logloss: 0.0361582
# [1100]	valid_0's binary_logloss: 0.0360403
# [1150]	valid_0's binary_logloss: 0.0359017
# [1200]	valid_0's binary_logloss: 0.0357528
# [1250]	valid_0's binary_logloss: 0.0356032
# [1300]	valid_0's binary_logloss: 0.0354697
# [1350]	valid_0's binary_logloss: 0.0353319
# [1400]	valid_0's binary_logloss: 0.0351767
# [1450]	valid_0's binary_logloss: 0.0350733
# [1500]	valid_0's binary_logloss: 0.0349613
# [1550]	valid_0's binary_logloss: 0.0348579
# [1600]	valid_0's binary_logloss: 0.0347511
# [1650]	valid_0's binary_logloss: 0.034641
# [1700]	valid_0's binary_logloss: 0.0345256
# [1750]	valid_0's binary_logloss: 0.0344088
# [1800]	valid_0's binary_logloss: 0.0343229
# [1850]	valid_0's binary_logloss: 0.0342151
# [1900]	valid_0's binary_logloss: 0.0340949
# [1950]	valid_0's binary_logloss: 0.0339923
# [2000]	valid_0's binary_logloss: 0.0339027
# [2050]	valid_0's binary_logloss: 0.0338066
# [2100]	valid_0's binary_logloss: 0.03371
# [2150]	valid_0's binary_logloss: 0.0336134
# [2200]	valid_0's binary_logloss: 0.0335323
# [2250]	valid_0's binary_logloss: 0.033445
# [2300]	valid_0's binary_logloss: 0.0333467
# [2350]	valid_0's binary_logloss: 0.0332633
# [2400]	valid_0's binary_logloss: 0.0331697
# [2450]	valid_0's binary_logloss: 0.0330776
# [2500]	valid_0's binary_logloss: 0.0329953
# [2550]	valid_0's binary_logloss: 0.0329127
# [2600]	valid_0's binary_logloss: 0.0328356
# [2650]	valid_0's binary_logloss: 0.032756
# [2700]	valid_0's binary_logloss: 0.0326576
# [2750]	valid_0's binary_logloss: 0.0325746
# [2800]	valid_0's binary_logloss: 0.0324894
# [2850]	valid_0's binary_logloss: 0.0324111
# [2900]	valid_0's binary_logloss: 0.0323468
# [2950]	valid_0's binary_logloss: 0.0322532
# [3000]	valid_0's binary_logloss: 0.0321548
# [3050]	valid_0's binary_logloss: 0.032074
# [3100]	valid_0's binary_logloss: 0.0320003
# [3150]	valid_0's binary_logloss: 0.0319263
# [3200]	valid_0's binary_logloss: 0.0318495
# [3250]	valid_0's binary_logloss: 0.0317835
# [3300]	valid_0's binary_logloss: 0.0317083
# [3350]	valid_0's binary_logloss: 0.0316217
# [3400]	valid_0's binary_logloss: 0.0315674
# [3450]	valid_0's binary_logloss: 0.0315139
# [3500]	valid_0's binary_logloss: 0.0314292
# [3550]	valid_0's binary_logloss: 0.0313648
# [3600]	valid_0's binary_logloss: 0.0312896
# [3650]	valid_0's binary_logloss: 0.0312231
# [3700]	valid_0's binary_logloss: 0.0311389
# [3750]	valid_0's binary_logloss: 0.0310679
# [3800]	valid_0's binary_logloss: 0.0309948
# [3850]	valid_0's binary_logloss: 0.0309406
# [3900]	valid_0's binary_logloss: 0.0308801
# [3950]	valid_0's binary_logloss: 0.0308253
# [4000]	valid_0's binary_logloss: 0.0307612
# [4050]	valid_0's binary_logloss: 0.0306942
# [4100]	valid_0's binary_logloss: 0.0306324
# [4150]	valid_0's binary_logloss: 0.0305666
# [4200]	valid_0's binary_logloss: 0.0305144
# [4250]	valid_0's binary_logloss: 0.0304588
# [4300]	valid_0's binary_logloss: 0.0303895
# [4350]	valid_0's binary_logloss: 0.0303278
# [4400]	valid_0's binary_logloss: 0.0302588
# [4450]	valid_0's binary_logloss: 0.0301924
# [4500]	valid_0's binary_logloss: 0.0301209
# [4550]	valid_0's binary_logloss: 0.0300504
# [4600]	valid_0's binary_logloss: 0.0299872
# [4650]	valid_0's binary_logloss: 0.0299365
# [4700]	valid_0's binary_logloss: 0.0298897
# [4750]	valid_0's binary_logloss: 0.0298298
# [4800]	valid_0's binary_logloss: 0.0297807
# [4850]	valid_0's binary_logloss: 0.0297136
# [4900]	valid_0's binary_logloss: 0.0296684
# [4950]	valid_0's binary_logloss: 0.0296105
# [5000]	valid_0's binary_logloss: 0.0295583
# [5050]	valid_0's binary_logloss: 0.0295058
# [5100]	valid_0's binary_logloss: 0.0294445
# [5150]	valid_0's binary_logloss: 0.029378
# [5200]	valid_0's binary_logloss: 0.0293213
# [5250]	valid_0's binary_logloss: 0.0292652
# [5300]	valid_0's binary_logloss: 0.0292111
# [5350]	valid_0's binary_logloss: 0.0291703
# [5400]	valid_0's binary_logloss: 0.0291152
# [5450]	valid_0's binary_logloss: 0.0290707

# %%
train_data["pred"] = oof[:, -1]

# %%
out_df = pd.DataFrame()
out_df['id'] = train_data['id'].unique().tolist()
out_df['match_id'] = out_df['id']

# %% [markdown]
# #Check Feature Importances

# %%
def plot_importances(models):
    importance_df = pd.DataFrame(models[0].feature_importances_, 
                                 index=features, 
                                 columns=['importance'])\
                        .sort_values("importance", ascending=False)

    plt.subplots(figsize=(len(features) // 4, 5))
    plt.bar(importance_df.index, importance_df.importance)
    plt.grid()
    plt.xticks(rotation=90)
    plt.ylabel("importance")
    plt.tight_layout()
    plt.show()

plot_importances(models)

# %% [markdown]
# #Check CV

# %%
# !pip install optuna

# %%
def post_process(df):
    id2match = dict(zip(df['id'].values, df['matches'].str.split()))

    for base, match in df[['id', 'matches']].values:
        match = match.split()
        if len(match) == 1:        
            continue

        for m in match:
            if base not in id2match[m]:
                id2match[m].append(base)
    df['matches'] = df['id'].map(id2match).map(' '.join)
    return df

# %%
import optuna

def objective(trial):
    x = trial.suggest_uniform('threshold', 0, 1)
    train_pred_df = train_data[train_data['pred'] > x][['id', 'match_id']]
    train_pred_df = train_pred_df.groupby('id')['match_id'].\
                        apply(list).reset_index()
    train_pred_df['matches'] = train_pred_df['match_id'].apply(lambda x: ' '.join(set(x)))
    train_pred_df = post_process(train_pred_df)
    score = get_score(train_pred_df)
    print(f"CV: {score:.6f}")
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# %%
threshold = study.best_params['threshold']
threshold

# %%
study.best_value

# %%
train_pred_df = train_data[train_data['pred'] > threshold][['id', 'match_id']]
train_pred_df = train_pred_df.groupby('id')['match_id'].\
                    apply(list).reset_index()
train_pred_df['matches'] = train_pred_df['match_id'].apply(lambda x: ' '.join(set(x)))
train_pred_df = post_process(train_pred_df)
score = get_score(train_pred_df)
print(f"CV: {score:.6f}")
