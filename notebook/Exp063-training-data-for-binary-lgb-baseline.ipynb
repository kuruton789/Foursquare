# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Imports
import warnings
warnings.filterwarnings('ignore')

import sys

if "google.colab" in sys.modules:
    # !pip uninstall lightgbm -y
    # !pip install lightgbm==3.3.1
    # !pip install Levenshtein

import os
import gc
import time
import random
import pickle
import Levenshtein
import difflib
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import lightgbm as lgb
from tqdm.auto import tqdm
from requests import get
from collections import Counter, defaultdict
from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
# Out:
# Found existing installation: lightgbm 2.2.3
# Uninstalling lightgbm-2.2.3:
#   Successfully uninstalled lightgbm-2.2.3
# Collecting lightgbm==3.3.1
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 4.1 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.21.6)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (1.0.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm==3.3.1) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.1) (1.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.1
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 4.3 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 35.6 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.2
#   Downloading jarowinkler-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 57.2 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.2 rapidfuzz-2.0.11

# %%
def stratified_group_k_fold(X, y, groups, k, seed=None):
    labels_num = np.max(y) + 1
    y_counts_per_group = defaultdict(lambda: np.zeros(labels_num))
    y_distr = Counter()
    for label, g in zip(y, groups):
        y_counts_per_group[g][label] += 1
        y_distr[label] += 1

    y_counts_per_fold = defaultdict(lambda: np.zeros(labels_num))
    groups_per_fold = defaultdict(set)

    def eval_y_counts_per_fold(y_counts, fold):
        y_counts_per_fold[fold] += y_counts
        std_per_label = []
        for label in range(labels_num):
            label_std = np.std([y_counts_per_fold[i][label] / y_distr[label] for i in range(k)])
            std_per_label.append(label_std)
        y_counts_per_fold[fold] -= y_counts
        return np.mean(std_per_label)
    
    groups_and_y_counts = list(y_counts_per_group.items())
    random.Random(seed).shuffle(groups_and_y_counts)

    for g, y_counts in sorted(groups_and_y_counts, key=lambda x: -np.std(x[1])):
        best_fold = None
        min_eval = None
        for i in range(k):
            fold_eval = eval_y_counts_per_fold(y_counts, i)
            if min_eval is None or fold_eval < min_eval:
                min_eval = fold_eval
                best_fold = i
        y_counts_per_fold[best_fold] += y_counts
        groups_per_fold[best_fold].add(g)

    all_groups = set(groups)
    for i in range(k):
        train_groups = all_groups - groups_per_fold[i]
        test_groups = groups_per_fold[i]

        train_indices = [i for i, g in enumerate(groups) if g in train_groups]
        test_indices = [i for i, g in enumerate(groups) if g in test_groups]

        yield train_indices, test_indices

# %%
def get_distribution(y_vals):
    y_distr = Counter(y_vals)
    y_vals_sum = sum(y_distr.values())
    return [f'{y_distr[i] / y_vals_sum:.2%}' for i in range(np.max(y_vals) + 1)]

# %%
## Parameters
class CFG:
    AUTHOR = "kuruton"
    expID = ""
    if "google.colab" in sys.modules:
        expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0].split("-")[0]
    ROOT_DIR = '/content/drive/MyDrive/Kaggle/Foursquare'
    DATASET_DIR = os.path.join(ROOT_DIR, 'Dataset')
    INPUT_DIR = os.path.join(ROOT_DIR, 'Input')
    OUTPUT_DIR = os.path.join(ROOT_DIR, 'Output')
    is_debug = False
    SEED = 2022
    num_neighbors = 20
    num_split = 3
    feat_columns = ['name', 'address', 'city', 
                'state', 'zip', 'url', 
              'phone', 'categories', 'country']
    vec_columns = ['name', 'categories', 'address', 
                  'state', 'url', 'country']

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
seed_everything(CFG.SEED)

# %%
if not os.path.exists(os.path.join(CFG.OUTPUT_DIR, CFG.expID)):
    os.makedirs(os.path.join(CFG.OUTPUT_DIR, CFG.expID))

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
def recall_knn(df, Neighbors = 10):
    print('Start knn grouped by country')
    train_df_country = []
    for country, country_df in tqdm(df.groupby('country')):
        country_df = country_df.reset_index(drop = True)

        neighbors = min(len(country_df), Neighbors)
        knn = KNeighborsRegressor(n_neighbors = neighbors,
                                    metric = 'haversine',
                                    n_jobs = -1)
        knn.fit(country_df[['latitude','longitude']], country_df.index)
        dists, nears = knn.kneighbors(country_df[['latitude', 'longitude']], 
                                        return_distance = True)

        for k in range(neighbors):            
            cur_df = country_df[['id']]
            cur_df['match_id'] = country_df['id'].values[nears[:, k]]
            cur_df['kdist_country'] = dists[:, k]
            cur_df['kneighbors_country'] = k
            
            train_df_country.append(cur_df)
    train_df_country = pd.concat(train_df_country)
    
    print('Start knn')
    train_df = []
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in range(Neighbors):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        train_df.append(cur_df)
    
    train_df = pd.concat(train_df)
    train_df = train_df.merge(train_df_country,
                                 on = ['id', 'match_id'],
                                 how = 'outer')
    del train_df_country
    
    return train_df

# %%
def add_features(df):    
    for col in tqdm(CFG.feat_columns):       
        if col in CFG.vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(difflib.SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
            
    return df

# %%
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

def get_score(input_df: pd.DataFrame):
    scores = []
    for id_str, matches in zip(input_df['id'].to_numpy(), input_df['matches'].to_numpy()):
        targets = poi2ids[id2poi[id_str]]
        preds = set(matches.split())
        score = len((targets & preds)) / len((targets | preds))
        scores.append(score)
    scores = np.array(scores)
    return scores.mean()

def analysis(df):
    print('Num of data: %s' % len(df))
    print('Num of unique id: %s' % df['id'].nunique())
    print('Num of unique poi: %s' % df['point_of_interest'].nunique())
    
    poi_grouped = df.groupby('point_of_interest')['id'].count().reset_index()
    print('Mean num of unique poi: %s' % poi_grouped['id'].mean())

# %%
## Data load
if "google.colab" in sys.modules:
    data_root = CFG.INPUT_DIR
else:
    data_root = '../input/foursquare-location-matching'
data = pd.read_csv(os.path.join(data_root, 'train.csv'))

if CFG.is_debug:
    data = data.sample(n = 10000, random_state = CFG.SEED)
    data = data.reset_index(drop = True)

# %%
## Data split
kf = GroupKFold(n_splits=2)
for i, (trn_idx, val_idx) in enumerate(kf.split(data, 
                                                data['point_of_interest'], 
                                                data['point_of_interest'])):
    data.loc[val_idx, 'set'] = i

print('Num of train data: %s' % len(data))
print(data['set'].value_counts())

valid_data = data[data['set'] == 0]
train_data = data[data['set'] == 1]

print('Train data: ')
analysis(train_data)
print('Valid data: ')
analysis(valid_data)

train_poi = train_data['point_of_interest'].unique().tolist()
valid_poi = valid_data['point_of_interest'].unique().tolist()

print(set(train_poi) & set(valid_poi))

train_ids = train_data['id'].unique().tolist()
valid_ids = valid_data['id'].unique().tolist()

print(set(train_ids) & set(valid_ids))

tv_ids_d = {}
tv_ids_d['train_ids'] = train_ids
tv_ids_d['valid_ids'] = valid_ids

np.save('tv_ids_d.npy', tv_ids_d)

del train_data, valid_data
gc.collect()

data = data.set_index('id')
data = data.loc[tv_ids_d['train_ids']]
data = data.reset_index()
# Out:
# Num of train data: 1138812
# 1.0    569406
# 0.0    569406
# Name: set, dtype: int64
# Train data:
# Num of data: 569406
# Num of unique id: 569406
# Num of unique poi: 369987
# Mean num of unique poi: 1.5389892077289202
# Valid data:
# Num of data: 569406
# Num of unique id: 569406
# Num of unique poi: 369985
# Mean num of unique poi: 1.5389975269267673
# set()
# set()

# %%
## Train data generated by knn
id2index_d = dict(zip(data['id'].values, data.index))

tfidf_d = {}
for col in CFG.vec_columns:
    tfidf = TfidfVectorizer()
    tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
    tfidf_d[col] = tv_fit

train_data = recall_knn(data, CFG.num_neighbors)

data = data.set_index('id')
ids = train_data['id'].tolist()
match_ids = train_data['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train_data['label'] = np.array(poi == match_poi, dtype = np.int8)
del poi, match_poi, ids, match_ids
gc.collect()

print('Num of unique id: %s' % train_data['id'].nunique())
print('Num of train data: %s' % len(train_data))
print('Pos rate: %s' % train_data['label'].mean())
print(train_data.sample(5))
# Out:
# Start knn grouped by country
#   0%|          | 0/210 [00:00<?, ?it/s]
# Start knn
# Num of unique id: 569406
# Num of train data: 13928057
# Pos rate: 0.07242905453359359
#                         id          match_id     kdist  kneighbors  \
# 2271553   E_fd464ba1740098  E_e9f184d83cae1e  0.007594         3.0
# 2195812   E_db1da0832b0edb  E_43d12cd75a508f  0.003153         3.0
# 6242880   E_f6b56f1f995bb8  E_559775ec266daa  0.002581        10.0
# 9817306   E_3daed89cf926d8  E_7d12548cb02d23  0.001735        17.0
# 11950281  E_92c117b8a31433  E_8f8f0ab8d049d3       NaN         NaN
#
#           kdist_country  kneighbors_country  label
# 2271553        0.006657                 2.0      0
# 2195812        0.003124                 3.0      0
# 6242880        0.002541                10.0      0
# 9817306        0.001725                17.0      0
# 11950281       0.040197                12.0      0

# %%
## Eval
data = data.reset_index()

id2poi = get_id2poi(data)
poi2ids = get_poi2ids(data)

eval_df = pd.DataFrame()
eval_df['id'] = data['id'].unique().tolist()
eval_df['match_id'] = eval_df['id']
print('Unique id: %s' % len(eval_df))

eval_df_ = train_data[train_data['label'] == 1][['id', 'match_id']]
eval_df = pd.concat([eval_df, eval_df_])

eval_df = eval_df.groupby('id')['match_id'].\
                        apply(list).reset_index()
eval_df['matches'] = eval_df['match_id'].apply(lambda x: ' '.join(set(x)))
print('Unique id: %s' % len(eval_df))

iou_score = get_score(eval_df)
print('IoU score: %s' % iou_score)
# Out:
# Unique id: 569406
# Unique id: 569406
# IoU score: 0.9231233344021228

# %%
distrs = [get_distribution(train_data["label"])]
index = ['training set']

for fold_ind, (dev_ind, val_ind) in enumerate(stratified_group_k_fold(train_data, train_data["label"], train_data["id"], k=CFG.num_split, seed=CFG.SEED)):
    train_data.loc[val_ind, "fold"] = fold_ind

    dev_y, val_y = train_data.loc[dev_ind, "label"], train_data.loc[val_ind, "label"]
    dev_groups, val_groups = train_data.loc[dev_ind, "id"], train_data.loc[val_ind, "id"]
    
    assert len(set(dev_groups) & set(val_groups)) == 0
    
    distrs.append(get_distribution(dev_y))
    index.append(f'development set - fold {fold_ind}')
    distrs.append(get_distribution(val_y))
    index.append(f'validation set - fold {fold_ind}')

display('Distribution per class:')
pd.DataFrame(distrs, index=index, columns=[f'Label {l}' for l in range(np.max(train_data["label"]) + 1)])
# Out:
# 'Distribution per class:'
#                          Label 0 Label 1
# training set              92.76%   7.24%
# development set - fold 0  92.76%   7.24%
# validation set - fold 0   92.76%   7.24%
# development set - fold 1  92.76%   7.24%
# validation set - fold 1   92.76%   7.24%
# development set - fold 2  92.76%   7.24%
# validation set - fold 2   92.76%   7.24%

# %% [markdown]
# # model learning

# %%
data = data.set_index('id')
train_data = add_features(train_data)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
train_data['kdist_diff'] = (train_data['kdist'] - train_data['kdist_country']) /\
                            train_data['kdist_country']
train_data['kneighbors_mean'] = train_data[['kneighbors', 'kneighbors_country']].mean(axis = 1)

# %%
features = ['kdist','kneighbors','kdist_country','kneighbors_country', 'kdist_diff', 'kneighbors_mean']

columns = ['name', 'address', 'city', 'state',
       'zip', 'country', 'url', 'phone', 'categories']

for c in columns:
    if c == 'country':
        features += ['country_leven', 'country_sim', 'country_gesh', 'country_nleven']
        continue
    features += [f"{c}_gesh", f"{c}_jaro", f"{c}_lcs", f"{c}_leven"]
    if c == 'city':
        features += [f"{c}_len_diff", f"{c}_nleven", f"{c}_nlcsk", f"{c}_nlcs"]
    if c in ['address', 'categories', 'country', 'name', 'state', 'url']:
        features += [f"{c}_len_diff", f"{c}_nleven", f"{c}_nlcsk", f"{c}_nlcs", f"{c}_sim"]

print(len(features))
print(features)
# Out:
# 71
# ['kdist', 'kneighbors', 'kdist_country', 'kneighbors_country', 'kdist_diff', 'kneighbors_mean', 'name_gesh', 'name_jaro', 'name_lcs', 'name_leven', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs', 'name_sim', 'address_gesh', 'address_jaro', 'address_lcs', 'address_leven', 'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs', 'address_sim', 'city_gesh', 'city_jaro', 'city_lcs', 'city_leven', 'city_len_diff', 'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_jaro', 'state_lcs', 'state_leven', 'state_len_diff', 'state_nleven', 'state_nlcsk', 'state_nlcs', 'state_sim', 'zip_gesh', 'zip_jaro', 'zip_lcs', 'zip_leven', 'country_leven', 'country_sim', 'country_gesh', 'country_nleven', 'url_gesh', 'url_jaro', 'url_lcs', 'url_leven', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs', 'url_sim', 'phone_gesh', 'phone_jaro', 'phone_lcs', 'phone_leven', 'categories_gesh', 'categories_jaro', 'categories_lcs', 'categories_leven', 'categories_len_diff', 'categories_nleven', 'categories_nlcsk', 'categories_nlcs', 'categories_sim']

# %%
def fit_lgb(X, y, params=None, es_rounds=20, seed=42, N_SPLITS=5, 
             n_class=None, model_dir=None, folds=None):
    models = []
    oof = np.zeros((len(y), 2), dtype=np.float64)
    
    for i in tqdm(range(CFG.num_split)):
        print(f"== fold {i} ==")
        trn_idx = folds!=i
        val_idx = folds==i
        X_train, y_train = X[trn_idx], y.iloc[trn_idx]
        X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]

        if model_dir is None:
            model = lgb.LGBMClassifier(**params)
            model.fit(
                X_train, y_train, 
                eval_set=[(X_valid, y_valid)],  
                early_stopping_rounds=es_rounds, 
                eval_metric='binary',  
    #             verbose=-1)
                verbose=50)
        else:
            with open(f'{model_dir}/lgb_fold{i}.pkl', 'rb') as f:
                model = pickle.load(f)

        pred = model.predict_proba(X_valid)
        oof[val_idx] = pred
        models.append(model)

        file = os.path.join(CFG.OUTPUT_DIR, os.path.join(CFG.expID, f'lgb_fold{i}.pkl'))
        pickle.dump(model, open(file, 'wb'))
        print()

    cv = (oof.argmax(axis=-1) == y).mean()
    print(f"CV-accuracy: {cv}")

    return oof, models

def inference_lgb(models, feat_df):
    pred = np.array([model.predict_proba(feat_df) for model in models])
    pred = np.mean(pred, axis=0)
    return pred

# %%
params = {
    'objective': "binary",
    'learning_rate': 0.2,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'random_state': 42,

    'max_depth': 7,   
    'num_leaves': 35, 
    'n_estimators': 1000000, 
    "colsample_bytree": 0.9,
}


oof, models = fit_lgb(train_data[features], train_data["label"].astype(int), 
                      params=params, n_class=2, 
                      N_SPLITS=CFG.num_split, folds=train_data["fold"].values)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# == fold 0 ==
# [50]	valid_0's binary_logloss: 0.043856
# [100]	valid_0's binary_logloss: 0.0422617
# [150]	valid_0's binary_logloss: 0.041475
# [200]	valid_0's binary_logloss: 0.0409486
# [250]	valid_0's binary_logloss: 0.0404098
# [300]	valid_0's binary_logloss: 0.0399976
# [350]	valid_0's binary_logloss: 0.0397226
# [400]	valid_0's binary_logloss: 0.0393879
# [450]	valid_0's binary_logloss: 0.0390966
# [500]	valid_0's binary_logloss: 0.0389123
# [550]	valid_0's binary_logloss: 0.0387007
# [600]	valid_0's binary_logloss: 0.0384849
# [650]	valid_0's binary_logloss: 0.0382878
# [700]	valid_0's binary_logloss: 0.0380809
# [750]	valid_0's binary_logloss: 0.0378988
# [800]	valid_0's binary_logloss: 0.0377384
# [850]	valid_0's binary_logloss: 0.0375895
# [900]	valid_0's binary_logloss: 0.0374552
# [950]	valid_0's binary_logloss: 0.0372941
# [1000]	valid_0's binary_logloss: 0.0371695
# [1050]	valid_0's binary_logloss: 0.0370325
# [1100]	valid_0's binary_logloss: 0.0368985
# [1150]	valid_0's binary_logloss: 0.0367502
# [1200]	valid_0's binary_logloss: 0.0366426
# [1250]	valid_0's binary_logloss: 0.0365316
# [1300]	valid_0's binary_logloss: 0.0364161
# [1350]	valid_0's binary_logloss: 0.036297
# [1400]	valid_0's binary_logloss: 0.0361693
# [1450]	valid_0's binary_logloss: 0.036052
# [1500]	valid_0's binary_logloss: 0.035916
# [1550]	valid_0's binary_logloss: 0.0357907
# [1600]	valid_0's binary_logloss: 0.0357054
# [1650]	valid_0's binary_logloss: 0.0356003
# [1700]	valid_0's binary_logloss: 0.0354919
# [1750]	valid_0's binary_logloss: 0.0354036
# [1800]	valid_0's binary_logloss: 0.0353112
# [1850]	valid_0's binary_logloss: 0.0352133
# [1900]	valid_0's binary_logloss: 0.0351035
# [1950]	valid_0's binary_logloss: 0.035015
# [2000]	valid_0's binary_logloss: 0.0349359
# [2050]	valid_0's binary_logloss: 0.0348403
# [2100]	valid_0's binary_logloss: 0.0347639
# [2150]	valid_0's binary_logloss: 0.0346793
# [2200]	valid_0's binary_logloss: 0.0346046
# [2250]	valid_0's binary_logloss: 0.0345242
# [2300]	valid_0's binary_logloss: 0.0344416
# [2350]	valid_0's binary_logloss: 0.0343598
# [2400]	valid_0's binary_logloss: 0.0342788
# [2450]	valid_0's binary_logloss: 0.0341949
# [2500]	valid_0's binary_logloss: 0.0341201
# [2550]	valid_0's binary_logloss: 0.0340382
# [2600]	valid_0's binary_logloss: 0.0339587
# [2650]	valid_0's binary_logloss: 0.0338957
# [2700]	valid_0's binary_logloss: 0.0338313
# [2750]	valid_0's binary_logloss: 0.0337539
# [2800]	valid_0's binary_logloss: 0.0336851
# [2850]	valid_0's binary_logloss: 0.0336063
# [2900]	valid_0's binary_logloss: 0.0335507
# [2950]	valid_0's binary_logloss: 0.033473
# [3000]	valid_0's binary_logloss: 0.0334113
# [3050]	valid_0's binary_logloss: 0.0333443
# [3100]	valid_0's binary_logloss: 0.0332699
# [3150]	valid_0's binary_logloss: 0.0331994
# [3200]	valid_0's binary_logloss: 0.0331312
# [3250]	valid_0's binary_logloss: 0.0330618
# [3300]	valid_0's binary_logloss: 0.0329929
# [3350]	valid_0's binary_logloss: 0.0329364
# [3400]	valid_0's binary_logloss: 0.0328769
# [3450]	valid_0's binary_logloss: 0.0328174
# [3500]	valid_0's binary_logloss: 0.0327569
# [3550]	valid_0's binary_logloss: 0.0326992
# [3600]	valid_0's binary_logloss: 0.0326499
# [3650]	valid_0's binary_logloss: 0.0325982
# [3700]	valid_0's binary_logloss: 0.0325463
# [3750]	valid_0's binary_logloss: 0.0324928
# [3800]	valid_0's binary_logloss: 0.0324445
# [3850]	valid_0's binary_logloss: 0.0323932
# [3900]	valid_0's binary_logloss: 0.0323389
# [3950]	valid_0's binary_logloss: 0.032279
# [4000]	valid_0's binary_logloss: 0.0322285
# [4050]	valid_0's binary_logloss: 0.032183
# [4100]	valid_0's binary_logloss: 0.0321322
# [4150]	valid_0's binary_logloss: 0.0320738
# [4200]	valid_0's binary_logloss: 0.0320246
# [4250]	valid_0's binary_logloss: 0.0319868
# [4300]	valid_0's binary_logloss: 0.0319372
# [4350]	valid_0's binary_logloss: 0.0319
# [4400]	valid_0's binary_logloss: 0.0318577
# [4450]	valid_0's binary_logloss: 0.0318201
# [4500]	valid_0's binary_logloss: 0.0317813
# [4550]	valid_0's binary_logloss: 0.0317305
# [4600]	valid_0's binary_logloss: 0.0316845
# [4650]	valid_0's binary_logloss: 0.0316267
# [4700]	valid_0's binary_logloss: 0.0315782
# [4750]	valid_0's binary_logloss: 0.0315395
# [4800]	valid_0's binary_logloss: 0.031488
# [4850]	valid_0's binary_logloss: 0.0314412
# [4900]	valid_0's binary_logloss: 0.0313906
# [4950]	valid_0's binary_logloss: 0.031339
# [5000]	valid_0's binary_logloss: 0.0312973
# [5050]	valid_0's binary_logloss: 0.0312502
# [5100]	valid_0's binary_logloss: 0.0312034
# [5150]	valid_0's binary_logloss: 0.0311654
# [5200]	valid_0's binary_logloss: 0.0311316
# [5250]	valid_0's binary_logloss: 0.0311048
# [5300]	valid_0's binary_logloss: 0.0310639
# [5350]	valid_0's binary_logloss: 0.0310317
# [5400]	valid_0's binary_logloss: 0.0309932
# [5450]	valid_0's binary_logloss: 0.0309511
# [5500]	valid_0's binary_logloss: 0.030916
# [5550]	valid_0's binary_logloss: 0.0308768
# [5600]	valid_0's binary_logloss: 0.0308349
# [5650]	valid_0's binary_logloss: 0.0307967
# [5700]	valid_0's binary_logloss: 0.0307671
# [5750]	valid_0's binary_logloss: 0.0307295
# [5800]	valid_0's binary_logloss: 0.0306859
# [5850]	valid_0's binary_logloss: 0.0306537
# [5900]	valid_0's binary_logloss: 0.0306108
# [5950]	valid_0's binary_logloss: 0.0305784
# [6000]	valid_0's binary_logloss: 0.030538
# [6050]	valid_0's binary_logloss: 0.0305109
# [6100]	valid_0's binary_logloss: 0.030477
# [6150]	valid_0's binary_logloss: 0.0304363
# [6200]	valid_0's binary_logloss: 0.0303937
# [6250]	valid_0's binary_logloss: 0.0303498
# [6300]	valid_0's binary_logloss: 0.0303218
# [6350]	valid_0's binary_logloss: 0.0302855
# [6400]	valid_0's binary_logloss: 0.0302546
# [6450]	valid_0's binary_logloss: 0.0302255
# [6500]	valid_0's binary_logloss: 0.0301948
# [6550]	valid_0's binary_logloss: 0.0301578
# [6600]	valid_0's binary_logloss: 0.030123
# [6650]	valid_0's binary_logloss: 0.030095
# [6700]	valid_0's binary_logloss: 0.030062
# [6750]	valid_0's binary_logloss: 0.0300279
# [6800]	valid_0's binary_logloss: 0.0299906
# [6850]	valid_0's binary_logloss: 0.0299562
# [6900]	valid_0's binary_logloss: 0.029927
# [6950]	valid_0's binary_logloss: 0.0298907
# [7000]	valid_0's binary_logloss: 0.0298659
# [7050]	valid_0's binary_logloss: 0.0298412
# [7100]	valid_0's binary_logloss: 0.0298118
# [7150]	valid_0's binary_logloss: 0.0297715
# [7200]	valid_0's binary_logloss: 0.0297335
# [7250]	valid_0's binary_logloss: 0.0296951
# [7300]	valid_0's binary_logloss: 0.0296726
# [7350]	valid_0's binary_logloss: 0.0296422
# [7400]	valid_0's binary_logloss: 0.0296139
# [7450]	valid_0's binary_logloss: 0.0295827
# [7500]	valid_0's binary_logloss: 0.0295481
# [7550]	valid_0's binary_logloss: 0.0295204
# [7600]	valid_0's binary_logloss: 0.0294901
# [7650]	valid_0's binary_logloss: 0.0294606
# [7700]	valid_0's binary_logloss: 0.0294388
# [7750]	valid_0's binary_logloss: 0.0294164
# [7800]	valid_0's binary_logloss: 0.0293928
# [7850]	valid_0's binary_logloss: 0.0293677
# [7900]	valid_0's binary_logloss: 0.0293379
# [7950]	valid_0's binary_logloss: 0.0293073
# [8000]	valid_0's binary_logloss: 0.0292816
# [8050]	valid_0's binary_logloss: 0.0292576
# [8100]	valid_0's binary_logloss: 0.0292334
# [8150]	valid_0's binary_logloss: 0.0292114
# [8200]	valid_0's binary_logloss: 0.0291815
# [8250]	valid_0's binary_logloss: 0.0291506
# [8300]	valid_0's binary_logloss: 0.0291183
# [8350]	valid_0's binary_logloss: 0.029094
# [8400]	valid_0's binary_logloss: 0.0290634
# [8450]	valid_0's binary_logloss: 0.029041
# [8500]	valid_0's binary_logloss: 0.0290184
# [8550]	valid_0's binary_logloss: 0.0289941
# [8600]	valid_0's binary_logloss: 0.028978
# [8650]	valid_0's binary_logloss: 0.0289609
# [8700]	valid_0's binary_logloss: 0.0289445
# [8750]	valid_0's binary_logloss: 0.0289205
# [8800]	valid_0's binary_logloss: 0.0288988
# [8850]	valid_0's binary_logloss: 0.0288859
# [8900]	valid_0's binary_logloss: 0.028867
# [8950]	valid_0's binary_logloss: 0.0288477
# [9000]	valid_0's binary_logloss: 0.02882
# [9050]	valid_0's binary_logloss: 0.0288106
# [9100]	valid_0's binary_logloss: 0.028799
# [9150]	valid_0's binary_logloss: 0.0287711
# [9200]	valid_0's binary_logloss: 0.0287566
# [9250]	valid_0's binary_logloss: 0.0287418
# [9300]	valid_0's binary_logloss: 0.0287186
# [9350]	valid_0's binary_logloss: 0.0286995
# [9400]	valid_0's binary_logloss: 0.0286849
# [9450]	valid_0's binary_logloss: 0.028668
# [9500]	valid_0's binary_logloss: 0.028639
# [9550]	valid_0's binary_logloss: 0.0286213
# [9600]	valid_0's binary_logloss: 0.028602
# [9650]	valid_0's binary_logloss: 0.0285801
# [9700]	valid_0's binary_logloss: 0.0285521
# [9750]	valid_0's binary_logloss: 0.0285343
# [9800]	valid_0's binary_logloss: 0.0285138
# [9850]	valid_0's binary_logloss: 0.0284915
# [9900]	valid_0's binary_logloss: 0.0284662
# [9950]	valid_0's binary_logloss: 0.0284482
# [10000]	valid_0's binary_logloss: 0.0284373
# [10050]	valid_0's binary_logloss: 0.0284187
# [10100]	valid_0's binary_logloss: 0.0284045
# [10150]	valid_0's binary_logloss: 0.0283872
# [10200]	valid_0's binary_logloss: 0.0283678
# [10250]	valid_0's binary_logloss: 0.0283457
# [10300]	valid_0's binary_logloss: 0.0283228
# [10350]	valid_0's binary_logloss: 0.0283077
# [10400]	valid_0's binary_logloss: 0.0282962
# [10450]	valid_0's binary_logloss: 0.0282809
# [10500]	valid_0's binary_logloss: 0.0282607
# [10550]	valid_0's binary_logloss: 0.0282395
# [10600]	valid_0's binary_logloss: 0.0282152
# [10650]	valid_0's binary_logloss: 0.0281972
# [10700]	valid_0's binary_logloss: 0.0281845
# [10750]	valid_0's binary_logloss: 0.0281758
# [10800]	valid_0's binary_logloss: 0.0281563
# [10850]	valid_0's binary_logloss: 0.0281473
# [10900]	valid_0's binary_logloss: 0.0281321
# [10950]	valid_0's binary_logloss: 0.028114
# [11000]	valid_0's binary_logloss: 0.0280958
# [11050]	valid_0's binary_logloss: 0.0280824
# [11100]	valid_0's binary_logloss: 0.0280662
# [11150]	valid_0's binary_logloss: 0.0280528
# [11200]	valid_0's binary_logloss: 0.0280391
# [11250]	valid_0's binary_logloss: 0.0280216
# [11300]	valid_0's binary_logloss: 0.0280104
# [11350]	valid_0's binary_logloss: 0.0279903
# [11400]	valid_0's binary_logloss: 0.0279732
# [11450]	valid_0's binary_logloss: 0.0279645
# [11500]	valid_0's binary_logloss: 0.0279532
# [11550]	valid_0's binary_logloss: 0.0279362
# [11600]	valid_0's binary_logloss: 0.0279203
# [11650]	valid_0's binary_logloss: 0.0279024
# [11700]	valid_0's binary_logloss: 0.0278882
#
# == fold 1 ==
# [50]	valid_0's binary_logloss: 0.0434928
# [100]	valid_0's binary_logloss: 0.0417659
# [150]	valid_0's binary_logloss: 0.0409265
# [200]	valid_0's binary_logloss: 0.0403031
# [250]	valid_0's binary_logloss: 0.0398291
# [300]	valid_0's binary_logloss: 0.0394687
# [350]	valid_0's binary_logloss: 0.0391423
# [400]	valid_0's binary_logloss: 0.0389004
# [450]	valid_0's binary_logloss: 0.0386223
# [500]	valid_0's binary_logloss: 0.0383759
# [550]	valid_0's binary_logloss: 0.0381485
# [600]	valid_0's binary_logloss: 0.0379678
# [650]	valid_0's binary_logloss: 0.0377896
# [700]	valid_0's binary_logloss: 0.0376057
# [750]	valid_0's binary_logloss: 0.0374279
# [800]	valid_0's binary_logloss: 0.03727
# [850]	valid_0's binary_logloss: 0.0371049
# [900]	valid_0's binary_logloss: 0.036966
# [950]	valid_0's binary_logloss: 0.0368034
# [1000]	valid_0's binary_logloss: 0.0366359
# [1050]	valid_0's binary_logloss: 0.0364829
# [1100]	valid_0's binary_logloss: 0.0363517
# [1150]	valid_0's binary_logloss: 0.0362393
# [1200]	valid_0's binary_logloss: 0.0361303
# [1250]	valid_0's binary_logloss: 0.0360225
# [1300]	valid_0's binary_logloss: 0.0359207
# [1350]	valid_0's binary_logloss: 0.0358084
# [1400]	valid_0's binary_logloss: 0.0356876
# [1450]	valid_0's binary_logloss: 0.0355753
# [1500]	valid_0's binary_logloss: 0.0354483
# [1550]	valid_0's binary_logloss: 0.0353437
# [1600]	valid_0's binary_logloss: 0.0352353
# [1650]	valid_0's binary_logloss: 0.0351321
# [1700]	valid_0's binary_logloss: 0.0350273
# [1750]	valid_0's binary_logloss: 0.0349323
# [1800]	valid_0's binary_logloss: 0.0348291
# [1850]	valid_0's binary_logloss: 0.0347133
# [1900]	valid_0's binary_logloss: 0.0346249
# [1950]	valid_0's binary_logloss: 0.034543
# [2000]	valid_0's binary_logloss: 0.0344744
# [2050]	valid_0's binary_logloss: 0.03439
# [2100]	valid_0's binary_logloss: 0.0343147
# [2150]	valid_0's binary_logloss: 0.034219
# [2200]	valid_0's binary_logloss: 0.0341453
# [2250]	valid_0's binary_logloss: 0.0340602
# [2300]	valid_0's binary_logloss: 0.0339771
# [2350]	valid_0's binary_logloss: 0.0339008
# [2400]	valid_0's binary_logloss: 0.0338183
# [2450]	valid_0's binary_logloss: 0.0337333
# [2500]	valid_0's binary_logloss: 0.0336585
# [2550]	valid_0's binary_logloss: 0.0335655
# [2600]	valid_0's binary_logloss: 0.0334872
# [2650]	valid_0's binary_logloss: 0.0334235
# [2700]	valid_0's binary_logloss: 0.0333644
# [2750]	valid_0's binary_logloss: 0.033303
# [2800]	valid_0's binary_logloss: 0.0332467
# [2850]	valid_0's binary_logloss: 0.0331929
# [2900]	valid_0's binary_logloss: 0.033122
# [2950]	valid_0's binary_logloss: 0.0330437
# [3000]	valid_0's binary_logloss: 0.0329742
# [3050]	valid_0's binary_logloss: 0.0329162
# [3100]	valid_0's binary_logloss: 0.0328516
# [3150]	valid_0's binary_logloss: 0.032798
# [3200]	valid_0's binary_logloss: 0.0327355
# [3250]	valid_0's binary_logloss: 0.0326771
# [3300]	valid_0's binary_logloss: 0.0326247
# [3350]	valid_0's binary_logloss: 0.0325751
# [3400]	valid_0's binary_logloss: 0.0325102
# [3450]	valid_0's binary_logloss: 0.032453
# [3500]	valid_0's binary_logloss: 0.0323859
# [3550]	valid_0's binary_logloss: 0.0323355
# [3600]	valid_0's binary_logloss: 0.0322679
# [3650]	valid_0's binary_logloss: 0.0322208
# [3700]	valid_0's binary_logloss: 0.0321515
# [3750]	valid_0's binary_logloss: 0.0320955
# [3800]	valid_0's binary_logloss: 0.0320359
# [3850]	valid_0's binary_logloss: 0.0319845
# [3900]	valid_0's binary_logloss: 0.031935
# [3950]	valid_0's binary_logloss: 0.0318794
# [4000]	valid_0's binary_logloss: 0.0318365
# [4050]	valid_0's binary_logloss: 0.0317729
# [4100]	valid_0's binary_logloss: 0.0317286
# [4150]	valid_0's binary_logloss: 0.0316872
# [4200]	valid_0's binary_logloss: 0.0316321
# [4250]	valid_0's binary_logloss: 0.0315736
# [4300]	valid_0's binary_logloss: 0.031529
# [4350]	valid_0's binary_logloss: 0.0314724
# [4400]	valid_0's binary_logloss: 0.0314325
# [4450]	valid_0's binary_logloss: 0.0313862
# [4500]	valid_0's binary_logloss: 0.0313314
# [4550]	valid_0's binary_logloss: 0.0312792
# [4600]	valid_0's binary_logloss: 0.0312339
# [4650]	valid_0's binary_logloss: 0.0311828
# [4700]	valid_0's binary_logloss: 0.0311292
# [4750]	valid_0's binary_logloss: 0.0310832
# [4800]	valid_0's binary_logloss: 0.0310298
# [4850]	valid_0's binary_logloss: 0.0309854
# [4900]	valid_0's binary_logloss: 0.0309418
# [4950]	valid_0's binary_logloss: 0.0308926
# [5000]	valid_0's binary_logloss: 0.0308416
# [5050]	valid_0's binary_logloss: 0.0307968
# [5100]	valid_0's binary_logloss: 0.0307478
# [5150]	valid_0's binary_logloss: 0.0307164
# [5200]	valid_0's binary_logloss: 0.0306781
# [5250]	valid_0's binary_logloss: 0.0306464
# [5300]	valid_0's binary_logloss: 0.0306014
# [5350]	valid_0's binary_logloss: 0.0305614
# [5400]	valid_0's binary_logloss: 0.0305328
# [5450]	valid_0's binary_logloss: 0.0305006
# [5500]	valid_0's binary_logloss: 0.0304593
# [5550]	valid_0's binary_logloss: 0.0304139
# [5600]	valid_0's binary_logloss: 0.0303653
# [5650]	valid_0's binary_logloss: 0.0303192
# [5700]	valid_0's binary_logloss: 0.0302908
# [5750]	valid_0's binary_logloss: 0.030253
# [5800]	valid_0's binary_logloss: 0.0302269
# [5850]	valid_0's binary_logloss: 0.0301856
# [5900]	valid_0's binary_logloss: 0.0301525
# [5950]	valid_0's binary_logloss: 0.0301267
# [6000]	valid_0's binary_logloss: 0.0300878
# [6050]	valid_0's binary_logloss: 0.0300562
# [6100]	valid_0's binary_logloss: 0.0300288
# [6150]	valid_0's binary_logloss: 0.0299911
# [6200]	valid_0's binary_logloss: 0.0299561
# [6250]	valid_0's binary_logloss: 0.0299274
# [6300]	valid_0's binary_logloss: 0.0298945
# [6350]	valid_0's binary_logloss: 0.0298595
# [6400]	valid_0's binary_logloss: 0.0298301
# [6450]	valid_0's binary_logloss: 0.0298023
# [6500]	valid_0's binary_logloss: 0.0297712
# [6550]	valid_0's binary_logloss: 0.0297497
# [6600]	valid_0's binary_logloss: 0.0297074
# [6650]	valid_0's binary_logloss: 0.0296761
# [6700]	valid_0's binary_logloss: 0.0296413
# [6750]	valid_0's binary_logloss: 0.0296112
# [6800]	valid_0's binary_logloss: 0.0295743
# [6850]	valid_0's binary_logloss: 0.029553
# [6900]	valid_0's binary_logloss: 0.0295174
# [6950]	valid_0's binary_logloss: 0.0294921
# [7000]	valid_0's binary_logloss: 0.0294669
# [7050]	valid_0's binary_logloss: 0.0294375
# [7100]	valid_0's binary_logloss: 0.0294119
# [7150]	valid_0's binary_logloss: 0.029379
# [7200]	valid_0's binary_logloss: 0.0293454
# [7250]	valid_0's binary_logloss: 0.0293185
# [7300]	valid_0's binary_logloss: 0.0292858
# [7350]	valid_0's binary_logloss: 0.0292548
# [7400]	valid_0's binary_logloss: 0.0292231
# [7450]	valid_0's binary_logloss: 0.0291894
# [7500]	valid_0's binary_logloss: 0.0291529
# [7550]	valid_0's binary_logloss: 0.0291232
# [7600]	valid_0's binary_logloss: 0.0291038
# [7650]	valid_0's binary_logloss: 0.0290799
# [7700]	valid_0's binary_logloss: 0.029054
# [7750]	valid_0's binary_logloss: 0.0290338
# [7800]	valid_0's binary_logloss: 0.0290176
# [7850]	valid_0's binary_logloss: 0.0289892
# [7900]	valid_0's binary_logloss: 0.028965
# [7950]	valid_0's binary_logloss: 0.0289396
# [8000]	valid_0's binary_logloss: 0.0289188
# [8050]	valid_0's binary_logloss: 0.0288904
# [8100]	valid_0's binary_logloss: 0.0288705
# [8150]	valid_0's binary_logloss: 0.0288401
# [8200]	valid_0's binary_logloss: 0.0288141
# [8250]	valid_0's binary_logloss: 0.0287935
# [8300]	valid_0's binary_logloss: 0.0287761
# [8350]	valid_0's binary_logloss: 0.0287504
# [8400]	valid_0's binary_logloss: 0.0287179
# [8450]	valid_0's binary_logloss: 0.0286874
# [8500]	valid_0's binary_logloss: 0.0286598
# [8550]	valid_0's binary_logloss: 0.0286282
# [8600]	valid_0's binary_logloss: 0.0285992
# [8650]	valid_0's binary_logloss: 0.0285712
# [8700]	valid_0's binary_logloss: 0.0285511
# [8750]	valid_0's binary_logloss: 0.0285268
# [8800]	valid_0's binary_logloss: 0.0285091
# [8850]	valid_0's binary_logloss: 0.0284952
# [8900]	valid_0's binary_logloss: 0.0284709
# [8950]	valid_0's binary_logloss: 0.0284465
# [9000]	valid_0's binary_logloss: 0.0284309
# [9050]	valid_0's binary_logloss: 0.028414
# [9100]	valid_0's binary_logloss: 0.028396
# [9150]	valid_0's binary_logloss: 0.0283696
# [9200]	valid_0's binary_logloss: 0.0283515
# [9250]	valid_0's binary_logloss: 0.0283314
# [9300]	valid_0's binary_logloss: 0.028304
# [9350]	valid_0's binary_logloss: 0.028288
# [9400]	valid_0's binary_logloss: 0.0282751
# [9450]	valid_0's binary_logloss: 0.0282549
# [9500]	valid_0's binary_logloss: 0.0282367
# [9550]	valid_0's binary_logloss: 0.0282215
# [9600]	valid_0's binary_logloss: 0.0282034
# [9650]	valid_0's binary_logloss: 0.0281872
# [9700]	valid_0's binary_logloss: 0.0281682
# [9750]	valid_0's binary_logloss: 0.028147
# [9800]	valid_0's binary_logloss: 0.0281288
# [9850]	valid_0's binary_logloss: 0.0281078
# [9900]	valid_0's binary_logloss: 0.0280932
# [9950]	valid_0's binary_logloss: 0.0280829
# [10000]	valid_0's binary_logloss: 0.0280743
# [10050]	valid_0's binary_logloss: 0.0280488
# [10100]	valid_0's binary_logloss: 0.0280319
# [10150]	valid_0's binary_logloss: 0.0280131
# [10200]	valid_0's binary_logloss: 0.0279977
# [10250]	valid_0's binary_logloss: 0.0279771
# [10300]	valid_0's binary_logloss: 0.0279617
# [10350]	valid_0's binary_logloss: 0.027941
# [10400]	valid_0's binary_logloss: 0.0279302
# [10450]	valid_0's binary_logloss: 0.0279159
# [10500]	valid_0's binary_logloss: 0.0279042
# [10550]	valid_0's binary_logloss: 0.0278921
# [10600]	valid_0's binary_logloss: 0.0278662
# [10650]	valid_0's binary_logloss: 0.0278535
# [10700]	valid_0's binary_logloss: 0.0278367
# [10750]	valid_0's binary_logloss: 0.0278186
# [10800]	valid_0's binary_logloss: 0.0278091
# [10850]	valid_0's binary_logloss: 0.0277928
# [10900]	valid_0's binary_logloss: 0.0277701
# [10950]	valid_0's binary_logloss: 0.027756
# [11000]	valid_0's binary_logloss: 0.0277376
# [11050]	valid_0's binary_logloss: 0.0277225
# [11100]	valid_0's binary_logloss: 0.027699
# [11150]	valid_0's binary_logloss: 0.0276876
# [11200]	valid_0's binary_logloss: 0.0276697
# [11250]	valid_0's binary_logloss: 0.0276532
# [11300]	valid_0's binary_logloss: 0.0276375
# [11350]	valid_0's binary_logloss: 0.0276252
# [11400]	valid_0's binary_logloss: 0.0276142
# [11450]	valid_0's binary_logloss: 0.027602
# [11500]	valid_0's binary_logloss: 0.0275853
# [11550]	valid_0's binary_logloss: 0.027573
# [11600]	valid_0's binary_logloss: 0.0275632
#
# == fold 2 ==
# [50]	valid_0's binary_logloss: 0.0436606
# [100]	valid_0's binary_logloss: 0.0419109
# [150]	valid_0's binary_logloss: 0.0410404
# [200]	valid_0's binary_logloss: 0.0405325
# [250]	valid_0's binary_logloss: 0.0401252
# [300]	valid_0's binary_logloss: 0.0397281
# [350]	valid_0's binary_logloss: 0.039366
# [400]	valid_0's binary_logloss: 0.0391045
# [450]	valid_0's binary_logloss: 0.0388626
# [500]	valid_0's binary_logloss: 0.0385792
# [550]	valid_0's binary_logloss: 0.0383755
# [600]	valid_0's binary_logloss: 0.0381491
# [650]	valid_0's binary_logloss: 0.0379745
# [700]	valid_0's binary_logloss: 0.0377715
# [750]	valid_0's binary_logloss: 0.0375989
# [800]	valid_0's binary_logloss: 0.0374501
# [850]	valid_0's binary_logloss: 0.0373266
# [900]	valid_0's binary_logloss: 0.0371521
# [950]	valid_0's binary_logloss: 0.0369909
# [1000]	valid_0's binary_logloss: 0.0368403
# [1050]	valid_0's binary_logloss: 0.0366908
# [1100]	valid_0's binary_logloss: 0.0365514
# [1150]	valid_0's binary_logloss: 0.036433
# [1200]	valid_0's binary_logloss: 0.0363212
# [1250]	valid_0's binary_logloss: 0.03619
# [1300]	valid_0's binary_logloss: 0.0360666
# [1350]	valid_0's binary_logloss: 0.0359409
# [1400]	valid_0's binary_logloss: 0.0358044
# [1450]	valid_0's binary_logloss: 0.0356994
# [1500]	valid_0's binary_logloss: 0.035592
# [1550]	valid_0's binary_logloss: 0.0354754
# [1600]	valid_0's binary_logloss: 0.0353854
# [1650]	valid_0's binary_logloss: 0.0352732
# [1700]	valid_0's binary_logloss: 0.0351738
# [1750]	valid_0's binary_logloss: 0.0350741
# [1800]	valid_0's binary_logloss: 0.0349835
# [1850]	valid_0's binary_logloss: 0.0349056
# [1900]	valid_0's binary_logloss: 0.0348348
# [1950]	valid_0's binary_logloss: 0.0347348
# [2000]	valid_0's binary_logloss: 0.0346418
# [2050]	valid_0's binary_logloss: 0.0345607
# [2100]	valid_0's binary_logloss: 0.0344754
# [2150]	valid_0's binary_logloss: 0.0343806
# [2200]	valid_0's binary_logloss: 0.0342881
# [2250]	valid_0's binary_logloss: 0.0342169
# [2300]	valid_0's binary_logloss: 0.0341428
# [2350]	valid_0's binary_logloss: 0.0340636
# [2400]	valid_0's binary_logloss: 0.0339787
# [2450]	valid_0's binary_logloss: 0.0339064
# [2500]	valid_0's binary_logloss: 0.0338402
# [2550]	valid_0's binary_logloss: 0.0337573
# [2600]	valid_0's binary_logloss: 0.0336827
# [2650]	valid_0's binary_logloss: 0.0336147
# [2700]	valid_0's binary_logloss: 0.0335509
# [2750]	valid_0's binary_logloss: 0.0334745
# [2800]	valid_0's binary_logloss: 0.0334094
# [2850]	valid_0's binary_logloss: 0.0333445
# [2900]	valid_0's binary_logloss: 0.0332739
# [2950]	valid_0's binary_logloss: 0.0331984
# [3000]	valid_0's binary_logloss: 0.033137
# [3050]	valid_0's binary_logloss: 0.0330797
# [3100]	valid_0's binary_logloss: 0.0330083
# [3150]	valid_0's binary_logloss: 0.032926
# [3200]	valid_0's binary_logloss: 0.0328442
# [3250]	valid_0's binary_logloss: 0.032784
# [3300]	valid_0's binary_logloss: 0.0327093
# [3350]	valid_0's binary_logloss: 0.032645
# [3400]	valid_0's binary_logloss: 0.0325791
# [3450]	valid_0's binary_logloss: 0.0325083
# [3500]	valid_0's binary_logloss: 0.0324451
# [3550]	valid_0's binary_logloss: 0.0323856
# [3600]	valid_0's binary_logloss: 0.032337
# [3650]	valid_0's binary_logloss: 0.032294
# [3700]	valid_0's binary_logloss: 0.0322403
# [3750]	valid_0's binary_logloss: 0.0321743
# [3800]	valid_0's binary_logloss: 0.0321083
# [3850]	valid_0's binary_logloss: 0.0320526
# [3900]	valid_0's binary_logloss: 0.0319914
# [3950]	valid_0's binary_logloss: 0.0319488
# [4000]	valid_0's binary_logloss: 0.0318994
# [4050]	valid_0's binary_logloss: 0.0318413
# [4100]	valid_0's binary_logloss: 0.0317879
# [4150]	valid_0's binary_logloss: 0.0317446
# [4200]	valid_0's binary_logloss: 0.031697
# [4250]	valid_0's binary_logloss: 0.0316442
# [4300]	valid_0's binary_logloss: 0.0315841
# [4350]	valid_0's binary_logloss: 0.03153
# [4400]	valid_0's binary_logloss: 0.0314888
# [4450]	valid_0's binary_logloss: 0.0314456
# [4500]	valid_0's binary_logloss: 0.0313976
# [4550]	valid_0's binary_logloss: 0.0313546
# [4600]	valid_0's binary_logloss: 0.0313146
# [4650]	valid_0's binary_logloss: 0.0312534
# [4700]	valid_0's binary_logloss: 0.0312069
# [4750]	valid_0's binary_logloss: 0.0311557
# [4800]	valid_0's binary_logloss: 0.0311093
# [4850]	valid_0's binary_logloss: 0.0310704
# [4900]	valid_0's binary_logloss: 0.0310267
# [4950]	valid_0's binary_logloss: 0.0309784
# [5000]	valid_0's binary_logloss: 0.0309317
# [5050]	valid_0's binary_logloss: 0.0308864
# [5100]	valid_0's binary_logloss: 0.0308354
# [5150]	valid_0's binary_logloss: 0.0307994
# [5200]	valid_0's binary_logloss: 0.0307686
# [5250]	valid_0's binary_logloss: 0.0307199
# [5300]	valid_0's binary_logloss: 0.0306754
# [5350]	valid_0's binary_logloss: 0.0306279
# [5400]	valid_0's binary_logloss: 0.0305792
# [5450]	valid_0's binary_logloss: 0.0305334
# [5500]	valid_0's binary_logloss: 0.0304986
# [5550]	valid_0's binary_logloss: 0.0304562
# [5600]	valid_0's binary_logloss: 0.030417
# [5650]	valid_0's binary_logloss: 0.0303854
# [5700]	valid_0's binary_logloss: 0.03034
# [5750]	valid_0's binary_logloss: 0.0303112
# [5800]	valid_0's binary_logloss: 0.0302713
# [5850]	valid_0's binary_logloss: 0.0302226
# [5900]	valid_0's binary_logloss: 0.0301873
# [5950]	valid_0's binary_logloss: 0.0301571
# [6000]	valid_0's binary_logloss: 0.0301231
# [6050]	valid_0's binary_logloss: 0.0301012
# [6100]	valid_0's binary_logloss: 0.030069
# [6150]	valid_0's binary_logloss: 0.030037
# [6200]	valid_0's binary_logloss: 0.0300046
# [6250]	valid_0's binary_logloss: 0.0299696
# [6300]	valid_0's binary_logloss: 0.029953
# [6350]	valid_0's binary_logloss: 0.0299284
# [6400]	valid_0's binary_logloss: 0.0298874
# [6450]	valid_0's binary_logloss: 0.0298576
# [6500]	valid_0's binary_logloss: 0.0298209
# [6550]	valid_0's binary_logloss: 0.0297857
# [6600]	valid_0's binary_logloss: 0.0297501
# [6650]	valid_0's binary_logloss: 0.029714
# [6700]	valid_0's binary_logloss: 0.0296791
# [6750]	valid_0's binary_logloss: 0.0296437
# [6800]	valid_0's binary_logloss: 0.0296003
# [6850]	valid_0's binary_logloss: 0.0295643
# [6900]	valid_0's binary_logloss: 0.0295312
# [6950]	valid_0's binary_logloss: 0.0295036
# [7000]	valid_0's binary_logloss: 0.0294644
# [7050]	valid_0's binary_logloss: 0.0294379
# [7100]	valid_0's binary_logloss: 0.0294041
# [7150]	valid_0's binary_logloss: 0.0293772
# [7200]	valid_0's binary_logloss: 0.0293586
# [7250]	valid_0's binary_logloss: 0.0293296
# [7300]	valid_0's binary_logloss: 0.0293078
# [7350]	valid_0's binary_logloss: 0.0292785
# [7400]	valid_0's binary_logloss: 0.0292519
# [7450]	valid_0's binary_logloss: 0.0292234
# [7500]	valid_0's binary_logloss: 0.0291955
# [7550]	valid_0's binary_logloss: 0.0291678
# [7600]	valid_0's binary_logloss: 0.0291463
# [7650]	valid_0's binary_logloss: 0.0291128
# [7700]	valid_0's binary_logloss: 0.0290875
# [7750]	valid_0's binary_logloss: 0.0290596
# [7800]	valid_0's binary_logloss: 0.0290365
# [7850]	valid_0's binary_logloss: 0.0290096
# [7900]	valid_0's binary_logloss: 0.0289804
# [7950]	valid_0's binary_logloss: 0.0289562
# [8000]	valid_0's binary_logloss: 0.0289352
# [8050]	valid_0's binary_logloss: 0.0289135
# [8100]	valid_0's binary_logloss: 0.0288911
# [8150]	valid_0's binary_logloss: 0.0288718
# [8200]	valid_0's binary_logloss: 0.0288487
# [8250]	valid_0's binary_logloss: 0.028829
# [8300]	valid_0's binary_logloss: 0.0288101
# [8350]	valid_0's binary_logloss: 0.0287907
# [8400]	valid_0's binary_logloss: 0.0287638
# [8450]	valid_0's binary_logloss: 0.0287459
# [8500]	valid_0's binary_logloss: 0.0287242
# [8550]	valid_0's binary_logloss: 0.0287033
# [8600]	valid_0's binary_logloss: 0.0286861
# [8650]	valid_0's binary_logloss: 0.0286535
# [8700]	valid_0's binary_logloss: 0.0286242
# [8750]	valid_0's binary_logloss: 0.0286071
# [8800]	valid_0's binary_logloss: 0.0285823
# [8850]	valid_0's binary_logloss: 0.0285551
# [8900]	valid_0's binary_logloss: 0.0285286
# [8950]	valid_0's binary_logloss: 0.0284998
# [9000]	valid_0's binary_logloss: 0.0284784
# [9050]	valid_0's binary_logloss: 0.028467
# [9100]	valid_0's binary_logloss: 0.0284503
# [9150]	valid_0's binary_logloss: 0.0284278
# [9200]	valid_0's binary_logloss: 0.0284011
# [9250]	valid_0's binary_logloss: 0.0283846
# [9300]	valid_0's binary_logloss: 0.0283665
# [9350]	valid_0's binary_logloss: 0.0283523
# [9400]	valid_0's binary_logloss: 0.0283303
# [9450]	valid_0's binary_logloss: 0.02832
# [9500]	valid_0's binary_logloss: 0.0283003
# [9550]	valid_0's binary_logloss: 0.0282755
# [9600]	valid_0's binary_logloss: 0.0282549
# [9650]	valid_0's binary_logloss: 0.0282422
# [9700]	valid_0's binary_logloss: 0.0282224
# [9750]	valid_0's binary_logloss: 0.0282067
# [9800]	valid_0's binary_logloss: 0.028183
# [9850]	valid_0's binary_logloss: 0.0281652
# [9900]	valid_0's binary_logloss: 0.0281439
# [9950]	valid_0's binary_logloss: 0.0281227
# [10000]	valid_0's binary_logloss: 0.0281033
# [10050]	valid_0's binary_logloss: 0.0280778
# [10100]	valid_0's binary_logloss: 0.0280579
# [10150]	valid_0's binary_logloss: 0.0280365
# [10200]	valid_0's binary_logloss: 0.0280205
# [10250]	valid_0's binary_logloss: 0.028007
# [10300]	valid_0's binary_logloss: 0.0279937
# [10350]	valid_0's binary_logloss: 0.0279804
# [10400]	valid_0's binary_logloss: 0.0279697
# [10450]	valid_0's binary_logloss: 0.0279481
# [10500]	valid_0's binary_logloss: 0.0279437
#
# CV-accuracy: 0.9909576044957312

# %%
train_data["pred"] = oof[:, -1]

# %%
out_df = pd.DataFrame()
out_df['id'] = train_data['id'].unique().tolist()
out_df['match_id'] = out_df['id']

# %% [markdown]
# #Check Feature Importances

# %%
def plot_importances(models):
    importance_df = pd.DataFrame(models[0].feature_importances_, 
                                 index=features, 
                                 columns=['importance'])\
                        .sort_values("importance", ascending=False)

    plt.subplots(figsize=(len(features) // 4, 5))
    plt.bar(importance_df.index, importance_df.importance)
    plt.grid()
    plt.xticks(rotation=90)
    plt.ylabel("importance")
    plt.tight_layout()
    plt.show()

plot_importances(models)

# %% [markdown]
# #Check CV

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 4.3 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.36)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 58.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.3)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.1 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.7.1)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.6 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 55.1 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 57.9 MB/s
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.2.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=ee4c791c4e376e4ff449912b48763eed1a8b3a333552d2eb17da1e0aec09edae
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.0 alembic-1.7.7 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 optuna-2.10.0 pbr-5.9.0 pyperclip-1.8.2 stevedore-3.5.0

# %%
def post_process(df):
    id2match = dict(zip(df['id'].values, df['matches'].str.split()))

    for base, match in df[['id', 'matches']].values:
        match = match.split()
        if len(match) == 1:        
            continue

        for m in match:
            if base not in id2match[m]:
                id2match[m].append(base)
    df['matches'] = df['id'].map(id2match).map(' '.join)
    return df

# %%
import optuna

def objective(trial):
    x = trial.suggest_uniform('threshold', 0, 1)
    train_pred_df = train_data[train_data['pred'] > x][['id', 'match_id']]
    train_pred_df = train_pred_df.groupby('id')['match_id'].\
                        apply(list).reset_index()
    train_pred_df['matches'] = train_pred_df['match_id'].apply(lambda x: ' '.join(set(x)))
    train_pred_df = post_process(train_pred_df)
    score = get_score(train_pred_df)
    print(f"CV: {score:.6f}")
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2022-05-21 22:52:32,016] A new study created in memory with name: no-name-b2d76ee5-8863-4d1f-b627-9a3a9cfe9d7b
# [I 2022-05-21 22:53:23,135] Trial 0 finished with value: 0.8689446784172689 and parameters: {'threshold': 0.6431809911441491}. Best is trial 0 with value: 0.8689446784172689.
# CV: 0.868945
# [I 2022-05-21 22:53:41,830] Trial 1 finished with value: 0.8504452342329056 and parameters: {'threshold': 0.2445095691076018}. Best is trial 0 with value: 0.8689446784172689.
# CV: 0.850445
# [I 2022-05-21 22:54:00,771] Trial 2 finished with value: 0.8676979027065052 and parameters: {'threshold': 0.45722727025316134}. Best is trial 0 with value: 0.8689446784172689.
# CV: 0.867698
# [I 2022-05-21 22:54:19,027] Trial 3 finished with value: 0.8698376418933278 and parameters: {'threshold': 0.560223475021837}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.869838
# [I 2022-05-21 22:54:37,911] Trial 4 finished with value: 0.8681937832983839 and parameters: {'threshold': 0.47026165898485406}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.868194
# [I 2022-05-21 22:54:56,537] Trial 5 finished with value: 0.8465032660530231 and parameters: {'threshold': 0.22085274764668827}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.846503
# [I 2022-05-21 22:55:17,727] Trial 6 finished with value: 0.7333900495945812 and parameters: {'threshold': 0.029077273935492642}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.733390
# [I 2022-05-21 22:55:36,563] Trial 7 finished with value: 0.86846450941217 and parameters: {'threshold': 0.4795839629622589}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.868465
# [I 2022-05-21 22:55:56,496] Trial 8 finished with value: 0.8030507067877856 and parameters: {'threshold': 0.08781106993422272}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.803051
# [I 2022-05-21 22:56:15,595] Trial 9 finished with value: 0.8684759471622197 and parameters: {'threshold': 0.48027328137257796}. Best is trial 3 with value: 0.8698376418933278.
# CV: 0.868476
# [W 2022-05-21 22:56:29,926] Trial 10 failed because of the following error: KeyError('E_f80078d2018ab5')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-27-bb3581855466>", line 8, in objective
#     train_pred_df = post_process(train_pred_df)
#   File "<ipython-input-26-b2a407a72a7d>", line 10, in post_process
#     if base not in id2match[m]:
# KeyError: 'E_f80078d2018ab5'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-bb3581855466> in <module>()
#      12
#      13 study = optuna.create_study(direction='maximize')
# ---> 14 study.optimize(objective, n_trials=100)
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     407             callbacks=callbacks,
#     408             gc_after_trial=gc_after_trial,
# --> 409             show_progress_bar=show_progress_bar,
#     410         )
#     411
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     262
#     263     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 264         raise func_err
#     265     return trial
#     266
#
# /usr/local/lib/python3.7/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-27-bb3581855466> in objective(trial)
#       6     train_pred_df = train_pred_df.groupby('id')['match_id'].                        apply(list).reset_index()
#       7     train_pred_df['matches'] = train_pred_df['match_id'].apply(lambda x: ' '.join(set(x)))
# ----> 8     train_pred_df = post_process(train_pred_df)
#       9     score = get_score(train_pred_df)
#      10     print(f"CV: {score:.6f}")
#
# <ipython-input-26-b2a407a72a7d> in post_process(df)
#       8
#       9         for m in match:
# ---> 10             if base not in id2match[m]:
#      11                 id2match[m].append(base)
#      12     df['matches'] = df['id'].map(id2match).map(' '.join)
#
# KeyError: 'E_f80078d2018ab5'

# %%
threshold = study.best_params['threshold']
threshold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f40927f7d58> in <module>()
# ----> 1 threshold = study.best_params['threshold']
#       2 threshold
#
# NameError: name 'study' is not defined

# %%
study.best_value

# %%
train_pred_df = train_data[train_data['pred'] > threshold][['id', 'match_id']]
train_pred_df = train_pred_df.groupby('id')['match_id'].\
                    apply(list).reset_index()
train_pred_df['matches'] = train_pred_df['match_id'].apply(lambda x: ' '.join(set(x)))
train_pred_df = post_process(train_pred_df)
score = get_score(train_pred_df)
print(f"CV: {score:.6f}")
