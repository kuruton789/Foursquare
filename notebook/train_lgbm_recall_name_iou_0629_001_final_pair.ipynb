# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install Levenshtein
    # !pip install unidecode
    # !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 4.2 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 63.8 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.3
#   Downloading jarowinkler-1.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#      |████████████████████████████████| 101 kB 11.9 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.4 rapidfuzz-2.0.15
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 4.3 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 4.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=1601643b6a5022896e4aaee34eebbc9db5c2546282e2268f144a2f5ee67524c8
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import seaborn as sns
import re
from requests import get
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from difflib import SequenceMatcher
import lightgbm as lgb
import pickle
import Levenshtein
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from unidecode import unidecode
import emoji
import re

random.seed(42)
np.random.seed(42)
warnings.filterwarnings('ignore')

# %%
if "google.colab" in sys.modules:
    expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0]
ROOT_PATH = '/content/drive/MyDrive/Kaggle/Foursquare'
INPUT_PATH = os.path.join(ROOT_PATH, 'input')
OUTPUT_PATH = os.path.join(os.path.join(ROOT_PATH, 'output'), expID)
MODEL_PATH = os.path.join(os.path.join(ROOT_PATH, 'models'), expID)
TARGET = 'point_of_interest'

# %%
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %%
N_NEIGHBORS = 100
NAME_RANK=5
ADDRESS_RANK = 3
CAT_RANK = 5
K_NEIGHBORS = 3
FILTER = 0.0
N_FOLD = 2
DISTANCE = 10000
CATEGORY_COUNT = 100
NAME_THRESHOLD = 0.4
CAT_THRESHOLD = 0.2

DEBUG = True
TFIDF = True
KDIST = True
NET = False # post processでは当たり前にやってた。# predの閾値は利用していなかったので、改良の余地あり。
MOJIBAKE = False
SAMPLING = False

def remove_emoji(src_str):
    return ''.join(c for c in src_str if c not in emoji.UNICODE_EMOJI)

# %%
# with open(os.path.join(OUTPUT_PATH, 'name_variants.pkl'), mode='rb') as f:
#     name_dict = pickle.load(f)

# %%
data = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
if DEBUG:
    data = data.iloc[:10000]
print(data.shape)

# cols = ['name', 'address', 'city', 'state']
cols = ['name']
# cols = ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone'] # categoriesは大文字が小文字になると困る。
for col in cols:
#     if col=='name':
#         data[col].update(data[col].map(name_dict))
    data[col] = data[col].fillna('').apply(unidecode)
    data[col] = data[col].str.lower()
    data[col] = data[col].apply(remove_emoji)

data.head()
# Out:
# (10000, 13)
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     cafe stad oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           carioca manero -22.907225  -43.178244
# 2  E_000007f24ebc95      raantadphmkaaraaekd  13.780813  100.484900
# 3  E_000008a8ba4f48                 turkcell  37.844510   27.844202
# 4  E_00001d92066153  restaurante casa cofino  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# 1   NaN  Brazilian Restaurants  P_d82910d8382a83
# 2   NaN   Salons / Barbershops  P_b1066599e78477
# 3   NaN     Mobile Phone Shops  P_b2ed86905a4cd3
# 4   NaN    Spanish Restaurants  P_809a884d4407fb

# %%
def sub(x):
    return re.sub(r'[^a-zA-Z0-9 ]', ' ', x)
cols = ['name', 'address', 'city', 'state']
# cols = ['name']
for col in cols:
    data[col] = data[col].fillna('').apply(sub)
    data[f'{col}_split'] = data[col].str.split()

# %%
if MOJIBAKE:
    data.loc[data['name'].str.contains('[买哪侈为裤溦发围货浓调时吧间价爱处灵节怎么办]', na=False), ['name', 'address', 'city']] = '<MOJIBAKE>'

# %%
kf = GroupKFold(n_splits=N_FOLD)
for i, (_, val_idx) in enumerate(kf.split(data, data[TARGET], data[TARGET])):
    data.loc[val_idx, "cv"] = i
print(data["cv"].value_counts())
# Out:
# 0.0    5000
# 1.0    5000
# Name: cv, dtype: int64

# %% [markdown]
# # add Data

# %%
with open(os.path.join(INPUT_PATH, 'id2com_30.pkl'), mode='rb') as f:
    id2com = pickle.load(f)
node_df = pd.read_csv(os.path.join(INPUT_PATH, 'node_df.csv'))
node_df.columns = ['main_category', 'id_code', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']
node_df = node_df[['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']]

def add_co_net(x):
    if x is np.nan:
        return np.nan
    out = -1
    for cat in x.split(', '):
        if cat in id2com.keys():
            out = id2com[cat]
            break

    return out

data['co_net'] = data['categories'].apply(add_co_net)

# %%
def add_main_category(x):
    if x is np.nan:
        return np.nan

    return x.split(', ')[0]

data['main_category'] = data['categories'].apply(add_main_category)

# %%
aggregated_df = pd.read_csv(os.path.join(INPUT_PATH, 'aggregated_df.csv'))
aggregated_df = aggregated_df.iloc[2:]
aggregated_df.columns = ['main_category', 'median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min', 'count']

float_cols = ['median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min']
aggregated_df[float_cols] = aggregated_df[float_cols].astype(float)
aggregated_df['count'] = aggregated_df['count'].astype(int)
aggregated_df['category_rate'] = aggregated_df['count'] / aggregated_df['count'].sum() # leakではない？

aggregated_df.head()
# Out:
#           main_category  median_distances_max  median_distances_75  \
# 2                  ATMs          1.446457e+07         27032.192275
# 3           Acai Houses          1.350800e+05         17781.269899
# 4    Accessories Stores          1.317399e+07         17636.724841
# 5  Acehnese Restaurants          1.394807e+05         28385.619678
# 6        Acupuncturists          1.099943e+06         30876.313672
#
#    median_distances_median  median_distances_25  median_distances_min  count  \
# 2              4490.248044          1012.594350              0.000000   1366
# 3              6117.784384          1359.040401             19.017952     25
# 4              4397.253023          1609.960599              0.000000    890
# 5             11585.417039          6524.589277            308.232222     22
# 6              5262.894842          1160.926141              0.000000     67
#
#    category_rate
# 2       0.002505
# 3       0.000046
# 4       0.001632
# 5       0.000040
# 6       0.000123

# %%
large_scales = list(aggregated_df[(aggregated_df['median_distances_median']>=DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)
small_scales = list(aggregated_df[(aggregated_df['median_distances_median']<DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)

def add_scale(x):
    categories = x.split(", ")
    out = -1
    for cat in categories:
        if cat in large_scales:
            out = 1
            break
        if cat in small_scales:
            out = 0
            break
    return out

data['scale'] = data['categories'].fillna('').apply(add_scale)
data.scale.value_counts()
# Out:
#  0    7918
#  1    1105
# -1     977
# Name: scale, dtype: int64

# %%
cols = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient']
data= data.merge(node_df[cols], on='main_category', how='left')

cols = ['main_category', 'median_distances_median', 'category_rate'] # maxとかはリークな気がする。
data= data.merge(aggregated_df[cols], on='main_category', how='left')

# %%
# category similarity
cats = data.categories.fillna('')

cat_stats = {}

for c in cats:
    csplit = c.split(", ")
    for c_ in csplit:
        if c_ not in cat_stats:
            cat_stats[c_] = [1, {ca: 1 for ca in csplit}]
        else:
            prev_cat_stats = cat_stats[c_]
            prev_cat_stats[0] += 1
            prev_sims = prev_cat_stats[1]
            
            for ca in csplit:
                prev_sims[ca] = prev_sims.get(ca, 0) + 1
        
for c, val in cat_stats.items():
    
    overall_count = sum(v for ca, v in val[1].items() if ca != c and v > 1)
    
    new_probs = {c: 1.0}
    if overall_count != 0:
        new_probs.update({ca: round(v / overall_count, 3) for ca, v in val[1].items() if v / overall_count > 0.01 and ca != c and v > 1})
        cat_stats[c] = [1.0, new_probs]
        
def get_cat_similarity(cat1, cat2):
    
    if cat1 == '' or cat2 == '':
        return 0.000000001
    
    if cat1 in cat2 or cat2 in cat1:
        return 1.0
    
    best = 0
    
    for c1 in cat1.split(", "):
        for c2 in cat2.split(", "):
            if c1 in cat_stats:
                best = max(best, cat_stats[c1][1].get(c2, 0))
            if c2 in cat_stats:
                best = max(best, cat_stats[c2][1].get(c1, 0))
    
    return best
get_cat_similarity('Bars', 'Cafes, Restaurants')
# Out:
# 0.101

# %% [markdown]
# # Generate Train Data

# %%
# def get_name_contain(name, match_name):
#     if name=='' or match_name=='':
#         return False
#     elif name in match_name or match_name in name:
#         return True
#     else:
#         return False

# def recall_knn_name(df, Neighbors = 10):
#     train = pd.DataFrame()
#     dfs = []
#     Neighbors = min(Neighbors, len(df))
#     knn = NearestNeighbors(n_neighbors = Neighbors)
#     knn.fit(df[['latitude','longitude']], df.index)
    
#     num_splits = len(df) // NUM_SPLIT_DATA
#     start_row = 0
#     for i in tqdm(range(1, NUM_SPLIT_DATA + 1)):
#         end_row = start_row + num_splits
#         if i < NUM_SPLIT_DATA:
#             tmp = df.iloc[start_row : end_row]
#         else:
#             tmp = df.iloc[start_row: ]
#         dists, nears = knn.kneighbors(tmp[['latitude','longitude']])
    
#         for k in tqdm(range(Neighbors)):            
#             cur_df = tmp[['id']]
#             cur_df['match_id'] = df['id'].values[nears[:, k]]
#             cur_df['kdist_name'] = dists[:, k]
#             cur_df['kneighbors_name'] = k
        
#             cols = ['name']
#     #         cols = ['name', 'categories', 'address']
#             for col in cols:
#                 cur_df[col] = tmp[col]
#                 cur_df[f'match_{col}'] = df[col].values[nears[:, k]]
#                 cur_df[f'{col}_contain'] = np.vectorize(get_name_contain)(cur_df[col], cur_df[f'match_{col}'])
#             cur_df = cur_df[(cur_df['name']==cur_df['match_name']) | (cur_df['name_contain'])]
        
#             dfs.append(cur_df)
#         start_row = end_row
#         print('end_row', end_row)

#     return pd.concat(dfs)

# cvs = []
# for i in range(N_FOLD):
#     tmp = recall_knn_name(data[data['cv']==i], 1000)
# #     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
# #               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
#     tmp['cv_name'] = i
#     print(tmp.shape)
#     cvs.append(tmp)
# train_name = pd.concat(cvs)
# print(train_name.shape)
# # train_name.drop(['name', 'match_name', 'name_contain', 'kneighbors_name'], axis=1, inplace=True)
# # train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
# # train.drop(['address', 'match_address', 'address_split', 'match_address_split'], axis=1, inplace=True)
# train_name.drop(['name', 'match_name', 'name_contain'], axis=1, inplace=True)
# train_name.head()
# # 8679523

# %%
def sm_ratio_name(x):
    return SequenceMatcher(None, x['name'], x['match_name']).ratio()

def sm_ratio_name(name, match_name):
    return SequenceMatcher(None, name, match_name).ratio()

def get_name_iou(name_split, match_name_split):
    if len(set(name_split) | set(match_name_split))==0:
        return 0
    else:
        return len(set(name_split) & set(match_name_split)) / len(set(name_split) | set(match_name_split))

def apply_get_cat_similarity(categories, match_categories):
    return get_cat_similarity(categories, match_categories)

def recall_knn_name(df, Neighbors = 10):
    train = pd.DataFrame()
    dfs = []
    Neighbors = min(Neighbors, len(df))
    # print(f'{Neighbors=}')
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in tqdm(range(Neighbors)):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        
        cols = ['name', 'categories']
        for col in cols:
            cur_df[col] = df[col]
            cur_df[f'match_{col}'] = df[col].values[nears[:, k]]

        cols = ['name']
        for col in cols:
            cur_df[f'{col}_split'] = df[f'{col}_split']
            cur_df[f'match_{col}_split'] = df[f'{col}_split'].values[nears[:, k]]
            cur_df[f'{col}_iou'] = np.vectorize(get_name_iou)(cur_df[f'{col}_split'], cur_df[f'match_{col}_split'])
        
        cur_df['cat_similarity'] = np.vectorize(apply_get_cat_similarity)(cur_df['categories'].fillna(''), cur_df['match_categories'].fillna(''))
        cur_df = cur_df[(cur_df['cat_similarity']>0.0) | (cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
#                        | (cur_df['address_iou']>0.0)| (cur_df['city_iou']>0.0)| (cur_df['state_iou']>0.0)]
#         cur_df = cur_df[(cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
        dfs.append(cur_df)
        
        if k!=0 and (k % 50 == 0 or k==Neighbors-1):
            print(f'calc rank: {k}')
            tmp = pd.concat(dfs)
            tmp['sm_ratio_name'] = np.vectorize(sm_ratio_name)(tmp['name'], tmp['match_name'])
            tmp['name_rank'] = 99 # 念の為、入れておく
#             tmp['cat_rank'] = 99 # 念の為、入れておく
            train = pd.concat([train, tmp])
            train['name_rank'] = train.groupby('id')['sm_ratio_name'].rank(ascending=False, method='dense')
#             train['cat_rank'] = train.groupby('id')['cat_similarity'].rank(ascending=False, method='dense')
            train = train[((train['name_rank']<=NAME_RANK) & train['sm_ratio_name']>0.0) | 
                                  (train['categories']==train['match_categories']) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   (train['cat_similarity']==1.0) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   ((train['cat_rank']<=CAT_RANK) & (train['cat_similarity']>0.0) & (train['sm_ratio_name']>0.0)) | 
                                  (train['kneighbors']<K_NEIGHBORS)]
            del tmp, dfs
            dfs = []

    return train

cvs = []
for i in range(N_FOLD):
    tmp = recall_knn_name(data[data['cv']==i], N_NEIGHBORS)
#     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
#               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
    tmp['cv'] = i
    cvs.append(tmp)
train = pd.concat(cvs)
print(train.shape)
train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
train.head()
# 8679523
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 89
#   0%|          | 0/90 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 89
# (61769, 15)
#                  id          match_id  kdist  kneighbors  name_iou  \
# 0  E_000001272c6c5d  E_000001272c6c5d    0.0           0       1.0
# 2  E_000007f24ebc95  E_000007f24ebc95    0.0           0       1.0
# 3  E_000008a8ba4f48  E_000008a8ba4f48    0.0           0       1.0
# 6  E_00002a131a2bf6  E_00002a131a2bf6    0.0           0       1.0
# 8  E_00007dcd2bb53f  E_00007dcd2bb53f    0.0           0       1.0
#
#    cat_similarity  name_rank  cv
# 0             1.0        1.0   0
# 2             1.0        1.0   0
# 3             1.0        1.0   0
# 6             1.0        1.0   0
# 8             1.0        1.0   0

# %%
# train.to_csv(os.path.join(OUTPUT_PATH, 'train_pred_100.csv'), index = False)

# %%
# train = train.merge(train_name, on = ['id', 'match_id'], how = 'outer')
# train.head()

# %%
# train.loc[train['cv'].isnull(), 'cv'] = train.loc[train['cv'].isnull(), 'cv_name']
# train.loc[train['kdist'].isnull(), 'kdist'] = train.loc[train['kdist'].isnull(), 'kdist_name']
# train.drop(['cv_name', 'kdist_name'], axis=1, inplace=True)

# %%
if TFIDF:
    id2index_d = dict(zip(data['id'].values, data.index)) # tf-idfで使う
data = data.set_index('id')

# %%
for col in ['co_net', 'scale']:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'is_match_{col}'] = train[col]==train[f'match_{col}']
# train.drop(['co_net', 'match_co_net', 'scale', 'match_scale'], axis=1, inplace=True)

# %%
num_cols = ['adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'median_distances_median', 'category_rate']
for col in num_cols:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'mean_{col}'] = (train[col] + train[f'match_{col}']) / 2
#     train.drop([col, f'match_{col}'], axis=1, inplace=True)

# %%
# label作り

ids = train['id'].tolist()
match_ids = train['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train['label'] = np.array(poi == match_poi, dtype = np.int8)

# %% [markdown]
# # Check Maximum Score

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(data.index.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(train.iterrows()):
    if row['label']==1:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
# for base, match in oof_pred.items():
#     if len(match) == 1:        
#         continue

#     for m in match:
#         if base not in oof_pred[m]:
#             oof_pred[m].append(base)

# %%
ids = list(data.index.unique())
scores = []

for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('max score is ', np.array(scores).mean())
# 0.913(30, co_net)
# 50: 0.928(5), 0.930(10)
# 100: 0.930, 0.938
# 200: 0.934
# 300: 0.938

# scale(10000)
# 50: 0.928
# 300: 0.941

# 0.926
# 0.918
# 0.933
# 0.940
# 0.941
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# max score is  0.6507149183908703

# %%
train['label'].value_counts()
# 0    5067914
# 1    1980366

# 0    3326444
# 1    1952844
# Out:
# 0    51682
# 1    10087
# Name: label, dtype: int64

# %%
train.label.mean()
# 0.232
# 0.223
# Out:
# 0.16330197995758391

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'))

# %%
data.to_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = pd.read_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = data.set_index('id')

# data2 = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
# id2index_d = dict(zip(data2['id'].values, data2.index))
# del data2

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            print(col)
            pass
#             df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ## Candidate Miss Sampling

# %%
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    if preds != targets:
        print(f'preds: {preds}')
        print(f'targets: {targets}')
        print(f'{TARGET}: {id2poi[id_x]}')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# targets: {'E_01ac18fb3338f8', 'E_18b1f2b78f43d7'}
# point_of_interest: P_3811acd239ccce
# preds: {'E_01ac3594e0eaa6'}
# targets: {'E_01ac3594e0eaa6', 'E_76138b1f711c7c'}
# point_of_interest: P_86ff4eb1df500a
# preds: {'E_01ac4421b39daf'}
# targets: {'E_cead52c4c25644', 'E_cc60ea6ce1889b', 'E_01ac4421b39daf', 'E_a96bbd8438ec41', 'E_6e41470a277787', 'E_69f844c9ec3b6a', 'E_8ca40c615e1315', 'E_e81f96408ed8b6'}
# point_of_interest: P_f41b41191c85c3
# preds: {'E_01ac466df9096c'}
# targets: {'E_09c18a59b1b260', 'E_01ac466df9096c'}
# point_of_interest: P_2cda6069ddce14
# preds: {'E_01ac4d0d727f91'}
# targets: {'E_01ac4d0d727f91', 'E_8f40a54c75a8c1', 'E_789721eabbf90c', 'E_f1b714975f00a9'}
# point_of_interest: P_688c231df7c57d
# preds: {'E_01ac569e78e6f2'}
# targets: {'E_01ac569e78e6f2', 'E_bbd60998e28c63'}
# point_of_interest: P_9f30491b245752
# preds: {'E_01ac6b7f236e00'}
# targets: {'E_3d826290bc5dfa', 'E_01ac6b7f236e00'}
# point_of_interest: P_c3c66900d5b3d9
# preds: {'E_01ac6cbb76e779'}
# targets: {'E_f529611dfdbc76', 'E_01ac6cbb76e779'}
# point_of_interest: P_c116ddefbd3398
# preds: {'E_01ac7bf451f2b6'}
# targets: {'E_1445ddae0aeb45', 'E_01ac7bf451f2b6'}
# point_of_interest: P_31f76cddfbd503
# preds: {'E_01ac7dbe6ed1ab'}
# targets: {'E_7cff511e2abcea', 'E_01ac7dbe6ed1ab', 'E_5f912002a43dea'}
# point_of_interest: P_83fd5e6a0d8ecd
# preds: {'E_01ac7f19e03cb9'}
# targets: {'E_01ac7f19e03cb9', 'E_1f0f2be5650f0b'}
# point_of_interest: P_e60232e308525c
# preds: {'E_01ac89599b46de'}
# targets: {'E_01ac89599b46de', 'E_ee0b764f8774e8'}
# point_of_interest: P_11972981bf0d90
# preds: {'E_01acb300e64fd4'}
# targets: {'E_01acb300e64fd4', 'E_83d0e9c03b3659'}
# point_of_interest: P_5d6253b1429e37
# preds: {'E_01ad053c0be4f0'}
# targets: {'E_3ce9082ee7056c', 'E_01ad053c0be4f0'}
# point_of_interest: P_a38d29517ff8da
# preds: {'E_01ad0b4ed1c175'}
# targets: {'E_01ad0b4ed1c175', 'E_610066a5922cff'}
# point_of_interest: P_429041c7b1a721
# preds: {'E_01ad3199091c91'}
# targets: {'E_7b5f4098338c4f', 'E_01ad3199091c91'}
# point_of_interest: P_7dc29aac4a7b7d
# preds: {'E_01ad39671925f4'}
# targets: {'E_c016f21e97aacf', 'E_01ad39671925f4'}
# point_of_interest: P_8dad58626ea847
# preds: {'E_01ad5887585bc3'}
# targets: {'E_01ad5887585bc3', 'E_c11658e4bf6d52'}
# point_of_interest: P_39afb8408b78e4
# preds: {'E_01ad6d432978bf'}
# targets: {'E_01ad6d432978bf', 'E_5b505b1511dc54'}
# point_of_interest: P_498dafa0887a87
# preds: {'E_01ad8fbdf911f5'}
# targets: {'E_1d322d73a2b383', 'E_01ad8fbdf911f5'}
# point_of_interest: P_09d5c64c2d3938
# preds: {'E_01ada867935ffc'}
# targets: {'E_01ada867935ffc', 'E_08cb6f2b4e1ed2'}
# point_of_interest: P_c1467f2a52f539
# preds: {'E_01adc9f0969073'}
# targets: {'E_01adc9f0969073', 'E_51abd7eccccca2'}
# point_of_interest: P_736b4a25214127
# preds: {'E_01ae028735e681'}
# targets: {'E_01ae028735e681', 'E_7baf4660c8893e'}
# point_of_interest: P_fa85d39ff86bb9
# preds: {'E_01ae0afb672fd4'}
# targets: {'E_01ae0afb672fd4', 'E_6d13006ba31d0c'}
# point_of_interest: P_f48aabb03ca52c
# preds: {'E_019f9484b85264', 'E_01ae2eefb1f7e8'}
# targets: {'E_01ae2eefb1f7e8', 'E_c550b9bcf57056', 'E_d3f2adacdce143', 'E_019f9484b85264', 'E_629cbf6444ba4f'}
# point_of_interest: P_068653d153c660
# preds: {'E_01ae487b051c89'}
# targets: {'E_4e8b78d82a3c38', 'E_01ae487b051c89', 'E_fa1f714a2969bb', 'E_cbbcb74779dda3'}
# point_of_interest: P_0c7eaf7c27709d
# preds: {'E_01ae54e7b13893'}
# targets: {'E_01ae54e7b13893', 'E_228bb093bbc493'}
# point_of_interest: P_3b498e7f59a781
# preds: {'E_01ae5679ad2f19'}
# targets: {'E_dfad27e02805be', 'E_01ae5679ad2f19'}
# point_of_interest: P_bbb21e6010613f
# preds: {'E_01ae5af9538d56'}
# targets: {'E_dfba6847b7efd3', 'E_01ae5af9538d56'}
# point_of_interest: P_ac21fc2b6229ba
# preds: {'E_01ae65c74b882a'}
# targets: {'E_01ae65c74b882a', 'E_14d19ac950f9c1'}
# point_of_interest: P_40f14e1e0378a4
# preds: {'E_01ae6732de10ca'}
# targets: {'E_01ae6732de10ca', 'E_1194e473a58c88'}
# point_of_interest: P_2a3f760d045dea
# preds: {'E_01ae88f42c7130'}
# targets: {'E_01ae88f42c7130', 'E_caaa690f6a406a'}
# point_of_interest: P_f12a336969f2cb
# preds: {'E_01ae89c52df6f4'}
# targets: {'E_2bb73fa31a730c', 'E_01ae89c52df6f4'}
# point_of_interest: P_8d51a7865e1443
# preds: {'E_01aebb283f72d3'}
# targets: {'E_a2e8f460c3e3dc', 'E_01aebb283f72d3'}
# point_of_interest: P_182fe2a981a964
# preds: {'E_01aeeb1fbdc511'}
# targets: {'E_01aeeb1fbdc511', 'E_07563a07f984c0'}
# point_of_interest: P_190b5f99fb5d0c
# preds: {'E_01aef49d348dab'}
# targets: {'E_4e5d32337cdfd2', 'E_81f774f5f9bd26', 'E_2a14ae5d9a528e', 'E_01aef49d348dab'}
# point_of_interest: P_bf94a7d4592160
# preds: {'E_01af1ad8a65175'}
# targets: {'E_9fdb2c1a7b4676', 'E_ed25cc3f183286', 'E_01af1ad8a65175'}
# point_of_interest: P_25c77d098bdcec
# preds: {'E_01af26d9483fc0'}
# targets: {'E_72ea9a538f8912', 'E_01af26d9483fc0'}
# point_of_interest: P_55e246a65a3164
# preds: {'E_01af2a42ee7823'}
# targets: {'E_f5bd4e46e527a6', 'E_01af2a42ee7823'}
# point_of_interest: P_7c89b678099ffc
# preds: {'E_01af2c21a90331'}
# targets: {'E_1bb5f8196a961d', 'E_01af2c21a90331'}
# point_of_interest: P_8ecfb086308bfd
# preds: {'E_01af391db216c4'}
# targets: {'E_b47d012438bdd9', 'E_01af391db216c4'}
# point_of_interest: P_dc6c91e745556d
# preds: {'E_01af398f3b5302'}
# targets: {'E_cb66750b18f1e5', 'E_01af398f3b5302'}
# point_of_interest: P_05ddc9062a7195
# preds: {'E_01af6d4f8cc185'}
# targets: {'E_01af6d4f8cc185', 'E_06946a65dead3e', 'E_ae429c2765a530'}
# point_of_interest: P_c0118c9d597509
# preds: {'E_01af6f748a7782'}
# targets: {'E_01af6f748a7782', 'E_f6547dc8883250'}
# point_of_interest: P_2f687f271bec4c
# preds: {'E_01af7378053822'}
# targets: {'E_01af7378053822', 'E_6e44436d0d06d8'}
# point_of_interest: P_bc8be05bd06a70
# preds: {'E_01af8cdb40daf4'}
# targets: {'E_de745193255bd0', 'E_01af8cdb40daf4'}
# point_of_interest: P_e4028ab09484ea
# preds: {'E_01af92b2bbe159'}
# targets: {'E_a2b375fdbb11b6', 'E_01af92b2bbe159'}
# point_of_interest: P_6522b8fa55e3aa
# preds: {'E_01af9aab047e8d'}
# targets: {'E_f0d168efc5088f', 'E_01af9aab047e8d'}
# point_of_interest: P_7544b6b963972a
# preds: {'E_01afc80592b489'}
# targets: {'E_e010f94b492d6d', 'E_2d3cdf7c9fa621', 'E_586bc0282f8aba', 'E_95721f1a0721ae', 'E_b8afb03d5ad3b6', 'E_604eb7b8147dfb', 'E_01afc80592b489', 'E_8b40ff79fe16b1', 'E_3914b52c4e4eda', 'E_09cc368f5d2699', 'E_fbd692a6a51b05', 'E_a6ab62b4796cee', 'E_2ca9d4bf16b948', 'E_49be79b68389eb', 'E_cd21d90e03608d', 'E_0770769a358634', 'E_921337d80f3dae', 'E_96efde25316564', 'E_667ff2c4613735'}
# point_of_interest: P_6d6283eb3d77f8
# preds: {'E_01afeef43f3e43'}
# targets: {'E_01afeef43f3e43', 'E_a61046a2dac690'}
# point_of_interest: P_bbde487b4705cf
# preds: {'E_01aff8ae1b6976'}
# targets: {'E_08a8c968b962a7', 'E_71e5bfd2370b87', 'E_8c4fb49bdc77c9', 'E_01aff8ae1b6976'}
# point_of_interest: P_05091251ee9b32
# preds: {'E_01b00a7170e9f0'}
# targets: {'E_d67a04ea64fd80', 'E_01b00a7170e9f0'}
# point_of_interest: P_da2723896f40f6
# preds: {'E_01b019b33dbc3f'}
# targets: {'E_1240f3f9f8c51c', 'E_01b019b33dbc3f'}
# point_of_interest: P_a28d81ced9bbfa
# preds: {'E_01b023a35b9cd2'}
# targets: {'E_01b023a35b9cd2', 'E_4cb661ee70b614'}
# point_of_interest: P_1ee6621f8215b7
# preds: {'E_01b036fca418c8'}
# targets: {'E_01b036fca418c8', 'E_3ef134874e5d76', 'E_36ab5a6bede677'}
# point_of_interest: P_576b3748ce2e31
# preds: {'E_01b052dcbe9e0a'}
# targets: {'E_01b052dcbe9e0a', 'E_13ed62e4734574'}
# point_of_interest: P_7db14f188d25e8
# preds: {'E_01b074ef3bbc06'}
# targets: {'E_01b074ef3bbc06', 'E_229c41b84184fb'}
# point_of_interest: P_c19d9f3cefe78d
# preds: {'E_01b07f1b09d8fd'}
# targets: {'E_01b07f1b09d8fd', 'E_3ff469f0c50548'}
# point_of_interest: P_3eb09dbf74e6fa
# preds: {'E_01b09b399de4b9'}
# targets: {'E_daef2df27398a2', 'E_01b09b399de4b9'}
# point_of_interest: P_d3d3f3537a6849
# preds: {'E_01b09efb7d916a'}
# targets: {'E_01b09efb7d916a', 'E_8391c2ee38e90a'}
# point_of_interest: P_26be7c279dd927
# preds: {'E_01b0a987e04dfd'}
# targets: {'E_01b0a987e04dfd', 'E_ffbc3a9796b9f9'}
# point_of_interest: P_bec41d7ab65bcb
# preds: {'E_01b0be3680a942'}
# targets: {'E_9070e06cfba550', 'E_01b0be3680a942'}
# point_of_interest: P_a5389fbc367f06
# preds: {'E_01b0e105d3a3e5'}
# targets: {'E_f8e78bc01ce4ab', 'E_01b0e105d3a3e5'}
# point_of_interest: P_7bb56bf616f4da
# preds: {'E_01b10f0f401200'}
# targets: {'E_01b10f0f401200', 'E_54e298bb7a6ec2'}
# point_of_interest: P_5cce1456539100
# preds: {'E_01b118a7c41209'}
# targets: {'E_6965ef76158430', 'E_01b118a7c41209'}
# point_of_interest: P_6e0bfe8ee7efdb
# preds: {'E_01b1397a9447ca'}
# targets: {'E_01b1397a9447ca', 'E_553165d41ec799'}
# point_of_interest: P_9b204a720e7962
# preds: {'E_01b16d6a56c6d0'}
# targets: {'E_3d80af0ee0eae2', 'E_01b16d6a56c6d0'}
# point_of_interest: P_414bb1a08c0599
# preds: {'E_01b16db7750328'}
# targets: {'E_147ade78136979', 'E_64f1b80c096c01', 'E_01b16db7750328'}
# point_of_interest: P_5048c41c745302
# preds: {'E_01b1854cd64b52'}
# targets: {'E_01b1854cd64b52', 'E_07a90a4ab85f7e'}
# point_of_interest: P_a427a097faf4a0
# preds: {'E_01b18d36797362'}
# targets: {'E_01b18d36797362', 'E_20c9986c537ddb'}
# point_of_interest: P_3522fdaade6d70
# preds: {'E_01b1a6a120e982'}
# targets: {'E_ca363f3557a315', 'E_01b1a6a120e982'}
# point_of_interest: P_1bd5aa73ab6a85
# preds: {'E_01b1a708facf3c'}
# targets: {'E_c79b0e21c046bd', 'E_01b1a708facf3c'}
# point_of_interest: P_223653d6bd8c75
# preds: {'E_01b1c4b04203b8'}
# targets: {'E_b33cb0946a99eb', 'E_01b1c4b04203b8'}
# point_of_interest: P_78e414ed378fb2
# preds: {'E_01b1cc91502a55'}
# targets: {'E_01b1cc91502a55', 'E_49dd2012e55697'}
# point_of_interest: P_905946186bc7c0
# preds: {'E_01b1d2eedb84ea'}
# targets: {'E_01b1d2eedb84ea', 'E_b761addfe83338'}
# point_of_interest: P_7698f1fdd28405
# preds: {'E_01b1fb1fdad77a'}
# targets: {'E_0e9e4ead7a2b95', 'E_01b1fb1fdad77a'}
# point_of_interest: P_4781db75e4fa44
# preds: {'E_01b20b9e87b46d'}
# targets: {'E_ea7b6393998f95', 'E_01b20b9e87b46d'}
# point_of_interest: P_e8c3913c427f1e
# preds: {'E_01b21077806b1a'}
# targets: {'E_01b21077806b1a', 'E_efd9716b00f80e', 'E_d0674b91ab70af'}
# point_of_interest: P_fb17e2c201178c
# preds: {'E_01b21d86c55dc7'}
# targets: {'E_01b21d86c55dc7', 'E_f29209d97b3b2b'}
# point_of_interest: P_a9a0abd5b229dd
# preds: {'E_01b21e0d437bf9'}
# targets: {'E_c233a4a98c459f', 'E_01b21e0d437bf9', 'E_e2faef9e3b8a78'}
# point_of_interest: P_4cafb6237c31f6
# preds: {'E_01b22a7f0032ef'}
# targets: {'E_ada63468b057f9', 'E_01b22a7f0032ef', 'E_149a30e1bd27e5'}
# point_of_interest: P_07ae27d5ea308f
# preds: {'E_01b248471e4c99'}
# targets: {'E_8ed7fa4ff57074', 'E_f09b4c77cb805a', 'E_01b248471e4c99'}
# point_of_interest: P_e5c05141ddb502
# preds: {'E_01b24d63b1656a'}
# targets: {'E_bade95a4f0cff0', 'E_01b24d63b1656a'}
# point_of_interest: P_aafcef7d7f63a9
# preds: {'E_01b25f930fa7b7'}
# targets: {'E_eaacca48dc0f3a', 'E_01b25f930fa7b7'}
# point_of_interest: P_181405b1f70dea
# preds: {'E_01b269633b3edd'}
# targets: {'E_39c83f95cf5eeb', 'E_01b269633b3edd', 'E_dd2ef622bc4fe1'}
# point_of_interest: P_b07e7b6262cc24
# preds: {'E_01b29c8763ddf8'}
# targets: {'E_01b29c8763ddf8', 'E_ec21af96e0e923'}
# point_of_interest: P_f2258d9e0eb152
# preds: {'E_01b2c6520ad7d4'}
# targets: {'E_01b2c6520ad7d4', 'E_e45db8a33c2fa1'}
# point_of_interest: P_8bc1149bf8e60b
# preds: {'E_01b2cd7f6444ba'}
# targets: {'E_dc09aff55bc686', 'E_01b2cd7f6444ba'}
# point_of_interest: P_048b73b68cc3b6
# preds: {'E_01b2cebfc87967'}
# targets: {'E_01b2cebfc87967', 'E_6ab5881173b36b'}
# point_of_interest: P_63d0c5d7e58eea
# preds: {'E_01b302bf473f25'}
# targets: {'E_84b77c278a59fb', 'E_01b302bf473f25'}
# point_of_interest: P_db28090ac8f897
# preds: {'E_01b3068695744c'}
# targets: {'E_7d30ac4fc7476c', 'E_01b3068695744c'}
# point_of_interest: P_79ac88ab7ace50
# preds: {'E_01b319e58213b2'}
# targets: {'E_01b319e58213b2', 'E_4c354aceab0695'}
# point_of_interest: P_76bd8d3da3536d
# preds: {'E_01b3260d15f75d'}
# targets: {'E_01b3260d15f75d', 'E_e860a67646ef9b'}
# point_of_interest: P_66d5ff20bad01a
# preds: {'E_01b35767eb9bc5'}
# targets: {'E_41df46009a3607', 'E_01b35767eb9bc5'}
# point_of_interest: P_86b27d99b99e70
# preds: {'E_01b372a239546d'}
# targets: {'E_8c50075fa83a6e', 'E_d3370de75295bf', 'E_01b372a239546d', 'E_d8ddc1aff38db7', 'E_98ea4c605d3467', 'E_5b26fe13307f92'}
# point_of_interest: P_f7bb4ef31a057a
# preds: {'E_01b375503fab2a'}
# targets: {'E_01b375503fab2a', 'E_6b8fd4ea1fd8bf'}
# point_of_interest: P_1037860f152442
# preds: {'E_01b37f42c31e25'}
# targets: {'E_2ac6cacd75aaf4', 'E_01b37f42c31e25'}
# point_of_interest: P_fa4428c5e34bc7
# preds: {'E_01b399fc0f2b0c'}
# targets: {'E_01b399fc0f2b0c', 'E_49580489559c93'}
# point_of_interest: P_25affb932dbdaf
# preds: {'E_01b3ac4b7de82c'}
# targets: {'E_01b3ac4b7de82c', 'E_9b41528d363076', 'E_75709f8ee9cf43'}
# point_of_interest: P_d73a170a336334
# preds: {'E_01b3bc8e6f0e3e'}
# targets: {'E_c3bc0dd6b0e16a', 'E_01b3bc8e6f0e3e'}
# point_of_interest: P_85d9fec522f0be
# preds: {'E_01b3bef877c299'}
# targets: {'E_2de1f44d356d33', 'E_01b3bef877c299'}
# point_of_interest: P_6e61f674380f7d
# preds: {'E_01b3db7bf0fba4'}
# targets: {'E_6d3c941394fd79', 'E_c84c96268ed84e', 'E_01b3db7bf0fba4', 'E_0d8884a14f09bc'}
# point_of_interest: P_b95f8af5fb3cb0
# preds: {'E_01b3fc959d2192'}
# targets: {'E_01b3fc959d2192', 'E_f1c56e85f03086'}
# point_of_interest: P_bda3877942f71d
# preds: {'E_01b40568d191dc'}
# targets: {'E_01b40568d191dc', 'E_0390c71756d013'}
# point_of_interest: P_d297f7739964d3
# preds: {'E_01b42327d42cf4'}
# targets: {'E_c6d3b8112e57b1', 'E_01b42327d42cf4'}
# point_of_interest: P_c52695a174857b
# preds: {'E_01b43447c6c6a8'}
# targets: {'E_9c0674b9a8380c', 'E_01b43447c6c6a8'}
# point_of_interest: P_41c0fe06d304ba
# preds: {'E_01b4413034beba'}
# targets: {'E_01b4413034beba', 'E_dbec0f5a6844b6'}
# point_of_interest: P_60d654b32cbfdc
# preds: {'E_01b45bf6634358'}
# targets: {'E_01b45bf6634358', 'E_b2d9864deff54d'}
# point_of_interest: P_3a31a3d21e3f46
# preds: {'E_01b464fa4e0610'}
# targets: {'E_b3ea36c865562a', 'E_01b464fa4e0610', 'E_a9ad6fe5f21c63', 'E_a73976f6f9af9e', 'E_fea9225f4dd897', 'E_ae9fd1392be5fb'}
# point_of_interest: P_08061c352f3a95
# preds: {'E_01b47be6a5c630'}
# targets: {'E_01b47be6a5c630', 'E_64b36c2d686dd3'}
# point_of_interest: P_b0a0586e938ef3
# preds: {'E_01b497da10d0c7'}
# targets: {'E_ac181ac7171c29', 'E_01b497da10d0c7'}
# point_of_interest: P_3eba818decbdfa
# preds: {'E_01b499dcc383fb'}
# targets: {'E_1ab363c88c0e54', 'E_01b499dcc383fb'}
# point_of_interest: P_30591e78ed7f5b
# preds: {'E_01b49de282fe08'}
# targets: {'E_11f6011538b020', 'E_afa03099d7bf6a', 'E_01b49de282fe08'}
# point_of_interest: P_2fd8973fe6fe1b
# preds: {'E_01b4ade31a2269'}
# targets: {'E_01b4ade31a2269', 'E_c2e0a4ba7b4fb7'}
# point_of_interest: P_f14f7eae54df79
# preds: {'E_01b4c272ab118e'}
# targets: {'E_65b29177887771', 'E_01b4c272ab118e'}
# point_of_interest: P_61ced42e5c8985
# preds: {'E_01b4fb523188be'}
# targets: {'E_01b4fb523188be', 'E_3171d0caa0cbcf'}
# point_of_interest: P_63fc74de887806
# preds: {'E_01b506b37b3472'}
# targets: {'E_7e126d7ad533e6', 'E_01b506b37b3472'}
# point_of_interest: P_e54f857c461952
# preds: {'E_01b5102305f8bb'}
# targets: {'E_7749b2cc501469', 'E_01b5102305f8bb', 'E_226ff2e43c21c3'}
# point_of_interest: P_eec69f7430f148
# preds: {'E_01b5227bd46732'}
# targets: {'E_01b5227bd46732', 'E_2cef483fb13b14'}
# point_of_interest: P_93dcb67733faa2
# preds: {'E_01b52ac2bee796'}
# targets: {'E_01b52ac2bee796', 'E_2e5cea1a7b02a5'}
# point_of_interest: P_0416a896978a03
# preds: {'E_01b536fb3bd9d7'}
# targets: {'E_96a54d903240f5', 'E_01b536fb3bd9d7'}
# point_of_interest: P_f629c0670525b7
# preds: {'E_01b5528061a55c'}
# targets: {'E_149ef5812f9504', 'E_51992407136257', 'E_d201b969da05dd', 'E_7b72549127df56', 'E_cd17aea060abec', 'E_e9175796d067dd', 'E_ce3bd895b9065e', 'E_76a84c7d1bd5d1', 'E_52551876e972f1', 'E_8f6065b03982dc', 'E_01b5528061a55c', 'E_414dc0969cc772', 'E_7f7c6ee2e27b8f', 'E_6737a62306b6b3', 'E_d3d9203c94ae42'}
# point_of_interest: P_1eaa69a8fc116e
# preds: {'E_01b55e74db2bd0'}
# targets: {'E_d1425c09925d0f', 'E_01b55e74db2bd0'}
# point_of_interest: P_f12fdcec846538
# preds: {'E_010a91b47d63e2', 'E_01b57d74078ed3'}
# targets: {'E_9c29cd293ecaf4', 'E_010a91b47d63e2', 'E_07775d2ebebf6b', 'E_01b57d74078ed3'}
# point_of_interest: P_c20d38cd96dd1a
# preds: {'E_01b57e50f4bd5c'}
# targets: {'E_86775b4a6e60c1', 'E_01b57e50f4bd5c'}
# point_of_interest: P_dfff8c1b3de100
# preds: {'E_01b5913a4b4eff'}
# targets: {'E_98b243c6f6cca1', 'E_01b5913a4b4eff'}
# point_of_interest: P_31f11d42fe6a7b
# preds: {'E_01b595bed27cfe'}
# targets: {'E_01b595bed27cfe', 'E_955319afba1c23'}
# point_of_interest: P_bb2e74d07f5ad2
# preds: {'E_01b59628d470c0'}
# targets: {'E_a5ae25fc290bf1', 'E_bf05e8ef6e8ed6', 'E_4cb7a4a7d41c4b', 'E_259d8d721a25e7', 'E_028c64a6f524ae', 'E_1191a7c877f692', 'E_01b59628d470c0', 'E_34807dcd98f639', 'E_80253ed2fafbfa', 'E_6451ddf6439f76'}
# point_of_interest: P_3317a06e07b613
# preds: {'E_01b5f2af001b55'}
# targets: {'E_19a6ec2b842048', 'E_0fd276dc6c4616', 'E_01b5f2af001b55'}
# point_of_interest: P_4af1a610641570
# preds: {'E_01b5f46d030baf'}
# targets: {'E_5355815a05797d', 'E_01b5f46d030baf'}
# point_of_interest: P_18ce10b28a893f
# preds: {'E_01b5f4cdf464cb'}
# targets: {'E_01b5f4cdf464cb', 'E_9a9eb62f95b3cd', 'E_950a9d5cd4b893'}
# point_of_interest: P_ec11be41a2a9d7
# preds: {'E_01b5faa6fc2e98'}
# targets: {'E_01b5faa6fc2e98', 'E_1df2c71bea6261'}
# point_of_interest: P_5cfaab5641d63c
# preds: {'E_01b61651eba589'}
# targets: {'E_01b61651eba589', 'E_1d6bbc1f4ac908'}
# point_of_interest: P_69da58dc131b49
# preds: {'E_01b627216c6c13'}
# targets: {'E_bc9ab2ee5c8814', 'E_01b627216c6c13'}
# point_of_interest: P_d882b9d3c4c1c9
# preds: {'E_01b646dbb2b17b'}
# targets: {'E_b5f8eb572a9d83', 'E_01b646dbb2b17b'}
# point_of_interest: P_6a89bc175e1916
# preds: {'E_01b66c448034eb'}
# targets: {'E_36c6e3ab136fb3', 'E_01b66c448034eb'}
# point_of_interest: P_d501cc6fdf396f
# preds: {'E_01b6742a9ee988'}
# targets: {'E_01b6742a9ee988', 'E_8df01e62423311', 'E_441fc2205bdfd3', 'E_c118e1d24d496b'}
# point_of_interest: P_fa39bd58a89e49
# preds: {'E_01b67b2a223f9c'}
# targets: {'E_01b67b2a223f9c', 'E_a1111228beedca'}
# point_of_interest: P_7c6e11431d8dfd
# preds: {'E_01b69a99344143'}
# targets: {'E_4ae123905d3367', 'E_01b69a99344143'}
# point_of_interest: P_5aeee41920f474
# preds: {'E_01b6e76a686789'}
# targets: {'E_01b6e76a686789', 'E_6a9d40a24a5c81'}
# point_of_interest: P_30c3620a91c5c4
# preds: {'E_01b6eccf96d05a'}
# targets: {'E_a6171520a729d7', 'E_01b6eccf96d05a'}
# point_of_interest: P_e070cbfad9f4b6
# preds: {'E_01b6feb3ff2c05'}
# targets: {'E_01b6feb3ff2c05', 'E_0c287085cad5f3'}
# point_of_interest: P_53197540c202bd
# preds: {'E_01b724da53fdbe'}
# targets: {'E_d7349d6d9d87b8', 'E_01b724da53fdbe'}
# point_of_interest: P_a0707616b5097e
# preds: {'E_01b7251f447d04'}
# targets: {'E_01b7251f447d04', 'E_45a6a43af8d771'}
# point_of_interest: P_8e00493ea58eb4
# preds: {'E_01b7639d5d3a12'}
# targets: {'E_d1bae866e51ea5', 'E_01b7639d5d3a12'}
# point_of_interest: P_a46a5d90c71b2a
# preds: {'E_01b7aec94b03ef'}
# targets: {'E_01b7aec94b03ef', 'E_9972fff0d537cc'}
# point_of_interest: P_926f8b03ba1e97
# preds: {'E_01b7b2acb35733'}
# targets: {'E_01b7b2acb35733', 'E_ebe9524dee9f45'}
# point_of_interest: P_1d8c6a6c25d57f
# preds: {'E_01b7b2ef6c965d'}
# targets: {'E_3b680e67e00b9b', 'E_01b7b2ef6c965d'}
# point_of_interest: P_36749ed06269c0
# preds: {'E_01b7ca89ab1c7f'}
# targets: {'E_7e4bcedd4c029b', 'E_201acd0eab130b', 'E_01b7ca89ab1c7f'}
# point_of_interest: P_06f9073efb7355
# preds: {'E_01b7dfc4919c00'}
# targets: {'E_01b7dfc4919c00', 'E_59a6643d648812'}
# point_of_interest: P_b4d75d35641438
# preds: {'E_01b7e09170ea7e'}
# targets: {'E_470e5d714cf0d2', 'E_01b7e09170ea7e'}
# point_of_interest: P_542e0f51b47c49
# preds: {'E_01b7eebe06525c'}
# targets: {'E_8145efb752acd9', 'E_01b7eebe06525c'}
# point_of_interest: P_e748ccfe160d94
# preds: {'E_01b7f5c34e47af'}
# targets: {'E_01b7f5c34e47af', 'E_0dcc1c446239ef'}
# point_of_interest: P_fed8d47fffd047
# preds: {'E_01b8035fbb2129'}
# targets: {'E_01b8035fbb2129', 'E_8cada8f5767fb8'}
# point_of_interest: P_77731ae14ef141
# preds: {'E_01b8062d30a7a0'}
# targets: {'E_4093ffc7483841', 'E_01b8062d30a7a0'}
# point_of_interest: P_ccfff096e18173
# preds: {'E_01b829b99851d1'}
# targets: {'E_01b829b99851d1', 'E_342b60ff74265f'}
# point_of_interest: P_6e2744d7d7448d
# preds: {'E_01b82ea3e43d2f'}
# targets: {'E_01b82ea3e43d2f', 'E_7ad307e2c486fa'}
# point_of_interest: P_05953291a00eba
# preds: {'E_01b831dc1870c1', 'E_012392ee1fd714'}
# targets: {'E_01b831dc1870c1', 'E_4a26e8f5ffe600', 'E_012392ee1fd714'}
# point_of_interest: P_daf2745c0d6414
# preds: {'E_01b87da8e6222a'}
# targets: {'E_01b87da8e6222a', 'E_601623825cbaee'}
# point_of_interest: P_4962ca03b0ca77
# preds: {'E_01b88cec93c8cc'}
# targets: {'E_01b88cec93c8cc', 'E_b2919f72ba75b7'}
# point_of_interest: P_e423010346e8e2
# preds: {'E_01b8da472d8bfa'}
# targets: {'E_01b8da472d8bfa', 'E_53e1e12557c182'}
# point_of_interest: P_b2ac9fdb4b81ec
# preds: {'E_01b8f563d84d7f'}
# targets: {'E_206c53ab3c4ba3', 'E_01b8f563d84d7f'}
# point_of_interest: P_165351d59fefb7
# preds: {'E_01b90a0d75392c'}
# targets: {'E_01b90a0d75392c', 'E_86187b5f82f755'}
# point_of_interest: P_e2b28224f07b0c
# preds: {'E_01b9127dd91105'}
# targets: {'E_01b9127dd91105', 'E_a2007d10abc354'}
# point_of_interest: P_7e7a19bab95693
# preds: {'E_01b94d8faf5471'}
# targets: {'E_0cf9e911b01ec4', 'E_01b94d8faf5471', 'E_d66b03a1aa0039', 'E_5ce729de97343a'}
# point_of_interest: P_7ed97a0aeb7776
# preds: {'E_01b96f45eb6cff'}
# targets: {'E_01b96f45eb6cff', 'E_3bca44c3e0c9b3'}
# point_of_interest: P_2ae79de144c6d3
# preds: {'E_01b9758bc1f37d'}
# targets: {'E_01b9758bc1f37d', 'E_323215fe8af1e0'}
# point_of_interest: P_4271db210c82dc
# preds: {'E_01b979e472066e'}
# targets: {'E_2cc71606364da7', 'E_01b979e472066e'}
# point_of_interest: P_13a13c6b484b11
# preds: {'E_01b987eeb136ec'}
# targets: {'E_77ef437ef0cdf7', 'E_01b987eeb136ec'}
# point_of_interest: P_6c5b37691ceed5
# preds: {'E_01b9a0da7b0b35'}
# targets: {'E_829f7fc2e289e1', 'E_01b9a0da7b0b35'}
# point_of_interest: P_74ea82d74bd54c
# preds: {'E_01b9c946685768'}
# targets: {'E_159ce198b7279c', 'E_01b9c946685768'}
# point_of_interest: P_458b940d22d4c0
# preds: {'E_01b9d36d597808'}
# targets: {'E_a717d437a34ef0', 'E_01b9d36d597808'}
# point_of_interest: P_cd6f3f047daa08
# preds: {'E_01b9e6e3f2b2e9'}
# targets: {'E_01b9e6e3f2b2e9', 'E_35e1407057fdd9', 'E_a0920f744bac88'}
# point_of_interest: P_8578c692f75512
# preds: {'E_01b9f660ceefa1'}
# targets: {'E_01b9f660ceefa1', 'E_f5f733f92ff691'}
# point_of_interest: P_bdad9dc011b054
# preds: {'E_01ba01314f8475'}
# targets: {'E_f616fae866d2f2', 'E_01ba01314f8475'}
# point_of_interest: P_2a4f859349c849
# preds: {'E_01ba055b86e73a'}
# targets: {'E_01ba055b86e73a', 'E_3390d60d504d6f'}
# point_of_interest: P_8d84cd70856b6d
# preds: {'E_01ba0e12c9ca73'}
# targets: {'E_a83eb804f12ed7', 'E_01ba0e12c9ca73'}
# point_of_interest: P_0b79c82933f53b
# preds: {'E_01ba470724f4d9'}
# targets: {'E_fa4ae53c013a8e', 'E_01ba470724f4d9'}
# point_of_interest: P_3432e018eabef7
# preds: {'E_01ba4e8c4fbaee'}
# targets: {'E_01ba4e8c4fbaee', 'E_5af6055aabe438'}
# point_of_interest: P_0cfed633edf97f
# preds: {'E_01ba7e078ad221'}
# targets: {'E_01ba7e078ad221', 'E_3dbf11f400ed8a', 'E_0a93656bb31074', 'E_cc13bf6aea7c37'}
# point_of_interest: P_874f3c7d2c4649
# preds: {'E_01ba99da9b9796'}
# targets: {'E_01ba99da9b9796', 'E_a11e0dbb9a7a9e'}
# point_of_interest: P_7aa5d79275e0d6
# preds: {'E_01ba9fbe4ae71a'}
# targets: {'E_01ba9fbe4ae71a', 'E_7ce02491b481c4'}
# point_of_interest: P_158b703771deae
# preds: {'E_01baa35642bcd3'}
# targets: {'E_81cab77210b774', 'E_01baa35642bcd3', 'E_5f6dc1532a586e'}
# point_of_interest: P_bd57e3eb4d033c
# preds: {'E_01bab5f1ad74f1'}
# targets: {'E_6d043cdf5b5307', 'E_01bab5f1ad74f1'}
# point_of_interest: P_1e79beaad4de12
# preds: {'E_01bac4084af07a'}
# targets: {'E_01bac4084af07a', 'E_6e48026f23bb6c'}
# point_of_interest: P_d8261f7e022d00
# preds: {'E_01bae02c954ae0'}
# targets: {'E_08deef8eb1d61f', 'E_52b9730b9acb55', 'E_01bae02c954ae0'}
# point_of_interest: P_b6c2d8cd3d2c67
# preds: {'E_01bb48e4326f88'}
# targets: {'E_01bb48e4326f88', 'E_6e4eb6d752802a'}
# point_of_interest: P_9ab06dc5818d25
# preds: {'E_01bb5dcfcd402e'}
# targets: {'E_01bb5dcfcd402e', 'E_9b381fbc026515'}
# point_of_interest: P_a92e953ddcac38
# preds: {'E_01bb637eee626c'}
# targets: {'E_6d09f2710b320e', 'E_3a71d7cd65f4ea', 'E_d9f7c76034bbe5', 'E_01bb637eee626c'}
# point_of_interest: P_1898d938ffaa4d
# preds: {'E_01bb7d21e2ed5f'}
# targets: {'E_01bb7d21e2ed5f', 'E_3a7ad68a483b05', 'E_cc4e5dc26521ad'}
# point_of_interest: P_54c2a56fac49c8
# preds: {'E_01bb8c9f7ba2ac'}
# targets: {'E_01bb8c9f7ba2ac', 'E_46a22fbda8961a'}
# point_of_interest: P_79381f018d9750
# preds: {'E_01bb96cc3ed250'}
# targets: {'E_01bb96cc3ed250', 'E_58593e986a807c'}
# point_of_interest: P_8fda02dc5f80e3
# preds: {'E_01bbba1733c47c'}
# targets: {'E_40bab30065b8ea', 'E_01bbba1733c47c'}
# point_of_interest: P_0dd32dd07b21c0
# preds: {'E_01bbcfb51efbba'}
# targets: {'E_ce40b6436a10b4', 'E_01bbcfb51efbba'}
# point_of_interest: P_509359fcf9cd3b
# preds: {'E_01bc0b5f653fc2'}
# targets: {'E_7cd0270a5c4eb5', 'E_01bc0b5f653fc2'}
# point_of_interest: P_2ef39feaa9e0bb
# preds: {'E_01bc1c321347bf'}
# targets: {'E_9f70e24e06ecec', 'E_01bc1c321347bf'}
# point_of_interest: P_db946b5962a8db
# preds: {'E_01bc4750a891c8'}
# targets: {'E_01bc4750a891c8', 'E_a8ba201c145c28'}
# point_of_interest: P_afefe862d64418
# preds: {'E_01bc5570d42a33'}
# targets: {'E_01bc5570d42a33', 'E_47d540bf658673'}
# point_of_interest: P_958a71ac023d94
# preds: {'E_01bc573e77f781'}
# targets: {'E_d54a99ca2dbc64', 'E_01bc573e77f781'}
# point_of_interest: P_79f5b257c3c2ed
# preds: {'E_01bc5ef3783f8e'}
# targets: {'E_01bc5ef3783f8e', 'E_9e56a681c00afb'}
# point_of_interest: P_914152704e5d90
# preds: {'E_01bc6301c1269d'}
# targets: {'E_01bc6301c1269d', 'E_7701bd632073ca'}
# point_of_interest: P_e7869e0c30f38c
# preds: {'E_01bc87d2b28dee'}
# targets: {'E_01bc87d2b28dee', 'E_0cac374aeed612'}
# point_of_interest: P_ecda8c3d77483e
# preds: {'E_01bca4e64836d0'}
# targets: {'E_8a6b1ba0b0f619', 'E_01bca4e64836d0'}
# point_of_interest: P_03feb1b0445c9e
# preds: {'E_01bcb20a9ba974'}
# targets: {'E_01bcb20a9ba974', 'E_e70e6bc329b2bc'}
# point_of_interest: P_c6d9d75a234590
# preds: {'E_01bcb6e109637d'}
# targets: {'E_71e1bebef11d29', 'E_01bcb6e109637d'}
# point_of_interest: P_089eabcddd4c25
# preds: {'E_01bcc19c92d7b8'}
# targets: {'E_01bcc19c92d7b8', 'E_04b50392cb5247'}
# point_of_interest: P_38b7019b92553d
# preds: {'E_01bd12a71a583f'}
# targets: {'E_01bd12a71a583f', 'E_f71d2a71b21a6d'}
# point_of_interest: P_c178cf3ffb34ef
# preds: {'E_01bd12c30c4dec'}
# targets: {'E_01bd12c30c4dec', 'E_daa3282b72f41a'}
# point_of_interest: P_4fc63937b5080d
# preds: {'E_01bd502ac5a3b5'}
# targets: {'E_774b17a93db17f', 'E_01bd502ac5a3b5'}
# point_of_interest: P_275a613936cc03
# preds: {'E_01bd6cb5f018d1'}
# targets: {'E_e16e68ab7f8beb', 'E_01bd6cb5f018d1'}
# point_of_interest: P_c14928a8016a1f
# preds: {'E_01bd9fc47fa133'}
# targets: {'E_6b02215d490496', 'E_7a17b33378f734', 'E_cd382ef515ac81', 'E_0fc455a063a213', 'E_e1fcd0d04ad7c5', 'E_582aa238ad5dbd', 'E_a57c25c1e7e521', 'E_01bd9fc47fa133', 'E_6e3b0b620bcb56', 'E_fe50d952d5238c', 'E_622074e4af284c', 'E_98505512ec19e2'}
# point_of_interest: P_6d31f9882f4d79
# preds: {'E_01bdaab0a02814'}
# targets: {'E_01bdaab0a02814', 'E_2b23e5f798a482'}
# point_of_interest: P_809dcbf775be07
# preds: {'E_01bdb88aee9730'}
# targets: {'E_40f5ea7a0ad278', 'E_01bdb88aee9730'}
# point_of_interest: P_1e100e841c9a19
# preds: {'E_01bdcac0e84c45'}
# targets: {'E_01bdcac0e84c45', 'E_ab6d8b09c82111'}
# point_of_interest: P_25a175e19fd4f0
# preds: {'E_01bdd54bc1df4b'}
# targets: {'E_f96410421cf3ee', 'E_c1c88c820e9898', 'E_f3f5d5c978405a', 'E_e004606d0fb187', 'E_cf4f1911db4fa9', 'E_741f90466c70e6', 'E_3d99d5754d35a7', 'E_822709dbed7922', 'E_e0e376c95982d1', 'E_47bc1ca43a3628', 'E_f7d1d79deb560b', 'E_094b6b96cadfc2', 'E_91c53be8031780', 'E_de3248bd5e3f09', 'E_01bdd54bc1df4b'}
# point_of_interest: P_509e2eb4bb9fe4
# preds: {'E_01bdd5b5021159'}
# targets: {'E_01bdd5b5021159', 'E_6dbbf423bd75c8'}
# point_of_interest: P_663bacd742abad
# preds: {'E_01bde9831b041b'}
# targets: {'E_ca4b18a840454c', 'E_01bde9831b041b'}
# point_of_interest: P_35114d278a6ad4
# preds: {'E_01bdffcaa1af2e'}
# targets: {'E_4722cb66d7725c', 'E_01bdffcaa1af2e'}
# point_of_interest: P_00cab0569ad0a0
# preds: {'E_01be0ba8781f27'}
# targets: {'E_01be0ba8781f27', 'E_8fd1700dd90b0f'}
# point_of_interest: P_278db49d6f23a2
# preds: {'E_01be0ebf086435'}
# targets: {'E_46b89c6cdd84d3', 'E_94d9bfb8e7cef7', 'E_01be0ebf086435'}
# point_of_interest: P_3bc70975d5b095
# preds: {'E_01be11bb56f76d'}
# targets: {'E_01be11bb56f76d', 'E_4cb94bd6754718'}
# point_of_interest: P_a623985e09b53a
# preds: {'E_01be19753c908c'}
# targets: {'E_01be19753c908c', 'E_d277ae8b27f02c'}
# point_of_interest: P_62aec1cb5fc2e5
# preds: {'E_01be6ef7b1f5aa'}
# targets: {'E_01be6ef7b1f5aa', 'E_e766304de8f974'}
# point_of_interest: P_fcbdc8ef2a4fd4
# preds: {'E_01beafbaabc309'}
# targets: {'E_c35233a46ed811', 'E_893d0d9f97cdd1', 'E_01beafbaabc309'}
# point_of_interest: P_c97fb03b3c87d3
# preds: {'E_01bec41a0450af'}
# targets: {'E_a2bd38452ee09b', 'E_5113befcb5da40', 'E_01bec41a0450af', 'E_1d59d1a554f2c2'}
# point_of_interest: P_a3e645ed437049
# preds: {'E_01bef02538fd0d'}
# targets: {'E_9cfd1045d5f927', 'E_01bef02538fd0d'}
# point_of_interest: P_6a8520dbffdeb1
# preds: {'E_01befb9a85c1c1'}
# targets: {'E_01befb9a85c1c1', 'E_d26d81911a5d99', 'E_d2c407f265c881'}
# point_of_interest: P_e2fc531eef825e
# preds: {'E_01bf0a26d6f876'}
# targets: {'E_01bf0a26d6f876', 'E_593362deedaacd'}
# point_of_interest: P_5e2364351a598a
# preds: {'E_01bf12cf9d1829'}
# targets: {'E_4094ffa2f12cdb', 'E_01bf12cf9d1829'}
# point_of_interest: P_9bdecd6b513003
# preds: {'E_01bf1e1d77e3d3'}
# targets: {'E_5a56c6f8b8e1e3', 'E_70f42925741d5e', 'E_d3c183e5e78e78', 'E_a6663b2c47424e', 'E_01bf1e1d77e3d3', 'E_0bbd0564a63f4c'}
# point_of_interest: P_4e0f4046a6ba69
# preds: {'E_01bf3031bfa985'}
# targets: {'E_01bf3031bfa985', 'E_e6bc3a6bd7551f'}
# point_of_interest: P_4d77cef5574e17
# preds: {'E_01bf34bd1da459'}
# targets: {'E_01bf34bd1da459', 'E_babc7b73467e52'}
# point_of_interest: P_faf1a8976c8b3f
# preds: {'E_01bf589582b286'}
# targets: {'E_01bf589582b286', 'E_a8aaba6d5e8043'}
# point_of_interest: P_59f9473d4e199f
# preds: {'E_01bf5ca1d9b948'}
# targets: {'E_01bf5ca1d9b948', 'E_bd4d71c2dbc8fb', 'E_9f60c829005d89', 'E_9ec24dfbb4c6f9', 'E_8adea558567324', 'E_c47a08a03d3eec', 'E_52860b7bea5544'}
# point_of_interest: P_35d434741080d5
# preds: {'E_01bf5ca2257821'}
# targets: {'E_01bf5ca2257821', 'E_1f08f712f9a23f'}
# point_of_interest: P_c1050261575fee
# preds: {'E_01bf699e513e65'}
# targets: {'E_01bf699e513e65', 'E_85e21bf1d69d70'}
# point_of_interest: P_baf5e945e77de5
# preds: {'E_01bf6f53886e16'}
# targets: {'E_01bf6f53886e16', 'E_c73870f2205926'}
# point_of_interest: P_d492bca562ff78
# preds: {'E_01bfad815b6517'}
# targets: {'E_42c20a81bb19ae', 'E_01bfad815b6517'}
# point_of_interest: P_754873e3e8a5d9
# preds: {'E_01bfbd61da1077'}
# targets: {'E_9558548307570a', 'E_01bfbd61da1077'}
# point_of_interest: P_90f3f7a0ad535a
# preds: {'E_01bfcc09959f89'}
# targets: {'E_ed633ed6c147e3', 'E_01bfcc09959f89'}
# point_of_interest: P_44f23b5e94ce0d
# preds: {'E_01bfd979799937'}
# targets: {'E_01bfd979799937', 'E_57d2b9482540b4'}
# point_of_interest: P_276e7d9d1c6dd5
# preds: {'E_01c02e5762fa08'}
# targets: {'E_01c02e5762fa08', 'E_bd3bef30ccdf4b'}
# point_of_interest: P_653c46bd1f01ea
# preds: {'E_01c041d8e369d4'}
# targets: {'E_01c041d8e369d4', 'E_e977743bbab30b'}
# point_of_interest: P_6e941f79992d1b
# preds: {'E_01c05de40a01ed'}
# targets: {'E_8e346d163ab5b2', 'E_ccc0fd0218bb0c', 'E_01c05de40a01ed', 'E_9b84c10d18e9ef', 'E_5a2d468b71a670', 'E_660fe0ee68805c'}
# point_of_interest: P_5c83538888c422
# preds: {'E_01c068bbff3f3b'}
# targets: {'E_5a872a08f6bb6e', 'E_29cad0fdbf98f6', 'E_01c068bbff3f3b', 'E_682a27dfbecb7b'}
# point_of_interest: P_b1811a0e8dcb9c
# preds: {'E_01c081b5fb9db9'}
# targets: {'E_01c081b5fb9db9', 'E_9dc2b33f83739e'}
# point_of_interest: P_deee94b7b47354
# preds: {'E_01c083b41fff5d'}
# targets: {'E_235d98eb24dde4', 'E_1a4677bbd2681b', 'E_4bfe56f7f9e251', 'E_59feeb764b3940', 'E_5f607762942007', 'E_46dd5e0775bcd4', 'E_72e3dda2b70978', 'E_875780a8e8708a', 'E_79071340b4ff1d', 'E_cb82f13071b722', 'E_898f36c6fc7827', 'E_066b7c1e6b27f9', 'E_5164750bf02ad9', 'E_01c083b41fff5d', 'E_f1c0735f736baf', 'E_b2447646bc18e4', 'E_54888a6294e231', 'E_b69346b702c431', 'E_a5a19458ec9bae', 'E_36fb52614b777c', 'E_ad6ea42666e268', 'E_4e2f81db84f25c', 'E_c92739d7305e9f', 'E_ba03b8f32bda64'}
# point_of_interest: P_b8969e19b16e89
# preds: {'E_01c085e9694942'}
# targets: {'E_01c085e9694942', 'E_f215ec34f4ad3c'}
# point_of_interest: P_86f0fbfdd73129
# preds: {'E_01c098e33b19b8'}
# targets: {'E_db0609a219b923', 'E_01c098e33b19b8'}
# point_of_interest: P_7e875e31a6690e
# preds: {'E_01c099418cfb6e'}
# targets: {'E_01c099418cfb6e', 'E_a6b4b7298a52a9'}
# point_of_interest: P_e375de960c5a53
# preds: {'E_01c0acbd4482e1'}
# targets: {'E_01c0acbd4482e1', 'E_4ce42e70683b2e'}
# point_of_interest: P_2e3ec652ad36f0
# preds: {'E_01c0b02cf4ffd9'}
# targets: {'E_01c0b02cf4ffd9', 'E_a723a457d11713'}
# point_of_interest: P_c7d85687e6a59e
# preds: {'E_01c0ba22566576'}
# targets: {'E_db7b2afc645219', 'E_01c0ba22566576'}
# point_of_interest: P_a99b43407da0b5
# preds: {'E_01c0c41d97774b'}
# targets: {'E_01c0c41d97774b', 'E_a74b1e6662eb6a'}
# point_of_interest: P_074a23b165dfc1
# preds: {'E_01c0d3a6dd0fcf'}
# targets: {'E_90d0a8a46842de', 'E_01c0d3a6dd0fcf'}
# point_of_interest: P_3c12a12f540162
# preds: {'E_01c0f9f9e61648'}
# targets: {'E_01c0f9f9e61648', 'E_f709a75ba45fcf'}
# point_of_interest: P_c6fdc5cdf0a8c5
# preds: {'E_01c0fa3af7d1b7'}
# targets: {'E_38e50595775eab', 'E_01c0fa3af7d1b7'}
# point_of_interest: P_1b08adf2ab5a8a
# preds: {'E_01c11508d586f1'}
# targets: {'E_d5ba4c49d95c36', 'E_01c11508d586f1'}
# point_of_interest: P_6b5674dfc5bc62
# preds: {'E_01c1200b9d1e3b'}
# targets: {'E_975c895e408526', 'E_01c1200b9d1e3b'}
# point_of_interest: P_afb36e99e9fb2f
# preds: {'E_01c1209c5c410b'}
# targets: {'E_01c1209c5c410b', 'E_ae7bacfc68a154'}
# point_of_interest: P_3c9c6cf039f236
# preds: {'E_01c1504738df86'}
# targets: {'E_01c1504738df86', 'E_14d0819b890dc2'}
# point_of_interest: P_30b5f32ee3901f
# preds: {'E_01c1553d361a52'}
# targets: {'E_01c1553d361a52', 'E_2f6b3280fffea2'}
# point_of_interest: P_6fa9e9dfee9311
# preds: {'E_01c166d59b0427'}
# targets: {'E_863f8ec840bdfa', 'E_01c166d59b0427'}
# point_of_interest: P_af56582e73b4ef
# preds: {'E_01c1795890be7e'}
# targets: {'E_01c1795890be7e', 'E_40603d89eca19c'}
# point_of_interest: P_472499352ea46a
# preds: {'E_01c18a905aac47'}
# targets: {'E_01c18a905aac47', 'E_9e3420468ff7a0'}
# point_of_interest: P_91af7dcf9e9d97
# preds: {'E_01c1b3ea12a9ff'}
# targets: {'E_cf982bb78eedb3', 'E_01c1b3ea12a9ff'}
# point_of_interest: P_f1acc7b9ab5ec0
# preds: {'E_01c1b534c7bd76'}
# targets: {'E_01c1b534c7bd76', 'E_e4139314ed565f'}
# point_of_interest: P_47d60d8dafca5e
# preds: {'E_01c1b9eb38bfbb'}
# targets: {'E_48c06077186517', 'E_01c1b9eb38bfbb'}
# point_of_interest: P_b59e01dc668d1c
# preds: {'E_01c1e8dc0bc9e6'}
# targets: {'E_90b6d6729a464c', 'E_01c1e8dc0bc9e6'}
# point_of_interest: P_a27794e993c6d2
# preds: {'E_01c1fa842b59a3'}
# targets: {'E_780ebec2a44721', 'E_01c1fa842b59a3'}
# point_of_interest: P_f1cd44e0e97714
# preds: {'E_01c2118576538f'}
# targets: {'E_fa013b95140989', 'E_01c2118576538f'}
# point_of_interest: P_da98356b6c4914
# preds: {'E_01c2187922c17a'}
# targets: {'E_6399c8dd1cd967', 'E_eb7dae7a32031c', 'E_01c2187922c17a', 'E_9874d8e9910f1f', 'E_fcbc69d9408a5c'}
# point_of_interest: P_9e1336bc165135
# preds: {'E_01c238e96329c4'}
# targets: {'E_f77034564cb8d3', 'E_01c238e96329c4'}
# point_of_interest: P_9ca3d79fbd1bc8
# preds: {'E_01c258529fe9f1'}
# targets: {'E_c7b667fb502705', 'E_1cbccb5737f337', 'E_a74644938dc5f0', 'E_44192bc3cede47', 'E_01c258529fe9f1', 'E_3ffc4786088b18', 'E_71b2bcf867cdbb'}
# point_of_interest: P_53c7884e9564af
# preds: {'E_01c2657821a97a'}
# targets: {'E_01c2657821a97a', 'E_6aaacfd52fd3b7'}
# point_of_interest: P_fb863b5a232b78
# preds: {'E_01c26d027cb516'}
# targets: {'E_6ec43b1e3e701d', 'E_01c26d027cb516'}
# point_of_interest: P_649127d129d951
# preds: {'E_01c2732245ca13'}
# targets: {'E_01c2732245ca13', 'E_9dd07beb34cef1'}
# point_of_interest: P_3501b939406a38
# preds: {'E_01c2856f5ae171'}
# targets: {'E_01c2856f5ae171', 'E_c66356ff176b83'}
# point_of_interest: P_58f96c5f3a5cd1
# preds: {'E_01c29f42e7a915'}
# targets: {'E_a85192657ac098', 'E_01c29f42e7a915'}
# point_of_interest: P_22c9abb710cdcf
# preds: {'E_01c2cefecb1d6c'}
# targets: {'E_9310c3c4e42263', 'E_01c2cefecb1d6c'}
# point_of_interest: P_78f459275e9907
# preds: {'E_01c2e9c37ae67a'}
# targets: {'E_01c2e9c37ae67a', 'E_b438ac70623ded'}
# point_of_interest: P_b0a96df27974ad
# preds: {'E_01c3004e3d82d0'}
# targets: {'E_bd0ca602f6a2c0', 'E_01c3004e3d82d0'}
# point_of_interest: P_809a85e8e105c6
# preds: {'E_01c3109f2f3ad4'}
# targets: {'E_01c3109f2f3ad4', 'E_de473de2245752'}
# point_of_interest: P_301cb2eb480055
# preds: {'E_01c337e6b66710'}
# targets: {'E_01c337e6b66710', 'E_57b5b8cec8f4d5'}
# point_of_interest: P_6ef70cd956eac1
# preds: {'E_01c34b866684d8'}
# targets: {'E_74fe75290fdc49', 'E_1ac06d43c36955', 'E_01c34b866684d8', 'E_ee1129c6bb8e6b', 'E_ceeabb99c4e54a'}
# point_of_interest: P_4b5d21849b2416
# preds: {'E_01c355f924b5d7'}
# targets: {'E_79adbc6afede6e', 'E_01c355f924b5d7'}
# point_of_interest: P_4ab2c823616e58
# preds: {'E_01c35cc8daa62a'}
# targets: {'E_4962bd658d4d4a', 'E_01c35cc8daa62a'}
# point_of_interest: P_4a18a17da072db
# preds: {'E_01c368901e37d0'}
# targets: {'E_01c368901e37d0', 'E_1612917dace415'}
# point_of_interest: P_13c338950c67ef
# preds: {'E_01c37380a4bea1'}
# targets: {'E_01c37380a4bea1', 'E_8fba2e2e4e1593', 'E_765b2f292fe5f1'}
# point_of_interest: P_c11f5299d8cfc6
# preds: {'E_01c3aa2bdaaccf'}
# targets: {'E_01c3aa2bdaaccf', 'E_ead1890dd1ba95'}
# point_of_interest: P_22115a2c014da6
# preds: {'E_01c432e2671c3e'}
# targets: {'E_c5c648fb43c9ba', 'E_01c432e2671c3e'}
# point_of_interest: P_24131204aa9297
# preds: {'E_01c471a195f540'}
# targets: {'E_1c3f7c85d28696', 'E_01c471a195f540'}
# point_of_interest: P_7f066025cc027f
# preds: {'E_01c48500bc1058'}
# targets: {'E_8a9a6d5d375951', 'E_01c48500bc1058'}
# point_of_interest: P_c8ae5b6637b6b0
# preds: {'E_01c495356e42ed'}
# targets: {'E_81577fa7e687ff', 'E_01c495356e42ed'}
# point_of_interest: P_4d4bc5a9b218f4
# preds: {'E_01c4a3948efce0'}
# targets: {'E_01c4a3948efce0', 'E_cac671c0f6eadf'}
# point_of_interest: P_d977ea624734a2
# preds: {'E_01c4d7c4f7f8fe'}
# targets: {'E_01c4d7c4f7f8fe', 'E_b391c2a788de73'}
# point_of_interest: P_2b21df33f38ce2
# preds: {'E_01c4e359bff167'}
# targets: {'E_01c4e359bff167', 'E_e9ed16ebb9ecdd'}
# point_of_interest: P_d7b2e2a3bc575d
# preds: {'E_01c505936fdc44'}
# targets: {'E_e27987bf0f1a43', 'E_01c505936fdc44'}
# point_of_interest: P_4cc402cf9264be
# preds: {'E_01c514dd0a79e6'}
# targets: {'E_824cc9cfff076b', 'E_01c514dd0a79e6'}
# point_of_interest: P_100759e4987214
# preds: {'E_01c544879f8d2f'}
# targets: {'E_01c544879f8d2f', 'E_bdca202e175225'}
# point_of_interest: P_13b3c062cffbb2
# preds: {'E_01c54dbe2d80f0'}
# targets: {'E_01c54dbe2d80f0', 'E_1e1845233d7223', 'E_251f4d96782bdf'}
# point_of_interest: P_63cad0456c393c
# preds: {'E_01c55303b3d90c'}
# targets: {'E_01c55303b3d90c', 'E_3cab289f73f23b', 'E_52bb9cde3ec60d', 'E_3e64ac2d3914f0'}
# point_of_interest: P_243ca8e3e0d0ac
# preds: {'E_01c57578e7be78'}
# targets: {'E_c24b5e7b3d0b34', 'E_01c57578e7be78'}
# point_of_interest: P_5616c86cbffc18
# preds: {'E_01c582f0556905'}
# targets: {'E_5cb734a3531b8b', 'E_01c582f0556905'}
# point_of_interest: P_612b5eb3fd6097
# preds: {'E_01c5de7e9f5adb'}
# targets: {'E_fa5f151475913e', 'E_01c5de7e9f5adb', 'E_40576d86c5dac8'}
# point_of_interest: P_18b912f7b82514
# preds: {'E_01c5e83a66579d'}
# targets: {'E_01c5e83a66579d', 'E_600d8522e82447'}
# point_of_interest: P_b292f922e4fefd
# preds: {'E_01c5ee397af5d6'}
# targets: {'E_734058979e2379', 'E_01c5ee397af5d6'}
# point_of_interest: P_461f1722e4089b
# preds: {'E_01c5f8d38be03b'}
# targets: {'E_01c5f8d38be03b', 'E_42bb0d45782f23'}
# point_of_interest: P_2a3ee5787fb634
# preds: {'E_01c601dfa6a437'}
# targets: {'E_01c601dfa6a437', 'E_4e4c951f8f16b2'}
# point_of_interest: P_81e58343634d6a
# preds: {'E_01c639d17100c4'}
# targets: {'E_a45a6519f057dc', 'E_3e270f5d76844a', 'E_01c639d17100c4'}
# point_of_interest: P_d8e1456a431e05
# preds: {'E_01c6603da297ed'}
# targets: {'E_01c6603da297ed', 'E_883e8ad70344dc'}
# point_of_interest: P_45727f736ae2bc
# preds: {'E_01c66ada18c377'}
# targets: {'E_581ab7a3c63057', 'E_01c66ada18c377', 'E_d68109f307ac3e'}
# point_of_interest: P_093b929be97430
# preds: {'E_01c69c0848f787'}
# targets: {'E_a2198f9e3a299c', 'E_01c69c0848f787'}
# point_of_interest: P_ad85551f72b3e3
# preds: {'E_01c6aa5ec15014'}
# targets: {'E_05cde1f33a4cba', 'E_9c3a3e5b00e320', 'E_01c6aa5ec15014'}
# point_of_interest: P_2756215bf5e880
# preds: {'E_01c6bd7768a6de'}
# targets: {'E_01c6bd7768a6de', 'E_0c408fbfdf9e62'}
# point_of_interest: P_ebc8a39a43f219
# preds: {'E_01c6dcb465ed0f'}
# targets: {'E_9dafeb7f61d946', 'E_01c6dcb465ed0f'}
# point_of_interest: P_be0a03c2aeeee0
# preds: {'E_01c7218a506d8b'}
# targets: {'E_01c7218a506d8b', 'E_8c538ca774ccd0'}
# point_of_interest: P_91dfd607d76947
# preds: {'E_01c72ec665132b'}
# targets: {'E_224ecc68ae4c99', 'E_01c72ec665132b'}
# point_of_interest: P_71fce58212bbff
# preds: {'E_01c737dc7ba2f4'}
# targets: {'E_01c737dc7ba2f4', 'E_89bcb4e3ea7707'}
# point_of_interest: P_2cd5a4b74a74d1
# preds: {'E_01c7480aa93db8'}
# targets: {'E_01c7480aa93db8', 'E_aad1e79938433a'}
# point_of_interest: P_99696f928e49b3
# preds: {'E_01c75bb55d073f'}
# targets: {'E_5cca1bbafec7ca', 'E_01c75bb55d073f'}
# point_of_interest: P_65a7e86dfad1ca
# preds: {'E_01c76161fe6031'}
# targets: {'E_01c76161fe6031', 'E_50ad763c50c461'}
# point_of_interest: P_9ac0ebc22dbf6f
# preds: {'E_01c768e906bd80'}
# targets: {'E_01c768e906bd80', 'E_89faf137975828'}
# point_of_interest: P_34cc67ef847190
# preds: {'E_01c76ada386488'}
# targets: {'E_01c76ada386488', 'E_2a4db1951febaf'}
# point_of_interest: P_e609f0a5acb9d6
# preds: {'E_01c773fe4d74ef'}
# targets: {'E_01c773fe4d74ef', 'E_dc92d6f52c9194'}
# point_of_interest: P_9279e1121a093b
# preds: {'E_01c776dddaa8a9'}
# targets: {'E_01c776dddaa8a9', 'E_61ec1c1f51f92e'}
# point_of_interest: P_5cd7b8e014f111
# preds: {'E_01c7810508cf58'}
# targets: {'E_5c40cacd8b6f1d', 'E_01c7810508cf58'}
# point_of_interest: P_05cae15b7b3788
# preds: {'E_01c791c6023df2'}
# targets: {'E_8a3f4df8bce905', 'E_3c00079b4eed4a', 'E_a000cba9595c73', 'E_5b12fd4ada60f2', 'E_d94b04ad505846', 'E_01c791c6023df2', 'E_6d43dd3e054aaf', 'E_5e0a777ebe2cf9', 'E_c667545c7f4f23', 'E_fc68ed5343fe2d', 'E_b09a19162a0072'}
# point_of_interest: P_71cd8b36fcf777
# preds: {'E_01c803f6186051'}
# targets: {'E_b6701e0a8883ec', 'E_01c803f6186051'}
# point_of_interest: P_a7255c3bd4fe2f
# preds: {'E_01c8195a01b4e7'}
# targets: {'E_3c0f48682221e5', 'E_ad31f92f27f3b1', 'E_0e790d18aaa487', 'E_0d3c23e5f5a1ac', 'E_3fa4f386b2d179', 'E_5e52ca19eb9404', 'E_722bbf774e2aea', 'E_9876b7ad9e8ce3', 'E_cc65898bbf48a5', 'E_64957bdcbbe6bf', 'E_a2a26c4a0c9d66', 'E_0ed34d32c689d7', 'E_332445d106d426', 'E_c287472e70c61d', 'E_01c8195a01b4e7', 'E_7c9fec464d0710', 'E_d7ebbbeccf6972', 'E_08dc198eb66eba', 'E_481647948f4b8b', 'E_3c45a622f10a3a', 'E_700caf68727ca9', 'E_637a718d71e849', 'E_2337735c959715', 'E_1b12c9bf62d16c', 'E_7ff90274442c45', 'E_3aa4e37675d4e5', 'E_fdc96fe8b39e78', 'E_89cbd32cf39190', 'E_f106a529fe545c', 'E_36fb2b187bb779'}
# point_of_interest: P_ae7c55a13d8c80
# preds: {'E_01c85b4028f3cd'}
# targets: {'E_01c85b4028f3cd', 'E_6d02a8bea3e2f9'}
# point_of_interest: P_2bc3d976f01eeb
# preds: {'E_01c878ad0d33b3'}
# targets: {'E_01c878ad0d33b3', 'E_80d406ceb58f35'}
# point_of_interest: P_9ab59ce163097e
# preds: {'E_01c89cfd32e896'}
# targets: {'E_35da5c71bd3dd8', 'E_01c89cfd32e896'}
# point_of_interest: P_da9d9b7390d2bc
# preds: {'E_01c8ad58245cca'}
# targets: {'E_c5a8cc299c5562', 'E_01c8ad58245cca'}
# point_of_interest: P_0fc436613cc6eb
# preds: {'E_01c8cee2649cdd'}
# targets: {'E_01c8cee2649cdd', 'E_eb46f16508469b'}
# point_of_interest: P_9317c625dd7d88
# preds: {'E_01c8cefae48f7b'}
# targets: {'E_01c8cefae48f7b', 'E_e49a76f0a0d965'}
# point_of_interest: P_56c5bfb2810a0c
# preds: {'E_01c8d12e160a64'}
# targets: {'E_01c8d12e160a64', 'E_a02901ad97d420', 'E_5287a1292b797f', 'E_3c0bbee5fb5558', 'E_72cbd6ce51e812', 'E_60d3a5fa490ac7', 'E_ff7aada4442a64', 'E_e52ee7d57ade7a', 'E_df0196709e4c86', 'E_134eb35175191e', 'E_522944d1a546df'}
# point_of_interest: P_841cb9da762621
# preds: {'E_01c8d4748e0c54'}
# targets: {'E_01c8d4748e0c54', 'E_5876a0fff5dd99'}
# point_of_interest: P_4d242f963e0e1b
# preds: {'E_01c8e9b9b87c7a'}
# targets: {'E_01c8e9b9b87c7a', 'E_0f564a0f5530db'}
# point_of_interest: P_0fa30e06f63391
# preds: {'E_01c8f3c38140f2'}
# targets: {'E_01c8f3c38140f2', 'E_4eb65537ed69f4'}
# point_of_interest: P_6c9b498d9611bf
# preds: {'E_01c90b8f40dd22'}
# targets: {'E_01c90b8f40dd22', 'E_85065c6aa013f8'}
# point_of_interest: P_2c6b7c0def49ae
# preds: {'E_01c92d97293fb9'}
# targets: {'E_01c92d97293fb9', 'E_53fa4130589026'}
# point_of_interest: P_2c8d565ab987bf
# preds: {'E_01c92e3b836989'}
# targets: {'E_da1a2e4cc4b159', 'E_01c92e3b836989'}
# point_of_interest: P_5e518ff79f1ef0
# preds: {'E_01c930ff1a6ea9'}
# targets: {'E_9dec2ec62b4feb', 'E_01c930ff1a6ea9'}
# point_of_interest: P_70d818e4f674db
# preds: {'E_01c960bd053ee7'}
# targets: {'E_01c960bd053ee7', 'E_0b7ad626e173d8', 'E_4a92c27f94e376'}
# point_of_interest: P_27f65a144e3c50
# preds: {'E_01c964c2522a06'}
# targets: {'E_01c964c2522a06', 'E_9a27ca78c1032d'}
# point_of_interest: P_25e22dd2e16ff8
# preds: {'E_01c972d3b9e59e'}
# targets: {'E_45c64ac4fc0c3e', 'E_01c972d3b9e59e'}
# point_of_interest: P_0fff137375228b
# preds: {'E_01c97badcf7ded'}
# targets: {'E_43d09319744426', 'E_01c97badcf7ded'}
# point_of_interest: P_854c2ce7bb9c27
# preds: {'E_01c9a21c0c8711'}
# targets: {'E_21c0b0f7766012', 'E_01c9a21c0c8711', 'E_8fc8a05e89791f', 'E_b1f0292477b487', 'E_f14a9e375eb933'}
# point_of_interest: P_cc8cfc20513151
# preds: {'E_01c9c25e6bfc70'}
# targets: {'E_5797204e3b1d47', 'E_ace65f8a760748', 'E_bc4b495475860a', 'E_c78bfd167f6741', 'E_7391259f089132', 'E_33c899cf055d63', 'E_88b7bf689b9eec', 'E_88c1ceb301b4f8', 'E_cc8641df61be6d', 'E_1d5250fdd2ae29', 'E_9c50d6d6554f7f', 'E_01c9c25e6bfc70'}
# point_of_interest: P_e727a518d57ee5
# preds: {'E_01c9cedf63e492'}
# targets: {'E_01c9cedf63e492', 'E_9a095043162c94', 'E_27eaf9557ae134'}
# point_of_interest: P_4fd8938063a408
# preds: {'E_01c9d4e4b3b577'}
# targets: {'E_1da7c7f998343d', 'E_01c9d4e4b3b577'}
# point_of_interest: P_11978020a42707
# preds: {'E_01c9dc3639d604'}
# targets: {'E_c990b3ce2555d2', 'E_01c9dc3639d604', 'E_8b0229f7489859'}
# point_of_interest: P_7cd7f4790ff296
# preds: {'E_01c9facbad575b'}
# targets: {'E_abeb3cafbf3caa', 'E_01c9facbad575b'}
# point_of_interest: P_fd8055c0ac9b4b
# preds: {'E_01ca05915d7735'}
# targets: {'E_9340a40369eee8', 'E_01ca05915d7735'}
# point_of_interest: P_03191d80687482
# preds: {'E_01ca18db159822'}
# targets: {'E_d557598799cbad', 'E_01ca18db159822'}
# point_of_interest: P_bda21e6deff213
# preds: {'E_01ca25e6b13ac8'}
# targets: {'E_1c1523d82b388c', 'E_01ca25e6b13ac8'}
# point_of_interest: P_36049dd1ae4f46
# preds: {'E_01ca2c0a48d3c9'}
# targets: {'E_422e39e244af4d', 'E_01ca2c0a48d3c9'}
# point_of_interest: P_3fffa016e6f2b8
# preds: {'E_01ca2eb75dd23f'}
# targets: {'E_2f51b40b7bdeca', 'E_01ca2eb75dd23f'}
# point_of_interest: P_c56d5749063182
# preds: {'E_01ca31c5b1b3be'}
# targets: {'E_ca0ceb63a5bab5', 'E_01ca31c5b1b3be'}
# point_of_interest: P_a630a46113e02e
# preds: {'E_01ca397f47f636'}
# targets: {'E_2cda9e57c7abd6', 'E_01ca397f47f636'}
# point_of_interest: P_13816db9716005
# preds: {'E_01ca4dee89a13c'}
# targets: {'E_89d55e50185937', 'E_01ca4dee89a13c'}
# point_of_interest: P_2231df26ceab43
# preds: {'E_01ca535bc77b99'}
# targets: {'E_01ca535bc77b99', 'E_dbed87e84bfb7e'}
# point_of_interest: P_c935ee4c18eb19
# preds: {'E_01ca59cd4f50a3'}
# targets: {'E_01ca59cd4f50a3', 'E_c1b91f3f991e93'}
# point_of_interest: P_5a2cd80b05838a
# preds: {'E_01ca6d3db8b729'}
# targets: {'E_9a40b5d718ac67', 'E_01ca6d3db8b729'}
# point_of_interest: P_04527baaf9f99b
# preds: {'E_01ca93d1523cc7'}
# targets: {'E_6b85f69a53a1b9', 'E_01ca93d1523cc7', 'E_024b7befabea2e'}
# point_of_interest: P_f47c643cfd3806
# preds: {'E_01caa6271068b6'}
# targets: {'E_8899520ea189d9', 'E_01caa6271068b6'}
# point_of_interest: P_bd319193bef2aa
# preds: {'E_01cac0e3def659'}
# targets: {'E_045d15c2fa69ec', 'E_61d7f612a1e744', 'E_01cac0e3def659'}
# point_of_interest: P_e6165c4a27e360
# preds: {'E_01caca6c456060'}
# targets: {'E_6501d39e205031', 'E_01caca6c456060'}
# point_of_interest: P_d007c0b31b13a7
# preds: {'E_01caf50cd74858'}
# targets: {'E_01caf50cd74858', 'E_259228d9624db2'}
# point_of_interest: P_852e937177fbfc
# preds: {'E_01caf5dfb500f1'}
# targets: {'E_01caf5dfb500f1', 'E_15cc68a6a787a3'}
# point_of_interest: P_f3fa01c75836a4
# preds: {'E_01cb0a7adc9a4b'}
# targets: {'E_7a1bcaf53c9699', 'E_01cb0a7adc9a4b'}
# point_of_interest: P_eae8db8f8252ea
# preds: {'E_01cb27d17341ee'}
# targets: {'E_01cb27d17341ee', 'E_ad40fe968c2217'}
# point_of_interest: P_5640e0e4a82e21
# preds: {'E_01cb2e4a7672d5'}
# targets: {'E_01cb2e4a7672d5', 'E_08b20134bfd5c3'}
# point_of_interest: P_cd7831c50d02ee
# preds: {'E_01cb7d0adb5d87'}
# targets: {'E_b0c7b14713140d', 'E_01cb7d0adb5d87'}
# point_of_interest: P_664233e1acf641
# preds: {'E_01cb8004929723'}
# targets: {'E_5af11c2bca74fa', 'E_01cb8004929723'}
# point_of_interest: P_db529c27fef80c
# preds: {'E_01cb94c87ecb16'}
# ...
# targets: {'E_023b0058b3ac13', 'E_ff726bf2b90ff7'}
# point_of_interest: P_a1906b4d756392
# preds: {'E_023b36938fc939'}
# targets: {'E_abd8f37c44cde5', 'E_023b36938fc939'}
# point_of_interest: P_c6ee17c92b911f
# preds: {'E_023b62d10f4040'}
# targets: {'E_cb67e54894ae0d', 'E_023b62d10f4040'}
# point_of_interest: P_a9db168cc65f6e
# preds: {'E_023b7f523df319'}
# targets: {'E_023b7f523df319', 'E_2259dce9fd4031'}
# point_of_interest: P_b0219b75ed7e3e
# preds: {'E_023b918814b246'}
# targets: {'E_023b918814b246', 'E_d946d5f88c1ff5'}
# point_of_interest: P_8a3f68c04d3177
# preds: {'E_023b9fb70bb4e3'}
# targets: {'E_023b9fb70bb4e3', 'E_331cfdafa5ad8a'}
# point_of_interest: P_9a3be30e1d3855
# preds: {'E_023ba7ed57f3a0'}
# targets: {'E_b3a5b13113d54f', 'E_2fe1750fa82464', 'E_023ba7ed57f3a0'}
# point_of_interest: P_2d5d3bff760ffe
# preds: {'E_023bbd760868b9'}
# targets: {'E_a4a5dfc82f46ec', 'E_111596961699cd', 'E_17a1616dbcc2aa', 'E_ed11ed7e8c442d', 'E_fa138b4ecbaecf', 'E_58c740ce468580', 'E_9af1efc329cb5d', 'E_a74e360ef7a060', 'E_dcd9e4c185cf93', 'E_d371d9d322f00d', 'E_156f04c648f0c7', 'E_b687ceae125bb0', 'E_023bbd760868b9', 'E_fdc7e531451a7e', 'E_aa093f30f97a61', 'E_3d8fbc40ae1e51'}
# point_of_interest: P_b1ce78ed49069f
# preds: {'E_023bc5f766dd74'}
# targets: {'E_0e107bc798e5dc', 'E_023bc5f766dd74'}
# point_of_interest: P_80d707c8dfeed6
# preds: {'E_023bcf281230ba'}
# targets: {'E_5c50239be2706e', 'E_023bcf281230ba'}
# point_of_interest: P_bd4c2c547f5c47
# preds: {'E_023be4d8ec39b2'}
# targets: {'E_023be4d8ec39b2', 'E_9d997628000662'}
# point_of_interest: P_93072e83631669
# preds: {'E_023bfc567b1345'}
# targets: {'E_023bfc567b1345', 'E_1a19dfbf608eb3'}
# point_of_interest: P_8b663b3348f7bc
# preds: {'E_023c0135360919'}
# targets: {'E_023c0135360919', 'E_c9f7c575b0c78f'}
# point_of_interest: P_4b2a4bac79c680
# preds: {'E_023c065ef22e2a'}
# targets: {'E_023c065ef22e2a', 'E_9945fc4da5e1d6'}
# point_of_interest: P_d882afc7f86a7f
# preds: {'E_023c07fe60763a'}
# targets: {'E_3700a682d8017a', 'E_023c07fe60763a'}
# point_of_interest: P_2516fd6da373a3
# preds: {'E_023c098be3cdcb'}
# targets: {'E_0ac0e7773f6235', 'E_023c098be3cdcb'}
# point_of_interest: P_8f68a271e2b16a
# preds: {'E_023c0a49ccb540'}
# targets: {'E_4099960f4c2fa4', 'E_023c0a49ccb540'}
# point_of_interest: P_69d04bdee5915c
# preds: {'E_023c27e3f52d3e'}
# targets: {'E_023c27e3f52d3e', 'E_411258c82b409f'}
# point_of_interest: P_f8213620e91cc8
# preds: {'E_023c33bd33060a'}
# targets: {'E_dc1053f8bd8641', 'E_023c33bd33060a'}
# point_of_interest: P_c207ae22e0a0df
# preds: {'E_023c523d5264f4'}
# targets: {'E_023c523d5264f4', 'E_e544b8fcf98ed8'}
# point_of_interest: P_ab4c43dc973096
# preds: {'E_023c69b6fe0b48'}
# targets: {'E_4e7a0b8c10702c', 'E_023c69b6fe0b48'}
# point_of_interest: P_1c52e006b00713
# preds: {'E_023c73b70794b4'}
# targets: {'E_fa3690349895a6', 'E_023c73b70794b4'}
# point_of_interest: P_835bcbf53511ab
# preds: {'E_023d00cba6f9cf'}
# targets: {'E_5f8f7fc5d1a4ce', 'E_023d00cba6f9cf'}
# point_of_interest: P_c748e79a7fa9b5
# preds: {'E_023d0449cede96'}
# targets: {'E_023d0449cede96', 'E_a5da6e07e2b506'}
# point_of_interest: P_9cf1265b382713
# preds: {'E_023d44b3f14852'}
# targets: {'E_023d44b3f14852', 'E_1a1e919b459957'}
# point_of_interest: P_2d4806677658f9
# preds: {'E_023d4b08daa6b1'}
# targets: {'E_023d4b08daa6b1', 'E_f1e9ac87c242de'}
# point_of_interest: P_9ac46b262298bc
# preds: {'E_023d640cbe4807'}
# targets: {'E_ed5e4338ba67a3', 'E_023d640cbe4807'}
# point_of_interest: P_c5dd5b1f36b366
# preds: {'E_023d651ca4d794'}
# targets: {'E_ad00615f18c36c', 'E_023d651ca4d794'}
# point_of_interest: P_5dee6410addc68
# preds: {'E_023d7585a48080'}
# targets: {'E_023d7585a48080', 'E_944f7429be2343', 'E_ea0c8bb575bcf4'}
# point_of_interest: P_27f60f4946635c
# preds: {'E_023de7638a9b85'}
# targets: {'E_3eaa6a47bf6d3d', 'E_023de7638a9b85'}
# point_of_interest: P_88472edc3064b1
# preds: {'E_023e04531ddb28'}
# targets: {'E_696f0a01bed654', 'E_023e04531ddb28'}
# point_of_interest: P_57137b14177edb
# preds: {'E_023e1a456ffab8'}
# targets: {'E_023e1a456ffab8', 'E_130c56e3c4d227'}
# point_of_interest: P_55b435bad371db
# preds: {'E_023e20076dba35'}
# targets: {'E_bc8ffea661266d', 'E_2874f34f8277e0', 'E_023e20076dba35'}
# point_of_interest: P_5a306143c0f480
# preds: {'E_023e2818696f4c'}
# targets: {'E_6ef87d44610fa6', 'E_023e2818696f4c'}
# point_of_interest: P_46e68cef0909af
# preds: {'E_023e3b8ae5e5a5'}
# targets: {'E_023e3b8ae5e5a5', 'E_bd2dd296c305d1'}
# point_of_interest: P_d159c49c6ee838
# preds: {'E_023e431a8a215c'}
# targets: {'E_88d55db51e1ec9', 'E_023e431a8a215c'}
# point_of_interest: P_a61d9dfcd36489
# preds: {'E_023e493c9b6cac'}
# targets: {'E_023e493c9b6cac', 'E_c4b84b96f70fb4'}
# point_of_interest: P_fd16a8a5070ae0
# preds: {'E_023e9002751021'}
# targets: {'E_a1e183420086aa', 'E_023e9002751021'}
# point_of_interest: P_ac15ccf808b590
# preds: {'E_023ebcd037530f'}
# targets: {'E_023ebcd037530f', 'E_eb17913fbca733', 'E_479a83bce6ea4f', 'E_864726a5fd7478'}
# point_of_interest: P_d9606cc7eba617
# preds: {'E_023ee91d0c4f2f'}
# targets: {'E_e4202964dc314f', 'E_023ee91d0c4f2f'}
# point_of_interest: P_b0c5b9ebc00da2
# preds: {'E_023eeb4390c873'}
# targets: {'E_8c8b908127fe31', 'E_023eeb4390c873'}
# point_of_interest: P_439a880c8ce70f
# preds: {'E_023eebe852faef'}
# targets: {'E_023eebe852faef', 'E_5bb380ae34df41'}
# point_of_interest: P_eefcdf321f112d
# preds: {'E_023eec262cb428'}
# targets: {'E_fefc353e5f1869', 'E_023eec262cb428'}
# point_of_interest: P_1e6c1bffb2a966
# preds: {'E_023ef73379010b'}
# targets: {'E_a72f9c79b68ffa', 'E_023ef73379010b'}
# point_of_interest: P_01cd7094db6a44
# preds: {'E_023f734e2f04bc'}
# targets: {'E_023f734e2f04bc', 'E_0d9a3f09996ec0'}
# point_of_interest: P_916b9245c80607
# preds: {'E_023f734ed4136a'}
# targets: {'E_a135e45e273a9d', 'E_023f734ed4136a'}
# point_of_interest: P_ba8331367b0610
# preds: {'E_023fbee6f2eca2'}
# targets: {'E_36767edc586399', 'E_6be470ce86dd74', 'E_1a32cb267a5d3f', 'E_913515ca83ab80', 'E_c7f3772de38636', 'E_efc2e6c6ca0a90', 'E_e7614ecf99fec7', 'E_6d72095a00fa11', 'E_1630d2f6620738', 'E_342eff77943ff6', 'E_bdf8c4bdd7fc68', 'E_ed5e9af3a0e15d', 'E_f7501a17acacc2', 'E_0466183646e6e4', 'E_09999543a31bad', 'E_625b901d773012', 'E_42afd65b08f029', 'E_ea4997d2095956', 'E_4c35e4a7bf0d2a', 'E_af87e32e6b5fbb', 'E_fa87acde7e43c8', 'E_08ee0834492ba0', 'E_462bd626cfb58a', 'E_b31d2a4dec94dc', 'E_f944b6df101cd5', 'E_1e4bcbf7547b90', 'E_1cbce92a8f6e4a', 'E_b0f6053f8bb6d7', 'E_44e132bcdd4aed', 'E_af53cc93e9e66a', 'E_a6fd06a2c84a08', 'E_31f44ebe51c095', 'E_cc0bb3c2c2bfa9', 'E_56a286ca67516a', 'E_a0da255b80add2', 'E_cca3ab8dc9bb98', 'E_5a06bbb6bfea4d', 'E_023fbee6f2eca2', 'E_40ec92ea978896', 'E_a581bd01697aca', 'E_5efadd5695b71d', 'E_44f240d332bc94', 'E_f29811354d0cb2', 'E_2af897ee854864', 'E_a793f3251d280d', 'E_b307a98bc57940', 'E_150067dfeecc2f', 'E_c3837e50d6d9f6', 'E_27e51cbac0bb0a', 'E_e0b2222a679524', 'E_8ae79d01e8e789', 'E_db5bc76e202bc8', 'E_33dcb6a5dc2a3a', 'E_0cccc027b09760', 'E_8f05e49a27b1b2', 'E_568f3d6d7189f4', 'E_ff1f89bf5199a1', 'E_48090c6449bf6e', 'E_5fb900473eca9f', 'E_8648ca37e50fe3', 'E_0facc73150cb8e', 'E_f3fad6252e6cd8', 'E_93f3d656b71006', 'E_967358ddbd538a', 'E_fde8886736c90c', 'E_eb69bb426d2d3e', 'E_1d1d0ec3e08783', 'E_a5eb07437b9b09', 'E_5e71527e00a5a3', 'E_cfcec824b632cd', 'E_36168fc46916eb', 'E_e4e894fcd359a6', 'E_b18583505a0b09', 'E_31aab636b56b37', 'E_2bd539cd746060', 'E_a25947c05c2277', 'E_7b0069d2ea7a6e', 'E_88fec9c496e66d'}
# point_of_interest: P_aab187db71cff5
# preds: {'E_023fe215e6e873'}
# targets: {'E_15b118a4a0106c', 'E_023fe215e6e873'}
# point_of_interest: P_3c8c2ff07a739c
# preds: {'E_023ff34b678988'}
# targets: {'E_023ff34b678988', 'E_980c9b6cb10a75'}
# point_of_interest: P_db71a224c6086f
# preds: {'E_0240121c0f0542'}
# targets: {'E_a75b2b64e1b88e', 'E_bb13d7d7b8e8b3', 'E_60d0b7c342f110', 'E_0240121c0f0542'}
# point_of_interest: P_38dddd67f9ff2d
# preds: {'E_02407bcb48f685'}
# targets: {'E_02407bcb48f685', 'E_161f133f378ee6'}
# point_of_interest: P_7f704e571834a1
# preds: {'E_024082637d4e7b'}
# targets: {'E_1f6def594de1ea', 'E_024082637d4e7b', 'E_e71a3dfae33a15', 'E_77c033b29097e1', 'E_a84743792c2126', 'E_b34b9f1db777fe', 'E_14af23b376c4c2', 'E_3fc4812532f202', 'E_493f0d5482ea54', 'E_5d3a9f239028c3', 'E_d489f13e5124ac', 'E_e717a382e058f4', 'E_1e42d953080e1e', 'E_5035642a4772be', 'E_2568f90f9e1ebb', 'E_debd4d4c7cd9dd', 'E_d0b441b26133c5', 'E_f2a5f40f3e93ab', 'E_7947ec3a0d3cb2', 'E_cc8a8f7e9cebf6', 'E_20654cb406a673', 'E_8aa90748b780a5', 'E_0e3bd47cc30256', 'E_48b116a04ade0c', 'E_f321495c178e74', 'E_c79f3062ecfa60', 'E_dfaa7127e7bb96', 'E_20f418dd06b1e5'}
# point_of_interest: P_b8b0bd25683dc4
# preds: {'E_0240ad9e2c4006'}
# targets: {'E_956834726f047f', 'E_bf2cabcbc3dba5', 'E_8802c9732c4e85', 'E_0240ad9e2c4006', 'E_6ffe5e4ecd5e84', 'E_82b93dfa861490', 'E_e47f3ee48ba38e', 'E_e1c217308de395', 'E_c801591e0971a7', 'E_5ef560a55544d2'}
# point_of_interest: P_53ee50fee13b93
# preds: {'E_0240ed6c6cfa9b'}
# targets: {'E_728785cf2fead4', 'E_0240ed6c6cfa9b'}
# point_of_interest: P_01f7883abccfcf
# preds: {'E_024103fd99e516'}
# targets: {'E_67f95081f135a4', 'E_024103fd99e516'}
# point_of_interest: P_43087729824c1e
# preds: {'E_0241231e143536'}
# targets: {'E_0241231e143536', 'E_464e586cf7d865', 'E_7617688fc67310', 'E_52ceb9e6290bbe'}
# point_of_interest: P_1bfa550fce79aa
# preds: {'E_024141c46d1217'}
# targets: {'E_024141c46d1217', 'E_6ca9e7e4cd83b1'}
# point_of_interest: P_f788d939613cc6
# preds: {'E_024141e7150992'}
# targets: {'E_024141e7150992', 'E_0382d4da274d31', 'E_40946f1e5aeee2', 'E_ee92d3df221909'}
# point_of_interest: P_e34de28e819163
# preds: {'E_02419f981e7c2b'}
# targets: {'E_02419f981e7c2b', 'E_a5dd521b86930d'}
# point_of_interest: P_2254bff4b89683
# preds: {'E_0241c1346791d1'}
# targets: {'E_4679f6fa5facc4', 'E_36451f9ead9c5c', 'E_209bdb960afb8b', 'E_0241c1346791d1', 'E_5d621cdd131f93'}
# point_of_interest: P_1fcb6439447f93
# preds: {'E_0241d96a3570bc'}
# targets: {'E_0241d96a3570bc', 'E_f5ebbd67fc4cff'}
# point_of_interest: P_9435133fde8db3
# preds: {'E_024272d29331fd'}
# targets: {'E_edcb0245f40070', 'E_024272d29331fd'}
# point_of_interest: P_521c2b48926ebe
# preds: {'E_0242770f3ea8d6'}
# targets: {'E_71fa21b52ba1db', 'E_1623f067b199a2', 'E_0242770f3ea8d6', 'E_1cbddd6994716b', 'E_70df531618f9ef', 'E_9b852d4d313126'}
# point_of_interest: P_168d071abdaf4c
# preds: {'E_024284337b5d37'}
# targets: {'E_c20569cb0ad87e', 'E_024284337b5d37'}
# point_of_interest: P_5cb3fdaa6f4e5f
# preds: {'E_0242884db09eb9'}
# targets: {'E_0242884db09eb9', 'E_d64ca654f7b1e5'}
# point_of_interest: P_b30569820dd96e
# preds: {'E_0242a04d2d8c29'}
# targets: {'E_7abffc51c7e73d', 'E_767929f4a323e7', 'E_de92e18bcb66ad', 'E_0242a04d2d8c29', 'E_e6f06c5df786f8', 'E_867fa2fd9bf5de'}
# point_of_interest: P_9f2820fb1fbd3d
# preds: {'E_0242b39a8c71d6'}
# targets: {'E_0242b39a8c71d6', 'E_ee43597364f976'}
# point_of_interest: P_7ccba7a7062e8b
# preds: {'E_0242d0f4c8546e'}
# targets: {'E_80c87b637aefc2', 'E_0242d0f4c8546e'}
# point_of_interest: P_2d7f4f051dc5f9
# preds: {'E_0243064ff4f7a5'}
# targets: {'E_ebd8c47990a23b', 'E_0243064ff4f7a5'}
# point_of_interest: P_aabb4fc2321da9
# preds: {'E_024309f7637b28'}
# targets: {'E_70d2c43279f9ad', 'E_b697b9e34f9200', 'E_024309f7637b28'}
# point_of_interest: P_9542e1db60665d
# preds: {'E_0243110c499931'}
# targets: {'E_0243110c499931', 'E_2e3da0f49f3a6c'}
# point_of_interest: P_3eeedf44a5cd86
# preds: {'E_024321a54feed0'}
# targets: {'E_024321a54feed0', 'E_d8d9db521cc220'}
# point_of_interest: P_c3f054d7c596de
# preds: {'E_0243784db22de1'}
# targets: {'E_93ca7568fe45e5', 'E_0243784db22de1'}
# point_of_interest: P_67d9c799c9ff93
# preds: {'E_02438f4f9923fa'}
# targets: {'E_b41367eab02bff', 'E_02438f4f9923fa'}
# point_of_interest: P_6f994668dd3f0f
# preds: {'E_0243be19fc8a19'}
# targets: {'E_1f65839fefb4ac', 'E_a76c9cc03fb99b', 'E_956a787e874fba', 'E_771f21a750f05f', 'E_a5e7b1c4cd599e', 'E_0243be19fc8a19', 'E_da74da3dc24b8c'}
# point_of_interest: P_20b370c0a9e0e0
# preds: {'E_0243d24caecd85'}
# targets: {'E_ff702db1095fa2', 'E_0243d24caecd85'}
# point_of_interest: P_3750992e9715ad
# preds: {'E_0243de6357d2d1'}
# targets: {'E_0243de6357d2d1', 'E_b671b39b3bf54f'}
# point_of_interest: P_fc0d0c704c4366
# preds: {'E_0243ee7c3f5cd1'}
# targets: {'E_0243ee7c3f5cd1', 'E_4ddec20837c64c'}
# point_of_interest: P_a6c431a7fb0d13
# preds: {'E_0243fa2ec3f1cb'}
# targets: {'E_0243fa2ec3f1cb', 'E_85fd701f8c301b'}
# point_of_interest: P_06eed84ee84341
# preds: {'E_0243fdd53de8ad'}
# targets: {'E_0243fdd53de8ad', 'E_848ca7554c559e', 'E_7529de7a74ecff'}
# point_of_interest: P_ecedf3e4d0cfdc
# preds: {'E_02442cee8e4ff2'}
# targets: {'E_983399228d29b0', 'E_02442cee8e4ff2'}
# point_of_interest: P_77fc3390bc4db2
# preds: {'E_02443caab836fd'}
# targets: {'E_98afa92c64ec81', 'E_c23b0e64824723', 'E_2751949cdde182', 'E_c635438f048b80', 'E_02443caab836fd', 'E_cb0aa18bd1eec1', 'E_cba738f19014d1'}
# point_of_interest: P_82389e85c670d6
# preds: {'E_02446ecc2c2126'}
# targets: {'E_02446ecc2c2126', 'E_a67c4289743800'}
# point_of_interest: P_9e48c43464f73c
# preds: {'E_02448ad5beb7f9'}
# targets: {'E_8fd0d07a87cc9a', 'E_02448ad5beb7f9'}
# point_of_interest: P_e2ddaa5eb0d806
# preds: {'E_0244a0ab691642'}
# targets: {'E_21bbbaffff5326', 'E_0244a0ab691642'}
# point_of_interest: P_10ff32bab7b9ee
# preds: {'E_0244e4c3e4baf6'}
# targets: {'E_f8578246d7aee7', 'E_0244e4c3e4baf6'}
# point_of_interest: P_85373963e579a5
# preds: {'E_02451350cead62'}
# targets: {'E_48565884c0f951', 'E_50b6218e32a8e3', 'E_31de1fa02f93a6', 'E_6997f97afc3cfa', 'E_be833818847fab', 'E_3fd43b25b792cf', 'E_5c230593b9cdad', 'E_f42dba02fd94bd', 'E_3e92b7b48705d1', 'E_76c24605853152', 'E_12367481819846', 'E_f5deaa2cc71a27', 'E_264a04d5562388', 'E_454fb9a7210513', 'E_4640617b339568', 'E_f306000be11fec', 'E_f05b27309aa4e6', 'E_02451350cead62'}
# point_of_interest: P_699d12930e6932
# preds: {'E_0245243e21e07c'}
# targets: {'E_0245243e21e07c', 'E_8881ca4c3bcefe'}
# point_of_interest: P_9f7b8aa4adc7bc
# preds: {'E_0245368dab23f1'}
# targets: {'E_08b471882a156c', 'E_0245368dab23f1'}
# point_of_interest: P_e7d0a2ab150d1a
# preds: {'E_0245417e7994ed'}
# targets: {'E_d5c82c6f3db3a2', 'E_0245417e7994ed'}
# point_of_interest: P_1277fe8cf5c28d
# preds: {'E_02455845947e1a'}
# targets: {'E_02455845947e1a', 'E_c59f900765005e'}
# point_of_interest: P_a715b8ace1eacf
# preds: {'E_024579cdd41d7d'}
# targets: {'E_024579cdd41d7d', 'E_0cccf0ac986563'}
# point_of_interest: P_9d251696fe5f79
# preds: {'E_02458e31feca0f'}
# targets: {'E_25f1df690c693c', 'E_02458e31feca0f'}
# point_of_interest: P_f65a2b7df749c6
# preds: {'E_0245bf466ca05f'}
# targets: {'E_0245bf466ca05f', 'E_b430413b3ba4a1'}
# point_of_interest: P_55024874314d6b
# preds: {'E_0245c89f0b1518'}
# targets: {'E_6a3eb09a07284a', 'E_15d02b213b48a6', 'E_0245c89f0b1518', 'E_43c1ae5eb35d55'}
# point_of_interest: P_fe37608196f8e1
# preds: {'E_0245d31b4df736'}
# targets: {'E_0245d31b4df736', 'E_44a96970e6a50e'}
# point_of_interest: P_99c28b0ec83b5a
# preds: {'E_0245dd4f1b176b'}
# targets: {'E_0245dd4f1b176b', 'E_6e3351847af9f3'}
# point_of_interest: P_1aec95986bbdf5
# preds: {'E_0245f6be2639b7'}
# targets: {'E_0245f6be2639b7', 'E_a9fec2c33469c5'}
# point_of_interest: P_6228425b245f59
# preds: {'E_0246118ba947e7'}
# targets: {'E_65eb533507a00c', 'E_0246118ba947e7'}
# point_of_interest: P_81b33c0644c66e
# preds: {'E_0246168c0f5d55'}
# targets: {'E_f895b982ad3c0c', 'E_0246168c0f5d55'}
# point_of_interest: P_dbc251ef9c28fd
# preds: {'E_024618b670e240'}
# targets: {'E_59c835df48bead', 'E_024618b670e240', 'E_a739c2b32af465', 'E_2739bcf24e1f1d', 'E_bbbdf0b3e8db13', 'E_5cf560acaca812', 'E_fddf703a51f676', 'E_3caea5e1d70e08', 'E_3484112d1dd4c5'}
# point_of_interest: P_b428f766067bfe
# preds: {'E_024623a2757d3f'}
# targets: {'E_024623a2757d3f', 'E_cb1b8e7ceee4e9'}
# point_of_interest: P_bc031397011d0d
# preds: {'E_0246378614f17a'}
# targets: {'E_eb3c34fb00eb40', 'E_0246378614f17a'}
# point_of_interest: P_885329f28978da
# preds: {'E_024643d575e298'}
# targets: {'E_024643d575e298', 'E_2beca7c8215858', 'E_e549f4f1289dcd'}
# point_of_interest: P_626d24bf3c3542
# preds: {'E_02466ec2881f6a'}
# targets: {'E_30228196dea1f9', 'E_02466ec2881f6a'}
# point_of_interest: P_06e17423909fd4
# preds: {'E_0246770867e0b7'}
# targets: {'E_64ed4acc6017f2', 'E_0246770867e0b7'}
# point_of_interest: P_54923d354f540e
# preds: {'E_024694d70db30e'}
# targets: {'E_024694d70db30e', 'E_3717862a056319'}
# point_of_interest: P_2e5071fd59f9ec
# preds: {'E_0246ca08392264'}
# targets: {'E_0410fb88ac512d', 'E_8cbf45602f17cb', 'E_0246ca08392264'}
# point_of_interest: P_9bc3dc62c2ba4d

# %%
e_id = 'E_0000764d65557e'
poi = 'P_be89c778befb23'

# %%
data[data[TARGET]==poi]
# Out:
#                         name  latitude   longitude  \
# id
# E_0000764d65557e  mcdonald s -7.265894  112.749382
#
#                                           address city state  zip country  \
# id
# E_0000764d65557e  Plaza Surabaya  Pemuda Building             NaN      ID
#
#                   url phone  ... state_split   cv co_net  \
# id                           ...
# E_0000764d65557e  NaN   NaN  ...          []  1.0    0.0
#
#                           main_category scale adjacency_frequency  \
# id
# E_0000764d65557e  Fast Food Restaurants     0                 5.0
#
#                   betweeness_centrality  clustering_coefficient  \
# id
# E_0000764d65557e               0.003875                     0.3
#
#                  median_distances_median  category_rate
# id
# E_0000764d65557e             6354.897123       0.015049
#
# [1 rows x 25 columns]

# %%
train[train['id']==e_id]
# Out:
#                  id          match_id     kdist  kneighbors  name_iou  \
# 7  E_0000764d65557e  E_0000764d65557e  0.000000           0  1.000000
# 7  E_0000764d65557e  E_013b2d64e1eb4a  0.004748           1  0.000000
# 7  E_0000764d65557e  E_004d2ea1d5d2ba  0.007341           2  0.000000
# 7  E_0000764d65557e  E_008d2b54a93e06  0.043329          13  0.333333
# 7  E_0000764d65557e  E_01f127a71e90dc  0.645305          36  0.000000
# 7  E_0000764d65557e  E_01601b89bbacea  0.720570          58  0.333333
# 7  E_0000764d65557e  E_004270eba243f5  0.891830          62  0.000000
#
#    cat_similarity  name_rank  cv  co_net  match_co_net  ...  \
# 7    1.000000e+00        1.0   1     0.0           0.0  ...
# 7    0.000000e+00        9.0   1     0.0           NaN  ...
# 7    0.000000e+00        8.0   1     0.0           4.0  ...
# 7    1.000000e+00        2.0   1     0.0           0.0  ...
# 7    1.000000e+00        4.0   1     0.0           0.0  ...
# 7    1.000000e+00        3.0   1     0.0           0.0  ...
# 7    1.000000e-09        5.0   1     0.0           NaN  ...
#
#    clustering_coefficient  match_clustering_coefficient  \
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.166667
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
#
#    mean_clustering_coefficient  median_distances_median  \
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.233333              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
#
#    match_median_distances_median  mean_median_distances_median  category_rate  \
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3710.036939                   5032.467031       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    3091.985179                   4723.441151       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
#
#    match_category_rate  mean_category_rate  label
# 7             0.015049            0.015049      1
# 7                  NaN                 NaN      0
# 7             0.005702            0.010375      0
# 7             0.015049            0.015049      0
# 7             0.001271            0.008160      0
# 7             0.015049            0.015049      0
# 7                  NaN                 NaN      0
#
# [7 rows x 30 columns]

# %%
# data2 = data.copy()
# data2.reset_index(drop=False, inplace=True)
# tmp = train[train.id==e_id]
# # tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], on='id', how='left')
# tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], left_on='match_id', right_on='id', how='left')
# del data2

# tmp

# %% [markdown]
# # Make Features

# %% [markdown]
# ## TF-IDF

# %%
if TFIDF:
    vec_columns = ['name', 'categories', 'address', 'state', 'url', 'country']

    tfidf_d = {}
    for col in vec_columns:
        tfidf = TfidfVectorizer()
        tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
        tfidf_d[col] = tv_fit

# %% [markdown]
# ## NLP

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
str_columns = ['url', 'name', 'address', 'city', 'state', 'zip', 'categories', 'phone',  'country']
# data['city_state'] = data['city'].fillna('') + data['state'].fillna('')
# data['all'] = data['name'] + data['address'].fillna('') + data['city'].fillna('') + data['state'].fillna('')
# str_columns += ['city_state', 'all']

# if COM > 0:
#     co_columns = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']

# def intersection(s, match_s):
#     return len(set(s.split(' ')) & set(match_s.split(' ')))

# %%
# %%time

# def sm_ratio(x):
#     return SequenceMatcher(None, x[0], x[1]).ratio()

# def levens_dist(x):
#     return Levenshtein.distance(x[0], x[1])

# def calc_jaro_winkler(x):
#     return Levenshtein.jaro_winkler(x[0], x[1])

# def calc_LCS(x):
#     return LCS(str(x[0]), str(x[1]))

def add_features(df):
    for col in tqdm(str_columns):
        before_cols = df.columns
        if TFIDF and col in vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_tfidf_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
            df[f'{col}_tfidf_diff'] = (tv_fit[indexs] - tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
#         arrs = np.array([col_values, matcol_values])
#         df[f'{col}_gesh'] = np.apply_along_axis(sm_ratio, 0, arrs)
#         df[f'{col}_leven'] = np.apply_along_axis(levens_dist, 0, arrs)
#         df[f'{col}_jaro'] = np.apply_along_axis(calc_jaro_winkler, 0, arrs)
#         df[f'{col}_lcs'] = np.apply_along_axis(calc_LCS, 0, arrs)
#         del arrs
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
#         intersections = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
#                 intersections.append(intersection(str(s), str(match_s)))
            elif s != 'nan' and match_s != 'nan':
                geshs.append(-1)
                levens.append(-1)
                jaros.append(-1)
                lcss.append(-1)
#                 intersections.append(-1)
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
#                 intersections.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
#         df[f'{col}_intersections'] = intersections
        
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
        
        del col_values, matcol_values
        after_cols = df.columns
        diff_cols = list(set(after_cols) - set(before_cols))
        df[diff_cols] = reduce_mem_usage(df[diff_cols])
        gc.collect()
        
#     if COM > 0:
#         for col in tqdm(co_columns):
#             col_values = data.loc[df['id']][col].values
#             matcol_values = data.loc[df['match_id']][col].values
#             if col != 'main_category':
#                 df[f's_{col}'] = col_values
#                 df[f't_{col}'] = matcol_values

#             if TFIDF and col in ['main_category', 'co_net']:
#                 df[f'is_match_{col}'] = col_values == matcol_values

    return df

train = add_features(train)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.65 MB
# Decreased by 68.2%
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.47 MB
# Decreased by 71.6%
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.53 MB
# Decreased by 70.5%
# Memory usage of dataframe is 4.24 MB
# Memory usage after optimization is: 1.24 MB
# Decreased by 70.8%
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.47 MB
# Decreased by 71.6%
# Memory usage of dataframe is 2.36 MB
# Memory usage after optimization is: 0.94 MB
# Decreased by 60.0%
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.59 MB
# Decreased by 69.3%
# Memory usage of dataframe is 2.36 MB
# Memory usage after optimization is: 0.94 MB
# Decreased by 60.0%
# Memory usage of dataframe is 5.18 MB
# Memory usage after optimization is: 1.47 MB
# Decreased by 71.6%
# CPU times: user 32 s, sys: 233 ms, total: 32.2 s
# Wall time: 32.1 s

# %% [markdown]
# # Train

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'))

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        print(col)
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
#             df[col] = df[col].astype('category')
            pass

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

train = reduce_mem_usage(train)
# Out:
# Memory usage of dataframe is 21.44 MB
# id
# match_id
# kdist
# kneighbors
# name_iou
# cat_similarity
# name_rank
# cv
# co_net
# match_co_net
# is_match_co_net
# scale
# match_scale
# is_match_scale
# adjacency_frequency
# match_adjacency_frequency
# mean_adjacency_frequency
# betweeness_centrality
# match_betweeness_centrality
# mean_betweeness_centrality
# clustering_coefficient
# match_clustering_coefficient
# mean_clustering_coefficient
# median_distances_median
# match_median_distances_median
# mean_median_distances_median
# category_rate
# match_category_rate
# mean_category_rate
# label
# url_tfidf_sim
# url_tfidf_diff
# url_gesh
# url_leven
# url_jaro
# url_lcs
# url_len_diff
# url_nleven
# url_nlcsk
# url_nlcs
# name_tfidf_sim
# name_tfidf_diff
# name_gesh
# name_leven
# name_jaro
# name_lcs
# name_len_diff
# name_nleven
# name_nlcsk
# name_nlcs
# address_tfidf_sim
# address_tfidf_diff
# address_gesh
# address_leven
# address_jaro
# address_lcs
# address_len_diff
# address_nleven
# address_nlcsk
# address_nlcs
# city_gesh
# city_leven
# city_jaro
# city_lcs
# city_len_diff
# city_nleven
# city_nlcsk
# city_nlcs
# state_tfidf_sim
# state_tfidf_diff
# state_gesh
# state_leven
# state_jaro
# state_lcs
# state_len_diff
# state_nleven
# state_nlcsk
# state_nlcs
# zip_gesh
# zip_leven
# zip_jaro
# zip_lcs
# categories_tfidf_sim
# categories_tfidf_diff
# categories_gesh
# categories_leven
# categories_jaro
# categories_lcs
# categories_len_diff
# categories_nleven
# categories_nlcsk
# categories_nlcs
# phone_gesh
# phone_leven
# phone_jaro
# phone_lcs
# country_tfidf_sim
# country_tfidf_diff
# country_gesh
# country_leven
# country_jaro
# country_lcs
# country_len_diff
# country_nleven
# country_nlcsk
# country_nlcs
# Memory usage after optimization is: 12.84 MB
# Decreased by 40.1%

# %%
features = ['kdist', 'name_gesh', 'name_leven', 'name_jaro',
       'name_lcs', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs',
       'address_gesh', 'address_leven', 'address_jaro', 'address_lcs',
       'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs',
       'city_gesh', 'city_leven', 'city_jaro', 'city_lcs', 'city_len_diff',
       'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_leven',
       'state_jaro', 'state_lcs', 'state_len_diff', 'state_nleven',
       'state_nlcsk', 'state_nlcs', 'zip_gesh', 'zip_leven', 'zip_jaro',
       'zip_lcs', 'categories_gesh', 'categories_leven', 'categories_jaro',
       'categories_lcs', 'categories_len_diff', 'categories_nleven',
       'categories_nlcsk', 'categories_nlcs', 'phone_gesh', 'phone_leven',
       'phone_jaro', 'phone_lcs', 'url_gesh', 'url_leven', 'url_jaro',
       'url_lcs', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs',
       'country_len_diff', 'country_jaro', 'country_lcs', 'country_nlcsk',
       'country_nleven', 'country_nlcs', 'country_leven', 'country_gesh', 
       'co_net', 'match_co_net', 'name_rank',
#        'match_scale', 'is_match_scale', 'is_match_co_net']
       'is_match_scale', 'is_match_co_net', 'match_scale', 'scale',
       'category_rate', 'match_adjacency_frequency', 'clustering_coefficient', 'match_category_rate',
       'betweeness_centrality', 'mean_clustering_coefficient', 'match_median_distances_median',
       'mean_category_rate', 'match_betweeness_centrality', 'mean_betweeness_centrality', 'mean_adjacency_frequency',
       'adjacency_frequency', 'median_distances_median', 'match_clustering_coefficient', 'mean_median_distances_median',
       'cat_similarity', 'name_iou'] # cat_similarity
#        'city_state_gesh', 'all_jaro', 'all_gesh', 'city_state_jaro', 'city_state_len_diff', 'all_nleven', 'city_state_nlcs', 'city_state_leven']
#         'name_intersections', 'address_intersections', 'city_intersections', 'state_intersections']

if TFIDF:
       features.extend(
           ['country_tfidf_sim', 'name_tfidf_diff', 'address_tfidf_diff', 'state_tfidf_sim', 'categories_tfidf_sim', 'url_tfidf_diff', 
       'country_tfidf_diff', 'categories_tfidf_diff', 'url_tfidf_sim', 'name_tfidf_sim', 'address_tfidf_sim', 'state_tfidf_diff'])
    

print(set(train.columns) - set(features))
print(f'no cols: {set(features) - set(train.columns)}')
# Out:
# {'label', 'cv', 'match_id', 'kneighbors', 'id'}
# no cols: set()

# %%
params = {
    'num_boost_round': 10000,
    'num_leaves': 500,
    'max_bin':300,
    'feature_fraction': 0.52,
    'bagging_fraction': 0.52,
    'max_depth': -1,
    'objective': 'binary',
    'learning_rate': 0.05,
    "boosting_type": "gbdt",
    "metric": 'auc',
    'early_stopping_rounds': 100,
    "verbosity": 50,
    'random_state': 47
}

# %%
# %%time

models = []
oof = np.zeros((len(train), N_FOLD), dtype=np.float64)
for i in range(N_FOLD):
    trn_idx = train['cv']!=i
    val_idx = train['cv']==i
    valid = train[train['cv']==i]
    train_X, train_y = train[trn_idx][features], train[trn_idx]['label']
    valid_X, valid_y = train[val_idx][features], train[val_idx]['label']
    
    print(f'*** start train cv: {i} ***')
    model = lgb.LGBMClassifier(**params)
    model.fit(
                train_X, train_y, 
                eval_set=[(valid_X, valid_y)])
    
    oof[val_idx] = model.predict_proba(valid_X)
    models.append(model)
    
    model_path = os.path.join(MODEL_PATH, f'lgb_fold{i}.pkl')
    print(f'save model: {model_path}')
    pickle.dump(model, open(model_path, 'wb'))
# Out:
# *** start train cv: 0 ***
# [1]	valid_0's auc: 0.997517
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.997734
# [3]	valid_0's auc: 0.997879
# [4]	valid_0's auc: 0.998029
# [5]	valid_0's auc: 0.997851
# [6]	valid_0's auc: 0.997583
# [7]	valid_0's auc: 0.997549
# [8]	valid_0's auc: 0.997445
# [9]	valid_0's auc: 0.997439
# [10]	valid_0's auc: 0.998056
# [11]	valid_0's auc: 0.998039
# [12]	valid_0's auc: 0.998032
# [13]	valid_0's auc: 0.998028
# [14]	valid_0's auc: 0.998019
# [15]	valid_0's auc: 0.998022
# [16]	valid_0's auc: 0.998386
# [17]	valid_0's auc: 0.998382
# [18]	valid_0's auc: 0.998382
# [19]	valid_0's auc: 0.998375
# [20]	valid_0's auc: 0.998375
# [21]	valid_0's auc: 0.998369
# [22]	valid_0's auc: 0.998365
# [23]	valid_0's auc: 0.998545
# [24]	valid_0's auc: 0.998724
# [25]	valid_0's auc: 0.998721
# [26]	valid_0's auc: 0.998723
# [27]	valid_0's auc: 0.998723
# [28]	valid_0's auc: 0.998726
# [29]	valid_0's auc: 0.998904
# [30]	valid_0's auc: 0.999304
# [31]	valid_0's auc: 0.999306
# [32]	valid_0's auc: 0.999304
# [33]	valid_0's auc: 0.999319
# [34]	valid_0's auc: 0.999503
# [35]	valid_0's auc: 0.999501
# [36]	valid_0's auc: 0.999495
# [37]	valid_0's auc: 0.999492
# [38]	valid_0's auc: 0.999493
# [39]	valid_0's auc: 0.999492
# [40]	valid_0's auc: 0.999491
# [41]	valid_0's auc: 0.999488
# [42]	valid_0's auc: 0.999501
# [43]	valid_0's auc: 0.999497
# [44]	valid_0's auc: 0.999494
# [45]	valid_0's auc: 0.999493
# [46]	valid_0's auc: 0.999501
# [47]	valid_0's auc: 0.999503
# [48]	valid_0's auc: 0.999501
# [49]	valid_0's auc: 0.999506
# [50]	valid_0's auc: 0.999507
# [51]	valid_0's auc: 0.999517
# [52]	valid_0's auc: 0.999518
# [53]	valid_0's auc: 0.999515
# [54]	valid_0's auc: 0.99952
# [55]	valid_0's auc: 0.99952
# [56]	valid_0's auc: 0.999518
# [57]	valid_0's auc: 0.99952
# [58]	valid_0's auc: 0.999517
# [59]	valid_0's auc: 0.999518
# [60]	valid_0's auc: 0.999518
# [61]	valid_0's auc: 0.999516
# [62]	valid_0's auc: 0.999515
# [63]	valid_0's auc: 0.999514
# [64]	valid_0's auc: 0.999513
# [65]	valid_0's auc: 0.999511
# [66]	valid_0's auc: 0.999512
# [67]	valid_0's auc: 0.999511
# [68]	valid_0's auc: 0.99951
# [69]	valid_0's auc: 0.999512
# [70]	valid_0's auc: 0.999513
# [71]	valid_0's auc: 0.999862
# [72]	valid_0's auc: 0.999861
# [73]	valid_0's auc: 0.99986
# [74]	valid_0's auc: 0.999859
# [75]	valid_0's auc: 0.99986
# [76]	valid_0's auc: 0.999862
# [77]	valid_0's auc: 0.999863
# [78]	valid_0's auc: 0.999877
# [79]	valid_0's auc: 0.999876
# [80]	valid_0's auc: 0.999874
# [81]	valid_0's auc: 0.999871
# [82]	valid_0's auc: 0.999869
# [83]	valid_0's auc: 0.99987
# [84]	valid_0's auc: 0.999868
# [85]	valid_0's auc: 0.999868
# [86]	valid_0's auc: 0.999867
# [87]	valid_0's auc: 0.999866
# [88]	valid_0's auc: 0.999866
# [89]	valid_0's auc: 0.999879
# [90]	valid_0's auc: 0.999885
# [91]	valid_0's auc: 0.999891
# [92]	valid_0's auc: 0.99989
# [93]	valid_0's auc: 0.999889
# [94]	valid_0's auc: 0.999888
# [95]	valid_0's auc: 0.999887
# [96]	valid_0's auc: 0.999888
# [97]	valid_0's auc: 0.999888
# [98]	valid_0's auc: 0.999887
# [99]	valid_0's auc: 0.999887
# [100]	valid_0's auc: 0.999887
# [101]	valid_0's auc: 0.999886
# [102]	valid_0's auc: 0.999886
# [103]	valid_0's auc: 0.999885
# [104]	valid_0's auc: 0.999884
# [105]	valid_0's auc: 0.999885
# [106]	valid_0's auc: 0.999887
# [107]	valid_0's auc: 0.999889
# [108]	valid_0's auc: 0.999888
# [109]	valid_0's auc: 0.99989
# [110]	valid_0's auc: 0.999888
# [111]	valid_0's auc: 0.999887
# [112]	valid_0's auc: 0.999888
# [113]	valid_0's auc: 0.999888
# [114]	valid_0's auc: 0.999888
# [115]	valid_0's auc: 0.999888
# [116]	valid_0's auc: 0.999888
# [117]	valid_0's auc: 0.999887
# [118]	valid_0's auc: 0.999886
# [119]	valid_0's auc: 0.999886
# [120]	valid_0's auc: 0.999887
# [121]	valid_0's auc: 0.999888
# [122]	valid_0's auc: 0.999887
# [123]	valid_0's auc: 0.999886
# [124]	valid_0's auc: 0.99989
# [125]	valid_0's auc: 0.999893
# [126]	valid_0's auc: 0.999894
# [127]	valid_0's auc: 0.999893
# [128]	valid_0's auc: 0.999893
# [129]	valid_0's auc: 0.999892
# [130]	valid_0's auc: 0.999894
# [131]	valid_0's auc: 0.999895
# [132]	valid_0's auc: 0.999895
# [133]	valid_0's auc: 0.999895
# [134]	valid_0's auc: 0.999895
# [135]	valid_0's auc: 0.999894
# [136]	valid_0's auc: 0.999895
# [137]	valid_0's auc: 0.999896
# [138]	valid_0's auc: 0.999896
# [139]	valid_0's auc: 0.999896
# [140]	valid_0's auc: 0.999895
# [141]	valid_0's auc: 0.999897
# [142]	valid_0's auc: 0.999897
# [143]	valid_0's auc: 0.999897
# [144]	valid_0's auc: 0.999899
# [145]	valid_0's auc: 0.999899
# [146]	valid_0's auc: 0.999899
# [147]	valid_0's auc: 0.999898
# [148]	valid_0's auc: 0.999897
# [149]	valid_0's auc: 0.999897
# [150]	valid_0's auc: 0.999899
# [151]	valid_0's auc: 0.999901
# [152]	valid_0's auc: 0.999902
# [153]	valid_0's auc: 0.999902
# [154]	valid_0's auc: 0.999901
# [155]	valid_0's auc: 0.999901
# [156]	valid_0's auc: 0.9999
# [157]	valid_0's auc: 0.9999
# [158]	valid_0's auc: 0.999899
# [159]	valid_0's auc: 0.999899
# [160]	valid_0's auc: 0.999898
# [161]	valid_0's auc: 0.999898
# [162]	valid_0's auc: 0.999898
# [163]	valid_0's auc: 0.999898
# [164]	valid_0's auc: 0.999897
# [165]	valid_0's auc: 0.999896
# [166]	valid_0's auc: 0.999896
# [167]	valid_0's auc: 0.999895
# [168]	valid_0's auc: 0.999894
# [169]	valid_0's auc: 0.999895
# [170]	valid_0's auc: 0.999894
# [171]	valid_0's auc: 0.999895
# [172]	valid_0's auc: 0.999894
# [173]	valid_0's auc: 0.999894
# [174]	valid_0's auc: 0.999893
# [175]	valid_0's auc: 0.999893
# [176]	valid_0's auc: 0.999895
# [177]	valid_0's auc: 0.999895
# [178]	valid_0's auc: 0.999894
# [179]	valid_0's auc: 0.999894
# [180]	valid_0's auc: 0.999894
# [181]	valid_0's auc: 0.999893
# [182]	valid_0's auc: 0.999893
# [183]	valid_0's auc: 0.999892
# [184]	valid_0's auc: 0.999892
# [185]	valid_0's auc: 0.999892
# [186]	valid_0's auc: 0.999891
# [187]	valid_0's auc: 0.99989
# [188]	valid_0's auc: 0.99989
# [189]	valid_0's auc: 0.999889
# [190]	valid_0's auc: 0.999888
# [191]	valid_0's auc: 0.999888
# [192]	valid_0's auc: 0.999888
# [193]	valid_0's auc: 0.999888
# [194]	valid_0's auc: 0.99989
# [195]	valid_0's auc: 0.999889
# [196]	valid_0's auc: 0.999888
# [197]	valid_0's auc: 0.999888
# [198]	valid_0's auc: 0.999888
# [199]	valid_0's auc: 0.99989
# [200]	valid_0's auc: 0.999889
# [201]	valid_0's auc: 0.99989
# [202]	valid_0's auc: 0.999893
# [203]	valid_0's auc: 0.999893
# [204]	valid_0's auc: 0.999892
# [205]	valid_0's auc: 0.999895
# [206]	valid_0's auc: 0.999895
# [207]	valid_0's auc: 0.999896
# [208]	valid_0's auc: 0.999897
# [209]	valid_0's auc: 0.999897
# [210]	valid_0's auc: 0.999896
# [211]	valid_0's auc: 0.999896
# [212]	valid_0's auc: 0.999895
# [213]	valid_0's auc: 0.999894
# [214]	valid_0's auc: 0.999897
# [215]	valid_0's auc: 0.999896
# [216]	valid_0's auc: 0.999898
# [217]	valid_0's auc: 0.999898
# [218]	valid_0's auc: 0.999899
# [219]	valid_0's auc: 0.999899
# [220]	valid_0's auc: 0.999899
# [221]	valid_0's auc: 0.999899
# [222]	valid_0's auc: 0.999898
# [223]	valid_0's auc: 0.999898
# [224]	valid_0's auc: 0.999897
# [225]	valid_0's auc: 0.999897
# [226]	valid_0's auc: 0.999896
# [227]	valid_0's auc: 0.999895
# [228]	valid_0's auc: 0.999895
# [229]	valid_0's auc: 0.999895
# [230]	valid_0's auc: 0.999898
# [231]	valid_0's auc: 0.999898
# [232]	valid_0's auc: 0.999898
# [233]	valid_0's auc: 0.999897
# [234]	valid_0's auc: 0.999899
# [235]	valid_0's auc: 0.999898
# [236]	valid_0's auc: 0.999898
# [237]	valid_0's auc: 0.9999
# [238]	valid_0's auc: 0.999899
# [239]	valid_0's auc: 0.999898
# [240]	valid_0's auc: 0.999899
# [241]	valid_0's auc: 0.999898
# [242]	valid_0's auc: 0.999898
# [243]	valid_0's auc: 0.999899
# [244]	valid_0's auc: 0.9999
# [245]	valid_0's auc: 0.999899
# [246]	valid_0's auc: 0.999898
# [247]	valid_0's auc: 0.999898
# [248]	valid_0's auc: 0.999897
# [249]	valid_0's auc: 0.999896
# [250]	valid_0's auc: 0.999896
# [251]	valid_0's auc: 0.999897
# [252]	valid_0's auc: 0.999895
# Early stopping, best iteration is:
# [152]	valid_0's auc: 0.999902
# save model: /content/drive/MyDrive/Kaggle/Foursquare/models/train_lgbm_recall_name_iou_0629_001_final_pair/lgb_fold0.pkl
# *** start train cv: 1 ***
# [1]	valid_0's auc: 0.996835
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.997562
# [3]	valid_0's auc: 0.998734
# [4]	valid_0's auc: 0.998735
# [5]	valid_0's auc: 0.998667
# [6]	valid_0's auc: 0.99877
# [7]	valid_0's auc: 0.99893
# [8]	valid_0's auc: 0.998965
# [9]	valid_0's auc: 0.999443
# [10]	valid_0's auc: 0.999454
# [11]	valid_0's auc: 0.99945
# [12]	valid_0's auc: 0.999454
# [13]	valid_0's auc: 0.999468
# [14]	valid_0's auc: 0.999494
# [15]	valid_0's auc: 0.999546
# [16]	valid_0's auc: 0.999326
# [17]	valid_0's auc: 0.999332
# [18]	valid_0's auc: 0.999025
# [19]	valid_0's auc: 0.99904
# [20]	valid_0's auc: 0.999049
# [21]	valid_0's auc: 0.999087
# [22]	valid_0's auc: 0.999106
# [23]	valid_0's auc: 0.999101
# [24]	valid_0's auc: 0.999107
# [25]	valid_0's auc: 0.999106
# [26]	valid_0's auc: 0.999068
# [27]	valid_0's auc: 0.999037
# [28]	valid_0's auc: 0.998985
# [29]	valid_0's auc: 0.998944
# [30]	valid_0's auc: 0.998956
# [31]	valid_0's auc: 0.998947
# [32]	valid_0's auc: 0.998949
# [33]	valid_0's auc: 0.998921
# [34]	valid_0's auc: 0.999229
# [35]	valid_0's auc: 0.99924
# [36]	valid_0's auc: 0.999221
# [37]	valid_0's auc: 0.999223
# [38]	valid_0's auc: 0.999226
# [39]	valid_0's auc: 0.999228
# [40]	valid_0's auc: 0.99923
# [41]	valid_0's auc: 0.999217
# [42]	valid_0's auc: 0.999221
# [43]	valid_0's auc: 0.999231
# [44]	valid_0's auc: 0.999235
# [45]	valid_0's auc: 0.99924
# [46]	valid_0's auc: 0.999243
# [47]	valid_0's auc: 0.999244
# [48]	valid_0's auc: 0.999249
# [49]	valid_0's auc: 0.999257
# [50]	valid_0's auc: 0.999261
# [51]	valid_0's auc: 0.99925
# [52]	valid_0's auc: 0.999256
# [53]	valid_0's auc: 0.999259
# [54]	valid_0's auc: 0.999246
# [55]	valid_0's auc: 0.999215
# [56]	valid_0's auc: 0.999216
# [57]	valid_0's auc: 0.999211
# [58]	valid_0's auc: 0.999209
# [59]	valid_0's auc: 0.999211
# [60]	valid_0's auc: 0.999212
# [61]	valid_0's auc: 0.999211
# [62]	valid_0's auc: 0.99921
# [63]	valid_0's auc: 0.999211
# [64]	valid_0's auc: 0.999203
# [65]	valid_0's auc: 0.999205
# [66]	valid_0's auc: 0.999203
# [67]	valid_0's auc: 0.999203
# [68]	valid_0's auc: 0.999206
# [69]	valid_0's auc: 0.999199
# [70]	valid_0's auc: 0.999198
# [71]	valid_0's auc: 0.999193
# [72]	valid_0's auc: 0.999199
# [73]	valid_0's auc: 0.999194
# [74]	valid_0's auc: 0.999192
# [75]	valid_0's auc: 0.999191
# [76]	valid_0's auc: 0.99919
# [77]	valid_0's auc: 0.99919
# [78]	valid_0's auc: 0.999193
# [79]	valid_0's auc: 0.999194
# [80]	valid_0's auc: 0.999193
# [81]	valid_0's auc: 0.999155
# [82]	valid_0's auc: 0.999154
# [83]	valid_0's auc: 0.999153
# [84]	valid_0's auc: 0.999153
# [85]	valid_0's auc: 0.99915
# [86]	valid_0's auc: 0.999147
# [87]	valid_0's auc: 0.999163
# [88]	valid_0's auc: 0.999165
# [89]	valid_0's auc: 0.999166
# [90]	valid_0's auc: 0.999166
# [91]	valid_0's auc: 0.999166
# [92]	valid_0's auc: 0.999164
# [93]	valid_0's auc: 0.999156
# [94]	valid_0's auc: 0.999156
# [95]	valid_0's auc: 0.999154
# [96]	valid_0's auc: 0.999154
# [97]	valid_0's auc: 0.999153
# [98]	valid_0's auc: 0.999151
# [99]	valid_0's auc: 0.999153
# [100]	valid_0's auc: 0.99915
# [101]	valid_0's auc: 0.999148
# [102]	valid_0's auc: 0.999147
# [103]	valid_0's auc: 0.999145
# [104]	valid_0's auc: 0.999144
# [105]	valid_0's auc: 0.999144
# [106]	valid_0's auc: 0.999143
# [107]	valid_0's auc: 0.999142
# [108]	valid_0's auc: 0.999142
# [109]	valid_0's auc: 0.999142
# [110]	valid_0's auc: 0.999141
# [111]	valid_0's auc: 0.999134
# [112]	valid_0's auc: 0.999133
# [113]	valid_0's auc: 0.999133
# [114]	valid_0's auc: 0.999131
# [115]	valid_0's auc: 0.99913
# Early stopping, best iteration is:
# [15]	valid_0's auc: 0.999546
# save model: /content/drive/MyDrive/Kaggle/Foursquare/models/train_lgbm_recall_name_iou_0629_001_final_pair/lgb_fold1.pkl
# CPU times: user 2min 2s, sys: 858 ms, total: 2min 3s
# Wall time: 16.5 s

# %%
# int_cols = ['s_co_net', 's_adjacency_frequency', 't_adjacency_frequency', 't_co_net']
# float_cols = ['t_clustering_coefficient', 's_clustering_coefficient', 's_betweeness_centrality', 't_betweeness_centrality']
# for col in int_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)
    
# for col in float_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)

# %%
cv = (oof.argmax(axis=-1) == train["label"].astype(int)).mean()
print(f"CV-accuracy: {cv}")
# 0.9726
# Out:
# CV-accuracy: 0.9986239051951626

# %%
importance_df = pd.DataFrame(models[0].feature_importances_, 
                             index=features, 
                             columns=['importance'])\
                    .sort_values("importance", ascending=False)


plt.figure(figsize=(20, 10))
sns.barplot(x="importance", y="index", data=importance_df.head(30).reset_index(drop=False))
plt.show()

# %%
del train_X, train_y, valid_X, valid_y, models

# %% [markdown]
# # Change Submission Format

# %%
tmp = train[['id', 'match_id', 'label']]
tmp[['pred_0', 'pred_1']] = oof

# %%
tmp.to_csv(os.path.join(OUTPUT_PATH, 'oof.csv'), index = False)

# %% [markdown]
# ### memoryリセットかけた

# %%
oof = pd.read_csv(os.path.join(OUTPUT_PATH, 'oof.csv'))
oof.head()
# Out:
#                  id          match_id  label    pred_0    pred_1
# 0  E_000001272c6c5d  E_000001272c6c5d      1  0.000410  0.999590
# 1  E_000007f24ebc95  E_000007f24ebc95      1  0.000399  0.999601
# 2  E_000008a8ba4f48  E_000008a8ba4f48      1  0.000398  0.999602
# 3  E_00002a131a2bf6  E_00002a131a2bf6      1  0.000399  0.999601
# 4  E_00007dcd2bb53f  E_00007dcd2bb53f      1  0.000399  0.999601

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(oof.id.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(oof.iterrows()):
    if row['pred_0'] < row['pred_1']:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
scores = []
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('cv score is', np.array(scores).mean())
# 0.8643
# 0.8655
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# cv score is 0.6484893760755864

# %% [markdown]
# # Add new pair

# %%
train['pred'] = oof['pred_1']

# %%
used_pair = set()
for id, match_id in train[['id', 'match_id']].values:
    used_pair.add((id, match_id))
    used_pair.add((match_id, id))
len(used_pair)
# Out:
# 86548

# %%
id2idx = {x:i for i, x in enumerate(data.index)}
idx2id = {i:x for i, x in enumerate(data.index)}

# %%
class UnionFind():
    def __init__(self, n):
        self.n = n
        self.parents = [-1] * n

    def find(self, x):
        if self.parents[x] < 0:
            return x
        else:
            self.parents[x] = self.find(self.parents[x])
            return self.parents[x]

    def union(self, x, y):
        x = self.find(x)
        y = self.find(y)

        if x == y:
            return

        if self.parents[x] > self.parents[y]:
            x, y = y, x

        self.parents[x] += self.parents[y]
        self.parents[y] = x

    def size(self, x):
        return -self.parents[self.find(x)]

    def same(self, x, y):
        return self.find(x) == self.find(y)

# %%
UFT = UnionFind(len(data))

# %%
for id, match_id in train.loc[train['pred'] > 0.5, ['id', 'match_id']].values:
    UFT.union(id2idx[id], id2idx[match_id])

# %%
group_idxs = defaultdict(list)
for i in range(len(data)):
    group_idxs[UFT.find(i)].append(i)

# %%
for group_idx in group_idxs.values():
    if len(group_idx) <= 2:
        continue
    print(len(group_idx))
# Out:
# 7
# 6
# 7
# 5

# %%
add_ids = []
add_match_ids = []
for group_idx in group_idxs.values():
    if len(group_idx) <= 2:
        continue
    for i in range(len(group_idx) - 1):
        for j in range(i + 1, len(group_idx)):
            if not (idx2id[group_idx[i]], idx2id[group_idx[j]]) in used_pair:
                add_ids.append(idx2id[group_idx[i]])
                add_match_ids.append(idx2id[group_idx[j]])
                used_pair.add((idx2id[group_idx[i]], idx2id[group_idx[j]]))
                used_pair.add((idx2id[group_idx[j]], idx2id[group_idx[i]]))
print(len(add_ids))
# Out:
# 30

# %% [markdown]
# # Check Misclassification

# %%
oof['pred'] = oof['pred_1'].round()
tmp = oof[['id', 'match_id', 'label', 'pred', 'pred_1']]

# %%
t = tmp[tmp['label']!=tmp['pred']]
tt = t[t['pred_1']<0.2]

# %%
len(t)
# Out:
# 351177

# %%
tt
# Out:
#                         id          match_id  label  pred    pred_1
# 1856      E_00dcbf399a3c66  E_1d401732135818      1   0.0  0.011808
# 4461      E_020e76b9a1aadf  E_9fcab1f6916cf5      1   0.0  0.112397
# 9905      E_04852c224633d4  E_1d401732135818      1   0.0  0.000399
# 24529     E_0b0cce8f893902  E_1d401732135818      1   0.0  0.001068
# 56283     E_1949df04eeb0f2  E_1d401732135818      1   0.0  0.005025
# ...                    ...               ...    ...   ...       ...
# 10239215  E_fbc7e55e9f2125  E_0ebf876b47a817      1   0.0  0.104191
# 10239233  E_fc0d4fc04aa6fe  E_f83e473226d964      1   0.0  0.162517
# 10239273  E_fc8eace7feadfc  E_d85e06a47237d2      1   0.0  0.032958
# 10239424  E_fe43e9366d948a  E_c75dfa321e03dc      1   0.0  0.017536
# 10239519  E_ff6ce9b5e1e7ad  E_5de505da9bf8e2      1   0.0  0.093900
#
# [131995 rows x 5 columns]

# %%
id = 'E_0146e712d66bb8'
m_id = 'E_512009c07275bc'
ids = [id, m_id]
data[data.index.isin(ids)]
# data[data.id.isin(ids)]
# Out:
#                                                                name  \
# id
# E_0146e712d66bb8  guccitong ming nan shi yi dai  yi bi yi yuan d...
# E_512009c07275bc  tan suo  kun lun gao fang wan biao  yi bi yi y...
#
#                    latitude  longitude  \
# id
# E_0146e712d66bb8  38.415602 -95.925751
# E_512009c07275bc  38.415602 -95.925751
#
#                                                             address city  \
# id
# E_0146e712d66bb8  oe         1143            a           1143   ...
# E_512009c07275bc  lh             1143 88 8                      ...
#
#                  state  zip country  url phone  ... state_split   cv co_net  \
# id                                              ...
# E_0146e712d66bb8    KS  NaN      US  NaN   NaN  ...        [KS]  0.0   -1.0
# E_512009c07275bc    KS  NaN      US  NaN   NaN  ...        [KS]  0.0   -1.0
#
#                           main_category scale adjacency_frequency  \
# id
# E_0146e712d66bb8  Ethiopian Restaurants     0                 NaN
# E_512009c07275bc  Ethiopian Restaurants     0                 NaN
#
#                   betweeness_centrality  clustering_coefficient  \
# id
# E_0146e712d66bb8                    NaN                     NaN
# E_512009c07275bc                    NaN                     NaN
#
#                  median_distances_median  category_rate
# id
# E_0146e712d66bb8                     0.0        0.00113
# E_512009c07275bc                     0.0        0.00113
#
# [2 rows x 25 columns]

# %%
train[(train['id']==id) & (train['match_id']==m_id)][['kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven']]
# Out:
# Empty DataFrame
# Columns: [kdist, categories_jaro, name_jaro, categories_lcs, name_tfidf_sim, name_leven, name_nleven]
# Index: []

# %%
train.name_lcs.min()
# Out:
# 0

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==0)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                        id          match_id  kdist  categories_jaro  \
# 24923    E_05968db3eae9d8  E_f2631dac113cc9    0.0              1.0
# 79749    E_11d4647dcc2093  E_c55a9728cf1ad4    0.0              1.0
# 272059   E_3d173cf36ea045  E_5fdb53e0f88509    0.0              1.0
# 408955   E_5be60953b0015f  E_0bab9eb45a7363    0.0              1.0
# 425857   E_5faff0ea77b622  E_8ba6cfb8818ac2    0.0              1.0
# ...                   ...               ...    ...              ...
# 708652   E_9f2c4360daa6b0  E_a534324f5cee01    0.0              1.0
# 754621   E_a9836ce1f2fda4  E_a6ac1d78e8ccb8    0.0              1.0
# 837524   E_bc14a8427db6be  E_caf447b497ce4e    0.0              1.0
# 1041319  E_e9f9bbed668045  E_a6ac1d78e8ccb8    0.0              1.0
# 1078567  E_f260f8e20c9a57  E_5b8747d303a1f4    0.0              1.0
#
#          name_jaro  categories_lcs  name_tfidf_sim  name_leven  name_nleven  \
# 24923          1.0            20.0             1.0           0          0.0
# 79749          1.0             4.0             1.0           0          0.0
# 272059         1.0            46.0             1.0           0          0.0
# 408955         1.0            18.0             1.0           0          0.0
# 425857         1.0            12.0             1.0           0          0.0
# ...            ...             ...             ...         ...          ...
# 708652         1.0             5.0             1.0           0          0.0
# 754621         1.0             5.0             1.0           0          0.0
# 837524         1.0             5.0             1.0           0          0.0
# 1041319        1.0             5.0             1.0           0          0.0
# 1078567        1.0             5.0             1.0           0          0.0
#
#          label
# 24923        0
# 79749        0
# 272059       0
# 408955       0
# 425857       0
# ...        ...
# 708652       0
# 754621       0
# 837524       0
# 1041319      0
# 1078567      0
#
# [102 rows x 10 columns]

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==1)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                      id          match_id  kdist  categories_jaro  name_jaro  \
# 1      E_000002eae2a589  E_000002eae2a589    0.0              1.0        1.0
# 2      E_000007f24ebc95  E_000007f24ebc95    0.0              1.0        1.0
# 3      E_000008a8ba4f48  E_000008a8ba4f48    0.0              1.0        1.0
# 4      E_00001d92066153  E_00001d92066153    0.0              1.0        1.0
# 5      E_000023d8f4be44  E_000023d8f4be44    0.0              1.0        1.0
# ...                 ...               ...    ...              ...        ...
# 25384  E_05aff53ddd7f6c  E_05aff53ddd7f6c    0.0              1.0        1.0
# 62226  E_0def1629f08239  E_0def1629f08239    0.0              1.0        1.0
# 68032  E_0f39fad86242ed  E_0f39fad86242ed    0.0              1.0        1.0
# 25919  E_05ce3e833e0f2e  E_05ce3e833e0f2e    0.0              1.0        1.0
# 35691  E_080027ca1a3b0a  E_080027ca1a3b0a    0.0              1.0        1.0
#
#        categories_lcs  name_tfidf_sim  name_leven  name_nleven  label
# 1                21.0             1.0           0          0.0      1
# 2                20.0             1.0           0          0.0      1
# 3                18.0             1.0           0          0.0      1
# 4                19.0             1.0           0          0.0      1
# 5                 4.0             1.0           0          0.0      1
# ...               ...             ...         ...          ...    ...
# 25384            21.0             1.0           0          0.0      1
# 62226            21.0             1.0           0          0.0      1
# 68032            21.0             1.0           0          0.0      1
# 25919            21.0             1.0           0          0.0      1
# 35691            21.0             1.0           0          0.0      1
#
# [1042754 rows x 10 columns]

# %%
train.head(20)[['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                   id          match_id  kdist  categories_jaro  name_jaro  \
# 1   E_000002eae2a589  E_000002eae2a589    0.0              1.0        1.0
# 2   E_000007f24ebc95  E_000007f24ebc95    0.0              1.0        1.0
# 3   E_000008a8ba4f48  E_000008a8ba4f48    0.0              1.0        1.0
# 4   E_00001d92066153  E_00001d92066153    0.0              1.0        1.0
# 5   E_000023d8f4be44  E_000023d8f4be44    0.0              1.0        1.0
# 6   E_00002a131a2bf6  E_00002a131a2bf6    0.0              1.0        1.0
# 7   E_0000764d65557e  E_0000764d65557e    0.0              1.0        1.0
# 8   E_00007dcd2bb53f  E_00007dcd2bb53f    0.0              1.0        1.0
# 9   E_0000890af22ff5  E_0000890af22ff5    0.0              1.0        1.0
# 14  E_0000f17c539685  E_0000f17c539685    0.0              1.0        1.0
# 16  E_00011cca3f0bd6  E_00011cca3f0bd6    0.0              1.0        1.0
# 17  E_00014f107dc217  E_00014f107dc217    0.0              1.0        1.0
# 20  E_000177396ded71  E_000177396ded71    0.0              1.0        1.0
# 21  E_0001827d6b4ee2  E_0001827d6b4ee2    0.0              1.0        1.0
# 22  E_000184ea12d0f0  E_000184ea12d0f0    0.0              1.0        1.0
# 23  E_0001968548bde2  E_0001968548bde2    0.0              NaN        1.0
# 25  E_0001a397f67ad5  E_0001a397f67ad5    0.0              1.0        1.0
# 26  E_0001b37c96a0ff  E_0001b37c96a0ff    0.0              1.0        1.0
# 27  E_0001e184ce8606  E_0001e184ce8606    0.0              1.0        1.0
# 29  E_00021310ea7a71  E_00021310ea7a71    0.0              1.0        1.0
#
#     categories_lcs  name_tfidf_sim  name_leven  name_nleven  label
# 1             21.0             1.0           0          0.0      1
# 2             20.0             1.0           0          0.0      1
# 3             18.0             1.0           0          0.0      1
# 4             19.0             1.0           0          0.0      1
# 5              4.0             1.0           0          0.0      1
# 6             17.0             1.0           0          0.0      1
# 7             21.0             1.0           0          0.0      1
# 8             15.0             1.0           0          0.0      1
# 9             12.0             1.0           0          0.0      1
# 14            10.0             1.0           0          0.0      1
# 16            15.0             1.0           0          0.0      1
# 17            18.0             1.0           0          0.0      1
# 20             7.0             1.0           0          0.0      1
# 21            15.0             1.0           0          0.0      1
# 22            17.0             1.0           0          0.0      1
# 23             NaN             1.0           0          0.0      1
# 25            10.0             1.0           0          0.0      1
# 26            28.0             1.0           0          0.0      1
# 27            17.0             1.0           0          0.0      1
# 29             9.0             1.0           0          0.0      1

# %%
# cols = ['kdist_country', 'kdist', 'categories_jaro', 'name_jaro']
# train[(train['id']==id) & (train['match_id']==m_id)][cols]

# %%
# train[train['kdist_country']== train['kdist']]

# %%
# data[data.index.isin(ids)].loc['E_34199c1154c0d9']['name'].split()

# %%
# data[data.index.isin(ids)].loc['E_0258802b17b98e']['name'].split()
