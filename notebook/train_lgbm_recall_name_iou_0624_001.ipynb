# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
if "google.colab" in sys.modules:
    # !pip install Levenshtein
    # !pip install unidecode
    # !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 28.7 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 63.4 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.3
#   Downloading jarowinkler-1.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.1 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.4 rapidfuzz-2.0.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 23.4 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 27.7 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=712f252c76e116fe59f8378d3eb6446c0d8dbc9562e6a2759699703278e41f67
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import gc
import random
from glob import glob
from sklearn.model_selection import GroupKFold, KFold, StratifiedKFold
import warnings
import seaborn as sns
import re
from requests import get
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from difflib import SequenceMatcher
import lightgbm as lgb
import pickle
import Levenshtein
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from unidecode import unidecode
import emoji
import re

random.seed(42)
np.random.seed(42)
warnings.filterwarnings('ignore')

# %%
if "google.colab" in sys.modules:
    expID = get("http://172.28.0.2:9000/api/sessions").json()[0]["name"].split(".")[0]
ROOT_PATH = '/content/drive/MyDrive/Kaggle/Foursquare'
INPUT_PATH = os.path.join(ROOT_PATH, 'input')
OUTPUT_PATH = os.path.join(os.path.join(ROOT_PATH, 'output'), expID)
MODEL_PATH = os.path.join(os.path.join(ROOT_PATH, 'models'), expID)
TARGET = 'point_of_interest'

# %%
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)

# %%
N_NEIGHBORS = 90
NAME_RANK=5
ADDRESS_RANK = 3
CAT_RANK = 5
K_NEIGHBORS = 3
FILTER = 0.0
N_FOLD = 2
DISTANCE = 10000
CATEGORY_COUNT = 100
NAME_THRESHOLD = 0.4
CAT_THRESHOLD = 0.2

DEBUG = False
TFIDF = True
KDIST = True
NET = False # post processでは当たり前にやってた。# predの閾値は利用していなかったので、改良の余地あり。
MOJIBAKE = False
SAMPLING = False

def remove_emoji(src_str):
    return ''.join(c for c in src_str if c not in emoji.UNICODE_EMOJI)

# %%
# with open(os.path.join(OUTPUT_PATH, 'name_variants.pkl'), mode='rb') as f:
#     name_dict = pickle.load(f)

# %%
data = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
if DEBUG:
    data = data.iloc[:10000]
print(data.shape)

# cols = ['name', 'address', 'city', 'state']
cols = ['name']
# cols = ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone'] # categoriesは大文字が小文字になると困る。
for col in cols:
#     if col=='name':
#         data[col].update(data[col].map(name_dict))
    data[col] = data[col].fillna('').apply(unidecode)
    data[col] = data[col].str.lower()
    data[col] = data[col].apply(remove_emoji)

data.head()
# Out:
# (1138812, 13)
#                  id                     name   latitude   longitude  \
# 0  E_000001272c6c5d     cafe stad oudenaarde  50.859975    3.634196
# 1  E_000002eae2a589           carioca manero -22.907225  -43.178244
# 2  E_000007f24ebc95      raantadphmkaaraaekd  13.780813  100.484900
# 3  E_000008a8ba4f48                 turkcell  37.844510   27.844202
# 4  E_00001d92066153  restaurante casa cofino  43.338196   -4.326821
#
#                   address        city            state   zip country  url  \
# 0             Abdijstraat  Nederename  Oost-Vlaanderen  9700      BE  NaN
# 1                     NaN         NaN              NaN   NaN      BR  NaN
# 2                     NaN         NaN              NaN   NaN      TH  NaN
# 3  Adnan Menderes Bulvarı         NaN              NaN   NaN      TR  NaN
# 4                     NaN    Caviedes        Cantabria   NaN      ES  NaN
#
#   phone             categories point_of_interest
# 0   NaN                   Bars  P_677e840bb6fc7e
# 1   NaN  Brazilian Restaurants  P_d82910d8382a83
# 2   NaN   Salons / Barbershops  P_b1066599e78477
# 3   NaN     Mobile Phone Shops  P_b2ed86905a4cd3
# 4   NaN    Spanish Restaurants  P_809a884d4407fb

# %%
def sub(x):
    return re.sub(r'[^a-zA-Z0-9 ]', ' ', x)
cols = ['name', 'address', 'city', 'state']
# cols = ['name']
for col in cols:
    data[col] = data[col].fillna('').apply(sub)
    data[f'{col}_split'] = data[col].str.split()

# %%
if MOJIBAKE:
    data.loc[data['name'].str.contains('[买哪侈为裤溦发围货浓调时吧间价爱处灵节怎么办]', na=False), ['name', 'address', 'city']] = '<MOJIBAKE>'

# %%
kf = GroupKFold(n_splits=N_FOLD)
for i, (_, val_idx) in enumerate(kf.split(data, data[TARGET], data[TARGET])):
    data.loc[val_idx, "cv"] = i
print(data["cv"].value_counts())
# Out:
# 1.0    569406
# 0.0    569406
# Name: cv, dtype: int64

# %% [markdown]
# # add Data

# %%
with open(os.path.join(OUTPUT_PATH, 'id2com_30.pkl'), mode='rb') as f:
    id2com = pickle.load(f)
node_df = pd.read_csv(os.path.join(OUTPUT_PATH, 'node_df.csv'))
node_df.columns = ['main_category', 'id_code', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']
node_df = node_df[['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']]

def add_co_net(x):
    if x is np.nan:
        return np.nan
    out = -1
    for cat in x.split(', '):
        if cat in id2com.keys():
            out = id2com[cat]
            break

    return out

data['co_net'] = data['categories'].apply(add_co_net)

# %%
def add_main_category(x):
    if x is np.nan:
        return np.nan

    return x.split(', ')[0]

data['main_category'] = data['categories'].apply(add_main_category)

# %%
aggregated_df = pd.read_csv(os.path.join(INPUT_PATH, 'aggregated_df.csv'))
aggregated_df = aggregated_df.iloc[2:]
aggregated_df.columns = ['main_category', 'median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min', 'count']

float_cols = ['median_distances_max', 'median_distances_75', 'median_distances_median', 'median_distances_25', 'median_distances_min']
aggregated_df[float_cols] = aggregated_df[float_cols].astype(float)
aggregated_df['count'] = aggregated_df['count'].astype(int)
aggregated_df['category_rate'] = aggregated_df['count'] / aggregated_df['count'].sum() # leakではない？

aggregated_df.head()
# Out:
#           main_category  median_distances_max  median_distances_75  \
# 2                  ATMs          1.446457e+07         27032.192275
# 3           Acai Houses          1.350800e+05         17781.269899
# 4    Accessories Stores          1.317399e+07         17636.724841
# 5  Acehnese Restaurants          1.394807e+05         28385.619678
# 6        Acupuncturists          1.099943e+06         30876.313672
#
#    median_distances_median  median_distances_25  median_distances_min  count  \
# 2              4490.248044          1012.594350              0.000000   1366
# 3              6117.784384          1359.040401             19.017952     25
# 4              4397.253023          1609.960599              0.000000    890
# 5             11585.417039          6524.589277            308.232222     22
# 6              5262.894842          1160.926141              0.000000     67
#
#    category_rate
# 2       0.002505
# 3       0.000046
# 4       0.001632
# 5       0.000040
# 6       0.000123

# %%
large_scales = list(aggregated_df[(aggregated_df['median_distances_median']>=DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)
small_scales = list(aggregated_df[(aggregated_df['median_distances_median']<DISTANCE) & (aggregated_df['count']>=CATEGORY_COUNT)].main_category)

def add_scale(x):
    categories = x.split(", ")
    out = -1
    for cat in categories:
        if cat in large_scales:
            out = 1
            break
        if cat in small_scales:
            out = 0
            break
    return out

data['scale'] = data['categories'].fillna('').apply(add_scale)
data.scale.value_counts()
# Out:
#  0    897808
#  1    127772
# -1    113232
# Name: scale, dtype: int64

# %%
cols = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient']
data= data.merge(node_df[cols], on='main_category', how='left')

cols = ['main_category', 'median_distances_median', 'category_rate'] # maxとかはリークな気がする。
data= data.merge(aggregated_df[cols], on='main_category', how='left')

# %%
# category similarity
cats = data.categories.fillna('')

cat_stats = {}

for c in cats:
    csplit = c.split(", ")
    for c_ in csplit:
        if c_ not in cat_stats:
            cat_stats[c_] = [1, {ca: 1 for ca in csplit}]
        else:
            prev_cat_stats = cat_stats[c_]
            prev_cat_stats[0] += 1
            prev_sims = prev_cat_stats[1]
            
            for ca in csplit:
                prev_sims[ca] = prev_sims.get(ca, 0) + 1
        
for c, val in cat_stats.items():
    
    overall_count = sum(v for ca, v in val[1].items() if ca != c and v > 1)
    
    new_probs = {c: 1.0}
    if overall_count != 0:
        new_probs.update({ca: round(v / overall_count, 3) for ca, v in val[1].items() if v / overall_count > 0.01 and ca != c and v > 1})
        cat_stats[c] = [1.0, new_probs]
        
def get_cat_similarity(cat1, cat2):
    
    if cat1 == '' or cat2 == '':
        return 0.000000001
    
    if cat1 in cat2 or cat2 in cat1:
        return 1.0
    
    best = 0
    
    for c1 in cat1.split(", "):
        for c2 in cat2.split(", "):
            if c1 in cat_stats:
                best = max(best, cat_stats[c1][1].get(c2, 0))
            if c2 in cat_stats:
                best = max(best, cat_stats[c2][1].get(c1, 0))
    
    return best
get_cat_similarity('Bars', 'Cafes, Restaurants')
# Out:
# 0.065

# %% [markdown]
# # Generate Train Data

# %%
# def get_name_contain(name, match_name):
#     if name=='' or match_name=='':
#         return False
#     elif name in match_name or match_name in name:
#         return True
#     else:
#         return False

# def recall_knn_name(df, Neighbors = 10):
#     train = pd.DataFrame()
#     dfs = []
#     Neighbors = min(Neighbors, len(df))
#     knn = NearestNeighbors(n_neighbors = Neighbors)
#     knn.fit(df[['latitude','longitude']], df.index)
    
#     num_splits = len(df) // NUM_SPLIT_DATA
#     start_row = 0
#     for i in tqdm(range(1, NUM_SPLIT_DATA + 1)):
#         end_row = start_row + num_splits
#         if i < NUM_SPLIT_DATA:
#             tmp = df.iloc[start_row : end_row]
#         else:
#             tmp = df.iloc[start_row: ]
#         dists, nears = knn.kneighbors(tmp[['latitude','longitude']])
    
#         for k in tqdm(range(Neighbors)):            
#             cur_df = tmp[['id']]
#             cur_df['match_id'] = df['id'].values[nears[:, k]]
#             cur_df['kdist_name'] = dists[:, k]
#             cur_df['kneighbors_name'] = k
        
#             cols = ['name']
#     #         cols = ['name', 'categories', 'address']
#             for col in cols:
#                 cur_df[col] = tmp[col]
#                 cur_df[f'match_{col}'] = df[col].values[nears[:, k]]
#                 cur_df[f'{col}_contain'] = np.vectorize(get_name_contain)(cur_df[col], cur_df[f'match_{col}'])
#             cur_df = cur_df[(cur_df['name']==cur_df['match_name']) | (cur_df['name_contain'])]
        
#             dfs.append(cur_df)
#         start_row = end_row
#         print('end_row', end_row)

#     return pd.concat(dfs)

# cvs = []
# for i in range(N_FOLD):
#     tmp = recall_knn_name(data[data['cv']==i], 1000)
# #     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
# #               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
#     tmp['cv_name'] = i
#     print(tmp.shape)
#     cvs.append(tmp)
# train_name = pd.concat(cvs)
# print(train_name.shape)
# # train_name.drop(['name', 'match_name', 'name_contain', 'kneighbors_name'], axis=1, inplace=True)
# # train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
# # train.drop(['address', 'match_address', 'address_split', 'match_address_split'], axis=1, inplace=True)
# train_name.drop(['name', 'match_name', 'name_contain'], axis=1, inplace=True)
# train_name.head()
# # 8679523

# %%
def sm_ratio_name(x):
    return SequenceMatcher(None, x['name'], x['match_name']).ratio()

def sm_ratio_name(name, match_name):
    return SequenceMatcher(None, name, match_name).ratio()

def get_name_iou(name_split, match_name_split):
    if len(set(name_split) | set(match_name_split))==0:
        return 0
    else:
        return len(set(name_split) & set(match_name_split)) / len(set(name_split) | set(match_name_split))

def apply_get_cat_similarity(categories, match_categories):
    return get_cat_similarity(categories, match_categories)

def recall_knn_name(df, Neighbors = 10):
    train = pd.DataFrame()
    dfs = []
    Neighbors = min(Neighbors, len(df))
    # print(f'{Neighbors=}')
    knn = NearestNeighbors(n_neighbors = Neighbors)
    knn.fit(df[['latitude','longitude']], df.index)
    dists, nears = knn.kneighbors(df[['latitude','longitude']])
    
    for k in tqdm(range(Neighbors)):            
        cur_df = df[['id']]
        cur_df['match_id'] = df['id'].values[nears[:, k]]
        cur_df['kdist'] = dists[:, k]
        cur_df['kneighbors'] = k
        
        cols = ['name', 'categories']
        for col in cols:
            cur_df[col] = df[col]
            cur_df[f'match_{col}'] = df[col].values[nears[:, k]]

        cols = ['name']
        for col in cols:
            cur_df[f'{col}_split'] = df[f'{col}_split']
            cur_df[f'match_{col}_split'] = df[f'{col}_split'].values[nears[:, k]]
            cur_df[f'{col}_iou'] = np.vectorize(get_name_iou)(cur_df[f'{col}_split'], cur_df[f'match_{col}_split'])
        
        cur_df['cat_similarity'] = np.vectorize(apply_get_cat_similarity)(cur_df['categories'].fillna(''), cur_df['match_categories'].fillna(''))
        cur_df = cur_df[(cur_df['cat_similarity']>0.0) | (cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
#                        | (cur_df['address_iou']>0.0)| (cur_df['city_iou']>0.0)| (cur_df['state_iou']>0.0)]
#         cur_df = cur_df[(cur_df['kneighbors']<K_NEIGHBORS) | (cur_df['name_iou']>0.0)]
        dfs.append(cur_df)
        
        if k!=0 and (k % 50 == 0 or k==Neighbors-1):
            print(f'calc rank: {k}')
            tmp = pd.concat(dfs)
            tmp['sm_ratio_name'] = np.vectorize(sm_ratio_name)(tmp['name'], tmp['match_name'])
            tmp['name_rank'] = 99 # 念の為、入れておく
#             tmp['cat_rank'] = 99 # 念の為、入れておく
            train = pd.concat([train, tmp])
            train['name_rank'] = train.groupby('id')['sm_ratio_name'].rank(ascending=False, method='dense')
#             train['cat_rank'] = train.groupby('id')['cat_similarity'].rank(ascending=False, method='dense')
            train = train[((train['name_rank']<=NAME_RANK) & train['sm_ratio_name']>0.0) | 
                                  (train['categories']==train['match_categories']) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   (train['cat_similarity']==1.0) | (train['sm_ratio_name']>=NAME_THRESHOLD) | 
#                                   ((train['cat_rank']<=CAT_RANK) & (train['cat_similarity']>0.0) & (train['sm_ratio_name']>0.0)) | 
                                  (train['kneighbors']<K_NEIGHBORS)]
            del tmp, dfs
            dfs = []

    return train

cvs = []
for i in range(N_FOLD):
    tmp = recall_knn_name(data[data['cv']==i], N_NEIGHBORS)
#     tmp = tmp[ ((tmp['sm_ratio_name']>FILTER) & (tmp['name_rank']<=NAME_RANK)) |
#               (tmp['kneighbors']<K_NEIGHBORS) | (tmp['sm_ratio_name']>NAME_THRESHOLD)] # 念の為
    tmp['cv'] = i
    cvs.append(tmp)
train = pd.concat(cvs)
print(train.shape)
train.drop(['name', 'match_name', 'sm_ratio_name', 'name_split', 'match_name_split', 'categories', 'match_categories', 'sm_ratio_name'], axis=1, inplace=True)
train.head()
# 8679523
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 89
#   0%|          | 0/90 [00:00<?, ?it/s]
# calc rank: 50
# calc rank: 89
# (10239579, 15)
#                  id          match_id  kdist  kneighbors  name_iou  \
# 1  E_000002eae2a589  E_000002eae2a589    0.0           0       1.0
# 2  E_000007f24ebc95  E_000007f24ebc95    0.0           0       1.0
# 3  E_000008a8ba4f48  E_000008a8ba4f48    0.0           0       1.0
# 4  E_00001d92066153  E_00001d92066153    0.0           0       1.0
# 5  E_000023d8f4be44  E_000023d8f4be44    0.0           0       1.0
#
#    cat_similarity  name_rank  cv
# 1             1.0        1.0   0
# 2             1.0        1.0   0
# 3             1.0        1.0   0
# 4             1.0        1.0   0
# 5             1.0        1.0   0

# %%
# train.to_csv(os.path.join(OUTPUT_PATH, 'train_pred_100.csv'), index = False)

# %%
# train = train.merge(train_name, on = ['id', 'match_id'], how = 'outer')
# train.head()

# %%
# train.loc[train['cv'].isnull(), 'cv'] = train.loc[train['cv'].isnull(), 'cv_name']
# train.loc[train['kdist'].isnull(), 'kdist'] = train.loc[train['kdist'].isnull(), 'kdist_name']
# train.drop(['cv_name', 'kdist_name'], axis=1, inplace=True)

# %%
if TFIDF:
    id2index_d = dict(zip(data['id'].values, data.index)) # tf-idfで使う
data = data.set_index('id')

# %%
for col in ['co_net', 'scale']:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'is_match_{col}'] = train[col]==train[f'match_{col}']
# train.drop(['co_net', 'match_co_net', 'scale', 'match_scale'], axis=1, inplace=True)

# %%
num_cols = ['adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'median_distances_median', 'category_rate']
for col in num_cols:
    col_values = data.loc[train['id']][col].values
    matcol_values = data.loc[train['match_id']][col].values
    train[col] = col_values
    train[f'match_{col}'] = matcol_values
    train[f'mean_{col}'] = (train[col] + train[f'match_{col}']) / 2
#     train.drop([col, f'match_{col}'], axis=1, inplace=True)

# %%
# label作り

ids = train['id'].tolist()
match_ids = train['match_id'].tolist()

poi = data.loc[ids]['point_of_interest'].values
match_poi = data.loc[match_ids]['point_of_interest'].values

train['label'] = np.array(poi == match_poi, dtype = np.int8)

# %% [markdown]
# # Check Maximum Score

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(data.index.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(train.iterrows()):
    if row['label']==1:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
# for base, match in oof_pred.items():
#     if len(match) == 1:        
#         continue

#     for m in match:
#         if base not in oof_pred[m]:
#             oof_pred[m].append(base)

# %%
ids = list(data.index.unique())
scores = []

for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('max score is ', np.array(scores).mean())
# 0.913(30, co_net)
# 50: 0.928(5), 0.930(10)
# 100: 0.930, 0.938
# 200: 0.934
# 300: 0.938

# scale(10000)
# 50: 0.928
# 300: 0.941

# 0.926
# 0.918
# 0.933
# 0.940
# 0.941
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# max score is  0.9408453411859072

# %%
train['label'].value_counts()
# 0    5067914
# 1    1980366

# 0    3326444
# 1    1952844
# Out:
# 0    8122886
# 1    2116693
# Name: label, dtype: int64

# %%
train.label.mean()
# 0.232
# 0.223
# Out:
# 0.20671679958717054

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp2.csv'))

# %%
data.to_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = pd.read_csv(os.path.join(OUTPUT_PATH, 'data_tmp.csv'))
# data = data.set_index('id')

# data2 = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))
# id2index_d = dict(zip(data2['id'].values, data2.index))
# del data2

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            print(col)
            pass
#             df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ## Candidate Miss Sampling

# %%
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    if preds != targets:
        print(f'preds: {preds}')
        print(f'targets: {targets}')
        print(f'{TARGET}: {id2poi[id_x]}')
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# targets: {'E_fcb6db35029ea4', 'E_2bef6f72a4141e', 'E_0218a1607e5d48'}
# point_of_interest: P_a2138f4d817ae2
# preds: {'E_fcb704bf710f8f'}
# targets: {'E_b46d1c51a19acf', 'E_fcb704bf710f8f'}
# point_of_interest: P_d0f1401003e10d
# preds: {'E_fcb73fe910343f', 'E_020b8907509ae4', 'E_f57af69bd48021'}
# targets: {'E_020b8907509ae4', 'E_1c892d973bfb52', 'E_fcb73fe910343f', 'E_f57af69bd48021'}
# point_of_interest: P_64c57d92ba208d
# preds: {'E_fcb7409928d86d', 'E_cd100cade604b7'}
# targets: {'E_fcb7409928d86d', 'E_cd100cade604b7', 'E_fcd476fe24ecf2'}
# point_of_interest: P_f68379dd165e46
# preds: {'E_fcb76eb8aa30df'}
# targets: {'E_2f7795ddc02605', 'E_0fc67c8de4c0d5', 'E_72d3d7527ba6f9', 'E_8a3e1eff85f29a', 'E_fcb76eb8aa30df', 'E_3f622d18341b33'}
# point_of_interest: P_03aa0dba833844
# preds: {'E_fcb7718d3b9438'}
# targets: {'E_6c2638a614099b', 'E_ab67e8017bee9a', 'E_fcb7718d3b9438'}
# point_of_interest: P_4661690302dbad
# preds: {'E_fcb793675aca04'}
# targets: {'E_4288d926d9669d', 'E_fcb793675aca04'}
# point_of_interest: P_d8769b6d57dc71
# preds: {'E_fcb7be205daee7'}
# targets: {'E_fcb7be205daee7', 'E_a2f7e6829bcef7'}
# point_of_interest: P_d4eac379fbde98
# preds: {'E_fcb89ef5a29b6d', 'E_cc3f41ad8f77d2', 'E_432d6cb8bb806a', 'E_debad846997826', 'E_a16a3ede97304d', 'E_86b7249230586d', 'E_68b327ca7a0c69'}
# targets: {'E_fcb89ef5a29b6d', 'E_6ebe26783f3a50', 'E_cc3f41ad8f77d2', 'E_33569cb1137078', 'E_526d7af3cd6049', 'E_432d6cb8bb806a', 'E_debad846997826', 'E_a16a3ede97304d', 'E_86b7249230586d', 'E_68b327ca7a0c69'}
# point_of_interest: P_f8c089d876baa5
# preds: {'E_fcb9a78a11e2c8', 'E_a58ad793d5e70a', 'E_8769263816176a'}
# targets: {'E_cce2593f6a1957', 'E_ad0f599d94ded7', 'E_8769263816176a', 'E_a58ad793d5e70a', 'E_fcb9a78a11e2c8'}
# point_of_interest: P_0acf132ba27d29
# preds: {'E_fcb9c99ffee521'}
# targets: {'E_5a458fc99ce953', 'E_fcb9c99ffee521'}
# point_of_interest: P_37be18bc3da2ce
# preds: {'E_fcb9d09b0f0613'}
# targets: {'E_fcb9d09b0f0613', 'E_ee6f7b5ee7c636'}
# point_of_interest: P_ed66a6dfcd5e8d
# preds: {'E_fcbabed956a422'}
# targets: {'E_63f40f38eb1216', 'E_fcbabed956a422'}
# point_of_interest: P_0094deac35f322
# preds: {'E_4d2a9770b02bd4', 'E_b9ecd7e76cd600', 'E_fcbba85c221d0d', 'E_56b2e70fb8f97e', 'E_1afdb43b3645a0', 'E_235fc8fbf6607e', 'E_b9b0f3c854c13f', 'E_7cf12f5789adba'}
# targets: {'E_4d2a9770b02bd4', 'E_3af999748520cd', 'E_a1fc7b34e0310f', 'E_b9ecd7e76cd600', 'E_fcbba85c221d0d', 'E_56b2e70fb8f97e', 'E_eb0f33ac34a475', 'E_1afdb43b3645a0', 'E_235fc8fbf6607e', 'E_b9b0f3c854c13f', 'E_7cf12f5789adba'}
# point_of_interest: P_d2659dcd04024a
# preds: {'E_881eda05ebfd2e', 'E_fcbcdd3c680acd'}
# targets: {'E_881eda05ebfd2e', 'E_40b8950dee8b10', 'E_fcbcdd3c680acd'}
# point_of_interest: P_dfd6d254fa60de
# preds: {'E_fcbd4471531364'}
# targets: {'E_fcbd4471531364', 'E_3a0f3c604e782f'}
# point_of_interest: P_4eae9b5b20fc0e
# preds: {'E_fcbdc1cd6715ef'}
# targets: {'E_fcbdc1cd6715ef', 'E_eb579f0cbd6d8d'}
# point_of_interest: P_c919c0fbe3d671
# preds: {'E_fcbef0a89dde46'}
# targets: {'E_fcbef0a89dde46', 'E_a760fc4029dfe0'}
# point_of_interest: P_02c623418be86c
# preds: {'E_fcbef0df405a9f'}
# targets: {'E_fcbef0df405a9f', 'E_03a9abd9a9cec4'}
# point_of_interest: P_32cde2556bc63e
# preds: {'E_fcbf1bab2caad7'}
# targets: {'E_8e12d835812316', 'E_fcbf1bab2caad7', 'E_73838a8f322bfb', 'E_fd2e41c01a2901', 'E_361b0fc38f14d9', 'E_5f5bce03a85808', 'E_b5d7366d35c972', 'E_df03ca04c049c3', 'E_7094e818a93260', 'E_ba29f084ca1e9c', 'E_c04ca727bc208d', 'E_b9a628a6bdf8f5', 'E_027fe050b5109e', 'E_8b48199ef0ac39', 'E_9185862e287713', 'E_e7be44c7983113'}
# point_of_interest: P_0576b1b5ba3344
# preds: {'E_fcbf30df2aff45', 'E_fb9a489eba6273'}
# targets: {'E_e33a32a191fd19', 'E_fcbf30df2aff45', 'E_fb9a489eba6273'}
# point_of_interest: P_749691e6b481eb
# preds: {'E_fcbf52f6a7a8aa'}
# targets: {'E_180eb716065a01', 'E_fcbf52f6a7a8aa', 'E_2ee4e150f54593'}
# point_of_interest: P_acf82c3c2c18c3
# preds: {'E_fcbf79385e1e13'}
# targets: {'E_fcbf79385e1e13', 'E_6271265ff0e358'}
# point_of_interest: P_da8ac7485a72d6
# preds: {'E_a4b2e72e587fbd', 'E_fcc0b2a00d3cfb'}
# targets: {'E_6cd11c3aec9006', 'E_c0105fb0264793', 'E_fcc0b2a00d3cfb', 'E_a4b2e72e587fbd', 'E_e5bd3fd232a545'}
# point_of_interest: P_ac6d90d52ba180
# preds: {'E_fea3de492d0380', 'E_fcc137376788c8', 'E_3be6815893fec0', 'E_f93c735f31b65d'}
# targets: {'E_3be6815893fec0', 'E_fcc137376788c8', 'E_f93c735f31b65d', 'E_380b52452fa335', 'E_fea3de492d0380', 'E_e1f1d8c9174ba9'}
# point_of_interest: P_4a03e6c93ece04
# preds: {'E_fcc1e9307b454d'}
# targets: {'E_89bbbfae28929e', 'E_fcc1e9307b454d', 'E_ee82a80f8d3a1f'}
# point_of_interest: P_d161c37272a4fb
# preds: {'E_fcc212e68c1c47'}
# targets: {'E_fcc212e68c1c47', 'E_8643a041af53b3'}
# point_of_interest: P_815e4349ed7792
# preds: {'E_3789c5f5e0ff2a', 'E_fcc227b357b2dd'}
# targets: {'E_c26c5c1b2e63e4', 'E_3789c5f5e0ff2a', 'E_fcc227b357b2dd'}
# point_of_interest: P_c7fca79a82781b
# preds: {'E_fcc2aaec59c14e', 'E_b745059e3eb6fd'}
# targets: {'E_fcc2aaec59c14e', 'E_b745059e3eb6fd', 'E_b3463bc4873308'}
# point_of_interest: P_82bd57b61546fe
# preds: {'E_8472dfb67233e4', 'E_a94fb9ea797ea3', 'E_b5bf5eb591caa0', 'E_fcc2eac4b82377', 'E_f35098e9f993c5', 'E_dab35142dd7b26'}
# targets: {'E_57b6972a889579', 'E_a94fb9ea797ea3', 'E_8472dfb67233e4', 'E_b5bf5eb591caa0', 'E_fcc2eac4b82377', 'E_2455abb0a10a6d', 'E_3efe71ec6a4e56', 'E_f35098e9f993c5', 'E_dab35142dd7b26'}
# point_of_interest: P_7b387a197309ee
# preds: {'E_fcc2f880a4d559'}
# targets: {'E_327d4d1aa4481e', 'E_739db07b6fb795', 'E_91a02fb091cdc0', 'E_c5973d5033a570', 'E_d2db3739ae8bc8', 'E_271389fc260a72', 'E_1fda1cb4ca4937', 'E_9a10749070296f', 'E_d50b4c66fe5cbe', 'E_ffaf3f2b2d4120', 'E_2d6aaa862fb793', 'E_595b406f1067f8', 'E_f74a2bdd0dedd1', 'E_7fffc710716e8f', 'E_fcc2f880a4d559', 'E_e6bf736f461a7c'}
# point_of_interest: P_73d37d2fb608b6
# preds: {'E_fcc33cfc64325a'}
# targets: {'E_5847de96301325', 'E_82ad7a55bdf778', 'E_fcc33cfc64325a', 'E_f75d9b2d2ed105', 'E_9e2d99055ddf66', 'E_78b1d7ca7b07ae', 'E_cfa59165c93b55', 'E_9f683c1bbe19f7', 'E_da09eb8397440e', 'E_ea1bcc2c1669d9', 'E_5bda37ce0bc8da', 'E_43b16a5cd79901', 'E_fc42617acfb9a3', 'E_bf7ad8cf2c1002', 'E_a1a9a77aeca146'}
# point_of_interest: P_ad464e8f73902d
# preds: {'E_fcc3625045d09f'}
# targets: {'E_0fe063a786d190', 'E_fcc3625045d09f'}
# point_of_interest: P_2921de75753291
# preds: {'E_fcc36f4e76002c', 'E_022114a1b125ee', 'E_3f40fb0d3f1fe1', 'E_de238176428bcf', 'E_a5afa3b326856e', 'E_fd2d7aef646dab', 'E_f8860230bcaeb0'}
# targets: {'E_8d183284964f18', 'E_fd380b5290b7f1', 'E_48a07f393144d1', 'E_94ed67dfe5be4d', 'E_fcc36f4e76002c', 'E_bedac21ce3d81d', 'E_dd2998cd36ef79', 'E_8dc52185bae88e', 'E_d446059ff6314f', 'E_c3c8afcbdbb34a', 'E_680374bcc5098f', 'E_eeff04e3538873', 'E_77a92452d4d300', 'E_34d5fa41de1cde', 'E_499345178dd348', 'E_c1854b2d19162b', 'E_de238176428bcf', 'E_3d0488633f44d9', 'E_aae91cd51a9374', 'E_b56fbe71add344', 'E_815036f722b938', 'E_fd2d7aef646dab', 'E_dafab37f824dd1', 'E_663e1499964372', 'E_377f236c1685ee', 'E_022114a1b125ee', 'E_e0eedfc308d424', 'E_3f40fb0d3f1fe1', 'E_a5afa3b326856e', 'E_c181f9c53a3bf1', 'E_16c461ca8ff46a', 'E_f8860230bcaeb0', 'E_77a1f984d6515b', 'E_8b78ee40bdecc7', 'E_9cda0644f1ddf8', 'E_cd7df02054c0e8', 'E_11c59edf6d2611', 'E_d763731184955c', 'E_2a39ce6222e051', 'E_4b2804e886d179', 'E_71f0a216f60624', 'E_2fb4e90f9252c4', 'E_7469548ab287cc', 'E_9225eaffb93e73', 'E_240a701f7890c1', 'E_e55babcef6d525', 'E_c9de3c6007288e'}
# point_of_interest: P_6e7dd319013fa4
# preds: {'E_fcc46721be5161', 'E_249554ecef6eb4'}
# targets: {'E_fcc46721be5161', 'E_249554ecef6eb4', 'E_14605a7c8faaef'}
# point_of_interest: P_b31854c4033207
# preds: {'E_fcc4d554045271'}
# targets: {'E_fcc4d554045271', 'E_91d7f58ee0399b'}
# point_of_interest: P_b6c5e0b91144bc
# preds: {'E_42f5ef4c59e1d6', 'E_bce4ddaa66b9f6', 'E_1e84a9df1254df', 'E_082655de807e7d', 'E_fcc4f5167d6098', 'E_105d819b4443ee'}
# targets: {'E_2d7a442020225f', 'E_42f5ef4c59e1d6', 'E_a73a1a2d6d0d07', 'E_bce4ddaa66b9f6', 'E_1e84a9df1254df', 'E_956b5efb06443d', 'E_082655de807e7d', 'E_fcc4f5167d6098', 'E_105d819b4443ee'}
# point_of_interest: P_9e157b47411f2e
# preds: {'E_fcc597646318c1'}
# targets: {'E_fcc597646318c1', 'E_c575751057013e'}
# point_of_interest: P_0b240b9c0f1df4
# preds: {'E_fcc5f318ce33d8'}
# targets: {'E_fcc5f318ce33d8', 'E_08b85e1d34cc6b'}
# point_of_interest: P_f2d7449f90cf2b
# preds: {'E_fcc698a057695a'}
# targets: {'E_fcc698a057695a', 'E_656634a2d9e571'}
# point_of_interest: P_532b4a2e6e7a81
# preds: {'E_fcc6bee50609ec', 'E_abf2d5b16c3104', 'E_1f61a814629e55', 'E_a3df3be8acd2bb', 'E_2779328db31b5c'}
# targets: {'E_a586eadf0080ec', 'E_43c820a076edd3', 'E_059bba5e9d705c', 'E_90b8d5d3d1670b', 'E_3f938a510d9436', 'E_87dd644eb4de3c', 'E_6277ca968ccaf9', 'E_fc08204edf6e14', 'E_8e5620c6c290b0', 'E_e8fe4dceb741fc', 'E_c2f4ff87d64f56', 'E_10639b4b65d135', 'E_2d5bcb36b01967', 'E_23d26e3cfe8248', 'E_ebf4ebb1d287cb', 'E_f1349769ed93ca', 'E_e0707a53830f73', 'E_00f91ad3d844c7', 'E_5fdb7a6d841a99', 'E_fa0223339cc61a', 'E_abf2d5b16c3104', 'E_0e2daac2f241eb', 'E_0918ed79d7e19c', 'E_d322550c4df228', 'E_ece5864aa16090', 'E_572ef4e5a016fa', 'E_5aa077b16eed10', 'E_e069b25d0d19b4', 'E_3aa5a77ddb32ea', 'E_e64111a454c468', 'E_5073bd0799df06', 'E_72ae77050f445f', 'E_0148052ad7e6ef', 'E_b894b295da3127', 'E_eb31e849d9e8e9', 'E_0b94dcae5a8d02', 'E_28c51681035a99', 'E_9304cc9714f54d', 'E_cd7eb628e0c2c0', 'E_64c47f72cb1f7c', 'E_58600e94e2be69', 'E_c353d9ef04a400', 'E_ad5e43b36532fa', 'E_2779328db31b5c', 'E_1f28b9914bf118', 'E_791698b56e63dc', 'E_5967b4e2baf0a5', 'E_ac7b544a6bab3b', 'E_5fb70a0a0f8ec7', 'E_750d031bfa0514', 'E_ad71d6b89393f6', 'E_0276dc3ac1b940', 'E_8f4ec6b229ad82', 'E_64153083f79f78', 'E_a9c178129c45a1', 'E_1f61a814629e55', 'E_92a7a60b5e8ea1', 'E_cb836eafc04654', 'E_e91fa0e9259859', 'E_c9999b4301992a', 'E_9199a57cc81cdf', 'E_e56b5d017ff5be', 'E_1af36b24cef8d8', 'E_c08a043305bda8', 'E_a1eb0b2a454c91', 'E_bcb36c33d4ab6a', 'E_e7f8dfb1261475', 'E_7399af91b4ae05', 'E_5930b83a258341', 'E_baa2c502231c04', 'E_a3df3be8acd2bb', 'E_fc8bb26ceab15f', 'E_fcc6bee50609ec', 'E_e6ea395f6107e3', 'E_add34db0029a90', 'E_edef4e884c7f66', 'E_b162bc42355a76', 'E_c1b165eaf3be5c', 'E_0beeb18be5f9a6', 'E_b4513c27872acd'}
# point_of_interest: P_7c5f67c96b0d53
# preds: {'E_615843b234aeb9', 'E_fcc6f4c94525bc'}
# targets: {'E_615843b234aeb9', 'E_70e171037dbbfa', 'E_fcc6f4c94525bc'}
# point_of_interest: P_0f7a2d168c0825
# preds: {'E_fcc728f297f1d8'}
# targets: {'E_fcc728f297f1d8', 'E_7cda23a96dbac9', 'E_35313cf08df8bf'}
# point_of_interest: P_4943e6e732637f
# preds: {'E_fcc75700080ef1', 'E_f78349a97aefd2'}
# targets: {'E_c6a0fd28ebdca2', 'E_2cf7ed329db3ce', 'E_a6876e04a8b260', 'E_fcc75700080ef1', 'E_f78349a97aefd2', 'E_a4667b6382286f'}
# point_of_interest: P_88511318818031
# preds: {'E_7ab1d75419ca2a', 'E_fcc7f296e33c07', 'E_65537225818279', 'E_315008468794d2', 'E_59d7bb129bc8cf'}
# targets: {'E_063189f25bd8b2', 'E_7ab1d75419ca2a', 'E_fcc7f296e33c07', 'E_65537225818279', 'E_315008468794d2', 'E_59d7bb129bc8cf'}
# point_of_interest: P_87606d6388637f
# preds: {'E_fcc90ca74d7951'}
# targets: {'E_fcc90ca74d7951', 'E_890e9b0e769638', 'E_3eb138445648ea'}
# point_of_interest: P_74c04a772239f7
# preds: {'E_f9ea46a7fc6db6', 'E_390778d6c1a195', 'E_fcc9f0f0bfb00e'}
# targets: {'E_eaaeb99d3d880f', 'E_d581c3934b536b', 'E_387fa31497e45a', 'E_f9ea46a7fc6db6', 'E_5f9011eeb99372', 'E_390778d6c1a195', 'E_fcc9f0f0bfb00e', 'E_1e2c24066e5867', 'E_d569d1260bd69b'}
# point_of_interest: P_529a20a1108f2d
# preds: {'E_fcca3da560b9f1'}
# targets: {'E_ff988a01735cfb', 'E_fcca3da560b9f1'}
# point_of_interest: P_e508d149512292
# preds: {'E_775f8fe252cd40', 'E_7d50a79c010aaa', 'E_fcca926bd870f3', 'E_57ae6d331e8549', 'E_e41c4cf2e1adea'}
# targets: {'E_1bc2cbf10294b5', 'E_775f8fe252cd40', 'E_8a368e0eaf8b58', 'E_7d50a79c010aaa', 'E_fcca926bd870f3', 'E_e41c4cf2e1adea', 'E_57ae6d331e8549', 'E_225f90ff78b5fd'}
# point_of_interest: P_2b1633094758d6
# preds: {'E_af53d9ae34c721', 'E_fccad2fb1a7fbb', 'E_9a950ccff64f10', 'E_a923e556fddfae', 'E_bdfcaf4ff81822', 'E_3a94a893e0ca2c', 'E_f6befca44ab424', 'E_c70cbc480e741f', 'E_2f8a4ee63cbb10'}
# targets: {'E_af53d9ae34c721', 'E_39e3002802b19e', 'E_fccad2fb1a7fbb', 'E_9a950ccff64f10', 'E_4fb657429cc8e0', 'E_9f035ad28bd670', 'E_a923e556fddfae', 'E_8556e2bf98b9bd', 'E_4e53e941f8ff6e', 'E_bdfcaf4ff81822', 'E_3a94a893e0ca2c', 'E_9c7b7bb2dd4ffc', 'E_f6befca44ab424', 'E_c70cbc480e741f', 'E_2f8a4ee63cbb10', 'E_845acfdb500718'}
# point_of_interest: P_1da84df140b02d
# preds: {'E_fccb35a9165b6e'}
# targets: {'E_fccb35a9165b6e', 'E_7a671a514147c4'}
# point_of_interest: P_f43596c4f51eb9
# preds: {'E_fccbcb6cd5253e'}
# targets: {'E_fccbcb6cd5253e', 'E_2042eda0d7ff72'}
# point_of_interest: P_a895dc3526328b
# preds: {'E_fccbe3635976e8'}
# targets: {'E_50d8a28d912a3b', 'E_60087beed59736', 'E_9dba5fbed73972', 'E_c58e6203779ab1', 'E_0db4c3735fd042', 'E_fccbe3635976e8', 'E_343e2087e7e0a3', 'E_63377148bbb6bd'}
# point_of_interest: P_15fe28a0f75909
# preds: {'E_4000239763e58f', 'E_938c57e5bfd1a8', 'E_19f2c05d70b101', 'E_7cd2b0bedf6fd7', 'E_a80306a5f68c09', 'E_da3ce8021514df', 'E_a821513a573d09', 'E_23dd4448d8d4da', 'E_3b8731e041fb79', 'E_ab8ffa5ac8f054', 'E_504b40447f99d9', 'E_de8facfb1b5d4a', 'E_d291cfe027f02e', 'E_e33e2dea022aed', 'E_e7b191e3ebaa2f', 'E_fccbeeb457396d', 'E_581a636175eaa0', 'E_9bd4bed139b807', 'E_15fb33fd4d2086'}
# targets: {'E_4585176787a86f', 'E_8893bce2532d7d', 'E_4000239763e58f', 'E_938c57e5bfd1a8', 'E_ec2c47f7ef1d7c', 'E_ca1624256c38bd', 'E_32ba68f3babbb9', 'E_3b8a4736e504ad', 'E_19f2c05d70b101', 'E_fc8d70909f570f', 'E_4216513ff2fe47', 'E_7cd2b0bedf6fd7', 'E_a80306a5f68c09', 'E_da3ce8021514df', 'E_a821513a573d09', 'E_75fee2c9bb8732', 'E_c1616366202461', 'E_23dd4448d8d4da', 'E_7f81b2f8ae27dd', 'E_3b8731e041fb79', 'E_86f0c5f29e7822', 'E_ab8ffa5ac8f054', 'E_15563294fef3af', 'E_e4f01ccb26843a', 'E_504b40447f99d9', 'E_d291cfe027f02e', 'E_de8facfb1b5d4a', 'E_10d295733835b1', 'E_e33e2dea022aed', 'E_e7b191e3ebaa2f', 'E_a0114fd78ddb29', 'E_fccbeeb457396d', 'E_581a636175eaa0', 'E_88616d55fbf743', 'E_cfec51a2e3fbb1', 'E_9bd4bed139b807', 'E_ee5ddda43a8aae', 'E_24074e504de86f', 'E_fa35f80d2eac4d', 'E_15fb33fd4d2086', 'E_af18a6f7d30cba', 'E_a3f080d764e47e', 'E_d07756e14855b9', 'E_33ad5785b90700', 'E_e5cd5c58ea9097', 'E_e57255c5aa4405', 'E_285841ea976ce6', 'E_346bb35113f18f'}
# point_of_interest: P_ff24d5001f44a4
# preds: {'E_fccc62b706def0'}
# targets: {'E_fccc62b706def0', 'E_38f8b64890071c', 'E_54a7680699a2f5', 'E_7e0b113a60f414'}
# point_of_interest: P_7f0d0d5506f996
# preds: {'E_fccce260e2ce6f', 'E_27a47f7da1f1f8'}
# targets: {'E_17f3f9ee21c8a4', 'E_fc07609b2e1e9c', 'E_fccce260e2ce6f', 'E_25159b6861aa36', 'E_3cad89be2f6e17', 'E_d00a2b8d52898a', 'E_fd335e6367c2cd', 'E_7a933f1e6d2a5a', 'E_f78777e3613122', 'E_437031372df0fa', 'E_095303c0ffcc82', 'E_7c873369e1fd4d', 'E_cd5bd8e17712e8', 'E_dbe114981cf6c0', 'E_89cfb7e332c994', 'E_f8bb8e9d9853c8', 'E_b68b98a106350c', 'E_b0e4ac37f5db61', 'E_d5c654c7dcad6f', 'E_5cb5e7b6d16e75', 'E_f858f9b665288e', 'E_27a47f7da1f1f8'}
# point_of_interest: P_a358ceecd08ded
# preds: {'E_fcccef10bc0181'}
# targets: {'E_217cdcb6759ccb', 'E_a69403f633fb00', 'E_672442f15f1552', 'E_fba425e21cdf4e', 'E_fcccef10bc0181'}
# point_of_interest: P_6faeed483e4412
# preds: {'E_52b535436ebf91', 'E_37a40df3f42787', 'E_e35cfda5db1ce7', 'E_a9d5548350cdb3', 'E_347e1120c38a31', 'E_9350f8a1ff267c', 'E_8a1d411effedf7', 'E_9149f4f9fd34d2', 'E_8316eb72acae32', 'E_63f9e41b460d72', 'E_e652c38f68a34b', 'E_8757c9d957f94a', 'E_5cc24d81284c29', 'E_230950f8a4f5cb', 'E_53283f6da4eac3', 'E_07fee809a7dd5a', 'E_681124b6d7ca38', 'E_53338c98fc5d03', 'E_8431845fd8333d', 'E_fccd3115e2fc5a', 'E_887fe6cb705fec', 'E_c7e8bfdda91508', 'E_8eb994a115e2ab', 'E_51718c21887fca', 'E_90527cc61184c0', 'E_2bf67c508c0af0'}
# targets: {'E_52b535436ebf91', 'E_37a40df3f42787', 'E_ea291cb4e93738', 'E_e35cfda5db1ce7', 'E_918ac58204004f', 'E_347e1120c38a31', 'E_a9d5548350cdb3', 'E_737e4d47b3d0fe', 'E_9350f8a1ff267c', 'E_8a1d411effedf7', 'E_9149f4f9fd34d2', 'E_63f9e41b460d72', 'E_8316eb72acae32', 'E_e652c38f68a34b', 'E_8757c9d957f94a', 'E_5cc24d81284c29', 'E_8fd6c82f03bdc6', 'E_230950f8a4f5cb', 'E_53283f6da4eac3', 'E_07fee809a7dd5a', 'E_1d0ec27cbe81b5', 'E_681124b6d7ca38', 'E_53338c98fc5d03', 'E_8431845fd8333d', 'E_fccd3115e2fc5a', 'E_887fe6cb705fec', 'E_c7e8bfdda91508', 'E_8eb994a115e2ab', 'E_dedf8f1db4140b', 'E_51718c21887fca', 'E_90527cc61184c0', 'E_2bf67c508c0af0'}
# point_of_interest: P_cd8f1ebfd54b2a
# preds: {'E_72f3e094122700', 'E_fe5834e0e554ac', 'E_3d124945757a16', 'E_fccd406bb16124'}
# targets: {'E_fccd406bb16124', 'E_72f3e094122700', 'E_fe5834e0e554ac', 'E_3d124945757a16', 'E_87919cc2df99fc'}
# point_of_interest: P_b09422e0ee2b37
# preds: {'E_fccd4e76d9c741'}
# targets: {'E_1b7e3d7a55f992', 'E_fccd4e76d9c741'}
# point_of_interest: P_a0148709d28725
# preds: {'E_c65400a98d9307', 'E_c9cf7216ff4cce', 'E_fccda1659dc703', 'E_25fa1091e61735', 'E_5e816b21afa2e6'}
# targets: {'E_c65400a98d9307', 'E_c9cf7216ff4cce', 'E_fccda1659dc703', 'E_25fa1091e61735', 'E_5e816b21afa2e6', 'E_c150298dfaa19d'}
# point_of_interest: P_3f51afc1166dfc
# preds: {'E_fcce50dced89d7'}
# targets: {'E_bd2e1aba6fb061', 'E_fcce50dced89d7'}
# point_of_interest: P_6013d5005d5216
# preds: {'E_fcceb0516973b0', 'E_ad09e534beffb7'}
# targets: {'E_b5dd53a70a90d8', 'E_fcceb0516973b0', 'E_ad09e534beffb7'}
# point_of_interest: P_fb8d5c8bb220b9
# preds: {'E_fcceda55847916'}
# targets: {'E_09a18e943232aa', 'E_fcceda55847916'}
# point_of_interest: P_f9bfa216b8a153
# preds: {'E_35a6b20a6dd9c3', 'E_1816d3e375f79c', 'E_fccee6f7436a2c', 'E_0862931e19655d'}
# targets: {'E_871bbf76ed143c', 'E_aecc57299cf47f', 'E_35a6b20a6dd9c3', 'E_370a3ff30933c6', 'E_1816d3e375f79c', 'E_69719a54953328', 'E_fccee6f7436a2c', 'E_8a8624cc9a9163', 'E_066a767b2323e6', 'E_0862931e19655d'}
# point_of_interest: P_e5759f0c2e8864
# preds: {'E_fccef5c8b9ddcd'}
# targets: {'E_d23507488d5393', 'E_c5e0783c6f9630', 'E_540269e963b449', 'E_550b95cf4db111', 'E_e026471a2cdee6', 'E_06aea418983a17', 'E_065caeef66ca7f', 'E_fccef5c8b9ddcd', 'E_d57ae62f7ed3a5', 'E_50a5619cebf61f', 'E_9c4bde25dd3b08', 'E_3689b1c40999d0'}
# point_of_interest: P_c308a04e9cd188
# preds: {'E_fccf0c4a658305'}
# targets: {'E_fccf0c4a658305', 'E_bcfe4038657761'}
# point_of_interest: P_b86ba447d66e85
# preds: {'E_fccf3a51dbc4e5'}
# targets: {'E_fccf3a51dbc4e5', 'E_2c74d7a9d38267'}
# point_of_interest: P_b581fccc823adf
# preds: {'E_fcd01d6789c0fd'}
# targets: {'E_66761fda87d8f8', 'E_fcd01d6789c0fd'}
# point_of_interest: P_b3f2c8730b5590
# preds: {'E_fcd022163f5845'}
# targets: {'E_0129ec0e7eb2eb', 'E_fcd022163f5845'}
# point_of_interest: P_9efc25483b66d2
# preds: {'E_fcd037159a86cc'}
# targets: {'E_5313e5c9675214', 'E_fcd037159a86cc'}
# point_of_interest: P_e14a6265ace0ad
# preds: {'E_cd6ea64aeed280', 'E_0ba54a4628119f', 'E_fcd065abefe0ae'}
# targets: {'E_0c9607a746734a', 'E_cfb199b0e7f23d', 'E_6bd87221ecefe3', 'E_a463fd137db5b3', 'E_1302e4caa47454', 'E_562f4cb8a4f845', 'E_0214fc9e563e98', 'E_e4687e302b4805', 'E_4004f5678c7659', 'E_abcf0173b98cfa', 'E_cd6ea64aeed280', 'E_03f38fb9b31561', 'E_7cf07fb3b23ea4', 'E_f2f015b1b53655', 'E_8116dafbe5cec1', 'E_5f79b2f1e91b86', 'E_729fb9704295c4', 'E_8cb74dd0f849b4', 'E_b0e182d2ef15c2', 'E_1529e33e52bbfd', 'E_df43f8168034a1', 'E_d8d9d3b889b988', 'E_8c7f27a2588d6f', 'E_7166ce8a3931ef', 'E_fcd065abefe0ae', 'E_a91da46e752e4c', 'E_6b61a9596f36fd', 'E_44ee4ee86665c4', 'E_b778165bf447c3', 'E_bebce8029163fd', 'E_d486d924f336f1', 'E_dd1efca476179b', 'E_0ba54a4628119f', 'E_ac0d3acf76ef19', 'E_1526e879abaec9', 'E_4970889a6e67e5', 'E_1f37cff2611301', 'E_7017d8d4448871', 'E_c1a431db57acfe', 'E_53bd2cbef5fc29', 'E_ea61666bb7dd50', 'E_dee23a071ea3f7', 'E_88fc588df069a7', 'E_1628aa9b58a715', 'E_67712be9adae60'}
# point_of_interest: P_9a1384e16f3e4f
# preds: {'E_fcd0bdf304d7db', 'E_479e03d9326cf3', 'E_9e761f5cc7e38e'}
# targets: {'E_a2e640cc4aea28', 'E_479e03d9326cf3', 'E_9e761f5cc7e38e', 'E_fcd0bdf304d7db', 'E_22e11b37138d2f'}
# point_of_interest: P_53296480afa950
# preds: {'E_92c74ab7c05427', 'E_5516f9b9f7790b', 'E_fcd0ee7543746e'}
# targets: {'E_fcd0ee7543746e', 'E_2a87ea09a34d41', 'E_116bb378ac2f11', 'E_92c74ab7c05427', 'E_5516f9b9f7790b'}
# point_of_interest: P_ac63db5aee500e
# preds: {'E_516bf3737c1b7e', 'E_1317659960ff54', 'E_26e6b5ee76418a', 'E_fcd147b818730b'}
# targets: {'E_1317659960ff54', 'E_fbb67376a2f74d', 'E_516bf3737c1b7e', 'E_fcd147b818730b', 'E_26e6b5ee76418a'}
# point_of_interest: P_a96b81fbe8bfd0
# preds: {'E_fcd155ce1bf201'}
# targets: {'E_fcd155ce1bf201', 'E_13d3113021293d'}
# point_of_interest: P_2f737426bf861f
# preds: {'E_fcd1df6e9d3611'}
# targets: {'E_e3445a39d3b87c', 'E_4400f8dd22b9bf', 'E_c804c1738013e0', 'E_d6d54108986138', 'E_7fa0530d355c93', 'E_8e984dc758affb', 'E_566ff1c1142b63', 'E_6a98c568aec382', 'E_76f611de884255', 'E_0847847228e6da', 'E_0a1ca91fb411b2', 'E_e5c73855659860', 'E_1ac8c834eb6e7c', 'E_45a5dd191da716', 'E_553a4d008f0fe9', 'E_ae3eb1cf4e056e', 'E_bf4f696e4e4c9f', 'E_d26d1bd02db5c1', 'E_f8681b98541c52', 'E_7860c735e0843f', 'E_b0a7d99b908a04', 'E_0abd0b3f5f7fbb', 'E_049ca044abf002', 'E_4dbaafd6a4ba54', 'E_67f5f6de3a2efc', 'E_3fe9cc909dac86', 'E_2b19155a937b5b', 'E_e6ad2cf49a0f1c', 'E_cd661fce3ef904', 'E_ed84f9a3e1a3ef', 'E_7a616daa47e92b', 'E_95d3f005074fc8', 'E_fcd1df6e9d3611', 'E_7c8dd2983b7055', 'E_a1937d1c010fc9', 'E_0e2aacd91f1c37', 'E_60a54a8ea685f2'}
# point_of_interest: P_a3fddc2f0a77e7
# preds: {'E_fcd254971eb22e'}
# targets: {'E_fcd254971eb22e', 'E_7565e5d9f634e5'}
# point_of_interest: P_f47da9552c27a9
# preds: {'E_fcd2f243d813ce'}
# targets: {'E_7aa9ad34d2c0d0', 'E_fcd2f243d813ce'}
# point_of_interest: P_46af9a41d33d6c
# preds: {'E_8edcb98c1674f1', 'E_fcd39aeb744077'}
# targets: {'E_8edcb98c1674f1', 'E_fcd39aeb744077', 'E_f816e07f244bc9'}
# point_of_interest: P_bc5a827b040abf
# preds: {'E_b0939f637f865a', 'E_fcd3a20ec9a022', 'E_2223b288bb3a86'}
# targets: {'E_b0939f637f865a', 'E_fcd3a20ec9a022', 'E_aa14fa6c3ec3a1', 'E_2223b288bb3a86'}
# point_of_interest: P_46929e75e6601c
# preds: {'E_fcd3c65c3dc60a', 'E_24db69f0cf3648', 'E_23b03d6b40ab17', 'E_57eea3eaee76b4'}
# targets: {'E_23b03d6b40ab17', 'E_51624c542c5cf8', 'E_24db69f0cf3648', 'E_57eea3eaee76b4', 'E_fcd3c65c3dc60a'}
# point_of_interest: P_14487b5330e566
# preds: {'E_fcd4281288cf75'}
# targets: {'E_fcd4281288cf75', 'E_e3bdf82e29e3a1'}
# point_of_interest: P_46c24ed5254ef3
# preds: {'E_fcd476fe24ecf2'}
# targets: {'E_fcb7409928d86d', 'E_cd100cade604b7', 'E_fcd476fe24ecf2'}
# point_of_interest: P_f68379dd165e46
# preds: {'E_fcd47fe89cec14'}
# targets: {'E_fcd47fe89cec14', 'E_c6dd878b458edd'}
# point_of_interest: P_7dde98b326e807
# preds: {'E_63afa0ffc14f71', 'E_fcd5d162b6928e', 'E_ddaec0c4fe2d7e', 'E_085061fecbe86b', 'E_bc6eb5345e0837', 'E_f5a9c620286bf3', 'E_31e192a8b25558', 'E_2cd455710064db', 'E_5aaaa0b71c18f7'}
# targets: {'E_63afa0ffc14f71', 'E_fcd5d162b6928e', 'E_ddaec0c4fe2d7e', 'E_afe55eafe76536', 'E_085061fecbe86b', 'E_bc6eb5345e0837', 'E_f5a9c620286bf3', 'E_31e192a8b25558', 'E_2cd455710064db', 'E_5aaaa0b71c18f7'}
# point_of_interest: P_8690e32a11d515
# preds: {'E_fcd6a391a7e9dc', 'E_6047d018b910b7', 'E_bb6993b23ef6bf', 'E_837662ae3d6663', 'E_b51ed5f636dee8'}
# targets: {'E_5041732d7c0443', 'E_fcd6a391a7e9dc', 'E_6047d018b910b7', 'E_92f84d3e7b19d6', 'E_b51ed5f636dee8', 'E_db044454e37a51', 'E_bb6993b23ef6bf', 'E_837662ae3d6663', 'E_50c44a9ef4a4ef'}
# point_of_interest: P_0f48b6a18f9d15
# preds: {'E_fcd7583a850556'}
# targets: {'E_a15c8877d0a05c', 'E_99f57fc7de2c28', 'E_0608e083719497', 'E_19332fd7f01d9e', 'E_031f885c2e80e2', 'E_fcd7583a850556', 'E_3abdef26a3ab0e', 'E_1a335675b2c03f', 'E_e6396292f3e647', 'E_a11a9c834a8f1c', 'E_89571fc9420db5', 'E_6f645b36bea8af'}
# point_of_interest: P_554e94ddafb268
# preds: {'E_ea1a7faf95c7e0', 'E_2f718c08f0a78f', 'E_fcd7c4eb6142f9'}
# targets: {'E_2f718c08f0a78f', 'E_ea1a7faf95c7e0', 'E_97fbf2680c16d1', 'E_fcd7c4eb6142f9'}
# point_of_interest: P_b1ef667f422efb
# preds: {'E_fcd84801c55ae8', 'E_fe81be811d0c55'}
# targets: {'E_fcd84801c55ae8', 'E_9e759f83f3339f', 'E_fe81be811d0c55'}
# point_of_interest: P_eeac785dcf2d03
# preds: {'E_41773cbd44dcc2', 'E_fcd86c0e39f5b5', 'E_bb8161eca54c89', 'E_43ca105d985c9b', 'E_b4cd560d5dc77b', 'E_1e2d2cc91b9e05'}
# targets: {'E_41773cbd44dcc2', 'E_2647ea4c94e206', 'E_fcd86c0e39f5b5', 'E_bb8161eca54c89', 'E_43ca105d985c9b', 'E_b4cd560d5dc77b', 'E_1e2d2cc91b9e05', 'E_21daffc8d9a27a'}
# point_of_interest: P_5c5276c2da3548
# preds: {'E_10938d5258c2c2', 'E_001b7fcfd8ecc1', 'E_70a8821793f23e', 'E_2bb2c752a040b5', 'E_b1425cc3466d4a', 'E_45c0a6abf36465', 'E_7b7ef56436a4b0', 'E_fcd9aed6011c7f', 'E_26f35f8275f3bc', 'E_586ee948e1b11b', 'E_7b9009baa2e642'}
# targets: {'E_40640fa00d3708', 'E_692f58f0cad6ce', 'E_10938d5258c2c2', 'E_001b7fcfd8ecc1', 'E_70a8821793f23e', 'E_b2de242a415dc5', 'E_2bb2c752a040b5', 'E_b1425cc3466d4a', 'E_0b8e79d52c633f', 'E_7b7ef56436a4b0', 'E_45c0a6abf36465', 'E_5fc9be7a8cea1c', 'E_586ee948e1b11b', 'E_fcd9aed6011c7f', 'E_26f35f8275f3bc', 'E_7b9009baa2e642'}
# point_of_interest: P_fbffd4beaf833d
# preds: {'E_fcdbb712fb6da7', 'E_ecfcc61dbb9b49', 'E_9856ba0b498916'}
# targets: {'E_9856ba0b498916', 'E_7ba3efe287e53f', 'E_ecfcc61dbb9b49', 'E_fcdbb712fb6da7'}
# point_of_interest: P_58c949a345fa15
# preds: {'E_fcdbe32ed7921d'}
# targets: {'E_35ceb11453b4a4', 'E_41b61bd52219e8', 'E_90296a1edf8229', 'E_f7f986fd374681', 'E_e538bb559e4c13', 'E_fa21736579541b', 'E_964618be9d9fea', 'E_6207c27a47fbc5', 'E_40e0786a1924ef', 'E_fcdbe32ed7921d', 'E_8462592c50b1a9', 'E_4e06167b71ad77', 'E_0551ed385d1132', 'E_58fe43f3fc16a7', 'E_b000cf6f252471', 'E_c0bedfcab0c11b', 'E_c52f6e4267cb53', 'E_e216922a902467', 'E_45fa4fab4b91d5', 'E_298a25022f2120', 'E_bff5ccfdaa1e56', 'E_47ac64535aa32e', 'E_bde5077ee1aefe', 'E_5ae7bd3d0ba18f', 'E_66891d9daa39dc', 'E_6a7847a3f0d2d0', 'E_46d96a83caf8ce', 'E_29017510b340ec', 'E_e2a1301657397d', 'E_ac748d366e5265', 'E_adce9a0eed290f', 'E_50faa571a8695a', 'E_91b4cfe2e103f5', 'E_e1c6fa9aac5338', 'E_fe8a359e7d66eb', 'E_7698e745d1ac51'}
# point_of_interest: P_1b9460f59e0c56
# preds: {'E_fcdc4a3dc51a1e'}
# targets: {'E_fcdc4a3dc51a1e', 'E_6d282f64e16fd9'}
# point_of_interest: P_f7c35548211257
# preds: {'E_fcdceae351b196'}
# targets: {'E_0a4bea152beeac', 'E_7117e682395c62', 'E_fcdceae351b196', 'E_83709687788146', 'E_8cdc4c163c2f46', 'E_fc5734507dca64'}
# point_of_interest: P_b2b76e18bbcce0
# preds: {'E_fcdd09dbcb8990'}
# targets: {'E_649ef3ab731996', 'E_8f31f6e2f2c81b', 'E_ee6445c238d6f6', 'E_46ba86c843cdb0', 'E_1bbf368c9ba1e7', 'E_163dac50d11ba6', 'E_2984717a0fbdb8', 'E_68f4a18cd29b0b', 'E_adeed208b40848', 'E_26d773a12563c4', 'E_6c6e4b8ea2ca80', 'E_566d96d156f432', 'E_db0a2a50312063', 'E_cff00c297ba03f', 'E_1e214751b72785', 'E_765c02705bd045', 'E_e6c87c8676f87a', 'E_f2e6b36ee91c2a', 'E_32da1a3f50da95', 'E_db8c72dca5d7c2', 'E_3f459cad2fa5df', 'E_978013f69d7596', 'E_a6e54daa8012c3', 'E_e6671d37decf29', 'E_fcdd09dbcb8990', 'E_c28c3425995c46', 'E_2891784859a066'}
# point_of_interest: P_36354d2fd7fc2a
# preds: {'E_fcdd9b70490341'}
# targets: {'E_63b798c32021ca', 'E_c143412fea455f', 'E_ce9f80a5ac8fec', 'E_3e18b62756a816', 'E_4f103b03dfdf18', 'E_38a289f49adc6a', 'E_8b962c2478c605', 'E_fcdd9b70490341'}
# point_of_interest: P_87e811e68477de
# preds: {'E_fcddc3892aaee3'}
# targets: {'E_723dc3aaad482d', 'E_fcddc3892aaee3'}
# point_of_interest: P_1f05b64a71fd4c
# preds: {'E_98a54e387a8d50', 'E_fcddc5d462ef18'}
# targets: {'E_28c0dfc287c209', 'E_30a18f8e1c96ae', 'E_fcddc5d462ef18', 'E_d93a44f01d016e', 'E_98a54e387a8d50'}
# point_of_interest: P_68d4d88817e90c
# preds: {'E_42c61cf5297867', 'E_fcddcb5d5d8f95'}
# targets: {'E_42c61cf5297867', 'E_fcddcb5d5d8f95', 'E_c52be6db8b77d5'}
# point_of_interest: P_629707e2af2d07
# preds: {'E_fcde4947146a7e'}
# targets: {'E_fcde4947146a7e', 'E_1606011e6bf642'}
# point_of_interest: P_0a978e13c77157
# preds: {'E_fcdebfe72f7bd8'}
# targets: {'E_fcdebfe72f7bd8', 'E_f2995a648ac4d0'}
# point_of_interest: P_0109312b117ed9
# preds: {'E_fcdec86a97a2a4'}
# targets: {'E_ae38341e438628', 'E_fcdec86a97a2a4'}
# point_of_interest: P_94ba88b670bedc
# preds: {'E_fcdf73087edf5f'}
# targets: {'E_616535607ef152', 'E_fcdf73087edf5f'}
# point_of_interest: P_f670851f2774e2
# preds: {'E_fcdfb06f8393a1'}
# targets: {'E_fcdfb06f8393a1', 'E_91fdbf0428f6f8'}
# point_of_interest: P_06c489285a776d
# preds: {'E_fce08167496755'}
# targets: {'E_8b41de7553b6f0', 'E_fce08167496755'}
# point_of_interest: P_72ec14febf7435
# preds: {'E_b01c2856795a41', 'E_b5340bbd77e221', 'E_fce0d0dff409dc'}
# targets: {'E_876ae0b7d7d53e', 'E_bebf73a0a64a67', 'E_fce0d0dff409dc', 'E_b01c2856795a41', 'E_b5340bbd77e221'}
# point_of_interest: P_d99f4284545161
# preds: {'E_fce18d0ee20dbf'}
# targets: {'E_d58f2d37883c27', 'E_fce18d0ee20dbf'}
# point_of_interest: P_c2629052ff9ea6
# preds: {'E_4e6bef51f1c845', 'E_11ad9a53719364', 'E_fce255e9c17eee', 'E_7cc82fb6e08dd7'}
# targets: {'E_004a4a861431af', 'E_4e6bef51f1c845', 'E_fce255e9c17eee', 'E_11ad9a53719364', 'E_7cc82fb6e08dd7'}
# point_of_interest: P_86de5e9318abff
# preds: {'E_fce27109bdf3c7'}
# targets: {'E_fce27109bdf3c7', 'E_bc88c121b1055a'}
# point_of_interest: P_5658fbb41300b2
# preds: {'E_fce292deebf378'}
# targets: {'E_d5134cbbf89f28', 'E_fce292deebf378'}
# point_of_interest: P_d78831131e60c6
# preds: {'E_fce39708b27aca'}
# targets: {'E_b5d00c40153285', 'E_fce39708b27aca'}
# point_of_interest: P_08147a05c4b1b9
# preds: {'E_fce5c7825da483', 'E_b8ef702cde956d'}
# targets: {'E_fce5c7825da483', 'E_b8ef702cde956d', 'E_7a0c6196c0d879'}
# point_of_interest: P_6303daf1676603
# preds: {'E_fce6a71c6ce1fb'}
# targets: {'E_dd38fabfd8cc28', 'E_2ca2a52051c697', 'E_b5d5004c69f873', 'E_6c32050305212e', 'E_7aeb0cab185ea5', 'E_61105ca2a4a115', 'E_45b4d6f2af7e78', 'E_897afb52a603ac', 'E_479dabf38b6ea6', 'E_989bd1ac6b7026', 'E_c2d723f8960b4d', 'E_640949951e4c6e', 'E_101a01a340ddab', 'E_8467539ec05cfd', 'E_8617a41f7c7a9e', 'E_fe704af74b2ef1', 'E_4344074725cc37', 'E_667df05d2b441a', 'E_322ae5126ec20d', 'E_aeb2ec5ed1a733', 'E_fce6a71c6ce1fb'}
# point_of_interest: P_b0620d68a78f5a
# preds: {'E_fce6bf9b57e86f'}
# targets: {'E_fce6bf9b57e86f', 'E_9cd3ba453e65a4'}
# point_of_interest: P_0e4386901d02f3
# preds: {'E_fce6fef2c98815'}
# targets: {'E_fce6fef2c98815', 'E_8849e248a99fba', 'E_8631e6531d1f8e'}
# point_of_interest: P_ae8e94181e3ec5
# preds: {'E_fce81dfea741a2'}
# targets: {'E_fce81dfea741a2', 'E_bfd27276be63b4'}
# point_of_interest: P_94f92134d14195
# preds: {'E_e33dd11a1351b2', 'E_79fdd25823bbe7', 'E_6b4202fe7a3cbf', 'E_f74e55f7520e43', 'E_a097dbc6c75013', 'E_fce8b8178f97ba', 'E_1939de5a70f731', 'E_f7f9cd64668f38'}
# targets: {'E_e33dd11a1351b2', 'E_79fdd25823bbe7', 'E_8ac886aa49c4f9', 'E_5589a1ce3555f4', 'E_b2b40f087bb618', 'E_bf998a15067c5a', 'E_e85bf1c0daec7e', 'E_5bb6f34b45fdc2', 'E_8d94f480fa38cb', 'E_44d14cf4936df1', 'E_7a66e40473284c', 'E_e1dcf62203437e', 'E_4576c71cbf6089', 'E_f74e55f7520e43', 'E_ab8e128fde770a', 'E_88b974117db59c', 'E_137431ee415dc1', 'E_9bb6ff8a6bafee', 'E_de736990e3fea7', 'E_edc6e11607c209', 'E_24209ea89a5737', 'E_f95cfc4ba00400', 'E_6b4202fe7a3cbf', 'E_d4527279e57f81', 'E_0705c635699cb0', 'E_a097dbc6c75013', 'E_c8e037b22886a8', 'E_080f9f37bd6cfe', 'E_1939de5a70f731', 'E_407d90e2c466a8', 'E_b7be9db10883dd', 'E_1d4efea8f88caa', 'E_d509a2e16f267f', 'E_0269337d645c98', 'E_04ff79c3b1352e', 'E_6ee62ddc88ea69', 'E_86a6acb3fa2b96', 'E_17b82fa25bcca4', 'E_8f0a66ae7c67fe', 'E_0e671a0192e508', 'E_d108ded22cc286', 'E_f33900addc4734', 'E_ac8e43ad3f0c1f', 'E_5020581b17cf60', 'E_d0cc43dae6bc7f', 'E_fce8b8178f97ba', 'E_f7f9cd64668f38', 'E_1188c8ae8ab009', 'E_fc45c0a4974ee1', 'E_9c5aeeedee1aba', 'E_7891fd57304b05', 'E_23cdac41a952a1'}
# point_of_interest: P_ea5a068b35685f
# preds: {'E_fce8e43452ccf9'}
# targets: {'E_69299de87eedb7', 'E_fce8e43452ccf9', 'E_a961b231b9f6e4'}
# point_of_interest: P_184baa08494671
# preds: {'E_99487ff4b543e5', 'E_034dbffe9091b8', 'E_10ba158d14199a', 'E_7bcb5170689541', 'E_3a49b30ddce8fe', 'E_4cc580a265f492', 'E_e4d0d928bbba2e', 'E_b5c475b33652e9', 'E_929e2729df172f', 'E_60e54efd71aeb6', 'E_ff57e025e203b9', 'E_8eb5c42bcc257e', 'E_d9ea193e01065c', 'E_0eca06ebaea979', 'E_6d1bc39e6729f2', 'E_5b52e0b9cb8b66', 'E_308c9c7ff9e6d5', 'E_0f580bd38141a2', 'E_e4b5204098b4c5', 'E_1f92d47ba7a1cc', 'E_fa228efc196671', 'E_23f587800c6079', 'E_54f16f670314ab', 'E_3da8d76b7b7d39', 'E_fc1a9d549652a9', 'E_a35bd490252ff3', 'E_af0e1651406a81', 'E_2c081798b6e79d', 'E_8c6cc18804ce2b', 'E_cd918e8049b6c4', 'E_4e617462c8b7e1', 'E_61a627aa0ec991', 'E_124e712813151b', 'E_ab7a639fa2b033', 'E_ac23f01e8e72b9', 'E_efda26936720b9', 'E_301b6af66a540a', 'E_fce922efdeeaa4', 'E_b8f79a4634eacf', 'E_48f66062f2f9b8', 'E_ed27bd39ce2892', 'E_decd15588c8db8', 'E_dde76805c3a4a8', 'E_9e11d3c59f88f5', 'E_a52633d3e8480a', 'E_c2ae00f219f895', 'E_1454adce4b27ac', 'E_58a57463c876ac'}
# targets: {'E_99487ff4b543e5', 'E_034dbffe9091b8', 'E_10ba158d14199a', 'E_27cd8d0ddeba8f', 'E_7bcb5170689541', 'E_9db749574c8b47', 'E_3a49b30ddce8fe', 'E_916a8a7b4e8e35', 'E_c3f42a48b76319', 'E_e5ce328a176764', 'E_1e52bae5636b8a', 'E_4cc580a265f492', 'E_e4d0d928bbba2e', 'E_80995985c04084', 'E_b5c475b33652e9', 'E_929e2729df172f', 'E_60e54efd71aeb6', 'E_ff57e025e203b9', 'E_8eb5c42bcc257e', 'E_c6a9207754e4fc', 'E_d9ea193e01065c', 'E_0eca06ebaea979', 'E_6d1bc39e6729f2', 'E_9f8f78cb56db5c', 'E_5b52e0b9cb8b66', 'E_308c9c7ff9e6d5', 'E_0f580bd38141a2', 'E_e4b5204098b4c5', 'E_1f92d47ba7a1cc', 'E_fa228efc196671', 'E_f74402b061b6fd', 'E_23f587800c6079', 'E_e120a7ce86dc1f', 'E_a773cd61fdda3f', 'E_54f16f670314ab', 'E_3da8d76b7b7d39', 'E_05b9c9fc1cd4a1', 'E_5699a2ccfe94f7', 'E_eb4c02ae7b0a6c', 'E_eb5fe7824ed7d3', 'E_fc1a9d549652a9', 'E_a35bd490252ff3', 'E_b39702efbcc007', 'E_7f48278215b26a', 'E_2c081798b6e79d', 'E_af0e1651406a81', 'E_8c6cc18804ce2b', 'E_4e617462c8b7e1', 'E_2f72db27d2da2a', 'E_61a627aa0ec991', 'E_cbdbc1ad3299a0', 'E_cd918e8049b6c4', 'E_124e712813151b', 'E_ab7a639fa2b033', 'E_ac23f01e8e72b9', 'E_efda26936720b9', 'E_301b6af66a540a', 'E_fce922efdeeaa4', 'E_b8f79a4634eacf', 'E_83c4b56d8b81c5', 'E_29816e4c5dae58', 'E_48f66062f2f9b8', 'E_821648d8055764', 'E_decd15588c8db8', 'E_dde76805c3a4a8', 'E_ed27bd39ce2892', 'E_73e5cc25c072dc', 'E_9e11d3c59f88f5', 'E_b914ebf8adb3e1', 'E_8b22c133e8916d', 'E_a52633d3e8480a', 'E_c2ae00f219f895', 'E_1454adce4b27ac', 'E_58a57463c876ac'}
# point_of_interest: P_162d8569d0fe9b
# preds: {'E_fce942e23e82c2'}
# targets: {'E_fce942e23e82c2', 'E_e5918ce0aeb854'}
# point_of_interest: P_a20dc8c435009e
# preds: {'E_fcea9d93a9eab5'}
# targets: {'E_fcea9d93a9eab5', 'E_02e2921f02dd17'}
# point_of_interest: P_a89434bc656ae2
# preds: {'E_fcead7623d5b59'}
# targets: {'E_6274055ed61fe0', 'E_b72e5e2531b431', 'E_fcead7623d5b59'}
# point_of_interest: P_4bf360520bfce1
# preds: {'E_c171d51d0366b6', 'E_fcec22ae6168f2', 'E_a8ee5be976ac0f'}
# targets: {'E_c171d51d0366b6', 'E_2b67af982aed5d', 'E_fcec22ae6168f2', 'E_a8ee5be976ac0f'}
# point_of_interest: P_d1083647816628
# preds: {'E_fcec305846dab4'}
# targets: {'E_bf23e8e90da8e2', 'E_fcec305846dab4'}
# point_of_interest: P_73f5351f39da02
# preds: {'E_fd7aa97d4e7025', 'E_fcecb6cdcdebc6'}
# targets: {'E_fd7aa97d4e7025', 'E_fcecb6cdcdebc6', 'E_82f3cb078ec7b6'}
# point_of_interest: P_63f8172f402f5b
# preds: {'E_fcecd39628f8cf', 'E_11fe5ece1ca596'}
# targets: {'E_11fe5ece1ca596', 'E_fcecd39628f8cf', 'E_e5bd417cf9bdd8'}
# point_of_interest: P_95a11e5ace0139
# preds: {'E_fcecdbcd787e09'}
# targets: {'E_57b27bbc9263f8', 'E_fcecdbcd787e09'}
# point_of_interest: P_5e41f6e8d3a3dd
# preds: {'E_fcee9b645ad3c9'}
# targets: {'E_fcee9b645ad3c9', 'E_8876dbb710e8a0'}
# point_of_interest: P_a606de1a77fbab
# preds: {'E_fceea2d51e78c5'}
# targets: {'E_7ef6705e4f0667', 'E_fceea2d51e78c5'}
# point_of_interest: P_280a20a2137294
# preds: {'E_fcef275a58be88', 'E_a566171c70f765'}
# targets: {'E_e10705937a433a', 'E_fcef275a58be88', 'E_a566171c70f765'}
# point_of_interest: P_755d53b43a4eba
# preds: {'E_fcef8bd8e8bc06'}
# targets: {'E_d10d20432993d8', 'E_fcef8bd8e8bc06'}
# point_of_interest: P_695845bb6912d1
# preds: {'E_fcefef3d7891df'}
# targets: {'E_fcefef3d7891df', 'E_e90b061c03c61d'}
# point_of_interest: P_a959bb476c5544
# preds: {'E_fcf1d2d64d7b50'}
# targets: {'E_fcf1d2d64d7b50', 'E_5bd4643f6982eb', 'E_d58368805a5595'}
# point_of_interest: P_9cc3b65c71212d
# preds: {'E_c3535c688247e4', 'E_1a5635647f08d8', 'E_aa01e39b8365ff', 'E_12cc1f8dd54d2a', 'E_fcf1e3b0970210'}
# targets: {'E_c3535c688247e4', 'E_1a5635647f08d8', 'E_aa01e39b8365ff', 'E_12cc1f8dd54d2a', 'E_fcf1e3b0970210', 'E_640003a6b60be4', 'E_e60c6ca4e33729'}
# point_of_interest: P_c7df5a99fbba9c
# preds: {'E_fcf248053480ae'}
# targets: {'E_fcf248053480ae', 'E_5800be7b32412b'}
# point_of_interest: P_07e0c6a721f368
# preds: {'E_ac716662b1335f', 'E_fcf2aeef4f599e', 'E_bcbf5bbc9d0a3c', 'E_62615ca829ccfd', 'E_7a7b7cbc85c58c', 'E_93e4ccb919ce6a'}
# targets: {'E_ac716662b1335f', 'E_3a7ba868068757', 'E_50d39f7778cca3', 'E_fac32c6270b179', 'E_8a760e34685930', 'E_fcf2aeef4f599e', 'E_d7d86cc227fd45', 'E_9cafb9969671ca', 'E_bcbf5bbc9d0a3c', 'E_bbc703b27836d3', 'E_1c69afd8299e2d', 'E_62615ca829ccfd', 'E_7a7b7cbc85c58c', 'E_93e4ccb919ce6a'}
# point_of_interest: P_1d5530c72bceaa
# preds: {'E_fcf36e189fa5bd', 'E_90f1cdd89c92df'}
# targets: {'E_90f1cdd89c92df', 'E_e55c02f7348f90', 'E_94578390c27147', 'E_18ed049b0ac507', 'E_fcf36e189fa5bd', 'E_011a9c54e5859a', 'E_0666ed40425446', 'E_f0fba846105be7', 'E_4092b6086e9aca'}
# point_of_interest: P_edb2c59400c518
# preds: {'E_535debebc5170f', 'E_fcf3ab7d2b3eb7', 'E_36a0f25986dbfa'}
# targets: {'E_830a8ec11df7f4', 'E_fcf3ab7d2b3eb7', 'E_535debebc5170f', 'E_36a0f25986dbfa'}
# point_of_interest: P_b48c604488e902
# preds: {'E_669f765e67b9ff', 'E_fcf3ed9ea08878', 'E_4adcd18ffc61b7', 'E_8904c741463ab6'}
# targets: {'E_015d3cb456ecfe', 'E_fcf3ed9ea08878', 'E_8904c741463ab6', 'E_242a5ba83736c0', 'E_a6547b46fb40e3', 'E_4adcd18ffc61b7', 'E_df5523db3ee56d', 'E_669f765e67b9ff'}
# point_of_interest: P_8e583fc8573b8e
# preds: {'E_72563d9ed0ff50', 'E_bcadb5ad7994d7', 'E_fcf56e75c3604c', 'E_11ee3195fe3816', 'E_cb1f551e944d73', 'E_bbaf7a431463a6', 'E_c90290b2e08690'}
# targets: {'E_72563d9ed0ff50', 'E_5ca2051ead529a', 'E_bcadb5ad7994d7', 'E_e7aace734c1f86', 'E_fcf56e75c3604c', 'E_11ee3195fe3816', 'E_86caeaa2c7f32d', 'E_530c6a5cf37a97', 'E_1e7a11ee9798c9', 'E_c650c867edc14c', 'E_cb1f551e944d73', 'E_bbaf7a431463a6', 'E_c90290b2e08690', 'E_0c3b6cfcd08264'}
# point_of_interest: P_a923fce843d3dd
# preds: {'E_fcf59fb6f627dd'}
# targets: {'E_fcf59fb6f627dd', 'E_47583921be63e2'}
# point_of_interest: P_baffa24f7b0a04
# preds: {'E_fcf6484ef19d1b'}
# targets: {'E_fcf6484ef19d1b', 'E_1b4e8a02b62626'}
# point_of_interest: P_451c5f62aaa511
# preds: {'E_fcf6b495822252'}
# targets: {'E_56f760953df7ac', 'E_feec483254dcd8', 'E_fcf6b495822252', 'E_2f24377e73981b', 'E_fbf86c98d309e5', 'E_01442055a49395', 'E_7fcef0ed77ac55', 'E_4ddc0b3462f9a4', 'E_23c2fb1a28edca'}
# point_of_interest: P_ada342ad548729
# preds: {'E_fcf7377954e8a9'}
# targets: {'E_fcf7377954e8a9', 'E_87eeb62d27c41e', 'E_6880545541d714'}
# point_of_interest: P_bd561413a8defe
# preds: {'E_87389c5255ffb0', 'E_97f652ff52bb61', 'E_2374785204bb32', 'E_6251d670ce09e3', 'E_fcf7483e564a73', 'E_230c160c11e418'}
# targets: {'E_87389c5255ffb0', 'E_97f652ff52bb61', 'E_2374785204bb32', 'E_6251d670ce09e3', 'E_fcf7483e564a73', 'E_230c160c11e418', 'E_3786df6b7b92b4'}
# point_of_interest: P_1278442e363225
# preds: {'E_fcf81118431380', 'E_7bb97e590bd0d9'}
# targets: {'E_91c57d11420760', 'E_fcf81118431380', 'E_7bb97e590bd0d9'}
# point_of_interest: P_7650f28dda89a5
# preds: {'E_fcf8434821d56e'}
# targets: {'E_67106d516aa454', 'E_fcf8434821d56e'}
# point_of_interest: P_3d57ec52a0043a
# preds: {'E_425f08391c8f85', 'E_5cff261ec7096c', 'E_fcf8fc47f8464d', 'E_51d3a0046de7d5'}
# targets: {'E_425f08391c8f85', 'E_aa8c197853dc57', 'E_51d3a0046de7d5', 'E_5cff261ec7096c', 'E_fcf8fc47f8464d'}
# point_of_interest: P_7ac96c0c817c3b
# preds: {'E_57420799faca85', 'E_f62663f1deec44', 'E_327a38390d9286', 'E_5f804450015c4b', 'E_15926f9aa15e32', 'E_fcf979f2bfe7ce', 'E_bb606e1c6711e8'}
# targets: {'E_57420799faca85', 'E_af22dc1ee4a02c', 'E_f62663f1deec44', 'E_fcf979f2bfe7ce', 'E_327a38390d9286', 'E_5f804450015c4b', 'E_7acfd3ae72e785', 'E_15926f9aa15e32', 'E_1e32b20c466494', 'E_bb606e1c6711e8', 'E_0a2bbe64dcbec6'}
# point_of_interest: P_128733a0ac8c56
# preds: {'E_ed818dc7837df4', 'E_fcf9d47c1764f6', 'E_76d543acb86279', 'E_89385f2ba1662a', 'E_75266f009943bc', 'E_195ee8ee365aab', 'E_f06af28f5c26cd', 'E_5994fcb2ebc3ad'}
# targets: {'E_a9a2de09c867d9', 'E_b276106172297e', 'E_9067f0633a43cc', 'E_85cd612b2f7ba0', 'E_7109538fc929a5', 'E_0db3900cc0d061', 'E_0998c5dd950fc0', 'E_76d543acb86279', 'E_a0bfd1d9f3ed2e', 'E_3a13743332098e', 'E_de4b9a8b840588', 'E_fcf9d47c1764f6', 'E_4ccf7f85658bb4', 'E_8ccd84cffe215c', 'E_75266f009943bc', 'E_7b334046b8fba1', 'E_cc63d2981d42c9', 'E_fa22227c82013d', 'E_5dd5df6f84b53c', 'E_a3d1eb66e10fd9', 'E_2d5f7445497523', 'E_89385f2ba1662a', 'E_b13d21336a88fc', 'E_195ee8ee365aab', 'E_8bf1cdc5fc698a', 'E_6c2a3fd4218e7d', 'E_0ae453e13d8bfe', 'E_0b3971429dcdee', 'E_004665bfc60fd0', 'E_6a7f50433a9286', 'E_1c0c2edd0c38f4', 'E_9421efd852af6e', 'E_6adbb54de7dbe4', 'E_9c8bdc7591221c', 'E_c59b3008a8507e', 'E_f6a78e74731bc1', 'E_6117cb4a82c7e3', 'E_9f732c64fd82e3', 'E_65bd02a7ea973e', 'E_fb4c3389d496b4', 'E_cab15a6d640ce8', 'E_72cce7c6813155', 'E_0f87175dac9e5b', 'E_2d083dd443899f', 'E_bea5ca3f6fed81', 'E_9ef4cc57492133', 'E_534996bbb7a2bb', 'E_5914a0bf5eb9ab', 'E_eaa74dca0cff5e', 'E_3c2143255d0747', 'E_0c12fdd23bd6ce', 'E_02b93e45e569c8', 'E_f7555ada4c9109', 'E_2065ed82eb5460', 'E_74a121196cd9b8', 'E_febb2afa340a0d', 'E_889ddd18f934d0', 'E_c4987d1a30c985', 'E_3246dc571614e7', 'E_c0e086a107fb01', 'E_fdd1aa166da6c7', 'E_726ee176c4369f', 'E_7656f9b28b832c', 'E_a7edbb545aaee7', 'E_444a20989d5b0a', 'E_3ae73bb67b2789', 'E_8591678f16ef48', 'E_b01730d6ae614a', 'E_e816a0b1d31d0f', 'E_087a7277c3e53f', 'E_820de90c0e5d1d', 'E_3c0f1274a30b1c', 'E_2cb102aac35a5a', 'E_21de35d95d995b', 'E_5994fcb2ebc3ad', 'E_525113d90af81f', 'E_f98bb54470c857', 'E_6d2a7c044e6a72', 'E_bee273c2b83e21', 'E_b60aba97b904d4', 'E_dc1d089daf934b', 'E_bebabb28b6b0ec', 'E_7f775582853a43', 'E_5e69b5fb986c83', 'E_88a44f76c0b10c', 'E_806df943016f5e', 'E_c7e43887aa7a09', 'E_4825ab3d5973f6', 'E_be3d39a4317e92', 'E_1d4f8f2c792eae', 'E_fba1bf99d5a9e1', 'E_f06af28f5c26cd', 'E_2ee4227ade087b', 'E_f1bf694207613a', 'E_f1f93f4b66b474', 'E_860ebbe1078366', 'E_ed818dc7837df4', 'E_22433f14de1030', 'E_9e76549828274f', 'E_e4928a6a70d505', 'E_dc63a460220e7c', 'E_482e321901aec9', 'E_851263e562b968', 'E_1f4149a9419c2f', 'E_360004948ce8a4', 'E_7a8e172d852004'}
# point_of_interest: P_16f3e1dfab51fa
# preds: {'E_fcfa0c0966486e', 'E_9c995a194527e2', 'E_4ef1b1621b31bd'}
# targets: {'E_37060b02813ad4', 'E_06555d152b106e', 'E_69c6fa1123c6d8', 'E_5f8c7d4913d768', 'E_8923fcd4e80d3d', 'E_ba05aba810e47e', 'E_2ad1dfb4f29a74', 'E_0e6124a6a7e174', 'E_9c995a194527e2', 'E_440c3ef480677b', 'E_55bbab51451cac', 'E_a6f1af32649ab3', 'E_8c4384cb5b7550', 'E_02d6db2f9577df', 'E_4ef1b1621b31bd', 'E_0f9abfb48426f7', 'E_87c09740e80459', 'E_c7f90af7befa90', 'E_f975bc5d88b02d', 'E_cba41070bb33c4', 'E_3470c668fdcd9d', 'E_fcfa0c0966486e'}
# point_of_interest: P_b5ab9566af2c2a
# preds: {'E_fcfa3085bafe59', 'E_b8c95300ba21b2', 'E_9259f7f438714c'}
# targets: {'E_128c016b7c4ff6', 'E_fcfa3085bafe59', 'E_0b7da0b25ceeb7', 'E_b8c95300ba21b2', 'E_9259f7f438714c'}
# point_of_interest: P_7fc62beef718c6
# preds: {'E_88c40688ab1b6c', 'E_6b07615690c2cf', 'E_b7a454a4b9cac8', 'E_fcfa6eb0dcf5d4'}
# targets: {'E_6b07615690c2cf', 'E_b7a454a4b9cac8', 'E_fcfa6eb0dcf5d4', 'E_88c40688ab1b6c', 'E_6929f6a30a5b30'}
# point_of_interest: P_ae25228573d3c6
# preds: {'E_fcfac1982fced0'}
# targets: {'E_5ddd73b580bb24', 'E_fcfac1982fced0'}
# point_of_interest: P_80c068c9691ba7
# preds: {'E_fcfafda10681df'}
# targets: {'E_e8720e909964fd', 'E_fcfafda10681df', 'E_36b1d588d0a34c'}
# point_of_interest: P_98a2bed3e89499
# preds: {'E_ec5605c5386c1b', 'E_fcfb0e70c60edd', 'E_c31a4d5b7a4198'}
# targets: {'E_ec5605c5386c1b', 'E_fcfb0e70c60edd', 'E_c31a4d5b7a4198', 'E_452ba65b447d69'}
# point_of_interest: P_53c02f3375bedb
# preds: {'E_79cc38dadb44f9', 'E_fcfbcb3eeaaaf8'}
# targets: {'E_79cc38dadb44f9', 'E_fcfbcb3eeaaaf8', 'E_251d3e11654f27'}
# point_of_interest: P_88d769c8500a63
# preds: {'E_fcfc6ed254ca7f'}
# targets: {'E_fcfc6ed254ca7f', 'E_c0bc49cd485137'}
# point_of_interest: P_d0e6b466537c07
# preds: {'E_fcfcaf2fac8cc3'}
# targets: {'E_d8b8214947149f', 'E_e52d2113fda381', 'E_514008af0e77a3', 'E_75470865d65510', 'E_fcfcaf2fac8cc3', 'E_b2cdac3f2a13cc', 'E_63199800e42b0b', 'E_a83d93657c2135'}
# point_of_interest: P_65ca1947c72259
# preds: {'E_fcfcc56b82eea7'}
# targets: {'E_f5ea3bcf4d95ae', 'E_fcfcc56b82eea7'}
# point_of_interest: P_ad1e3795d07741
# preds: {'E_fcfcc62e8841f3'}
# targets: {'E_ff1d3c723d22db', 'E_b2fbfcb0aa772b', 'E_ebcf9ac6db772e', 'E_4c0813c35dbc67', 'E_2ce7783d8de249', 'E_b5a176a2f42334', 'E_fcfcc62e8841f3', 'E_34f1b7acf790d0', 'E_47170c268dc652', 'E_d584b66512ad54', 'E_02859690862ec2', 'E_a608c0472dd03a', 'E_25b7be884af6e5', 'E_90728039312c4a'}
# point_of_interest: P_d53da5ae846a3b
# preds: {'E_d585e028cc06a3', 'E_fcfe030470139c', 'E_881f6de48181e4'}
# targets: {'E_d585e028cc06a3', 'E_881f6de48181e4', 'E_6ecb24a1feb271', 'E_fcfe030470139c'}
# point_of_interest: P_a287f2e3be6c3d
# preds: {'E_fcfe376f68342f'}
# targets: {'E_fcfe376f68342f', 'E_136956527b98c3'}
# point_of_interest: P_7ca5ff57e425df
# preds: {'E_fcfead6e8944d9'}
# targets: {'E_1cac3f0e1d367d', 'E_fcfead6e8944d9'}
# point_of_interest: P_051ee82a895806
# preds: {'E_02f647fdb56d8e', 'E_f4cd6be977b69f', 'E_b2d4b47d660f0e', 'E_4beaa456dc16fb', 'E_25c7066597a032', 'E_fd000fa2b08492', 'E_196c36ac299191', 'E_737d75f581d321'}
# targets: {'E_02f647fdb56d8e', 'E_02aec251854bf4', 'E_2ab264c7046057', 'E_4547ccaeefb8df', 'E_f4cd6be977b69f', 'E_b2d4b47d660f0e', 'E_4beaa456dc16fb', 'E_737d75f581d321', 'E_1cc9c5ddcd173b', 'E_84b487d2a774d1', 'E_961cf0d19d3c2c', 'E_320039872972b5', 'E_fd000fa2b08492', 'E_ed300093e3fb69', 'E_9739fb65297b92', 'E_cad4a3f35860e8', 'E_196c36ac299191', 'E_25c7066597a032'}
# point_of_interest: P_984583b15e8ae4
# preds: {'E_850fa29cbb608c', 'E_584e44d1d1160b', 'E_634fd3693d5d16', 'E_fd017b0eebd064'}
# targets: {'E_634fd3693d5d16', 'E_82a66d7063ea21', 'E_fd017b0eebd064', 'E_584e44d1d1160b', 'E_850fa29cbb608c'}
# point_of_interest: P_88548f05dd05e0
# preds: {'E_fd01b37b3c70cf'}
# targets: {'E_a3ab56a3047a30', 'E_fd01b37b3c70cf', 'E_4b80c463cb0c00', 'E_14e1c5976d37d5'}
# point_of_interest: P_9c71c373e32fc4
# preds: {'E_bbbebb25fca8fb', 'E_fd01b6060b0869'}
# targets: {'E_fd01b6060b0869', 'E_bbbebb25fca8fb', 'E_083e0619c7621e'}
# point_of_interest: P_7889ea7b10ecdc
# preds: {'E_92b7c4bf588f52', 'E_c248b4d74c634e', 'E_fd023ab1e75e29'}
# targets: {'E_cdc4bf5ad8f7f1', 'E_92b7c4bf588f52', 'E_c248b4d74c634e', 'E_fd023ab1e75e29'}
# point_of_interest: P_3d985046c00e10
# preds: {'E_fd0271fe05c962'}
# targets: {'E_35e21df9af4cac', 'E_fd0271fe05c962'}
# point_of_interest: P_a677f5d6c19e4c
# preds: {'E_fd02835bf33c1b', 'E_821807a649f116'}
# targets: {'E_02e4eebe1e6312', 'E_36861b93da5252', 'E_0be9f9566ce2d1', 'E_24b790502eb5dc', 'E_9fc23c23415c3d', 'E_fd02835bf33c1b', 'E_821807a649f116'}
# point_of_interest: P_dd33722465f737
# preds: {'E_fd0287319c60c3', 'E_9345e0d9c91eb0', 'E_0a7e9437763227'}
# targets: {'E_701549f4dd6b30', 'E_42bf2cc467899f', 'E_b6fd9634184dc5', 'E_fd0287319c60c3', 'E_0a7e9437763227', 'E_3973db2f0bd094', 'E_9345e0d9c91eb0', 'E_6f9a26e3dd6bfd'}
# point_of_interest: P_f074de45a6bda0
# preds: {'E_fd03105eaac685'}
# targets: {'E_fd03105eaac685', 'E_66108fc4e64ca8', 'E_75d5066f813322'}
# point_of_interest: P_588b46886c3761
# preds: {'E_fd0441d6e942b3'}
# targets: {'E_fd0441d6e942b3', 'E_26c6192b8ba207'}
# point_of_interest: P_7a821ea195b2bb
# preds: {'E_8aa14df8e40f06', 'E_fd0472a5150237'}
# targets: {'E_fd0472a5150237', 'E_4a55e093682b48', 'E_8aa14df8e40f06', 'E_cf5718936c8d9b'}
# point_of_interest: P_eabf4f3fa43d8e
# preds: {'E_bd9f3a492abdc1', 'E_29b4d0a7732fd0', 'E_fd04eff8e731cf'}
# targets: {'E_bd9f3a492abdc1', 'E_29b4d0a7732fd0', 'E_ef57e4826da6a3', 'E_fd04eff8e731cf'}
# point_of_interest: P_cb0d59a075970c
# preds: {'E_fd05305339176a'}
# ...
# preds: {'E_ffef033fdd2215'}
# targets: {'E_09284c74af94fa', 'E_ffef033fdd2215', 'E_1955aeefa085c8'}
# point_of_interest: P_077edfe27f12fa
# preds: {'E_ffef1186631782', 'E_098bbd04488463'}
# targets: {'E_7f7df37ca29f7d', 'E_ffef1186631782', 'E_098bbd04488463'}
# point_of_interest: P_4b739ce9c90689
# preds: {'E_60a188f00e91b2', 'E_baceed4201029f', 'E_f8e1fd79ce0944', 'E_be5188c06e3e66', 'E_fff0686373f911', 'E_7da5adbc889734', 'E_8309c5766613cf'}
# targets: {'E_60a188f00e91b2', 'E_baceed4201029f', 'E_f8e1fd79ce0944', 'E_be5188c06e3e66', 'E_ffc48172d51f16', 'E_fff0686373f911', 'E_68911ddb2cab12', 'E_7da5adbc889734', 'E_bc1f3c57ee0511', 'E_8309c5766613cf'}
# point_of_interest: P_455e8b62ca4f5a
# preds: {'E_31dfd99e4cf565', 'E_2a58a1b968419d', 'E_8015d24e901473', 'E_c88b079b174d14', 'E_fff07e4897e36e', 'E_93e588933cf51d', 'E_e1398a003edb62', 'E_be82e3aeb23edb', 'E_164a39648823e8', 'E_84ed7cb3e3782e', 'E_27746db2599e7e', 'E_cec171e8565bca', 'E_1f1418c85e5208'}
# targets: {'E_2a58a1b968419d', 'E_84ed7cb3e3782e', 'E_c88b079b174d14', 'E_fff07e4897e36e', 'E_93e588933cf51d', 'E_e1398a003edb62', 'E_be82e3aeb23edb', 'E_1651debc73c571', 'E_f33195a7b1e255', 'E_164a39648823e8', 'E_cec171e8565bca', 'E_8015d24e901473', 'E_27746db2599e7e', 'E_31dfd99e4cf565', 'E_1f1418c85e5208'}
# point_of_interest: P_bd887fbc13ac54
# preds: {'E_99e05910762091', 'E_538ebc482cd5d8', 'E_94f3d3df8a9528', 'E_fff084dced1f09', 'E_9a564349fa6881', 'E_2b80b1eacd3291', 'E_a2ed3a1044c4f5', 'E_98c81f24be1470'}
# targets: {'E_99e05910762091', 'E_538ebc482cd5d8', 'E_94f3d3df8a9528', 'E_d7b7f6a89dcaaf', 'E_fff084dced1f09', 'E_9a564349fa6881', 'E_2b80b1eacd3291', 'E_af65698ef49dfc', 'E_2e5e606031ef06', 'E_a2ed3a1044c4f5', 'E_98c81f24be1470', 'E_543ac8c2066f2a', 'E_f41eb2d5194c22', 'E_a870bb23cb3df3'}
# point_of_interest: P_5510cf5bb797e3
# preds: {'E_a0e2d5b5172ed3', 'E_a514ded7a1697c', 'E_a0bbb87321e9e0', 'E_6f92823c034a93', 'E_fff168ca975c01', 'E_30c25db9c7f4b3'}
# targets: {'E_a0e2d5b5172ed3', 'E_a514ded7a1697c', 'E_a0bbb87321e9e0', 'E_6f92823c034a93', 'E_e2b367fddf04bf', 'E_43665738c74031', 'E_fff168ca975c01', 'E_30c25db9c7f4b3'}
# point_of_interest: P_bda21437f64eb6
# preds: {'E_6830347bfd7280', 'E_fff1b1dd4d8883', 'E_26a34403fce0f5', 'E_a548922b549a81', 'E_65db18d9f6eb30', 'E_82fd05ee7efa00', 'E_f22e0da1d97e0f', 'E_d5bb45fc42fdde'}
# targets: {'E_6830347bfd7280', 'E_fff1b1dd4d8883', 'E_26a34403fce0f5', 'E_850a256d3f5d13', 'E_a548922b549a81', 'E_65db18d9f6eb30', 'E_82fd05ee7efa00', 'E_ec481101ef4297', 'E_f22e0da1d97e0f', 'E_0a4a05ef60e434', 'E_3e9eb656adfba1', 'E_d5bb45fc42fdde', 'E_91f1942b9a4144'}
# point_of_interest: P_346b237d61cd5c
# preds: {'E_fff1eac4917e2f'}
# targets: {'E_2740338cb4bac5', 'E_fff1eac4917e2f'}
# point_of_interest: P_c39b5c766497d0
# preds: {'E_fff27edaf455ae'}
# targets: {'E_fff27edaf455ae', 'E_a21e2fa389cd7a'}
# point_of_interest: P_c4291acb6061c9
# preds: {'E_defb0c87e0e8f1', 'E_bb94da5af8de80', 'E_fff33cdd288e2c', 'E_da9ebf0b71ae9e', 'E_36296aaf40eb69', 'E_7b0acc9e55515d', 'E_e563a9b2f88065', 'E_7d43f65f541c80', 'E_651155a119dc78', 'E_1ae31b7a544b54'}
# targets: {'E_defb0c87e0e8f1', 'E_bb94da5af8de80', 'E_fff33cdd288e2c', 'E_144046d1c111aa', 'E_da9ebf0b71ae9e', 'E_36296aaf40eb69', 'E_7b0acc9e55515d', 'E_e563a9b2f88065', 'E_7d43f65f541c80', 'E_651155a119dc78', 'E_1ae31b7a544b54'}
# point_of_interest: P_7f75f291dfcae8
# preds: {'E_fff35a21c59588'}
# targets: {'E_fff35a21c59588', 'E_c1c5e6b105e3bc'}
# point_of_interest: P_41fad6a9473c69
# preds: {'E_fff39c4a604330'}
# targets: {'E_a9ed8bb6ce6106', 'E_fff39c4a604330'}
# point_of_interest: P_7fc384bf991009
# preds: {'E_fff3f40a762e93'}
# targets: {'E_94379a705e5143', 'E_4eb9a9ecfc8cc8', 'E_ef7103b8d78e40', 'E_469b88d09124ec', 'E_e55dff9c1b1a54', 'E_d8b9072b84d939', 'E_c72cbd53b65012', 'E_0870969c2a1b6a', 'E_95134d7b1f75ba', 'E_62222b0e1c13fa', 'E_8d50dcaeac54c1', 'E_38698a5579e504', 'E_9def7e6622aff9', 'E_bedb87cd827a8b', 'E_f336a60ceca48a', 'E_ffe8c72a51f9c6', 'E_6009e2a82c00ca', 'E_f43a547c2bf278', 'E_de86a86735fb6d', 'E_e0ca03194ccffb', 'E_2dcb5b985819b4', 'E_8cb7549de2a7ff', 'E_0ff39c27b373f2', 'E_02761e40f68230', 'E_0ff1a279a14a0f', 'E_f6c73a9b378bab', 'E_7a97df0189d838', 'E_e4707d5fe73c96', 'E_c6c0db2d9485da', 'E_a61e7727e4c47b', 'E_c5b233c31b5b11', 'E_1fee0ba9ef9772', 'E_54455ed849627c', 'E_42250fcb04266c', 'E_80ee19ca1a1d2a', 'E_dfaf5f0b5ca510', 'E_50826410cedcf5', 'E_4d90c2ac0fdbbd', 'E_c82a952258ca44', 'E_9afb683ae9c42d', 'E_813f15ff086eea', 'E_c012349ce1d098', 'E_1967ffa1c92d7d', 'E_90958502ddf574', 'E_b88be0c865c715', 'E_759283f776859c', 'E_85c1c4a86d07ac', 'E_c3b0a81f7dcebc', 'E_80191e9690ae4d', 'E_e76f85ed8f35fc', 'E_9909b6725039f8', 'E_0ec9254b228d91', 'E_631b03c5da16d9', 'E_6b09ea55b6cce2', 'E_23d3c7e4117a18', 'E_e43c2dfc8c59cb', 'E_75dd68f89e611f', 'E_351afd081caaca', 'E_1387ed99e9ce8e', 'E_3919c782eed08c', 'E_9f24e2fbcf2bd8', 'E_4f6b56e4b7de98', 'E_cdf1c07db03007', 'E_d6f70b3c0af2f7', 'E_112935613c0fe6', 'E_6745b7ef2d4036', 'E_55a5491b9969d9', 'E_2ace04975dad08', 'E_836817aec832d6', 'E_f2929554eec961', 'E_e971a894f5a94a', 'E_b8334ac91bbf00', 'E_2e29c9c9fa4622', 'E_1f45847efea3e5', 'E_72834ea099fa85', 'E_824f097568d33d', 'E_d16734d8b6ed38', 'E_f127bc8fcc9a60', 'E_648719d7f10d7e', 'E_a03f46663d15a6', 'E_3c61203f76d8e6', 'E_3938de6cbda8ca', 'E_af908d0eec6a19', 'E_a04071b93d451e', 'E_2edcb9bc5e6252', 'E_9ff1b72865099e', 'E_34efdc0811bcda', 'E_d06f04df5862ab', 'E_0eb7483e7563be', 'E_22ebf019b96ce1', 'E_220731ef18aa2b', 'E_c5718ff5345ab7', 'E_d3c83a7d32211d', 'E_ee475a84e88c26', 'E_c0767d1b87cfa6', 'E_acf39c38433c0e', 'E_8ac726b963c6d5', 'E_ca4e974daebde7', 'E_d4912a13853779', 'E_9854239e1edccb', 'E_3e2813d69a8c59', 'E_7e37451e479da4', 'E_1f8472e776298d', 'E_9f1603ea1e92bb', 'E_c4090a83e97b73', 'E_0fa9246c3bebcb', 'E_7a53ac861de8a2', 'E_5365a77191a928', 'E_62f9235b937698', 'E_e39ee996aa8d12', 'E_46293cf1df101f', 'E_2972bc662f0831', 'E_a72ad6078cfe59', 'E_04c39deab3aba2', 'E_07f58814417602', 'E_9e8dba4d449678', 'E_283d0adc360078', 'E_046132a06d8bc5', 'E_0fc82270e70bf3', 'E_5f1899f44a7c86', 'E_19c2a0c71f183d', 'E_62433d49b17303', 'E_29f7cf3af5170b', 'E_59055483770086', 'E_be041b6f3871fa', 'E_7775dd642dcc30', 'E_4d9a4e1a8bcd38', 'E_229b69a945928d', 'E_eecbea7afd4a51', 'E_745012fb2341d0', 'E_8d896a44f7e9f5', 'E_6162726cc21f7f', 'E_2202b119f83988', 'E_e773e0b06aff87', 'E_73874b2cdd4d92', 'E_60d8a84257cf63', 'E_6730382afd40c7', 'E_414f7880fbfcc8', 'E_8260fbe8c93237', 'E_f161de57b49b0c', 'E_f7bf39282f3ac2', 'E_9018114f979de9', 'E_88a9e9044743bb', 'E_0bea717f95598d', 'E_a21ac79b27e67f', 'E_73643b4e9192a6', 'E_99cd0807addab6', 'E_cf456fca5d811b', 'E_fbfa341173cef3', 'E_ce0796a22e7431', 'E_9afb7e0f12c543', 'E_a212368ad314e5', 'E_8b0c48bb236b24', 'E_583807772277c9', 'E_e80d060c1536bd', 'E_8f19392e1702c5', 'E_f68bf00215f313', 'E_dd60a994b06437', 'E_6fd2b312eb7d2f', 'E_d72dd3688bf5d9', 'E_072ee0f2f2d57b', 'E_f67974531d123e', 'E_81c1ce4f402780', 'E_e363c38d88f33c', 'E_064c0b1349b6bc', 'E_db9177b0745d11', 'E_8f74678428e747', 'E_cd810f976c37d1', 'E_cdcf89fbc20b3b', 'E_492682b489c5c5', 'E_ab0681b7651abb', 'E_f0ad84e1e13837', 'E_c32833701814e1', 'E_05bd0fb0583a00', 'E_0c1da0c43edac4', 'E_19929ac288e12c', 'E_0ad700c8278a40', 'E_e2b5b47143a5f3', 'E_04d15c990bfd9e', 'E_5c0b1edbffefa1', 'E_1da10bd0569205', 'E_76eb204fa2a49f', 'E_91c69e0866c171', 'E_76b7416d2c897a', 'E_cfbdf3a7e88e93', 'E_568073f005d825', 'E_61bbdb554a2c6b', 'E_1e594d5dd8ad5d', 'E_87c385365c7bfe', 'E_9ef2a538f6cb05', 'E_9da4babb2dc98a', 'E_59d0031512fc4d', 'E_1c359ed6eaf0da', 'E_4a0fa512b78444', 'E_f53c7bed857753', 'E_b24a4a582eb499', 'E_400ff1d74561fe', 'E_5ab963c9aa78d6', 'E_6b5b65fed6c5c4', 'E_62137c8 ...
# point_of_interest: P_fb339198a31db3
# preds: {'E_cd0d4f078ba9a6', 'E_fff406b7128e76'}
# targets: {'E_cd0d4f078ba9a6', 'E_fa99078086e7c8', 'E_fff406b7128e76'}
# point_of_interest: P_df0f6b0d356fa5
# preds: {'E_fff502210b5083'}
# targets: {'E_139baa75f173f7', 'E_fff502210b5083'}
# point_of_interest: P_46a490191d5111
# preds: {'E_fff610e05c669a'}
# targets: {'E_236a8d942ba98d', 'E_2235fd2b8e3b33', 'E_55f8dc7c352fdf', 'E_efeb98b3a2e6a3', 'E_fff610e05c669a', 'E_ecc220d607b8c4', 'E_e266beee62653f', 'E_c2f81a76a332c7', 'E_4bfc30e59e5c1e', 'E_05bcefa943af5c', 'E_1ea74a22184a46'}
# point_of_interest: P_397aee87a200fe
# preds: {'E_fc74b56d737ae3', 'E_fff66bd98231ac'}
# targets: {'E_24726948012455', 'E_0825d0574b6014', 'E_fff66bd98231ac', 'E_f2440c8e92b0b2', 'E_fc74b56d737ae3', 'E_25016b93248671', 'E_86b07a1eb702c2'}
# point_of_interest: P_81ef009ce81cfb
# preds: {'E_036e02d50e8899', 'E_fff7871b89de63', 'E_8253bf51d7daa9', 'E_7bf3410dcdbe1d'}
# targets: {'E_e9ff9cf67cdb82', 'E_3d780b7f217827', 'E_267313446db841', 'E_831aef2dde91a5', 'E_7cb4171bb1b0fe', 'E_c0943ca8325026', 'E_0bcb3476e71761', 'E_8ab60acfb8d5e5', 'E_bf8b0e418fe79d', 'E_c4f534be7597e9', 'E_8253bf51d7daa9', 'E_b368a03176b5e9', 'E_3b95404237bfd8', 'E_2ab6204de9f88c', 'E_ab5e2bdab03a73', 'E_e9863ee18f0f24', 'E_4fdb47a714f128', 'E_3fd2db0d62a021', 'E_b4470520f18bfd', 'E_01cb94c87ecb16', 'E_65895c944e1825', 'E_d744da9e72f128', 'E_c4c3c7e3abf37a', 'E_3c776c4dca047b', 'E_b6bcd0abdc59bb', 'E_499d70f0ea4673', 'E_7042ec353dda3a', 'E_7bf3410dcdbe1d', 'E_94cf05f3655112', 'E_b0ac23d30e5d29', 'E_869709fc0feefb', 'E_036e02d50e8899', 'E_28fbfb3405b2ab', 'E_04eec92d750e17', 'E_ba2bcf588f2f31', 'E_49d41a451f1357', 'E_42a8d4f5cd3c5d', 'E_35b09125341428', 'E_860a08f5a9fa1d', 'E_fff7871b89de63', 'E_b08459c6156232', 'E_7d657f045e762f', 'E_363e7549520807', 'E_ad529e21e5cf87', 'E_cf1ff302c49aa6', 'E_e28fed36384998', 'E_cb7a01ce2648c8'}
# point_of_interest: P_613812d1d196e5
# preds: {'E_fff79504c2f5a0'}
# targets: {'E_fff79504c2f5a0', 'E_9821e7d25f3259'}
# point_of_interest: P_4d34884ebb3d1e
# preds: {'E_fa9cc3e00627b4', 'E_fff7e3b47c8884', 'E_0c4ceb74236407'}
# targets: {'E_fa9cc3e00627b4', 'E_a7147a419efd7a', 'E_59e3459983ddc4', 'E_0c4ceb74236407', 'E_9bb3a2c55a2788', 'E_207b463915525b', 'E_fff7e3b47c8884'}
# point_of_interest: P_ae7e9ca82eb46b
# preds: {'E_a0b65b50fe2d13', 'E_f010fc2ff286c7', 'E_9780a5641a5e01', 'E_fff7ef9e2bf8b5'}
# targets: {'E_e78f939b1c5997', 'E_97c8e51887e1c8', 'E_ca7831a1152340', 'E_125160d22f1d40', 'E_739c156b99ee41', 'E_e5fa79ead3ca4a', 'E_7d48a5dfb0108a', 'E_f6cd8c78e9f571', 'E_9349688d0bbdcc', 'E_9780a5641a5e01', 'E_44f84684680307', 'E_2e04e39fa6eae6', 'E_822eeb37a531a6', 'E_07c8f23eeef5ef', 'E_867e13e14bd14f', 'E_a0b65b50fe2d13', 'E_e147fafea289b5', 'E_68ffe417725fb0', 'E_fff7ef9e2bf8b5', 'E_128e39e59cb703', 'E_d44a1fed814160', 'E_f010fc2ff286c7', 'E_329d43a18af3e2', 'E_04d37344e3b493', 'E_33c0e5d8b73e59', 'E_f99ff3be42b85a', 'E_84c725f04d148d', 'E_e5e3dbb0aca13a', 'E_f240f7b075cb66', 'E_05492dbf35e9df', 'E_c370450e26f8da', 'E_02bb6365f7219d'}
# point_of_interest: P_65769c7e8a4d68
# preds: {'E_ac5c79012d0a6e', 'E_fff8dc2f9f231e', 'E_6147ccc1654631'}
# targets: {'E_ac5c79012d0a6e', 'E_975352f338b43a', 'E_3444740b764be0', 'E_9966dc85cc9a72', 'E_fff8dc2f9f231e', 'E_6147ccc1654631'}
# point_of_interest: P_88e9f5ceb3ef63
# preds: {'E_fff91a35d8450e'}
# targets: {'E_8c4d3eae70b0b6', 'E_4fba5535dd4663', 'E_2687d57ff5d8f8', 'E_f34992fee0fea1', 'E_fff91a35d8450e', 'E_545253fae23ac0', 'E_18e6d22f5814d7', 'E_c1b46643951edb', 'E_6a6af6657da169', 'E_379cdc6ac34f61'}
# point_of_interest: P_f9d0383fcd3375
# preds: {'E_fff970fefa5030'}
# targets: {'E_5596f8e6b79a0a', 'E_946af2da40ad33', 'E_fff970fefa5030'}
# point_of_interest: P_86211a487b8d36
# preds: {'E_fff9ecf69690da', 'E_5a051b204b6f1f', 'E_393d42bc0cdbce'}
# targets: {'E_fff9ecf69690da', 'E_5a051b204b6f1f', 'E_393d42bc0cdbce', 'E_f9f321bbd92810'}
# point_of_interest: P_0d8cb65f0aabef
# preds: {'E_d27ee7afd3dfcf', 'E_12d46bdd9a48cd', 'E_fff9fde4bb588b', 'E_86dc8f86a37524', 'E_110abe3244b781', 'E_7949f9fccece0d', 'E_dc58a9627ef81d', 'E_9ca4c40f5c4bfb', 'E_7fa50a9b5c716a', 'E_4582cbe6311784', 'E_3d702be64bc520', 'E_7a3605ad09873c', 'E_9d5569bb9c912c', 'E_7a5a4643a1793c', 'E_ccbdaf4bd611ea', 'E_61c368ebed2929', 'E_ad36723ad3919f'}
# targets: {'E_85fd3226ebf730', 'E_7fa50a9b5c716a', 'E_9ca4c40f5c4bfb', 'E_1a1004d18455f1', 'E_4582cbe6311784', 'E_ad36723ad3919f', 'E_0bd232628aed2c', 'E_12d46bdd9a48cd', 'E_fff9fde4bb588b', 'E_3d702be64bc520', 'E_ccbdaf4bd611ea', 'E_d27ee7afd3dfcf', 'E_86dc8f86a37524', 'E_d487f94d32e0db', 'E_7949f9fccece0d', 'E_7a5a4643a1793c', 'E_61c368ebed2929', 'E_ba275df384e4db', 'E_110abe3244b781', 'E_dc58a9627ef81d', 'E_7a3605ad09873c', 'E_9d5569bb9c912c', 'E_a14b58bb276fa1', 'E_59cfad2bb4c3cf', 'E_7ab09afb1e3417'}
# point_of_interest: P_1e8e17b542e178
# preds: {'E_fffa45025c612f'}
# targets: {'E_1b0dca65a7d8cb', 'E_47134eec37ad3e', 'E_fffa45025c612f'}
# point_of_interest: P_cee99f2efdd9ca
# preds: {'E_fffa63a008cbcd'}
# targets: {'E_623477839dbabb', 'E_fffa63a008cbcd'}
# point_of_interest: P_037468d7274565
# preds: {'E_1b1219771c2043', 'E_21fa073ae384f9', 'E_a0156de39267f8', 'E_fffac30c476d81', 'E_1f3d42adcfe5e5', 'E_c83769ec3d4042'}
# targets: {'E_1b1219771c2043', 'E_31cdd83e28c26d', 'E_21fa073ae384f9', 'E_37575e96587df4', 'E_c7e67ae2fa2506', 'E_e1ef13dbe6dace', 'E_050e27e0d8730d', 'E_0568da68fa916c', 'E_1bce18a92a7d97', 'E_a0156de39267f8', 'E_fffac30c476d81', 'E_1f3d42adcfe5e5', 'E_bc1c284402464f', 'E_c83769ec3d4042', 'E_f40e1a9c047527', 'E_0bf85126c569c7', 'E_ef3fd6555ddfc0'}
# point_of_interest: P_4de520740c4ca4
# preds: {'E_fffc623025d9c7'}
# targets: {'E_fffc623025d9c7', 'E_dacc3109c8f9af'}
# point_of_interest: P_a18d59ed8d1b60
# preds: {'E_fffc94cbf08007'}
# targets: {'E_fffc94cbf08007', 'E_c6ae0edb8f697e'}
# point_of_interest: P_ac9cca68dcce06
# preds: {'E_fffde923648247'}
# targets: {'E_fffde923648247', 'E_c05167aac5b3f5'}
# point_of_interest: P_e416fda64302f1
# preds: {'E_fffe6d258fd605', 'E_e1b2397966e6e7'}
# targets: {'E_fffe6d258fd605', 'E_59b459e448fce1', 'E_e1b2397966e6e7'}
# point_of_interest: P_7e9de22212d02c
# preds: {'E_959fea1a5ee646', 'E_591d9bc7dbdb0e', 'E_799e6abd807731', 'E_c9ff41f8d5f343', 'E_fffe9cbe5a2c75'}
# targets: {'E_f54890d9f4cec8', 'E_959fea1a5ee646', 'E_591d9bc7dbdb0e', 'E_799e6abd807731', 'E_64aacc7e5a2801', 'E_c9ff41f8d5f343', 'E_fffe9cbe5a2c75'}
# point_of_interest: P_97e04d9412237c
# preds: {'E_c5e2c92a64ad20', 'E_fffebfdf9be4cc'}
# targets: {'E_c5e2c92a64ad20', 'E_fffebfdf9be4cc', 'E_380d545ca08021'}
# point_of_interest: P_9d295f9b619c61
# preds: {'E_ffff83a9496324'}
# targets: {'E_c7618699344378', 'E_ffff83a9496324', 'E_73c8800d7ca936'}
# point_of_interest: P_a630bf50670209
# preds: {'E_ffffb80854f713', 'E_008558a7c44ed5'}
# targets: {'E_ffffb80854f713', 'E_a05914fd828a1c', 'E_008558a7c44ed5', 'E_f5d055893ef064'}
# point_of_interest: P_7ccbeab96cd82e
# preds: {'E_27bcc6f6dd33ed', 'E_ffffc572b4d35b', 'E_8081185a219dc3'}
# targets: {'E_2f2d2cddc9bceb', 'E_2c023b9995f3ed', 'E_715f3cdecb5a9c', 'E_97e209b71d9e2b', 'E_a690401ef32775', 'E_55a3173dcf0afb', 'E_ccce01d35e4bb9', 'E_dd87f47ac061f9', 'E_fb46d2ef0aa83c', 'E_3c6ce34400830b', 'E_3d11785a5c17b3', 'E_41ba0ec3d20a87', 'E_42e65609de0b83', 'E_d03b08a4b4c643', 'E_228816bf35c635', 'E_6cdee403ae037a', 'E_140d67717e2d94', 'E_17a9c780152c95', 'E_164ddb739d3a0a', 'E_195a9c71600fd5', 'E_7eff49983c6aae', 'E_1ab928c3b6ff8f', 'E_a3f5efa32b61e4', 'E_daec4fe0f67a32', 'E_6781d6dc30517e', 'E_daf7f534cb27fb', 'E_dba0f10d7e8ee2', 'E_ffffc572b4d35b', 'E_aeb56cd1562100', 'E_68f7241cf74ab6', 'E_4113d3e1cfad18', 'E_6e74746d07af54', 'E_8bb4b3ee0c2545', 'E_8081185a219dc3', 'E_27e9a292b8d5c5', 'E_89c96ef9598397', 'E_e30d2199f33e14', 'E_82dba89a0b1625', 'E_27bcc6f6dd33ed', 'E_317ab5c540ee7b', 'E_04074a25e0158f', 'E_262de0dd9121c8', 'E_00911dfe3e73c9', 'E_2594bb48e53f02', 'E_613b3e931eed56', 'E_8a1a1ee359b513', 'E_9b8960c3ca6ce7', 'E_6291bd32843b71', 'E_22173232a724f4', 'E_95e47258c151ac', 'E_9789223349d203', 'E_a357fea47f42c6', 'E_fab1e94cd3c3ee', 'E_67ce70f92a4648', 'E_3d03c9cc82a5ce', 'E_5ce7fc40a0736a', 'E_773e4716304a03', 'E_21f8bccd2c4b6a', 'E_cf11032bd3e80c', 'E_771a8749f5e13a', 'E_ecb38b2d992261', 'E_c3e000daf39030', 'E_46a062dcbe4086', 'E_ab5647083ae7bc', 'E_44b416dbe8d3bf', 'E_4d4539c08587f1', 'E_83a78a20004360', 'E_ed824ef794fd8d', 'E_7bc9754f88e61e', 'E_e119eafad69c11', 'E_60671d056a2f42', 'E_9a5e5d5a74c443', 'E_9dbe99342afc03', 'E_b7a5768590c1cc', 'E_f6784c3ad5cf36'}
# point_of_interest: P_ae96252a6a9380

# %%
e_id = 'E_0000764d65557e'
poi = 'P_be89c778befb23'

# %%
data[data[TARGET]==poi]
# Out:
#                                   name  latitude   longitude  \
# id
# E_0000764d65557e            mcdonald s -7.265894  112.749382
# E_0507e10f6eb526            mcdonald s -7.265468  112.748612
# E_30424388e6852c       mcd delta plaza -7.265279  112.748338
# E_7da6445404a886  mcdonald delta plaza -7.279387  112.759431
# E_f4b00a6db8b587      mc d delta plaza -7.264304  112.749496
#
#                                           address      city       state  \
# id
# E_0000764d65557e  Plaza Surabaya  Pemuda Building
# E_0507e10f6eb526            Plaza Surabaya  Lt  1  Surabaya  Jawa Timur
# E_30424388e6852c
# E_7da6445404a886
# E_f4b00a6db8b587
#
#                     zip country                         url      phone  ...  \
# id                                                                      ...
# E_0000764d65557e    NaN      ID                         NaN        NaN  ...
# E_0507e10f6eb526  60271      ID  http://www.mcdonalds.co.id  315450509  ...
# E_30424388e6852c    NaN      ID                         NaN        NaN  ...
# E_7da6445404a886    NaN      ID                         NaN        NaN  ...
# E_f4b00a6db8b587    NaN      ID                         NaN        NaN  ...
#
#                     state_split   cv co_net          main_category scale  \
# id
# E_0000764d65557e             []  0.0    0.0  Fast Food Restaurants     0
# E_0507e10f6eb526  [Jawa, Timur]  0.0    0.0  Fast Food Restaurants     0
# E_30424388e6852c             []  0.0    0.0   American Restaurants     0
# E_7da6445404a886             []  0.0    NaN                    NaN    -1
# E_f4b00a6db8b587             []  0.0    0.0  Fast Food Restaurants     0
#
#                  adjacency_frequency  betweeness_centrality  \
# id
# E_0000764d65557e                 5.0               0.003875
# E_0507e10f6eb526                 5.0               0.003875
# E_30424388e6852c                 7.0               0.027375
# E_7da6445404a886                 NaN                    NaN
# E_f4b00a6db8b587                 5.0               0.003875
#
#                   clustering_coefficient median_distances_median  \
# id
# E_0000764d65557e                0.300000             6354.897123
# E_0507e10f6eb526                0.300000             6354.897123
# E_30424388e6852c                0.190476             6815.049017
# E_7da6445404a886                     NaN                     NaN
# E_f4b00a6db8b587                0.300000             6354.897123
#
#                   category_rate
# id
# E_0000764d65557e       0.015049
# E_0507e10f6eb526       0.015049
# E_30424388e6852c       0.008548
# E_7da6445404a886            NaN
# E_f4b00a6db8b587       0.015049
#
# [5 rows x 25 columns]

# %%
train[train['id']==e_id]
# Out:
#                  id          match_id     kdist  kneighbors  name_iou  \
# 7  E_0000764d65557e  E_0000764d65557e  0.000000           0       1.0
# 7  E_0000764d65557e  E_47dfd60969c589  0.000478           1       0.0
# 7  E_0000764d65557e  E_0bc47bcb7d588e  0.000514           2       0.0
# 7  E_0000764d65557e  E_0507e10f6eb526  0.000880           8       1.0
# 7  E_0000764d65557e  E_c3297d51132b3f  0.001462          20       0.0
# 7  E_0000764d65557e  E_f4b00a6db8b587  0.001594          22       0.0
# 7  E_0000764d65557e  E_98cbf3929e673c  0.001926          33       0.0
# 7  E_0000764d65557e  E_4fc971dfaefd59  0.003169          60       0.0
# 7  E_0000764d65557e  E_8ea8718b17229d  0.003492          71       0.0
# 7  E_0000764d65557e  E_c269bd2cbf5d6d  0.003865          84       0.0
#
#    cat_similarity  name_rank  cv  co_net  match_co_net  ...  \
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    0.000000e+00       11.0   0     0.0           NaN  ...
# 7    0.000000e+00       13.0   0     0.0           0.0  ...
# 7    1.000000e+00        1.0   0     0.0           0.0  ...
# 7    1.000000e+00        5.0   0     0.0           0.0  ...
# 7    1.000000e+00        5.0   0     0.0           0.0  ...
# 7    1.800000e-02        4.0   0     0.0           0.0  ...
# 7    1.000000e+00       10.0   0     0.0           0.0  ...
# 7    1.000000e-09        3.0   0     0.0           NaN  ...
# 7    1.800000e-02        2.0   0     0.0           0.0  ...
#
#    clustering_coefficient  match_clustering_coefficient  \
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.000000
# 7                     0.3                      0.300000
# 7                     0.3                      0.190476
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.300000
# 7                     0.3                           NaN
# 7                     0.3                      0.136364
#
#    mean_clustering_coefficient  median_distances_median  \
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.150000              6354.897123
# 7                     0.300000              6354.897123
# 7                     0.245238              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.300000              6354.897123
# 7                          NaN              6354.897123
# 7                     0.218182              6354.897123
#
#    match_median_distances_median  mean_median_distances_median  category_rate  \
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3226.275791                   4790.586457       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    6815.049017                   6584.973070       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                    3200.938525                   4777.917824       0.015049
# 7                    6354.897123                   6354.897123       0.015049
# 7                            NaN                           NaN       0.015049
# 7                    3307.259945                   4831.078534       0.015049
#
#    match_category_rate  mean_category_rate  label
# 7             0.015049            0.015049      1
# 7                  NaN                 NaN      0
# 7             0.002269            0.008659      0
# 7             0.015049            0.015049      1
# 7             0.008548            0.011799      0
# 7             0.015049            0.015049      1
# 7             0.005019            0.010034      0
# 7             0.015049            0.015049      0
# 7                  NaN                 NaN      0
# 7             0.026689            0.020869      0
#
# [10 rows x 30 columns]

# %%
# data2 = data.copy()
# data2.reset_index(drop=False, inplace=True)
# tmp = train[train.id==e_id]
# # tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], on='id', how='left')
# tmp = tmp.merge(data2[['id', 'latitude', 'longitude', 'name', 'categories']], left_on='match_id', right_on='id', how='left')
# del data2

# tmp

# %% [markdown]
# # Make Features

# %% [markdown]
# ## TF-IDF

# %%
if TFIDF:
    vec_columns = ['name', 'categories', 'address', 'state', 'url', 'country']

    tfidf_d = {}
    for col in vec_columns:
        tfidf = TfidfVectorizer()
        tv_fit = tfidf.fit_transform(data[col].fillna('nan'))
        tfidf_d[col] = tv_fit

# %% [markdown]
# ## NLP

# %%
# %load_ext Cython

# %%
# %%cython
# def LCS(str S, str T):
#     cdef int i, j
#     cdef list dp = [[0] * (len(T) + 1) for _ in range(len(S) + 1)]
#     for i in range(len(S)):
#         for j in range(len(T)):
#             dp[i + 1][j + 1] = max(dp[i][j] + (S[i] == T[j]), dp[i + 1][j], dp[i][j + 1], dp[i + 1][j + 1])
#     return dp[len(S)][len(T)]

# %%
str_columns = ['url', 'name', 'address', 'city', 'state', 'zip', 'categories', 'phone',  'country']
# data['city_state'] = data['city'].fillna('') + data['state'].fillna('')
# data['all'] = data['name'] + data['address'].fillna('') + data['city'].fillna('') + data['state'].fillna('')
# str_columns += ['city_state', 'all']

# if COM > 0:
#     co_columns = ['main_category', 'adjacency_frequency', 'betweeness_centrality', 'clustering_coefficient', 'co_net']

# def intersection(s, match_s):
#     return len(set(s.split(' ')) & set(match_s.split(' ')))

# %%
# %%time

# def sm_ratio(x):
#     return SequenceMatcher(None, x[0], x[1]).ratio()

# def levens_dist(x):
#     return Levenshtein.distance(x[0], x[1])

# def calc_jaro_winkler(x):
#     return Levenshtein.jaro_winkler(x[0], x[1])

# def calc_LCS(x):
#     return LCS(str(x[0]), str(x[1]))

def add_features(df):
    for col in tqdm(str_columns):
        before_cols = df.columns
        if TFIDF and col in vec_columns:
            tv_fit = tfidf_d[col]
            indexs = [id2index_d[i] for i in df['id']]
            match_indexs = [id2index_d[i] for i in df['match_id']]                    
            df[f'{col}_tfidf_sim'] = tv_fit[indexs].multiply(tv_fit[match_indexs]).sum(axis = 1).A.ravel()
            df[f'{col}_tfidf_diff'] = (tv_fit[indexs] - tv_fit[match_indexs]).sum(axis = 1).A.ravel()
        
        col_values = data.loc[df['id']][col].values.astype(str)
        matcol_values = data.loc[df['match_id']][col].values.astype(str)
        
#         arrs = np.array([col_values, matcol_values])
#         df[f'{col}_gesh'] = np.apply_along_axis(sm_ratio, 0, arrs)
#         df[f'{col}_leven'] = np.apply_along_axis(levens_dist, 0, arrs)
#         df[f'{col}_jaro'] = np.apply_along_axis(calc_jaro_winkler, 0, arrs)
#         df[f'{col}_lcs'] = np.apply_along_axis(calc_LCS, 0, arrs)
#         del arrs
        
        geshs = []
        levens = []
        jaros = []
        lcss = []
#         intersections = []
        for s, match_s in zip(col_values, matcol_values):
            if s != 'nan' and match_s != 'nan':                    
                geshs.append(SequenceMatcher(None, s, match_s).ratio())
                levens.append(Levenshtein.distance(s, match_s))
                jaros.append(Levenshtein.jaro_winkler(s, match_s))
                lcss.append(LCS(str(s), str(match_s)))
#                 intersections.append(intersection(str(s), str(match_s)))
            elif s != 'nan' and match_s != 'nan':
                geshs.append(-1)
                levens.append(-1)
                jaros.append(-1)
                lcss.append(-1)
#                 intersections.append(-1)
            else:
                geshs.append(np.nan)
                levens.append(np.nan)
                jaros.append(np.nan)
                lcss.append(np.nan)
#                 intersections.append(np.nan)
        
        df[f'{col}_gesh'] = geshs
        df[f'{col}_leven'] = levens
        df[f'{col}_jaro'] = jaros
        df[f'{col}_lcs'] = lcss
#         df[f'{col}_intersections'] = intersections
        
        
        if col not in ['phone', 'zip']:
            df[f'{col}_len'] = list(map(len, col_values))
            df[f'match_{col}_len'] = list(map(len, matcol_values)) 
            df[f'{col}_len_diff'] = np.abs(df[f'{col}_len'] - df[f'match_{col}_len'])
            df[f'{col}_nleven'] = df[f'{col}_leven'] / \
                                    df[[f'{col}_len', f'match_{col}_len']].max(axis = 1)
            
            df[f'{col}_nlcsk'] = df[f'{col}_lcs'] / df[f'match_{col}_len']
            df[f'{col}_nlcs'] = df[f'{col}_lcs'] / df[f'{col}_len']
            
            df = df.drop(f'{col}_len', axis = 1)
            df = df.drop(f'match_{col}_len', axis = 1)
            gc.collect()
        
        del col_values, matcol_values
        after_cols = df.columns
        diff_cols = list(set(after_cols) - set(before_cols))
        df[diff_cols] = reduce_mem_usage(df[diff_cols])
        gc.collect()
        
#     if COM > 0:
#         for col in tqdm(co_columns):
#             col_values = data.loc[df['id']][col].values
#             matcol_values = data.loc[df['match_id']][col].values
#             if col != 'main_category':
#                 df[f's_{col}'] = col_values
#                 df[f't_{col}'] = matcol_values

#             if TFIDF and col in ['main_category', 'co_net']:
#                 df[f'is_match_{col}'] = col_values == matcol_values

    return df

train = add_features(train)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 273.43 MB
# Decreased by 68.2%
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 273.43 MB
# Decreased by 68.2%
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 273.43 MB
# Decreased by 68.2%
# Memory usage of dataframe is 703.10 MB
# Memory usage after optimization is: 205.07 MB
# Decreased by 70.8%
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 244.13 MB
# Decreased by 71.6%
# Memory usage of dataframe is 390.61 MB
# Memory usage after optimization is: 156.24 MB
# Decreased by 60.0%
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 263.66 MB
# Decreased by 69.3%
# Memory usage of dataframe is 390.61 MB
# Memory usage after optimization is: 156.24 MB
# Decreased by 60.0%
# Memory usage of dataframe is 859.34 MB
# Memory usage after optimization is: 263.66 MB
# Decreased by 69.3%
# CPU times: user 1h 22min 46s, sys: 45.5 s, total: 1h 23min 32s
# Wall time: 1h 23min 21s

# %% [markdown]
# # Train

# %%
train.to_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'), index = False)
# train = pd.read_csv(os.path.join(OUTPUT_PATH, 'train_tmp.csv'))

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        print(col)
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
#             df[col] = df[col].astype('category')
            pass

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

train = reduce_mem_usage(train)
# Out:
# Memory usage of dataframe is 3622.90 MB
# id
# match_id
# kdist
# kneighbors
# name_iou
# cat_similarity
# name_rank
# cv
# co_net
# match_co_net
# is_match_co_net
# scale
# match_scale
# is_match_scale
# adjacency_frequency
# match_adjacency_frequency
# mean_adjacency_frequency
# betweeness_centrality
# match_betweeness_centrality
# mean_betweeness_centrality
# clustering_coefficient
# match_clustering_coefficient
# mean_clustering_coefficient
# median_distances_median
# match_median_distances_median
# mean_median_distances_median
# category_rate
# match_category_rate
# mean_category_rate
# label
# url_tfidf_sim
# url_tfidf_diff
# url_gesh
# url_leven
# url_jaro
# url_lcs
# url_len_diff
# url_nleven
# url_nlcsk
# url_nlcs
# name_tfidf_sim
# name_tfidf_diff
# name_gesh
# name_leven
# name_jaro
# name_lcs
# name_len_diff
# name_nleven
# name_nlcsk
# name_nlcs
# address_tfidf_sim
# address_tfidf_diff
# address_gesh
# address_leven
# address_jaro
# address_lcs
# address_len_diff
# address_nleven
# address_nlcsk
# address_nlcs
# city_gesh
# city_leven
# city_jaro
# city_lcs
# city_len_diff
# city_nleven
# city_nlcsk
# city_nlcs
# state_tfidf_sim
# state_tfidf_diff
# state_gesh
# state_leven
# state_jaro
# state_lcs
# state_len_diff
# state_nleven
# state_nlcsk
# state_nlcs
# zip_gesh
# zip_leven
# zip_jaro
# zip_lcs
# categories_tfidf_sim
# categories_tfidf_diff
# categories_gesh
# categories_leven
# categories_jaro
# categories_lcs
# categories_len_diff
# categories_nleven
# categories_nlcsk
# categories_nlcs
# phone_gesh
# phone_leven
# phone_jaro
# phone_lcs
# country_tfidf_sim
# country_tfidf_diff
# country_gesh
# country_leven
# country_jaro
# country_lcs
# country_len_diff
# country_nleven
# country_nlcsk
# country_nlcs
# Memory usage after optimization is: 2197.18 MB
# Decreased by 39.4%

# %%
features = ['kdist', 'kneighbors', 'name_gesh', 'name_leven', 'name_jaro',
       'name_lcs', 'name_len_diff', 'name_nleven', 'name_nlcsk', 'name_nlcs',
       'address_gesh', 'address_leven', 'address_jaro', 'address_lcs',
       'address_len_diff', 'address_nleven', 'address_nlcsk', 'address_nlcs',
       'city_gesh', 'city_leven', 'city_jaro', 'city_lcs', 'city_len_diff',
       'city_nleven', 'city_nlcsk', 'city_nlcs', 'state_gesh', 'state_leven',
       'state_jaro', 'state_lcs', 'state_len_diff', 'state_nleven',
       'state_nlcsk', 'state_nlcs', 'zip_gesh', 'zip_leven', 'zip_jaro',
       'zip_lcs', 'categories_gesh', 'categories_leven', 'categories_jaro',
       'categories_lcs', 'categories_len_diff', 'categories_nleven',
       'categories_nlcsk', 'categories_nlcs', 'phone_gesh', 'phone_leven',
       'phone_jaro', 'phone_lcs', 'url_gesh', 'url_leven', 'url_jaro',
       'url_lcs', 'url_len_diff', 'url_nleven', 'url_nlcsk', 'url_nlcs',
       'country_len_diff', 'country_jaro', 'country_lcs', 'country_nlcsk',
       'country_nleven', 'country_nlcs', 'country_leven', 'country_gesh', 
       'co_net', 'match_co_net', 'name_rank',
#        'match_scale', 'is_match_scale', 'is_match_co_net']
       'is_match_scale', 'is_match_co_net', 'match_scale', 'scale',
       'category_rate', 'match_adjacency_frequency', 'clustering_coefficient', 'match_category_rate',
       'betweeness_centrality', 'mean_clustering_coefficient', 'match_median_distances_median',
       'mean_category_rate', 'match_betweeness_centrality', 'mean_betweeness_centrality', 'mean_adjacency_frequency',
       'adjacency_frequency', 'median_distances_median', 'match_clustering_coefficient', 'mean_median_distances_median',
       'cat_similarity', 'name_iou'] # cat_similarity
#        'city_state_gesh', 'all_jaro', 'all_gesh', 'city_state_jaro', 'city_state_len_diff', 'all_nleven', 'city_state_nlcs', 'city_state_leven']
#         'name_intersections', 'address_intersections', 'city_intersections', 'state_intersections']

if TFIDF:
       features.extend(
           ['country_tfidf_sim', 'name_tfidf_diff', 'address_tfidf_diff', 'state_tfidf_sim', 'categories_tfidf_sim', 'url_tfidf_diff', 
       'country_tfidf_diff', 'categories_tfidf_diff', 'url_tfidf_sim', 'name_tfidf_sim', 'address_tfidf_sim', 'state_tfidf_diff'])
    

print(set(train.columns) - set(features))
print(f'no cols: {set(features) - set(train.columns)}')
# Out:
# {'match_id', 'cv', 'id', 'label'}
# no cols: set()

# %%
params = {
    'num_boost_round': 10000,
    'num_leaves': 500,
    'max_bin':300,
    'feature_fraction': 0.52,
    'bagging_fraction': 0.52,
    'max_depth': -1,
    'objective': 'binary',
    'learning_rate': 0.05,
    "boosting_type": "gbdt",
    "metric": 'auc',
    'early_stopping_rounds': 100,
    "verbosity": 50,
    'random_state': 47
}

# %%
# %%time

models = []
oof = np.zeros((len(train), N_FOLD), dtype=np.float64)
for i in range(N_FOLD):
    trn_idx = train['cv']!=i
    val_idx = train['cv']==i
    valid = train[train['cv']==i]
    train_X, train_y = train[trn_idx][features], train[trn_idx]['label']
    valid_X, valid_y = train[val_idx][features], train[val_idx]['label']
    
    print(f'*** start train cv: {i} ***')
    model = lgb.LGBMClassifier(**params)
    model.fit(
                train_X, train_y, 
                eval_set=[(valid_X, valid_y)])
    
    oof[val_idx] = model.predict_proba(valid_X)
    models.append(model)
    
    model_path = os.path.join(MODEL_PATH, f'lgb_fold{i}.pkl')
    print(f'save model: {model_path}')
    pickle.dump(model, open(model_path, 'wb'))
# Out:
# *** start train cv: 0 ***
# [1]	valid_0's auc: 0.967217
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.971123
# [3]	valid_0's auc: 0.97984
# [4]	valid_0's auc: 0.98175
# [5]	valid_0's auc: 0.982893
# [6]	valid_0's auc: 0.983927
# [7]	valid_0's auc: 0.984457
# [8]	valid_0's auc: 0.98478
# [9]	valid_0's auc: 0.984952
# [10]	valid_0's auc: 0.985185
# [11]	valid_0's auc: 0.985336
# [12]	valid_0's auc: 0.985498
# [13]	valid_0's auc: 0.98548
# [14]	valid_0's auc: 0.985508
# [15]	valid_0's auc: 0.985485
# [16]	valid_0's auc: 0.985488
# [17]	valid_0's auc: 0.985707
# [18]	valid_0's auc: 0.985898
# [19]	valid_0's auc: 0.98586
# [20]	valid_0's auc: 0.986053
# [21]	valid_0's auc: 0.986284
# [22]	valid_0's auc: 0.986371
# [23]	valid_0's auc: 0.986349
# [24]	valid_0's auc: 0.986549
# [25]	valid_0's auc: 0.986629
# [26]	valid_0's auc: 0.986772
# [27]	valid_0's auc: 0.986868
# [28]	valid_0's auc: 0.986855
# [29]	valid_0's auc: 0.986946
# [30]	valid_0's auc: 0.987021
# [31]	valid_0's auc: 0.987018
# [32]	valid_0's auc: 0.987108
# [33]	valid_0's auc: 0.98723
# [34]	valid_0's auc: 0.987301
# [35]	valid_0's auc: 0.987372
# [36]	valid_0's auc: 0.987384
# [37]	valid_0's auc: 0.987438
# [38]	valid_0's auc: 0.987472
# [39]	valid_0's auc: 0.987483
# [40]	valid_0's auc: 0.987532
# [41]	valid_0's auc: 0.987572
# [42]	valid_0's auc: 0.987665
# [43]	valid_0's auc: 0.987736
# [44]	valid_0's auc: 0.98777
# [45]	valid_0's auc: 0.987808
# [46]	valid_0's auc: 0.987884
# [47]	valid_0's auc: 0.987959
# [48]	valid_0's auc: 0.988009
# [49]	valid_0's auc: 0.988048
# [50]	valid_0's auc: 0.988093
# [51]	valid_0's auc: 0.988127
# [52]	valid_0's auc: 0.988146
# [53]	valid_0's auc: 0.988187
# [54]	valid_0's auc: 0.988242
# [55]	valid_0's auc: 0.98827
# [56]	valid_0's auc: 0.988299
# [57]	valid_0's auc: 0.988331
# [58]	valid_0's auc: 0.988354
# [59]	valid_0's auc: 0.988414
# [60]	valid_0's auc: 0.988444
# [61]	valid_0's auc: 0.988492
# [62]	valid_0's auc: 0.988547
# [63]	valid_0's auc: 0.988562
# [64]	valid_0's auc: 0.988595
# [65]	valid_0's auc: 0.988617
# [66]	valid_0's auc: 0.988663
# [67]	valid_0's auc: 0.988698
# [68]	valid_0's auc: 0.988734
# [69]	valid_0's auc: 0.98876
# [70]	valid_0's auc: 0.988785
# [71]	valid_0's auc: 0.98881
# [72]	valid_0's auc: 0.988831
# [73]	valid_0's auc: 0.988873
# [74]	valid_0's auc: 0.988895
# [75]	valid_0's auc: 0.988911
# [76]	valid_0's auc: 0.988947
# [77]	valid_0's auc: 0.988968
# [78]	valid_0's auc: 0.988998
# [79]	valid_0's auc: 0.989037
# [80]	valid_0's auc: 0.98907
# [81]	valid_0's auc: 0.989091
# [82]	valid_0's auc: 0.989132
# [83]	valid_0's auc: 0.989159
# [84]	valid_0's auc: 0.98919
# [85]	valid_0's auc: 0.989207
# [86]	valid_0's auc: 0.989232
# [87]	valid_0's auc: 0.989257
# [88]	valid_0's auc: 0.989279
# [89]	valid_0's auc: 0.989299
# [90]	valid_0's auc: 0.989315
# [91]	valid_0's auc: 0.989339
# [92]	valid_0's auc: 0.989362
# [93]	valid_0's auc: 0.989388
# [94]	valid_0's auc: 0.989408
# [95]	valid_0's auc: 0.989429
# [96]	valid_0's auc: 0.989452
# [97]	valid_0's auc: 0.989464
# [98]	valid_0's auc: 0.98948
# [99]	valid_0's auc: 0.989497
# [100]	valid_0's auc: 0.989519
# [101]	valid_0's auc: 0.989532
# [102]	valid_0's auc: 0.989548
# [103]	valid_0's auc: 0.989566
# [104]	valid_0's auc: 0.989585
# [105]	valid_0's auc: 0.989601
# [106]	valid_0's auc: 0.98961
# [107]	valid_0's auc: 0.989632
# [108]	valid_0's auc: 0.989648
# [109]	valid_0's auc: 0.989665
# [110]	valid_0's auc: 0.989682
# [111]	valid_0's auc: 0.989697
# [112]	valid_0's auc: 0.989718
# [113]	valid_0's auc: 0.989733
# [114]	valid_0's auc: 0.98975
# [115]	valid_0's auc: 0.989768
# [116]	valid_0's auc: 0.989786
# [117]	valid_0's auc: 0.989799
# [118]	valid_0's auc: 0.989812
# [119]	valid_0's auc: 0.98983
# [120]	valid_0's auc: 0.989846
# [121]	valid_0's auc: 0.989857
# [122]	valid_0's auc: 0.989871
# [123]	valid_0's auc: 0.989887
# [124]	valid_0's auc: 0.989905
# [125]	valid_0's auc: 0.989925
# [126]	valid_0's auc: 0.989935
# [127]	valid_0's auc: 0.989945
# [128]	valid_0's auc: 0.989958
# [129]	valid_0's auc: 0.989972
# [130]	valid_0's auc: 0.989986
# [131]	valid_0's auc: 0.989994
# [132]	valid_0's auc: 0.990007
# [133]	valid_0's auc: 0.99002
# [134]	valid_0's auc: 0.990031
# [135]	valid_0's auc: 0.99004
# [136]	valid_0's auc: 0.990051
# [137]	valid_0's auc: 0.990064
# [138]	valid_0's auc: 0.990077
# [139]	valid_0's auc: 0.990091
# [140]	valid_0's auc: 0.990106
# [141]	valid_0's auc: 0.990116
# [142]	valid_0's auc: 0.990125
# [143]	valid_0's auc: 0.990132
# [144]	valid_0's auc: 0.990144
# [145]	valid_0's auc: 0.990153
# [146]	valid_0's auc: 0.990163
# [147]	valid_0's auc: 0.99017
# [148]	valid_0's auc: 0.990177
# [149]	valid_0's auc: 0.990184
# [150]	valid_0's auc: 0.990191
# [151]	valid_0's auc: 0.990196
# [152]	valid_0's auc: 0.990209
# [153]	valid_0's auc: 0.99022
# [154]	valid_0's auc: 0.990226
# [155]	valid_0's auc: 0.990234
# [156]	valid_0's auc: 0.990244
# [157]	valid_0's auc: 0.990252
# [158]	valid_0's auc: 0.990259
# [159]	valid_0's auc: 0.990267
# [160]	valid_0's auc: 0.990277
# [161]	valid_0's auc: 0.990283
# [162]	valid_0's auc: 0.990297
# [163]	valid_0's auc: 0.990304
# [164]	valid_0's auc: 0.99031
# [165]	valid_0's auc: 0.990314
# [166]	valid_0's auc: 0.990323
# [167]	valid_0's auc: 0.990332
# [168]	valid_0's auc: 0.990342
# [169]	valid_0's auc: 0.99035
# [170]	valid_0's auc: 0.990361
# [171]	valid_0's auc: 0.990371
# [172]	valid_0's auc: 0.990374
# [173]	valid_0's auc: 0.990383
# [174]	valid_0's auc: 0.99039
# [175]	valid_0's auc: 0.990397
# [176]	valid_0's auc: 0.990404
# [177]	valid_0's auc: 0.990412
# [178]	valid_0's auc: 0.990418
# [179]	valid_0's auc: 0.990426
# [180]	valid_0's auc: 0.990433
# [181]	valid_0's auc: 0.990437
# [182]	valid_0's auc: 0.990446
# [183]	valid_0's auc: 0.99045
# [184]	valid_0's auc: 0.990455
# [185]	valid_0's auc: 0.990465
# [186]	valid_0's auc: 0.990471
# [187]	valid_0's auc: 0.990475
# [188]	valid_0's auc: 0.990484
# [189]	valid_0's auc: 0.990489
# [190]	valid_0's auc: 0.990497
# [191]	valid_0's auc: 0.990503
# [192]	valid_0's auc: 0.99051
# [193]	valid_0's auc: 0.990515
# [194]	valid_0's auc: 0.990521
# [195]	valid_0's auc: 0.990526
# [196]	valid_0's auc: 0.990528
# [197]	valid_0's auc: 0.990537
# [198]	valid_0's auc: 0.990542
# [199]	valid_0's auc: 0.990549
# [200]	valid_0's auc: 0.990553
# [201]	valid_0's auc: 0.990563
# [202]	valid_0's auc: 0.990567
# [203]	valid_0's auc: 0.990573
# [204]	valid_0's auc: 0.99058
# [205]	valid_0's auc: 0.990582
# [206]	valid_0's auc: 0.99059
# [207]	valid_0's auc: 0.990596
# [208]	valid_0's auc: 0.990601
# [209]	valid_0's auc: 0.990604
# [210]	valid_0's auc: 0.990607
# [211]	valid_0's auc: 0.99061
# [212]	valid_0's auc: 0.990613
# [213]	valid_0's auc: 0.990617
# [214]	valid_0's auc: 0.990624
# [215]	valid_0's auc: 0.990627
# [216]	valid_0's auc: 0.990633
# [217]	valid_0's auc: 0.990637
# [218]	valid_0's auc: 0.990642
# [219]	valid_0's auc: 0.990646
# [220]	valid_0's auc: 0.990649
# [221]	valid_0's auc: 0.990653
# [222]	valid_0's auc: 0.990659
# [223]	valid_0's auc: 0.990663
# [224]	valid_0's auc: 0.990666
# [225]	valid_0's auc: 0.990669
# [226]	valid_0's auc: 0.990672
# [227]	valid_0's auc: 0.99068
# [228]	valid_0's auc: 0.990684
# [229]	valid_0's auc: 0.990687
# [230]	valid_0's auc: 0.990691
# [231]	valid_0's auc: 0.990694
# [232]	valid_0's auc: 0.990697
# [233]	valid_0's auc: 0.9907
# [234]	valid_0's auc: 0.990707
# [235]	valid_0's auc: 0.990709
# [236]	valid_0's auc: 0.99071
# [237]	valid_0's auc: 0.99071
# [238]	valid_0's auc: 0.990712
# [239]	valid_0's auc: 0.990713
# [240]	valid_0's auc: 0.99072
# [241]	valid_0's auc: 0.990722
# [242]	valid_0's auc: 0.990727
# [243]	valid_0's auc: 0.990727
# [244]	valid_0's auc: 0.99073
# [245]	valid_0's auc: 0.990734
# [246]	valid_0's auc: 0.990737
# [247]	valid_0's auc: 0.990739
# [248]	valid_0's auc: 0.990745
# [249]	valid_0's auc: 0.990746
# [250]	valid_0's auc: 0.990746
# [251]	valid_0's auc: 0.990747
# [252]	valid_0's auc: 0.990749
# [253]	valid_0's auc: 0.990753
# [254]	valid_0's auc: 0.990755
# [255]	valid_0's auc: 0.990757
# [256]	valid_0's auc: 0.990757
# [257]	valid_0's auc: 0.990758
# [258]	valid_0's auc: 0.990762
# [259]	valid_0's auc: 0.990762
# [260]	valid_0's auc: 0.990764
# [261]	valid_0's auc: 0.99077
# [262]	valid_0's auc: 0.990772
# [263]	valid_0's auc: 0.990773
# [264]	valid_0's auc: 0.990773
# [265]	valid_0's auc: 0.990774
# [266]	valid_0's auc: 0.990776
# [267]	valid_0's auc: 0.990782
# [268]	valid_0's auc: 0.990785
# [269]	valid_0's auc: 0.990785
# [270]	valid_0's auc: 0.990789
# [271]	valid_0's auc: 0.99079
# [272]	valid_0's auc: 0.990793
# [273]	valid_0's auc: 0.990792
# [274]	valid_0's auc: 0.990793
# [275]	valid_0's auc: 0.990795
# [276]	valid_0's auc: 0.990795
# [277]	valid_0's auc: 0.990794
# [278]	valid_0's auc: 0.990795
# [279]	valid_0's auc: 0.990798
# [280]	valid_0's auc: 0.990799
# [281]	valid_0's auc: 0.990798
# [282]	valid_0's auc: 0.990798
# [283]	valid_0's auc: 0.990799
# [284]	valid_0's auc: 0.990801
# [285]	valid_0's auc: 0.9908
# [286]	valid_0's auc: 0.990803
# [287]	valid_0's auc: 0.990805
# [288]	valid_0's auc: 0.990806
# [289]	valid_0's auc: 0.99081
# [290]	valid_0's auc: 0.990812
# [291]	valid_0's auc: 0.990811
# [292]	valid_0's auc: 0.990811
# [293]	valid_0's auc: 0.990813
# [294]	valid_0's auc: 0.990817
# [295]	valid_0's auc: 0.990821
# [296]	valid_0's auc: 0.990823
# [297]	valid_0's auc: 0.990822
# [298]	valid_0's auc: 0.990825
# [299]	valid_0's auc: 0.990827
# [300]	valid_0's auc: 0.990829
# [301]	valid_0's auc: 0.990831
# [302]	valid_0's auc: 0.990831
# [303]	valid_0's auc: 0.990832
# [304]	valid_0's auc: 0.990832
# [305]	valid_0's auc: 0.990835
# [306]	valid_0's auc: 0.990834
# [307]	valid_0's auc: 0.990835
# [308]	valid_0's auc: 0.990839
# [309]	valid_0's auc: 0.990842
# [310]	valid_0's auc: 0.990845
# [311]	valid_0's auc: 0.990846
# [312]	valid_0's auc: 0.990848
# [313]	valid_0's auc: 0.99085
# [314]	valid_0's auc: 0.99085
# [315]	valid_0's auc: 0.99085
# [316]	valid_0's auc: 0.990852
# [317]	valid_0's auc: 0.990854
# [318]	valid_0's auc: 0.990854
# [319]	valid_0's auc: 0.990854
# [320]	valid_0's auc: 0.990858
# [321]	valid_0's auc: 0.99086
# [322]	valid_0's auc: 0.990861
# [323]	valid_0's auc: 0.990861
# [324]	valid_0's auc: 0.990862
# [325]	valid_0's auc: 0.990863
# [326]	valid_0's auc: 0.990865
# [327]	valid_0's auc: 0.990866
# [328]	valid_0's auc: 0.990865
# [329]	valid_0's auc: 0.990868
# [330]	valid_0's auc: 0.99087
# [331]	valid_0's auc: 0.990869
# [332]	valid_0's auc: 0.990869
# [333]	valid_0's auc: 0.990868
# [334]	valid_0's auc: 0.990865
# [335]	valid_0's auc: 0.990864
# [336]	valid_0's auc: 0.990863
# [337]	valid_0's auc: 0.990864
# [338]	valid_0's auc: 0.990862
# [339]	valid_0's auc: 0.990862
# [340]	valid_0's auc: 0.99086
# [341]	valid_0's auc: 0.990861
# [342]	valid_0's auc: 0.990861
# [343]	valid_0's auc: 0.990859
# [344]	valid_0's auc: 0.990864
# [345]	valid_0's auc: 0.990864
# [346]	valid_0's auc: 0.990866
# [347]	valid_0's auc: 0.990865
# [348]	valid_0's auc: 0.990865
# [349]	valid_0's auc: 0.990887
# [350]	valid_0's auc: 0.990887
# [351]	valid_0's auc: 0.990888
# [352]	valid_0's auc: 0.990888
# [353]	valid_0's auc: 0.990889
# [354]	valid_0's auc: 0.99089
# [355]	valid_0's auc: 0.99089
# [356]	valid_0's auc: 0.99089
# [357]	valid_0's auc: 0.990892
# [358]	valid_0's auc: 0.990892
# [359]	valid_0's auc: 0.990895
# [360]	valid_0's auc: 0.990898
# [361]	valid_0's auc: 0.990899
# [362]	valid_0's auc: 0.990901
# [363]	valid_0's auc: 0.990901
# [364]	valid_0's auc: 0.990901
# [365]	valid_0's auc: 0.990901
# [366]	valid_0's auc: 0.990906
# [367]	valid_0's auc: 0.990905
# [368]	valid_0's auc: 0.990906
# [369]	valid_0's auc: 0.990903
# [370]	valid_0's auc: 0.990904
# [371]	valid_0's auc: 0.990904
# [372]	valid_0's auc: 0.990905
# [373]	valid_0's auc: 0.990906
# [374]	valid_0's auc: 0.990907
# [375]	valid_0's auc: 0.990907
# [376]	valid_0's auc: 0.99091
# [377]	valid_0's auc: 0.990912
# [378]	valid_0's auc: 0.990915
# [379]	valid_0's auc: 0.990916
# [380]	valid_0's auc: 0.990916
# [381]	valid_0's auc: 0.990916
# [382]	valid_0's auc: 0.990916
# [383]	valid_0's auc: 0.990917
# [384]	valid_0's auc: 0.990919
# [385]	valid_0's auc: 0.990921
# [386]	valid_0's auc: 0.990921
# [387]	valid_0's auc: 0.990922
# [388]	valid_0's auc: 0.990924
# [389]	valid_0's auc: 0.990925
# [390]	valid_0's auc: 0.990925
# [391]	valid_0's auc: 0.990925
# [392]	valid_0's auc: 0.990926
# [393]	valid_0's auc: 0.990926
# [394]	valid_0's auc: 0.990927
# [395]	valid_0's auc: 0.990927
# [396]	valid_0's auc: 0.990929
# [397]	valid_0's auc: 0.990924
# [398]	valid_0's auc: 0.990924
# [399]	valid_0's auc: 0.990927
# [400]	valid_0's auc: 0.990929
# [401]	valid_0's auc: 0.990932
# [402]	valid_0's auc: 0.990932
# [403]	valid_0's auc: 0.990933
# [404]	valid_0's auc: 0.990936
# [405]	valid_0's auc: 0.990936
# [406]	valid_0's auc: 0.990937
# [407]	valid_0's auc: 0.990937
# [408]	valid_0's auc: 0.990937
# [409]	valid_0's auc: 0.990937
# [410]	valid_0's auc: 0.990937
# [411]	valid_0's auc: 0.990938
# [412]	valid_0's auc: 0.990939
# [413]	valid_0's auc: 0.990942
# [414]	valid_0's auc: 0.990942
# [415]	valid_0's auc: 0.990943
# [416]	valid_0's auc: 0.990944
# [417]	valid_0's auc: 0.990945
# [418]	valid_0's auc: 0.990945
# [419]	valid_0's auc: 0.990948
# [420]	valid_0's auc: 0.990949
# [421]	valid_0's auc: 0.990949
# [422]	valid_0's auc: 0.99095
# [423]	valid_0's auc: 0.990953
# [424]	valid_0's auc: 0.990957
# [425]	valid_0's auc: 0.990958
# [426]	valid_0's auc: 0.99096
# [427]	valid_0's auc: 0.990965
# [428]	valid_0's auc: 0.990968
# [429]	valid_0's auc: 0.990971
# [430]	valid_0's auc: 0.990971
# [431]	valid_0's auc: 0.990972
# [432]	valid_0's auc: 0.990974
# [433]	valid_0's auc: 0.990976
# [434]	valid_0's auc: 0.990976
# [435]	valid_0's auc: 0.990976
# [436]	valid_0's auc: 0.990976
# [437]	valid_0's auc: 0.990977
# [438]	valid_0's auc: 0.990977
# [439]	valid_0's auc: 0.99098
# [440]	valid_0's auc: 0.990981
# [441]	valid_0's auc: 0.990982
# [442]	valid_0's auc: 0.990982
# [443]	valid_0's auc: 0.990983
# [444]	valid_0's auc: 0.990986
# [445]	valid_0's auc: 0.990986
# [446]	valid_0's auc: 0.990986
# [447]	valid_0's auc: 0.990987
# [448]	valid_0's auc: 0.990987
# [449]	valid_0's auc: 0.990987
# [450]	valid_0's auc: 0.990988
# [451]	valid_0's auc: 0.990989
# [452]	valid_0's auc: 0.990991
# [453]	valid_0's auc: 0.990993
# [454]	valid_0's auc: 0.990992
# [455]	valid_0's auc: 0.990992
# [456]	valid_0's auc: 0.990994
# [457]	valid_0's auc: 0.990995
# [458]	valid_0's auc: 0.990995
# [459]	valid_0's auc: 0.990994
# [460]	valid_0's auc: 0.990994
# [461]	valid_0's auc: 0.990995
# [462]	valid_0's auc: 0.990996
# [463]	valid_0's auc: 0.991001
# [464]	valid_0's auc: 0.991
# [465]	valid_0's auc: 0.991001
# [466]	valid_0's auc: 0.991001
# [467]	valid_0's auc: 0.991003
# [468]	valid_0's auc: 0.991002
# [469]	valid_0's auc: 0.991002
# [470]	valid_0's auc: 0.991003
# [471]	valid_0's auc: 0.991003
# [472]	valid_0's auc: 0.991003
# [473]	valid_0's auc: 0.991006
# [474]	valid_0's auc: 0.991006
# [475]	valid_0's auc: 0.991006
# [476]	valid_0's auc: 0.991006
# [477]	valid_0's auc: 0.991005
# [478]	valid_0's auc: 0.991006
# [479]	valid_0's auc: 0.991007
# [480]	valid_0's auc: 0.991007
# [481]	valid_0's auc: 0.99101
# [482]	valid_0's auc: 0.99101
# [483]	valid_0's auc: 0.991011
# [484]	valid_0's auc: 0.991012
# [485]	valid_0's auc: 0.991013
# [486]	valid_0's auc: 0.991013
# [487]	valid_0's auc: 0.991014
# [488]	valid_0's auc: 0.991014
# [489]	valid_0's auc: 0.991015
# [490]	valid_0's auc: 0.991015
# [491]	valid_0's auc: 0.991016
# [492]	valid_0's auc: 0.991016
# [493]	valid_0's auc: 0.991016
# [494]	valid_0's auc: 0.991015
# [495]	valid_0's auc: 0.991015
# [496]	valid_0's auc: 0.991016
# [497]	valid_0's auc: 0.991018
# [498]	valid_0's auc: 0.991017
# [499]	valid_0's auc: 0.991019
# [500]	valid_0's auc: 0.991019
# [501]	valid_0's auc: 0.99102
# [502]	valid_0's auc: 0.99102
# [503]	valid_0's auc: 0.991021
# [504]	valid_0's auc: 0.991022
# [505]	valid_0's auc: 0.991021
# [506]	valid_0's auc: 0.991021
# [507]	valid_0's auc: 0.991021
# [508]	valid_0's auc: 0.991022
# [509]	valid_0's auc: 0.99102
# [510]	valid_0's auc: 0.99102
# [511]	valid_0's auc: 0.991021
# [512]	valid_0's auc: 0.991021
# [513]	valid_0's auc: 0.991022
# [514]	valid_0's auc: 0.991022
# [515]	valid_0's auc: 0.991023
# [516]	valid_0's auc: 0.991024
# [517]	valid_0's auc: 0.991024
# [518]	valid_0's auc: 0.991024
# [519]	valid_0's auc: 0.991024
# [520]	valid_0's auc: 0.991025
# [521]	valid_0's auc: 0.991026
# [522]	valid_0's auc: 0.991026
# [523]	valid_0's auc: 0.991029
# [524]	valid_0's auc: 0.991028
# [525]	valid_0's auc: 0.991028
# [526]	valid_0's auc: 0.991029
# [527]	valid_0's auc: 0.991029
# [528]	valid_0's auc: 0.991029
# [529]	valid_0's auc: 0.991029
# [530]	valid_0's auc: 0.991029
# [531]	valid_0's auc: 0.99103
# [532]	valid_0's auc: 0.991031
# [533]	valid_0's auc: 0.99103
# [534]	valid_0's auc: 0.991031
# [535]	valid_0's auc: 0.991032
# [536]	valid_0's auc: 0.991032
# [537]	valid_0's auc: 0.991033
# [538]	valid_0's auc: 0.991034
# [539]	valid_0's auc: 0.991037
# [540]	valid_0's auc: 0.991038
# [541]	valid_0's auc: 0.991036
# [542]	valid_0's auc: 0.991037
# [543]	valid_0's auc: 0.991038
# [544]	valid_0's auc: 0.991039
# [545]	valid_0's auc: 0.991036
# [546]	valid_0's auc: 0.991037
# [547]	valid_0's auc: 0.991038
# [548]	valid_0's auc: 0.99104
# [549]	valid_0's auc: 0.991041
# [550]	valid_0's auc: 0.991041
# [551]	valid_0's auc: 0.99104
# [552]	valid_0's auc: 0.991038
# [553]	valid_0's auc: 0.991039
# [554]	valid_0's auc: 0.991039
# [555]	valid_0's auc: 0.99104
# [556]	valid_0's auc: 0.99104
# [557]	valid_0's auc: 0.991041
# [558]	valid_0's auc: 0.99104
# [559]	valid_0's auc: 0.99104
# [560]	valid_0's auc: 0.991042
# [561]	valid_0's auc: 0.991042
# [562]	valid_0's auc: 0.991043
# [563]	valid_0's auc: 0.991044
# [564]	valid_0's auc: 0.991043
# [565]	valid_0's auc: 0.991045
# [566]	valid_0's auc: 0.991045
# [567]	valid_0's auc: 0.991047
# [568]	valid_0's auc: 0.991045
# [569]	valid_0's auc: 0.991046
# [570]	valid_0's auc: 0.991044
# [571]	valid_0's auc: 0.991044
# [572]	valid_0's auc: 0.991044
# [573]	valid_0's auc: 0.991045
# [574]	valid_0's auc: 0.991046
# [575]	valid_0's auc: 0.991047
# [576]	valid_0's auc: 0.991048
# [577]	valid_0's auc: 0.991048
# [578]	valid_0's auc: 0.991048
# [579]	valid_0's auc: 0.991048
# [580]	valid_0's auc: 0.991048
# [581]	valid_0's auc: 0.991048
# [582]	valid_0's auc: 0.991049
# [583]	valid_0's auc: 0.991049
# [584]	valid_0's auc: 0.991048
# [585]	valid_0's auc: 0.991049
# [586]	valid_0's auc: 0.99105
# [587]	valid_0's auc: 0.99105
# [588]	valid_0's auc: 0.991052
# [589]	valid_0's auc: 0.991052
# [590]	valid_0's auc: 0.991055
# [591]	valid_0's auc: 0.991054
# [592]	valid_0's auc: 0.991056
# [593]	valid_0's auc: 0.991057
# [594]	valid_0's auc: 0.991057
# [595]	valid_0's auc: 0.991058
# [596]	valid_0's auc: 0.991058
# [597]	valid_0's auc: 0.991057
# [598]	valid_0's auc: 0.991056
# [599]	valid_0's auc: 0.991056
# [600]	valid_0's auc: 0.991057
# [601]	valid_0's auc: 0.991057
# [602]	valid_0's auc: 0.991056
# [603]	valid_0's auc: 0.991056
# [604]	valid_0's auc: 0.991056
# [605]	valid_0's auc: 0.991057
# [606]	valid_0's auc: 0.991057
# [607]	valid_0's auc: 0.991057
# [608]	valid_0's auc: 0.991057
# [609]	valid_0's auc: 0.991056
# [610]	valid_0's auc: 0.991057
# [611]	valid_0's auc: 0.991057
# [612]	valid_0's auc: 0.991058
# [613]	valid_0's auc: 0.991058
# [614]	valid_0's auc: 0.99106
# [615]	valid_0's auc: 0.99106
# [616]	valid_0's auc: 0.991061
# [617]	valid_0's auc: 0.991062
# [618]	valid_0's auc: 0.991063
# [619]	valid_0's auc: 0.991064
# [620]	valid_0's auc: 0.991065
# [621]	valid_0's auc: 0.991065
# [622]	valid_0's auc: 0.991065
# [623]	valid_0's auc: 0.991065
# [624]	valid_0's auc: 0.991067
# [625]	valid_0's auc: 0.991068
# [626]	valid_0's auc: 0.991068
# [627]	valid_0's auc: 0.991069
# [628]	valid_0's auc: 0.991071
# [629]	valid_0's auc: 0.991071
# [630]	valid_0's auc: 0.991071
# [631]	valid_0's auc: 0.991071
# [632]	valid_0's auc: 0.991069
# [633]	valid_0's auc: 0.991069
# [634]	valid_0's auc: 0.991069
# [635]	valid_0's auc: 0.99107
# [636]	valid_0's auc: 0.991069
# [637]	valid_0's auc: 0.991069
# [638]	valid_0's auc: 0.991071
# [639]	valid_0's auc: 0.991071
# [640]	valid_0's auc: 0.991073
# [641]	valid_0's auc: 0.991073
# [642]	valid_0's auc: 0.991073
# [643]	valid_0's auc: 0.991073
# [644]	valid_0's auc: 0.991073
# [645]	valid_0's auc: 0.991073
# [646]	valid_0's auc: 0.991076
# [647]	valid_0's auc: 0.991077
# [648]	valid_0's auc: 0.991079
# [649]	valid_0's auc: 0.991079
# [650]	valid_0's auc: 0.99108
# [651]	valid_0's auc: 0.991078
# [652]	valid_0's auc: 0.991081
# [653]	valid_0's auc: 0.991082
# [654]	valid_0's auc: 0.991083
# [655]	valid_0's auc: 0.991083
# [656]	valid_0's auc: 0.991082
# [657]	valid_0's auc: 0.99108
# [658]	valid_0's auc: 0.99108
# [659]	valid_0's auc: 0.991082
# [660]	valid_0's auc: 0.991082
# [661]	valid_0's auc: 0.991083
# [662]	valid_0's auc: 0.991084
# [663]	valid_0's auc: 0.991086
# [664]	valid_0's auc: 0.991088
# [665]	valid_0's auc: 0.991089
# [666]	valid_0's auc: 0.991089
# [667]	valid_0's auc: 0.99109
# [668]	valid_0's auc: 0.991091
# [669]	valid_0's auc: 0.991091
# [670]	valid_0's auc: 0.991091
# [671]	valid_0's auc: 0.991091
# [672]	valid_0's auc: 0.991092
# [673]	valid_0's auc: 0.991093
# [674]	valid_0's auc: 0.991094
# [675]	valid_0's auc: 0.991095
# [676]	valid_0's auc: 0.991095
# [677]	valid_0's auc: 0.991097
# [678]	valid_0's auc: 0.991097
# [679]	valid_0's auc: 0.991097
# [680]	valid_0's auc: 0.991097
# [681]	valid_0's auc: 0.991097
# [682]	valid_0's auc: 0.991096
# [683]	valid_0's auc: 0.991097
# [684]	valid_0's auc: 0.991097
# [685]	valid_0's auc: 0.991097
# [686]	valid_0's auc: 0.991098
# [687]	valid_0's auc: 0.991099
# [688]	valid_0's auc: 0.9911
# [689]	valid_0's auc: 0.9911
# [690]	valid_0's auc: 0.9911
# [691]	valid_0's auc: 0.991101
# [692]	valid_0's auc: 0.991102
# [693]	valid_0's auc: 0.991102
# [694]	valid_0's auc: 0.991102
# [695]	valid_0's auc: 0.991102
# [696]	valid_0's auc: 0.991103
# [697]	valid_0's auc: 0.991103
# [698]	valid_0's auc: 0.991103
# [699]	valid_0's auc: 0.991103
# [700]	valid_0's auc: 0.991104
# [701]	valid_0's auc: 0.991105
# [702]	valid_0's auc: 0.991105
# [703]	valid_0's auc: 0.991105
# [704]	valid_0's auc: 0.991105
# [705]	valid_0's auc: 0.991105
# [706]	valid_0's auc: 0.991106
# [707]	valid_0's auc: 0.99111
# [708]	valid_0's auc: 0.991107
# [709]	valid_0's auc: 0.991107
# [710]	valid_0's auc: 0.991107
# [711]	valid_0's auc: 0.991107
# [712]	valid_0's auc: 0.991107
# [713]	valid_0's auc: 0.991108
# [714]	valid_0's auc: 0.991108
# [715]	valid_0's auc: 0.991108
# [716]	valid_0's auc: 0.99111
# [717]	valid_0's auc: 0.99111
# [718]	valid_0's auc: 0.99111
# [719]	valid_0's auc: 0.991109
# [720]	valid_0's auc: 0.99111
# [721]	valid_0's auc: 0.991109
# [722]	valid_0's auc: 0.99111
# [723]	valid_0's auc: 0.99111
# [724]	valid_0's auc: 0.99111
# [725]	valid_0's auc: 0.99111
# [726]	valid_0's auc: 0.991111
# [727]	valid_0's auc: 0.991112
# [728]	valid_0's auc: 0.991113
# [729]	valid_0's auc: 0.991111
# [730]	valid_0's auc: 0.991113
# [731]	valid_0's auc: 0.991115
# [732]	valid_0's auc: 0.991115
# [733]	valid_0's auc: 0.991115
# [734]	valid_0's auc: 0.991115
# [735]	valid_0's auc: 0.991115
# [736]	valid_0's auc: 0.991115
# [737]	valid_0's auc: 0.991116
# [738]	valid_0's auc: 0.991116
# [739]	valid_0's auc: 0.991117
# [740]	valid_0's auc: 0.991121
# [741]	valid_0's auc: 0.991122
# [742]	valid_0's auc: 0.991122
# [743]	valid_0's auc: 0.99112
# [744]	valid_0's auc: 0.991119
# [745]	valid_0's auc: 0.99112
# [746]	valid_0's auc: 0.99112
# [747]	valid_0's auc: 0.99112
# [748]	valid_0's auc: 0.991121
# [749]	valid_0's auc: 0.991121
# [750]	valid_0's auc: 0.991121
# [751]	valid_0's auc: 0.99112
# [752]	valid_0's auc: 0.99112
# [753]	valid_0's auc: 0.991118
# [754]	valid_0's auc: 0.991117
# [755]	valid_0's auc: 0.991118
# [756]	valid_0's auc: 0.991118
# [757]	valid_0's auc: 0.991119
# [758]	valid_0's auc: 0.991119
# [759]	valid_0's auc: 0.99112
# [760]	valid_0's auc: 0.99112
# [761]	valid_0's auc: 0.99112
# [762]	valid_0's auc: 0.991121
# [763]	valid_0's auc: 0.991123
# [764]	valid_0's auc: 0.991124
# [765]	valid_0's auc: 0.991124
# [766]	valid_0's auc: 0.991124
# [767]	valid_0's auc: 0.991125
# [768]	valid_0's auc: 0.991124
# [769]	valid_0's auc: 0.991124
# [770]	valid_0's auc: 0.991123
# [771]	valid_0's auc: 0.991125
# [772]	valid_0's auc: 0.991125
# [773]	valid_0's auc: 0.991126
# [774]	valid_0's auc: 0.991128
# [775]	valid_0's auc: 0.991129
# [776]	valid_0's auc: 0.991129
# [777]	valid_0's auc: 0.991128
# [778]	valid_0's auc: 0.991128
# [779]	valid_0's auc: 0.991129
# [780]	valid_0's auc: 0.991129
# [781]	valid_0's auc: 0.991129
# [782]	valid_0's auc: 0.99113
# [783]	valid_0's auc: 0.99113
# [784]	valid_0's auc: 0.991131
# [785]	valid_0's auc: 0.991131
# [786]	valid_0's auc: 0.991131
# [787]	valid_0's auc: 0.991132
# [788]	valid_0's auc: 0.991132
# [789]	valid_0's auc: 0.991131
# [790]	valid_0's auc: 0.991131
# [791]	valid_0's auc: 0.991131
# [792]	valid_0's auc: 0.991131
# [793]	valid_0's auc: 0.99113
# [794]	valid_0's auc: 0.991131
# [795]	valid_0's auc: 0.991131
# [796]	valid_0's auc: 0.991131
# [797]	valid_0's auc: 0.991131
# [798]	valid_0's auc: 0.991131
# [799]	valid_0's auc: 0.991131
# [800]	valid_0's auc: 0.991131
# [801]	valid_0's auc: 0.991131
# [802]	valid_0's auc: 0.991132
# [803]	valid_0's auc: 0.991132
# [804]	valid_0's auc: 0.991133
# [805]	valid_0's auc: 0.991133
# [806]	valid_0's auc: 0.991133
# [807]	valid_0's auc: 0.991133
# [808]	valid_0's auc: 0.991133
# [809]	valid_0's auc: 0.991132
# [810]	valid_0's auc: 0.991133
# [811]	valid_0's auc: 0.991134
# [812]	valid_0's auc: 0.991134
# [813]	valid_0's auc: 0.991135
# [814]	valid_0's auc: 0.991136
# [815]	valid_0's auc: 0.991136
# [816]	valid_0's auc: 0.991137
# [817]	valid_0's auc: 0.991138
# [818]	valid_0's auc: 0.991137
# [819]	valid_0's auc: 0.991137
# [820]	valid_0's auc: 0.991136
# [821]	valid_0's auc: 0.991136
# [822]	valid_0's auc: 0.991138
# [823]	valid_0's auc: 0.991137
# [824]	valid_0's auc: 0.991138
# [825]	valid_0's auc: 0.991136
# [826]	valid_0's auc: 0.991136
# [827]	valid_0's auc: 0.991136
# [828]	valid_0's auc: 0.991136
# [829]	valid_0's auc: 0.991139
# [830]	valid_0's auc: 0.99114
# [831]	valid_0's auc: 0.991138
# [832]	valid_0's auc: 0.99114
# [833]	valid_0's auc: 0.991141
# [834]	valid_0's auc: 0.99114
# [835]	valid_0's auc: 0.99114
# [836]	valid_0's auc: 0.991139
# [837]	valid_0's auc: 0.991139
# [838]	valid_0's auc: 0.99114
# [839]	valid_0's auc: 0.99114
# [840]	valid_0's auc: 0.99114
# [841]	valid_0's auc: 0.991141
# [842]	valid_0's auc: 0.991142
# [843]	valid_0's auc: 0.991142
# [844]	valid_0's auc: 0.991142
# [845]	valid_0's auc: 0.991142
# [846]	valid_0's auc: 0.991143
# [847]	valid_0's auc: 0.991143
# [848]	valid_0's auc: 0.991142
# [849]	valid_0's auc: 0.991142
# [850]	valid_0's auc: 0.991143
# [851]	valid_0's auc: 0.991143
# [852]	valid_0's auc: 0.991143
# [853]	valid_0's auc: 0.991142
# [854]	valid_0's auc: 0.991142
# [855]	valid_0's auc: 0.991142
# [856]	valid_0's auc: 0.991144
# [857]	valid_0's auc: 0.991143
# [858]	valid_0's auc: 0.991143
# [859]	valid_0's auc: 0.991143
# [860]	valid_0's auc: 0.991143
# [861]	valid_0's auc: 0.991144
# [862]	valid_0's auc: 0.991146
# [863]	valid_0's auc: 0.991147
# [864]	valid_0's auc: 0.991147
# [865]	valid_0's auc: 0.991147
# [866]	valid_0's auc: 0.991147
# [867]	valid_0's auc: 0.991147
# [868]	valid_0's auc: 0.991147
# [869]	valid_0's auc: 0.991147
# [870]	valid_0's auc: 0.991148
# [871]	valid_0's auc: 0.991149
# [872]	valid_0's auc: 0.991149
# [873]	valid_0's auc: 0.991149
# [874]	valid_0's auc: 0.991151
# [875]	valid_0's auc: 0.991151
# [876]	valid_0's auc: 0.991149
# [877]	valid_0's auc: 0.99115
# [878]	valid_0's auc: 0.991151
# [879]	valid_0's auc: 0.991151
# [880]	valid_0's auc: 0.991151
# [881]	valid_0's auc: 0.991151
# [882]	valid_0's auc: 0.991152
# [883]	valid_0's auc: 0.991152
# [884]	valid_0's auc: 0.991152
# [885]	valid_0's auc: 0.991152
# [886]	valid_0's auc: 0.991152
# [887]	valid_0's auc: 0.991152
# [888]	valid_0's auc: 0.991151
# [889]	valid_0's auc: 0.991151
# [890]	valid_0's auc: 0.99115
# [891]	valid_0's auc: 0.991151
# [892]	valid_0's auc: 0.991151
# [893]	valid_0's auc: 0.991151
# [894]	valid_0's auc: 0.991152
# [895]	valid_0's auc: 0.991152
# [896]	valid_0's auc: 0.991152
# [897]	valid_0's auc: 0.991153
# [898]	valid_0's auc: 0.991154
# [899]	valid_0's auc: 0.991154
# [900]	valid_0's auc: 0.991155
# [901]	valid_0's auc: 0.991153
# [902]	valid_0's auc: 0.991153
# [903]	valid_0's auc: 0.991153
# [904]	valid_0's auc: 0.991154
# [905]	valid_0's auc: 0.991154
# [906]	valid_0's auc: 0.991154
# [907]	valid_0's auc: 0.991155
# [908]	valid_0's auc: 0.991156
# [909]	valid_0's auc: 0.991156
# [910]	valid_0's auc: 0.991156
# [911]	valid_0's auc: 0.991157
# [912]	valid_0's auc: 0.991157
# [913]	valid_0's auc: 0.991157
# [914]	valid_0's auc: 0.991157
# [915]	valid_0's auc: 0.991157
# [916]	valid_0's auc: 0.991157
# [917]	valid_0's auc: 0.991157
# [918]	valid_0's auc: 0.991157
# [919]	valid_0's auc: 0.991157
# [920]	valid_0's auc: 0.991157
# [921]	valid_0's auc: 0.991159
# [922]	valid_0's auc: 0.991158
# [923]	valid_0's auc: 0.991159
# [924]	valid_0's auc: 0.99116
# [925]	valid_0's auc: 0.99116
# [926]	valid_0's auc: 0.99116
# [927]	valid_0's auc: 0.991162
# [928]	valid_0's auc: 0.991161
# [929]	valid_0's auc: 0.991161
# [930]	valid_0's auc: 0.991161
# [931]	valid_0's auc: 0.991159
# [932]	valid_0's auc: 0.99116
# [933]	valid_0's auc: 0.99116
# [934]	valid_0's auc: 0.99116
# [935]	valid_0's auc: 0.99116
# [936]	valid_0's auc: 0.99116
# [937]	valid_0's auc: 0.991162
# [938]	valid_0's auc: 0.991162
# [939]	valid_0's auc: 0.991162
# [940]	valid_0's auc: 0.991162
# [941]	valid_0's auc: 0.991162
# [942]	valid_0's auc: 0.991162
# [943]	valid_0's auc: 0.991162
# [944]	valid_0's auc: 0.991162
# [945]	valid_0's auc: 0.991162
# [946]	valid_0's auc: 0.991162
# [947]	valid_0's auc: 0.991162
# [948]	valid_0's auc: 0.991162
# [949]	valid_0's auc: 0.991162
# [950]	valid_0's auc: 0.991162
# [951]	valid_0's auc: 0.99116
# [952]	valid_0's auc: 0.99116
# [953]	valid_0's auc: 0.99116
# [954]	valid_0's auc: 0.991162
# [955]	valid_0's auc: 0.991161
# [956]	valid_0's auc: 0.99116
# [957]	valid_0's auc: 0.991161
# [958]	valid_0's auc: 0.991161
# [959]	valid_0's auc: 0.991162
# [960]	valid_0's auc: 0.991163
# [961]	valid_0's auc: 0.991164
# [962]	valid_0's auc: 0.991164
# [963]	valid_0's auc: 0.991164
# [964]	valid_0's auc: 0.991165
# [965]	valid_0's auc: 0.991165
# [966]	valid_0's auc: 0.991166
# [967]	valid_0's auc: 0.991166
# [968]	valid_0's auc: 0.991166
# [969]	valid_0's auc: 0.991166
# [970]	valid_0's auc: 0.991166
# [971]	valid_0's auc: 0.991166
# [972]	valid_0's auc: 0.991166
# [973]	valid_0's auc: 0.991167
# [974]	valid_0's auc: 0.991168
# [975]	valid_0's auc: 0.991167
# [976]	valid_0's auc: 0.991167
# [977]	valid_0's auc: 0.991167
# [978]	valid_0's auc: 0.991167
# [979]	valid_0's auc: 0.991167
# [980]	valid_0's auc: 0.991167
# [981]	valid_0's auc: 0.991168
# [982]	valid_0's auc: 0.991168
# [983]	valid_0's auc: 0.991168
# [984]	valid_0's auc: 0.991168
# [985]	valid_0's auc: 0.991168
# [986]	valid_0's auc: 0.991168
# [987]	valid_0's auc: 0.991168
# [988]	valid_0's auc: 0.991168
# [989]	valid_0's auc: 0.991169
# [990]	valid_0's auc: 0.991169
# [991]	valid_0's auc: 0.991169
# [992]	valid_0's auc: 0.99117
# [993]	valid_0's auc: 0.99117
# [994]	valid_0's auc: 0.991171
# [995]	valid_0's auc: 0.991171
# [996]	valid_0's auc: 0.99117
# [997]	valid_0's auc: 0.991172
# [998]	valid_0's auc: 0.991171
# [999]	valid_0's auc: 0.991171
# [1000]	valid_0's auc: 0.991171
# [1001]	valid_0's auc: 0.991171
# [1002]	valid_0's auc: 0.991171
# [1003]	valid_0's auc: 0.991171
# [1004]	valid_0's auc: 0.991172
# [1005]	valid_0's auc: 0.991172
# [1006]	valid_0's auc: 0.991172
# [1007]	valid_0's auc: 0.991173
# [1008]	valid_0's auc: 0.991172
# [1009]	valid_0's auc: 0.991172
# [1010]	valid_0's auc: 0.991172
# [1011]	valid_0's auc: 0.991173
# [1012]	valid_0's auc: 0.991173
# [1013]	valid_0's auc: 0.991172
# [1014]	valid_0's auc: 0.991172
# [1015]	valid_0's auc: 0.991172
# [1016]	valid_0's auc: 0.991173
# [1017]	valid_0's auc: 0.991174
# [1018]	valid_0's auc: 0.991175
# [1019]	valid_0's auc: 0.991175
# [1020]	valid_0's auc: 0.991175
# [1021]	valid_0's auc: 0.991175
# [1022]	valid_0's auc: 0.991175
# [1023]	valid_0's auc: 0.991177
# [1024]	valid_0's auc: 0.991177
# [1025]	valid_0's auc: 0.991178
# [1026]	valid_0's auc: 0.991178
# [1027]	valid_0's auc: 0.991179
# [1028]	valid_0's auc: 0.991179
# [1029]	valid_0's auc: 0.991179
# [1030]	valid_0's auc: 0.99118
# [1031]	valid_0's auc: 0.991179
# [1032]	valid_0's auc: 0.991178
# [1033]	valid_0's auc: 0.991179
# [1034]	valid_0's auc: 0.991179
# [1035]	valid_0's auc: 0.991179
# [1036]	valid_0's auc: 0.991178
# [1037]	valid_0's auc: 0.991179
# [1038]	valid_0's auc: 0.99118
# [1039]	valid_0's auc: 0.991181
# [1040]	valid_0's auc: 0.991183
# [1041]	valid_0's auc: 0.991183
# [1042]	valid_0's auc: 0.991183
# [1043]	valid_0's auc: 0.99118
# [1044]	valid_0's auc: 0.991181
# [1045]	valid_0's auc: 0.991181
# [1046]	valid_0's auc: 0.99118
# [1047]	valid_0's auc: 0.99118
# [1048]	valid_0's auc: 0.99118
# [1049]	valid_0's auc: 0.99118
# [1050]	valid_0's auc: 0.99118
# [1051]	valid_0's auc: 0.99118
# [1052]	valid_0's auc: 0.991183
# [1053]	valid_0's auc: 0.991184
# [1054]	valid_0's auc: 0.991185
# [1055]	valid_0's auc: 0.991184
# [1056]	valid_0's auc: 0.991186
# [1057]	valid_0's auc: 0.991186
# [1058]	valid_0's auc: 0.991186
# [1059]	valid_0's auc: 0.991185
# [1060]	valid_0's auc: 0.991185
# [1061]	valid_0's auc: 0.991186
# [1062]	valid_0's auc: 0.991187
# [1063]	valid_0's auc: 0.991187
# [1064]	valid_0's auc: 0.991188
# [1065]	valid_0's auc: 0.991188
# [1066]	valid_0's auc: 0.991189
# [1067]	valid_0's auc: 0.99119
# [1068]	valid_0's auc: 0.99119
# [1069]	valid_0's auc: 0.99119
# [1070]	valid_0's auc: 0.991191
# [1071]	valid_0's auc: 0.991191
# [1072]	valid_0's auc: 0.991191
# [1073]	valid_0's auc: 0.991191
# [1074]	valid_0's auc: 0.991191
# [1075]	valid_0's auc: 0.991191
# [1076]	valid_0's auc: 0.991191
# [1077]	valid_0's auc: 0.991191
# [1078]	valid_0's auc: 0.991192
# [1079]	valid_0's auc: 0.991193
# [1080]	valid_0's auc: 0.991191
# [1081]	valid_0's auc: 0.991191
# [1082]	valid_0's auc: 0.991192
# [1083]	valid_0's auc: 0.991192
# [1084]	valid_0's auc: 0.991192
# [1085]	valid_0's auc: 0.991192
# [1086]	valid_0's auc: 0.991191
# [1087]	valid_0's auc: 0.991193
# [1088]	valid_0's auc: 0.991193
# [1089]	valid_0's auc: 0.991193
# [1090]	valid_0's auc: 0.991193
# [1091]	valid_0's auc: 0.991193
# [1092]	valid_0's auc: 0.991194
# [1093]	valid_0's auc: 0.991194
# [1094]	valid_0's auc: 0.991194
# [1095]	valid_0's auc: 0.991194
# [1096]	valid_0's auc: 0.991194
# [1097]	valid_0's auc: 0.991193
# [1098]	valid_0's auc: 0.991193
# [1099]	valid_0's auc: 0.991194
# [1100]	valid_0's auc: 0.991194
# [1101]	valid_0's auc: 0.991195
# [1102]	valid_0's auc: 0.991196
# [1103]	valid_0's auc: 0.991194
# [1104]	valid_0's auc: 0.991194
# [1105]	valid_0's auc: 0.991195
# [1106]	valid_0's auc: 0.991195
# [1107]	valid_0's auc: 0.991194
# [1108]	valid_0's auc: 0.991195
# [1109]	valid_0's auc: 0.991195
# [1110]	valid_0's auc: 0.991195
# [1111]	valid_0's auc: 0.991196
# [1112]	valid_0's auc: 0.991197
# [1113]	valid_0's auc: 0.991197
# [1114]	valid_0's auc: 0.991197
# [1115]	valid_0's auc: 0.991197
# [1116]	valid_0's auc: 0.991197
# [1117]	valid_0's auc: 0.991197
# [1118]	valid_0's auc: 0.991197
# [1119]	valid_0's auc: 0.991197
# [1120]	valid_0's auc: 0.991197
# [1121]	valid_0's auc: 0.991197
# [1122]	valid_0's auc: 0.991197
# [1123]	valid_0's auc: 0.991198
# [1124]	valid_0's auc: 0.991199
# [1125]	valid_0's auc: 0.991199
# [1126]	valid_0's auc: 0.991199
# [1127]	valid_0's auc: 0.9912
# [1128]	valid_0's auc: 0.9912
# [1129]	valid_0's auc: 0.9912
# [1130]	valid_0's auc: 0.9912
# [1131]	valid_0's auc: 0.991201
# [1132]	valid_0's auc: 0.991201
# [1133]	valid_0's auc: 0.991201
# [1134]	valid_0's auc: 0.991201
# [1135]	valid_0's auc: 0.9912
# [1136]	valid_0's auc: 0.9912
# [1137]	valid_0's auc: 0.9912
# [1138]	valid_0's auc: 0.9912
# [1139]	valid_0's auc: 0.9912
# [1140]	valid_0's auc: 0.9912
# [1141]	valid_0's auc: 0.9912
# [1142]	valid_0's auc: 0.991199
# [1143]	valid_0's auc: 0.9912
# [1144]	valid_0's auc: 0.9912
# [1145]	valid_0's auc: 0.9912
# [1146]	valid_0's auc: 0.9912
# [1147]	valid_0's auc: 0.991201
# [1148]	valid_0's auc: 0.9912
# [1149]	valid_0's auc: 0.991201
# [1150]	valid_0's auc: 0.991202
# [1151]	valid_0's auc: 0.991201
# [1152]	valid_0's auc: 0.991201
# [1153]	valid_0's auc: 0.991202
# [1154]	valid_0's auc: 0.991201
# [1155]	valid_0's auc: 0.991202
# [1156]	valid_0's auc: 0.991202
# [1157]	valid_0's auc: 0.991203
# [1158]	valid_0's auc: 0.991204
# [1159]	valid_0's auc: 0.991203
# [1160]	valid_0's auc: 0.991203
# [1161]	valid_0's auc: 0.991203
# [1162]	valid_0's auc: 0.991204
# [1163]	valid_0's auc: 0.991204
# [1164]	valid_0's auc: 0.991204
# [1165]	valid_0's auc: 0.991205
# [1166]	valid_0's auc: 0.991206
# [1167]	valid_0's auc: 0.991206
# [1168]	valid_0's auc: 0.991207
# [1169]	valid_0's auc: 0.991208
# [1170]	valid_0's auc: 0.991208
# [1171]	valid_0's auc: 0.991208
# [1172]	valid_0's auc: 0.991207
# [1173]	valid_0's auc: 0.991207
# [1174]	valid_0's auc: 0.991208
# [1175]	valid_0's auc: 0.991209
# [1176]	valid_0's auc: 0.99121
# [1177]	valid_0's auc: 0.991211
# [1178]	valid_0's auc: 0.991211
# [1179]	valid_0's auc: 0.991211
# [1180]	valid_0's auc: 0.991212
# [1181]	valid_0's auc: 0.991212
# [1182]	valid_0's auc: 0.991213
# [1183]	valid_0's auc: 0.991213
# [1184]	valid_0's auc: 0.991213
# [1185]	valid_0's auc: 0.991214
# [1186]	valid_0's auc: 0.991214
# [1187]	valid_0's auc: 0.991214
# [1188]	valid_0's auc: 0.991214
# [1189]	valid_0's auc: 0.991214
# [1190]	valid_0's auc: 0.991214
# [1191]	valid_0's auc: 0.991214
# [1192]	valid_0's auc: 0.991214
# [1193]	valid_0's auc: 0.991214
# [1194]	valid_0's auc: 0.991215
# [1195]	valid_0's auc: 0.991215
# [1196]	valid_0's auc: 0.991215
# [1197]	valid_0's auc: 0.991215
# [1198]	valid_0's auc: 0.991215
# [1199]	valid_0's auc: 0.991216
# [1200]	valid_0's auc: 0.991216
# [1201]	valid_0's auc: 0.991216
# [1202]	valid_0's auc: 0.991216
# [1203]	valid_0's auc: 0.991216
# [1204]	valid_0's auc: 0.991216
# [1205]	valid_0's auc: 0.991216
# [1206]	valid_0's auc: 0.991217
# [1207]	valid_0's auc: 0.991217
# [1208]	valid_0's auc: 0.991218
# [1209]	valid_0's auc: 0.991218
# [1210]	valid_0's auc: 0.991218
# [1211]	valid_0's auc: 0.991218
# [1212]	valid_0's auc: 0.991218
# [1213]	valid_0's auc: 0.991218
# [1214]	valid_0's auc: 0.991219
# [1215]	valid_0's auc: 0.991219
# [1216]	valid_0's auc: 0.99122
# [1217]	valid_0's auc: 0.99122
# [1218]	valid_0's auc: 0.991221
# [1219]	valid_0's auc: 0.991219
# [1220]	valid_0's auc: 0.991219
# [1221]	valid_0's auc: 0.991219
# [1222]	valid_0's auc: 0.99122
# [1223]	valid_0's auc: 0.99122
# [1224]	valid_0's auc: 0.991221
# [1225]	valid_0's auc: 0.99122
# [1226]	valid_0's auc: 0.991219
# [1227]	valid_0's auc: 0.99122
# [1228]	valid_0's auc: 0.99122
# [1229]	valid_0's auc: 0.991221
# [1230]	valid_0's auc: 0.991221
# [1231]	valid_0's auc: 0.991221
# [1232]	valid_0's auc: 0.991221
# [1233]	valid_0's auc: 0.991221
# [1234]	valid_0's auc: 0.99122
# [1235]	valid_0's auc: 0.99122
# [1236]	valid_0's auc: 0.991222
# [1237]	valid_0's auc: 0.991222
# [1238]	valid_0's auc: 0.991222
# [1239]	valid_0's auc: 0.991222
# [1240]	valid_0's auc: 0.991222
# [1241]	valid_0's auc: 0.991223
# [1242]	valid_0's auc: 0.991223
# [1243]	valid_0's auc: 0.991223
# [1244]	valid_0's auc: 0.991223
# [1245]	valid_0's auc: 0.991223
# [1246]	valid_0's auc: 0.991222
# [1247]	valid_0's auc: 0.991222
# [1248]	valid_0's auc: 0.991222
# [1249]	valid_0's auc: 0.991223
# [1250]	valid_0's auc: 0.991222
# [1251]	valid_0's auc: 0.991222
# [1252]	valid_0's auc: 0.991222
# [1253]	valid_0's auc: 0.991222
# [1254]	valid_0's auc: 0.991222
# [1255]	valid_0's auc: 0.991222
# [1256]	valid_0's auc: 0.991222
# [1257]	valid_0's auc: 0.991223
# [1258]	valid_0's auc: 0.991222
# [1259]	valid_0's auc: 0.991221
# [1260]	valid_0's auc: 0.991222
# [1261]	valid_0's auc: 0.991223
# [1262]	valid_0's auc: 0.991223
# [1263]	valid_0's auc: 0.991223
# [1264]	valid_0's auc: 0.991222
# [1265]	valid_0's auc: 0.991222
# [1266]	valid_0's auc: 0.991222
# [1267]	valid_0's auc: 0.991222
# [1268]	valid_0's auc: 0.991223
# [1269]	valid_0's auc: 0.991224
# [1270]	valid_0's auc: 0.991224
# [1271]	valid_0's auc: 0.991222
# [1272]	valid_0's auc: 0.991223
# [1273]	valid_0's auc: 0.991223
# [1274]	valid_0's auc: 0.991223
# [1275]	valid_0's auc: 0.991223
# [1276]	valid_0's auc: 0.991224
# [1277]	valid_0's auc: 0.991224
# [1278]	valid_0's auc: 0.991224
# [1279]	valid_0's auc: 0.991224
# [1280]	valid_0's auc: 0.991224
# [1281]	valid_0's auc: 0.991225
# [1282]	valid_0's auc: 0.991225
# [1283]	valid_0's auc: 0.991223
# [1284]	valid_0's auc: 0.991223
# [1285]	valid_0's auc: 0.991223
# [1286]	valid_0's auc: 0.991221
# [1287]	valid_0's auc: 0.991221
# [1288]	valid_0's auc: 0.991221
# [1289]	valid_0's auc: 0.991221
# [1290]	valid_0's auc: 0.991221
# [1291]	valid_0's auc: 0.991222
# [1292]	valid_0's auc: 0.991222
# [1293]	valid_0's auc: 0.991222
# [1294]	valid_0's auc: 0.991223
# [1295]	valid_0's auc: 0.991223
# [1296]	valid_0's auc: 0.991222
# [1297]	valid_0's auc: 0.991223
# [1298]	valid_0's auc: 0.991223
# [1299]	valid_0's auc: 0.991223
# [1300]	valid_0's auc: 0.991222
# [1301]	valid_0's auc: 0.991223
# [1302]	valid_0's auc: 0.991223
# [1303]	valid_0's auc: 0.991223
# [1304]	valid_0's auc: 0.991223
# [1305]	valid_0's auc: 0.991224
# [1306]	valid_0's auc: 0.991224
# [1307]	valid_0's auc: 0.991224
# [1308]	valid_0's auc: 0.991225
# [1309]	valid_0's auc: 0.991225
# [1310]	valid_0's auc: 0.991225
# [1311]	valid_0's auc: 0.991225
# [1312]	valid_0's auc: 0.991225
# [1313]	valid_0's auc: 0.991226
# [1314]	valid_0's auc: 0.991226
# [1315]	valid_0's auc: 0.991226
# [1316]	valid_0's auc: 0.991226
# [1317]	valid_0's auc: 0.991226
# [1318]	valid_0's auc: 0.991227
# [1319]	valid_0's auc: 0.991226
# [1320]	valid_0's auc: 0.991226
# [1321]	valid_0's auc: 0.991226
# [1322]	valid_0's auc: 0.991226
# [1323]	valid_0's auc: 0.991226
# [1324]	valid_0's auc: 0.991226
# [1325]	valid_0's auc: 0.991226
# [1326]	valid_0's auc: 0.991227
# [1327]	valid_0's auc: 0.991227
# [1328]	valid_0's auc: 0.991228
# [1329]	valid_0's auc: 0.991228
# [1330]	valid_0's auc: 0.991228
# [1331]	valid_0's auc: 0.991229
# [1332]	valid_0's auc: 0.991229
# [1333]	valid_0's auc: 0.991229
# [1334]	valid_0's auc: 0.991229
# [1335]	valid_0's auc: 0.991229
# [1336]	valid_0's auc: 0.991229
# [1337]	valid_0's auc: 0.991229
# [1338]	valid_0's auc: 0.991229
# [1339]	valid_0's auc: 0.99123
# [1340]	valid_0's auc: 0.99123
# [1341]	valid_0's auc: 0.99123
# [1342]	valid_0's auc: 0.99123
# [1343]	valid_0's auc: 0.99123
# [1344]	valid_0's auc: 0.991231
# [1345]	valid_0's auc: 0.991228
# [1346]	valid_0's auc: 0.991228
# [1347]	valid_0's auc: 0.991229
# [1348]	valid_0's auc: 0.991229
# [1349]	valid_0's auc: 0.991229
# [1350]	valid_0's auc: 0.991228
# [1351]	valid_0's auc: 0.991229
# [1352]	valid_0's auc: 0.991228
# [1353]	valid_0's auc: 0.991228
# [1354]	valid_0's auc: 0.991228
# [1355]	valid_0's auc: 0.991228
# [1356]	valid_0's auc: 0.991228
# [1357]	valid_0's auc: 0.991228
# [1358]	valid_0's auc: 0.991228
# [1359]	valid_0's auc: 0.991229
# [1360]	valid_0's auc: 0.991229
# [1361]	valid_0's auc: 0.991229
# [1362]	valid_0's auc: 0.991229
# [1363]	valid_0's auc: 0.991229
# [1364]	valid_0's auc: 0.991229
# [1365]	valid_0's auc: 0.991229
# [1366]	valid_0's auc: 0.991229
# [1367]	valid_0's auc: 0.991229
# [1368]	valid_0's auc: 0.991229
# [1369]	valid_0's auc: 0.991229
# [1370]	valid_0's auc: 0.991229
# [1371]	valid_0's auc: 0.99123
# [1372]	valid_0's auc: 0.99123
# [1373]	valid_0's auc: 0.99123
# [1374]	valid_0's auc: 0.99123
# [1375]	valid_0's auc: 0.99123
# [1376]	valid_0's auc: 0.99123
# [1377]	valid_0's auc: 0.99123
# [1378]	valid_0's auc: 0.99123
# [1379]	valid_0's auc: 0.99123
# [1380]	valid_0's auc: 0.99123
# [1381]	valid_0's auc: 0.991231
# [1382]	valid_0's auc: 0.99123
# [1383]	valid_0's auc: 0.99123
# [1384]	valid_0's auc: 0.99123
# [1385]	valid_0's auc: 0.99123
# [1386]	valid_0's auc: 0.99123
# [1387]	valid_0's auc: 0.99123
# [1388]	valid_0's auc: 0.991231
# [1389]	valid_0's auc: 0.991231
# [1390]	valid_0's auc: 0.991231
# [1391]	valid_0's auc: 0.991232
# [1392]	valid_0's auc: 0.991232
# [1393]	valid_0's auc: 0.991232
# [1394]	valid_0's auc: 0.991233
# [1395]	valid_0's auc: 0.991233
# [1396]	valid_0's auc: 0.991233
# [1397]	valid_0's auc: 0.991233
# [1398]	valid_0's auc: 0.991233
# [1399]	valid_0's auc: 0.991234
# [1400]	valid_0's auc: 0.991234
# [1401]	valid_0's auc: 0.991234
# [1402]	valid_0's auc: 0.991233
# [1403]	valid_0's auc: 0.991233
# [1404]	valid_0's auc: 0.991234
# [1405]	valid_0's auc: 0.991234
# [1406]	valid_0's auc: 0.991234
# [1407]	valid_0's auc: 0.991234
# [1408]	valid_0's auc: 0.991235
# [1409]	valid_0's auc: 0.991235
# [1410]	valid_0's auc: 0.991235
# [1411]	valid_0's auc: 0.991235
# [1412]	valid_0's auc: 0.991235
# [1413]	valid_0's auc: 0.991235
# [1414]	valid_0's auc: 0.991235
# [1415]	valid_0's auc: 0.991235
# [1416]	valid_0's auc: 0.991235
# [1417]	valid_0's auc: 0.991235
# [1418]	valid_0's auc: 0.991235
# [1419]	valid_0's auc: 0.991236
# [1420]	valid_0's auc: 0.991236
# [1421]	valid_0's auc: 0.991236
# [1422]	valid_0's auc: 0.991238
# [1423]	valid_0's auc: 0.991238
# [1424]	valid_0's auc: 0.991238
# [1425]	valid_0's auc: 0.991237
# [1426]	valid_0's auc: 0.991237
# [1427]	valid_0's auc: 0.991238
# [1428]	valid_0's auc: 0.991238
# [1429]	valid_0's auc: 0.991236
# [1430]	valid_0's auc: 0.991236
# [1431]	valid_0's auc: 0.991237
# [1432]	valid_0's auc: 0.991237
# [1433]	valid_0's auc: 0.991237
# [1434]	valid_0's auc: 0.991237
# [1435]	valid_0's auc: 0.991237
# [1436]	valid_0's auc: 0.991237
# [1437]	valid_0's auc: 0.991237
# [1438]	valid_0's auc: 0.991236
# [1439]	valid_0's auc: 0.991236
# [1440]	valid_0's auc: 0.991236
# [1441]	valid_0's auc: 0.991236
# [1442]	valid_0's auc: 0.991236
# [1443]	valid_0's auc: 0.991236
# [1444]	valid_0's auc: 0.991237
# [1445]	valid_0's auc: 0.991237
# [1446]	valid_0's auc: 0.991236
# [1447]	valid_0's auc: 0.991236
# [1448]	valid_0's auc: 0.991236
# [1449]	valid_0's auc: 0.991237
# [1450]	valid_0's auc: 0.991237
# [1451]	valid_0's auc: 0.991237
# [1452]	valid_0's auc: 0.991238
# [1453]	valid_0's auc: 0.991237
# [1454]	valid_0's auc: 0.991237
# [1455]	valid_0's auc: 0.991237
# [1456]	valid_0's auc: 0.991237
# [1457]	valid_0's auc: 0.991237
# [1458]	valid_0's auc: 0.991238
# [1459]	valid_0's auc: 0.991238
# [1460]	valid_0's auc: 0.991239
# [1461]	valid_0's auc: 0.991239
# [1462]	valid_0's auc: 0.991238
# [1463]	valid_0's auc: 0.991238
# [1464]	valid_0's auc: 0.991238
# [1465]	valid_0's auc: 0.991237
# [1466]	valid_0's auc: 0.991237
# [1467]	valid_0's auc: 0.991238
# [1468]	valid_0's auc: 0.991238
# [1469]	valid_0's auc: 0.991238
# [1470]	valid_0's auc: 0.991238
# [1471]	valid_0's auc: 0.991239
# [1472]	valid_0's auc: 0.991238
# [1473]	valid_0's auc: 0.991239
# [1474]	valid_0's auc: 0.991239
# [1475]	valid_0's auc: 0.991239
# [1476]	valid_0's auc: 0.991239
# [1477]	valid_0's auc: 0.991239
# [1478]	valid_0's auc: 0.99124
# [1479]	valid_0's auc: 0.99124
# [1480]	valid_0's auc: 0.99124
# [1481]	valid_0's auc: 0.99124
# [1482]	valid_0's auc: 0.99124
# [1483]	valid_0's auc: 0.991241
# [1484]	valid_0's auc: 0.991241
# [1485]	valid_0's auc: 0.991241
# [1486]	valid_0's auc: 0.991241
# [1487]	valid_0's auc: 0.991241
# [1488]	valid_0's auc: 0.991241
# [1489]	valid_0's auc: 0.991241
# [1490]	valid_0's auc: 0.991241
# [1491]	valid_0's auc: 0.991241
# [1492]	valid_0's auc: 0.991242
# [1493]	valid_0's auc: 0.991242
# [1494]	valid_0's auc: 0.991242
# [1495]	valid_0's auc: 0.991242
# [1496]	valid_0's auc: 0.991241
# [1497]	valid_0's auc: 0.991242
# [1498]	valid_0's auc: 0.991242
# [1499]	valid_0's auc: 0.991243
# [1500]	valid_0's auc: 0.991243
# [1501]	valid_0's auc: 0.991243
# [1502]	valid_0's auc: 0.991243
# [1503]	valid_0's auc: 0.991243
# [1504]	valid_0's auc: 0.991243
# [1505]	valid_0's auc: 0.991244
# [1506]	valid_0's auc: 0.991244
# [1507]	valid_0's auc: 0.991245
# [1508]	valid_0's auc: 0.991244
# [1509]	valid_0's auc: 0.991244
# [1510]	valid_0's auc: 0.991245
# [1511]	valid_0's auc: 0.991245
# [1512]	valid_0's auc: 0.991245
# [1513]	valid_0's auc: 0.991245
# [1514]	valid_0's auc: 0.991246
# [1515]	valid_0's auc: 0.991246
# [1516]	valid_0's auc: 0.991246
# [1517]	valid_0's auc: 0.991246
# [1518]	valid_0's auc: 0.991246
# [1519]	valid_0's auc: 0.991246
# [1520]	valid_0's auc: 0.991247
# [1521]	valid_0's auc: 0.991247
# [1522]	valid_0's auc: 0.991247
# [1523]	valid_0's auc: 0.991247
# [1524]	valid_0's auc: 0.991247
# [1525]	valid_0's auc: 0.991246
# [1526]	valid_0's auc: 0.991247
# [1527]	valid_0's auc: 0.991247
# [1528]	valid_0's auc: 0.991247
# [1529]	valid_0's auc: 0.991247
# [1530]	valid_0's auc: 0.991247
# [1531]	valid_0's auc: 0.991247
# [1532]	valid_0's auc: 0.991246
# [1533]	valid_0's auc: 0.991247
# [1534]	valid_0's auc: 0.991247
# [1535]	valid_0's auc: 0.991247
# [1536]	valid_0's auc: 0.991247
# [1537]	valid_0's auc: 0.991248
# [1538]	valid_0's auc: 0.991247
# [1539]	valid_0's auc: 0.991248
# [1540]	valid_0's auc: 0.991248
# [1541]	valid_0's auc: 0.991248
# [1542]	valid_0's auc: 0.991249
# [1543]	valid_0's auc: 0.991249
# [1544]	valid_0's auc: 0.991249
# [1545]	valid_0's auc: 0.991249
# [1546]	valid_0's auc: 0.991249
# [1547]	valid_0's auc: 0.991249
# [1548]	valid_0's auc: 0.991249
# [1549]	valid_0's auc: 0.991249
# [1550]	valid_0's auc: 0.991248
# [1551]	valid_0's auc: 0.991248
# [1552]	valid_0's auc: 0.991248
# [1553]	valid_0's auc: 0.991248
# [1554]	valid_0's auc: 0.991248
# [1555]	valid_0's auc: 0.991248
# [1556]	valid_0's auc: 0.991249
# [1557]	valid_0's auc: 0.991248
# [1558]	valid_0's auc: 0.991248
# [1559]	valid_0's auc: 0.991247
# [1560]	valid_0's auc: 0.991247
# [1561]	valid_0's auc: 0.991248
# [1562]	valid_0's auc: 0.991248
# [1563]	valid_0's auc: 0.991248
# [1564]	valid_0's auc: 0.991248
# [1565]	valid_0's auc: 0.991249
# [1566]	valid_0's auc: 0.991249
# [1567]	valid_0's auc: 0.991249
# [1568]	valid_0's auc: 0.99125
# [1569]	valid_0's auc: 0.99125
# [1570]	valid_0's auc: 0.991251
# [1571]	valid_0's auc: 0.99125
# [1572]	valid_0's auc: 0.991251
# [1573]	valid_0's auc: 0.991251
# [1574]	valid_0's auc: 0.991251
# [1575]	valid_0's auc: 0.991251
# [1576]	valid_0's auc: 0.991252
# [1577]	valid_0's auc: 0.991252
# [1578]	valid_0's auc: 0.991252
# [1579]	valid_0's auc: 0.991252
# [1580]	valid_0's auc: 0.991252
# [1581]	valid_0's auc: 0.991252
# [1582]	valid_0's auc: 0.991251
# [1583]	valid_0's auc: 0.991251
# [1584]	valid_0's auc: 0.991251
# [1585]	valid_0's auc: 0.991251
# [1586]	valid_0's auc: 0.991252
# [1587]	valid_0's auc: 0.991252
# [1588]	valid_0's auc: 0.991252
# ...
# [1640]	valid_0's auc: 0.99126
# [1641]	valid_0's auc: 0.99126
# [1642]	valid_0's auc: 0.99126
# [1643]	valid_0's auc: 0.99126
# [1644]	valid_0's auc: 0.99126
# [1645]	valid_0's auc: 0.991261
# [1646]	valid_0's auc: 0.991261
# [1647]	valid_0's auc: 0.991261
# [1648]	valid_0's auc: 0.991261
# [1649]	valid_0's auc: 0.991261
# [1650]	valid_0's auc: 0.991263
# [1651]	valid_0's auc: 0.991263
# [1652]	valid_0's auc: 0.991262
# [1653]	valid_0's auc: 0.991262
# [1654]	valid_0's auc: 0.991263
# [1655]	valid_0's auc: 0.991261
# [1656]	valid_0's auc: 0.991261
# [1657]	valid_0's auc: 0.991262
# [1658]	valid_0's auc: 0.991262
# [1659]	valid_0's auc: 0.991262
# [1660]	valid_0's auc: 0.991262
# [1661]	valid_0's auc: 0.991262
# [1662]	valid_0's auc: 0.991262
# [1663]	valid_0's auc: 0.991262
# [1664]	valid_0's auc: 0.991263
# [1665]	valid_0's auc: 0.991263
# [1666]	valid_0's auc: 0.991263
# [1667]	valid_0's auc: 0.991263
# [1668]	valid_0's auc: 0.991263
# [1669]	valid_0's auc: 0.991264
# [1670]	valid_0's auc: 0.991265
# [1671]	valid_0's auc: 0.991265
# [1672]	valid_0's auc: 0.991265
# [1673]	valid_0's auc: 0.991265
# [1674]	valid_0's auc: 0.991265
# [1675]	valid_0's auc: 0.991265
# [1676]	valid_0's auc: 0.991265
# [1677]	valid_0's auc: 0.991265
# [1678]	valid_0's auc: 0.991265
# [1679]	valid_0's auc: 0.991265
# [1680]	valid_0's auc: 0.991265
# [1681]	valid_0's auc: 0.991266
# [1682]	valid_0's auc: 0.991267
# [1683]	valid_0's auc: 0.991266
# [1684]	valid_0's auc: 0.991267
# [1685]	valid_0's auc: 0.991266
# [1686]	valid_0's auc: 0.991265
# [1687]	valid_0's auc: 0.991265
# [1688]	valid_0's auc: 0.991265
# [1689]	valid_0's auc: 0.991264
# [1690]	valid_0's auc: 0.991264
# [1691]	valid_0's auc: 0.991264
# [1692]	valid_0's auc: 0.991264
# [1693]	valid_0's auc: 0.991264
# [1694]	valid_0's auc: 0.991264
# [1695]	valid_0's auc: 0.991265
# [1696]	valid_0's auc: 0.991265
# [1697]	valid_0's auc: 0.991265
# [1698]	valid_0's auc: 0.991265
# [1699]	valid_0's auc: 0.991265
# [1700]	valid_0's auc: 0.991265
# [1701]	valid_0's auc: 0.991266
# [1702]	valid_0's auc: 0.991267
# [1703]	valid_0's auc: 0.991268
# [1704]	valid_0's auc: 0.991269
# [1705]	valid_0's auc: 0.991269
# [1706]	valid_0's auc: 0.991269
# [1707]	valid_0's auc: 0.991269
# [1708]	valid_0's auc: 0.991269
# [1709]	valid_0's auc: 0.99127
# [1710]	valid_0's auc: 0.99127
# [1711]	valid_0's auc: 0.991269
# [1712]	valid_0's auc: 0.991269
# [1713]	valid_0's auc: 0.99127
# [1714]	valid_0's auc: 0.991269
# [1715]	valid_0's auc: 0.991269
# [1716]	valid_0's auc: 0.991269
# [1717]	valid_0's auc: 0.99127
# [1718]	valid_0's auc: 0.99127
# [1719]	valid_0's auc: 0.99127
# [1720]	valid_0's auc: 0.99127
# [1721]	valid_0's auc: 0.991269
# [1722]	valid_0's auc: 0.99127
# [1723]	valid_0's auc: 0.99127
# [1724]	valid_0's auc: 0.991269
# [1725]	valid_0's auc: 0.99127
# [1726]	valid_0's auc: 0.991271
# [1727]	valid_0's auc: 0.991271
# [1728]	valid_0's auc: 0.991271
# [1729]	valid_0's auc: 0.991271
# [1730]	valid_0's auc: 0.991271
# [1731]	valid_0's auc: 0.991271
# [1732]	valid_0's auc: 0.991271
# [1733]	valid_0's auc: 0.991271
# [1734]	valid_0's auc: 0.991271
# [1735]	valid_0's auc: 0.991272
# [1736]	valid_0's auc: 0.991272
# [1737]	valid_0's auc: 0.991272
# [1738]	valid_0's auc: 0.991272
# [1739]	valid_0's auc: 0.991273
# [1740]	valid_0's auc: 0.991273
# [1741]	valid_0's auc: 0.991273
# [1742]	valid_0's auc: 0.991273
# [1743]	valid_0's auc: 0.991273
# [1744]	valid_0's auc: 0.991273
# [1745]	valid_0's auc: 0.991273
# [1746]	valid_0's auc: 0.991273
# [1747]	valid_0's auc: 0.991273
# [1748]	valid_0's auc: 0.991274
# [1749]	valid_0's auc: 0.991274
# [1750]	valid_0's auc: 0.991275
# [1751]	valid_0's auc: 0.991275
# [1752]	valid_0's auc: 0.991275
# [1753]	valid_0's auc: 0.991276
# [1754]	valid_0's auc: 0.991276
# [1755]	valid_0's auc: 0.991278
# [1756]	valid_0's auc: 0.991277
# [1757]	valid_0's auc: 0.991278
# [1758]	valid_0's auc: 0.991278
# [1759]	valid_0's auc: 0.991278
# [1760]	valid_0's auc: 0.991279
# [1761]	valid_0's auc: 0.991279
# [1762]	valid_0's auc: 0.991279
# [1763]	valid_0's auc: 0.991279
# [1764]	valid_0's auc: 0.991279
# [1765]	valid_0's auc: 0.991279
# [1766]	valid_0's auc: 0.991279
# [1767]	valid_0's auc: 0.991278
# [1768]	valid_0's auc: 0.991278
# [1769]	valid_0's auc: 0.991278
# [1770]	valid_0's auc: 0.991278
# [1771]	valid_0's auc: 0.991278
# [1772]	valid_0's auc: 0.991278
# [1773]	valid_0's auc: 0.991278
# [1774]	valid_0's auc: 0.991279
# [1775]	valid_0's auc: 0.991279
# [1776]	valid_0's auc: 0.99128
# [1777]	valid_0's auc: 0.991279
# [1778]	valid_0's auc: 0.99128
# [1779]	valid_0's auc: 0.991279
# [1780]	valid_0's auc: 0.991279
# [1781]	valid_0's auc: 0.991281
# [1782]	valid_0's auc: 0.991281
# [1783]	valid_0's auc: 0.991281
# [1784]	valid_0's auc: 0.991283
# [1785]	valid_0's auc: 0.991283
# [1786]	valid_0's auc: 0.991283
# [1787]	valid_0's auc: 0.991284
# [1788]	valid_0's auc: 0.991283
# [1789]	valid_0's auc: 0.991283
# [1790]	valid_0's auc: 0.991282
# [1791]	valid_0's auc: 0.991283
# [1792]	valid_0's auc: 0.991283
# [1793]	valid_0's auc: 0.991283
# [1794]	valid_0's auc: 0.991282
# [1795]	valid_0's auc: 0.991282
# [1796]	valid_0's auc: 0.991283
# [1797]	valid_0's auc: 0.991282
# [1798]	valid_0's auc: 0.991282
# [1799]	valid_0's auc: 0.991282
# [1800]	valid_0's auc: 0.991282
# [1801]	valid_0's auc: 0.991282
# [1802]	valid_0's auc: 0.991282
# [1803]	valid_0's auc: 0.991283
# [1804]	valid_0's auc: 0.991283
# [1805]	valid_0's auc: 0.991282
# [1806]	valid_0's auc: 0.991283
# [1807]	valid_0's auc: 0.991283
# [1808]	valid_0's auc: 0.991284
# [1809]	valid_0's auc: 0.991284
# [1810]	valid_0's auc: 0.991284
# [1811]	valid_0's auc: 0.991284
# [1812]	valid_0's auc: 0.991284
# [1813]	valid_0's auc: 0.991284
# [1814]	valid_0's auc: 0.991284
# [1815]	valid_0's auc: 0.991284
# [1816]	valid_0's auc: 0.991283
# [1817]	valid_0's auc: 0.991284
# [1818]	valid_0's auc: 0.991284
# [1819]	valid_0's auc: 0.991284
# [1820]	valid_0's auc: 0.991285
# [1821]	valid_0's auc: 0.991285
# [1822]	valid_0's auc: 0.991285
# [1823]	valid_0's auc: 0.991285
# [1824]	valid_0's auc: 0.991285
# [1825]	valid_0's auc: 0.991285
# [1826]	valid_0's auc: 0.991285
# [1827]	valid_0's auc: 0.991285
# [1828]	valid_0's auc: 0.991286
# [1829]	valid_0's auc: 0.991286
# [1830]	valid_0's auc: 0.991285
# [1831]	valid_0's auc: 0.991286
# [1832]	valid_0's auc: 0.991286
# [1833]	valid_0's auc: 0.991286
# [1834]	valid_0's auc: 0.991286
# [1835]	valid_0's auc: 0.991286
# [1836]	valid_0's auc: 0.991286
# [1837]	valid_0's auc: 0.991286
# [1838]	valid_0's auc: 0.991286
# [1839]	valid_0's auc: 0.991285
# [1840]	valid_0's auc: 0.991285
# [1841]	valid_0's auc: 0.991285
# [1842]	valid_0's auc: 0.991286
# [1843]	valid_0's auc: 0.991286
# [1844]	valid_0's auc: 0.991286
# [1845]	valid_0's auc: 0.991287
# [1846]	valid_0's auc: 0.991286
# [1847]	valid_0's auc: 0.991286
# [1848]	valid_0's auc: 0.991287
# [1849]	valid_0's auc: 0.991287
# [1850]	valid_0's auc: 0.991287
# [1851]	valid_0's auc: 0.991287
# [1852]	valid_0's auc: 0.991287
# [1853]	valid_0's auc: 0.991287
# [1854]	valid_0's auc: 0.991287
# [1855]	valid_0's auc: 0.991287
# [1856]	valid_0's auc: 0.991286
# [1857]	valid_0's auc: 0.991287
# [1858]	valid_0's auc: 0.991288
# [1859]	valid_0's auc: 0.991288
# [1860]	valid_0's auc: 0.991288
# [1861]	valid_0's auc: 0.991287
# [1862]	valid_0's auc: 0.991287
# [1863]	valid_0's auc: 0.991287
# [1864]	valid_0's auc: 0.991288
# [1865]	valid_0's auc: 0.991288
# [1866]	valid_0's auc: 0.991288
# [1867]	valid_0's auc: 0.991288
# [1868]	valid_0's auc: 0.991288
# [1869]	valid_0's auc: 0.991289
# [1870]	valid_0's auc: 0.991289
# [1871]	valid_0's auc: 0.991289
# [1872]	valid_0's auc: 0.991289
# [1873]	valid_0's auc: 0.991289
# [1874]	valid_0's auc: 0.991289
# [1875]	valid_0's auc: 0.991289
# [1876]	valid_0's auc: 0.991289
# [1877]	valid_0's auc: 0.991289
# [1878]	valid_0's auc: 0.991289
# [1879]	valid_0's auc: 0.991289
# [1880]	valid_0's auc: 0.991289
# [1881]	valid_0's auc: 0.991289
# [1882]	valid_0's auc: 0.991289
# [1883]	valid_0's auc: 0.991289
# [1884]	valid_0's auc: 0.991289
# [1885]	valid_0's auc: 0.991289
# [1886]	valid_0's auc: 0.991289
# [1887]	valid_0's auc: 0.991289
# [1888]	valid_0's auc: 0.991289
# [1889]	valid_0's auc: 0.991289
# [1890]	valid_0's auc: 0.991289
# [1891]	valid_0's auc: 0.991289
# [1892]	valid_0's auc: 0.991289
# [1893]	valid_0's auc: 0.99129
# [1894]	valid_0's auc: 0.99129
# [1895]	valid_0's auc: 0.99129
# [1896]	valid_0's auc: 0.99129
# [1897]	valid_0's auc: 0.99129
# [1898]	valid_0's auc: 0.99129
# [1899]	valid_0's auc: 0.99129
# [1900]	valid_0's auc: 0.99129
# [1901]	valid_0's auc: 0.991289
# [1902]	valid_0's auc: 0.99129
# [1903]	valid_0's auc: 0.99129
# [1904]	valid_0's auc: 0.99129
# [1905]	valid_0's auc: 0.99129
# [1906]	valid_0's auc: 0.991291
# [1907]	valid_0's auc: 0.99129
# [1908]	valid_0's auc: 0.991291
# [1909]	valid_0's auc: 0.991291
# [1910]	valid_0's auc: 0.991291
# [1911]	valid_0's auc: 0.991291
# [1912]	valid_0's auc: 0.991291
# [1913]	valid_0's auc: 0.991292
# [1914]	valid_0's auc: 0.991292
# [1915]	valid_0's auc: 0.991292
# [1916]	valid_0's auc: 0.991292
# [1917]	valid_0's auc: 0.991292
# [1918]	valid_0's auc: 0.991293
# [1919]	valid_0's auc: 0.991293
# [1920]	valid_0's auc: 0.991292
# [1921]	valid_0's auc: 0.991292
# [1922]	valid_0's auc: 0.991293
# [1923]	valid_0's auc: 0.991293
# [1924]	valid_0's auc: 0.991293
# [1925]	valid_0's auc: 0.991293
# [1926]	valid_0's auc: 0.991293
# [1927]	valid_0's auc: 0.991293
# [1928]	valid_0's auc: 0.991294
# [1929]	valid_0's auc: 0.991294
# [1930]	valid_0's auc: 0.991294
# [1931]	valid_0's auc: 0.991294
# [1932]	valid_0's auc: 0.991294
# [1933]	valid_0's auc: 0.991294
# [1934]	valid_0's auc: 0.991294
# [1935]	valid_0's auc: 0.991294
# [1936]	valid_0's auc: 0.991295
# [1937]	valid_0's auc: 0.991296
# [1938]	valid_0's auc: 0.991296
# [1939]	valid_0's auc: 0.991295
# [1940]	valid_0's auc: 0.991296
# [1941]	valid_0's auc: 0.991296
# [1942]	valid_0's auc: 0.991296
# [1943]	valid_0's auc: 0.991296
# [1944]	valid_0's auc: 0.991296
# [1945]	valid_0's auc: 0.991297
# [1946]	valid_0's auc: 0.991297
# [1947]	valid_0's auc: 0.991297
# [1948]	valid_0's auc: 0.991297
# [1949]	valid_0's auc: 0.991298
# [1950]	valid_0's auc: 0.991298
# [1951]	valid_0's auc: 0.991298
# [1952]	valid_0's auc: 0.991299
# [1953]	valid_0's auc: 0.991299
# [1954]	valid_0's auc: 0.991299
# [1955]	valid_0's auc: 0.991298
# [1956]	valid_0's auc: 0.991299
# [1957]	valid_0's auc: 0.991299
# [1958]	valid_0's auc: 0.9913
# [1959]	valid_0's auc: 0.9913
# [1960]	valid_0's auc: 0.991299
# [1961]	valid_0's auc: 0.991299
# [1962]	valid_0's auc: 0.9913
# [1963]	valid_0's auc: 0.9913
# [1964]	valid_0's auc: 0.9913
# [1965]	valid_0's auc: 0.991301
# [1966]	valid_0's auc: 0.991301
# [1967]	valid_0's auc: 0.991301
# [1968]	valid_0's auc: 0.991301
# [1969]	valid_0's auc: 0.991301
# [1970]	valid_0's auc: 0.9913
# [1971]	valid_0's auc: 0.991301
# [1972]	valid_0's auc: 0.991301
# [1973]	valid_0's auc: 0.991301
# [1974]	valid_0's auc: 0.991301
# [1975]	valid_0's auc: 0.991301
# [1976]	valid_0's auc: 0.991301
# [1977]	valid_0's auc: 0.991301
# [1978]	valid_0's auc: 0.9913
# [1979]	valid_0's auc: 0.991301
# [1980]	valid_0's auc: 0.991301
# [1981]	valid_0's auc: 0.9913
# [1982]	valid_0's auc: 0.9913
# [1983]	valid_0's auc: 0.9913
# [1984]	valid_0's auc: 0.9913
# [1985]	valid_0's auc: 0.9913
# [1986]	valid_0's auc: 0.9913
# [1987]	valid_0's auc: 0.9913
# [1988]	valid_0's auc: 0.991299
# [1989]	valid_0's auc: 0.991299
# [1990]	valid_0's auc: 0.9913
# [1991]	valid_0's auc: 0.9913
# [1992]	valid_0's auc: 0.991299
# [1993]	valid_0's auc: 0.9913
# [1994]	valid_0's auc: 0.9913
# [1995]	valid_0's auc: 0.9913
# [1996]	valid_0's auc: 0.991299
# [1997]	valid_0's auc: 0.991299
# [1998]	valid_0's auc: 0.991299
# [1999]	valid_0's auc: 0.9913
# [2000]	valid_0's auc: 0.991301
# [2001]	valid_0's auc: 0.991302
# [2002]	valid_0's auc: 0.991302
# [2003]	valid_0's auc: 0.991302
# [2004]	valid_0's auc: 0.991302
# [2005]	valid_0's auc: 0.991302
# [2006]	valid_0's auc: 0.991302
# [2007]	valid_0's auc: 0.991302
# [2008]	valid_0's auc: 0.991303
# [2009]	valid_0's auc: 0.991303
# [2010]	valid_0's auc: 0.991303
# [2011]	valid_0's auc: 0.991304
# [2012]	valid_0's auc: 0.991304
# [2013]	valid_0's auc: 0.991304
# [2014]	valid_0's auc: 0.991304
# [2015]	valid_0's auc: 0.991303
# [2016]	valid_0's auc: 0.991303
# [2017]	valid_0's auc: 0.991303
# [2018]	valid_0's auc: 0.991303
# [2019]	valid_0's auc: 0.991303
# [2020]	valid_0's auc: 0.991303
# [2021]	valid_0's auc: 0.991303
# [2022]	valid_0's auc: 0.991303
# [2023]	valid_0's auc: 0.991303
# [2024]	valid_0's auc: 0.991303
# [2025]	valid_0's auc: 0.991304
# [2026]	valid_0's auc: 0.991304
# [2027]	valid_0's auc: 0.991304
# [2028]	valid_0's auc: 0.991304
# [2029]	valid_0's auc: 0.991304
# [2030]	valid_0's auc: 0.991304
# [2031]	valid_0's auc: 0.991304
# [2032]	valid_0's auc: 0.991305
# [2033]	valid_0's auc: 0.991305
# [2034]	valid_0's auc: 0.991305
# [2035]	valid_0's auc: 0.991305
# [2036]	valid_0's auc: 0.991305
# [2037]	valid_0's auc: 0.991306
# [2038]	valid_0's auc: 0.991306
# [2039]	valid_0's auc: 0.991306
# [2040]	valid_0's auc: 0.991306
# [2041]	valid_0's auc: 0.991305
# [2042]	valid_0's auc: 0.991305
# [2043]	valid_0's auc: 0.991306
# [2044]	valid_0's auc: 0.991306
# [2045]	valid_0's auc: 0.991306
# [2046]	valid_0's auc: 0.991306
# [2047]	valid_0's auc: 0.991307
# [2048]	valid_0's auc: 0.991307
# [2049]	valid_0's auc: 0.991306
# [2050]	valid_0's auc: 0.991307
# [2051]	valid_0's auc: 0.991306
# [2052]	valid_0's auc: 0.991307
# [2053]	valid_0's auc: 0.991306
# [2054]	valid_0's auc: 0.991306
# [2055]	valid_0's auc: 0.991306
# [2056]	valid_0's auc: 0.991306
# [2057]	valid_0's auc: 0.991306
# [2058]	valid_0's auc: 0.991306
# [2059]	valid_0's auc: 0.991306
# [2060]	valid_0's auc: 0.991306
# [2061]	valid_0's auc: 0.991306
# [2062]	valid_0's auc: 0.991306
# [2063]	valid_0's auc: 0.991307
# [2064]	valid_0's auc: 0.991306
# [2065]	valid_0's auc: 0.991307
# [2066]	valid_0's auc: 0.991306
# [2067]	valid_0's auc: 0.991306
# [2068]	valid_0's auc: 0.991307
# [2069]	valid_0's auc: 0.991306
# [2070]	valid_0's auc: 0.991307
# [2071]	valid_0's auc: 0.991307
# [2072]	valid_0's auc: 0.991307
# [2073]	valid_0's auc: 0.991306
# [2074]	valid_0's auc: 0.991306
# [2075]	valid_0's auc: 0.991305
# [2076]	valid_0's auc: 0.991305
# [2077]	valid_0's auc: 0.991304
# [2078]	valid_0's auc: 0.991304
# [2079]	valid_0's auc: 0.991304
# [2080]	valid_0's auc: 0.991304
# [2081]	valid_0's auc: 0.991304
# [2082]	valid_0's auc: 0.991304
# [2083]	valid_0's auc: 0.991304
# [2084]	valid_0's auc: 0.991304
# [2085]	valid_0's auc: 0.991304
# [2086]	valid_0's auc: 0.991304
# [2087]	valid_0's auc: 0.991304
# [2088]	valid_0's auc: 0.991305
# [2089]	valid_0's auc: 0.991303
# [2090]	valid_0's auc: 0.991303
# [2091]	valid_0's auc: 0.991303
# [2092]	valid_0's auc: 0.991303
# [2093]	valid_0's auc: 0.991303
# [2094]	valid_0's auc: 0.991302
# [2095]	valid_0's auc: 0.991303
# [2096]	valid_0's auc: 0.991303
# [2097]	valid_0's auc: 0.991302
# [2098]	valid_0's auc: 0.991302
# [2099]	valid_0's auc: 0.991302
# [2100]	valid_0's auc: 0.991302
# [2101]	valid_0's auc: 0.991302
# [2102]	valid_0's auc: 0.991302
# [2103]	valid_0's auc: 0.991303
# [2104]	valid_0's auc: 0.991303
# [2105]	valid_0's auc: 0.991303
# [2106]	valid_0's auc: 0.991303
# [2107]	valid_0's auc: 0.991303
# [2108]	valid_0's auc: 0.991302
# [2109]	valid_0's auc: 0.991302
# [2110]	valid_0's auc: 0.991302
# [2111]	valid_0's auc: 0.991302
# [2112]	valid_0's auc: 0.991302
# [2113]	valid_0's auc: 0.991302
# [2114]	valid_0's auc: 0.991303
# [2115]	valid_0's auc: 0.991303
# [2116]	valid_0's auc: 0.991303
# [2117]	valid_0's auc: 0.991303
# [2118]	valid_0's auc: 0.991303
# [2119]	valid_0's auc: 0.991303
# [2120]	valid_0's auc: 0.991303
# [2121]	valid_0's auc: 0.991302
# [2122]	valid_0's auc: 0.991302
# [2123]	valid_0's auc: 0.991302
# [2124]	valid_0's auc: 0.991302
# [2125]	valid_0's auc: 0.991302
# [2126]	valid_0's auc: 0.991302
# [2127]	valid_0's auc: 0.991303
# [2128]	valid_0's auc: 0.991302
# [2129]	valid_0's auc: 0.991302
# [2130]	valid_0's auc: 0.991302
# [2131]	valid_0's auc: 0.991302
# [2132]	valid_0's auc: 0.991301
# [2133]	valid_0's auc: 0.991301
# [2134]	valid_0's auc: 0.991301
# [2135]	valid_0's auc: 0.991302
# [2136]	valid_0's auc: 0.991302
# [2137]	valid_0's auc: 0.991302
# [2138]	valid_0's auc: 0.991303
# [2139]	valid_0's auc: 0.991303
# [2140]	valid_0's auc: 0.991303
# [2141]	valid_0's auc: 0.991303
# [2142]	valid_0's auc: 0.991303
# [2143]	valid_0's auc: 0.991303
# [2144]	valid_0's auc: 0.991304
# [2145]	valid_0's auc: 0.991304
# [2146]	valid_0's auc: 0.991304
# [2147]	valid_0's auc: 0.991304
# [2148]	valid_0's auc: 0.991304
# Early stopping, best iteration is:
# [2048]	valid_0's auc: 0.991307
# save model: /content/drive/MyDrive/Kaggle/Foursquare/models/train_lgbm_recall_name_iou_0624_001/lgb_fold1.pkl
# CPU times: user 11h 34min 55s, sys: 44.8 s, total: 11h 35min 40s
# Wall time: 1h 45min 19s

# %%
# int_cols = ['s_co_net', 's_adjacency_frequency', 't_adjacency_frequency', 't_co_net']
# float_cols = ['t_clustering_coefficient', 's_clustering_coefficient', 's_betweeness_centrality', 't_betweeness_centrality']
# for col in int_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)
    
# for col in float_cols:
#     train.loc[train[col]=='nan', col] = np.nan
#     train.loc[~train[col].isnull(), col] = train.loc[~train[col].isnull(), col] .astype(float)

# %%
cv = (oof.argmax(axis=-1) == train["label"].astype(int)).mean()
print(f"CV-accuracy: {cv}")
# 0.9726
# Out:
# CV-accuracy: 0.9657039610710557

# %%
importance_df = pd.DataFrame(models[0].feature_importances_, 
                             index=features, 
                             columns=['importance'])\
                    .sort_values("importance", ascending=False)


plt.figure(figsize=(20, 10))
sns.barplot(x="importance", y="index", data=importance_df.head(30).reset_index(drop=False))
plt.show()

# %%
del train_X, train_y, valid_X, valid_y, models

# %% [markdown]
# # Change Submission Format

# %%
tmp = train[['id', 'match_id', 'label']]
tmp[['pred_0', 'pred_1']] = oof

# %%
tmp.to_csv(os.path.join(OUTPUT_PATH, 'oof.csv'), index = False)

# %% [markdown]
# ### memoryリセットかけた

# %%
oof = pd.read_csv(os.path.join(OUTPUT_PATH, 'oof.csv'))
oof.head()
# Out:
#                  id          match_id  label    pred_0    pred_1
# 0  E_000002eae2a589  E_000002eae2a589      1  0.000004  0.999996
# 1  E_000007f24ebc95  E_000007f24ebc95      1  0.000029  0.999971
# 2  E_000008a8ba4f48  E_000008a8ba4f48      1  0.000008  0.999992
# 3  E_00001d92066153  E_00001d92066153      1  0.000003  0.999997
# 4  E_000023d8f4be44  E_000023d8f4be44      1  0.000004  0.999996

# %%
y_true = pd.read_csv(os.path.join(INPUT_PATH, 'train.csv'))[['id', 'point_of_interest']]
def get_id2poi(input_df: pd.DataFrame) -> dict:
    return dict(zip(input_df['id'], input_df['point_of_interest']))

def get_poi2ids(input_df: pd.DataFrame) -> dict:
    return input_df.groupby('point_of_interest')['id'].apply(set).to_dict()

id2poi = get_id2poi(y_true)
poi2ids = get_poi2ids(y_true)
del y_true

# %%
ids = list(oof.id.unique())
oof_pred = {
   id_x: [id_x] for id_x in ids
}

for idx, row in tqdm(oof.iterrows()):
    if row['pred_0'] < row['pred_1']:
        oof_pred[row['id']].append(row['match_id'])
# Out:
# 0it [00:00, ?it/s]

# %%
scores = []
for id_x in tqdm(ids):
    preds = set(oof_pred[id_x])
    targets = poi2ids[id2poi[id_x]]
    score = len((targets & preds)) / len((targets | preds))
    scores.append(score)
print('cv score is', np.array(scores).mean())
# 0.8643
# 0.8655
# Out:
#   0%|          | 0/1138812 [00:00<?, ?it/s]
# cv score is 0.8637817684459473

# %% [markdown]
# # Check Misclassification

# %%
oof['pred'] = oof['pred_1'].round()
tmp = oof[['id', 'match_id', 'label', 'pred', 'pred_1']]

# %%
t = tmp[tmp['label']!=tmp['pred']]
tt = t[t['pred_1']<0.2]

# %%
len(t)
# Out:
# 351177

# %%
tt
# Out:
#                         id          match_id  label  pred    pred_1
# 1856      E_00dcbf399a3c66  E_1d401732135818      1   0.0  0.011808
# 4461      E_020e76b9a1aadf  E_9fcab1f6916cf5      1   0.0  0.112397
# 9905      E_04852c224633d4  E_1d401732135818      1   0.0  0.000399
# 24529     E_0b0cce8f893902  E_1d401732135818      1   0.0  0.001068
# 56283     E_1949df04eeb0f2  E_1d401732135818      1   0.0  0.005025
# ...                    ...               ...    ...   ...       ...
# 10239215  E_fbc7e55e9f2125  E_0ebf876b47a817      1   0.0  0.104191
# 10239233  E_fc0d4fc04aa6fe  E_f83e473226d964      1   0.0  0.162517
# 10239273  E_fc8eace7feadfc  E_d85e06a47237d2      1   0.0  0.032958
# 10239424  E_fe43e9366d948a  E_c75dfa321e03dc      1   0.0  0.017536
# 10239519  E_ff6ce9b5e1e7ad  E_5de505da9bf8e2      1   0.0  0.093900
#
# [131995 rows x 5 columns]

# %%
id = 'E_0146e712d66bb8'
m_id = 'E_512009c07275bc'
ids = [id, m_id]
data[data.index.isin(ids)]
# data[data.id.isin(ids)]
# Out:
#                                                                name  \
# id
# E_0146e712d66bb8  guccitong ming nan shi yi dai  yi bi yi yuan d...
# E_512009c07275bc  tan suo  kun lun gao fang wan biao  yi bi yi y...
#
#                    latitude  longitude  \
# id
# E_0146e712d66bb8  38.415602 -95.925751
# E_512009c07275bc  38.415602 -95.925751
#
#                                                             address city  \
# id
# E_0146e712d66bb8  oe         1143            a           1143   ...
# E_512009c07275bc  lh             1143 88 8                      ...
#
#                  state  zip country  url phone  ... state_split   cv co_net  \
# id                                              ...
# E_0146e712d66bb8    KS  NaN      US  NaN   NaN  ...        [KS]  0.0   -1.0
# E_512009c07275bc    KS  NaN      US  NaN   NaN  ...        [KS]  0.0   -1.0
#
#                           main_category scale adjacency_frequency  \
# id
# E_0146e712d66bb8  Ethiopian Restaurants     0                 NaN
# E_512009c07275bc  Ethiopian Restaurants     0                 NaN
#
#                   betweeness_centrality  clustering_coefficient  \
# id
# E_0146e712d66bb8                    NaN                     NaN
# E_512009c07275bc                    NaN                     NaN
#
#                  median_distances_median  category_rate
# id
# E_0146e712d66bb8                     0.0        0.00113
# E_512009c07275bc                     0.0        0.00113
#
# [2 rows x 25 columns]

# %%
train[(train['id']==id) & (train['match_id']==m_id)][['kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven']]
# Out:
# Empty DataFrame
# Columns: [kdist, categories_jaro, name_jaro, categories_lcs, name_tfidf_sim, name_leven, name_nleven]
# Index: []

# %%
train.name_lcs.min()
# Out:
# 0

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==0)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                        id          match_id  kdist  categories_jaro  \
# 24923    E_05968db3eae9d8  E_f2631dac113cc9    0.0              1.0
# 79749    E_11d4647dcc2093  E_c55a9728cf1ad4    0.0              1.0
# 272059   E_3d173cf36ea045  E_5fdb53e0f88509    0.0              1.0
# 408955   E_5be60953b0015f  E_0bab9eb45a7363    0.0              1.0
# 425857   E_5faff0ea77b622  E_8ba6cfb8818ac2    0.0              1.0
# ...                   ...               ...    ...              ...
# 708652   E_9f2c4360daa6b0  E_a534324f5cee01    0.0              1.0
# 754621   E_a9836ce1f2fda4  E_a6ac1d78e8ccb8    0.0              1.0
# 837524   E_bc14a8427db6be  E_caf447b497ce4e    0.0              1.0
# 1041319  E_e9f9bbed668045  E_a6ac1d78e8ccb8    0.0              1.0
# 1078567  E_f260f8e20c9a57  E_5b8747d303a1f4    0.0              1.0
#
#          name_jaro  categories_lcs  name_tfidf_sim  name_leven  name_nleven  \
# 24923          1.0            20.0             1.0           0          0.0
# 79749          1.0             4.0             1.0           0          0.0
# 272059         1.0            46.0             1.0           0          0.0
# 408955         1.0            18.0             1.0           0          0.0
# 425857         1.0            12.0             1.0           0          0.0
# ...            ...             ...             ...         ...          ...
# 708652         1.0             5.0             1.0           0          0.0
# 754621         1.0             5.0             1.0           0          0.0
# 837524         1.0             5.0             1.0           0          0.0
# 1041319        1.0             5.0             1.0           0          0.0
# 1078567        1.0             5.0             1.0           0          0.0
#
#          label
# 24923        0
# 79749        0
# 272059       0
# 408955       0
# 425857       0
# ...        ...
# 708652       0
# 754621       0
# 837524       0
# 1041319      0
# 1078567      0
#
# [102 rows x 10 columns]

# %%
train[
    (train['kdist']==0.0) &
    (train['categories_jaro']==1.0) & 
    (train['name_jaro']==1.0) & 
    (train['label']==1)
][['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                      id          match_id  kdist  categories_jaro  name_jaro  \
# 1      E_000002eae2a589  E_000002eae2a589    0.0              1.0        1.0
# 2      E_000007f24ebc95  E_000007f24ebc95    0.0              1.0        1.0
# 3      E_000008a8ba4f48  E_000008a8ba4f48    0.0              1.0        1.0
# 4      E_00001d92066153  E_00001d92066153    0.0              1.0        1.0
# 5      E_000023d8f4be44  E_000023d8f4be44    0.0              1.0        1.0
# ...                 ...               ...    ...              ...        ...
# 25384  E_05aff53ddd7f6c  E_05aff53ddd7f6c    0.0              1.0        1.0
# 62226  E_0def1629f08239  E_0def1629f08239    0.0              1.0        1.0
# 68032  E_0f39fad86242ed  E_0f39fad86242ed    0.0              1.0        1.0
# 25919  E_05ce3e833e0f2e  E_05ce3e833e0f2e    0.0              1.0        1.0
# 35691  E_080027ca1a3b0a  E_080027ca1a3b0a    0.0              1.0        1.0
#
#        categories_lcs  name_tfidf_sim  name_leven  name_nleven  label
# 1                21.0             1.0           0          0.0      1
# 2                20.0             1.0           0          0.0      1
# 3                18.0             1.0           0          0.0      1
# 4                19.0             1.0           0          0.0      1
# 5                 4.0             1.0           0          0.0      1
# ...               ...             ...         ...          ...    ...
# 25384            21.0             1.0           0          0.0      1
# 62226            21.0             1.0           0          0.0      1
# 68032            21.0             1.0           0          0.0      1
# 25919            21.0             1.0           0          0.0      1
# 35691            21.0             1.0           0          0.0      1
#
# [1042754 rows x 10 columns]

# %%
train.head(20)[['id', 'match_id', 'kdist', 'categories_jaro', 'name_jaro', 'categories_lcs', 'name_tfidf_sim', 'name_leven', 'name_nleven', 'label']]
# Out:
#                   id          match_id  kdist  categories_jaro  name_jaro  \
# 1   E_000002eae2a589  E_000002eae2a589    0.0              1.0        1.0
# 2   E_000007f24ebc95  E_000007f24ebc95    0.0              1.0        1.0
# 3   E_000008a8ba4f48  E_000008a8ba4f48    0.0              1.0        1.0
# 4   E_00001d92066153  E_00001d92066153    0.0              1.0        1.0
# 5   E_000023d8f4be44  E_000023d8f4be44    0.0              1.0        1.0
# 6   E_00002a131a2bf6  E_00002a131a2bf6    0.0              1.0        1.0
# 7   E_0000764d65557e  E_0000764d65557e    0.0              1.0        1.0
# 8   E_00007dcd2bb53f  E_00007dcd2bb53f    0.0              1.0        1.0
# 9   E_0000890af22ff5  E_0000890af22ff5    0.0              1.0        1.0
# 14  E_0000f17c539685  E_0000f17c539685    0.0              1.0        1.0
# 16  E_00011cca3f0bd6  E_00011cca3f0bd6    0.0              1.0        1.0
# 17  E_00014f107dc217  E_00014f107dc217    0.0              1.0        1.0
# 20  E_000177396ded71  E_000177396ded71    0.0              1.0        1.0
# 21  E_0001827d6b4ee2  E_0001827d6b4ee2    0.0              1.0        1.0
# 22  E_000184ea12d0f0  E_000184ea12d0f0    0.0              1.0        1.0
# 23  E_0001968548bde2  E_0001968548bde2    0.0              NaN        1.0
# 25  E_0001a397f67ad5  E_0001a397f67ad5    0.0              1.0        1.0
# 26  E_0001b37c96a0ff  E_0001b37c96a0ff    0.0              1.0        1.0
# 27  E_0001e184ce8606  E_0001e184ce8606    0.0              1.0        1.0
# 29  E_00021310ea7a71  E_00021310ea7a71    0.0              1.0        1.0
#
#     categories_lcs  name_tfidf_sim  name_leven  name_nleven  label
# 1             21.0             1.0           0          0.0      1
# 2             20.0             1.0           0          0.0      1
# 3             18.0             1.0           0          0.0      1
# 4             19.0             1.0           0          0.0      1
# 5              4.0             1.0           0          0.0      1
# 6             17.0             1.0           0          0.0      1
# 7             21.0             1.0           0          0.0      1
# 8             15.0             1.0           0          0.0      1
# 9             12.0             1.0           0          0.0      1
# 14            10.0             1.0           0          0.0      1
# 16            15.0             1.0           0          0.0      1
# 17            18.0             1.0           0          0.0      1
# 20             7.0             1.0           0          0.0      1
# 21            15.0             1.0           0          0.0      1
# 22            17.0             1.0           0          0.0      1
# 23             NaN             1.0           0          0.0      1
# 25            10.0             1.0           0          0.0      1
# 26            28.0             1.0           0          0.0      1
# 27            17.0             1.0           0          0.0      1
# 29             9.0             1.0           0          0.0      1

# %%
# cols = ['kdist_country', 'kdist', 'categories_jaro', 'name_jaro']
# train[(train['id']==id) & (train['match_id']==m_id)][cols]

# %%
# train[train['kdist_country']== train['kdist']]

# %%
# data[data.index.isin(ids)].loc['E_34199c1154c0d9']['name'].split()

# %%
# data[data.index.isin(ids)].loc['E_0258802b17b98e']['name'].split()
